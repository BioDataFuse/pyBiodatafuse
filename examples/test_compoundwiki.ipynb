# %% [markdown]
# # Example: CompoundWiki

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")

if src_path not in sys.path:
    sys.path.insert(0, src_path)

print("PYTHONPATH:", sys.path[0])
# Out:
# PYTHONPATH: c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src

# %%
# Import modules
import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import intact, kegg, compoundwiki, pubchem, molmedb, opentargets
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# # Load list of metabolites/chemicals/compounds

# %%
metabolites_of_interest = """15377
15361
15422
17234
16199
18211
57540
16865
15347
32952
35107
"""

metabolite_list = metabolites_of_interest.split("\n")
len(metabolite_list)
# Out:
# 12

# %%
data_input = pd.DataFrame(metabolite_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0      15377
# 1      15361
# 2      15422
# 3      17234
# 4      16199

# %% [markdown]
# ### Entity resolution using BridgeDB

# %%
bridgedb_compound_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species="Human",
    input_datasource="ChEBI",
    output_datasource="All",
)
bridgedb_compound_df.head(10)
# Out:
#   identifier identifier.source                       target    target.source
# 0      15377             ChEBI                       D00001        KEGG Drug
# 1      15377             ChEBI                  CHEBI:15377            ChEBI
# 2      15377             ChEBI                  HMDB0002111             HMDB
# 3      15377             ChEBI  XLYOFNOQVPJJNP-UHFFFAOYSA-N         InChIKey
# 4      15377             ChEBI                    HMDB02111             HMDB
# 5      15377             ChEBI                         Q283         Wikidata
# 6      15377             ChEBI                          937       ChemSpider
# 7      15377             ChEBI                      DB09145         DrugBank
# 8      15377             ChEBI                CHEMBL1098659  ChEMBL compound
# 9      15377             ChEBI                    7732-18-5              CAS

# %% [markdown]
# ### Compound Interactions from IntAct

# %%
intact_compound_df, intact_compound_metadata = intact.get_compound_interactions(
    bridgedb_compound_df, interaction_type="both"
)
intact_compound_df.head(10)
# Out:
# Querying IntAct for compounds: 100%|██████████| 2/2 [00:04<00:00,  2.01s/it]
# c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src\pyBiodatafuse\annotators\intact.py:422: UserWarning: The intermediate_df in IntAct annotator should be checked, please create an issue on https://github.com/BioDataFuse/pyBiodatafuse/issues/.
#   give_annotator_warning(Cons.INTACT)
#   identifier identifier.source       target target.source  \
# 0      15377             ChEBI  CHEBI:15377         ChEBI
# 1      15361             ChEBI  CHEBI:15361         ChEBI
# 2      15422             ChEBI  CHEBI:15422         ChEBI
# 3      17234             ChEBI  CHEBI:17234         ChEBI
# 4      16199             ChEBI  CHEBI:16199         ChEBI
# 5      18211             ChEBI  CHEBI:18211         ChEBI
# 6      57540             ChEBI  CHEBI:57540         ChEBI
# 7      16865             ChEBI  CHEBI:16865         ChEBI
# 8      15347             ChEBI  CHEBI:15347         ChEBI
# ...

# %%
intact_compound_df["IntAct_compound_interactions"][2]
# Out:
# [{'interaction_id': 'EBI-9007503',
#   'interactor_id_A': 'EBI-1108845',
#   'interactor_id_B': 'EBI-1108845',
#   'score': 0.71,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'competitor',
#   'type': 'direct interaction',
#   'detection_method': 'crosslink',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'atp',
#   'interactor_B_name': 'atp',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'atp',
#   'molecule_B': 'atp',
#   'id_A': 'CHEBI:15422',
#   'id_B': 'CHEBI:15422',
#   'pubmed_publication_id': '22331906',
#   'intact_link_to': '15422'},
#  {'interaction_id': 'EBI-26605262',
#   'interactor_id_A': 'EBI-1108845',
#   'interactor_id_B': 'EBI-1108845',
#   'score': 0.71,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'stimulator',
#   'type': 'direct interaction',
#   'detection_method': 'light microscopy',
# ...

# %%
combined_df = combine_sources(
    bridgedb_compound_df,
    [
        intact_compound_df, 
    ],
)

# %%
combined_df.head()
# Out:
#   identifier identifier.source  target     target.source  \
# 0      15377             ChEBI     962  PubChem Compound
# 1      15361             ChEBI  107735  PubChem Compound
# 2      15422             ChEBI    5957  PubChem Compound
# 3      16199             ChEBI    1176  PubChem Compound
# 4      18211             ChEBI     833  PubChem Compound
#
#                         IntAct_compound_interactions
# 0  [{'interaction_id': nan, 'interactor_id_A': na...
# 1  [{'interaction_id': 'EBI-9301798', 'interactor...
# 2  [{'interaction_id': 'EBI-9007503', 'interactor...
# 3  [{'interaction_id': nan, 'interactor_id_A': na...
# 4  [{'interaction_id': nan, 'interactor_id_A': na...

# %%
combined_df, compoundwiki_metadata = compoundwiki.get_compound_annotations(combined_df)
# Out:
# Processing input identifiers for compounds...
# Querying BridgeDb for PubChem IDs from ChEBI...
# id_to_pubchem  {'15377': '962', '15361': '107735', '15422': '5957', '16199': '1176', '18211': '833', '57540': '15938971', '16865': '119', '15347': '180'}
# A:                                           propEntity  \
# 0   https://compoundcloud.wikibase.cloud/entity/P36
# 1   https://compoundcloud.wikibase.cloud/entity/P23
# 2   https://compoundcloud.wikibase.cloud/entity/P28
# 3   https://compoundcloud.wikibase.cloud/entity/P41
# 4   https://compoundcloud.wikibase.cloud/entity/P45
# 5   https://compoundcloud.wikibase.cloud/entity/P22
# 6   https://compoundcloud.wikibase.cloud/entity/P43
# 7   https://compoundcloud.wikibase.cloud/entity/P44
# 8    https://compoundcloud.wikibase.cloud/entity/P9
# 9   https://compoundcloud.wikibase.cloud/entity/P10
# 10  https://compoundcloud.wikibase.cloud/entity/P27
# 11  https://compoundcloud.wikibase.cloud/entity/P27
# ...

# %%
combined_df.head()
# Out:
#   identifier identifier.source  target     target.source  \
# 0      15377             ChEBI     962  PubChem Compound
# 1      15361             ChEBI  107735  PubChem Compound
# 2      15422             ChEBI    5957  PubChem Compound
# 3      16199             ChEBI    1176  PubChem Compound
# 4      18211             ChEBI     833  PubChem Compound
#
#                         IntAct_compound_interactions  \
# 0  [{'interaction_id': nan, 'interactor_id_A': na...
# 1  [{'interaction_id': 'EBI-9301798', 'interactor...
# 2  [{'interaction_id': 'EBI-9007503', 'interactor...
# 3  [{'interaction_id': nan, 'interactor_id_A': na...
# 4  [{'interaction_id': nan, 'interactor_id_A': na...
#
#                               CompoundWiki_compounds
# 0  [{'CAS Registry Number': nan, 'ChEBI ID': nan,...
# 1  [{'CAS Registry Number': nan, 'ChEBI ID': nan,...
# 2  [{'CAS Registry Number': '56-65-5', 'ChEBI ID'...
# 3  [{'CAS Registry Number': nan, 'ChEBI ID': nan,...
# ...

# %%
combined_df['IntAct_compound_interactions'][2]
# Out:
# [{'interaction_id': 'EBI-9007503',
#   'interactor_id_A': 'EBI-1108845',
#   'interactor_id_B': 'EBI-1108845',
#   'score': 0.71,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'competitor',
#   'type': 'direct interaction',
#   'detection_method': 'crosslink',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'atp',
#   'interactor_B_name': 'atp',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'atp',
#   'molecule_B': 'atp',
#   'id_A': 'CHEBI:15422',
#   'id_B': 'CHEBI:15422',
#   'pubmed_publication_id': '22331906',
#   'intact_link_to': '15422',
#   'CompoundWiki_compounds': [{'CAS Registry Number': '56-65-5',
#     'ChEBI ID': '15422',
#     'ChEMBL ID': 'CHEMBL14249',
#     'CosIng number': '31370',
#     'DSSTOX compound identifier': 'DTXCID302559',
#     'EC number': '200-283-2',
#     'ECHA Substance Infocard ID': '100.000.258',
# ...

# %%
pygraph = generator.build_networkx_graph(combined_df)
# Out:
# Building graph:   0%|          | 0/11 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pygraph = generator.build_networkx_graph(combined_df)
#
# File c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src\pyBiodatafuse\graph\generator.py:2421, in build_networkx_graph(combined_df, disease_compound, pathway_compound, homolog_df_list)
#    2417     return _built_gene_based_graph(
#    2418         g, combined_df, disease_compound, pathway_compound, homolog_df_list
#    2419     )
#    2420 elif main_target_type == Cons.PUBCHEM_COMPOUND:
# -> 2421     return _built_compound_based_graph(
#    2422         g, combined_df, disease_compound, pathway_compound, homolog_df_list
#    2423     )
#    2424 else:
#    2425     raise ValueError(f"Unsupported target type: {main_target_type}")
#
# ...

# %%
combined_df.shape
# Out:
# (2, 5)

# %%
from pyBiodatafuse.graph import cytoscape

cytoscape.load_graph(pygraph, network_name="Test network")
# Out:
# Applying default style...
# Applying preferred layout

# %%
genes_of_interest = """KCNJ5
SLC25A1"""

gene_list = genes_of_interest.split("\n")
len(gene_list)
# Out:
# 2

# %%
data_input = pd.DataFrame(gene_list, columns=["identifier"])
data_input.head()

input_species = "Human"

bridgedb_df, bridgedb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species=input_species,
    input_datasource="HGNC",
    output_datasource="All",
)

bridgedb_df.head(25)
# Out:
#    identifier identifier.source          target          target.source
# 0       KCNJ5              HGNC         3355874                   Affy
# 1       KCNJ5              HGNC         3355873                   Affy
# 2       KCNJ5              HGNC         3355871                   Affy
# 3       KCNJ5              HGNC      GO:0086091          Gene Ontology
# 4       KCNJ5              HGNC       HGNC:6266  HGNC Accession Number
# 5       KCNJ5              HGNC         3355877                   Affy
# 6       KCNJ5              HGNC      GO:0006813          Gene Ontology
# 7       KCNJ5              HGNC      GO:0016021          Gene Ontology
# 8       KCNJ5              HGNC      uc001qet.5    UCSC Genome Browser
# 9       KCNJ5              HGNC  208397_PM_x_at                   Affy
# 10      KCNJ5              HGNC         3355876                   Affy
# 11      KCNJ5              HGNC      GO:0016020          Gene Ontology
# ...

# %%
pubchem_df, pubchem_metadata = pubchem.get_protein_compound_screened(bridgedb_df)
pubchem_df.head(15)
# Out:
# Querying PubChem: 100%|██████████| 2/2 [00:07<00:00,  3.56s/it]
#    identifier identifier.source      target   target.source  \
# 0       BRCA1              HGNC  A0A024R1V0  Uniprot-TrEMBL
# 1       BRCA1              HGNC  A0A024R1Z8  Uniprot-TrEMBL
# 2       BRCA1              HGNC  A0A0A0MSN1  Uniprot-TrEMBL
# 3       BRCA1              HGNC  A0A0U1RRA9  Uniprot-TrEMBL
# 4       BRCA1              HGNC  A0A2R8Y587  Uniprot-TrEMBL
# 5       BRCA1              HGNC  A0A2R8Y6Y9  Uniprot-TrEMBL
# 6       BRCA1              HGNC  A0A2R8Y7V5  Uniprot-TrEMBL
# 7       BRCA1              HGNC  A0A494C182  Uniprot-TrEMBL
# 8       BRCA1              HGNC      B7ZA85  Uniprot-TrEMBL
# 9       BRCA1              HGNC      C6YB45  Uniprot-TrEMBL
# 10      BRCA1              HGNC      C9IZW4  Uniprot-TrEMBL
# 11      BRCA1              HGNC      E7ENB7  Uniprot-TrEMBL
# 12      BRCA1              HGNC      E7EQW4  Uniprot-TrEMBL
# 13      BRCA1              HGNC      E7EUM2  Uniprot-TrEMBL
# ...

# %%
pubchem_df.head(25)
# Out:
#    identifier identifier.source      target   target.source  \
# 0       BRCA1              HGNC  A0A024R1V0  Uniprot-TrEMBL
# 1       BRCA1              HGNC  A0A024R1Z8  Uniprot-TrEMBL
# 2       BRCA1              HGNC  A0A0A0MSN1  Uniprot-TrEMBL
# 3       BRCA1              HGNC  A0A0U1RRA9  Uniprot-TrEMBL
# 4       BRCA1              HGNC  A0A2R8Y587  Uniprot-TrEMBL
# 5       BRCA1              HGNC  A0A2R8Y6Y9  Uniprot-TrEMBL
# 6       BRCA1              HGNC  A0A2R8Y7V5  Uniprot-TrEMBL
# 7       BRCA1              HGNC  A0A494C182  Uniprot-TrEMBL
# 8       BRCA1              HGNC      B7ZA85  Uniprot-TrEMBL
# 9       BRCA1              HGNC      C6YB45  Uniprot-TrEMBL
# 10      BRCA1              HGNC      C9IZW4  Uniprot-TrEMBL
# 11      BRCA1              HGNC      E7ENB7  Uniprot-TrEMBL
# 12      BRCA1              HGNC      E7EQW4  Uniprot-TrEMBL
# 13      BRCA1              HGNC      E7EUM2  Uniprot-TrEMBL
# 14      BRCA1              HGNC      E7EWN5  Uniprot-TrEMBL
# ...

# %%
pubchem_df["PubChem_assays"][23]
# Out:
# [{'pubchem_assay_id': 'AID:504669',
#   'assay_type': 'IC50',
#   'outcome': 'active',
#   'compound_cid': 'CID:739449',
#   'compound_name': '2-nitro-N-quinolin-8-ylbenzenesulfonamide',
#   'smiles': 'C1=CC=C(C(=C1)[N+](=O)[O-])S(=O)(=O)NC2=CC=CC3=C2N=CC=C3',
#   'inchi': 'InChI=1S/C15H11N3O4S/c19-18(20)13-8-1-2-9-14(13)23(21,22)17-12-7-3-5-11-6-4-10-16-15(11)12/h1-10,17H'},
#  {'pubchem_assay_id': 'AID:504669',
#   'assay_type': 'IC50',
#   'outcome': 'active',
#   'compound_cid': 'CID:2539138',
#   'compound_name': '4-[2-(4,5-dichloro-6-oxopyridazin-1-yl)acetyl]-3,3-dimethyl-1H-quinoxalin-2-one',
#   'smiles': 'CC1(C(=O)NC2=CC=CC=C2N1C(=O)CN3C(=O)C(=C(C=N3)Cl)Cl)C',
#   'inchi': 'InChI=1S/C16H14Cl2N4O3/c1-16(2)15(25)20-10-5-3-4-6-11(10)22(16)12(23)8-21-14(24)13(18)9(17)7-19-21/h3-7H,8H2,1-2H3,(H,20,25)'},
#  {'pubchem_assay_id': 'AID:504669',
#   'assay_type': 'IC50',
#   'outcome': 'active',
#   'compound_cid': 'CID:1077343',
# ...

# %%
kegg_df["KEGG_pathways"][3]
# Out:
# [{'pathway_id': 'path:mmu00830',
#   'pathway_label': 'Retinol metabolism - Mus musculus (house mouse)',
#   'pathway_gene_counts': 101,
#   'pathway_compounds': [{'KEGG_id': 'C00376'},
#    {'KEGG_id': 'C00473'},
#    {'KEGG_id': 'C00777'},
#    {'KEGG_id': 'C00778'},
#    {'KEGG_id': 'C00899'},
#    {'KEGG_id': 'C02075'},
#    {'KEGG_id': 'C02094'},
#    {'KEGG_id': 'C02110'},
#    {'KEGG_id': 'C02588'},
#    {'KEGG_id': 'C03455'},
#    {'KEGG_id': 'C05914'},
#    {'KEGG_id': 'C05915'},
#    {'KEGG_id': 'C05916'},
#    {'KEGG_id': 'C05917'},
#    {'KEGG_id': 'C11061'},
#    {'KEGG_id': 'C15492'},
#    {'KEGG_id': 'C15493'},
#    {'KEGG_id': 'C16677'},
#    {'KEGG_id': 'C16678'},
#    {'KEGG_id': 'C16679'},
#    {'KEGG_id': 'C16680'},
#    {'KEGG_id': 'C16681'},
#    {'KEGG_id': 'C16682'},
#    {'KEGG_id': 'C16683'},
#    {'KEGG_id': 'C21797'}]},
#  {'pathway_id': 'path:mmu01100',
#   'pathway_label': 'Metabolic pathways - Mus musculus (house mouse)',
#   'pathway_gene_counts': 0,
# ...

# %%
compounds_of_interest ="""CID:739449
"""

metabolite_list = compounds_of_interest.split("\n")
data_input = pd.DataFrame(metabolite_list, columns=["identifier"])

bridgedb_df_cmp, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species="Human",
    input_datasource="PubChem Compound",
    output_datasource="All",
)
bridgedb_df_cmp.head(25)
# Out:
# Empty DataFrame
# Columns: [identifier.source, target, target.source, identifier]
# Index: []

# %%
kegg_compound_df = kegg.get_compounds(bridgedb_df_cmp)
kegg_compound_df.head()
# Out:
#   identifier identifier.source  target  target.source  \
# 0     C15492     KEGG Compound  C15492  KEGG Compound
# 1     C00473     KEGG Compound  C00473  KEGG Compound
# 2     C00473     KEGG Compound  C17276  KEGG Compound
# 3     C21797     KEGG Compound  C21797  KEGG Compound
#
#                                       KEGG_compounds
# 0  {'KEGG_id': 'C15492', 'KEGG_compound_name': 'a...
# 1  {'KEGG_id': 'C00473', 'KEGG_compound_name': 'R...
# 2  {'KEGG_id': 'C17276', 'KEGG_compound_name': 'R...
# 3  {'KEGG_id': 'C21797', 'KEGG_compound_name': 'a...

# %%
combined_df = combine_sources(
    bridgedb_df,
    [
        m_df,
    ],
)

# %%
combined_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0    SLC17A9              HGNC  ENSG00000101194       Ensembl
# 1    SLC17A9              HGNC  ENSG00000101194       Ensembl
# 2    SLC25A1              HGNC  ENSG00000100075       Ensembl
# 3    SLC25A1              HGNC  ENSG00000100075       Ensembl
# 4      KCNJ5              HGNC  ENSG00000120457       Ensembl
#
#                        MolMeDB_transporter_inhibitor
# 0  [{'MolMeDB_compound_name': 'MM17483', 'MolMeDB...
# 1  [{'MolMeDB_compound_name': 'MM17483', 'MolMeDB...
# 2  [{'MolMeDB_compound_name': nan, 'MolMeDB_inchi...
# 3  [{'MolMeDB_compound_name': nan, 'MolMeDB_inchi...
# 4  [{'MolMeDB_compound_name': 'Euphorbiaproliferi...

# %%
combined_df, compoundwiki_metadata = compoundwiki.get_compound_annotations(combined_df)
# Out:
# Processing input identifiers for compounds...
# Querying BridgeDb for PubChem IDs from HGNC...
# No PubChem Compound IDs found in BridgeDb result.
# Processing MolMeDB column for compounds...
# Querying BridgeDb for PubChem IDs from InChIKey...
# id_to_pubchem  {'ACSIXWWBWUQEHA-UHFFFAOYSA-N': '25419', 'BRVXVMOWTHQKHC-LVYIKVSWSA-N': '56928145'}
# A:  Empty DataFrame
# Columns: []
# Index: []

# %%
combined_df.head(50)
# Out:
#    identifier identifier.source           target target.source  \
# 0       BRCA1              HGNC  ENSG00000012048       Ensembl
# 1       BRCA1              HGNC  ENSG00000012048       Ensembl
# 2       BRCA1              HGNC  ENSG00000012048       Ensembl
# 3       BRCA1              HGNC  ENSG00000012048       Ensembl
# 4       BRCA1              HGNC  ENSG00000012048       Ensembl
# 5       BRCA1              HGNC  ENSG00000012048       Ensembl
# 6       BRCA1              HGNC  ENSG00000012048       Ensembl
# 7       BRCA1              HGNC  ENSG00000012048       Ensembl
# 8       BRCA1              HGNC  ENSG00000012048       Ensembl
# 9       BRCA1              HGNC  ENSG00000012048       Ensembl
# 10      BRCA1              HGNC  ENSG00000012048       Ensembl
# 11      BRCA1              HGNC  ENSG00000012048       Ensembl
# 12      BRCA1              HGNC  ENSG00000012048       Ensembl
# 13      BRCA1              HGNC  ENSG00000012048       Ensembl
# ...

# %%
combined_df["PubChem_assays"][23]
# Out:
# [{'pubchem_assay_id': 'AID:504669',
#   'assay_type': 'IC50',
#   'outcome': 'active',
#   'compound_cid': 'CID:739449',
#   'compound_name': '2-nitro-N-quinolin-8-ylbenzenesulfonamide',
#   'smiles': 'C1=CC=C(C(=C1)[N+](=O)[O-])S(=O)(=O)NC2=CC=CC3=C2N=CC=C3',
#   'inchi': 'InChI=1S/C15H11N3O4S/c19-18(20)13-8-1-2-9-14(13)23(21,22)17-12-7-3-5-11-6-4-10-16-15(11)12/h1-10,17H'},
#  {'pubchem_assay_id': 'AID:504669',
#   'assay_type': 'IC50',
#   'outcome': 'active',
#   'compound_cid': 'CID:2539138',
#   'compound_name': '4-[2-(4,5-dichloro-6-oxopyridazin-1-yl)acetyl]-3,3-dimethyl-1H-quinoxalin-2-one',
#   'smiles': 'CC1(C(=O)NC2=CC=CC=C2N1C(=O)CN3C(=O)C(=C(C=N3)Cl)Cl)C',
#   'inchi': 'InChI=1S/C16H14Cl2N4O3/c1-16(2)15(25)20-10-5-3-4-6-11(10)22(16)12(23)8-21-14(24)13(18)9(17)7-19-21/h3-7H,8H2,1-2H3,(H,20,25)'},
#  {'pubchem_assay_id': 'AID:504669',
#   'assay_type': 'IC50',
#   'outcome': 'active',
#   'compound_cid': 'CID:1077343',
# ...

# %%
m_df, m_metadata = molmedb.get_gene_compound_inhibitor(bridgedb_df)

# %%
m_df.head(15)
# Out:
#   identifier identifier.source      target   target.source  \
# 0      KCNJ5              HGNC  A0A5J6E2W8  Uniprot-TrEMBL
# 1      KCNJ5              HGNC      P48544  Uniprot-TrEMBL
# 2    SLC17A9              HGNC      Q5W197  Uniprot-TrEMBL
# 3    SLC17A9              HGNC      Q9BYT1  Uniprot-TrEMBL
# 4    SLC25A1              HGNC      B4DP62  Uniprot-TrEMBL
# 5    SLC25A1              HGNC      P53007  Uniprot-TrEMBL
#
#                        MolMeDB_transporter_inhibitor
# 0  [{'MolMeDB_compound_name': 'Euphorbiaproliferi...
# 1  [{'MolMeDB_compound_name': 'Euphorbiaproliferi...
# 2  [{'MolMeDB_compound_name': 'MM17483', 'MolMeDB...
# 3  [{'MolMeDB_compound_name': 'MM17483', 'MolMeDB...
# 4  [{'MolMeDB_compound_name': nan, 'MolMeDB_inchi...
# 5  [{'MolMeDB_compound_name': nan, 'MolMeDB_inchi...

# %%
m_df['MolMeDB_transporter_inhibitor'][1]
# Out:
# [{'MolMeDB_compound_name': 'Euphorbiaproliferin C',
#   'MolMeDB_inchikey': 'MEMULCZBXUZFOZ-UHFFFAOYSA-N',
#   'MolMeDB_smiles': 'CC(=O)OC1C2(C)OCC3(C(=O)C=CC(C(C)(C)OC(C)=O)C23)C(OC(C)=O)C2C(OC(=O)C(C)C)C(C)CC21OC(C)=O',
#   'MolMeDB_id': 'MM470852',
#   'source_pmid': '27441737'},
#  {'MolMeDB_compound_name': 'Euphornin',
#   'MolMeDB_inchikey': 'BRVXVMOWTHQKHC-LVYIKVSWSA-N',
#   'MolMeDB_smiles': 'CC(=O)OC1CC(OC(C)=O)C(C)(C)/C=C\\C(C)C(OC(C)=O)C2(O)CC(C)C(OC(=O)c3ccccc3)C2/C=C\\1C',
#   'MolMeDB_id': 'MM470853',
#   'source_pmid': '30411614'}]

# %%
opentargets_df, opentargets_metadata = opentargets.get_gene_compound_interactions(bridgedb_df)
# Out:
# ...
# Mapping PubChem: 100%|██████████| 2/2 [00:00<00:00,  2.11it/s]

# %%
opentargets_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0      KCNJ5              HGNC  ENSG00000120457       Ensembl
# 1    SLC17A9              HGNC  ENSG00000101194       Ensembl
# 2    SLC25A1              HGNC  ENSG00000100075       Ensembl
#
#                           OpenTargets_gene_compounds
# 0  [{'chembl_id': 'CHEMBL:CHEMBL2107383', 'drugba...
# 1  [{'chembl_id': nan, 'drugbank_id': nan, 'compo...
# 2  [{'chembl_id': nan, 'drugbank_id': nan, 'compo...

# %%
opentargets_df['OpenTargets_gene_compounds'][0]
# Out:
# [{'chembl_id': 'CHEMBL:CHEMBL2107383',
#   'drugbank_id': None,
#   'compound_cid': 'CID:9930048',
#   'compound_name': 'VERNAKALANT HYDROCHLORIDE',
#   'clincal_trial_phase': 4.0,
#   'is_approved': True,
#   'relation': 'activates',
#   'adverse_effect_count': 1.0,
#   'adverse_effect': [{'name': 'atrial flutter'}]},
#  {'chembl_id': 'CHEMBL:CHEMBL2111112',
#   'drugbank_id': 'DrugBank:DB06217',
#   'compound_cid': 'CID:9930049',
#   'compound_name': 'VERNAKALANT',
#   'clincal_trial_phase': 4.0,
#   'is_approved': True,
#   'relation': 'activates',
#   'adverse_effect_count': 0.0,
#   'adverse_effect': nan}]

# %%
# Create mock dataframes
molmedb_data = {
    "identifier": ["KCNJ5", "SLC25A1"],
    "identifier.source": ["HGNC", "HGNC"],
    "target": ["P38398", "P38398"],
    "target.source": ["Uniprot-TrEMBL", "Uniprot-TrEMBL"],
    "MolMeDB_transporter_inhibitor": [[{
        "MolMeDB_compound_name": "Euphorbiaproliferin C",
        "MolMeDB_inchikey": "IYIKLHRQXLHMJQ-UHFFFAOYSA-N",
        "MolMeDB_smiles": "CC(=O)OC1C2(C)OCC3(C(=O)C=CC(C(C)(C)OC(C)=O)C23)C(OC(C)=O)C2C(OC(=O)C(C)C)C(C)CC21OC(C)=O",
        "MolMeDB_id": "MM470852",
        "source_pmid": "27441737"
    }], [{
        "MolMeDB_compound_name": "Euphorbiaproliferin C",
        "MolMeDB_inchikey": "XXROGKLTLUQVRX-UHFFFAOYSA-N",
        "MolMeDB_smiles": "CC(=O)OC1C2(C)OCC3(C(=O)C=CC(C(C)(C)OC(C)=O)C23)C(OC(C)=O)C2C(OC(=O)C(C)C)C(C)CC21OC(C)=O",
        "MolMeDB_id": "MM470852",
        "source_pmid": "27441737"
    }]]
}

molmedb_df = pd.DataFrame(molmedb_data)

opentargets_data = {
    "identifier": ["KCNJ5", "SLC25A1"],
    "identifier.source": ["HGNC", "HGNC"],
    "target": ["P38398", "P38398"],
    "target.source": ["Uniprot-TrEMBL", "Uniprot-TrEMBL"],
    "OpenTargets_gene_compounds": [[{
        "chembl_id": "CHEMBL:CHEMBL234926",
        "drugbank_id": None,
        "compound_cid": "CID:9930048",
        "compound_name": "VERNAKALANT HYDROCHLORIDE",
        "clincal_trial_phase": 4.0,
        "is_approved": True,
        "relation": "activates",
        "adverse_effect_count": 1.0,
        "adverse_effect": [{"name": "atrial flutter"}]
    }], [{
        "chembl_id": "CHEMBL:CHEMBL633",
        "drugbank_id": None,
        "compound_cid": "CID:9930048",
        "compound_name": "VERNAKALANT HYDROCHLORIDE",
        "clincal_trial_phase": 4.0,
        "is_approved": True,
        "relation": "activates",
        "adverse_effect_count": 1.0,
        "adverse_effect": [{"name": "atrial flutter"}]
    }]]
}

opentargets_df = pd.DataFrame(opentargets_data)

pubchem_data = {
    "identifier": ["KCNJ5", "SLC25A1"],
    "identifier.source": ["HGNC", "HGNC"],
    "target": ["P38398", "P38398"],
    "target.source": ["Uniprot-TrEMBL", "Uniprot-TrEMBL"],
    "PubChem_assays": [[{
        "pubchem_assay_id": "AID:504669",
        "assay_type": "IC50",
        "outcome": "active",
        "compound_cid": "CID:2157",
        "compound_name": "2-nitro-N-quinolin-8-ylbenzenesulfonamide",
        "smiles": "C1=CC=C(C(=C1)[N+](=O)[O-])S(=O)(=O)NC2=CC=CC3=C2N=CC=C3",
        "inchi": "InChI=1S/C15H11N3O4S/c19-18(20)13-8-1-2-9-14(13)23(21,22)17-12-7-3-5-11-6-4-10-16-15(11)12/h1-10,17H"
    }], [{
        "pubchem_assay_id": "AID:504669",
        "assay_type": "IC50",
        "outcome": "active",
        "compound_cid": "CID:7858",
        "compound_name": "2-nitro-N-quinolin-8-ylbenzenesulfonamide",
        "smiles": "C1=CC=C(C(=C1)[N+](=O)[O-])S(=O)(=O)NC2=CC=CC3=C2N=CC=C3",
        "inchi": "InChI=1S/C15H11N3O4S/c19-18(20)13-8-1-2-9-14(13)23(21,22)17-12-7-3-5-11-6-4-10-16-15(11)12/h1-10,17H"
    }]]
}

pubchem_df = pd.DataFrame(pubchem_data)

pubchem_df.head()
# Out:
#   identifier identifier.source  target   target.source  \
# 0      KCNJ5              HGNC  P38398  Uniprot-TrEMBL
# 1    SLC25A1              HGNC  P38398  Uniprot-TrEMBL
#
#                                       PubChem_assays
# 0  [{'pubchem_assay_id': 'AID:504669', 'assay_typ...
# 1  [{'pubchem_assay_id': 'AID:504669', 'assay_typ...

# %%
combined_df = combine_sources(
    bridgedb_df,
    [
        pubchem_df, 
    ],
)

# %%
combined_df, compoundwiki_metadata = compoundwiki.get_compound_annotations(combined_df)
# Out:
# Processing input identifiers for compounds...
# Querying BridgeDb for PubChem IDs from HGNC...
# No PubChem Compound IDs found in BridgeDb result.
# Processing PubChem column for compounds...
# A:                                           propEntity  \
# 0   https://compoundcloud.wikibase.cloud/entity/P36
# 1   https://compoundcloud.wikibase.cloud/entity/P47
# 2   https://compoundcloud.wikibase.cloud/entity/P47
# 3   https://compoundcloud.wikibase.cloud/entity/P23
# 4   https://compoundcloud.wikibase.cloud/entity/P28
# 5   https://compoundcloud.wikibase.cloud/entity/P41
# 6   https://compoundcloud.wikibase.cloud/entity/P22
# 7   https://compoundcloud.wikibase.cloud/entity/P43
# 8   https://compoundcloud.wikibase.cloud/entity/P44
# 9    https://compoundcloud.wikibase.cloud/entity/P9
# 10  https://compoundcloud.wikibase.cloud/entity/P10
# 11  https://compoundcloud.wikibase.cloud/entity/P27
# 12  https://compoundcloud.wikibase.cloud/entity/P27
# ...

# %%
combined_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0      KCNJ5              HGNC  ENSG00000120457       Ensembl
# 1    SLC25A1              HGNC  ENSG00000100075       Ensembl
#
#                                       PubChem_assays
# 0  [{'pubchem_assay_id': 'AID:504669', 'assay_typ...
# 1  [{'pubchem_assay_id': 'AID:504669', 'assay_typ...

# %%
combined_df['OpenTargets_gene_compounds'][0]
# Out:
# [{'chembl_id': 'CHEMBL:CHEMBL234926',
#   'drugbank_id': None,
#   'compound_cid': 'CID:9930048',
#   'compound_name': 'VERNAKALANT HYDROCHLORIDE',
#   'clincal_trial_phase': 4.0,
#   'is_approved': True,
#   'relation': 'activates',
#   'adverse_effect_count': 1.0,
#   'adverse_effect': [{'name': 'atrial flutter'}],
#   'CompoundWiki_compounds': [{'AOP-Wiki Stressor ID': '9',
#     'CAS Registry Number': '107-18-6',
#     'ChEBI ID': '16605',
#     'ChEMBL ID': 'CHEMBL234926',
#     'DSSTOX compound identifier': 'DTXCID2044',
#     'EC number': '203-470-7',
#     'ECHA Substance Infocard ID': '100.003.156',
#     'InChI': 'InChI=1S/C3H6O/c1-2-3-4/h2,4H,1,3H2',
#     'InChIKey': 'XXROGKLTLUQVRX-UHFFFAOYSA-N',
#     'KEGG ID': 'C02001',
#     'PubChem CID': '7858',
#     'SMILES (without stereochemistry)': 'C=CCO',
#     'ToxBank Wiki': 'https://wiki.toxbank.net/wiki/Allyl_alcohol',
#     'Wikidata Q identifier': 'Q414553',
#     'chemical formula': 'C₃H₆O',
# ...

# %%
pygraph = generator.build_networkx_graph(combined_df)
# Out:
# ...
# Building graph:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pygraph = generator.build_networkx_graph(combined_df)
#
# File c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src\pyBiodatafuse\graph\generator.py:2454, in build_networkx_graph(combined_df, disease_compound, pathway_compound, homolog_df_list)
#    2451 main_target_type = combined_df["target.source"].unique()[0]
#    2453 if main_target_type == Cons.ENSEMBL:
# -> 2454     return _built_gene_based_graph(
#    2455         g, combined_df, disease_compound, pathway_compound, homolog_df_list
#    2456     )
#    2457 elif main_target_type == Cons.PUBCHEM_COMPOUND:
#    2458     return _built_compound_based_graph(
#    2459         g, combined_df, disease_compound, pathway_compound, homolog_df_list
#    2460     )
#
# ...
