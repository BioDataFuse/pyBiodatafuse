# %% [markdown]
# # Example: CompoundWiki

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")

if src_path not in sys.path:
    sys.path.insert(0, src_path)

print("PYTHONPATH:", sys.path[0])
# Out:
# PYTHONPATH: c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src

# %%
# Import modules
import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import intact, kegg, compoundwiki
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# # Load list of metabolites/chemicals/compounds

# %%
metabolites_of_interest = """2504
15996
17368
16526
31742
63596
28499
35718
25212
78675
35107
"""

metabolite_list = metabolites_of_interest.split("\n")
len(metabolite_list)
# Out:
# 12

# %%
data_input = pd.DataFrame(metabolite_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0       2157
# 1      15996
# 2      17368
# 3      16526
# 4      31742

# %% [markdown]
# ### Entity resolution using BridgeDB

# %%
bridgedb_compound_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species="Human",
    input_datasource="ChEBI",
    output_datasource="All",
)
bridgedb_compound_df.head(10)
# Out:
#   identifier identifier.source                       target     target.source
# 0      15996             ChEBI                         6830  PubChem Compound
# 1      15996             ChEBI                       C00044     KEGG Compound
# 2      15996             ChEBI                      Q392227          Wikidata
# 3      15996             ChEBI                      DB04137          DrugBank
# 4      15996             ChEBI                         6569        ChemSpider
# 5      15996             ChEBI                      86-01-1               CAS
# 6      15996             ChEBI                CHEMBL1233147   ChEMBL compound
# 7      15996             ChEBI                  HMDB0001273              HMDB
# 8      15996             ChEBI                  CHEBI:15996             ChEBI
# 9      15996             ChEBI  XKMLYUALXHKNFT-UUOKFMHZSA-N          InChIKey

# %% [markdown]
# ### Compound Interactions from IntAct

# %%
intact_compound_df, intact_compound_metadata = intact.get_compound_interactions(
    bridgedb_compound_df, interaction_type="both"
)
intact_compound_df.head(10)
# Out:
# Querying IntAct for compounds: 100%|██████████| 1/1 [00:12<00:00, 12.50s/it]
# c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src\pyBiodatafuse\annotators\intact.py:422: UserWarning: The intermediate_df in IntAct annotator should be checked, please create an issue on https://github.com/BioDataFuse/pyBiodatafuse/issues/.
#   give_annotator_warning(Cons.INTACT)
#   identifier identifier.source       target target.source  \
# 0      15996             ChEBI  CHEBI:15996         ChEBI
# 1      17368             ChEBI  CHEBI:17368         ChEBI
# 2      16526             ChEBI  CHEBI:16526         ChEBI
# 3      31742             ChEBI  CHEBI:31742         ChEBI
# 4      63596             ChEBI  CHEBI:63596         ChEBI
# 5      28499             ChEBI  CHEBI:28499         ChEBI
# 6      25212             ChEBI  CHEBI:25212         ChEBI
# 7      35107             ChEBI  CHEBI:35107         ChEBI
#
#                         IntAct_compound_interactions
# 0  [{'interaction_id': 'EBI-1557199', 'interactor...
# 1  [{'interaction_id': nan, 'interactor_id_A': na...
# 2  [{'interaction_id': nan, 'interactor_id_A': na...
# 3  [{'interaction_id': nan, 'interactor_id_A': na...
# 4  [{'interaction_id': nan, 'interactor_id_A': na...
# 5  [{'interaction_id': nan, 'interactor_id_A': na...
# 6  [{'interaction_id': nan, 'interactor_id_A': na...
# 7  [{'interaction_id': nan, 'interactor_id_A': na...

# %%
intact_compound_df["IntAct_compound_interactions"][0]
# Out:
# [{'interaction_id': 'EBI-1557199',
#   'interactor_id_A': 'EBI-722284',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.62,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'enzymatic reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab4a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB4A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P20338',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15377662',
#   'intact_link_to': 'EBI-722284'},
#  {'interaction_id': 'EBI-22225605',
#   'interactor_id_A': 'EBI-9837586',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab32_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB32',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q13637',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-9837586'},
#  {'interaction_id': 'EBI-22225626',
#   'interactor_id_A': 'EBI-6552718',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.68,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab38_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB38',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P57729',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-6552718'},
#  {'interaction_id': 'EBI-22225745',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-6552718',
#   'score': 0.68,
#   'biological_role_A': 'cofactor',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'itc',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rab38_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RAB38',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P57729',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-6552718'},
#  {'interaction_id': 'EBI-22226216',
#   'interactor_id_A': 'EBI-6552718',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.68,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab38_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB38',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P57729',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-6552718'},
#  {'interaction_id': 'EBI-22226452',
#   'interactor_id_A': 'EBI-9837586',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab32_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB32',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q13637',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-9837586'},
#  {'interaction_id': 'EBI-6146856',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-6146607',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'fluorescence',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'q57uh8_tryb2',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Trypanosoma brucei brucei (strain 927/4 GUTat10.1)',
#   'molecule_A': 'gtp',
#   'molecule_B': 'Tb08.5H5.790',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q57UH8',
#   'pubmed_publication_id': '22609302',
#   'intact_link_to': 'EBI-6146607'},
#  {'interaction_id': 'EBI-6146876',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-6146607',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'fluorescence',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'q57uh8_tryb2',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Trypanosoma brucei brucei (strain 927/4 GUTat10.1)',
#   'molecule_A': 'gtp',
#   'molecule_B': 'Tb08.5H5.790',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q57UH8',
#   'pubmed_publication_id': '22609302',
#   'intact_link_to': 'EBI-6146607'},
#  {'interaction_id': 'EBI-1557205',
#   'interactor_id_A': 'EBI-1052826',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'enzymatic reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab6a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB6A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P20340',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15377662',
#   'intact_link_to': 'EBI-1052826'},
#  {'interaction_id': 'EBI-27066219',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-25475885',
#   'score': 0.44,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'p0dtd1-pro_0000449629',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'SARS-CoV-2',
#   'molecule_A': 'gtp',
#   'molecule_B': 'P0DTD1-PRO_0000449629',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P0DTD1-PRO_0000449629',
#   'pubmed_publication_id': '34352100',
#   'intact_link_to': 'EBI-25475885'},
#  {'interaction_id': 'EBI-9029815',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-9029118',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'mfn1_mouse',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Mus musculus',
#   'molecule_A': 'gtp',
#   'molecule_B': 'Mfn1',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q811U4',
#   'pubmed_publication_id': '24282027',
#   'intact_link_to': 'EBI-9029118'},
#  {'interaction_id': 'EBI-9029824',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-9029118',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'mfn1_mouse',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Mus musculus',
#   'molecule_A': 'gtp',
#   'molecule_B': 'Mfn1',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q811U4',
#   'pubmed_publication_id': '24282027',
#   'intact_link_to': 'EBI-9029118'},
#  {'interaction_id': 'EBI-1556758',
#   'interactor_id_A': 'EBI-399437',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'enzymatic reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB5A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P20339',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15377662',
#   'intact_link_to': 'EBI-399437'},
#  {'interaction_id': 'EBI-22225645',
#   'interactor_id_A': 'EBI-372165',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab7l_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB29',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:O14966',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-372165'},
#  {'interaction_id': 'EBI-22226181',
#   'interactor_id_A': 'EBI-372165',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab7l_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB29',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:O14966',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-372165'},
#  {'interaction_id': 'EBI-26430449',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-25475888',
#   'score': 0.44,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'p0dtd1-pro_0000449630',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'SARS-CoV-2',
#   'molecule_A': 'gtp',
#   'molecule_B': 'P0DTD1-PRO_0000449630',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P0DTD1-PRO_0000449630',
#   'pubmed_publication_id': '32500504',
#   'intact_link_to': 'EBI-25475888'},
#  {'interaction_id': 'EBI-1782740',
#   'interactor_id_A': 'EBI-2010692',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.52,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5a_canlf',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Canis familiaris (dog)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB5A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P18066',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15016378',
#   'intact_link_to': 'EBI-2010692'},
#  {'interaction_id': 'EBI-1782751',
#   'interactor_id_A': 'EBI-2010692',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.52,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5a_canlf',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Canis familiaris (dog)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB5A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P18066',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15016378',
#   'intact_link_to': 'EBI-2010692'},
#  {'interaction_id': 'EBI-6289085',
#   'interactor_id_A': 'EBI-948566',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'zhx2_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'ZHX2',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q9Y6X8',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22363216',
#   'intact_link_to': 'EBI-948566'},
#  {'interaction_id': 'EBI-1557216',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-520244',
#   'score': 0.44,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'stimulator',
#   'type': 'enzymatic reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'p85a_bovin',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Bos taurus (Bovine)',
#   'molecule_A': 'gtp',
#   'molecule_B': 'PIK3R1',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P23727',
#   'pubmed_publication_id': '15377662',
#   'intact_link_to': 'EBI-520244'},
#  {'interaction_id': 'EBI-10688358',
#   'interactor_id_A': 'EBI-399401',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5b_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB5B',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P61020',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '25605758',
#   'intact_link_to': 'EBI-399401'},
#  {'interaction_id': 'EBI-10688397',
#   'interactor_id_A': 'EBI-399401',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5b_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB5B',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P61020',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '25605758',
#   'intact_link_to': 'EBI-399401'},
#  {'interaction_id': 'EBI-10049260',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-602366',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rap2a_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RAP2A',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P10114',
#   'pubmed_publication_id': '25446900',
#   'intact_link_to': 'EBI-602366'},
#  {'interaction_id': 'EBI-9548771',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9548813',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9548831',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9548863',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-9548773',
#   'score': 0.56,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'djc27_mouse',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Mus musculus',
#   'molecule_A': 'gtp',
#   'molecule_B': 'Dnajc27',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q8CFP6',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9548941',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'competitor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9548941',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9549025',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9549027',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9549029',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-9548773',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'djc27_mouse',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Mus musculus',
#   'molecule_A': 'gtp',
#   'molecule_B': 'Dnajc27',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q8CFP6',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9549031',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-9549031',
#   'interactor_id_A': 'EBI-9548773',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'competitor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'djc27_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Dnajc27',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8CFP6',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24746703',
#   'intact_link_to': 'EBI-9548773'},
#  {'interaction_id': 'EBI-10688433',
#   'interactor_id_A': 'EBI-399401',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5b_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB5B',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P61020',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '25605758',
#   'intact_link_to': 'EBI-399401'},
#  {'interaction_id': 'EBI-1782523',
#   'interactor_id_A': 'EBI-2010692',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.52,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'association',
#   'detection_method': 'pull down',
#   'host_organism': 'Homo sapiens HeLa epitheloid cervical carcinoma cell',
#   'interactor_A_name': 'rab5a_canlf',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Canis familiaris (dog)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB5A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P18066',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15016378',
#   'intact_link_to': 'EBI-2010692'},
#  {'interaction_id': 'EBI-9029848',
#   'interactor_id_A': 'EBI-713135',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.61,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'dyn1_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'DNM1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q05193',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24282027',
#   'intact_link_to': 'EBI-713135'},
#  {'interaction_id': 'EBI-10049255',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-716845',
#   'score': 0.61,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rab1a_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RAB1A',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P62820',
#   'pubmed_publication_id': '25446900',
#   'intact_link_to': 'EBI-716845'},
#  {'interaction_id': 'EBI-10049314',
#   'interactor_id_A': 'EBI-29496',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'ypt1_yeast',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Saccharomyces cerevisiae',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'YPT1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P01123',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '25446900',
#   'intact_link_to': 'EBI-29496'},
#  {'interaction_id': 'EBI-25611216',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-1045214',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rab1b_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RAB1B',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q9H0U4',
#   'pubmed_publication_id': '32227113',
#   'intact_link_to': 'EBI-1045214'},
#  {'interaction_id': 'EBI-6310670',
#   'interactor_id_A': 'EBI-1050422',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'competition binding',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'lrrk1_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'LRRK1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q38SD2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22952686',
#   'intact_link_to': 'EBI-1050422'},
#  {'interaction_id': 'EBI-6309809',
#   'interactor_id_A': 'EBI-1307',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.78,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'pak1_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'PAK1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q13153',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '21454543',
#   'intact_link_to': 'EBI-1307'},
#  {'interaction_id': 'EBI-25610888',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-9254454',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'tbc20_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'TBC1D20',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q96BZ9',
#   'pubmed_publication_id': '32227113',
#   'intact_link_to': 'EBI-9254454'},
#  {'interaction_id': 'EBI-25611216',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-9254454',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'tbc20_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'TBC1D20',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q96BZ9',
#   'pubmed_publication_id': '32227113',
#   'intact_link_to': 'EBI-9254454'},
#  {'interaction_id': 'EBI-22304687',
#   'interactor_id_A': 'EBI-10714945',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.62,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'mmaa_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'MMAA',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8IVH4',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '20876572',
#   'intact_link_to': 'EBI-10714945'},
#  {'interaction_id': 'EBI-2410535',
#   'interactor_id_A': 'EBI-37523',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sey1_yeast',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Saccharomyces cerevisiae',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'SEY1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q99287',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '19665976',
#   'intact_link_to': 'EBI-37523'},
#  {'interaction_id': 'EBI-6128863',
#   'interactor_id_A': 'EBI-1162441',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rtkn_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Rtkn',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8C6B2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22404908',
#   'intact_link_to': 'EBI-1162441'},
#  {'interaction_id': 'EBI-6511116',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-717515',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'inhibitor',
#   'type': 'physical association',
#   'detection_method': 'affinity chrom',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'arhg7_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'ARHGEF7',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q14155',
#   'pubmed_publication_id': '21048939',
#   'intact_link_to': 'EBI-717515'},
#  {'interaction_id': 'EBI-22304659',
#   'interactor_id_A': 'EBI-10714945',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.62,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'mmaa_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'MMAA',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8IVH4',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '20876572',
#   'intact_link_to': 'EBI-10714945'},
#  {'interaction_id': 'EBI-22304677',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-10714945',
#   'score': 0.62,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'mmaa_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'MMAA',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q8IVH4',
#   'pubmed_publication_id': '20876572',
#   'intact_link_to': 'EBI-10714945'},
#  {'interaction_id': 'EBI-4533237',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-4420450',
#   'score': 0.44,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'o00429-4',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'DNM1L',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:O00429-4',
#   'pubmed_publication_id': '20850011',
#   'intact_link_to': 'EBI-4420450'},
#  {'interaction_id': 'EBI-27030297',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-949847',
#   'score': 0.44,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'itc',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'sacs_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'SACS',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q9NZJ4',
#   'pubmed_publication_id': '21507954',
#   'intact_link_to': 'EBI-949847'},
#  {'interaction_id': 'EBI-9257275',
#   'interactor_id_A': 'EBI-446694',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rtkn_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RTKN',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q9BST9',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '24525234',
#   'intact_link_to': 'EBI-446694'},
#  {'interaction_id': 'EBI-25610888',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-722293',
#   'score': 0.68,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rab8a_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RAB8A',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P61006',
#   'pubmed_publication_id': '32227113',
#   'intact_link_to': 'EBI-722293'},
#  {'interaction_id': 'EBI-6501545',
#   'interactor_id_A': 'EBI-5323863',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.98,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'affinity chrom',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'lrrk2_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'LRRK2',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q5S007',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '23241358',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-6374096',
#   'interactor_id_A': 'EBI-5323863',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.98,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'affinity chrom',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'lrrk2_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'LRRK2',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q5S007',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '20515039',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-6374128',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-5323863',
#   'score': 0.98,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'affinity chrom',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'lrrk2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'LRRK2',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q5S007',
#   'pubmed_publication_id': '20515039',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-22273726',
#   'interactor_id_A': 'EBI-4401353',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.59,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab9a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB9A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P51151',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '20048159',
#   'intact_link_to': 'EBI-4401353'},
#  {'interaction_id': 'EBI-21464621',
#   'interactor_id_A': 'EBI-10714945',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.62,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'mmaa_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'MMAA',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8IVH4',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '28497574',
#   'intact_link_to': 'EBI-10714945'},
#  {'interaction_id': 'EBI-22235789',
#   'interactor_id_A': 'EBI-4401353',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.59,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab9a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB9A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P51151',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '20048159',
#   'intact_link_to': 'EBI-4401353'},
#  {'interaction_id': 'EBI-22235818',
#   'interactor_id_A': 'EBI-4401353',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.59,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'cofactor',
#   'type': 'association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab9a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB9A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P51151',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '20048159',
#   'intact_link_to': 'EBI-4401353'},
#  {'interaction_id': 'EBI-25757716',
#   'interactor_id_A': 'EBI-10714945',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.62,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'mmaa_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'MMAA',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8IVH4',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '28497574',
#   'intact_link_to': 'EBI-10714945'},
#  {'interaction_id': 'EBI-9685152',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-353779',
#   'score': 0.44,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'triphosphatase ass',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'ddx3x_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'DDX3X',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:O00571',
#   'pubmed_publication_id': '10074132',
#   'intact_link_to': 'EBI-353779'},
#  {'interaction_id': 'EBI-1638059',
#   'interactor_id_A': 'EBI-1638043',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'filter binding',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rhou_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RHOU',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q7L0Q8',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15350535',
#   'intact_link_to': 'EBI-1638043'},
#  {'interaction_id': 'EBI-1557216',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-413628',
#   'score': 0.61,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'stimulator',
#   'type': 'enzymatic reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rac1_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RAC1',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P63000',
#   'pubmed_publication_id': '15377662',
#   'intact_link_to': 'EBI-413628'},
#  {'interaction_id': 'EBI-1557224',
#   'interactor_id_A': 'EBI-81752',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.8,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'enzymatic reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'cdc42_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'CDC42',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P60953',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '15377662',
#   'intact_link_to': 'EBI-81752'},
#  {'interaction_id': 'EBI-11302215',
#   'interactor_id_A': 'EBI-356544',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'inhibitor',
#   'type': 'redox reaction',
#   'detection_method': 'oxidoreduct assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'dhe3_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'GLUD1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P00367',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '25670081',
#   'intact_link_to': 'EBI-356544'},
#  {'interaction_id': 'EBI-11942764',
#   'interactor_id_A': 'EBI-5323863',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.98,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'lrrk2_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'LRRK2',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q5S007',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '27357661',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-22225745',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-5323863',
#   'score': 0.98,
#   'biological_role_A': 'cofactor',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'itc',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'lrrk2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'LRRK2',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q5S007',
#   'pubmed_publication_id': '31552791',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-6508127',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-5323863',
#   'score': 0.98,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'lrrk2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'LRRK2',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q5S007',
#   'pubmed_publication_id': '21073465',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-6508149',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-5323863',
#   'score': 0.98,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'affinity chrom',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'lrrk2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'LRRK2',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q5S007',
#   'pubmed_publication_id': '21073465',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-6509412',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-5323863',
#   'score': 0.98,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'lrrk2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'LRRK2',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q5S007',
#   'pubmed_publication_id': '19559761',
#   'intact_link_to': 'EBI-5323863'},
#  {'interaction_id': 'EBI-6516430',
#   'interactor_id_A': 'EBI-5323863',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.98,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
# ...
#   'molecule_A': 'RILP',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q96NA2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '25500191',
#   'intact_link_to': 'EBI-2856119'},
#  {'interaction_id': 'EBI-6115079',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-992949',
#   'score': 0.5,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'anti tag coip',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rragd_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RRAGD',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q9NQL2',
#   'pubmed_publication_id': '22424946',
#   'intact_link_to': 'EBI-992949'},
#  {'interaction_id': 'EBI-6115090',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-992949',
#   'score': 0.5,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'anti tag coip',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rragd_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RRAGD',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q9NQL2',
#   'pubmed_publication_id': '22424946',
#   'intact_link_to': 'EBI-992949'},
#  {'interaction_id': 'EBI-6115100',
#   'interactor_id_A': 'EBI-992949',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.5,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'association',
#   'detection_method': 'anti tag coip',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rragd_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RRAGD',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q9NQL2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22424946',
#   'intact_link_to': 'EBI-992949'},
#  {'interaction_id': 'EBI-6115108',
#   'interactor_id_A': 'EBI-992949',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.5,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'association',
#   'detection_method': 'anti tag coip',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rragd_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RRAGD',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q9NQL2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22424946',
#   'intact_link_to': 'EBI-992949'},
#  {'interaction_id': 'EBI-6552230',
#   'interactor_id_A': 'EBI-2551532',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5c_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Rab5c',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P35278',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-2551532'},
#  {'interaction_id': 'EBI-6552236',
#   'interactor_id_A': 'EBI-2551532',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab5c_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Rab5c',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P35278',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-2551532'},
#  {'interaction_id': 'EBI-6552578',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-4402507',
#   'score': 0.44,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rab20_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'RAB20',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q9NX57',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-4402507'},
#  {'interaction_id': 'EBI-6552588',
#   'interactor_id_A': 'EBI-4402507',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab20_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB20',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q9NX57',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-4402507'},
#  {'interaction_id': 'EBI-6552674',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-6552655',
#   'score': 0.44,
#   'biological_role_A': 'enzyme target',
#   'biological_role_B': 'enzyme',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'rab24_mouse',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Mus musculus',
#   'molecule_A': 'gtp',
#   'molecule_B': 'Rab24',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:P35290',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-6552655'},
#  {'interaction_id': 'EBI-6552684',
#   'interactor_id_A': 'EBI-6552655',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rab24_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Rab24',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P35290',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-6552655'},
#  {'interaction_id': 'EBI-6552785',
#   'interactor_id_A': 'EBI-3048577',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rb39a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB39A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q14964',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-3048577'},
#  {'interaction_id': 'EBI-6552795',
#   'interactor_id_A': 'EBI-3048577',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rb39a_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'RAB39A',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q14964',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-3048577'},
#  {'interaction_id': 'EBI-6379517',
#   'interactor_id_A': 'EBI-6379521',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rb33b_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Rab33b',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:O35963',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-6379521'},
#  {'interaction_id': 'EBI-6379544',
#   'interactor_id_A': 'EBI-6379521',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'gtpase reaction',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'rb33b_mouse',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Mus musculus',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'Rab33b',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:O35963',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '22939626',
#   'intact_link_to': 'EBI-6379521'},
#  {'interaction_id': 'EBI-989043',
#   'interactor_id_A': 'EBI-81752',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.8,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'enzyme target',
#   'type': 'physical association',
#   'detection_method': 'gtpase assay',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'cdc42_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'CDC42',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P60953',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '16862148',
#   'intact_link_to': 'EBI-81752'},
#  {'interaction_id': 'EBI-13942387',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-396343',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'footprinting',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'ima3_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'gtp',
#   'molecule_B': 'KPNA4',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:O00629',
#   'pubmed_publication_id': '10523667',
#   'intact_link_to': 'EBI-396343'},
#  {'interaction_id': 'EBI-13942432',
#   'interactor_id_A': 'EBI-989053',
#   'interactor_id_B': 'EBI-1797',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'footprinting',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gtp',
#   'interactor_B_name': 'ima1_yeast',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Saccharomyces cerevisiae',
#   'molecule_A': 'gtp',
#   'molecule_B': 'SRP1',
#   'id_A': 'CHEBI:15996',
#   'id_B': 'uniprotkb:Q02821',
#   'pubmed_publication_id': '10523667',
#   'intact_link_to': 'EBI-1797'},
#  {'interaction_id': 'EBI-1777544',
#   'interactor_id_A': 'EBI-443890',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.78,
#   'biological_role_A': 'enzyme',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'spr',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gpa1_arath',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Arabidopsis thaliana (Mouse-ear cress)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'GPA1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P18064',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '17951432',
#   'intact_link_to': 'EBI-443890'},
#  {'interaction_id': 'EBI-1645648',
#   'interactor_id_A': 'EBI-1645320',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'itc',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gcc2_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'GCC2',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8IWJ2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '18243103',
#   'intact_link_to': 'EBI-1645320'},
#  {'interaction_id': 'EBI-1645659',
#   'interactor_id_A': 'EBI-1645320',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'itc',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gcc2_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'GCC2',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8IWJ2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '18243103',
#   'intact_link_to': 'EBI-1645320'},
#  {'interaction_id': 'EBI-1646069',
#   'interactor_id_A': 'EBI-1645320',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'affinity chrom',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'gcc2_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'GCC2',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q8IWJ2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '18243103',
#   'intact_link_to': 'EBI-1645320'},
#  {'interaction_id': 'EBI-22233381',
#   'interactor_id_A': 'EBI-370916',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.44,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'nmr',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'alf_ecoli',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Escherichia coli (strain K12)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'fbaA',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:P0AB71',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '31464375',
#   'intact_link_to': 'EBI-370916'},
#  {'interaction_id': 'EBI-30874480',
#   'interactor_id_A': 'EBI-473814',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.59,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'stimulator',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'pkhm1_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'PLEKHM1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q9Y4G2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '28325809',
#   'intact_link_to': 'EBI-473814'},
#  {'interaction_id': 'EBI-30874497',
#   'interactor_id_A': 'EBI-473814',
#   'interactor_id_B': 'EBI-989053',
#   'score': 0.59,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'stimulator',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'pkhm1_human',
#   'interactor_B_name': 'gtp',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'PLEKHM1',
#   'molecule_B': 'gtp',
#   'id_A': 'uniprotkb:Q9Y4G2',
#   'id_B': 'CHEBI:15996',
#   'pubmed_publication_id': '28325809',
#   'intact_link_to': 'EBI-473814'}]

# %%
combined_df = combine_sources(
    bridgedb_compound_df,
    [
        intact_compound_df, 
    ],
)

# %%
combined_df.head()
# Out:
#   identifier identifier.source   target     target.source  \
# 0      15996             ChEBI     6830  PubChem Compound
# 1      17368             ChEBI      790  PubChem Compound
# 2      16526             ChEBI      280  PubChem Compound
# 3      31742             ChEBI  5282149  PubChem Compound
# 4      63596             ChEBI   173576  PubChem Compound
#
#                         IntAct_compound_interactions
# 0  [{'interaction_id': 'EBI-1557199', 'interactor...
# 1  [{'interaction_id': nan, 'interactor_id_A': na...
# 2  [{'interaction_id': nan, 'interactor_id_A': na...
# 3  [{'interaction_id': nan, 'interactor_id_A': na...
# 4  [{'interaction_id': nan, 'interactor_id_A': na...

# %%
combined_df, compoundwiki_metadata = compoundwiki.get_compound_annotations(combined_df)
# Out:
# Processing IntAct column for compounds: IntAct_compound_interactions
# Found CHEBI IDs in IntAct_compound_interactions: ['CHEBI:15996']
# Querying BridgeDb for PubChem IDs from ChEBI...
# Found 1 unique PubChem Compound IDs.
# Running SPARQL query:
# PREFIX wd: <https://compoundcloud.wikibase.cloud/entity/>
# PREFIX wdt: <https://compoundcloud.wikibase.cloud/prop/direct/>
# PREFIX wikibase: <http://wikiba.se/ontology#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#
# SELECT ?compound ?compoundLabel ?propEntity ?propLabel ?val ?valLabel WHERE {
#   VALUES ?pubchem { "6830" }
#   ?compound wdt:P13 ?pubchem .
#   ?compound ?prop ?val .
#   ?propEntity wikibase:directClaim ?prop .
#
#   OPTIONAL { ?compound rdfs:label ?compoundLabel . FILTER (lang(?compoundLabel) = "en") }
#   OPTIONAL { ?propEntity rdfs:label ?propLabel . FILTER (lang(?propLabel) = "en") }
#   OPTIONAL { ?val rdfs:label ?valLabel . FILTER (lang(?valLabel) = "en") }
# }
# ORDER BY ?compound ?propLabel
# A:  Empty DataFrame
# Columns: []
# Index: []
# Received CompoundWiki annotations for IntAct_compound_interactions: {}
# Injected CompoundWiki annotations into IntAct_compound_interactions.

# %%
combined_df.head()
# Out:
#   identifier identifier.source   target     target.source  \
# 0      15361             ChEBI   107735  PubChem Compound
# 1      16393             ChEBI  5280335  PubChem Compound
# 2      15996             ChEBI     6830  PubChem Compound
# 3      17440             ChEBI      378  PubChem Compound
#
#                         IntAct_compound_interactions  \
# 0  [{'interaction_id': 'EBI-6621805', 'interactor...
# 1  [{'interaction_id': 'EBI-26355556', 'interacto...
# 2  [{'interaction_id': 'EBI-27066219', 'interacto...
# 3  [{'interaction_id': 'EBI-9691115', 'interactor...
#
#                                        KEGG_pathways
# 0                                                NaN
# 1  [{'pathway_id': 'path:hsa00600', 'pathway_labe...
# 2  [{'pathway_id': 'path:hsa00230', 'pathway_labe...
# 3  [{'pathway_id': nan, 'pathway_label': nan, 'pa...

# %%
combined_df['IntAct_compound_interactions'][1]
# Out:
# [{'interaction_id': 'EBI-26355556',
#   'interactor_id_A': 'EBI-26355518',
#   'interactor_id_B': 'EBI-26355518',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'competitor',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sphingosine',
#   'interactor_B_name': 'sphingosine',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'sphingosine',
#   'molecule_B': 'sphingosine',
#   'id_A': 'CHEBI:16393',
#   'id_B': 'CHEBI:16393',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': '16393'},
#  {'interaction_id': 'EBI-26355565',
#   'interactor_id_A': 'EBI-26355518',
#   'interactor_id_B': 'EBI-26355518',
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'competitor',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sphingosine',
#   'interactor_B_name': 'sphingosine',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'sphingosine',
#   'molecule_B': 'sphingosine',
#   'id_A': 'CHEBI:16393',
#   'id_B': 'CHEBI:16393',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': '16393'},
#  {'interaction_id': 'EBI-26355511',
#   'interactor_id_A': 'EBI-26355518',
#   'interactor_id_B': 'EBI-25487316',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sphingosine',
#   'interactor_B_name': 'q1lzx8_chlae',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Chlorocebus aethiops',
#   'molecule_A': 'sphingosine',
#   'molecule_B': 'ACE2',
#   'id_A': 'CHEBI:16393',
#   'id_B': 'uniprotkb:Q1LZX8',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': 'EBI-25487316'},
#  {'interaction_id': 'EBI-26355565',
#   'interactor_id_A': 'EBI-26355518',
#   'interactor_id_B': 'EBI-25487316',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sphingosine',
#   'interactor_B_name': 'q1lzx8_chlae',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Chlorocebus aethiops',
#   'molecule_A': 'sphingosine',
#   'molecule_B': 'ACE2',
#   'id_A': 'CHEBI:16393',
#   'id_B': 'uniprotkb:Q1LZX8',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': 'EBI-25487316'},
#  {'interaction_id': 'EBI-26355556',
#   'interactor_id_A': 'EBI-26355518',
#   'interactor_id_B': 'EBI-7730807',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sphingosine',
#   'interactor_B_name': 'ace2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'sphingosine',
#   'molecule_B': 'ACE2',
#   'id_A': 'CHEBI:16393',
#   'id_B': 'uniprotkb:Q9BYF1',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': 'EBI-7730807'},
#  {'interaction_id': 'EBI-26355583',
#   'interactor_id_A': 'EBI-26355518',
#   'interactor_id_B': 'EBI-7730807',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sphingosine',
#   'interactor_B_name': 'ace2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'sphingosine',
#   'molecule_B': 'ACE2',
#   'id_A': 'CHEBI:16393',
#   'id_B': 'uniprotkb:Q9BYF1',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': 'EBI-7730807'},
#  {'interaction_id': 'EBI-26355592',
#   'interactor_id_A': 'EBI-26355518',
#   'interactor_id_B': 'EBI-7730807',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'sphingosine',
#   'interactor_B_name': 'ace2_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'sphingosine',
#   'molecule_B': 'ACE2',
#   'id_A': 'CHEBI:16393',
#   'id_B': 'uniprotkb:Q9BYF1',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': 'EBI-7730807'},
#  {'interaction_id': 'EBI-26355600',
#   'interactor_id_A': 'EBI-7730807',
#   'interactor_id_B': 'EBI-26355518',
#   'score': 0.54,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'competitor',
#   'type': 'physical association',
#   'detection_method': 'pull down',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'ace2_human',
#   'interactor_B_name': 'sphingosine',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Chemical synthesis (Chemical synthesis)',
#   'molecule_A': 'ACE2',
#   'molecule_B': 'sphingosine',
#   'id_A': 'uniprotkb:Q9BYF1',
#   'id_B': 'CHEBI:16393',
#   'pubmed_publication_id': '32917722',
#   'intact_link_to': 'EBI-7730807'}]

# %%
pygraph = generator.build_networkx_graph(combined_df)
# Out:
# Building graph: 100%|██████████| 2/2 [00:00<00:00, 969.56it/s]

# %%
combined_df.shape
# Out:
# (2, 5)

# %%
from pyBiodatafuse.graph import cytoscape

cytoscape.load_graph(pygraph, network_name="Test network")
# Out:
# Applying default style...
# Applying preferred layout

# %%
genes_of_interest = """ENSMUSG00000026295
ENSMUSG00000022877
ENSMUSG00000020914
ENSMUSG00000024747
ENSMUSG00000032081
ENSMUSG00000004035
ENSMUSG00000072949
ENSMUSG00000028970
ENSMUSG00000028937
ENSMUSG00000075044
ENSMUSG00000067274
ENSMUSG00000000001
ENSMUSG00000030619
ENSMUSG00000027490
ENSMUSG00000022472
ENSMUSG00000059552"""

gene_list = genes_of_interest.split("\n")
len(gene_list)
# Out:
# 16

# %%
data_input = pd.DataFrame(gene_list, columns=["identifier"])
data_input.head()

input_species = "Mouse"

bridgedb_df, bridgedb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species=input_species,
    input_datasource="Ensembl",
    output_datasource="All",
)

bridgedb_df.head(25)
# Out:
#             identifier identifier.source              target   target.source
# 0   ENSMUSG00000026295           Ensembl             4434677            Affy
# 1   ENSMUSG00000026295           Ensembl              Q8K1I3  Uniprot-TrEMBL
# 2   ENSMUSG00000026295           Ensembl        A_51_P166152         Agilent
# 3   ENSMUSG00000026295           Ensembl             5314352            Affy
# 4   ENSMUSG00000026295           Ensembl             4638627            Affy
# 5   ENSMUSG00000026295           Ensembl             4315932            Affy
# 6   ENSMUSG00000026295           Ensembl        1418916_a_at            Affy
# 7   ENSMUSG00000026295           Ensembl             5031793            Affy
# 8   ENSMUSG00000026295           Ensembl  ENSMUSG00000026295         Ensembl
# 9   ENSMUSG00000026295           Ensembl        ILMN_2903540        Illumina
# 10  ENSMUSG00000026295           Ensembl             5593013            Affy
# 11  ENSMUSG00000026295           Ensembl          A0A087WSF3  Uniprot-TrEMBL
# 12  ENSMUSG00000026295           Ensembl       A_55_P2179676         Agilent
# 13  ENSMUSG00000026295           Ensembl           108106_at            Affy
# 14  ENSMUSG00000026295           Ensembl         MGI:1922646             MGI
# 15  ENSMUSG00000026295           Ensembl           NP_083545          RefSeq
# 16  ENSMUSG00000026295           Ensembl            17215539            Affy
# 17  ENSMUSG00000026295           Ensembl          GO:0065003   Gene Ontology
# 18  ENSMUSG00000026295           Ensembl        ILMN_1218376        Illumina
# 19  ENSMUSG00000026295           Ensembl             4393830            Affy
# 20  ENSMUSG00000026295           Ensembl          GO:0046849   Gene Ontology
# 21  ENSMUSG00000026295           Ensembl              H3BLP2  Uniprot-TrEMBL
# 22  ENSMUSG00000026295           Ensembl             5063626            Affy
# 23  ENSMUSG00000026295           Ensembl          GO:0003674   Gene Ontology
# 24  ENSMUSG00000026295           Ensembl          GO:0005576   Gene Ontology

# %%
kegg_df, kegg_metadata = kegg.get_pathways(bridgedb_df)
kegg_df.head()
# Out:
# Getting KEGG IDs: 100%|██████████| 2/2 [00:09<00:00,  4.61s/it]
#            identifier identifier.source target target.source  \
# 0  ENSMUSG00000026295           Ensembl  75396     NCBI Gene
# 1  ENSMUSG00000022877           Ensembl  94175     NCBI Gene
# 2  ENSMUSG00000020914           Ensembl  21973     NCBI Gene
# 3  ENSMUSG00000024747           Ensembl  26358     NCBI Gene
# 4  ENSMUSG00000032081           Ensembl  11814     NCBI Gene
#
#                                        KEGG_pathways
# 0  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 1  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 2  [{'pathway_id': 'path:mmu01524', 'pathway_labe...
# 3  [{'pathway_id': 'path:mmu00830', 'pathway_labe...
# 4  [{'pathway_id': 'path:mmu03320', 'pathway_labe...

# %%
kegg_df["KEGG_pathways"][3]
# Out:
# [{'pathway_id': 'path:mmu00830',
#   'pathway_label': 'Retinol metabolism - Mus musculus (house mouse)',
#   'pathway_gene_counts': 101,
#   'pathway_compounds': [{'KEGG_id': 'C00376'},
#    {'KEGG_id': 'C00473'},
#    {'KEGG_id': 'C00777'},
#    {'KEGG_id': 'C00778'},
#    {'KEGG_id': 'C00899'},
#    {'KEGG_id': 'C02075'},
#    {'KEGG_id': 'C02094'},
#    {'KEGG_id': 'C02110'},
#    {'KEGG_id': 'C02588'},
#    {'KEGG_id': 'C03455'},
#    {'KEGG_id': 'C05914'},
#    {'KEGG_id': 'C05915'},
#    {'KEGG_id': 'C05916'},
#    {'KEGG_id': 'C05917'},
#    {'KEGG_id': 'C11061'},
#    {'KEGG_id': 'C15492'},
#    {'KEGG_id': 'C15493'},
#    {'KEGG_id': 'C16677'},
#    {'KEGG_id': 'C16678'},
#    {'KEGG_id': 'C16679'},
#    {'KEGG_id': 'C16680'},
#    {'KEGG_id': 'C16681'},
#    {'KEGG_id': 'C16682'},
#    {'KEGG_id': 'C16683'},
#    {'KEGG_id': 'C21797'}]},
#  {'pathway_id': 'path:mmu01100',
#   'pathway_label': 'Metabolic pathways - Mus musculus (house mouse)',
#   'pathway_gene_counts': 0,
#   'pathway_compounds': [{'KEGG_id': None}]}]

# %%
compounds_of_interest ="""C15492
C00473
C21797
"""

metabolite_list = compounds_of_interest.split("\n")
data_input = pd.DataFrame(metabolite_list, columns=["identifier"])

bridgedb_df_cmp, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species="Mouse",
    input_datasource="KEGG Compound",
    output_datasource="All",
)
bridgedb_df_cmp.head(25)
# Out:
#    identifier identifier.source                       target     target.source
# 0      C15492     KEGG Compound                    HMDB11618              HMDB
# 1      C15492     KEGG Compound                    Q27123154          Wikidata
# 2      C15492     KEGG Compound                       394057        ChemSpider
# 3      C15492     KEGG Compound                  HMDB0011618              HMDB
# 4      C15492     KEGG Compound  OVBOQVAIYMSUDT-HRYGCDPOSA-N          InChIKey
# 5      C15492     KEGG Compound                        52075             ChEBI
# 6      C15492     KEGG Compound                  CHEBI:52075             ChEBI
# 7      C15492     KEGG Compound                       C15492     KEGG Compound
# 8      C15492     KEGG Compound                  115797-14-3               CAS
# 9      C15492     KEGG Compound                 LMPR01090047        LIPID MAPS
# 10     C15492     KEGG Compound                       446798  PubChem Compound
# 11     C00473     KEGG Compound                       C00473     KEGG Compound
# 12     C00473     KEGG Compound                      68-26-8               CAS
# 13     C00473     KEGG Compound                 LMPR01090001        LIPID MAPS
# 14     C00473     KEGG Compound                       393012        ChemSpider
# 15     C00473     KEGG Compound                       C17276     KEGG Compound
# 16     C00473     KEGG Compound                   11103-57-4               CAS
# 17     C21797     KEGG Compound                      79-80-1               CAS
# 18     C21797     KEGG Compound                       C21797     KEGG Compound
# 19     C21797     KEGG Compound                      4940721        ChemSpider
# 20     C21797     KEGG Compound                 LMPR01090008        LIPID MAPS

# %%
kegg_compound_df = kegg.get_compounds(bridgedb_df_cmp)
kegg_compound_df.head()
# Out:
#   identifier identifier.source  target  target.source  \
# 0     C15492     KEGG Compound  C15492  KEGG Compound
# 1     C00473     KEGG Compound  C00473  KEGG Compound
# 2     C00473     KEGG Compound  C17276  KEGG Compound
# 3     C21797     KEGG Compound  C21797  KEGG Compound
#
#                                       KEGG_compounds
# 0  {'KEGG_id': 'C15492', 'KEGG_compound_name': 'a...
# 1  {'KEGG_id': 'C00473', 'KEGG_compound_name': 'R...
# 2  {'KEGG_id': 'C17276', 'KEGG_compound_name': 'R...
# 3  {'KEGG_id': 'C21797', 'KEGG_compound_name': 'a...

# %%
combined_df = combine_sources(
    bridgedb_df,
    [
        kegg_df,
    ],
)

# %%
combined_df, compoundwiki_metadata = compoundwiki.get_compound_annotations(combined_df, kegg_compound_df=kegg_compound_df)
# Out:
# Processing KEGG column for compounds...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\are10\anaconda3\envs\delanoenv\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\are10\anaconda3\envs\delanoenv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\are10\anaconda3\envs\delanoenv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'KEGG_pathways'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 combined_df, compoundwiki_metadata = compoundwiki.get_compound_annotations(combined_df, kegg_compound_df=kegg_compound_df)
#
# File c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src\pyBiodatafuse\annotators\compoundwiki.py:204, in get_compound_annotations(combined_df, kegg_compound_df)
#     201 print("Processing KEGG column for compounds...")
#     202 kegg_ids = []
# --> 204 for entry in kegg_compound_df[Cons.KEGG_PATHWAY_COL].dropna():
#     205     if isinstance(entry, list):
#     206         for item in entry:
#
# File c:\Users\are10\anaconda3\envs\delanoenv\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\are10\anaconda3\envs\delanoenv\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'KEGG_pathways'

# %%
combined_df.head()
# Out:
#            identifier identifier.source              target target.source  \
# 0  ENSMUSG00000026295           Ensembl  ENSMUSG00000026295       Ensembl
# 1  ENSMUSG00000022877           Ensembl  ENSMUSG00000022877       Ensembl
# 2  ENSMUSG00000020914           Ensembl  ENSMUSG00000020914       Ensembl
# 3  ENSMUSG00000024747           Ensembl  ENSMUSG00000024747       Ensembl
# 4  ENSMUSG00000032081           Ensembl  ENSMUSG00000032081       Ensembl
#
#                                        KEGG_pathways
# 0  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 1  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 2  [{'pathway_id': 'path:mmu01524', 'pathway_labe...
# 3  [{'pathway_id': 'path:mmu00830', 'pathway_labe...
# 4  [{'pathway_id': 'path:mmu03320', 'pathway_labe...
