# %% [markdown]
# # Example 2: Metabolite workflow
#
# This notebook provides insights on how to use the tool if you have list of metabolites.

# %% [markdown]
# # Import modules

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")

if src_path not in sys.path:
    sys.path.insert(0, src_path)

print("PYTHONPATH:", sys.path[0])
# Out:
# PYTHONPATH: c:\Users\are10\Documents\BAFSTU\code\pyBioDatafusemain\pyBiodatafuse\src

# %%
import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import molmedb, opentargets
from pyBiodatafuse.graph import saver
from pyBiodatafuse.graph import cytoscape
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import combine_sources, create_or_append_to_metadata

# %% [markdown]
# # Load list of metabolites/chemicals/compounds

# %%
metabolites_of_interest = """100208
10040286
10041551
10025195
5291"""

metabolite_list = metabolites_of_interest.split("\n")
len(metabolite_list)
# Out:
# 5

# %%
data_input = pd.DataFrame(metabolite_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0     100208
# 1   10040286
# 2   10041551
# 3   10025195
# 4       5291

# %% [markdown]
# ### Entity resolution using BridgeDB

# %%
bridgdb_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species="Human",
    input_datasource="PubChem Compound",
    output_datasource="All",
)
bridgdb_df.head()
# Out:
#   identifier identifier.source                       target     target.source
# 0     100208  PubChem-compound                        90560        ChemSpider
# 1     100208  PubChem-compound                       100208  PubChem Compound
# 2     100208  PubChem-compound                  HMDB0244377              HMDB
# 3     100208  PubChem-compound  OFDNQWIFNXBECV-UHFFFAOYSA-N          InChIKey
# 4     100208  PubChem-compound                       C11280     KEGG Compound

# %% [markdown]
# ### Transporter inhibited from MolMeDB

# %%
(
    molmedb_transporter_inhibited_df,
    molmedb_transporter_inhibited_metadata,
) = molmedb.get_compound_gene_inhibitor(bridgedb_df=bridgdb_df)
molmedb_transporter_inhibited_df.head()
# Out:
#   identifier identifier.source                       target target.source  \
# 0     100208  PubChem-compound  OFDNQWIFNXBECV-UHFFFAOYSA-N      InChIKey
# 1   10025195  PubChem-compound  LEJRLSZVESQKJK-UHFFFAOYSA-N      InChIKey
# 2   10040286  PubChem-compound  FYGREZKTJIXWIH-UHFFFAOYSA-N      InChIKey
# 3   10041551  PubChem-compound  OVVBIIBBRZVPAL-UHFFFAOYSA-N      InChIKey
# 4       5291  PubChem-compound  KTUFNOKKBVMGRW-UHFFFAOYSA-N      InChIKey
#
#                        MolMeDB_transporter_inhibited
# 0  [{'uniprot_trembl_id': 'P08183', 'hgnc_symbol'...
# 1  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 2  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 3  [{'uniprot_trembl_id': 'P23975', 'hgnc_symbol'...
# 4  [{'uniprot_trembl_id': 'O15244', 'hgnc_symbol'...

# %%
molmedb_transporter_inhibited_df["MolMeDB_transporter_inhibited"][0]
# Out:
# [{'uniprot_trembl_id': 'P08183',
#   'hgnc_symbol': 'ABCB1',
#   'source_pmid': '8621716'}]

# %% [markdown]
# ### Disease from OpenTargets

# %%
(
    opentargets_df,
    opentargets_metadata,
) = opentargets.get_compound_disease_interactions(bridgedb_df=bridgdb_df)
opentargets_df.head()
# Out:
# C:\Users\are10\AppData\Local\Temp\ipykernel_7284\3172929253.py:4: UserWarning: The intermediate_df in OpenTargets_diseases annotatur should be checked, please create an issue on https://github.com/BioDataFuse/pyBiodatafuse/issues/.
#   ) = opentargets.get_compound_disease_interactions(bridgedb_df=bridgdb_df)
#   identifier identifier.source    target     target.source  \
# 0     100208  PubChem-compound    100208  PubChem Compound
# 1   10025195  PubChem-compound  10025195  PubChem Compound
# 2   10040286  PubChem-compound  10040286  PubChem Compound
# 3   10041551  PubChem-compound  10041551  PubChem Compound
# 4       5291  PubChem-compound      5291  PubChem Compound
#
#                                 OpenTargets_diseases
# 0  [{'disease_name': nan, 'therapeutic_areas': na...
# 1  [{'disease_name': nan, 'therapeutic_areas': na...
# 2  [{'disease_name': nan, 'therapeutic_areas': na...
# 3  [{'disease_name': nan, 'therapeutic_areas': na...
# 4  [{'disease_name': 'colonic neoplasm', 'therape...

# %%
opentargets_df["OpenTargets_diseases"][4]
# Out:
# [{'disease_name': 'colonic neoplasm',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C2953',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005401',
#   'ORDO': '',
#   'EFO': 'EFO_0004288',
#   'DO': '',
#   'MESH': 'MESH_D003110',
#   'UMLS': 'UMLS_C0009375'},
#  {'disease_name': 'male breast carcinoma',
#   'therapeutic_areas': 'EFO_0010285:integumentary system disease, OTAR_0000017:reproductive system or breast disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3862',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005628',
#   'ORDO': '',
#   'EFO': 'EFO_0006861',
#   'DO': 'DO_1614',
#   'MESH': 'MESH_D018567',
#   'UMLS': 'UMLS_C0242788'},
#  {'disease_name': 'thyroid cancer',
#   'therapeutic_areas': 'EFO_0001379:endocrine system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C7510',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1781',
#   'MESH': '',
#   'UMLS': 'UMLS_C0007115'},
#  {'disease_name': 'systemic scleroderma',
#   'therapeutic_areas': 'MONDO_0024458:disorder of visual system, OTAR_0000010:respiratory or thoracic disease, EFO_0000540:immune system disease, OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0010285:integumentary system disease, EFO_0009690:urinary system disease, OTAR_0000018:genetic, familial or congenital disease',
#   'HPO': '',
#   'NCI': 'NCI_C72070',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005100',
#   'ORDO': 'ORDO_90291',
#   'EFO': '',
#   'DO': 'DO_418',
#   'MESH': 'MESH_D012595',
#   'UMLS': 'UMLS_C0036421'},
#  {'disease_name': 'malignant peripheral nerve sheath tumor',
#   'therapeutic_areas': 'EFO_0000618:nervous system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3798',
#   'OMIM': '',
#   'MONDO': 'MONDO_0017827',
#   'ORDO': 'ORDO_3148',
#   'EFO': '',
#   'DO': 'DO_5940',
#   'MESH': 'MESH_D018317',
#   'UMLS': 'UMLS_C0751690'},
#  {'disease_name': 'localised scleroderma',
#   'therapeutic_areas': 'EFO_0000540:immune system disease, OTAR_0000018:genetic, familial or congenital disease, MONDO_0024458:disorder of visual system, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': '',
#   'NCI': 'NCI_C72069',
#   'OMIM': '',
#   'MONDO': 'MONDO_0019562',
#   'ORDO': 'ORDO_90289',
#   'EFO': '',
#   'DO': 'DO_8472',
#   'MESH': 'MESH_D012594',
#   'UMLS': 'UMLS_C0036420'},
#  {'disease_name': 'colorectal cancer',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C4978',
#   'OMIM': 'OMIM_114500',
#   'MONDO': '',
#   'ORDO': 'ORDO_466667',
#   'EFO': '',
#   'DO': 'DO_9256',
#   'MESH': '',
#   'UMLS': 'UMLS_C0346629'},
#  {'disease_name': 'anaplastic large cell lymphoma',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, MONDO_0045024:cancer or benign tumor, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C3720',
#   'OMIM': '',
#   'MONDO': 'MONDO_0020325',
#   'ORDO': 'ORDO_98841',
#   'EFO': 'EFO_0003032',
#   'DO': 'DO_0050744',
#   'MESH': 'MESH_D017728',
#   'UMLS': 'UMLS_C0206180'},
#  {'disease_name': 'pneumonia',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease, EFO_0005741:infectious disease',
#   'HPO': '',
#   'NCI': 'NCI_C3333',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005249',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_552',
#   'MESH': 'MESH_D011014',
#   'UMLS': 'UMLS_C0032285'},
#  {'disease_name': 'pulmonary arterial hypertension',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease, EFO_0000319:cardiovascular disease',
#   'HPO': '',
#   'NCI': 'NCI_C3120',
#   'OMIM': 'OMIM_615371',
#   'MONDO': 'MONDO_0015924',
#   'ORDO': 'ORDO_182090',
#   'EFO': '',
#   'DO': 'DO_6432',
#   'MESH': 'MESH_D000081029',
#   'UMLS': 'UMLS_C2973725'},
#  {'disease_name': 'dermatofibrosarcoma protuberans',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000018:genetic, familial or congenital disease, OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0010285:integumentary system disease',
#   'HPO': '',
#   'NCI': 'NCI_C4683',
#   'OMIM': 'OMIM_607907',
#   'MONDO': '',
#   'ORDO': 'ORDO_31112',
#   'EFO': '',
#   'DO': 'DO_3507',
#   'MESH': 'MESH_D018223',
#   'UMLS': 'UMLS_C3693482'},
#  {'disease_name': 'melanoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0002861',
#   'NCI': 'NCI_C3224',
#   'OMIM': 'OMIM_155600',
#   'MONDO': 'MONDO_0005105',
#   'ORDO': 'ORDO_411533',
#   'EFO': 'EFO_0000756',
#   'DO': 'DO_1909',
#   'MESH': 'MESH_D008545',
#   'UMLS': 'UMLS_CN971653'},
#  {'disease_name': 'asthma',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease',
#   'HPO': 'HPO_HP:0002099',
#   'NCI': 'NCI_C28397',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_2841',
#   'MESH': 'MESH_D001249',
#   'UMLS': 'UMLS_C0004096'},
#  {'disease_name': 'influenza',
#   'therapeutic_areas': 'EFO_0005741:infectious disease, OTAR_0000010:respiratory or thoracic disease',
#   'HPO': '',
#   'NCI': 'NCI_C53482',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005812',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_8469',
#   'MESH': 'MESH_D009976',
#   'UMLS': 'UMLS_C0021400'},
#  {'disease_name': 'myeloid leukemia',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, EFO_0000540:immune system disease, OTAR_0000006:musculoskeletal or connective tissue disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3172',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_8692',
#   'MESH': 'MESH_D007951',
#   'UMLS': 'UMLS_C0023470'},
#  {'disease_name': 'head and neck squamous cell carcinoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C34447',
#   'OMIM': 'OMIM_275355',
#   'MONDO': 'MONDO_0010150',
#   'ORDO': 'ORDO_67037',
#   'EFO': 'EFO_0000181',
#   'DO': 'DO_5520',
#   'MESH': 'MESH_D000077195',
#   'UMLS': 'UMLS_C1168401'},
#  {'disease_name': 'rheumatoid arthritis',
#   'therapeutic_areas': 'EFO_0000540:immune system disease, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': 'HPO_HP:0001370',
#   'NCI': 'NCI_C2884',
#   'OMIM': 'OMIM_180300',
#   'MONDO': 'MONDO_0008383',
#   'ORDO': 'ORDO_284130',
#   'EFO': '',
#   'DO': 'DO_7148',
#   'MESH': 'MESH_D001172',
#   'UMLS': 'UMLS_C0003873'},
#  {'disease_name': 'chordoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': 'HPO_HP:0010762',
#   'NCI': 'NCI_C2947',
#   'OMIM': 'OMIM_215400',
#   'MONDO': '',
#   'ORDO': 'ORDO_178',
#   'EFO': '',
#   'DO': 'DO_3302',
#   'MESH': 'MESH_D002817',
#   'UMLS': 'UMLS_C0008487'},
#  {'disease_name': 'skin neoplasm',
#   'therapeutic_areas': 'EFO_0010285:integumentary system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3372',
#   'OMIM': '',
#   'MONDO': 'MONDO_0002531',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_4159',
#   'MESH': 'MESH_D012878',
#   'UMLS': 'UMLS_C0037286'},
#  {'disease_name': 'systemic scleroderma',
#   'therapeutic_areas': 'MONDO_0024458:disorder of visual system, OTAR_0000010:respiratory or thoracic disease, EFO_0000540:immune system disease, OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0010285:integumentary system disease, EFO_0009690:urinary system disease, OTAR_0000018:genetic, familial or congenital disease',
#   'HPO': '',
#   'NCI': 'NCI_C72070',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005100',
#   'ORDO': 'ORDO_90291',
#   'EFO': '',
#   'DO': 'DO_418',
#   'MESH': 'MESH_D012595',
#   'UMLS': 'UMLS_C0036421'},
#  {'disease_name': 'acute lymphoblastic leukemia',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0006721',
#   'NCI': 'NCI_C3167',
#   'OMIM': '',
#   'MONDO': 'MONDO_0004967',
#   'ORDO': 'ORDO_513',
#   'EFO': 'EFO_0000220',
#   'DO': 'DO_1037',
#   'MESH': '',
#   'UMLS': 'UMLS_C0023449'},
#  {'disease_name': 'multiple sclerosis',
#   'therapeutic_areas': 'EFO_0000618:nervous system disease, EFO_0000540:immune system disease',
#   'HPO': '',
#   'NCI': 'NCI_C3243',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_802',
#   'EFO': '',
#   'DO': 'DO_2377',
#   'MESH': 'MESH_D009103',
#   'UMLS': 'UMLS_C0026769'},
#  {'disease_name': 'neurofibromatosis type 1',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0000618:nervous system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3273',
#   'OMIM': 'OMIM_162200',
#   'MONDO': '',
#   'ORDO': 'ORDO_636',
#   'EFO': '',
#   'DO': 'DO_0111253',
#   'MESH': 'MESH_C538607',
#   'UMLS': 'UMLS_C0027831'},
#  {'disease_name': 'type 1 diabetes mellitus',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, EFO_0009605:pancreas disease, EFO_0001379:endocrine system disease, EFO_0000540:immune system disease, OTAR_0000020:nutritional or metabolic disease',
#   'HPO': '',
#   'NCI': 'NCI_C2986',
#   'OMIM': 'OMIM_222100',
#   'MONDO': '',
#   'ORDO': 'ORDO_243377',
#   'EFO': '',
#   'DO': 'DO_9744',
#   'MESH': 'MESH_D003922',
#   'UMLS': 'UMLS_C0011854'},
#  {'disease_name': 'gliosarcoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0000618:nervous system disease',
#   'HPO': '',
#   'NCI': 'NCI_C3796',
#   'OMIM': '',
#   'MONDO': 'MONDO_0016681',
#   'ORDO': 'ORDO_251576',
#   'EFO': 'EFO_1001465',
#   'DO': 'DO_3071',
#   'MESH': 'MESH_D018316',
#   'UMLS': 'UMLS_C0206726'},
#  {'disease_name': 'thyroid cancer',
#   'therapeutic_areas': 'EFO_0001379:endocrine system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C7510',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1781',
#   'MESH': '',
#   'UMLS': 'UMLS_C0007115'},
#  {'disease_name': 'small cell lung carcinoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000010:respiratory or thoracic disease, OTAR_0000018:genetic, familial or congenital disease, EFO_0001379:endocrine system disease',
#   'HPO': '',
#   'NCI': 'NCI_C4917',
#   'OMIM': 'OMIM_182280',
#   'MONDO': 'MONDO_0008433',
#   'ORDO': 'ORDO_70573',
#   'EFO': 'EFO_0000702',
#   'DO': 'DO_5409',
#   'MESH': 'MESH_D055752',
#   'UMLS': 'UMLS_C0262584'},
#  {'disease_name': 'polycythemia vera',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor, EFO_0000540:immune system disease, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': '',
#   'NCI': 'NCI_C3336',
#   'OMIM': 'OMIM_263300',
#   'MONDO': 'MONDO_0009891',
#   'ORDO': 'ORDO_729',
#   'EFO': 'EFO_0002429',
#   'DO': 'DO_8997',
#   'MESH': 'MESH_D011087',
#   'UMLS': 'UMLS_C0032463'},
#  {'disease_name': 'Eosinophilia',
#   'therapeutic_areas': 'EFO_0000651:phenotype',
#   'HPO': '',
#   'NCI': '',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': '',
#   'UMLS': 'UMLS_C0014457'},
#  {'disease_name': 'graft versus host disease',
#   'therapeutic_areas': 'OTAR_0000009:injury, poisoning or other complication, EFO_0000540:immune system disease',
#   'HPO': '',
#   'NCI': 'NCI_C3063',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_39812',
#   'EFO': '',
#   'DO': 'DO_0081267',
#   'MESH': 'MESH_D006086',
#   'UMLS': 'UMLS_C0018133'},
#  {'disease_name': 'mesothelioma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3234',
#   'OMIM': 'OMIM_156240',
#   'MONDO': 'MONDO_0005065',
#   'ORDO': '',
#   'EFO': 'EFO_0000588',
#   'DO': '',
#   'MESH': 'MESH_D008654',
#   'UMLS': 'UMLS_C0025500'},
#  {'disease_name': 'Desmoid-type fibromatosis',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, OTAR_0000006:musculoskeletal or connective tissue disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9182',
#   'OMIM': 'OMIM_135290',
#   'MONDO': 'MONDO_0007608',
#   'ORDO': 'ORDO_873',
#   'EFO': '',
#   'DO': 'DO_0080366',
#   'MESH': '',
#   'UMLS': 'UMLS_C0079218'},
#  {'disease_name': 'loiasis',
#   'therapeutic_areas': 'EFO_0010285:integumentary system disease, EFO_0005741:infectious disease',
#   'HPO': '',
#   'NCI': 'NCI_C34784',
#   'OMIM': '',
#   'MONDO': 'MONDO_0016566',
#   'ORDO': 'ORDO_2404',
#   'EFO': '',
#   'DO': 'DO_13523',
#   'MESH': 'MESH_D008118',
#   'UMLS': 'UMLS_C0023968'},
#  {'disease_name': 'COVID-19',
#   'therapeutic_areas': 'EFO_0005741:infectious disease',
#   'HPO': '',
#   'NCI': '',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0080600',
#   'MESH': 'MESH_D000086382',
#   'UMLS': 'UMLS_C5203670'},
#  {'disease_name': 'chronic myelogenous leukemia',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0000540:immune system disease, EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': '',
#   'NCI': 'NCI_C3174',
#   'OMIM': 'OMIM_608232',
#   'MONDO': 'MONDO_0011996',
#   'ORDO': 'ORDO_521',
#   'EFO': 'EFO_0000339',
#   'DO': 'DO_0081088',
#   'MESH': '',
#   'UMLS': 'UMLS_C0279543'},
#  {'disease_name': 'cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9305',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0050687',
#   'MESH': '',
#   'UMLS': 'UMLS_C0006826'},
#  {'disease_name': 'metastatic melanoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C8925',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005191',
#   'ORDO': '',
#   'EFO': 'EFO_0002617',
#   'DO': '',
#   'MESH': '',
#   'UMLS': 'UMLS_C0278883'},
#  {'disease_name': 'malignant colon neoplasm',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9242',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_219',
#   'MESH': '',
#   'UMLS': 'UMLS_C0007102'},
#  {'disease_name': 'pulmonary hypertension',
#   'therapeutic_areas': 'EFO_0000319:cardiovascular disease',
#   'HPO': '',
#   'NCI': '',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_6432',
#   'MESH': 'MESH_D006976',
#   'UMLS': 'UMLS_C0020542'},
#  {'disease_name': 'endometrial cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000017:reproductive system or breast disease',
#   'HPO': '',
#   'NCI': 'NCI_C27815',
#   'OMIM': 'OMIM_608089',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1380',
#   'MESH': '',
#   'UMLS': 'UMLS_C0007103'},
#  {'disease_name': 'pulmonary venoocclusive disease',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, OTAR_0000010:respiratory or thoracic disease, EFO_0000319:cardiovascular disease',
#   'HPO': '',
#   'NCI': 'NCI_C85039',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_31837',
#   'EFO': '',
#   'DO': 'DO_5453',
#   'MESH': 'MESH_D011668',
#   'UMLS': 'UMLS_C0034091'},
#  {'disease_name': 'sarcoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9118',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005089',
#   'ORDO': '',
#   'EFO': 'EFO_0000691',
#   'DO': 'DO_1115',
#   'MESH': 'MESH_D012509',
#   'UMLS': 'UMLS_C1261473'},
#  {'disease_name': 'ovarian cancer',
#   'therapeutic_areas': 'OTAR_0000017:reproductive system or breast disease, MONDO_0045024:cancer or benign tumor, EFO_0001379:endocrine system disease',
#   'HPO': '',
#   'NCI': 'NCI_C7431',
#   'OMIM': 'OMIM_167000',
#   'MONDO': '',
#   'ORDO': 'ORDO_213500',
#   'EFO': '',
#   'DO': 'DO_2394',
#   'MESH': 'MESH_D010051',
#   'UMLS': 'UMLS_C1140680'},
#  {'disease_name': 'rectum cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0010282:gastrointestinal disease',
#   'HPO': '',
#   'NCI': 'NCI_C7418',
#   'OMIM': '',
#   'MONDO': 'MONDO_0006519',
#   'ORDO': '',
#   'EFO': 'EFO_1000657',
#   'DO': 'DO_1993',
#   'MESH': '',
#   'UMLS': 'UMLS_C0949022'},
#  {'disease_name': 'desmoplastic small round cell tumor',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C8300',
#   'OMIM': '',
#   'MONDO': 'MONDO_0019373',
#   'ORDO': 'ORDO_83469',
#   'EFO': 'EFO_1000895',
#   'DO': 'DO_6785',
#   'MESH': 'MESH_D058405',
#   'UMLS': 'UMLS_C0281508'},
#  {'disease_name': 'lung cancer',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C7377',
#   'OMIM': 'OMIM_211980',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1324',
#   'MESH': '',
#   'UMLS': 'UMLS_C0242379'},
#  {'disease_name': 'breast cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0010285:integumentary system disease, OTAR_0000017:reproductive system or breast disease',
#   'HPO': '',
#   'NCI': 'NCI_C9335',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1612',
#   'MESH': '',
#   'UMLS': 'UMLS_C0006142'},
#  {'disease_name': 'papillary thyroid carcinoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0001379:endocrine system disease',
#   'HPO': 'HPO_HP:0002895',
#   'NCI': 'NCI_C4035',
#   'OMIM': 'OMIM_188550',
#   'MONDO': 'MONDO_0005075',
#   'ORDO': '',
#   'EFO': 'EFO_0000641',
#   'DO': 'DO_3969',
#   'MESH': '',
#   'UMLS': 'UMLS_C0238463'},
#  {'disease_name': 'COVID-19',
#   'therapeutic_areas': 'EFO_0005741:infectious disease',
#   'HPO': '',
#   'NCI': '',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0080600',
#   'MESH': 'MESH_D000086382',
#   'UMLS': 'UMLS_C5203670'},
#  {'disease_name': 'malignant epithelial tumor of ovary',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0001379:endocrine system disease, OTAR_0000017:reproductive system or breast disease',
#   'HPO': '',
#   'NCI': 'NCI_C40026',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_398934',
#   'EFO': '',
#   'DO': 'DO_2151',
#   'MESH': 'MESH_C538090',
#   'UMLS': 'UMLS_C0346161'},
#  {'disease_name': 'pancreatic carcinoma',
#   'therapeutic_areas': 'EFO_0001379:endocrine system disease, EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor, EFO_0009605:pancreas disease',
#   'HPO': '',
#   'NCI': 'NCI_C3850',
#   'OMIM': 'OMIM_260350',
#   'MONDO': 'MONDO_0005192',
#   'ORDO': '',
#   'EFO': 'EFO_0002618',
#   'DO': 'DO_4905',
#   'MESH': '',
#   'UMLS': 'UMLS_C0235974'},
#  {'disease_name': 'uterine cancer',
#   'therapeutic_areas': 'OTAR_0000017:reproductive system or breast disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3552',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_363',
#   'MESH': 'MESH_D014594',
#   'UMLS': 'UMLS_C0153567'},
#  {'disease_name': 'carcinoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C2916',
#   'OMIM': '',
#   'MONDO': 'MONDO_0004993',
#   'ORDO': '',
#   'EFO': 'EFO_0000313',
#   'DO': 'DO_305',
#   'MESH': 'MESH_D002277',
#   'UMLS': 'UMLS_C0007097'},
#  {'disease_name': 'Desmoid-type fibromatosis',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, OTAR_0000006:musculoskeletal or connective tissue disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9182',
#   'OMIM': 'OMIM_135290',
#   'MONDO': 'MONDO_0007608',
#   'ORDO': 'ORDO_873',
#   'EFO': '',
#   'DO': 'DO_0080366',
#   'MESH': '',
#   'UMLS': 'UMLS_C0079218'},
#  {'disease_name': 'T-cell acute lymphoblastic leukemia',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0000540:immune system disease, EFO_0005803:hematologic disease, OTAR_0000018:genetic, familial or congenital disease',
#   'HPO': '',
#   'NCI': 'NCI_C3183',
#   'OMIM': '',
#   'MONDO': 'MONDO_0004963',
#   'ORDO': '',
#   'EFO': 'EFO_0000209',
#   'DO': 'DO_5603',
#   'MESH': '',
#   'UMLS': 'UMLS_C1961099'},
#  {'disease_name': 'breast cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0010285:integumentary system disease, OTAR_0000017:reproductive system or breast disease',
#   'HPO': '',
#   'NCI': 'NCI_C9335',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1612',
#   'MESH': '',
#   'UMLS': 'UMLS_C0006142'},
#  {'disease_name': 'Uterine Carcinosarcoma',
#   'therapeutic_areas': 'OTAR_0000017:reproductive system or breast disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C42700',
#   'OMIM': '',
#   'MONDO': 'MONDO_0006485',
#   'ORDO': '',
#   'EFO': 'EFO_1000613',
#   'DO': 'DO_6171',
#   'MESH': 'MESH_D012192',
#   'UMLS': 'UMLS_C0280630'},
#  {'disease_name': 'gastric cancer',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9331',
#   'OMIM': 'OMIM_613659',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_10534',
#   'MESH': '',
#   'UMLS': 'UMLS_C0024623'},
#  {'disease_name': 'melanoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0002861',
#   'NCI': 'NCI_C3224',
#   'OMIM': 'OMIM_155600',
#   'MONDO': 'MONDO_0005105',
#   'ORDO': 'ORDO_411533',
#   'EFO': 'EFO_0000756',
#   'DO': 'DO_1909',
#   'MESH': 'MESH_D008545',
#   'UMLS': 'UMLS_CN971653'},
#  {'disease_name': 'Merkel cell skin cancer',
#   'therapeutic_areas': 'EFO_0010285:integumentary system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9231',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': 'MESH_D015266',
#   'UMLS': ''},
#  {'disease_name': 'tuberculosis',
#   'therapeutic_areas': 'EFO_0005741:infectious disease',
#   'HPO': '',
#   'NCI': 'NCI_C3423',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_3389',
#   'EFO': '',
#   'DO': 'DO_399',
#   'MESH': 'MESH_D014376',
#   'UMLS': 'UMLS_C0041296'},
#  {'disease_name': 'Malignant Pancreatic Neoplasm',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, EFO_0001379:endocrine system disease, EFO_0009605:pancreas disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9005',
#   'OMIM': 'OMIM_618680',
#   'MONDO': 'MONDO_0009831',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1793',
#   'MESH': '',
#   'UMLS': ''},
#  {'disease_name': 'lung cancer',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C7377',
#   'OMIM': 'OMIM_211980',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1324',
#   'MESH': '',
#   'UMLS': 'UMLS_C0242379'},
#  {'disease_name': 'cutaneous melanoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0010285:integumentary system disease',
#   'HPO': 'HPO_HP:0012056',
#   'NCI': 'NCI_C3510',
#   'OMIM': 'OMIM_155600',
#   'MONDO': 'MONDO_0005012',
#   'ORDO': '',
#   'EFO': 'EFO_0000389',
#   'DO': 'DO_8923',
#   'MESH': '',
#   'UMLS': 'UMLS_C0153535'},
#  {'disease_name': 'chondrosarcoma',
#   'therapeutic_areas': 'OTAR_0000006:musculoskeletal or connective tissue disease, MONDO_0045024:cancer or benign tumor, OTAR_0000018:genetic, familial or congenital disease',
#   'HPO': 'HPO_HP:0006765',
#   'NCI': 'NCI_C2946',
#   'OMIM': 'OMIM_215300',
#   'MONDO': 'MONDO_0008977',
#   'ORDO': 'ORDO_55880',
#   'EFO': 'EFO_0000333',
#   'DO': 'DO_3371',
#   'MESH': 'MESH_D002813',
#   'UMLS': 'UMLS_C0008479'},
#  {'disease_name': 'idiopathic pulmonary fibrosis',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000010:respiratory or thoracic disease',
#   'HPO': '',
#   'NCI': 'NCI_C35716',
#   'OMIM': 'OMIM_178500',
#   'MONDO': '',
#   'ORDO': 'ORDO_2032',
#   'EFO': 'EFO_0000768',
#   'DO': 'DO_0050156',
#   'MESH': 'MESH_D054990',
#   'UMLS': ''},
#  {'disease_name': 'non-small cell lung carcinoma',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0030358',
#   'NCI': 'NCI_C2926',
#   'OMIM': 'OMIM_211980',
#   'MONDO': 'MONDO_0005233',
#   'ORDO': 'ORDO_488201',
#   'EFO': 'EFO_0003060',
#   'DO': 'DO_3908',
#   'MESH': 'MESH_D002289',
#   'UMLS': 'UMLS_C0007131'},
#  {'disease_name': 'wet macular degeneration',
#   'therapeutic_areas': 'MONDO_0024458:disorder of visual system, OTAR_0000018:genetic, familial or congenital disease, MONDO_0002025:psychiatric disorder, EFO_0000618:nervous system disease',
#   'HPO': '',
#   'NCI': '',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005417',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_10873',
#   'MESH': 'MESH_D057135',
#   'UMLS': 'UMLS_C2237660'},
#  {'disease_name': 'pulmonary arterial hypertension',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease, EFO_0000319:cardiovascular disease',
#   'HPO': '',
#   'NCI': 'NCI_C3120',
#   'OMIM': 'OMIM_615371',
#   'MONDO': 'MONDO_0015924',
#   'ORDO': 'ORDO_182090',
#   'EFO': '',
#   'DO': 'DO_6432',
#   'MESH': 'MESH_D000081029',
#   'UMLS': 'UMLS_C2973725'},
#  {'disease_name': 'childhood acute lymphoblastic leukemia',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3168',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0080144',
#   'MESH': '',
#   'UMLS': 'UMLS_C0023452'},
#  {'disease_name': 'head and neck malignant neoplasia',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C4013',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005627',
#   'ORDO': '',
#   'EFO': 'EFO_0006859',
#   'DO': 'DO_11934',
#   'MESH': '',
#   'UMLS': 'UMLS_C0278996'},
#  {'disease_name': 'glioblastoma multiforme',
#   'therapeutic_areas': 'EFO_0000618:nervous system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0100843',
#   'NCI': 'NCI_C3058',
#   'OMIM': '',
#   'MONDO': 'MONDO_0018177',
#   'ORDO': 'ORDO_360',
#   'EFO': '',
#   'DO': 'DO_3068',
#   'MESH': 'MESH_D005909',
#   'UMLS': 'UMLS_C1621958'},
#  {'disease_name': 'fibromatosis',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': '',
#   'NCI': 'NCI_C3042',
#   'OMIM': 'OMIM_135290',
#   'MONDO': 'MONDO_0005031',
#   'ORDO': '',
#   'EFO': 'EFO_0000497',
#   'DO': '',
#   'MESH': '',
#   'UMLS': 'UMLS_C0016048'},
#  {'disease_name': 'B-cell acute lymphoblastic leukemia',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000018:genetic, familial or congenital disease, EFO_0000540:immune system disease, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C8936',
#   'OMIM': '',
#   'MONDO': 'MONDO_0004947',
#   'ORDO': '',
#   'EFO': 'EFO_0000094',
#   'DO': 'DO_7061',
#   'MESH': '',
#   'UMLS': 'UMLS_C1292769'},
#  {'disease_name': 'non-Hodgkins lymphoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C3211',
#   'OMIM': '',
#   'MONDO': 'MONDO_0018908',
#   'ORDO': 'ORDO_547',
#   'EFO': 'EFO_0005952',
#   'DO': 'DO_0060060',
#   'MESH': 'MESH_D008228',
#   'UMLS': 'UMLS_C0024305'},
#  {'disease_name': 'cirrhosis of liver',
#   'therapeutic_areas': 'EFO_0001379:endocrine system disease, EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C2951',
#   'OMIM': 'OMIM_215600',
#   'MONDO': 'MONDO_0005155',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_5082',
#   'MESH': 'MESH_D008103',
#   'UMLS': 'UMLS_C0023890'},
#  {'disease_name': 'neoplasm',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0002664',
#   'NCI': 'NCI_C3262',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005070',
#   'ORDO': '',
#   'EFO': 'EFO_0000616',
#   'DO': 'DO_14566',
#   'MESH': 'MESH_D009369',
#   'UMLS': 'UMLS_C0027651'},
#  {'disease_name': 'sickle cell anemia',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, OTAR_0000018:genetic, familial or congenital disease',
#   'HPO': '',
#   'NCI': 'NCI_C34383',
#   'OMIM': 'OMIM_603903',
#   'MONDO': '',
#   'ORDO': 'ORDO_232',
#   'EFO': '',
#   'DO': 'DO_10923',
#   'MESH': 'MESH_D000755',
#   'UMLS': 'UMLS_C0002895'},
#  {'disease_name': 'gastrointestinal stromal tumor',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3868',
#   'OMIM': 'OMIM_606764',
#   'MONDO': '',
#   'ORDO': 'ORDO_44890',
#   'EFO': '',
#   'DO': 'DO_9253',
#   'MESH': 'MESH_D046152',
#   'UMLS': 'UMLS_C0238198'},
#  {'disease_name': 'Plasmodium falciparum malaria',
#   'therapeutic_areas': 'EFO_0001379:endocrine system disease, EFO_0005803:hematologic disease, EFO_0010282:gastrointestinal disease, EFO_0005741:infectious disease',
#   'HPO': '',
#   'NCI': 'NCI_C34798',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005920',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_14067',
#   'MESH': 'MESH_D016778',
#   'UMLS': 'UMLS_C0024535'},
#  {'disease_name': 'chronic myelogenous leukemia',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0000540:immune system disease, EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': '',
#   'NCI': 'NCI_C3174',
#   'OMIM': 'OMIM_608232',
#   'MONDO': 'MONDO_0011996',
#   'ORDO': 'ORDO_521',
#   'EFO': 'EFO_0000339',
#   'DO': 'DO_0081088',
#   'MESH': '',
#   'UMLS': 'UMLS_C0279543'},
#  {'disease_name': 'fibrosarcoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': 'HPO_HP:0100244',
#   'NCI': 'NCI_C3043',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005164',
#   'ORDO': 'ORDO_2030',
#   'EFO': 'EFO_0002087',
#   'DO': 'DO_3355',
#   'MESH': 'MESH_D005354',
#   'UMLS': 'UMLS_C0016057'},
#  {'disease_name': 'prostate cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000017:reproductive system or breast disease',
#   'HPO': '',
#   'NCI': 'NCI_C7378',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_10283',
#   'MESH': 'MESH_D011471',
#   'UMLS': 'UMLS_C0376358'},
#  {'disease_name': 'cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9305',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0050687',
#   'MESH': '',
#   'UMLS': 'UMLS_C0006826'},
#  {'disease_name': 'kidney cancer',
#   'therapeutic_areas': 'EFO_0009690:urinary system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C7548',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_263',
#   'MESH': 'MESH_D007680',
#   'UMLS': 'UMLS_C0740457'},
#  {'disease_name': 'peritoneum cancer',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0010282:gastrointestinal disease',
#   'HPO': '',
#   'NCI': 'NCI_C3538',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_1725',
#   'MESH': '',
#   'UMLS': 'UMLS_C0153467'},
#  {'disease_name': 'graft versus host disease',
#   'therapeutic_areas': 'OTAR_0000009:injury, poisoning or other complication, EFO_0000540:immune system disease',
#   'HPO': '',
#   'NCI': 'NCI_C3063',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_39812',
#   'EFO': '',
#   'DO': 'DO_0081267',
#   'MESH': 'MESH_D006086',
#   'UMLS': 'UMLS_C0018133'},
#  {'disease_name': 'colorectal carcinoma',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C2955',
#   'OMIM': '',
#   'MONDO': 'MONDO_0024331',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0080199',
#   'MESH': '',
#   'UMLS': 'UMLS_CN221574'},
#  {'disease_name': 'pulmonary hypertension',
#   'therapeutic_areas': 'EFO_0000319:cardiovascular disease',
#   'HPO': '',
#   'NCI': '',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_6432',
#   'MESH': 'MESH_D006976',
#   'UMLS': 'UMLS_C0020542'},
#  {'disease_name': 'Central Nervous System Neoplasm',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0000618:nervous system disease',
#   'HPO': '',
#   'NCI': 'NCI_C9293',
#   'OMIM': '',
#   'MONDO': 'MONDO_0006130',
#   'ORDO': '',
#   'EFO': 'EFO_1000158',
#   'DO': '',
#   'MESH': '',
#   'UMLS': 'UMLS_C0085136'},
#  {'disease_name': 'lymphoblastic lymphoma',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, MONDO_0045024:cancer or benign tumor, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C9360',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0080147',
#   'MESH': '',
#   'UMLS': 'UMLS_C0079748'},
#  {'disease_name': 'hematopoietic and lymphoid cell neoplasm',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C27134',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': '',
#   'UMLS': 'UMLS_C0376544'},
#  {'disease_name': 'glioblastoma multiforme',
#   'therapeutic_areas': 'EFO_0000618:nervous system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0100843',
#   'NCI': 'NCI_C3058',
#   'OMIM': '',
#   'MONDO': 'MONDO_0018177',
#   'ORDO': 'ORDO_360',
#   'EFO': '',
#   'DO': 'DO_3068',
#   'MESH': 'MESH_D005909',
#   'UMLS': 'UMLS_C1621958'},
#  {'disease_name': 'gastrointestinal stromal tumor',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3868',
#   'OMIM': 'OMIM_606764',
#   'MONDO': '',
#   'ORDO': 'ORDO_44890',
#   'EFO': '',
#   'DO': 'DO_9253',
#   'MESH': 'MESH_D046152',
#   'UMLS': 'UMLS_C0238198'},
#  {'disease_name': 'lymphangioleiomyomatosis',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3725',
#   'OMIM': 'OMIM_606690',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': 'MESH_D018192',
#   'UMLS': 'UMLS_C0751674'},
#  {'disease_name': 'fallopian tube cancer',
#   'therapeutic_areas': 'OTAR_0000017:reproductive system or breast disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C7480',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_180242',
#   'EFO': '',
#   'DO': 'DO_1964',
#   'MESH': '',
#   'UMLS': 'UMLS_C0153579'},
#  {'disease_name': 'gastric adenocarcinoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0010282:gastrointestinal disease',
#   'HPO': '',
#   'NCI': 'NCI_C4004',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005036',
#   'ORDO': 'ORDO_464463',
#   'EFO': 'EFO_0000503',
#   'DO': 'DO_3717',
#   'MESH': '',
#   'UMLS': 'UMLS_C0278701'},
#  {'disease_name': 'Hypereosinophilic syndrome',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease, OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0000319:cardiovascular disease, EFO_0000540:immune system disease',
#   'HPO': '',
#   'NCI': 'NCI_C27038',
#   'OMIM': '',
#   'MONDO': 'MONDO_0015691',
#   'ORDO': 'ORDO_168956',
#   'EFO': '',
#   'DO': 'DO_999',
#   'MESH': 'MESH_D017681',
#   'UMLS': 'UMLS_C1540912'},
#  {'disease_name': 'stroke',
#   'therapeutic_areas': 'EFO_0000618:nervous system disease, EFO_0000319:cardiovascular disease',
#   'HPO': 'HPO_HP:0001297',
#   'NCI': 'NCI_C3390',
#   'OMIM': 'OMIM_601367',
#   'MONDO': 'MONDO_0005098',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': 'MESH_D020521',
#   'UMLS': 'UMLS_C0038454'},
#  {'disease_name': 'nephrogenic fibrosing dermopathy',
#   'therapeutic_areas': 'EFO_0010285:integumentary system disease',
#   'HPO': '',
#   'NCI': 'NCI_C84920',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_Orphanet_137617',
#   'EFO': '',
#   'DO': '',
#   'MESH': 'MESH_D054989',
#   'UMLS': ''},
#  {'disease_name': 'Hypereosinophilic syndrome',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease, OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0000319:cardiovascular disease, EFO_0000540:immune system disease',
#   'HPO': '',
#   'NCI': 'NCI_C27038',
#   'OMIM': '',
#   'MONDO': 'MONDO_0015691',
#   'ORDO': 'ORDO_168956',
#   'EFO': '',
#   'DO': 'DO_999',
#   'MESH': 'MESH_D017681',
#   'UMLS': 'UMLS_C1540912'},
#  {'disease_name': 'prostate adenocarcinoma',
#   'therapeutic_areas': 'OTAR_0000017:reproductive system or breast disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C2919',
#   'OMIM': 'OMIM_176807',
#   'MONDO': 'MONDO_0005082',
#   'ORDO': '',
#   'EFO': 'EFO_0000673',
#   'DO': 'DO_2526',
#   'MESH': '',
#   'UMLS': 'UMLS_C0007112'},
#  {'disease_name': 'plexiform neurofibroma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0000618:nervous system disease',
#   'HPO': '',
#   'NCI': 'NCI_C3797',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_5151',
#   'MESH': 'MESH_D018318',
#   'UMLS': ''},
#  {'disease_name': 'Thymic Carcinoma',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, EFO_0001379:endocrine system disease, EFO_0000540:immune system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C7569',
#   'OMIM': '',
#   'MONDO': 'MONDO_0006451',
#   'ORDO': 'ORDO_99868',
#   'EFO': 'EFO_1000576',
#   'DO': 'DO_3284',
#   'MESH': '',
#   'UMLS': 'UMLS_C0205969'},
#  {'disease_name': 'sarcoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C9118',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005089',
#   'ORDO': '',
#   'EFO': 'EFO_0000691',
#   'DO': 'DO_1115',
#   'MESH': 'MESH_D012509',
#   'UMLS': 'UMLS_C1261473'},
#  {'disease_name': 'scleroderma',
#   'therapeutic_areas': 'EFO_0000540:immune system disease, OTAR_0000018:genetic, familial or congenital disease, MONDO_0024458:disorder of visual system, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': 'HPO_HP:0100324',
#   'NCI': 'NCI_C0011644',
#   'OMIM': '',
#   'MONDO': 'MONDO_0019340',
#   'ORDO': 'ORDO_801',
#   'EFO': '',
#   'DO': 'DO_419',
#   'MESH': 'MESH_D012594',
#   'UMLS': 'UMLS_C0011644'},
#  {'disease_name': 'primary myelofibrosis',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, MONDO_0045024:cancer or benign tumor, EFO_0000540:immune system disease, EFO_0005803:hematologic disease, OTAR_0000006:musculoskeletal or connective tissue disease',
#   'HPO': '',
#   'NCI': 'NCI_C2862',
#   'OMIM': 'OMIM_254450',
#   'MONDO': 'MONDO_0009692',
#   'ORDO': 'ORDO_824',
#   'EFO': 'EFO_0002430',
#   'DO': 'DO_4971',
#   'MESH': 'MESH_D055728',
#   'UMLS': 'UMLS_C2355576'},
#  {'disease_name': 'colorectal adenocarcinoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0010282:gastrointestinal disease',
#   'HPO': '',
#   'NCI': 'NCI_C5105',
#   'OMIM': 'OMIM_114500',
#   'MONDO': 'MONDO_0005008',
#   'ORDO': '',
#   'EFO': 'EFO_0000365',
#   'DO': 'DO_0050861',
#   'MESH': '',
#   'UMLS': 'UMLS_C1319315'},
#  {'disease_name': 'acute myeloid leukemia',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0000540:immune system disease, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C3171',
#   'OMIM': 'OMIM_601626',
#   'MONDO': 'MONDO_0018874',
#   'ORDO': 'ORDO_519',
#   'EFO': 'EFO_0000222',
#   'DO': 'DO_9119',
#   'MESH': 'MESH_D015470',
#   'UMLS': 'UMLS_C0023467'},
#  {'disease_name': 'acute lung injury',
#   'therapeutic_areas': 'OTAR_0000009:injury, poisoning or other complication, OTAR_0000010:respiratory or thoracic disease',
#   'HPO': '',
#   'NCI': 'NCI_C155766',
#   'OMIM': '',
#   'MONDO': 'MONDO_0015796',
#   'ORDO': 'ORDO_178320',
#   'EFO': '',
#   'DO': '',
#   'MESH': 'MESH_D055371',
#   'UMLS': ''},
#  {'disease_name': 'synovial sarcoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0012570',
#   'NCI': 'NCI_C3400',
#   'OMIM': 'OMIM_300813',
#   'MONDO': 'MONDO_0010434',
#   'ORDO': 'ORDO_3273',
#   'EFO': 'EFO_0001376',
#   'DO': 'DO_5485',
#   'MESH': 'MESH_D013584',
#   'UMLS': 'UMLS_C0039101'},
#  {'disease_name': 'seasonal allergic rhinitis',
#   'therapeutic_areas': 'OTAR_0000010:respiratory or thoracic disease, EFO_0000540:immune system disease',
#   'HPO': '',
#   'NCI': 'NCI_C92188',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005324',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': 'MESH_D006255',
#   'UMLS': 'UMLS_C0018621'},
#  {'disease_name': 'T-lymphoblastic lymphoma',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor, OTAR_0000018:genetic, familial or congenital disease',
#   'HPO': '',
#   'NCI': 'NCI_C6919',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': '',
#   'UMLS': 'UMLS_C1292758'},
#  {'disease_name': 'neoplasm',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0002664',
#   'NCI': 'NCI_C3262',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005070',
#   'ORDO': '',
#   'EFO': 'EFO_0000616',
#   'DO': 'DO_14566',
#   'MESH': 'MESH_D009369',
#   'UMLS': 'UMLS_C0027651'},
#  {'disease_name': 'chronic myeloproliferative disorder',
#   'therapeutic_areas': 'OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0005803:hematologic disease, EFO_0000540:immune system disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C103126',
#   'OMIM': 'OMIM_131440',
#   'MONDO': 'MONDO_0020076',
#   'ORDO': 'ORDO_98274',
#   'EFO': '',
#   'DO': 'DO_2226',
#   'MESH': '',
#   'UMLS': 'UMLS_C1292778'},
#  {'disease_name': 'chronic graft versus host disease',
#   'therapeutic_areas': 'OTAR_0000009:injury, poisoning or other complication, EFO_0000540:immune system disease',
#   'HPO': '',
#   'NCI': 'NCI_C4981',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': 'ORDO_99921',
#   'EFO': '',
#   'DO': '',
#   'MESH': '',
#   'UMLS': 'UMLS_C0867389'},
#  {'disease_name': 'leukemia',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0001909',
#   'NCI': 'NCI_C3161',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005059',
#   'ORDO': '',
#   'EFO': 'EFO_0000565',
#   'DO': 'DO_1240',
#   'MESH': 'MESH_D007938',
#   'UMLS': 'UMLS_C0023418'},
#  {'disease_name': 'non-Hodgkins lymphoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C3211',
#   'OMIM': '',
#   'MONDO': 'MONDO_0018908',
#   'ORDO': 'ORDO_547',
#   'EFO': 'EFO_0005952',
#   'DO': 'DO_0060060',
#   'MESH': 'MESH_D008228',
#   'UMLS': 'UMLS_C0024305'},
#  {'disease_name': 'Spinal cord injury',
#   'therapeutic_areas': 'EFO_0000618:nervous system disease, OTAR_0000009:injury, poisoning or other complication',
#   'HPO': '',
#   'NCI': '',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': '',
#   'MESH': 'MESH_D013119',
#   'UMLS': ''},
#  {'disease_name': 'lymphoid leukemia',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0005803:hematologic disease',
#   'HPO': 'HPO_HP:0005526',
#   'NCI': 'NCI_C7539',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005402',
#   'ORDO': '',
#   'EFO': 'EFO_0004289',
#   'DO': 'DO_10747',
#   'MESH': 'MESH_D007945',
#   'UMLS': 'UMLS_C0023448'},
#  {'disease_name': 'acute lymphoblastic leukemia',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0006721',
#   'NCI': 'NCI_C3167',
#   'OMIM': '',
#   'MONDO': 'MONDO_0004967',
#   'ORDO': 'ORDO_513',
#   'EFO': 'EFO_0000220',
#   'DO': 'DO_1037',
#   'MESH': '',
#   'UMLS': 'UMLS_C0023449'},
#  {'disease_name': 'clear cell renal carcinoma',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, EFO_0009690:urinary system disease',
#   'HPO': '',
#   'NCI': 'NCI_C4033',
#   'OMIM': 'OMIM_144700',
#   'MONDO': 'MONDO_0005005',
#   'ORDO': 'ORDO_319276',
#   'EFO': 'EFO_0000349',
#   'DO': 'DO_4467',
#   'MESH': '',
#   'UMLS': 'UMLS_C0279702'},
#  {'disease_name': 'lymphoblastic lymphoma',
#   'therapeutic_areas': 'OTAR_0000018:genetic, familial or congenital disease, MONDO_0045024:cancer or benign tumor, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C9360',
#   'OMIM': '',
#   'MONDO': '',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_0080147',
#   'MESH': '',
#   'UMLS': 'UMLS_C0079748'},
#  {'disease_name': 'leukemia',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': 'HPO_HP:0001909',
#   'NCI': 'NCI_C3161',
#   'OMIM': '',
#   'MONDO': 'MONDO_0005059',
#   'ORDO': '',
#   'EFO': 'EFO_0000565',
#   'DO': 'DO_1240',
#   'MESH': 'MESH_D007938',
#   'UMLS': 'UMLS_C0023418'},
#  {'disease_name': 'lymphoma',
#   'therapeutic_areas': 'EFO_0005803:hematologic disease, OTAR_0000018:genetic, familial or congenital disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3208',
#   'OMIM': 'OMIM_605027',
#   'MONDO': 'MONDO_0005062',
#   'ORDO': 'ORDO_223735',
#   'EFO': 'EFO_0000574',
#   'DO': 'DO_0060058',
#   'MESH': 'MESH_D008223',
#   'UMLS': 'UMLS_C0024299'},
#  {'disease_name': 'stomach neoplasm',
#   'therapeutic_areas': 'EFO_0010282:gastrointestinal disease, MONDO_0045024:cancer or benign tumor',
#   'HPO': '',
#   'NCI': 'NCI_C3387',
#   'OMIM': '',
#   'MONDO': 'MONDO_0021085',
#   'ORDO': '',
#   'EFO': '',
#   'DO': 'DO_10534',
#   'MESH': 'MESH_D013274',
#   'UMLS': 'UMLS_C0038356'},
#  {'disease_name': 'acute myeloid leukemia',
#   'therapeutic_areas': 'MONDO_0045024:cancer or benign tumor, OTAR_0000006:musculoskeletal or connective tissue disease, EFO_0000540:immune system disease, EFO_0005803:hematologic disease',
#   'HPO': '',
#   'NCI': 'NCI_C3171',
#   'OMIM': 'OMIM_601626',
#   'MONDO': 'MONDO_0018874',
#   'ORDO': 'ORDO_519',
#   'EFO': 'EFO_0000222',
#   'DO': 'DO_9119',
#   'MESH': 'MESH_D015470',
#   'UMLS': 'UMLS_C0023467'}]

# %% [markdown]
# # Combine data sources

# %%
combined_df = combine_sources(
    bridgdb_df, df_list=[opentargets_df, molmedb_transporter_inhibited_df]
)
combined_df.head()
# Out:
#   identifier identifier.source    target     target.source  \
# 0     100208  PubChem-compound    100208  PubChem Compound
# 1   10040286  PubChem-compound  10040286  PubChem Compound
# 2   10041551  PubChem-compound  10041551  PubChem Compound
# 3   10025195  PubChem-compound  10025195  PubChem Compound
# 4       5291  PubChem-compound      5291  PubChem Compound
#
#                                 OpenTargets_diseases  \
# 0  [{'disease_name': nan, 'therapeutic_areas': na...
# 1  [{'disease_name': nan, 'therapeutic_areas': na...
# 2  [{'disease_name': nan, 'therapeutic_areas': na...
# 3  [{'disease_name': nan, 'therapeutic_areas': na...
# 4  [{'disease_name': 'colonic neoplasm', 'therape...
#
#                        MolMeDB_transporter_inhibited
# 0  [{'uniprot_trembl_id': 'P08183', 'hgnc_symbol'...
# 1  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 2  [{'uniprot_trembl_id': 'P23975', 'hgnc_symbol'...
# 3  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 4  [{'uniprot_trembl_id': 'O15244', 'hgnc_symbol'...

# %%
combined_metadata = create_or_append_to_metadata(
    bridgdb_metadata, [opentargets_metadata, molmedb_transporter_inhibited_metadata]
)

# %% [markdown]
# # Saving the graph

# %%
import os

DATA_DIR = "./data/metabolite_workflow"
os.makedirs(DATA_DIR, exist_ok=True)

# %%
# pygraph = saver.save_graph(
#     combined_df=combined_df,
#     combined_metadata=combined_metadata,
#     graph_name="metabolite_workflow",
#     graph_dir=DATA_DIR,
# )

# %% [markdown]
# # Generate graph

# %%
pygraph = generator.build_networkx_graph(combined_df)
# Out:
# Building graph: 100%|██████████| 5/5 [00:00<00:00, 502.85it/s]

# %%
print(pygraph)
# Out:
# MultiDiGraph with 109 nodes and 104 edges

# %%
cytoscape.load_graph(pygraph, network_name="Test network")
# Out:
# Applying default style...
# Applying preferred layout

# %%
graph_obj.count_edge_by_data_source(plot=True)
