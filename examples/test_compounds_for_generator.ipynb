# %% [markdown]
# # Example: Compounds for Generator

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")

if src_path not in sys.path:
    sys.path.insert(0, src_path)

print("PYTHONPATH:", sys.path[0])
# Out:
# PYTHONPATH: c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src

# %%
# Import modules
import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import intact, kegg, molmedb, aopwiki
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# # Load list of metabolites/chemicals/compounds

# %%
metabolites_of_interest = """100208
10040286
10041551
10025195
5291
6030
1172
1060
8571
697993
21831736
159603
445643
16865
"""

metabolite_list = metabolites_of_interest.split("\n")
len(metabolite_list)
# Out:
# 15

# %%
data_input = pd.DataFrame(metabolite_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0     100208
# 1   10040286
# 2   10041551
# 3   10025195
# 4       5291

# %% [markdown]
# ### Entity resolution using BridgeDB

# %%
bridgedb_compound_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species="Human",
    input_datasource="ChEBI",
    output_datasource="All",
)
bridgedb_compound_df.head(10)
# Out:
#   identifier identifier.source                       target     target.source
# 0     100208             ChEBI                       100208             ChEBI
# 1     100208             ChEBI                 CHEBI:100208             ChEBI
# 2     100208             ChEBI                    Q27176235          Wikidata
# 3     100208             ChEBI                     54631547  PubChem Compound
# 4     100208             ChEBI  OOHQDHOXZWVAAU-SEPYTNNBSA-N          InChIKey
# 5       5291             ChEBI                       C01498     KEGG Compound
# 6       5291             ChEBI                   CHEBI:5291             ChEBI
# 7       5291             ChEBI                      DB11242          DrugBank
# 8       5291             ChEBI                         5291             ChEBI
# 9       5291             ChEBI                    9000-70-8               CAS

# %% [markdown]
# ### Compound Interactions from IntAct

# %%
intact_compound_df, intact_compound_metadata = intact.get_compound_interactions(
    bridgedb_compound_df, interaction_type="both"
)
intact_compound_df.head(10)
# Out:
# Querying IntAct for compounds: 100%|██████████| 1/1 [00:08<00:00,  8.62s/it]
#   identifier identifier.source        target target.source  \
# 0     100208             ChEBI  CHEBI:100208         ChEBI
# 1       5291             ChEBI    CHEBI:5291         ChEBI
# 2       6030             ChEBI    CHEBI:6030         ChEBI
# 3       1060             ChEBI    CHEBI:1060         ChEBI
# 4     159603             ChEBI  CHEBI:159603         ChEBI
# 5      16865             ChEBI   CHEBI:16865         ChEBI
#
#                         IntAct_compound_interactions
# 0  [{'interaction_id': nan, 'interactor_id_A': na...
# 1  [{'interaction_id': nan, 'interactor_id_A': na...
# 2  [{'interaction_id': nan, 'interactor_id_A': na...
# 3  [{'interaction_id': nan, 'interactor_id_A': na...
# 4  [{'interaction_id': nan, 'interactor_id_A': na...
# 5  [{'interaction_id': nan, 'interactor_id_A': na...

# %% [markdown]
# ## MolMeDB

# %%
molmedb_df, molmedb_metadata = molmedb.get_compound_gene_inhibitor(bridgedb_compound_df)
molmedb_df.head()
# Out:
#   identifier identifier.source                       target target.source  \
# 0     100208             ChEBI  OOHQDHOXZWVAAU-SEPYTNNBSA-N      InChIKey
# 1       1060             ChEBI  UQIGQRSJIKIPKZ-VKHMYHEASA-N      InChIKey
# 2     159603             ChEBI  VJGQRELPQWNURN-JYJNAYRXSA-N      InChIKey
# 3      16865             ChEBI  BTCSSZJGUNDROE-UHFFFAOYSA-N      InChIKey
# 4       6030             ChEBI  QRXWMOHMRWLFEY-UHFFFAOYSA-N      InChIKey
#
#                        MolMeDB_transporter_inhibited
# 0  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...
# 1  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...
# 2  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...
# 3  [{'MolMeDB_uniprot_trembl_id': 'Uniprot-TrEMBL...
# 4  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...

# %% [markdown]
# ## KEGG

# %%
kegg_df, kegg_metadata = kegg.get_pathways(bridgedb_compound_df)
kegg_df.head()
# Out:
#   identifier identifier.source  target  target.source  \
# 0       5291             ChEBI  C01498  KEGG Compound
# 1       6030             ChEBI  C07054  KEGG Compound
# 2       1060             ChEBI  C03826  KEGG Compound
# 3      16865             ChEBI  C00334  KEGG Compound
#
#                                        KEGG_pathways
# 0  [{'pathway_id': 'path:hsa05146', 'pathway_labe...
# 1  [{'pathway_id': 'path:hsa00983', 'pathway_labe...
# 2  [{'pathway_id': 'path:hsa00040', 'pathway_labe...
# 3  [{'pathway_id': 'path:hsa00250', 'pathway_labe...

# %%
aop_df, aop_metadata = aopwiki.get_aops_compound(bridgedb_compound_df)
aop_df.head()
# Out:
# Querying AOP_Wiki_RDF for compounds: 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
# c:\Users\are10\Documents\BAFSTU\code\GitHub\pyBiodatafuse\src\pyBiodatafuse\annotators\aopwiki.py:344: UserWarning: The intermediate_df in AOP_Wiki_RDF_compounds annotator should be checked, please create an issue on https://github.com/BioDataFuse/pyBiodatafuse/issues/.
#   give_annotator_warning(Cons.AOPWIKI_COMPOUND_COL)
#   identifier identifier.source     target     target.source  \
# 0     100208             ChEBI   54631547  PubChem Compound
# 1       1060             ChEBI    5280626  PubChem Compound
# 2     159603             ChEBI  145456550  PubChem Compound
# 3      16865             ChEBI        119  PubChem Compound
# 4       6030             ChEBI       3767  PubChem Compound
#
#                               AOP_Wiki_RDF_compounds
# 0  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 1  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 2  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 3  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 4  [{'aop': '260', 'aop_title': 'CYP2E1 activatio...

# %%
aop_df["AOP_Wiki_RDF_compounds"][1]
# Out:
# [{'aop': nan,
#   'aop_title': nan,
#   'MIE_title': nan,
#   'MIE': nan,
#   'KE_downstream': nan,
#   'KE_downstream_title': nan,
#   'KER': nan,
#   'ao': nan,
#   'ao_title': nan,
#   'KE_upstream': nan,
#   'KE_upstream_title': nan,
#   'KE_upstream_organ': nan,
#   'KE_downstream_organ': nan}]

# %%
combined_df = combine_sources(
    bridgedb_compound_df,
    [
        intact_compound_df, 
        molmedb_df,
        aop_df,
        kegg_df
    ],
)

# %%
combined_df.head(25)
# Out:
#   identifier identifier.source     target     target.source  \
# 0     100208             ChEBI   54631547  PubChem Compound
# 1       6030             ChEBI       3767  PubChem Compound
# 2       1060             ChEBI    5280626  PubChem Compound
# 3     159603             ChEBI  145456550  PubChem Compound
# 4      16865             ChEBI        119  PubChem Compound
# 5       5291               NaN        NaN               NaN
#
#                         IntAct_compound_interactions  \
# 0  [{'interaction_id': nan, 'interactor_id_A': na...
# 1  [{'interaction_id': nan, 'interactor_id_A': na...
# 2  [{'interaction_id': nan, 'interactor_id_A': na...
# 3  [{'interaction_id': nan, 'interactor_id_A': na...
# 4  [{'interaction_id': nan, 'interactor_id_A': na...
# 5  [{'interaction_id': nan, 'interactor_id_A': na...
#
#                        MolMeDB_transporter_inhibited  \
# 0  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...
# 1  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...
# 2  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...
# 3  [{'MolMeDB_uniprot_trembl_id': nan, 'MolMeDB_h...
# 4  [{'MolMeDB_uniprot_trembl_id': 'Uniprot-TrEMBL...
# 5                                                NaN
#
#                               AOP_Wiki_RDF_compounds  \
# 0  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 1  [{'aop': '260', 'aop_title': 'CYP2E1 activatio...
# 2  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 3  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 4  [{'aop': nan, 'aop_title': nan, 'MIE_title': n...
# 5                                                NaN
#
#                                        KEGG_pathways
# 0                                                NaN
# 1  [{'pathway_id': 'path:hsa00983', 'pathway_labe...
# 2  [{'pathway_id': 'path:hsa00040', 'pathway_labe...
# 3                                                NaN
# 4  [{'pathway_id': 'path:hsa00250', 'pathway_labe...
# 5  [{'pathway_id': 'path:hsa05146', 'pathway_labe...

# %%
pygraph = generator.build_networkx_graph(combined_df)
# Out:
# Building graph: 100%|██████████| 5/5 [00:00<00:00, 908.72it/s]

# %%
combined_df.shape
# Out:
# (2, 5)

# %%
from pyBiodatafuse.graph import cytoscape

cytoscape.load_graph(pygraph, network_name="Test network")
# Out:
# Applying default style...
# Applying preferred layout
