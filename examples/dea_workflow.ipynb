# %% [markdown]
# # Example: Differentially Expressed Gene Analysis Workflow
#
# This notebook provides insights on how to use the tool if you have DEG file.
# Our current data sources include:
# * DisGeNet
# * MolMeDB
# * OpenTargets
# * WikiPathways
# * WikiData
# * STRING
# * Bgee

# %%
# Import modules
from pyBiodatafuse import data_loader, id_mapper
from pyBiodatafuse.annotators import disgenet, molmedb  # Example with just two resource
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# ## Load the DEA results

# %%
data_input = data_loader.create_df_from_dea("dea_example.xls")
data_input.head()
# Out:
#         identifier      F value   Pr(>F)  FDR(>F)   Log2FC       t.ratio  \
# 0  ENSG00000000003  198663.0000  0.07389  0.11995  0.21672  267662.00000
# 1  ENSG00000000005  532116.0000  0.00008  0.00041 -0.34276 -158217.00000
# 2  ENSG00000000419  123704.0000  0.29357  0.36707 -0.03554      -0.68119
# 3  ENSG00000000457  122821.0000  0.29781  0.37146 -0.10078 -168058.00000
# 4  ENSG00000000460       0.7331  0.62400  0.67303  0.25185  134237.00000
#
#    p.value
# 0  0.10432
# 1  0.69388
# 2  0.99364
# 3  0.62915
# 4  0.83158

# %% [markdown]
# ### Filtering the DEA table

# %%
data_filtered = data_loader.filter_dea(data_input, column_name="FDR(>F)", min_value=0.05)
data_filtered = data_loader.filter_dea(data_filtered, column_name="Log2FC", abs_value=0.5)
data_filtered.head()
# Out:
#           identifier   F value   Pr(>F)  FDR(>F)   Log2FC   t.ratio  p.value
# 70   ENSG00000005108  169738.0  0.12886  0.18847  0.59097  239599.0  0.20273
# 73   ENSG00000005189  250342.0  0.02632  0.05167  0.70124  335289.0  0.01499
# 168  ENSG00000008226    1751.0  0.11493  0.17170  0.96160  254376.0  0.14795
# 181  ENSG00000008517  240722.0  0.03233  0.06086 -0.77406 -308262.0  0.03358
# 337  ENSG00000021826  189207.0  0.08899  0.13960  0.50922  304276.0  0.04013

# %% [markdown]
# ## Entity resolution using BridgeDB

# %%
bridgdb_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_filtered,
    input_species="Human",
    input_datasource="Ensembl",
    output_datasource="All",
)
bridgdb_df.head()
# Out:
#         identifier identifier.source               target  \
# 0  ENSG00000005108           Ensembl         214920_PM_at
# 1  ENSG00000005108           Ensembl  Hs.29900.0.S1_3p_at
# 2  ENSG00000005108           Ensembl               221981
# 3  ENSG00000005108           Ensembl           GO:0016021
# 4  ENSG00000005108           Ensembl           uc064bom.1
#
#          target.source  F value_dea  Pr(>F)_dea  FDR(>F)_dea  Log2FC_dea  \
# 0                 Affy     169738.0     0.12886      0.18847     0.59097
# 1                 Affy     169738.0     0.12886      0.18847     0.59097
# 2            WikiGenes     169738.0     0.12886      0.18847     0.59097
# 3        Gene Ontology     169738.0     0.12886      0.18847     0.59097
# 4  UCSC Genome Browser     169738.0     0.12886      0.18847     0.59097
#
#    t.ratio_dea  p.value_dea
# 0     239599.0      0.20273
# 1     239599.0      0.20273
# 2     239599.0      0.20273
# 3     239599.0      0.20273
# 4     239599.0      0.20273

# %% [markdown]
# ## Disease annotating using DisGeNet

# %%
api_key = "0209751bfa7b6a981a8f5fb5f062313067ecd36c"  # TODO: add your key
params = {"source": "CURATED", "format": "json"}  # only curated data
disgenet_result, disgenet_metadata = disgenet.get_gene_disease(
    bridgedb_df=bridgdb_df, api_key=api_key, params=params
)
disgenet_result.head()
# Out:
#         identifier identifier.source  target target.source  F value_dea  \
# 0  ENSG00000005108           Ensembl  221981     NCBI Gene     169738.0
# 1  ENSG00000005189           Ensembl   81691     NCBI Gene     250342.0
# 2  ENSG00000008226           Ensembl    9940     NCBI Gene       1751.0
# 3  ENSG00000008517           Ensembl    9235     NCBI Gene     240722.0
# 4  ENSG00000021826           Ensembl    1373     NCBI Gene     189207.0
#
#    Pr(>F)_dea  FDR(>F)_dea  Log2FC_dea  t.ratio_dea  p.value_dea  \
# 0     0.12886      0.18847     0.59097     239599.0      0.20273
# 1     0.02632      0.05167     0.70124     335289.0      0.01499
# 2     0.11493      0.17170     0.96160     254376.0      0.14795
# 3     0.03233      0.06086    -0.77406    -308262.0      0.03358
# 4     0.08899      0.13960     0.50922     304276.0      0.04013
#
#                                             DisGeNET
# 0  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
# 1  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
# 2  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
# 3  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
# 4  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...

# %%
disgenet_result["DisGeNET"][0]
# Out:
# [{'gene_dsi': nan,
#   'gene_dpi': nan,
#   'gene_pli': nan,
#   'protein_class': nan,
#   'protein_class_name': nan,
#   'diseaseid': nan,
#   'disease_name': nan,
#   'disease_class': nan,
#   'disease_class_name': nan,
#   'disease_type': nan,
#   'disease_semantic_type': nan,
#   'score': nan,
#   'ei': nan,
#   'el': nan,
#   'year_initial': nan,
#   'year_final': nan,
#   'source': nan}]

# %% [markdown]
# ## Inhibitors of trasporters encoded by genes annotation by MolMeDB

# %%
inhibitor_df, inhibitor_metadata = molmedb.get_gene_mol_inhibitor(bridgedb_df=bridgdb_df)
inhibitor_df.head()
# Out:
#         identifier identifier.source      target   target.source  F value_dea  \
# 0  ENSG00000005108           Ensembl      Q9UPZ6  Uniprot-TrEMBL     169738.0
# 1  ENSG00000005189           Ensembl  A0A024R390  Uniprot-TrEMBL     250342.0
# 2  ENSG00000005189           Ensembl      H3BM72  Uniprot-TrEMBL     250342.0
# 3  ENSG00000005189           Ensembl      H3BPB2  Uniprot-TrEMBL     250342.0
# 4  ENSG00000005189           Ensembl      H3BQ98  Uniprot-TrEMBL     250342.0
#
#    Pr(>F)_dea  FDR(>F)_dea  Log2FC_dea  t.ratio_dea  p.value_dea  \
# 0     0.12886      0.18847     0.59097     239599.0      0.20273
# 1     0.02632      0.05167     0.70124     335289.0      0.01499
# 2     0.02632      0.05167     0.70124     335289.0      0.01499
# 3     0.02632      0.05167     0.70124     335289.0      0.01499
# 4     0.02632      0.05167     0.70124     335289.0      0.01499
#
#                                transporter_inhibitor
# 0  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 1  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 2  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 3  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 4  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...

# %%
inhibitor_df["transporter_inhibitor"][72]
# Out:
# [{'label': nan,
#   'InChIKey': nan,
#   'SMILES': nan,
#   'pubchem_compound_id': nan,
#   'molmedb_id': nan,
#   'source_doi': nan,
#   'source_pmid': nan,
#   'chebi_id': nan,
#   'drugbank_id': nan,
#   'pdb_ligand_id': nan}]

# %% [markdown]
# ## Combing all the results into single dataframe

# %%
combined_df = combine_sources([disgenet_result, inhibitor_df])

# %%
combined_df.head(4)
# Out:
#         identifier identifier.source  target target.source  F value_dea  \
# 0  ENSG00000005108           Ensembl  221981     NCBI Gene     169738.0
# 1  ENSG00000005189           Ensembl   81691     NCBI Gene     250342.0
# 2  ENSG00000008226           Ensembl    9940     NCBI Gene       1751.0
# 3  ENSG00000008517           Ensembl    9235     NCBI Gene     240722.0
#
#    Pr(>F)_dea  FDR(>F)_dea  Log2FC_dea  t.ratio_dea  p.value_dea  \
# 0     0.12886      0.18847     0.59097     239599.0      0.20273
# 1     0.02632      0.05167     0.70124     335289.0      0.01499
# 2     0.11493      0.17170     0.96160     254376.0      0.14795
# 3     0.03233      0.06086    -0.77406    -308262.0      0.03358
#
#                                             DisGeNET  \
# 0  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
# 1  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
# 2  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
# 3  [{'gene_dsi': nan, 'gene_dpi': nan, 'gene_pli'...
#
#                                transporter_inhibitor
# 0  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 1  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 2  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 3  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
