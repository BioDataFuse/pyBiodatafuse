# %% [markdown]
# # Example: Gene

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")

if src_path not in sys.path:
    sys.path.insert(0, src_path)

print("PYTHONPATH:", sys.path[0])
# Out:
# PYTHONPATH: c:\Users\are10\Documents\BAFSTU\code\pyBioDatafusemain\pyBiodatafuse\src

# %%
# Import modules
import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import intact
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# # Load list of genes

# %%
genes_of_interest = """CHRNG
CHRND
DMD
DAG1
AHR
ARNT
SCN4A
SCN2B
LC25A1
HTR3A
HTR3B
HTR3E
TP53
MDM2"""

gene_list = genes_of_interest.split("\n")
len(gene_list)
# Out:
# 14

# %%
data_input = pd.DataFrame(gene_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0      CHRNG
# 1      CHRND
# 2        DMD
# 3       DAG1
# 4        AHR

# %% [markdown]
# ### Entity resolution using BridgeDB

# %%
input_species = "Human"

bridgedb_df, bridgedb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input,
    input_species=input_species,
    input_datasource="HGNC",
    output_datasource="All",
)

bridgedb_df.head(25)
# Out:
#    identifier identifier.source            target   target.source
# 0       CHRNG              HGNC        GO:0042391   Gene Ontology
# 1       CHRNG              HGNC        A_23_P5718         Agilent
# 2       CHRNG              HGNC        GO:0016021   Gene Ontology
# 3       CHRNG              HGNC        GO:0016020   Gene Ontology
# 4       CHRNG              HGNC        GO:0006936   Gene Ontology
# 5       CHRNG              HGNC            P07510  Uniprot-TrEMBL
# 6       CHRNG              HGNC        GO:0005886   Gene Ontology
# 7       CHRNG              HGNC        GO:0043005   Gene Ontology
# 8       CHRNG              HGNC        GO:0110165   Gene Ontology
# 9       CHRNG              HGNC        GO:0005887   Gene Ontology
# 10      CHRNG              HGNC        GO:0006811   Gene Ontology
# 11      CHRNG              HGNC        GO:0007268   Gene Ontology
# 12      CHRNG              HGNC        0004610592        Illumina
# 13      CHRNG              HGNC        GO:1904315   Gene Ontology
# 14      CHRNG              HGNC        GO:0007271   Gene Ontology
# 15      CHRNG              HGNC     11752947_a_at            Affy
# 16      CHRNG              HGNC  g7382453_3p_x_at            Affy
# 17      CHRNG              HGNC           2532408            Affy
# 18      CHRNG              HGNC           2532409            Affy
# 19      CHRNG              HGNC        GO:0045211   Gene Ontology
# 20      CHRNG              HGNC       11742077_at            Affy
# 21      CHRNG              HGNC        GO:0005515   Gene Ontology
# 22      CHRNG              HGNC   ENSG00000196811         Ensembl
# 23      CHRNG              HGNC           2532400            Affy
# 24      CHRNG              HGNC           2532401            Affy

# %% [markdown]
# ### Gene Interactions from IntAct

# %%
intact_df, intact_metadata = intact.get_gene_interactions(bridgedb_df, interaction_type="both")
intact_df.head(10)
# Out:
#   identifier identifier.source           target target.source  \
# 0      CHRNG              HGNC  ENSG00000196811       Ensembl
# 1      CHRND              HGNC  ENSG00000135902       Ensembl
# 2        DMD              HGNC  ENSG00000198947       Ensembl
# 3       DAG1              HGNC  ENSG00000173402       Ensembl
# 4        AHR              HGNC  ENSG00000106546       Ensembl
# 5       ARNT              HGNC  ENSG00000143437       Ensembl
# 6      SCN4A              HGNC  ENSG00000007314       Ensembl
# 7      SCN2B              HGNC  ENSG00000149575       Ensembl
# 8      HTR3A              HGNC  ENSG00000166736       Ensembl
# 9      HTR3B              HGNC  ENSG00000149305       Ensembl
#
#                             IntAct_gene_interactions
# 0  [{'interaction_id': nan, 'interactor_id_A': na...
# 1  [{'interaction_id': nan, 'interactor_id_A': na...
# 2  [{'interaction_id': nan, 'interactor_id_A': na...
# 3  [{'interaction_id': 'EBI-7882257', 'interactor...
# 4  [{'interaction_id': nan, 'interactor_id_A': na...
# 5  [{'interaction_id': 'EBI-2291729', 'interactor...
# 6  [{'interaction_id': nan, 'interactor_id_A': na...
# 7  [{'interaction_id': nan, 'interactor_id_A': na...
# 8  [{'interaction_id': 'EBI-11163778', 'interacto...
# 9  [{'interaction_id': 'EBI-11163796', 'interacto...

# %%
intact_df["IntAct_gene_interactions"][3]
# Out:
# [{'interaction_id': 'EBI-7882257',
#   'interactor_id_A': 'EBI-1755945',
#   'interactor_id_B': 'EBI-1755945',
#   'binary_interaction_id': 13027532,
#   'confidence_values': ['intact-miscore:0.56'],
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'stoichiometry_A': '1-1',
#   'stoichiometry_B': '1-1',
#   'detection_method': 'x-ray diffraction',
#   'detection_method_id': 'MI:0114',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'dag1_human',
#   'interactor_B_name': 'dag1_human',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'DAG1',
#   'molecule_B': 'DAG1',
#   'id_A': 'Q14118',
#   'id_B': 'Q14118',
#   'pubmed_publication_id': '11423118',
#   'altIdsA': ['Q969J9 (uniprotkb)',
#    'ENSP00000412067.2 (ensembl)',
#    'A8K6M7 (uniprotkb)',
#    'ENSP00000387859.2 (ensembl)',
#    'ENSP00000501140.1 (ensembl)',
#    'Q14118 (uniprotkb)',
#    'ENSP00000513218.1 (ensembl)',
#    'EBI-1755945 (intact)',
#    'ENSP00000405859.2 (ensembl)',
#    'ENSP00000401805.2 (ensembl)',
#    'ENSP00000501165.2 (ensembl)',
#    'ENSP00000401382.3 (ensembl)',
#    'ENSP00000415321.4 (ensembl)',
#    'ENSP00000388833.2 (ensembl)',
#    'ENSP00000410145.3 (ensembl)',
#    'ENSP00000513217.1 (ensembl)',
#    'ENSP00000513216.1 (ensembl)',
#    'ENSP00000312435.2 (ensembl)'],
#   'altIdsB': ['Q969J9 (uniprotkb)',
#    'ENSP00000412067.2 (ensembl)',
#    'A8K6M7 (uniprotkb)',
#    'ENSP00000387859.2 (ensembl)',
#    'ENSP00000501140.1 (ensembl)',
#    'Q14118 (uniprotkb)',
#    'ENSP00000513218.1 (ensembl)',
#    'EBI-1755945 (intact)',
#    'ENSP00000405859.2 (ensembl)',
#    'ENSP00000401805.2 (ensembl)',
#    'ENSP00000501165.2 (ensembl)',
#    'ENSP00000401382.3 (ensembl)',
#    'ENSP00000415321.4 (ensembl)',
#    'ENSP00000388833.2 (ensembl)',
#    'ENSP00000410145.3 (ensembl)',
#    'ENSP00000513217.1 (ensembl)',
#    'ENSP00000513216.1 (ensembl)',
#    'ENSP00000312435.2 (ensembl)'],
#   'intact_link_to': 'DAG1'},
#  {'interaction_id': 'EBI-7882311',
#   'interactor_id_A': 'EBI-1755945',
#   'interactor_id_B': 'EBI-1755945',
#   'binary_interaction_id': 13027607,
#   'confidence_values': ['intact-miscore:0.56'],
#   'score': 0.56,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'direct interaction',
#   'stoichiometry_A': '0-0',
#   'stoichiometry_B': '0-0',
#   'detection_method': 'elisa',
#   'detection_method_id': 'MI:0411',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'dag1_human',
#   'interactor_B_name': 'dag1_human',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'DAG1',
#   'molecule_B': 'DAG1',
#   'id_A': 'Q14118',
#   'id_B': 'Q14118',
#   'pubmed_publication_id': '11423118',
#   'altIdsA': ['Q969J9 (uniprotkb)',
#    'ENSP00000412067.2 (ensembl)',
#    'A8K6M7 (uniprotkb)',
#    'ENSP00000387859.2 (ensembl)',
#    'ENSP00000501140.1 (ensembl)',
#    'Q14118 (uniprotkb)',
#    'ENSP00000513218.1 (ensembl)',
#    'EBI-1755945 (intact)',
#    'ENSP00000405859.2 (ensembl)',
#    'ENSP00000401805.2 (ensembl)',
#    'ENSP00000501165.2 (ensembl)',
#    'ENSP00000401382.3 (ensembl)',
#    'ENSP00000415321.4 (ensembl)',
#    'ENSP00000388833.2 (ensembl)',
#    'ENSP00000410145.3 (ensembl)',
#    'ENSP00000513217.1 (ensembl)',
#    'ENSP00000513216.1 (ensembl)',
#    'ENSP00000312435.2 (ensembl)'],
#   'altIdsB': ['Q969J9 (uniprotkb)',
#    'ENSP00000412067.2 (ensembl)',
#    'A8K6M7 (uniprotkb)',
#    'ENSP00000387859.2 (ensembl)',
#    'ENSP00000501140.1 (ensembl)',
#    'Q14118 (uniprotkb)',
#    'ENSP00000513218.1 (ensembl)',
#    'EBI-1755945 (intact)',
#    'ENSP00000405859.2 (ensembl)',
#    'ENSP00000401805.2 (ensembl)',
#    'ENSP00000501165.2 (ensembl)',
#    'ENSP00000401382.3 (ensembl)',
#    'ENSP00000415321.4 (ensembl)',
#    'ENSP00000388833.2 (ensembl)',
#    'ENSP00000410145.3 (ensembl)',
#    'ENSP00000513217.1 (ensembl)',
#    'ENSP00000513216.1 (ensembl)',
#    'ENSP00000312435.2 (ensembl)'],
#   'intact_link_to': 'DAG1'},
#  {'interaction_id': 'EBI-2134070',
#   'interactor_id_A': 'EBI-1018651',
#   'interactor_id_B': 'EBI-1755945',
#   'binary_interaction_id': 4053983,
#   'confidence_values': ['intact-miscore:0.4'],
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'stoichiometry_A': '0-0',
#   'stoichiometry_B': '0-0',
#   'detection_method': 'pull down',
#   'detection_method_id': 'MI:0096',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'p11532-5',
#   'interactor_B_name': 'dag1_human',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'DMD',
#   'molecule_B': 'DAG1',
#   'id_A': 'P11532-5',
#   'id_B': 'Q14118',
#   'pubmed_publication_id': '19109891',
#   'altIdsA': ['ENSP00000354464.4 (ensembl)',
#    'P11532-5 (uniprotkb)',
#    'EBI-1018651 (intact)'],
#   'altIdsB': ['Q969J9 (uniprotkb)',
#    'ENSP00000412067.2 (ensembl)',
#    'A8K6M7 (uniprotkb)',
#    'ENSP00000387859.2 (ensembl)',
#    'ENSP00000501140.1 (ensembl)',
#    'Q14118 (uniprotkb)',
#    'ENSP00000513218.1 (ensembl)',
#    'EBI-1755945 (intact)',
#    'ENSP00000405859.2 (ensembl)',
#    'ENSP00000401805.2 (ensembl)',
#    'ENSP00000501165.2 (ensembl)',
#    'ENSP00000401382.3 (ensembl)',
#    'ENSP00000415321.4 (ensembl)',
#    'ENSP00000388833.2 (ensembl)',
#    'ENSP00000410145.3 (ensembl)',
#    'ENSP00000513217.1 (ensembl)',
#    'ENSP00000513216.1 (ensembl)',
#    'ENSP00000312435.2 (ensembl)'],
#   'intact_link_to': 'DMD'},
#  {'interaction_id': 'EBI-2134085',
#   'interactor_id_A': 'EBI-1018651',
#   'interactor_id_B': 'EBI-1755945',
#   'binary_interaction_id': 4054006,
#   'confidence_values': ['intact-miscore:0.4'],
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'stoichiometry_A': '0-0',
#   'stoichiometry_B': '0-0',
#   'detection_method': 'pull down',
#   'detection_method_id': 'MI:0096',
#   'host_organism': 'In vitro',
#   'interactor_A_name': 'p11532-5',
#   'interactor_B_name': 'dag1_human',
#   'interactor_A_species': 'Homo sapiens',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'DMD',
#   'molecule_B': 'DAG1',
#   'id_A': 'P11532-5',
#   'id_B': 'Q14118',
#   'pubmed_publication_id': '19109891',
#   'altIdsA': ['ENSP00000354464.4 (ensembl)',
#    'P11532-5 (uniprotkb)',
#    'EBI-1018651 (intact)'],
#   'altIdsB': ['Q969J9 (uniprotkb)',
#    'ENSP00000412067.2 (ensembl)',
#    'A8K6M7 (uniprotkb)',
#    'ENSP00000387859.2 (ensembl)',
#    'ENSP00000501140.1 (ensembl)',
#    'Q14118 (uniprotkb)',
#    'ENSP00000513218.1 (ensembl)',
#    'EBI-1755945 (intact)',
#    'ENSP00000405859.2 (ensembl)',
#    'ENSP00000401805.2 (ensembl)',
#    'ENSP00000501165.2 (ensembl)',
#    'ENSP00000401382.3 (ensembl)',
#    'ENSP00000415321.4 (ensembl)',
#    'ENSP00000388833.2 (ensembl)',
#    'ENSP00000410145.3 (ensembl)',
#    'ENSP00000513217.1 (ensembl)',
#    'ENSP00000513216.1 (ensembl)',
#    'ENSP00000312435.2 (ensembl)'],
#   'intact_link_to': 'DMD'},
#  {'interaction_id': 'EBI-5327885',
#   'interactor_id_A': 'EBI-5327879',
#   'interactor_id_B': 'EBI-1755945',
#   'binary_interaction_id': 10324525,
#   'confidence_values': ['intact-miscore:0.4'],
#   'score': 0.4,
#   'biological_role_A': 'unspecified role',
#   'biological_role_B': 'unspecified role',
#   'type': 'physical association',
#   'stoichiometry_A': '0-0',
#   'stoichiometry_B': '0-0',
#   'detection_method': 'biophysical',
#   'detection_method_id': 'MI:0013',
#   'host_organism': 'Homo sapiens HeLa S3 epitheloid cervical carcinoma cell',
#   'interactor_A_name': 'ganglioside_gm1',
#   'interactor_B_name': 'dag1_human',
#   'interactor_A_species': 'Chemical synthesis (Chemical synthesis)',
#   'interactor_B_species': 'Homo sapiens',
#   'molecule_A': 'ganglioside_gm1',
#   'molecule_B': 'DAG1',
#   'id_A': 'CHEBI:61048',
#   'id_B': 'Q14118',
#   'pubmed_publication_id': '22106087',
#   'altIdsA': ['EBI-5327879 (intact)', 'CHEBI:61048 (chebi)'],
#   'altIdsB': ['Q969J9 (uniprotkb)',
#    'ENSP00000412067.2 (ensembl)',
#    'A8K6M7 (uniprotkb)',
#    'ENSP00000387859.2 (ensembl)',
#    'ENSP00000501140.1 (ensembl)',
#    'Q14118 (uniprotkb)',
#    'ENSP00000513218.1 (ensembl)',
#    'EBI-1755945 (intact)',
#    'ENSP00000405859.2 (ensembl)',
#    'ENSP00000401805.2 (ensembl)',
#    'ENSP00000501165.2 (ensembl)',
#    'ENSP00000401382.3 (ensembl)',
#    'ENSP00000415321.4 (ensembl)',
#    'ENSP00000388833.2 (ensembl)',
#    'ENSP00000410145.3 (ensembl)',
#    'ENSP00000513217.1 (ensembl)',
#    'ENSP00000513216.1 (ensembl)',
#    'ENSP00000312435.2 (ensembl)'],
#   'intact_link_to': None}]

# %%
combined_df = combine_sources(
    bridgedb_df,
    [intact_df],
)

# %%
pygraph = generator.build_networkx_graph(combined_df)
# Out:
# Building graph: 100%|██████████| 13/13 [00:00<00:00, 228.20it/s]

# %%
combined_df.shape
# Out:
# (13, 5)

# %%
from pyBiodatafuse.graph import cytoscape

cytoscape.load_graph(pygraph, network_name="Test network")
# Out:
# Applying default style...
# Applying preferred layout
