# %% [markdown]
# # Usecase: Nomination of compound combinations from KG.
#
# This notebook demonstrates the capability of BioDataFuse to nominate compound combinations.

# %%
# Import modules
import pickle

import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import (
    disgenet,
    minerva,
    molmedb,
    opentargets,
    pubchem,
    stringdb,
    wikipathways,
)
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# ### List of compounds for building the network

# %%
data_input = pd.read_csv("compounds.tsv", sep="\t", dtype=str)
data_input.head()
# Out:
#         cid      chembl_id                                             smiles  \
# 0      1697   CHEMBL268868          O=C1NC(=O)c2cc(Nc3ccccc3)c(Nc3ccccc3)cc21
# 1  46943432  CHEMBL1232461  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
# 2  59620153  CHEMBL4303369          COc1ccc2[nH]c3c(-c4cccc5ccccc45)nccc3c2c1
# 3     57267     CHEMBL8946         CCc1cc(Cl)c(OC)c(C(=O)NC[C@@H]2CCCN2CC)c1O
# 4  15942827  CHEMBL3137322                O[C@H]([C@H](O)[C@@H]1CO1)[C@H]1CO1
#
#                      InChI Key
# 0  AAALVYBICLMAMA-UHFFFAOYSA-N
# 1  AAAQFGUYHFJNHI-SFHVURJKSA-N
# 2  AABFWJDLCCDJJN-UHFFFAOYSA-N
# 3  AADCDMQTJNYOSS-LBPRGKRZSA-N
# 4  AAFJXZWCNVJTMK-GUCUJZIJSA-N

# %%
f"Number of Compounds: {len(data_input)}"
# Out:
# 'Number of Compounds: 5635'

# %% [markdown]
# ### Entity resolution for compounds
#
# **NOTE:** Bridgebd xrefs requires the identifiers to be list of strings.

# %%
df = data_input[["cid"]]
df.rename(columns={"cid": "identifier"}, inplace=True)

# %%
bridgdb_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=df,
    input_species="Human",
    input_datasource="PubChem Compound",  # ChEMBL compound
    output_datasource="All",
)
bridgdb_df.head()
# Out:
#   identifier identifier.source                       target    target.source
# 0       1697  PubChem-compound                  145915-58-8              CAS
# 1       1697  PubChem-compound  AAALVYBICLMAMA-UHFFFAOYSA-N         InChIKey
# 2       1697  PubChem-compound                        53110            ChEBI
# 3       1697  PubChem-compound                 CHEMBL268868  ChEMBL compound
# 4       1697  PubChem-compound                  CHEBI:53110            ChEBI

# %%
def get_compound_gene_edges(df: pd.DataFrame) -> pd.DataFrame:
    molmedb_transporter_inhibited_df, _ = molmedb.get_compound_gene_inhibitor(
        bridgedb_df=bridgdb_df
    )

    # Processing

    return molmedb_transporter_inhibited_df

# %%
# Out:
#      identifier identifier.source                       target target.source  \
# 0      10000456  PubChem-compound  HIDWEYPGMLIQSN-UHFFFAOYSA-N      InChIKey
# 1      10001434  PubChem-compound  SJMMDWXJSSJHOQ-UHFFFAOYSA-N      InChIKey
# 2        100016  PubChem-compound  RPQZTTQVRYEKCR-WCTZXXKLSA-N      InChIKey
# 3        100185  PubChem-compound  XHGLVMDBZZZXDP-UHFFFAOYSA-N      InChIKey
# 4      10026128  PubChem-compound  INASOKQDNHHMRE-UHFFFAOYSA-N      InChIKey
# ...         ...               ...                          ...           ...
# 4741    9967941  PubChem-compound  DKPQHFZUICCZHF-UHFFFAOYSA-N      InChIKey
# 4742    9982218  PubChem-compound  ISSSVYKMIIAPTH-UHFFFAOYSA-N      InChIKey
# 4743    9989505  PubChem-compound  DFVSGZHJSIEEQQ-UHFFFAOYSA-N      InChIKey
# 4744    9995890  PubChem-compound  YWEGXZZAORIRQR-UHFFFAOYSA-N      InChIKey
# 4745    9996409  PubChem-compound  LIYLTQQDABRNRX-UHFFFAOYSA-N      InChIKey
#
#                           MolMeDB_transporter_inhibited
# 0     [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 1     [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 2     [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 3     [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 4     [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# ...                                                 ...
# 4741  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 4742  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 4743  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 4744  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
# 4745  [{'uniprot_trembl_id': nan, 'hgnc_symbol': nan...
#
# [4746 rows x 5 columns]

# %%
def building_graph():
    # Compound - gene interactions
    molmedb_transporter_inhibited_df, _ = molmedb.get_compound_gene_inhibitor(
        bridgedb_df=bridgdb_df
    )

# %% [markdown]
# ### Combing all the results into single dataframe

# %%
combined_df = combine_sources(
    [
        minerva_df,
        wikipathways_df,
        opentargets_reactome_df,
        opentargets_go_df,
        disgenet_df,
        disease_df,
        opentargets_drug_df,
        inhibitor_df,
        string_ppi_metadata,
    ]
)

# %%
combined_df.head(4)
# Out:
#   identifier identifier.source           target target.source  \
# 0        AHR              HGNC  ENSG00000106546       Ensembl
# 1      CHRNG              HGNC  ENSG00000196811       Ensembl
# 2        DMD              HGNC  ENSG00000198947       Ensembl
# 3      HTR3A              HGNC  ENSG00000166736       Ensembl
#
#                                                 Bgee  \
# 0  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
# 1  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
# 2  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
# 3  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
#
#                                              MINERVA  \
# 0  [{'pathway_id': 953.0, 'pathway_label': 'Kynur...
# 1  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 2  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 3  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
#
#                                         WikiPathways  \
# 0  [{'pathway_id': 'WP5044', 'pathway_label': 'Ky...
# 1  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 2  [{'pathway_id': 'WP2858', 'pathway_label': 'Ec...
# 3  [{'pathway_id': 'WP706', 'pathway_label': 'Sud...
#
#                                 OpenTargets_Reactome  \
# 0  [{'pathway_label': 'Endogenous sterols', 'path...
# 1  [{'pathway_label': 'Highly sodium permeable po...
# 2  [{'pathway_label': 'Striated Muscle Contractio...
# 3  [{'pathway_label': 'Neurotransmitter receptors...
#
#                                       OpenTargets_GO  \
# 0  [{'go_id': 'GO:0005667', 'go_name': 'transcrip...
# 1  [{'go_id': 'GO:0015464', 'go_name': 'acetylcho...
# 2  [{'go_id': 'GO:0016010', 'go_name': 'dystrophi...
# 3  [{'go_id': 'GO:1904602', 'go_name': 'serotonin...
#
#                                 OpenTargets_Location  \
# 0  [{'location_id': 'SL-0086', 'location': 'Cytop...
# 1  [{'location_id': 'SL-0219', 'location': 'Posts...
# 2  [{'location_id': 'SL-0039', 'location': 'Cell ...
# 3  [{'location_id': 'SL-0219', 'location': 'Posts...
#
#                                 OpenTargets_Diseases  \
# 0  [{'disease_id': 'umls:C0033860', 'disease_name...
# 1  [{'disease_id': 'umls:C0085631', 'disease_name...
# 2  [{'disease_id': 'umls:C0013264', 'disease_name...
# 3  [{'disease_id': 'EFO_0003843', 'disease_name':...
#
#                                OpenTargets_Compounds  \
# 0  [{'chembl_id': 'CHEMBL259571', 'drugbank_id': ...
# 1  [{'chembl_id': 'CHEMBL1200641', 'drugbank_id':...
# 2  [{'chembl_id': 'CHEMBL2108278', 'drugbank_id':...
# 3  [{'chembl_id': 'CHEMBL56564', 'drugbank_id': '...
#
#                        MolMeDB_transporter_inhibitor  \
# 0  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
# 1  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
# 2  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
# 3  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
#
#                                       PubChem_Assays  \
# 0  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
# 1  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
# 2  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
# 3  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
#
#                                             StringDB
# 0  [{'stringdb_link_to': 'SCN4A', 'Ensembl': 'ENS...
# 1  [{'stringdb_link_to': 'SCN4A', 'Ensembl': 'ENS...
# 2                                                 []
# 3  [{'stringdb_link_to': 'DMD', 'Ensembl': 'ENSP0...

# %%
combined_df.shape
# Out:
# (50, 15)

# %% [markdown]
# ### Exporting the database in pickle format

# %%
with open("combined_df.pkl", "wb") as out:
    pickle.dump(combined_df, out)

# %% [markdown]
# ## Creating a graph from the annotated dataframe

# %%
fuse_df = generator.load_dataframe_from_pickle("combined_df.pkl")

# %%
fuse_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0        AHR              HGNC  ENSG00000106546       Ensembl
# 1      CHRNG              HGNC  ENSG00000196811       Ensembl
# 2        DMD              HGNC  ENSG00000198947       Ensembl
# 3      HTR3A              HGNC  ENSG00000166736       Ensembl
# 4      SCN4A              HGNC  ENSG00000007314       Ensembl
#
#                                                 Bgee  \
# 0  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
# 1  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
# 2  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
# 3  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
# 4  [{'anatomical_entity_id': 'UBERON_0000178', 'a...
#
#                                              MINERVA  \
# 0  [{'pathway_id': 953.0, 'pathway_label': 'Kynur...
# 1  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 2  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 3  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 4  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
#
#                                         WikiPathways  \
# 0  [{'pathway_id': 'WP5044', 'pathway_label': 'Ky...
# 1  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
# 2  [{'pathway_id': 'WP2858', 'pathway_label': 'Ec...
# 3  [{'pathway_id': 'WP706', 'pathway_label': 'Sud...
# 4  [{'pathway_id': nan, 'pathway_label': nan, 'pa...
#
#                                 OpenTargets_Reactome  \
# 0  [{'pathway_label': 'Endogenous sterols', 'path...
# 1  [{'pathway_label': 'Highly sodium permeable po...
# 2  [{'pathway_label': 'Striated Muscle Contractio...
# 3  [{'pathway_label': 'Neurotransmitter receptors...
# 4  [{'pathway_label': 'Phase 0 - rapid depolarisa...
#
#                                       OpenTargets_GO  \
# 0  [{'go_id': 'GO:0005667', 'go_name': 'transcrip...
# 1  [{'go_id': 'GO:0015464', 'go_name': 'acetylcho...
# 2  [{'go_id': 'GO:0016010', 'go_name': 'dystrophi...
# 3  [{'go_id': 'GO:1904602', 'go_name': 'serotonin...
# 4  [{'go_id': 'GO:0035725', 'go_name': 'sodium io...
#
#                                 OpenTargets_Location  \
# 0  [{'location_id': 'SL-0086', 'location': 'Cytop...
# 1  [{'location_id': 'SL-0219', 'location': 'Posts...
# 2  [{'location_id': 'SL-0039', 'location': 'Cell ...
# 3  [{'location_id': 'SL-0219', 'location': 'Posts...
# 4  [{'location_id': 'SL-0039', 'location': 'Cell ...
#
#                                 OpenTargets_Diseases  \
# 0  [{'disease_id': 'umls:C0033860', 'disease_name...
# 1  [{'disease_id': 'umls:C0085631', 'disease_name...
# 2  [{'disease_id': 'umls:C0013264', 'disease_name...
# 3  [{'disease_id': 'EFO_0003843', 'disease_name':...
# 4  [{'disease_id': 'EFO_0000432', 'disease_name':...
#
#                                OpenTargets_Compounds  \
# 0  [{'chembl_id': 'CHEMBL259571', 'drugbank_id': ...
# 1  [{'chembl_id': 'CHEMBL1200641', 'drugbank_id':...
# 2  [{'chembl_id': 'CHEMBL2108278', 'drugbank_id':...
# 3  [{'chembl_id': 'CHEMBL56564', 'drugbank_id': '...
# 4  [{'chembl_id': 'CHEMBL1077896', 'drugbank_id':...
#
#                        MolMeDB_transporter_inhibitor  \
# 0  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
# 1  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
# 2  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
# 3  [{'compound_name': nan, 'InChIKey': nan, 'SMIL...
# 4  [{'compound_name': '3-phenyl-1h-pyrazole', 'In...
#
#                                       PubChem_Assays  \
# 0  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
# 1  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
# 2  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
# 3  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
# 4  [{'pubchem_assay_id': nan, 'assay_type': nan, ...
#
#                                             StringDB
# 0  [{'stringdb_link_to': 'SCN4A', 'Ensembl': 'ENS...
# 1  [{'stringdb_link_to': 'SCN4A', 'Ensembl': 'ENS...
# 2                                                 []
# 3  [{'stringdb_link_to': 'DMD', 'Ensembl': 'ENSP0...
# 4                                                 []

# %%
pygraph = generator.networkx_graph(fuse_df)

# %% [markdown]
# ### Store the graph

# %%
with open("networkx_graph.pkl", "wb") as out:
    pickle.dump(pygraph, out)

# %% [markdown]
# ## Visualize the graph

# %%
# pos = nx.circular_layout(pygraph)

# plt.figure(3, figsize=(30, 30))
# nx.draw(pygraph, pos)
# plt.show()

# %%
from pyBiodatafuse.graph import cytoscape, neo4j

neo4j.save_graph_to_graphml(pygraph, output_path="graph_to-test.graphml")
cytoscape.load_graph(pygraph, network_name="test")
