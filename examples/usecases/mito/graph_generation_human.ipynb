# %% [markdown]
# ## Explore mitochondrial impairment in tumars

# %% [markdown]
# **Aim**: in this notebook, you will see all the steps for collecting data and constructing a KG to explore mitochondrial impairment in tumer (both in human and mice)

# %% [markdown]
# ### Import required libraries

# %%
# Import modules
import gzip
import os
import pickle
from io import BytesIO

import numpy as np
import pandas as pd
import requests
from gprofiler.gprofiler import GProfiler

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import (
    bgee,
    disgenet,
    minerva,
    molmedb,
    opentargets,
    pubchem,
    stringdb,
    wikipathways,
)
from pyBiodatafuse.constants import BGEE_GENE_EXPRESSION_LEVELS_COL, DISGENET_DISEASE_COL
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import (
    combine_sources,
    create_harmonized_input_file,
    create_or_append_to_metadata,
    get_identifier_of_interest,
)

os.makedirs("data", exist_ok=True)
base_dir = os.path.abspath(os.getcwd())

# %% [markdown]
# ### Load the input files

# %%
# Read only specific columns and skip the first row
all_genes_human = pd.read_excel("datasets/cachexia_vs_control_all_genes.xlsx")
all_genes_human.rename(
    columns={"Unnamed: 0": "identifier", "Unnamed: 1": "GENE_SYMBOL"}, inplace=True
)
deg_human = all_genes_human[all_genes_human["padj"] < 0.05]
print("Number of genes:", len(all_genes_human["identifier"].unique()))
deg_human.head(1)
# Out:
# Number of genes: 12322
#         identifier GENE_SYMBOL    baseMean  log2FoldChange   lfcSE      stat  \
# 6  ENSG00000001084        GCLC  412.449345        0.454035  0.1302  3.487222
#
#      pvalue      padj  minus_log10_pvalue
# 6  0.000488  0.018659            3.311521

# %%
deg_human[deg_human["identifier"] == "ENSG00000159713"]  # does not exist in the deg table shared
# Out:
#            identifier GENE_SYMBOL   baseMean  log2FoldChange     lfcSE  \
# 7049  ENSG00000159713       TPPP3  665.53875        1.436198  0.360226
#
#           stat    pvalue      padj  minus_log10_pvalue
# 7049  3.986934  0.000067  0.005344            4.174362

# %% [markdown]
# ### Entity resolution with BridgeDB

# %%
pickle_path_human = os.path.join(base_dir, "data/human/bridgedb_df_human.pkl")
metadata_path_human = os.path.join(base_dir, "data/human/bridgedb_metadata_human.pkl")

if not os.path.exists(pickle_path_human):
    bridgedb_df_human, bridgedb_metadata_human = id_mapper.bridgedb_xref(
        identifiers=all_genes_human,
        input_species="Human",
        input_datasource="Ensembl",
        output_datasource="All",
    )
    bridgedb_df_human.to_pickle(pickle_path_human)
    with open(metadata_path_human, "wb") as file:
        pickle.dump(bridgedb_metadata_human, file)
else:
    bridgedb_df_human = pd.read_pickle(pickle_path_human)
    with open(metadata_path_human, "rb") as file:
        bridgedb_metadata_human = pickle.load(file)

# %%
print("Number of genes with mapping in BridgeDb:", len(bridgedb_df_human["identifier"].unique()))
bridgedb_df_human.head(1)
# Out:
# Number of genes with mapping in BridgeDb: 12310
#         identifier identifier.source      target          target.source  \
# 0  ENSG00000000003           Ensembl  HGNC:11858  HGNC Accession Number
#
#   GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  \
# 0          TSPAN6    106.899174           -0.401659   0.143909 -2.791057
#
#    pvalue_dea  padj_dea  minus_log10_pvalue_dea
# 0    0.005254    0.0779                2.279542

# %% [markdown]
# ### Enrichment analysis using g:Profiler
# all the pathways and annotations are being added despite being significance.

# %%
gp = GProfiler(return_dataframe=True)
filename_human = "data/human/gprofiler_human_0.01.pkl"
if not os.path.exists(filename_human):
    gprofiler_human = gp.profile(
        organism="hsapiens",
        all_results=True,
        query=bridgedb_df_human[bridgedb_df_human["padj_dea"] <= 0.01]["identifier"]
        .unique()
        .tolist(),
        background=bridgedb_df_human["identifier"].unique().tolist(),
        no_evidences=False,
        significance_threshold_method="fdr",
        user_threshold=0.05,
    )
    gprofiler_human.rename(columns={"native": "id"}, inplace=True)
    gprofiler_human["datasource"] = "g:Profiler"
    gprofiler_human.to_pickle(filename_human)
else:
    with open(filename_human, "rb") as f:
        gprofiler_human = pickle.load(f)

# %%
print(gprofiler_human.shape)
gprofiler_human.head(1)
# Out:
# (18779, 17)
#   source          id           name       p_value  significant  \
# 0  GO:CC  GO:0005739  mitochondrion  5.957169e-12         True
#
#                                          description  term_size  query_size  \
# 0  "A semiautonomous, self replicating organelle ...       1434         226
#
#    intersection_size  effective_domain_size  precision    recall    query  \
# 0                 69                  12294    0.30531  0.048117  query_1
#
#                     parents  \
# 0  [GO:0005737, GO:0043231]
#
#                                        intersections  \
# 0  [ENSG00000010256, ENSG00000023228, ENSG0000002...
#
#                                            evidences  datasource
# 0  [[IDA, HDA, IBA, TAS, IEA], [IDA, TAS, IEA], [...  g:Profiler

# %%
# Function to count upregulated and downregulated genes
def count_up_down(genes, bridgedb_df_human):
    if not isinstance(genes, list) or len(genes) == 0:  # Ensure genes is a list
        return 0, 0

    genes = [str(g).strip() for g in genes]
    filtered_df = bridgedb_df_human[bridgedb_df_human["identifier"].isin(genes)]

    upregulated = (filtered_df["log2FoldChange_dea"] > 0).sum()
    downregulated = (filtered_df["log2FoldChange_dea"] < 0).sum()
    
    return upregulated, downregulated

# %%
# Keep only significant results
gprofiler_sig_human= gprofiler_human[gprofiler_human["significant"] == True]

# %%
gprofiler_sig_human[["no_upregulated_genes", "no_downregulated_genes"]]  = gprofiler_sig_human["intersections"].apply(
    lambda genes: pd.Series(count_up_down(genes, bridgedb_df_human[bridgedb_df_human["target.source"] == "Ensembl"]))
)

# %%
gprofiler_sig_human.shape
# Out:
# (410, 19)

# %%
selected_columns = ["source", "id", "name", "p_value", "term_size", "intersection_size", "parents","no_upregulated_genes", "no_downregulated_genes"]
gprofiler_sig_human[selected_columns].to_csv("data/human/gprofiler_sig_human_0.05.csv", index=False)

# %% [markdown]
# #### For the graph

# %%
gprofiler_human = gprofiler_human[
    ~gprofiler_human["parents"].apply(lambda x: x == [])
]  # rm the root terms

# %%
from pyBiodatafuse.constants import GPROFILER


def create_path_info(row):
    path_info = {
        col: row[col] for col in gprofiler_human.columns if col not in ["intersections", "source"]
    }
    return path_info


gprofiler_human["gprofiler"] = gprofiler_human.apply(create_path_info, axis=1)
gprofiler_human = gprofiler_human.drop(
    columns=[
        col
        for col in gprofiler_human.columns
        if col not in ["source", "id", "intersections", "gprofiler"]
    ]
)
gprofiler_human = gprofiler_human.explode("intersections").reset_index(drop=True)
unique_sources = sorted(gprofiler_human["source"].unique())
gprofiler_human_final = pd.DataFrame()
gprofiler_human_final["intersections"] = gprofiler_human["intersections"].unique()
for source in unique_sources:
    source_subset = gprofiler_human[gprofiler_human["source"] == source]
    source_dictionaries = source_subset.groupby("intersections")["gprofiler"].apply(list).to_dict()
    gprofiler_human_final[f"{GPROFILER}_{str.lower(source)}"] = gprofiler_human_final[
        "intersections"
    ].map(source_dictionaries)
gprofiler_human_final.head(1)
# Out:
#      intersections                                   g:Profiler_corum  \
# 0  ENSG00000001084  [{'id': 'CORUM:7186', 'name': 'Glutamate-cyste...
#
#                                     g:Profiler_go:bp  \
# 0  [{'id': 'GO:0044281', 'name': 'small molecule ...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0005739', 'name': 'mitochondrion',...
#
#                                     g:Profiler_go:mf  \
# 0  [{'id': 'GO:0003824', 'name': 'catalytic activ...
#
#                                        g:Profiler_hp  \
# 0  [{'id': 'HP:0012337', 'name': 'Abnormal homeos...
#
#                                       g:Profiler_hpa  \
# 0  [{'id': 'HPA:0440341', 'name': 'skeletal muscl...
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:hsa-miR-30c-5p', 'name': 'hsa-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-HSA-1430728', 'name': 'Metabol...
#
#                                        g:Profiler_tf  \
# 0  [{'id': 'TF:M07428', 'name': 'Factor: Six-3; m...
#
#                                        g:Profiler_wp
# 0  [{'id': 'WP:WP2882', 'name': 'Nuclear receptor...

# %%
## get version
def get_data_versions(organism):
    url = "https://biit.cs.ut.ee/gprofiler/api/util/data_versions"
    params = {"organism": organism}
    try:
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            return data
        else:
            raise Exception(f"Failed to retrieve data: {response.status_code}")
    except Exception as e:
        return {"error": str(e)}


get_data_versions("hsapiens")
# Out:
# {'biomart': 'Ensembl',
#  'biomart_version': '112',
#  'display_name': 'Human',
#  'genebuild': 'GRCh38.p14',
#  'gprofiler_version': 'e112_eg59_p19_25aa4782',
#  'organism': 'hsapiens',
#  'sources': {'CORUM': {'name': 'CORUM protein complexes',
#    'version': '28.11.2022 Corum 4.1'},
#   'GO:BP': {'name': 'biological process',
#    'version': 'annotations: BioMart\nclasses: releases/2024-10-27'},
#   'GO:CC': {'name': 'cellular component',
#    'version': 'annotations: BioMart\nclasses: releases/2024-10-27'},
#   'GO:MF': {'name': 'molecular function',
#    'version': 'annotations: BioMart\nclasses: releases/2024-10-27'},
#   'HP': {'name': 'Human Phenotype Ontology',
#    'version': 'annotations: 02.2025\nclasses: None'},
#   'HPA': {'name': 'Human Protein Atlas',
#    'version': 'annotations: HPA website: 23-07-17\nclasses: script: 24-01-02'},
#   'KEGG': {'name': 'Kyoto Encyclopedia of Genes and Genomes',
#    'version': 'KEGG FTP Release 2024-01-22'},
#   'MIRNA': {'name': 'miRTarBase', 'version': 'Release 9.0'},
#   'REAC': {'name': 'Reactome',
#    'version': 'annotations: BioMart\nclasses: 2025-2-3'},
#   'TF': {'name': 'Transfac',
#    'version': 'annotations: TRANSFAC Release 2023.2\nclasses: v2'},
#   'WP': {'name': 'WikiPathways', 'version': '20250110'}},
#  'taxonomy_id': '9606'}

# %%
ncbi_tf_gprofiler_df_human = pd.merge(
    ncbi_tf_df_human,
    gprofiler_human_final,
    left_on="identifier",
    right_on="intersections",
    how="outer",
)

# %%
ncbi_tf_gprofiler_df_human.head(2)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSG00000000003           Ensembl   7105     NCBI Gene          TSPAN6
# 1  ENSG00000000419           Ensembl   8813     NCBI Gene            DPM1
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 0    106.899174           -0.401659   0.143909 -2.791057    0.005254  ...
# 1    601.924666           -0.104654   0.161936 -0.646270    0.518105  ...
#
#    g:Profiler_go:bp  g:Profiler_go:cc g:Profiler_go:mf g:Profiler_hp  \
# 0               NaN               NaN              NaN           NaN
# 1               NaN               NaN              NaN           NaN
#
#   g:Profiler_hpa g:Profiler_kegg g:Profiler_mirna g:Profiler_reac  \
# 0            NaN             NaN              NaN             NaN
# 1            NaN             NaN              NaN             NaN
#
#   g:Profiler_tf g:Profiler_wp
# 0           NaN           NaN
# 1           NaN           NaN
#
# [2 rows x 28 columns]

# %%
ncbi_tf_gprofiler_df_human[ncbi_tf_gprofiler_df_human["g:Profiler_reac"].notna()].head(1)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 6  ENSG00000001084           Ensembl   2729     NCBI Gene            GCLC
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 6    412.449345            0.454035     0.1302  3.487222    0.000488  ...
#
#                                     g:Profiler_go:bp  \
# 6  [{'id': 'GO:0044281', 'name': 'small molecule ...
#
#                                     g:Profiler_go:cc  \
# 6  [{'id': 'GO:0005739', 'name': 'mitochondrion',...
#
#                                     g:Profiler_go:mf  \
# 6  [{'id': 'GO:0003824', 'name': 'catalytic activ...
#
#                                        g:Profiler_hp  \
# 6  [{'id': 'HP:0012337', 'name': 'Abnormal homeos...
#
#                                       g:Profiler_hpa  \
# 6  [{'id': 'HPA:0440341', 'name': 'skeletal muscl...
#
#                                      g:Profiler_kegg  \
# 6  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 6  [{'id': 'MIRNA:hsa-miR-30c-5p', 'name': 'hsa-m...
#
#                                      g:Profiler_reac  \
# 6  [{'id': 'REAC:R-HSA-1430728', 'name': 'Metabol...
#
#                                        g:Profiler_tf  \
# 6  [{'id': 'TF:M07428', 'name': 'Factor: Six-3; m...
#
#                                        g:Profiler_wp
# 6  [{'id': 'WP:WP2882', 'name': 'Nuclear receptor...
#
# [1 rows x 28 columns]

# %%
ncbi_tf_gprofiler_df_human[ncbi_tf_gprofiler_df_human["g:Profiler_reac"].notna()].head(1)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 6  ENSG00000001084           Ensembl   2729     NCBI Gene            GCLC
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 6    412.449345            0.454035     0.1302  3.487222    0.000488  ...
#
#                                     g:Profiler_go:bp  \
# 6  [{'id': 'GO:0044281', 'name': 'small molecule ...
#
#                                     g:Profiler_go:cc  \
# 6  [{'id': 'GO:0005739', 'name': 'mitochondrion',...
#
#                                     g:Profiler_go:mf  \
# 6  [{'id': 'GO:0003824', 'name': 'catalytic activ...
#
#                                        g:Profiler_hp  \
# 6  [{'id': 'HP:0012337', 'name': 'Abnormal homeos...
#
#                                       g:Profiler_hpa  \
# 6  [{'id': 'HPA:0440341', 'name': 'skeletal muscl...
#
#                                      g:Profiler_kegg  \
# 6  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 6  [{'id': 'MIRNA:hsa-miR-30c-5p', 'name': 'hsa-m...
#
#                                      g:Profiler_reac  \
# 6  [{'id': 'REAC:R-HSA-1430728', 'name': 'Metabol...
#
#                                        g:Profiler_tf  \
# 6  [{'id': 'TF:M07428', 'name': 'Factor: Six-3; m...
#
#                                        g:Profiler_wp
# 6  [{'id': 'WP:WP2882', 'name': 'Nuclear receptor...
#
# [1 rows x 28 columns]

# %% [markdown]
# ### Add MitoCarta data

# %%
# URLs for the Human MitoCarta Dataset
mitocarta_url_human = (
    "https://personal.broadinstitute.org/scalvo/MitoCarta3.0/Human.MitoCarta3.0.xls"
)
# Function to download and read a gzipped file into a dataframe
def download_save_and_read(url, filename):
    if not os.path.exists(filename):
        response = requests.get(url)
        with open(filename, "wb") as file:
            file.write(response.content)
    else:
        print(f"{filename} already exists, skipping download.")

    # Load the second sheet ("A Human MitoCarta3.0") into a DataFrame
    df = pd.read_excel(url, sheet_name="A Human MitoCarta3.0")
    return df


# Download and read the Human MitoCarta dataset
mitocarta_human_df = download_save_and_read(mitocarta_url_human, "data/human/human_mitocarta3.0.xls")

mitocarta_human_df.head(1)
# Out:
# data/human/human_mitocarta3.0.xls already exists, skipping download.
#   HumanGeneID  MouseOrthologGeneID Symbol      Synonyms    Description  \
# 0        1537              66445.0   CYC1  MC3DN6|UQCR4  cytochrome c1
#
#   MitoCarta3.0_List                              MitoCarta3.0_Evidence  \
# 0      MitoCarta3.0  literature, APEX_IMS, APEX_matrix, targetP sig...
#
#   MitoCarta3.0_SubMitoLocalization  \
# 0                              MIM
#
#                            MitoCarta3.0_MitoPathways TrainingDataset  ...  \
# 0  OXPHOS > Complex III > CIII subunits | Metabol...           Tmito  ...
#
#    liver_total_peak_intensity_log10  heart_total_peak_intensity_log10  \
# 0                              10.0                              10.4
#
#    skeletalmuscle_total_peak_intensity_log10  \
# 0                                        9.8
#
#   adipose_total_peak_intensity_log10  \
# 0                               10.1
#
#   smallintestine_total_peak_intensity_log10  \
# 0                                      10.2
#
#   largeintestine_total_peak_intensity_log10  \
# 0                                      10.2
#
#    stomach_total_peak_intensity_log10  placenta_total_peak_intensity_log10  \
# 0                                10.0                                 10.0
#
#   testis_total_peak_intensity_log10  HPA_Main_Location_2020 (Reliability)
# 0                               9.8              Mitochondria (Supported)
#
# [1 rows x 48 columns]

# %%
# Select relevant columns for inclusion in the graph
selected_columns_human = [
    "EnsemblGeneID_mapping_version_20200130",
    "Description",
    "MitoCarta3.0_Evidence",
    "MitoCarta3.0_SubMitoLocalization",
    "MitoCarta3.0_MitoPathways",
    "HPA_Main_Location_2020 (Reliability)",
    "Tissues",
]

mitocarta_human_selected = mitocarta_human_df[selected_columns_human]

# Rename columns for clarity
mitocarta_human_selected.rename(
    columns={
        "EnsemblGeneID_mapping_version_20200130": "ensembl_id",
        "Description": "gene_description",
        "MitoCarta3.0_Evidence": "evidence",
        "MitoCarta3.0_SubMitoLocalization": "sub_mito_localization",
        "MitoCarta3.0_MitoPathways": "mito_pathways",
        "HPA_Main_Location_2020 (Reliability)": "hpa_location",
        "Tissues": "tissue_expression",
    },
    inplace=True,
)

# %%
mitocarta_human_selected["mito_pathways"] = (
    mitocarta_human_selected["mito_pathways"]
    .str.split(">")
    .str[-1]
    .str.split("|")
    .str[0]
    .str.strip()
)

# %%
mitocarta_human_selected = mitocarta_human_selected.dropna(subset=["mito_pathways"]).reset_index(drop=True) # Drop rows with missing mito_pathways
mitocarta_human_selected["ensembl_id"] = mitocarta_human_selected["ensembl_id"].str.split("|")
mitocarta_human_selected = mitocarta_human_selected.explode("ensembl_id").reset_index(drop=True)

# %%
mitocarta_human_selected = mitocarta_human_selected[mitocarta_human_selected["ensembl_id"].isin(bridgedb_df_human["identifier"][bridgedb_df_human["padj_dea"] < 0.05])] # Keep only significant genes existing in our dataset

# %%
bridgedb_df_human.head(1)
# Out:
#         identifier identifier.source      target          target.source  \
# 0  ENSG00000000003           Ensembl  HGNC:11858  HGNC Accession Number
#
#   GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  \
# 0          TSPAN6    106.899174           -0.401659   0.143909 -2.791057
#
#    pvalue_dea  padj_dea  minus_log10_pvalue_dea
# 0    0.005254    0.0779                2.279542

# %%
mitocarta_human_selected.head(3)
# Out:
#         ensembl_id                                   gene_description  \
# 1  ENSG00000117118  succinate dehydrogenase complex iron sulfur su...
# 4  ENSG00000010256    ubiquinol-cytochrome c reductase core protein 1
# 7  ENSG00000088682                                        coenzyme Q9
#
#                                             evidence sub_mito_localization  \
# 1  literature, APEX_matrix, targetP signal+, yeas...                   MIM
# 4  literature, APEX_matrix, targetP signal+, yeas...                   MIM
# 7  APEX_matrix, targetP signal+, yeast mito homol...                   MIM
#
#            mito_pathways              hpa_location tissue_expression
# 1        OXPHOS subunits  Mitochondria (Supported)            all 14
# 4        OXPHOS subunits  Mitochondria (Supported)            all 14
# 7  Coenzyme Q metabolism                       NaN            all 14

# %%
aggregated_mitocarta_human_selected = mitocarta_human_selected.groupby("mito_pathways").agg(
    {
        "ensembl_id": list,
    }
).reset_index()
aggregated_mitocarta_human_selected["intersections"] = aggregated_mitocarta_human_selected["ensembl_id"].apply(len)

# %%
aggregated_mitocarta_human_selected.head(4)
# Out:
#            mito_pathways         ensembl_id  intersections
# 0       ABC transporters  [ENSG00000115657]              1
# 1  Amino acid metabolism  [ENSG00000133943]              1
# 2              Apoptosis  [ENSG00000176171]              1
# 3              Autophagy  [ENSG00000146729]              1

# %%
aggregated_mitocarta_human_selected[["no_upregulated_genes", "no_downregulated_genes"]]  = aggregated_mitocarta_human_selected["ensembl_id"].apply(
    lambda genes: pd.Series(count_up_down(genes, bridgedb_df_human[bridgedb_df_human["target.source"] == "Ensembl"]))
)

# %%
aggregated_mitocarta_human_selected.to_csv("data/human/mitocarta_human_0.05.csv", index=False)

# %%
aggregated_mitocarta_human_selected
# Out:
#                                       mito_pathways  \
# 0                                  ABC transporters
# 1                             Amino acid metabolism
# 2                                         Apoptosis
# 3                                         Autophagy
# 4                         Biotin utilizing proteins
# 5   Branched-chain amino acid dehydrogenase complex
# 6              Branched-chain amino acid metabolism
# 7                                 Calcium uniporter
# 8                                 Carnitine shuttle
# 9                 Carnitine synthesis and transport
# 10        Cholesterol, bile acid, steroid synthesis
# 11                            Coenzyme Q metabolism
# 12                              Creatine metabolism
# 13                             Fatty acid oxidation
# 14                        Fe-S cluster biosynthesis
# 15                         Fe-S-containing proteins
# 16                                  GABA metabolism
# 17                          Glycine cleavage system
# 18                    Heme synthesis and processing
# 19                                     Import motor
# 20                                 Iron homeostasis
# 21                             Itaconate metabolism
# 22                                 Lipid metabolism
# 23                                Lysine metabolism
# 24                                    MICOS complex
# 25       Mitochondrial permeability transition pore
# 26                           Mitochondrial ribosome
# 27                  Mitochondrial ribosome assembly
# 28                  NAD biosynthesis and metabolism
# 29              Nucleotide synthesis and processing
# 30                          OXPHOS assembly factors
# 31                                  OXPHOS subunits
# 32                          Organelle contact sites
# 33                          Phospholipid metabolism
# 34                              Pyruvate metabolism
# 35                        Q-linked reactions, other
# 36                   ROS and glutathione metabolism
# 37                                    SLC25A family
# 38                                   Selenoproteins
# 39                                        Signaling
# 40                         Small molecule transport
# 41                                Sulfur metabolism
# 42                                        TCA cycle
# 43                                      Translation
# 44                     Type II fatty acid synthesis
# 45                             Vitamin D metabolism
# 46                            Xenobiotic metabolism
# 47                            mt-mRNA modifications
# 48                            mt-rRNA modifications
# 49                              mt-tRNA synthetases
# 50                                     mtDNA repair
# 51                        mtRNA stability and decay
#
#                                            ensembl_id  intersections  \
# 0                                   [ENSG00000115657]              1
# 1                                   [ENSG00000133943]              1
# 2                                   [ENSG00000176171]              1
# 3                                   [ENSG00000146729]              1
# 4                                   [ENSG00000175198]              1
# 5                  [ENSG00000137992, ENSG00000083123]              2
# 6   [ENSG00000148090, ENSG00000198130, ENSG0000019...              5
# 7                                   [ENSG00000107745]              1
# 8                                   [ENSG00000157184]              1
# 9                                   [ENSG00000185973]              1
# 10                                  [ENSG00000116171]              1
# 11  [ENSG00000088682, ENSG00000119723, ENSG0000013...              4
# 12                                  [ENSG00000131730]              1
# 13                                  [ENSG00000104325]              1
# 14                                  [ENSG00000100209]              1
# 15  [ENSG00000100412, ENSG00000066926, ENSG0000017...              3
# 16                                  [ENSG00000148672]              1
# 17                 [ENSG00000091140, ENSG00000140905]              2
# 18                                  [ENSG00000023330]              1
# 19                                  [ENSG00000205981]              1
# 20                                  [ENSG00000167996]              1
# 21                                  [ENSG00000125246]              1
# 22                 [ENSG00000093144, ENSG00000107537]              2
# 23  [ENSG00000119689, ENSG00000127884, ENSG0000007...              4
# 24                                  [ENSG00000155008]              1
# 25                                  [ENSG00000108179]              1
# 26  [ENSG00000166902, ENSG00000135900, ENSG0000006...              4
# 27  [ENSG00000171861, ENSG00000182768, ENSG0000013...              3
# 28  [ENSG00000142082, ENSG00000112992, ENSG0000012...              6
# 29  [ENSG00000136143, ENSG00000163541, ENSG0000017...              4
# 30  [ENSG00000101019, ENSG00000101247, ENSG0000013...              7
# 31  [ENSG00000117118, ENSG00000010256, ENSG0000015...             25
# 32  [ENSG00000116688, ENSG00000165775, ENSG0000021...              4
# 33                                  [ENSG00000103642]              1
# 34                 [ENSG00000168291, ENSG00000110435]              2
# 35  [ENSG00000171503, ENSG00000140374, ENSG0000020...              3
# 36  [ENSG00000165672, ENSG00000126432, ENSG0000016...              3
# 37                                  [ENSG00000115840]              1
# 38                                  [ENSG00000167468]              1
# 39                                  [ENSG00000135441]              1
# 40                                  [ENSG00000014824]              1
# 41                                  [ENSG00000125166]              1
# 42                                  [ENSG00000182054]              1
# 43                                  [ENSG00000151806]              1
# 44                                  [ENSG00000151093]              1
# 45                                  [ENSG00000161513]              1
# 46                 [ENSG00000197448, ENSG00000100577]              2
# 47                                  [ENSG00000139637]              1
# 48                                  [ENSG00000169519]              1
# 49  [ENSG00000067704, ENSG00000059691, ENSG0000013...              4
# 50                                  [ENSG00000076248]              1
# 51                 [ENSG00000156502, ENSG00000147592]              2
#
#     no_upregulated_genes  no_downregulated_genes
# 0                      1                       0
# 1                      0                       1
# 2                      1                       0
# 3                      0                       1
# 4                      0                       1
# 5                      0                       2
# 6                      0                       5
# 7                      0                       1
# 8                      0                       1
# 9                      0                       1
# 10                     0                       1
# 11                     0                       4
# 12                     0                       1
# 13                     0                       1
# 14                     0                       1
# 15                     0                       3
# 16                     0                       1
# 17                     0                       2
# 18                     0                       1
# 19                     0                       1
# 20                     0                       1
# 21                     0                       1
# 22                     0                       2
# 23                     0                       4
# 24                     0                       1
# 25                     0                       1
# 26                     0                       4
# 27                     0                       3
# 28                     0                       6
# 29                     0                       4
# 30                     0                       7
# 31                     0                      25
# 32                     1                       3
# 33                     0                       1
# 34                     0                       2
# 35                     0                       3
# 36                     0                       3
# 37                     0                       1
# 38                     0                       1
# 39                     1                       0
# 40                     0                       1
# 41                     0                       1
# 42                     0                       1
# 43                     0                       1
# 44                     0                       1
# 45                     1                       0
# 46                     0                       2
# 47                     1                       0
# 48                     0                       1
# 49                     0                       4
# 50                     0                       1
# 51                     0                       2

# %% [markdown]
# #### For the graph

# %%
import pandas as pd
mitocarta_human_1 = pd.read_csv("data/human/mitocarta_human_0.01.csv")
mitocarta_human_1.rename(
    columns={
        "intersections": "intersection_size_0.01",
        "no_upregulated_genes": "no_upregulated_genes_0.01",
        "no_downregulated_genes": "no_downregulated_genes_0.01"
    },
    inplace=True,
)

mitocarta_human_1 = mitocarta_human_1.drop(columns=["ensembl_id"])
mitocarta_human_1.head()
# Out:
#                                      mito_pathways  intersection_size_0.01  \
# 0                                 ABC transporters                       1
# 1                        Biotin utilizing proteins                       1
# 2  Branched-chain amino acid dehydrogenase complex                       1
# 3             Branched-chain amino acid metabolism                       3
# 4                                Calcium uniporter                       1
#
#    no_upregulated_genes_0.01  no_downregulated_genes_0.01
# 0                          1                            0
# 1                          0                            1
# 2                          0                            1
# 3                          0                            3
# 4                          0                            1

# %%
mitocarta_human_5 = pd.read_csv("data/human/mitocarta_human_0.05.csv")
mitocarta_human_5.rename(
    columns={
        "intersections": "intersection_size_0.05",
        "no_upregulated_genes": "no_upregulated_genes_0.05",
        "no_downregulated_genes": "no_downregulated_genes_0.05"
    },
    inplace=True,
)

mitocarta_human_5 = mitocarta_human_5.drop(columns=["ensembl_id"])
mitocarta_human_5.head()
# Out:
#                mito_pathways  intersection_size_0.05  \
# 0           ABC transporters                       1
# 1      Amino acid metabolism                       1
# 2                  Apoptosis                       1
# 3                  Autophagy                       1
# 4  Biotin utilizing proteins                       1
#
#    no_upregulated_genes_0.05  no_downregulated_genes_0.05
# 0                          1                            0
# 1                          0                            1
# 2                          1                            0
# 3                          0                            1
# 4                          0                            1

# %%
mitocarta_human = pd.merge(mitocarta_human_1, mitocarta_human_5, on="mito_pathways", how="outer")
mitocarta_human.head()
# Out:
#                                      mito_pathways  intersection_size_0.01  \
# 0                                 ABC transporters                     1.0
# 1                        Biotin utilizing proteins                     1.0
# 2  Branched-chain amino acid dehydrogenase complex                     1.0
# 3             Branched-chain amino acid metabolism                     3.0
# 4                                Calcium uniporter                     1.0
#
#    no_upregulated_genes_0.01  no_downregulated_genes_0.01  \
# 0                        1.0                          0.0
# 1                        0.0                          1.0
# 2                        0.0                          1.0
# 3                        0.0                          3.0
# 4                        0.0                          1.0
#
#    intersection_size_0.05  no_upregulated_genes_0.05  \
# 0                       1                          1
# 1                       1                          0
# 2                       2                          0
# 3                       5                          0
# 4                       1                          0
#
#    no_downregulated_genes_0.05
# 0                            0
# 1                            1
# 2                            2
# 3                            5
# 4                            1

# %%
mitocarta_human.to_csv("data/human/mitocarta_human_0.05&0.01.csv", index=False)

# %%
aggregated_mitocarta_human_selected.to_csv("data/human/mitocarta_human_0.05.csv", index=False)
gprofiler_sig_human[selected_columns].to_csv("data/human/gprofiler_sig_human_0.05.csv", index=False)

# %%
gprofiler_sig_human_1 = pd.read_csv("data/human/gprofiler_sig_human_0.01.csv")
gprofiler_sig_human_1.head()
# Out:
#   source                  id  \
# 0  GO:CC          GO:0005739
# 1   KEGG          KEGG:01100
# 2   REAC  REAC:R-HSA-1428517
# 3  GO:BP          GO:0045333
# 4  GO:BP          GO:0009060
#
#                                                 name       p_value  term_size  \
# 0                                      mitochondrion  5.957169e-12       1434
# 1                                 Metabolic pathways  1.486192e-11       1097
# 2  Aerobic respiration and respiratory electron t...  3.919927e-11        170
# 3                               cellular respiration  6.969748e-09        220
# 4                                aerobic respiration  2.760689e-08        181
#
#    intersection_size                       parents  no_upregulated_genes  \
# 0                 69  ['GO:0005737', 'GO:0043231']                     6
# 1                 58                ['KEGG:00000']                     7
# 2                 23        ['REAC:R-HSA-1430728']                     0
# 3                 24                ['GO:0015980']                     0
# 4                 21                ['GO:0045333']                     0
#
#    no_downregulated_genes
# 0                      63
# 1                      51
# 2                      23
# 3                      24
# 4                      21

# %%
import pandas as pd
gprofiler_sig_human_1 = pd.read_csv("data/human/gprofiler_sig_human_0.01.csv")
gprofiler_sig_human_1.rename(
    columns={
        "intersection_size": "intersection_size_0.01",
        "p_value": "p_value_0.01",
        "term_size": "term_size_0.01",
        "no_upregulated_genes": "no_upregulated_genes_0.01",
        "no_downregulated_genes": "no_downregulated_genes_0.01"
    },
    inplace=True,
)
gprofiler_sig_human_1 = gprofiler_sig_human_1.drop(columns=["parents"])
gprofiler_sig_human_1.head()
# Out:
#   source                  id  \
# 0  GO:CC          GO:0005739
# 1   KEGG          KEGG:01100
# 2   REAC  REAC:R-HSA-1428517
# 3  GO:BP          GO:0045333
# 4  GO:BP          GO:0009060
#
#                                                 name  p_value_0.01  \
# 0                                      mitochondrion  5.957169e-12
# 1                                 Metabolic pathways  1.486192e-11
# 2  Aerobic respiration and respiratory electron t...  3.919927e-11
# 3                               cellular respiration  6.969748e-09
# 4                                aerobic respiration  2.760689e-08
#
#    term_size_0.01  intersection_size_0.01  no_upregulated_genes_0.01  \
# 0            1434                      69                          6
# 1            1097                      58                          7
# 2             170                      23                          0
# 3             220                      24                          0
# 4             181                      21                          0
#
#    no_downregulated_genes_0.01
# 0                           63
# 1                           51
# 2                           23
# 3                           24
# 4                           21

# %%
gprofiler_sig_human_5 = pd.read_csv("data/human/gprofiler_sig_human_0.05.csv")
gprofiler_sig_human_5.rename(
    columns={
        "intersection_size": "intersection_size_0.05",
        "p_value": "p_value_0.05",
        "term_size": "term_size_0.05",
        "no_upregulated_genes": "no_upregulated_genes_0.05",
        "no_downregulated_genes": "no_downregulated_genes_0.05"
    },
    inplace=True,
)
gprofiler_sig_human_5 = gprofiler_sig_human_5.drop(columns=["parents"])
gprofiler_sig_human_5.head()
# Out:
#   source                  id  \
# 0  GO:BP          GO:0045333
# 1  GO:CC          GO:0005739
# 2   REAC  REAC:R-HSA-1428517
# 3  GO:BP          GO:0006091
# 4  GO:BP          GO:0015980
#
#                                                 name  p_value_0.05  \
# 0                               cellular respiration  4.655093e-17
# 1                                      mitochondrion  1.790872e-16
# 2  Aerobic respiration and respiratory electron t...  5.063851e-16
# 3     generation of precursor metabolites and energy  1.355359e-15
# 4  energy derivation by oxidation of organic comp...  8.888125e-15
#
#    term_size_0.05  intersection_size_0.05  no_upregulated_genes_0.05  \
# 0             220                      50                          2
# 1            1434                     145                         14
# 2             170                      42                          0
# 3             423                      68                          7
# 4             292                      54                          3
#
#    no_downregulated_genes_0.05
# 0                           48
# 1                          131
# 2                           42
# 3                           61
# 4                           51

# %%
gprofiler_sig_human = pd.merge(gprofiler_sig_human_1, gprofiler_sig_human_5, on=["source", "id", "name"], how="outer")
gprofiler_sig_human.head()
# Out:
#   source                  id  \
# 0  GO:CC          GO:0005739
# 1   KEGG          KEGG:01100
# 2   REAC  REAC:R-HSA-1428517
# 3  GO:BP          GO:0045333
# 4  GO:BP          GO:0009060
#
#                                                 name  p_value_0.01  \
# 0                                      mitochondrion  5.957169e-12
# 1                                 Metabolic pathways  1.486192e-11
# 2  Aerobic respiration and respiratory electron t...  3.919927e-11
# 3                               cellular respiration  6.969748e-09
# 4                                aerobic respiration  2.760689e-08
#
#    term_size_0.01  intersection_size_0.01  no_upregulated_genes_0.01  \
# 0          1434.0                    69.0                        6.0
# 1          1097.0                    58.0                        7.0
# 2           170.0                    23.0                        0.0
# 3           220.0                    24.0                        0.0
# 4           181.0                    21.0                        0.0
#
#    no_downregulated_genes_0.01  p_value_0.05  term_size_0.05  \
# 0                         63.0  1.790872e-16          1434.0
# 1                         51.0  7.790632e-14          1097.0
# 2                         23.0  5.063851e-16           170.0
# 3                         24.0  4.655093e-17           220.0
# 4                         21.0  4.666298e-14           181.0
#
#    intersection_size_0.05  no_upregulated_genes_0.05  \
# 0                   145.0                       14.0
# 1                   115.0                       16.0
# 2                    42.0                        0.0
# 3                    50.0                        2.0
# 4                    41.0                        2.0
#
#    no_downregulated_genes_0.05
# 0                        131.0
# 1                         99.0
# 2                         42.0
# 3                         48.0
# 4                         39.0

# %%
gprofiler_sig_human.to_csv("data/human/gprofiler_sig_human_0.05&0.01.csv", index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from pyBiodatafuse.constants import MITOCARTA

df_melted = mitocarta_human_selected.apply(
    lambda row: [row["ensembl_id"], [row.drop("ensembl_id").to_dict()]], axis=1
)
df_transformed = pd.DataFrame(df_melted.tolist(), columns=["ensembl_id", MITOCARTA])
df_transformed.head()
# Out:
#         ensembl_id                                          MitoCarta
# 0  ENSG00000179091  [{'gene_description': 'cytochrome c1', 'eviden...
# 1  ENSG00000117118  [{'gene_description': 'succinate dehydrogenase...
# 2  ENSG00000167186  [{'gene_description': 'coenzyme Q7, hydroxylas...
# 3  ENSG00000073578  [{'gene_description': 'succinate dehydrogenase...
# 4  ENSG00000010256  [{'gene_description': 'ubiquinol-cytochrome c ...

# %%
# Merge Human MitoCarta with the graph dataset
ncbi_tf_gprofiler_mitocarta_df_human = pd.merge(
    ncbi_tf_gprofiler_df_human,
    df_transformed,
    left_on="identifier",
    right_on="ensembl_id",
    how="left",
).drop(columns=["ensembl_id"])

ncbi_tf_gprofiler_mitocarta_df_human.head(67)
# Out:
#          identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0   ENSG00000000003           Ensembl   7105     NCBI Gene          TSPAN6
# 1   ENSG00000000419           Ensembl   8813     NCBI Gene            DPM1
# 2   ENSG00000000457           Ensembl  57147     NCBI Gene           SCYL3
# 3   ENSG00000000938           Ensembl   2268     NCBI Gene             FGR
# 4   ENSG00000000971           Ensembl   3075     NCBI Gene             CFH
# ..              ...               ...    ...           ...             ...
# 62  ENSG00000005073           Ensembl   3207     NCBI Gene          HOXA11
# 63  ENSG00000005075           Ensembl   5439     NCBI Gene          POLR2J
# 64  ENSG00000005100           Ensembl  56919     NCBI Gene           DHX33
# 65  ENSG00000005102           Ensembl   4222     NCBI Gene           MEOX1
# 66  ENSG00000005156           Ensembl   3980     NCBI Gene            LIG3
#
#     baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 0     106.899174           -0.401659   0.143909 -2.791057    0.005254  ...
# 1     601.924666           -0.104654   0.161936 -0.646270    0.518105  ...
# 2     244.623536           -0.285418   0.118343 -2.411784    0.015875  ...
# 3      91.958767            0.599304   0.342110  1.751786    0.079811  ...
# 4     499.583125            0.079448   0.255376  0.311101    0.755724  ...
# ..           ...                 ...        ...       ...         ...  ...
# 62    143.704857            0.301559   0.200188  1.506379    0.131970  ...
# 63   1204.040045           -0.133500   0.107618 -1.240503    0.214789  ...
# 64    256.137917            0.166654   0.146994  1.133746    0.256901  ...
# 65    329.566304           -0.395962   0.258980 -1.528929    0.126282  ...
# 66    407.870877            0.186800   0.119628  1.561504    0.118405  ...
#
#     g:Profiler_go:cc  g:Profiler_go:mf g:Profiler_hp g:Profiler_hpa  \
# 0                NaN               NaN           NaN            NaN
# 1                NaN               NaN           NaN            NaN
# 2                NaN               NaN           NaN            NaN
# 3                NaN               NaN           NaN            NaN
# 4                NaN               NaN           NaN            NaN
# ..               ...               ...           ...            ...
# 62               NaN               NaN           NaN            NaN
# 63               NaN               NaN           NaN            NaN
# 64               NaN               NaN           NaN            NaN
# 65               NaN               NaN           NaN            NaN
# 66               NaN               NaN           NaN            NaN
#
#    g:Profiler_kegg g:Profiler_mirna g:Profiler_reac g:Profiler_tf  \
# 0              NaN              NaN             NaN           NaN
# 1              NaN              NaN             NaN           NaN
# 2              NaN              NaN             NaN           NaN
# 3              NaN              NaN             NaN           NaN
# 4              NaN              NaN             NaN           NaN
# ..             ...              ...             ...           ...
# 62             NaN              NaN             NaN           NaN
# 63             NaN              NaN             NaN           NaN
# 64             NaN              NaN             NaN           NaN
# 65             NaN              NaN             NaN           NaN
# 66             NaN              NaN             NaN           NaN
#
#    g:Profiler_wp                                          MitoCarta
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# ..           ...                                                ...
# 62           NaN                                                NaN
# 63           NaN                                                NaN
# 64           NaN                                                NaN
# 65           NaN                                                NaN
# 66           NaN  [{'gene_description': 'DNA ligase 3', 'evidenc...
#
# [67 rows x 29 columns]

# %%
ncbi_tf_gprofiler_mitocarta_df_human[MITOCARTA][66]
# Out:
# [{'gene_description': 'DNA ligase 3',
#   'evidence': 'literature, targetP signal, mito protein domain, coexpression',
#   'sub_mito_localization': 'Matrix',
#   'mito_pathways': 'mtDNA repair',
#   'hpa_location': 'Nucleoplasm (Supported)',
#   'tissue_expression': nan}]

# %%
ncbi_tf_gprofiler_mitocarta_df_human["target.source"] = ncbi_tf_gprofiler_mitocarta_df_human[
    "target.source"
].str.replace("NCBI Gene", "ncbi_gene_id", regex=False)

ncbi_tf_gprofiler_mitocarta_df_human.head(1)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSG00000000003           Ensembl   7105  ncbi_gene_id          TSPAN6
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 0    106.899174           -0.401659   0.143909 -2.791057    0.005254  ...
#
#    g:Profiler_go:cc  g:Profiler_go:mf g:Profiler_hp g:Profiler_hpa  \
# 0               NaN               NaN           NaN            NaN
#
#   g:Profiler_kegg g:Profiler_mirna g:Profiler_reac g:Profiler_tf  \
# 0             NaN              NaN             NaN           NaN
#
#   g:Profiler_wp MitoCarta
# 0           NaN       NaN
#
# [1 rows x 29 columns]

# %%
ncbi_tf_gprofiler_mitocarta_df_human[MITOCARTA].to_dict()
# Out:
# {0: nan,
#  1: nan,
#  2: nan,
#  3: nan,
#  4: nan,
#  5: nan,
#  6: nan,
#  7: nan,
#  8: nan,
#  9: nan,
#  10: nan,
#  11: nan,
#  12: nan,
#  13: nan,
#  14: nan,
#  15: nan,
#  16: [{'gene_description': 'BCL2 associated agonist of cell death',
#    'evidence': 'literature, mito protein domain',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Apoptosis',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': nan}],
#  17: [{'gene_description': 'leucine aminopeptidase 3',
#    'evidence': 'APEX_matrix, targetP signal+, Rickettsial homolog, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Proteases',
#    'hpa_location': 'Cytosol (Supported)',
#    'tissue_expression': 'all 14'}],
#  18: nan,
#  19: nan,
#  20: nan,
#  21: nan,
#  22: nan,
#  23: nan,
#  24: nan,
#  25: nan,
#  26: nan,
#  27: nan,
#  28: nan,
#  29: nan,
#  30: nan,
#  31: nan,
#  32: [{'gene_description': 'NADH:ubiquinone oxidoreductase complex assembly factor 7',
#    'evidence': 'APEX_matrix, GFP, targetP signal, Rickettsial homolog, mito protein domain+, coexpression, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, brainstem, spinalcord, kidney, adipose, largeintestine, stomach, placenta, testis'}],
#  33: nan,
#  34: nan,
#  35: nan,
#  36: [{'gene_description': 'ADP ribosylation factor 5',
#    'evidence': 'targetP signal, mito protein domain, coexpression, MS/MS',
#    'sub_mito_localization': 'unknown',
#    'mito_pathways': nan,
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  37: nan,
#  38: [{'gene_description': 'DNA polymerase delta interacting protein 2',
#    'evidence': 'literature, APEX_matrix, targetP signal+, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mtDNA nucleoid',
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  39: nan,
#  40: [{'gene_description': 'adenylate kinase 2',
#    'evidence': 'literature, APEX_IMS, Rickettsial homolog, mito protein domain, coexpression+, MS/MS++',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': 'Nucleotide synthesis and processing',
#    'hpa_location': nan,
#    'tissue_expression': 'all 14'}],
#  41: nan,
#  42: nan,
#  43: nan,
#  44: nan,
#  45: nan,
#  46: nan,
#  47: nan,
#  48: nan,
#  49: nan,
#  50: [{'gene_description': 'NADH:ubiquinone oxidoreductase subunit AB1',
#    'evidence': 'literature, APEX_matrix, targetP signal+, yeast mito homolog, Rickettsial homolog, mito protein domain, MS/MS+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS subunits',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  51: [{'gene_description': 'pyruvate dehydrogenase kinase 4',
#    'evidence': 'literature, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain+, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Pyruvate metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, testis'}],
#  52: nan,
#  53: [{'gene_description': 'solute carrier family 25 member 13',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+, coexpression, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  54: nan,
#  55: nan,
#  56: nan,
#  57: [{'gene_description': 'holocytochrome c synthase',
#    'evidence': 'literature, APEX_IMS, yeast mito homolog++, mito protein domain+, induction, coexpression, MS/MS',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': 'Cytochrome C',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'cerebrum, spinalcord, heart, adipose, smallintestine, largeintestine, placenta, testis'}],
#  58: nan,
#  59: nan,
#  60: nan,
#  61: [{'gene_description': 'solute carrier family 25 member 5',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+, induction, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  62: nan,
#  63: nan,
#  64: nan,
#  65: nan,
#  66: [{'gene_description': 'DNA ligase 3',
#    'evidence': 'literature, targetP signal, mito protein domain, coexpression',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mtDNA repair',
#    'hpa_location': 'Nucleoplasm (Supported)',
#    'tissue_expression': nan}],
#  67: nan,
#  68: nan,
#  69: nan,
#  70: nan,
#  71: nan,
#  72: nan,
#  73: nan,
#  74: nan,
#  75: nan,
#  76: nan,
#  77: [{'gene_description': 'carnitine O-octanoyltransferase',
#    'evidence': 'yeast mito homolog+, mito protein domain, induction, coexpression, MS/MS',
#    'sub_mito_localization': 'unknown',
#    'mito_pathways': 'Fatty acid oxidation',
#    'hpa_location': 'Vesicles (Approved)',
#    'tissue_expression': 'kidney, liver'}],
#  78: nan,
#  79: nan,
#  80: nan,
#  81: nan,
#  82: nan,
#  83: nan,
#  84: nan,
#  85: nan,
#  86: [{'gene_description': 'pyruvate dehydrogenase kinase 2',
#    'evidence': 'literature, APEX_matrix, yeast mito homolog+, mito protein domain+, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Pyruvate metabolism',
#    'hpa_location': 'Mitochondria;Nucleoplasm (Supported)',
#    'tissue_expression': 'all 14'}],
#  87: nan,
#  88: nan,
#  89: nan,
#  90: nan,
#  91: nan,
#  92: nan,
#  93: nan,
#  94: nan,
#  95: nan,
#  96: nan,
#  97: nan,
#  98: nan,
#  99: nan,
#  100: nan,
#  101: [{'gene_description': 'spermatogenesis associated 20',
#    'evidence': 'APEX_matrix, targetP signal',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': nan,
#    'hpa_location': 'Nucleoplasm (Approved)',
#    'tissue_expression': 'testis'}],
#  102: nan,
#  103: nan,
#  104: nan,
#  105: nan,
#  106: nan,
#  107: nan,
#  108: nan,
#  109: nan,
#  110: nan,
#  111: nan,
#  112: nan,
#  113: nan,
#  114: [{'gene_description': 'cytochrome c oxidase assembly factor heme A:farnesyltransferase COX10',
#    'evidence': 'literature, yeast mito homolog, Rickettsial homolog, mito protein domain, induction, coexpression++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': nan}],
#  115: nan,
#  116: nan,
#  117: nan,
#  118: nan,
#  119: [{'gene_description': 'elaC ribonuclease Z 2',
#    'evidence': 'APEX_matrix, GFP, targetP signal, Rickettsial homolog, mito protein domain, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Polycistronic mtRNA processing',
#    'hpa_location': 'Nucleoplasm (Enhanced)',
#    'tissue_expression': 'cerebellum, skeletalmuscle, adipose, largeintestine, stomach'}],
#  120: nan,
#  121: nan,
#  122: nan,
#  123: nan,
#  124: nan,
#  125: nan,
#  126: nan,
#  127: nan,
#  128: nan,
#  129: nan,
#  130: nan,
#  131: nan,
#  132: nan,
#  133: nan,
#  134: nan,
#  135: nan,
#  136: nan,
#  137: nan,
#  138: nan,
#  139: nan,
#  140: nan,
#  141: [{'gene_description': 'DnaJ heat shock protein family (Hsp40) member C11',
#    'evidence': 'GFP, yeast mito homolog+, Rickettsial homolog, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Intramitochondrial membrane interactions',
#    'hpa_location': 'Cytosol (Approved)',
#    'tissue_expression': 'all 14'}],
#  142: nan,
#  143: nan,
#  144: nan,
#  145: nan,
#  146: nan,
#  147: nan,
#  148: nan,
#  149: nan,
#  150: nan,
#  151: nan,
#  152: nan,
#  153: nan,
#  154: [{'gene_description': 'aminoadipate-semialdehyde synthase',
#    'evidence': 'APEX_matrix, targetP signal, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Lysine metabolism',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, adipose, largeintestine, stomach, placenta, testis'}],
#  155: nan,
#  156: nan,
#  157: [{'gene_description': 'cryptochrome circadian regulator 1',
#    'evidence': 'literature, mito protein domain, coexpression',
#    'sub_mito_localization': 'unknown',
#    'mito_pathways': nan,
#    'hpa_location': 'Microtubules;Nuclear membrane;Nucleoplasm (Supported)',
#    'tissue_expression': nan}],
#  158: nan,
#  159: nan,
#  160: nan,
#  161: nan,
#  162: nan,
#  163: nan,
#  164: nan,
#  165: nan,
#  166: nan,
#  167: nan,
#  168: nan,
#  169: nan,
#  170: nan,
#  171: nan,
#  172: nan,
#  173: nan,
#  174: nan,
#  175: nan,
#  176: nan,
#  177: nan,
#  178: nan,
#  179: nan,
#  180: nan,
#  181: nan,
#  182: nan,
#  183: [{'gene_description': 'ubiquinol-cytochrome c reductase core protein 1',
#    'evidence': 'literature, APEX_matrix, targetP signal+, yeast mito homolog+, Rickettsial homolog, mito protein domain+, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS subunits',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  184: nan,
#  185: nan,
#  186: nan,
#  187: nan,
#  188: nan,
#  189: nan,
#  190: nan,
#  191: nan,
#  192: nan,
#  193: nan,
#  194: nan,
#  195: nan,
#  196: nan,
#  197: nan,
#  198: nan,
#  199: nan,
#  200: nan,
#  201: nan,
#  202: nan,
#  203: nan,
#  204: nan,
#  205: nan,
#  206: nan,
#  207: nan,
#  208: nan,
#  209: nan,
#  210: nan,
#  211: nan,
#  212: nan,
#  213: nan,
#  214: nan,
#  215: nan,
#  216: [{'gene_description': 'tetratricopeptide repeat domain 19',
#    'evidence': 'literature, APEX_IMS, targetP signal+, mito protein domain, induction, MS/MS+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'cerebrum, cerebellum, spinalcord, adipose, largeintestine, stomach, testis'}],
#  217: nan,
#  218: nan,
#  219: [{'gene_description': 'leucyl-tRNA synthetase 2, mitochondrial',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-tRNA synthetases',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  220: nan,
#  221: nan,
#  222: nan,
#  223: nan,
#  224: nan,
#  225: nan,
#  226: nan,
#  227: nan,
#  228: nan,
#  229: nan,
#  230: nan,
#  231: nan,
#  232: nan,
#  233: nan,
#  234: nan,
#  235: nan,
#  236: nan,
#  237: nan,
#  238: nan,
#  239: nan,
#  240: nan,
#  241: nan,
#  242: nan,
#  243: [{'gene_description': 'solute carrier family 25 member 39',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+, induction, coexpression',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': nan,
#    'tissue_expression': nan}],
#  244: nan,
#  245: nan,
#  246: nan,
#  247: nan,
#  248: nan,
#  249: nan,
#  250: nan,
#  251: nan,
#  252: nan,
#  253: nan,
#  254: [{'gene_description': 'heme binding protein 1',
#    'evidence': 'APEX_IMS, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': nan,
#    'hpa_location': 'Vesicles (Approved)',
#    'tissue_expression': 'cerebrum, cerebellum, liver, adipose, placenta'}],
#  255: nan,
#  256: nan,
#  257: nan,
#  258: nan,
#  259: nan,
#  260: nan,
#  261: nan,
#  262: [{'gene_description': 'solute carrier family 30 member 9',
#    'evidence': 'APEX_matrix, targetP signal+, yeast mito homolog++, mito protein domain, induction, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Small molecule transport',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, adipose, largeintestine, stomach, placenta, testis'}],
#  263: nan,
#  264: [{'gene_description': 'cytochrome c oxidase assembly homolog COX15',
#    'evidence': 'literature, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain+, coexpression++, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, brainstem, spinalcord, kidney, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  265: nan,
#  266: nan,
#  267: nan,
#  268: [{'gene_description': 'BH3 interacting domain death agonist',
#    'evidence': 'literature, targetP signal+, mito protein domain, coexpression',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Apoptosis',
#    'hpa_location': 'Cytosol (Supported)',
#    'tissue_expression': nan}],
#  269: nan,
#  270: nan,
#  271: nan,
#  272: nan,
#  273: [{'gene_description': 'choline dehydrogenase',
#    'evidence': 'APEX_matrix, targetP signal+, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Q-linked reactions, other',
#    'hpa_location': nan,
#    'tissue_expression': 'spinalcord, kidney, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  274: nan,
#  275: nan,
#  276: nan,
#  277: nan,
#  278: nan,
#  279: nan,
#  280: nan,
#  281: nan,
#  282: nan,
#  283: nan,
#  284: nan,
#  285: nan,
#  286: nan,
#  287: nan,
#  288: nan,
#  289: nan,
#  290: nan,
#  291: nan,
#  292: nan,
#  293: nan,
#  294: nan,
#  295: nan,
#  296: nan,
#  297: nan,
#  298: nan,
#  299: nan,
#  300: nan,
#  301: nan,
#  302: nan,
#  303: nan,
#  304: nan,
#  305: nan,
#  306: nan,
#  307: nan,
#  308: nan,
#  309: nan,
#  310: nan,
#  311: [{'gene_description': "5'-aminolevulinate synthase 1",
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog+, Rickettsial homolog, mito protein domain+, induction, coexpression, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Heme synthesis and processing',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'liver, heart, adipose, largeintestine, placenta'}],
#  312: nan,
#  313: nan,
#  314: [{'gene_description': 'glutaredoxin 2',
#    'evidence': 'literature, targetP signal+, yeast mito homolog, Rickettsial homolog, mito protein domain, coexpression, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'ROS and glutathione metabolism',
#    'hpa_location': 'Nucleoplasm (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, skeletalmuscle, largeintestine, placenta, testis'}],
#  315: nan,
#  316: nan,
#  317: nan,
#  318: nan,
#  319: nan,
#  320: nan,
#  321: nan,
#  322: nan,
#  323: nan,
#  324: nan,
#  325: nan,
#  326: nan,
#  327: nan,
#  328: nan,
#  329: [{'gene_description': 'translocase of outer mitochondrial membrane 34',
#    'evidence': 'literature, mito protein domain',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'TOM',
#    'hpa_location': nan,
#    'tissue_expression': 'testis'}],
#  330: nan,
#  331: nan,
#  332: nan,
#  333: nan,
#  334: nan,
#  335: nan,
#  336: [{'gene_description': '1-acylglycerol-3-phosphate O-acyltransferase 4',
#    'evidence': 'literature, mito protein domain, induction',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Phospholipid metabolism',
#    'hpa_location': 'Golgi apparatus (Approved)',
#    'tissue_expression': 'testis'}],
#  337: nan,
#  338: [{'gene_description': 'mitochondrial intermediate peptidase',
#    'evidence': 'literature, APEX_matrix, targetP signal+, yeast mito homolog++, mito protein domain, induction, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Proteases',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'cerebrum, spinalcord, kidney, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  339: nan,
#  340: nan,
#  341: nan,
#  342: nan,
#  343: nan,
#  344: nan,
#  345: nan,
#  346: nan,
#  347: nan,
#  348: nan,
#  349: nan,
#  350: nan,
#  351: [{'gene_description': 'transcription factor B1, mitochondrial',
#    'evidence': 'literature, APEX_matrix, Rickettsial homolog, mito protein domain, MS/MS+',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome assembly',
#    'hpa_location': nan,
#    'tissue_expression': 'brainstem, largeintestine, placenta, testis'}],
#  352: nan,
#  353: nan,
#  354: nan,
#  355: [{'gene_description': 'BCL2 antagonist/killer 1',
#    'evidence': 'literature, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Apoptosis',
#    'hpa_location': nan,
#    'tissue_expression': 'brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  356: nan,
#  357: nan,
#  358: nan,
#  359: nan,
#  360: nan,
#  361: nan,
#  362: nan,
#  363: nan,
#  364: nan,
#  365: nan,
#  366: nan,
#  367: nan,
#  368: nan,
#  369: nan,
#  370: nan,
#  371: nan,
#  372: nan,
#  373: nan,
#  374: nan,
#  375: nan,
#  376: nan,
#  377: nan,
#  378: nan,
#  379: nan,
#  380: nan,
#  381: nan,
#  382: nan,
#  383: nan,
#  384: nan,
#  385: nan,
#  386: [{'gene_description': 'family with sequence similarity 136 member A',
#    'evidence': 'APEX_IMS, mito protein domain+, MS/MS++',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': nan,
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  387: nan,
#  388: nan,
#  389: nan,
#  390: nan,
#  391: nan,
#  392: nan,
#  393: nan,
#  394: nan,
#  395: nan,
#  396: nan,
#  397: nan,
#  398: nan,
#  399: nan,
#  400: nan,
#  401: [{'gene_description': 'NOP2/Sun RNA methyltransferase 2',
#    'evidence': 'literature, mito protein domain',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-tRNA modifications',
#    'hpa_location': 'Nucleoplasm (Approved)',
#    'tissue_expression': nan}],
#  402: nan,
#  403: nan,
#  404: nan,
#  405: nan,
#  406: nan,
#  407: nan,
#  408: nan,
#  409: nan,
#  410: nan,
#  411: nan,
#  412: nan,
#  413: nan,
#  414: nan,
#  415: nan,
#  416: nan,
#  417: nan,
#  418: nan,
#  419: nan,
#  420: nan,
#  421: nan,
#  422: nan,
#  423: nan,
#  424: nan,
#  425: nan,
#  426: nan,
#  427: nan,
#  428: nan,
#  429: nan,
#  430: nan,
#  431: nan,
#  432: nan,
#  433: nan,
#  434: [{'gene_description': 'apoptosis inducing factor mitochondria associated 2',
#    'evidence': 'literature, Rickettsial homolog, mito protein domain, coexpression',
#    'sub_mito_localization': 'Membrane',
#    'mito_pathways': 'Apoptosis',
#    'hpa_location': 'Vesicles (Supported)',
#    'tissue_expression': nan}],
#  435: nan,
#  436: nan,
#  437: nan,
#  438: nan,
#  439: nan,
#  440: nan,
#  441: nan,
#  442: nan,
#  443: [{'gene_description': 'tRNA isopentenyltransferase 1',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog, Rickettsial homolog, mito protein domain, coexpression',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-rRNA modifications',
#    'hpa_location': 'Nucleoplasm (Approved)',
#    'tissue_expression': 'cerebellum'}],
#  444: nan,
#  445: nan,
#  446: nan,
#  447: nan,
#  448: nan,
#  449: nan,
#  450: nan,
#  451: nan,
#  452: nan,
#  453: nan,
#  454: nan,
#  455: nan,
#  456: nan,
#  457: nan,
#  458: nan,
#  459: nan,
#  460: nan,
#  461: nan,
#  462: nan,
#  463: nan,
#  464: nan,
#  465: nan,
#  466: nan,
#  467: nan,
#  468: nan,
#  469: nan,
#  470: nan,
#  471: nan,
#  472: nan,
#  473: nan,
#  474: nan,
#  475: nan,
#  476: nan,
#  477: nan,
#  478: nan,
#  479: [{'gene_description': 'mitochondrial ribosomal protein S10',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  480: nan,
#  481: [{'gene_description': 'vacuolar protein sorting 13 homolog D',
#    'evidence': 'manual, mito protein domain, induction, coexpression',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Autophagy',
#    'hpa_location': 'Nucleoplasm;Vesicles (Approved)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, skeletalmuscle'}],
#  482: nan,
#  483: nan,
#  484: nan,
#  485: nan,
#  486: nan,
#  487: nan,
#  488: nan,
#  489: nan,
#  490: nan,
#  491: nan,
#  492: nan,
#  493: nan,
#  494: nan,
#  495: nan,
#  496: nan,
#  497: nan,
#  498: nan,
#  499: [{'gene_description': 'pentatricopeptide repeat domain 2',
#    'evidence': 'literature, mito protein domain+, induction, coexpression, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Polycistronic mtRNA processing',
#    'hpa_location': nan,
#    'tissue_expression': 'smallintestine, largeintestine, placenta'}],
#  500: nan,
#  501: nan,
#  502: nan,
#  503: [{'gene_description': 'mitochondrial calcium uniporter regulator 1',
#    'evidence': 'APEX_matrix, yeast mito homolog+, mito protein domain+, induction, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': nan,
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta'}],
#  504: nan,
#  505: [{'gene_description': 'LETM1 domain containing 1',
#    'evidence': 'GFP, targetP signal+, yeast mito homolog+, mito protein domain+, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'Membrane',
#    'mito_pathways': 'Small molecule transport',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, adipose, smallintestine, largeintestine, placenta, testis'}],
#  506: nan,
#  507: nan,
#  508: nan,
#  509: nan,
#  510: nan,
#  511: nan,
#  512: nan,
#  513: nan,
#  514: nan,
#  515: nan,
#  516: nan,
#  517: nan,
#  518: nan,
#  519: nan,
#  520: nan,
#  521: nan,
#  522: nan,
#  523: [{'gene_description': 'aldo-keto reductase family 7 member A2',
#    'evidence': 'APEX_matrix, targetP signal, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Xenobiotic metabolism',
#    'hpa_location': 'Cytosol (Supported)',
#    'tissue_expression': 'all 14'}],
#  524: nan,
#  525: nan,
#  526: nan,
#  527: nan,
#  528: nan,
#  529: nan,
#  530: nan,
#  531: nan,
#  532: nan,
#  533: nan,
#  534: nan,
#  535: nan,
#  536: nan,
#  537: nan,
#  538: nan,
#  539: nan,
#  540: nan,
#  541: nan,
#  542: nan,
#  543: nan,
#  544: nan,
#  545: nan,
#  546: nan,
#  547: nan,
#  548: nan,
#  549: nan,
#  550: nan,
#  551: nan,
#  552: nan,
#  553: nan,
#  554: nan,
#  555: nan,
#  556: nan,
#  557: nan,
#  558: nan,
#  559: [{'gene_description': 'mitochondrial ribosomal protein L43',
#    'evidence': 'literature, targetP signal+, yeast mito homolog++, mito protein domain, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': 'Mitochondria;Nucleoplasm (Approved)',
#    'tissue_expression': 'all 14'}],
#  560: nan,
#  561: nan,
#  562: nan,
#  563: nan,
#  564: nan,
#  565: nan,
#  566: nan,
#  567: nan,
#  568: nan,
#  569: nan,
#  570: nan,
#  571: nan,
#  572: nan,
#  573: nan,
#  574: nan,
#  575: nan,
#  576: nan,
#  577: nan,
#  578: nan,
#  579: nan,
#  580: nan,
#  581: nan,
#  582: nan,
#  583: nan,
#  584: nan,
#  585: nan,
#  586: nan,
#  587: nan,
#  588: nan,
#  589: nan,
#  590: nan,
#  591: nan,
#  592: [{'gene_description': 'aldehyde dehydrogenase 18 family member A1',
#    'evidence': 'literature, Rickettsial homolog, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Proline metabolism',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  593: nan,
#  594: [{'gene_description': 'glutamyl-tRNA amidotransferase subunit B',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog, Rickettsial homolog, mito protein domain+, coexpression+, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-tRNA synthetases',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, skeletalmuscle, adipose, stomach, testis'}],
#  595: nan,
#  596: nan,
#  597: nan,
#  598: nan,
#  599: nan,
#  600: nan,
#  601: nan,
#  602: nan,
#  603: nan,
#  604: nan,
#  605: nan,
#  606: nan,
#  607: nan,
#  608: [{'gene_description': 'mitochondrial pyruvate carrier 1',
#    'evidence': 'GFP, yeast mito homolog+, mito protein domain+, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'TCA-associated',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'all 14'}],
#  609: [{'gene_description': 'acetyl-CoA acyltransferase 1',
#    'evidence': 'yeast mito homolog++, Rickettsial homolog, mito protein domain, coexpression',
#    'sub_mito_localization': 'unknown',
#    'mito_pathways': 'Lipid metabolism',
#    'hpa_location': 'Peroxisomes (Enhanced)',
#    'tissue_expression': 'kidney, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  610: nan,
#  611: nan,
#  612: nan,
#  613: [{'gene_description': 'mitochondrial ribosomal protein S35',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog++, mito protein domain+, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  614: nan,
#  615: nan,
#  616: nan,
#  617: nan,
#  618: nan,
#  619: nan,
#  620: nan,
#  621: [{'gene_description': 'citrate synthase',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'TCA cycle',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'all 14'}],
#  622: [{'gene_description': 'mitochondrial ribosomal protein S24',
#    'evidence': 'literature, APEX_matrix, induction, coexpression++, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  623: nan,
#  624: nan,
#  625: nan,
#  626: nan,
#  627: nan,
#  628: nan,
#  629: nan,
#  630: [{'gene_description': 'sphingosine kinase 2',
#    'evidence': 'literature, mito protein domain',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Apoptosis',
#    'hpa_location': 'Vesicles (Supported)',
#    'tissue_expression': nan}],
#  631: nan,
#  632: nan,
#  633: [{'gene_description': 'isochorismatase domain containing 2',
#    'evidence': 'APEX_matrix, targetP signal, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': nan,
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  634: nan,
#  635: nan,
#  636: nan,
#  637: nan,
#  638: nan,
#  639: nan,
#  640: nan,
#  641: [{'gene_description': 'aarF domain containing kinase 1',
#    'evidence': 'yeast mito homolog+, Rickettsial homolog, mito protein domain, MS/MS',
#    'sub_mito_localization': 'unknown',
#    'mito_pathways': nan,
#    'hpa_location': 'Nucleoplasm (Approved)',
#    'tissue_expression': 'cerebrum, spinalcord, kidney, heart, skeletalmuscle, adipose, stomach, placenta'}],
#  642: [{'gene_description': 'hydroxyacylglutathione hydrolase',
#    'evidence': 'literature, APEX_matrix, targetP signal+, mito protein domain, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'ROS and glutathione metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  643: nan,
#  644: [{'gene_description': 'caspase 8',
#    'evidence': 'literature, mito protein domain',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Apoptosis',
#    'hpa_location': 'Cytosol (Supported)',
#    'tissue_expression': nan}],
#  645: nan,
#  646: nan,
#  647: nan,
#  648: nan,
#  649: nan,
#  650: nan,
#  651: nan,
#  652: nan,
#  653: nan,
#  654: nan,
#  655: nan,
#  656: nan,
#  657: nan,
#  658: nan,
#  659: nan,
#  660: nan,
#  661: nan,
#  662: nan,
#  663: nan,
#  664: nan,
#  665: nan,
#  666: nan,
#  667: nan,
#  668: nan,
#  669: nan,
#  670: nan,
#  671: nan,
#  672: nan,
#  673: nan,
#  674: [{'gene_description': 'nth like DNA glycosylase 1',
#    'evidence': 'literature, yeast mito homolog, Rickettsial homolog, mito protein domain',
#    'sub_mito_localization': 'unknown',
#    'mito_pathways': 'Fe-S-containing proteins',
#    'hpa_location': nan,
#    'tissue_expression': nan}],
#  675: nan,
#  676: nan,
#  677: nan,
#  678: [{'gene_description': 'ornithine aminotransferase',
#    'evidence': 'literature, APEX_matrix, targetP signal+, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Proline metabolism',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  679: nan,
#  680: nan,
#  681: nan,
#  682: nan,
#  683: nan,
#  684: nan,
#  685: nan,
#  686: [{'gene_description': 'lysyl-tRNA synthetase 1',
#    'evidence': 'literature, GFP, targetP signal, Rickettsial homolog, mito protein domain, coexpression',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-tRNA synthetases',
#    'hpa_location': 'Cytosol (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, skeletalmuscle, adipose, largeintestine, stomach, placenta, testis'}],
#  687: nan,
#  688: nan,
#  689: nan,
#  690: [{'gene_description': 'NADH:ubiquinone oxidoreductase subunit B4',
#    'evidence': 'literature, mito protein domain+, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS subunits',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  691: nan,
#  692: nan,
#  693: nan,
#  694: nan,
#  695: nan,
#  696: nan,
#  697: nan,
#  698: nan,
#  699: nan,
#  700: nan,
#  701: nan,
#  702: nan,
#  703: nan,
#  704: nan,
#  705: nan,
#  706: [{'gene_description': 'methylenetetrahydrofolate dehydrogenase (NADP+ dependent) 2, methenyltetrahydrofolate cyclohydrolase',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog+, Rickettsial homolog, mito protein domain, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Folate and 1-C metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'spinalcord, placenta, testis'}],
#  707: nan,
#  708: nan,
#  709: nan,
#  710: nan,
#  711: nan,
#  712: nan,
#  713: nan,
#  714: nan,
#  715: nan,
#  716: nan,
#  717: nan,
#  718: nan,
#  719: nan,
#  720: nan,
#  721: nan,
#  722: nan,
#  723: nan,
#  724: nan,
#  725: nan,
#  726: nan,
#  727: nan,
#  728: nan,
#  729: nan,
#  730: nan,
#  731: nan,
#  732: nan,
#  733: nan,
#  734: nan,
#  735: nan,
#  736: nan,
#  737: [{'gene_description': 'mitochondrial fission regulator 1',
#    'evidence': 'literature, targetP signal, mito protein domain+, coexpression',
#    'sub_mito_localization': 'Membrane',
#    'mito_pathways': 'Fission',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': nan}],
#  738: nan,
#  739: [{'gene_description': 'ferrochelatase',
#    'evidence': 'literature, APEX_matrix, targetP signal+, yeast mito homolog++, Rickettsial homolog, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Fe-S-containing proteins',
#    'hpa_location': nan,
#    'tissue_expression': 'all 14'}],
#  740: nan,
#  741: nan,
#  742: [{'gene_description': 'isopentenyl-diphosphate delta isomerase 1',
#    'evidence': 'targetP signal, mito protein domain, MS/MS+',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Cholesterol-associated',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  743: nan,
#  744: nan,
#  745: nan,
#  746: nan,
#  747: nan,
#  748: nan,
#  749: nan,
#  750: nan,
#  751: nan,
#  752: nan,
#  753: nan,
#  754: nan,
#  755: nan,
#  756: nan,
#  757: nan,
#  758: nan,
#  759: nan,
#  760: nan,
#  761: nan,
#  762: [{'gene_description': 'isoleucyl-tRNA synthetase 2, mitochondrial',
#    'evidence': 'APEX_matrix, targetP signal+, yeast mito homolog++, Rickettsial homolog, mito protein domain, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-tRNA synthetases',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'all 14'}],
#  763: [{'gene_description': 'isocitrate dehydrogenase (NAD(+)) 3 non-catalytic subunit gamma',
#    'evidence': 'literature, APEX_matrix, yeast mito homolog+, Rickettsial homolog, mito protein domain, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'TCA cycle',
#    'hpa_location': 'Mitochondria;Nucleoli (Approved)',
#    'tissue_expression': 'all 14'}],
#  764: nan,
#  765: nan,
#  766: nan,
#  767: nan,
#  768: [{'gene_description': 'pyruvate dehydrogenase kinase 3',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog+, mito protein domain+, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Pyruvate metabolism',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  769: nan,
#  770: nan,
#  771: nan,
#  772: nan,
#  773: nan,
#  774: [{'gene_description': 'Coenzyme A synthase',
#    'evidence': 'APEX_matrix, targetP signal, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Coenzyme A metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  775: nan,
#  776: nan,
#  777: nan,
#  778: nan,
#  779: nan,
#  780: nan,
#  781: nan,
#  782: nan,
#  783: nan,
#  784: nan,
#  785: nan,
#  786: nan,
#  787: nan,
#  788: nan,
#  789: nan,
#  790: nan,
#  791: nan,
#  792: nan,
#  793: nan,
#  794: nan,
#  795: nan,
#  796: nan,
#  797: nan,
#  798: nan,
#  799: nan,
#  800: nan,
#  801: nan,
#  802: nan,
#  803: nan,
#  804: nan,
#  805: nan,
#  806: nan,
#  807: nan,
#  808: nan,
#  809: nan,
#  810: nan,
#  811: [{'gene_description': 'FUN14 domain containing 1',
#    'evidence': 'yeast mito homolog, mito protein domain+, MS/MS',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Autophagy',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, skeletalmuscle, adipose, largeintestine, stomach, testis'}],
#  812: [{'gene_description': 'monoamine oxidase B',
#    'evidence': 'literature, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Xenobiotic metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  813: nan,
#  814: nan,
#  815: nan,
#  816: nan,
#  817: nan,
#  818: nan,
#  819: nan,
#  820: [{'gene_description': 'haloacid dehalogenase like hydrolase domain containing 5',
#    'evidence': 'APEX_matrix, targetP signal, yeast mito homolog, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': nan,
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'cerebellum, kidney, liver, skeletalmuscle, adipose, largeintestine, stomach, placenta, testis'}],
#  821: nan,
#  822: nan,
#  823: nan,
#  824: nan,
#  825: nan,
#  826: nan,
#  827: nan,
#  828: nan,
#  829: nan,
#  830: nan,
#  831: nan,
#  832: nan,
#  833: nan,
#  834: nan,
#  835: nan,
#  836: nan,
#  837: nan,
#  838: nan,
#  839: nan,
#  840: [{'gene_description': 'DNA polymerase beta',
#    'evidence': 'literature',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mtDNA repair',
#    'hpa_location': 'Vesicles (Uncertain)',
#    'tissue_expression': nan}],
#  841: nan,
#  842: nan,
#  843: nan,
#  844: nan,
#  845: nan,
#  846: nan,
#  847: nan,
#  848: nan,
#  849: nan,
#  850: nan,
#  851: nan,
#  852: nan,
#  853: nan,
#  854: nan,
#  855: nan,
#  856: nan,
#  857: nan,
#  858: nan,
#  859: nan,
#  860: nan,
#  861: nan,
#  862: nan,
#  863: nan,
#  864: nan,
#  865: nan,
#  866: nan,
#  867: nan,
#  868: nan,
#  869: nan,
#  870: nan,
#  871: nan,
#  872: nan,
#  873: nan,
#  874: nan,
#  875: nan,
#  876: nan,
#  877: nan,
#  878: nan,
#  879: nan,
#  880: nan,
#  881: nan,
#  882: nan,
#  883: nan,
#  884: nan,
#  885: nan,
#  886: nan,
#  887: nan,
#  888: nan,
#  889: nan,
#  890: nan,
#  891: nan,
#  892: nan,
#  893: nan,
#  894: [{'gene_description': 'aldehyde dehydrogenase 3 family member A2',
#    'evidence': 'targetP signal+, mito protein domain, coexpression',
#    'sub_mito_localization': 'Membrane',
#    'mito_pathways': 'ROS and glutathione metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'spinalcord, kidney, liver, smallintestine, largeintestine, stomach, placenta, testis'}],
#  895: nan,
#  896: nan,
#  897: nan,
#  898: nan,
#  899: nan,
#  900: nan,
#  901: nan,
#  902: [{'gene_description': 'hydroxysteroid 17-beta dehydrogenase 10',
#    'evidence': 'literature, APEX_matrix, Rickettsial homolog, mito protein domain, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Branched-chain amino acid metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'all 14'}],
#  903: nan,
#  904: nan,
#  905: nan,
#  906: nan,
#  907: nan,
#  908: [{'gene_description': 'tRNA nucleotidyl transferase 1',
#    'evidence': 'literature, targetP signal, yeast mito homolog, Rickettsial homolog, mito protein domain, induction, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-tRNA modifications',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'spinalcord, adipose, placenta, testis'}],
#  909: [{'gene_description': 'acyl-CoA dehydrogenase very long chain',
#    'evidence': 'literature, APEX_matrix, targetP signal+, mito protein domain+, coexpression+, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Fatty acid oxidation',
#    'hpa_location': 'Mitochondria;Nucleoli (Supported)',
#    'tissue_expression': 'all 14'}],
#  910: nan,
#  911: nan,
#  912: nan,
#  913: nan,
#  914: nan,
#  915: nan,
#  916: nan,
#  917: nan,
#  918: nan,
#  919: nan,
#  920: nan,
#  921: nan,
#  922: [{'gene_description': 'selenoprotein O',
#    'evidence': 'targetP signal+, yeast mito homolog, mito protein domain+, coexpression',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Selenoproteins',
#    'hpa_location': nan,
#    'tissue_expression': 'spinalcord, liver, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  923: nan,
#  924: nan,
#  925: nan,
#  926: nan,
#  927: nan,
#  928: [{'gene_description': 'succinate dehydrogenase complex flavoprotein subunit A',
#    'evidence': 'literature, APEX_matrix, targetP signal+, yeast mito homolog++, Rickettsial homolog, mito protein domain, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS subunits',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  929: nan,
#  930: nan,
#  931: nan,
#  932: nan,
#  933: nan,
#  934: nan,
#  935: nan,
#  936: nan,
#  937: nan,
#  938: nan,
#  939: nan,
#  940: nan,
#  941: nan,
#  942: [{'gene_description': 'mitochondrial ribosomal protein S34',
#    'evidence': 'literature, APEX_matrix, targetP signal, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  943: nan,
#  944: nan,
#  945: nan,
#  946: nan,
#  947: nan,
#  948: nan,
#  949: nan,
#  950: nan,
#  951: nan,
#  952: [{'gene_description': 'BCS1 homolog, ubiquinol-cytochrome c reductase complex chaperone',
#    'evidence': 'literature, APEX_matrix, yeast mito homolog++, Rickettsial homolog, mito protein domain+, coexpression+, MS/MS+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  953: nan,
#  954: nan,
#  955: nan,
#  956: nan,
#  957: nan,
#  958: nan,
#  959: nan,
#  960: nan,
#  961: nan,
#  962: nan,
#  963: nan,
#  964: nan,
#  965: nan,
#  966: nan,
#  967: nan,
#  968: nan,
#  969: nan,
#  970: nan,
#  971: nan,
#  972: [{'gene_description': 'acetyl-CoA acetyltransferase 1',
#    'evidence': 'literature, APEX_matrix, targetP signal+, Rickettsial homolog, mito protein domain, induction, coexpression+, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Lysine metabolism',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'all 14'}],
#  973: nan,
#  974: nan,
#  975: [{'gene_description': 'solute carrier family 25 member 40',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, adipose, largeintestine, stomach, placenta, testis'}],
#  976: [{'gene_description': 'translocase of inner mitochondrial membrane 21',
#    'evidence': 'APEX_IMS, GFP, yeast mito homolog++, mito protein domain+, coexpression, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, largeintestine, stomach, placenta, testis'}],
#  977: nan,
#  978: nan,
#  979: nan,
#  980: nan,
#  981: [{'gene_description': 'solute carrier family 25 member 3',
#    'evidence': 'literature, yeast mito homolog++, mito protein domain+, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  982: nan,
#  983: nan,
#  984: nan,
#  985: nan,
#  986: nan,
#  987: nan,
#  988: nan,
#  989: nan,
#  990: nan,
#  991: nan,
#  992: nan,
#  993: nan,
#  994: nan,
#  995: nan,
#  996: nan,
#  997: nan,
#  998: nan,
#  999: [{'gene_description': 'RNA exonuclease 2',
#    'evidence': 'APEX_matrix, targetP signal, yeast mito homolog++, mito protein domain, MS/MS+',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mtRNA stability and decay',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  ...}

# %%
# ncbi_tf_gprofiler_mitocarta_df_human["its_target"][ncbi_tf_gprofiler_mitocarta_df_human["its_target"].notna()]
ncbi_tf_gprofiler_mitocarta_df_human["its_target"][7]
# Out:
# [{'NCBI.GeneID.Target': '1647',
#   'Ensembl.GeneID.Target': 'ENSG00000116717',
#   'Name.Target': 'GADD45A',
#   'UniprotID.Target': 'P24522',
#   'Target.TFLink.ortho': 'Dr:Q6GMM1;Mm:P48316;Rn:Q66HL6',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#   'PubmedID': '29126285;11525640;11420680;27924024;29087512',
#   'Source.database': 'GTRD;ReMap;TRRUST',
#   'Small-scale.evidence': 'Yes'},
#  {'NCBI.GeneID.Target': '84271',
#   'Ensembl.GeneID.Target': 'ENSG00000100227',
#   'Name.Target': 'POLDIP3',
#   'UniprotID.Target': 'Q9BY77',
#   'Target.TFLink.ortho': 'Mm:Q8BG81;Rn:D4A2B0',
#   'Target.nonTFLink.ortho': 'Dr:A0A0R4ILC0',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '54842',
#   'Ensembl.GeneID.Target': 'ENSG00000151690',
#   'Name.Target': 'MFSD6',
#   'UniprotID.Target': 'Q6ZSS7',
#   'Target.TFLink.ortho': 'Ce:Q95Y88;Dm:A1Z9U2;Rn:D3ZCJ3',
#   'Target.nonTFLink.ortho': 'Mm:D3Z183',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '389203',
#   'Ensembl.GeneID.Target': 'ENSG00000250317',
#   'Name.Target': 'SMIM20',
#   'UniprotID.Target': 'Q8N5G0',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4043',
#   'Ensembl.GeneID.Target': 'ENSG00000163956',
#   'Name.Target': 'LRPAP1',
#   'UniprotID.Target': 'P30533',
#   'Target.TFLink.ortho': 'Ce:G5EF26;Dm:Q9VH64;Dr:A2BGU5;Mm:P55302;Rn:Q99068',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5188',
#   'Ensembl.GeneID.Target': 'ENSG00000059691',
#   'Name.Target': 'GATB',
#   'UniprotID.Target': 'O75879',
#   'Target.TFLink.ortho': 'Dm:Q9VCD0;Mm:Q99JT1;Rn:M0R4L6;Sc:P33893',
#   'Target.nonTFLink.ortho': 'Dr:Q7T010',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4836',
#   'Ensembl.GeneID.Target': 'ENSG00000136448',
#   'Name.Target': 'NMT1',
#   'UniprotID.Target': 'P30419',
#   'Target.TFLink.ortho': 'Dr:F1QY00;Mm:O70310;Rn:Q8K1Q0',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51655',
#   'Ensembl.GeneID.Target': 'ENSG00000108551',
#   'Name.Target': 'RASD1',
#   'UniprotID.Target': 'Q9Y272',
#   'Target.TFLink.ortho': 'Dr:Q6PHV8;Mm:O35626;Rn:Q9JKF8',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '28231',
#   'Ensembl.GeneID.Target': 'ENSG00000101187',
#   'Name.Target': 'SLCO4A1',
#   'UniprotID.Target': 'Q96BD0',
#   'Target.TFLink.ortho': 'Ce:Q9XWC5;Ce:X5LPS1;Dm:Q8SY02;Dr:E7FFX7;Mm:Q8K078;Rn:Q4V8N6',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '757',
#   'Ensembl.GeneID.Target': 'ENSG00000142188',
#   'Name.Target': 'TMEM50B',
#   'UniprotID.Target': 'P56557',
#   'Target.TFLink.ortho': 'Dm:Q9VZE2;Mm:Q9D1X9;Rn:Q5BJS6',
#   'Target.nonTFLink.ortho': 'Ce:Q9N2X7',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '9927',
#   'Ensembl.GeneID.Target': 'ENSG00000116688',
#   'Name.Target': 'MFN2',
#   'UniprotID.Target': 'O95140',
#   'Target.TFLink.ortho': 'Dr:A8WIN6;Mm:Q80U63',
#   'Target.nonTFLink.ortho': 'Rn:F7FHF7',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8869',
#   'Ensembl.GeneID.Target': 'ENSG00000115525',
#   'Name.Target': 'ST3GAL5',
#   'UniprotID.Target': 'Q9UNP4',
#   'Target.TFLink.ortho': 'Rn:Q68G12',
#   'Target.nonTFLink.ortho': 'Dr:F1RCA6;Mm:A0A0U1RNK2',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '123803',
#   'Ensembl.GeneID.Target': 'ENSG00000157045',
#   'Name.Target': 'NTAN1',
#   'UniprotID.Target': 'Q96AB6',
#   'Target.TFLink.ortho': 'Dm:Q7KIS4;Mm:Q64311;Rn:A0A0G2JWG0',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '54793',
#   'Ensembl.GeneID.Target': 'ENSG00000104756',
#   'Name.Target': 'KCTD9',
#   'UniprotID.Target': 'Q7L273',
#   'Target.TFLink.ortho': 'Dm:B9A0N7;Dr:A8DZF0;Rn:D3ZE91',
#   'Target.nonTFLink.ortho': 'Dr:B0V3Q8;Mm:E9PUA6',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '770',
#   'Ensembl.GeneID.Target': 'ENSG00000063180',
#   'Name.Target': 'CA11',
#   'UniprotID.Target': 'O75493',
#   'Target.TFLink.ortho': 'Mm:O70354;Rn:Q811X3',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '79731',
#   'Ensembl.GeneID.Target': 'ENSG00000137513',
#   'Name.Target': 'NARS2',
#   'UniprotID.Target': 'Q96I59',
#   'Target.TFLink.ortho': 'Ce:Q95PZ8;Dm:Q7JZR5;Mm:Q8BGV0;Sc:P25345',
#   'Target.nonTFLink.ortho': 'Rn:A0A0G2K7D7',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '57610',
#   'Ensembl.GeneID.Target': 'ENSG00000141084',
#   'Name.Target': 'RANBP10',
#   'UniprotID.Target': 'Q6VN20',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '80823',
#   'Ensembl.GeneID.Target': 'ENSG00000198908',
#   'Name.Target': 'BHLHB9',
#   'UniprotID.Target': 'Q6PI77',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285',
#   'Source.database': 'ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '9846',
#   'Ensembl.GeneID.Target': 'ENSG00000033327',
#   'Name.Target': 'GAB2',
#   'UniprotID.Target': 'Q9UQC2',
#   'Target.TFLink.ortho': 'Mm:Q3ZB57;Rn:F1LSR2',
#   'Target.nonTFLink.ortho': 'Dr:A0A0R4I9X7',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '149345',
#   'Ensembl.GeneID.Target': 'ENSG00000198892',
#   'Name.Target': 'SHISA4',
#   'UniprotID.Target': 'Q96DD7',
#   'Target.TFLink.ortho': 'Dr:A5WUR8;Mm:Q8CA71;Rn:A0MV40',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '124936',
#   'Ensembl.GeneID.Target': 'ENSG00000167740',
#   'Name.Target': 'CYB5D2',
#   'UniprotID.Target': 'Q8WUJ1',
#   'Target.TFLink.ortho': 'Ce:Q9XXA7;Dm:Q9W376;Mm:Q5SSH8;Rn:Q6AY62',
#   'Target.nonTFLink.ortho': 'Dr:A2CES0',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4722',
#   'Ensembl.GeneID.Target': 'ENSG00000213619',
#   'Name.Target': 'NDUFS3',
#   'UniprotID.Target': 'O75489',
#   'Target.TFLink.ortho': 'Dm:Q9VZU4;Dr:F1R4C8;Mm:Q9DCT2;Rn:D3ZG43',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '55699',
#   'Ensembl.GeneID.Target': 'ENSG00000067704',
#   'Name.Target': 'IARS2',
#   'UniprotID.Target': 'Q9NSE4',
#   'Target.TFLink.ortho': 'Dm:Q9VUY4;Dr:F1QUQ0;Mm:Q8BIJ6;Rn:A0A0G2K261;Sc:P48526',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '55625',
#   'Ensembl.GeneID.Target': 'ENSG00000153786',
#   'Name.Target': 'ZDHHC7',
#   'UniprotID.Target': 'Q9NXF8',
#   'Target.TFLink.ortho': 'Dr:Q6DHI1;Mm:Q91WU6;Rn:Q923G5',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2597',
#   'Ensembl.GeneID.Target': 'ENSG00000111640',
#   'Name.Target': 'GAPDH',
#   'UniprotID.Target': 'P04406',
#   'Target.TFLink.ortho': 'Ce:P17331;Ce:P04970;Ce:P17330;Ce:P17329;Dm:P07486;Dm:P07487;Mm:S4R1W1;Rn:P04797',
#   'Target.nonTFLink.ortho': 'Mm:S4R1W8;Mm:A0A1D5RLD8;Rn:D3ZGY4;Rn:M0R590',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8914',
#   'Ensembl.GeneID.Target': 'ENSG00000111602',
#   'Name.Target': 'TIMELESS',
#   'UniprotID.Target': 'Q9UNS1',
#   'Target.TFLink.ortho': 'Ce:G5EDN3;Dm:Q8INH7;Dr:E7FGL0;Mm:Q9R1X4;Rn:E9PTS7',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '753',
#   'Ensembl.GeneID.Target': 'ENSG00000168675',
#   'Name.Target': 'LDLRAD4',
#   'UniprotID.Target': 'O15165',
#   'Target.TFLink.ortho': 'Dr:E9QGX8;Mm:Q8BWJ4',
#   'Target.nonTFLink.ortho': 'Rn:F1LZA8',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4501',
#   'Ensembl.GeneID.Target': 'ENSG00000187193',
#   'Name.Target': 'MT1X',
#   'UniprotID.Target': 'P80297',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5224',
#   'Ensembl.GeneID.Target': 'ENSG00000164708',
#   'Name.Target': 'PGAM2',
#   'UniprotID.Target': 'P15259',
#   'Target.TFLink.ortho': 'Mm:O70250',
#   'Target.nonTFLink.ortho': 'Dr:Q7T3G4;Rn:P16290',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10904',
#   'Ensembl.GeneID.Target': 'ENSG00000166619',
#   'Name.Target': 'BLCAP',
#   'UniprotID.Target': 'P62952',
#   'Target.TFLink.ortho': 'Ce:G5EE03;Dm:Q9V3L0;Dr:Q9IB61;Mm:P62951;Rn:P62950',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '3835',
#   'Ensembl.GeneID.Target': 'ENSG00000079616',
#   'Name.Target': 'KIF22',
#   'UniprotID.Target': 'Q14807',
#   'Target.TFLink.ortho': 'Dr:B7ZV80;Mm:Q3V300;Rn:Q5I0E8',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '320',
#   'Ensembl.GeneID.Target': 'ENSG00000107282',
#   'Name.Target': 'APBA1',
#   'UniprotID.Target': 'Q02410',
#   'Target.TFLink.ortho': 'Mm:B2RUJ5;Rn:F1LR60',
#   'Target.nonTFLink.ortho': 'Dr:A0A2R9YJM9',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '200185',
#   'Ensembl.GeneID.Target': 'ENSG00000163463',
#   'Name.Target': 'KRTCAP2',
#   'UniprotID.Target': 'Q8N6L1',
#   'Target.TFLink.ortho': 'Dm:Q8INQ7;Dr:Q0P494;Mm:Q5RL79;Rn:B2RZC9',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10367',
#   'Ensembl.GeneID.Target': 'ENSG00000107745',
#   'Name.Target': 'MICU1',
#   'UniprotID.Target': 'Q9BPX6',
#   'Target.TFLink.ortho': 'Ce:Q95PZ2;Dm:A2VEI2;Mm:Q8VCX5;Rn:A0A0G2K0T5',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '100272147',
#   'Ensembl.GeneID.Target': 'ENSG00000182712',
#   'Name.Target': 'CMC4',
#   'UniprotID.Target': 'P56277',
#   'Target.TFLink.ortho': 'Dm:B7YZN8;Dr:A0A0R4IZJ0;Mm:Q61908;Rn:A0A0G2K2W2',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '11123',
#   'Ensembl.GeneID.Target': 'ENSG00000117602',
#   'Name.Target': 'RCAN3',
#   'UniprotID.Target': 'Q9UKA8',
#   'Target.TFLink.ortho': 'Mm:Q9JKK0;Rn:F7ENE7',
#   'Target.nonTFLink.ortho': 'Dr:Q6DG39',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4719',
#   'Ensembl.GeneID.Target': 'ENSG00000023228',
#   'Name.Target': 'NDUFS1',
#   'UniprotID.Target': 'P28331',
#   'Target.TFLink.ortho': 'Ce:Q9N4Y8;Dm:Q94511;Mm:Q91VD9;Rn:Q66HF1',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '1738',
#   'Ensembl.GeneID.Target': 'ENSG00000091140',
#   'Name.Target': 'DLD',
#   'UniprotID.Target': 'P09622',
#   'Target.TFLink.ortho': 'Ce:O17953;Dm:Q9VVL7;Dr:Q6TNU6;Mm:O08749;Rn:Q6P6R2;Sc:P09624',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '1146',
#   'Ensembl.GeneID.Target': 'ENSG00000196811',
#   'Name.Target': 'CHRNG',
#   'UniprotID.Target': 'P07510',
#   'Target.TFLink.ortho': 'Mm:F8VQK4',
#   'Target.nonTFLink.ortho': 'Dr:E7F9V1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '127687',
#   'Ensembl.GeneID.Target': 'ENSG00000197982',
#   'Name.Target': 'C1orf122',
#   'UniprotID.Target': 'Q6ZSJ8',
#   'Target.TFLink.ortho': 'Rn:D3ZK76',
#   'Target.nonTFLink.ortho': 'Mm:V9GXF1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51380',
#   'Ensembl.GeneID.Target': 'ENSG00000139631',
#   'Name.Target': 'CSAD',
#   'UniprotID.Target': 'Q9Y600',
#   'Target.TFLink.ortho': 'Mm:Q9DBE0;Rn:Q64611',
#   'Target.nonTFLink.ortho': 'Dr:F1QG14',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51209',
#   'Ensembl.GeneID.Target': 'ENSG00000123570',
#   'Name.Target': 'RAB9B',
#   'UniprotID.Target': 'Q9NP90',
#   'Target.TFLink.ortho': 'Dr:E7F8G0;Mm:Q8BHH2;Rn:D3ZP15',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '121441',
#   'Ensembl.GeneID.Target': 'ENSG00000139350',
#   'Name.Target': 'NEDD1',
#   'UniprotID.Target': 'Q8NHV4',
#   'Target.TFLink.ortho': 'Dm:Q9VJ57;Mm:P33215;Rn:D3ZAH3',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2110',
#   'Ensembl.GeneID.Target': 'ENSG00000171503',
#   'Name.Target': 'ETFDH',
#   'UniprotID.Target': 'Q16134',
#   'Target.TFLink.ortho': 'Ce:Q11190;Dm:Q7JWF1;Mm:Q921G7;Rn:Q66HF3;Sc:Q08822',
#   'Target.nonTFLink.ortho': 'Dr:Q66I16',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '728568',
#   'Ensembl.GeneID.Target': 'ENSG00000204954',
#   'Name.Target': 'BRAWNIN',
#   'UniprotID.Target': 'Q69YU5',
#   'Target.TFLink.ortho': 'Dr:E7EXZ6;Mm:Q8BTC1;Rn:D3ZZG3',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '6596',
#   'Ensembl.GeneID.Target': 'ENSG00000071794',
#   'Name.Target': 'HLTF',
#   'UniprotID.Target': 'Q14527',
#   'Target.TFLink.ortho': 'Dr:B0V118;Mm:Q6PCN7;Rn:A0A0G2JVH5',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2729',
#   'Ensembl.GeneID.Target': 'ENSG00000001084',
#   'Name.Target': 'GCLC',
#   'UniprotID.Target': 'P48506',
#   'Target.TFLink.ortho': 'Ce:Q20117;Dm:Q9W3K5;Dr:Q6NV35;Mm:P97494;Rn:P19468;Sc:P32477',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5528',
#   'Ensembl.GeneID.Target': 'ENSG00000112640',
#   'Name.Target': 'PPP2R5D',
#   'UniprotID.Target': 'Q14738',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': 'Mm:Q7TNL5;Rn:F1MAA3',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '11167',
#   'Ensembl.GeneID.Target': 'ENSG00000163430',
#   'Name.Target': 'FSTL1',
#   'UniprotID.Target': 'Q12841',
#   'Target.TFLink.ortho': 'Dr:Q2PMI2;Mm:Q62356;Rn:Q62632',
#   'Target.nonTFLink.ortho': 'Dr:F1Q6U6',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8195',
#   'Ensembl.GeneID.Target': 'ENSG00000125863',
#   'Name.Target': 'MKKS',
#   'UniprotID.Target': 'Q9NPJ1',
#   'Target.TFLink.ortho': 'Dr:F1QCQ8;Mm:Q9JI70;Rn:Q5XI30',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2235',
#   'Ensembl.GeneID.Target': 'ENSG00000066926',
#   'Name.Target': 'FECH',
#   'UniprotID.Target': 'P22830',
#   'Target.TFLink.ortho': 'Dm:Q9V9S8;Dr:F1R362;Mm:Q544X6;Rn:D3ZBM3;Sc:P16622',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '56180',
#   'Ensembl.GeneID.Target': 'ENSG00000101928',
#   'Name.Target': 'MOSPD1',
#   'UniprotID.Target': 'Q9UJG1',
#   'Target.TFLink.ortho': 'Dr:F1R9R3;Mm:Q8VEL0',
#   'Target.nonTFLink.ortho': 'Rn:Q5RJS6',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '7436',
#   'Ensembl.GeneID.Target': 'ENSG00000147852',
#   'Name.Target': 'VLDLR',
#   'UniprotID.Target': 'P98155',
#   'Target.TFLink.ortho': 'Mm:P98156;Rn:F1LPV2',
#   'Target.nonTFLink.ortho': 'Dr:E9QBA5',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '3418',
#   'Ensembl.GeneID.Target': 'ENSG00000182054',
#   'Name.Target': 'IDH2',
#   'UniprotID.Target': 'P48735',
#   'Target.TFLink.ortho': 'Ce:O17643;Mm:P54071;Rn:P56574',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5162',
#   'Ensembl.GeneID.Target': 'ENSG00000168291',
#   'Name.Target': 'PDHB',
#   'UniprotID.Target': 'P11177',
#   'Target.TFLink.ortho': 'Ce:O44451;Dm:Q7K5K3;Dr:Q7T368;Mm:Q9D051;Sc:P32473',
#   'Target.nonTFLink.ortho': 'Rn:A0A0G2KAM3',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285',
#   'Source.database': 'ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8882',
#   'Ensembl.GeneID.Target': 'ENSG00000109917',
#   'Name.Target': 'ZPR1',
#   'UniprotID.Target': 'O75312',
#   'Target.TFLink.ortho': 'Ce:O16999;Dm:Q9W379;Dr:Q1LY31;Mm:Q62384;Rn:D3ZWN1;Sc:P53303',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '3725',
#   'Ensembl.GeneID.Target': 'ENSG00000177606',
#   'Name.Target': 'JUN',
#   'UniprotID.Target': 'P05412',
#   'Target.TFLink.ortho': 'Dr:Q6NZT5;Mm:P05627;Rn:P17325',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '64374',
#   'Ensembl.GeneID.Target': 'ENSG00000120725',
#   'Name.Target': 'SIL1',
#   'UniprotID.Target': 'Q9H173',
#   'Target.TFLink.ortho': 'Dm:Q9VBV5;Dr:A0A0G2KDW7;Mm:Q9EPK6;Rn:Q6P6S4',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '1773',
#   'Ensembl.GeneID.Target': 'ENSG00000213918',
#   'Name.Target': 'DNASE1',
#   'UniprotID.Target': 'P24855',
#   'Target.TFLink.ortho': 'Mm:P49183',
#   'Target.nonTFLink.ortho': 'Dr:Q6DG72;Rn:P21704',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '142',
#   'Ensembl.GeneID.Target': 'ENSG00000143799',
#   'Name.Target': 'PARP1',
#   'UniprotID.Target': 'P09874',
#   'Target.TFLink.ortho': 'Ce:Q9N4H4;Dm:P35875;Dr:Q5RHR0;Rn:P27008',
#   'Target.nonTFLink.ortho': 'Mm:Q921K2',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5569',
#   'Ensembl.GeneID.Target': 'ENSG00000171033',
#   'Name.Target': 'PKIA',
#   'UniprotID.Target': 'P61925',
#   'Target.TFLink.ortho': 'Mm:P63248;Rn:P63249',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51428',
#   'Ensembl.GeneID.Target': 'ENSG00000183258',
#   'Name.Target': 'DDX41',
#   'UniprotID.Target': 'Q9UJV9',
#   'Target.TFLink.ortho': 'Dm:Q9V3C0;Mm:Q91VN6;Rn:B2RYL8',
#   'Target.nonTFLink.ortho': 'Ce:Q9N5K1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '79902',
#   'Ensembl.GeneID.Target': 'ENSG00000125450',
#   'Name.Target': 'NUP85',
#   'UniprotID.Target': 'Q9BW27',
#   'Target.TFLink.ortho': 'Ce:Q22078;Dm:A1YK02;Mm:Q8R480;Rn:Q4QQS8',
#   'Target.nonTFLink.ortho': 'Dr:A0A0R4IZD5',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51072',
#   'Ensembl.GeneID.Target': 'ENSG00000162959',
#   'Name.Target': 'MEMO1',
#   'UniprotID.Target': 'Q9Y316',
#   'Target.TFLink.ortho': 'Ce:Q22915;Dm:Q9VG04;Dr:A9JTC4;Mm:Q91VH6;Sc:P47085',
#   'Target.nonTFLink.ortho': 'Rn:F1LNE5',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '154810',
#   'Ensembl.GeneID.Target': 'ENSG00000166025',
#   'Name.Target': 'AMOTL1',
#   'UniprotID.Target': 'Q8IY63',
#   'Target.TFLink.ortho': 'Mm:Q9D4H4;Rn:F1LZQ6',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '92106',
#   'Ensembl.GeneID.Target': 'ENSG00000154814',
#   'Name.Target': 'OXNAD1',
#   'UniprotID.Target': 'Q96HP4',
#   'Target.TFLink.ortho': 'Dr:I3ISI1;Mm:Q8VE38;Rn:D4A0Y4',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8073',
#   'Ensembl.GeneID.Target': 'ENSG00000184007',
#   'Name.Target': 'PTP4A2',
#   'UniprotID.Target': 'Q12974',
#   'Target.TFLink.ortho': 'Mm:O70274;Rn:Q6P9X4',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '196483',
#   'Ensembl.GeneID.Target': 'ENSG00000118894',
#   'Name.Target': 'EEF2KMT',
#   'UniprotID.Target': 'Q96G04',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '226',
#   'Ensembl.GeneID.Target': 'ENSG00000149925',
#   'Name.Target': 'ALDOA',
#   'UniprotID.Target': 'P04075',
#   'Target.TFLink.ortho': 'Ce:P46563;Dm:P07764;Dr:Q803Q7;Mm:P05064;Rn:P05065',
#   'Target.nonTFLink.ortho': 'Dr:Q6P043',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '55089',
#   'Ensembl.GeneID.Target': 'ENSG00000139209',
#   'Name.Target': 'SLC38A4',
#   'UniprotID.Target': 'Q969I6',
#   'Target.TFLink.ortho': 'Dr:Q5SPB0;Mm:Q8R1S9;Rn:Q9EQ25',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '664',
#   'Ensembl.GeneID.Target': 'ENSG00000176171',
#   'Name.Target': 'BNIP3',
#   'UniprotID.Target': 'Q12983',
#   'Target.TFLink.ortho': 'Mm:O55003;Rn:Q9ET45',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '349565',
#   'Ensembl.GeneID.Target': 'ENSG00000163864',
#   'Name.Target': 'NMNAT3',
#   'UniprotID.Target': 'Q96T66',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '1666',
#   'Ensembl.GeneID.Target': 'ENSG00000104325',
#   'Name.Target': 'DECR1',
#   'UniprotID.Target': 'Q16698',
#   'Target.TFLink.ortho': 'Ce:Q93761;Dr:F1QB21;Mm:Q9CQ62;Rn:G3V734',
#   'Target.nonTFLink.ortho': 'Ce:Q22230;Ce:Q23116',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '64651',
#   'Ensembl.GeneID.Target': 'ENSG00000144655',
#   'Name.Target': 'CSRNP1',
#   'UniprotID.Target': 'Q96S65',
#   'Target.TFLink.ortho': 'Mm:P59054;Rn:D4AAK3',
#   'Target.nonTFLink.ortho': 'Dr:F1QNJ1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '56911',
#   'Ensembl.GeneID.Target': 'ENSG00000156265',
#   'Name.Target': 'MAP3K7CL',
#   'UniprotID.Target': 'P57077',
#   'Target.TFLink.ortho': 'Mm:P58500;Rn:A0A0G2K9U9',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '56850',
#   'Ensembl.GeneID.Target': 'ENSG00000068400',
#   'Name.Target': 'GRIPAP1',
#   'UniprotID.Target': 'Q4V328',
#   'Target.TFLink.ortho': 'Ce:Q20298;Dr:B0UYE9;Rn:Q9JHZ4',
#   'Target.nonTFLink.ortho': 'Mm:A2AEW8',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51422',
#   'Ensembl.GeneID.Target': 'ENSG00000106617',
#   'Name.Target': 'PRKAG2',
#   'UniprotID.Target': 'Q9UGJ0',
#   'Target.TFLink.ortho': 'Mm:Q91WG5;Rn:A0A140UHX4',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '80344',
#   'Ensembl.GeneID.Target': 'ENSG00000100897',
#   'Name.Target': 'DCAF11',
#   'UniprotID.Target': 'Q8TEB1',
#   'Target.TFLink.ortho': 'Ce:P90794;Dm:Q7JYQ4;Mm:Q91VU6;Rn:Q5M9G8',
#   'Target.nonTFLink.ortho': 'Dr:Q499B0',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23199',
#   'Ensembl.GeneID.Target': 'ENSG00000131149',
#   'Name.Target': 'GSE1',
#   'UniprotID.Target': 'Q14687',
#   'Target.TFLink.ortho': 'Dr:Q1LWL6;Mm:Q3U3C9;Rn:F1M4A7',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '54541',
#   'Ensembl.GeneID.Target': 'ENSG00000168209',
#   'Name.Target': 'DDIT4',
#   'UniprotID.Target': 'Q9NX09',
#   'Target.TFLink.ortho': 'Dm:Q9VTH4;Dr:Q7T346;Mm:Q9D3F7;Rn:G3V620',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8313',
#   'Ensembl.GeneID.Target': 'ENSG00000168646',
#   'Name.Target': 'AXIN2',
#   'UniprotID.Target': 'Q9Y2T1',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '60558',
#   'Ensembl.GeneID.Target': 'ENSG00000151806',
#   'Name.Target': 'GUF1',
#   'UniprotID.Target': 'Q8N442',
#   'Target.TFLink.ortho': 'Ce:P34617;Dm:Q9VRH6;Dr:E7FFK6;Mm:Q8C3X4;Rn:D3ZHF8;Sc:P46943',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8898',
#   'Ensembl.GeneID.Target': 'ENSG00000087053',
#   'Name.Target': 'MTMR2',
#   'UniprotID.Target': 'Q13614',
#   'Target.TFLink.ortho': 'Dm:Q9VMI9;Dr:A0JMK5;Mm:Q9Z2D1;Rn:D3ZA31',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23245',
#   'Ensembl.GeneID.Target': 'ENSG00000148219',
#   'Name.Target': 'ASTN2',
#   'UniprotID.Target': 'O75129',
#   'Target.TFLink.ortho': 'Mm:Q80Z10',
#   'Target.nonTFLink.ortho': 'Rn:A0A0G2JYU3',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '55661',
#   'Ensembl.GeneID.Target': 'ENSG00000124228',
#   'Name.Target': 'DDX27',
#   'UniprotID.Target': 'Q96GQ7',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '549',
#   'Ensembl.GeneID.Target': 'ENSG00000148090',
#   'Name.Target': 'AUH',
#   'UniprotID.Target': 'Q13825',
#   'Target.TFLink.ortho': 'Ce:O45106;Dm:A1Z934;Mm:A0A0R4J023;Rn:F1LU71',
#   'Target.nonTFLink.ortho': 'Dr:F1RDX1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '203260',
#   'Ensembl.GeneID.Target': 'ENSG00000159884',
#   'Name.Target': 'CCDC107',
#   'UniprotID.Target': 'Q8WV48',
#   'Target.TFLink.ortho': 'Mm:Q9DCC3;Rn:D4A3Y2',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23409',
#   'Ensembl.GeneID.Target': 'ENSG00000089163',
#   'Name.Target': 'SIRT4',
#   'UniprotID.Target': 'Q9Y6E7',
#   'Target.TFLink.ortho': 'Ce:Q20480;Dm:Q8IRR5;Dr:F1QHM6;Mm:Q8R216;Rn:G3V641',
#   'Target.nonTFLink.ortho': 'Ce:Q20481',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '26287',
#   'Ensembl.GeneID.Target': 'ENSG00000165887',
#   'Name.Target': 'ANKRD2',
#   'UniprotID.Target': 'Q9GZV1',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '391356',
#   'Ensembl.GeneID.Target': 'ENSG00000184924',
#   'Name.Target': 'PTRHD1',
#   'UniprotID.Target': 'Q6GMV3',
#   'Target.TFLink.ortho': 'Ce:A7WK43;Dm:Q9VET3;Dr:Q5RIN6;Mm:D3Z4S3;Rn:D3ZBG6',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2589',
#   'Ensembl.GeneID.Target': 'ENSG00000141429',
#   'Name.Target': 'GALNT1',
#   'UniprotID.Target': 'Q10472',
#   'Target.TFLink.ortho': 'Ce:P34678;Dr:E7FDA0;Mm:O08912;Rn:Q10473',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4609',
#   'Ensembl.GeneID.Target': 'ENSG00000136997',
#   'Name.Target': 'MYC',
#   'UniprotID.Target': 'P01106',
#   'Target.TFLink.ortho': 'Dr:F1RC36;Mm:P01108',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '93058',
#   'Ensembl.GeneID.Target': 'ENSG00000135469',
#   'Name.Target': 'COQ10A',
#   'UniprotID.Target': 'Q96MF6',
#   'Target.TFLink.ortho': 'Dm:Q8MLL3;Mm:E9Q3H6;Rn:D3ZX74;Sc:Q08058',
#   'Target.nonTFLink.ortho': 'Ce:Q304F0;Dr:E9QFB6',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '79634',
#   'Ensembl.GeneID.Target': 'ENSG00000144306',
#   'Name.Target': 'SCRN3',
#   'UniprotID.Target': 'Q0VDG4',
#   'Target.TFLink.ortho': 'Dr:Q803W1;Mm:Q3TMH2;Rn:A0A0G2K189',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '84872',
#   'Ensembl.GeneID.Target': 'ENSG00000135482',
#   'Name.Target': 'ZC3H10',
#   'UniprotID.Target': 'Q96K80',
#   'Target.TFLink.ortho': 'Dr:Q6ZM22;Mm:Q8R205;Rn:D3ZLM7',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4240',
#   'Ensembl.GeneID.Target': 'ENSG00000140545',
#   'Name.Target': 'MFGE8',
#   'UniprotID.Target': 'Q08431',
#   'Target.TFLink.ortho': 'Mm:P21956',
#   'Target.nonTFLink.ortho': 'Dr:A2RRT1;Dr:A4QP32;Rn:Q1PBJ1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '6749',
#   'Ensembl.GeneID.Target': 'ENSG00000149136',
#   'Name.Target': 'SSRP1',
#   'UniprotID.Target': 'Q08945',
#   'Target.TFLink.ortho': 'Ce:O01683;Ce:P41848;Dm:Q05344;Mm:Q08943;Rn:Q04931;Sc:Q04636',
#   'Target.nonTFLink.ortho': 'Dr:B8A5B7',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10489',
#   'Ensembl.GeneID.Target': 'ENSG00000132128',
#   'Name.Target': 'LRRC41',
#   'UniprotID.Target': 'Q15345',
#   'Target.TFLink.ortho': 'Dr:I3IS54;Mm:Q8K1C9;Rn:Q5M9H1',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2010',
#   'Ensembl.GeneID.Target': 'ENSG00000102119',
#   'Name.Target': 'EMD',
#   'UniprotID.Target': 'P50402',
#   'Target.TFLink.ortho': 'Mm:O08579;Rn:Q6PCU4',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5092',
#   'Ensembl.GeneID.Target': 'ENSG00000166228',
#   'Name.Target': 'PCBD1',
#   'UniprotID.Target': 'P61457',
#   'Target.TFLink.ortho': 'Ce:Q9TZH6;Dr:Q6PBI6;Mm:P61458;Rn:P61459',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2114',
#   'Ensembl.GeneID.Target': 'ENSG00000157557',
#   'Name.Target': 'ETS2',
#   'UniprotID.Target': 'P15036',
#   'Target.TFLink.ortho': 'Dr:Q501S1;Mm:P15037;Rn:D4AAH4',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '200765',
#   'Ensembl.GeneID.Target': 'ENSG00000221944',
#   'Name.Target': 'TIGD1',
#   'UniprotID.Target': 'Q96MW7',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4536',
#   'Ensembl.GeneID.Target': 'ENSG00000198763',
#   'Name.Target': 'MT-ND2',
#   'UniprotID.Target': 'P03891',
#   'Target.TFLink.ortho': 'Dr:Q9MIY9;Mm:P03893;Rn:P11662',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '9179',
#   'Ensembl.GeneID.Target': 'ENSG00000221838',
#   'Name.Target': 'AP4M1',
#   'UniprotID.Target': 'O00189',
#   'Target.TFLink.ortho': 'Dr:Q7SZZ7;Mm:Q9JKC7;Rn:Q2PWT8',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '9693',
#   'Ensembl.GeneID.Target': 'ENSG00000109756',
#   'Name.Target': 'RAPGEF2',
#   'UniprotID.Target': 'Q9Y4G8',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10121',
#   'Ensembl.GeneID.Target': 'ENSG00000138107',
#   'Name.Target': 'ACTR1A',
#   'UniprotID.Target': 'P61163',
#   'Target.TFLink.ortho': 'Mm:P61164;Rn:P85515',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51204',
#   'Ensembl.GeneID.Target': 'ENSG00000136463',
#   'Name.Target': 'TACO1',
#   'UniprotID.Target': 'Q9BSH4',
#   'Target.TFLink.ortho': 'Ce:Q965T4;Mm:Q8K0Z7;Rn:D4A601;Sc:P53212',
#   'Target.nonTFLink.ortho': 'Dr:F1QP29;Dr:A0A0G2L877',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '25855',
#   'Ensembl.GeneID.Target': 'ENSG00000174744',
#   'Name.Target': 'BRMS1',
#   'UniprotID.Target': 'Q9HCU9',
#   'Target.TFLink.ortho': 'Mm:Q99N20',
#   'Target.nonTFLink.ortho': 'Rn:Q5M7T3;Rn:A0A0H2UI40',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '140606',
#   'Ensembl.GeneID.Target': 'ENSG00000198832',
#   'Name.Target': 'SELENOM',
#   'UniprotID.Target': 'Q8WWX9',
#   'Target.TFLink.ortho': 'Mm:Q8VHC3;Rn:A0A0G2JZZ4',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '81579',
#   'Ensembl.GeneID.Target': 'ENSG00000123739',
#   'Name.Target': 'PLA2G12A',
#   'UniprotID.Target': 'Q9BZM1',
#   'Target.TFLink.ortho': 'Dr:A3KNJ5;Mm:Q9EPR2;Rn:B0K018',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51390',
#   'Ensembl.GeneID.Target': 'ENSG00000146416',
#   'Name.Target': 'AIG1',
#   'UniprotID.Target': 'Q9NVV5',
#   'Target.TFLink.ortho': 'Dm:Q9VPM9;Dm:Q9VTI1;Dr:Q5RIV5;Mm:Q9D8B1;Rn:B2RZC0',
#   'Target.nonTFLink.ortho': 'Dm:Q9VPN1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '25824',
#   'Ensembl.GeneID.Target': 'ENSG00000126432',
#   'Name.Target': 'PRDX5',
#   'UniprotID.Target': 'P30044',
#   'Target.TFLink.ortho': 'Dm:Q960M4;Mm:P99029;Rn:A0A0G2JSS8;Sc:P38013',
#   'Target.nonTFLink.ortho': 'Dr:F1QCE3',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10907',
#   'Ensembl.GeneID.Target': 'ENSG00000141759',
#   'Name.Target': 'TXNL4A',
#   'UniprotID.Target': 'P83876',
#   'Target.TFLink.ortho': 'Ce:L8E6I4;Dm:Q8SZ87;Dr:F1QTJ2;Mm:P83877;Rn:D3ZSW5;Sc:Q06819',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '85437',
#   'Ensembl.GeneID.Target': 'ENSG00000139168',
#   'Name.Target': 'ZCRB1',
#   'UniprotID.Target': 'Q8TBF4',
#   'Target.TFLink.ortho': 'Dr:Q5SP50;Mm:Q9CZ96;Rn:Q499V6',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23461',
#   'Ensembl.GeneID.Target': 'ENSG00000154265',
#   'Name.Target': 'ABCA5',
#   'UniprotID.Target': 'Q8WWZ7',
#   'Target.TFLink.ortho': 'Dr:F1QEL5;Mm:Q8K448',
#   'Target.nonTFLink.ortho': 'Rn:M0RA83',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '6641',
#   'Ensembl.GeneID.Target': 'ENSG00000172164',
#   'Name.Target': 'SNTB1',
#   'UniprotID.Target': 'Q13884',
#   'Target.TFLink.ortho': 'Dr:Q6GMG2;Mm:Q99L88;Rn:D3ZWC6',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8945',
#   'Ensembl.GeneID.Target': 'ENSG00000166167',
#   'Name.Target': 'BTRC',
#   'UniprotID.Target': 'Q9Y297',
#   'Target.TFLink.ortho': 'Mm:Q3ULA2;Rn:F1LMH8',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8568',
#   'Ensembl.GeneID.Target': 'ENSG00000160214',
#   'Name.Target': 'RRP1',
#   'UniprotID.Target': 'P56182',
#   'Target.TFLink.ortho': 'Ce:Q18674;Mm:P56183;Rn:Q5M9F3',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10912',
#   'Ensembl.GeneID.Target': 'ENSG00000130222',
#   'Name.Target': 'GADD45G',
#   'UniprotID.Target': 'O95257',
#   'Target.TFLink.ortho': 'Dr:Q6NUV6;Dr:Q6P021;Mm:Q9R0S0;Rn:Q9WTQ7',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4038',
#   'Ensembl.GeneID.Target': 'ENSG00000134569',
#   'Name.Target': 'LRP4',
#   'UniprotID.Target': 'O75096',
#   'Target.TFLink.ortho': 'Dm:Q9VXM0;Mm:Q8VI56;Rn:Q9QYP1',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '55275',
#   'Ensembl.GeneID.Target': 'ENSG00000141252',
#   'Name.Target': 'VPS53',
#   'UniprotID.Target': 'Q5VIR6',
#   'Target.TFLink.ortho': 'Dm:Q9VQY8;Dr:E7FAG0;Mm:Q8CCB4;Rn:D3ZPE5;Sc:P47061',
#   'Target.nonTFLink.ortho': 'Ce:P34561',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5264',
#   'Ensembl.GeneID.Target': 'ENSG00000107537',
#   'Name.Target': 'PHYH',
#   'UniprotID.Target': 'O14832',
#   'Target.TFLink.ortho': 'Ce:O62515;Mm:O35386;Rn:P57093',
#   'Target.nonTFLink.ortho': 'Dr:E7FCS1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '55217',
#   'Ensembl.GeneID.Target': 'ENSG00000185973',
#   'Name.Target': 'TMLHE',
#   'UniprotID.Target': 'Q9NVH6',
# ...
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4705',
#   'Ensembl.GeneID.Target': 'ENSG00000130414',
#   'Name.Target': 'NDUFA10',
#   'UniprotID.Target': 'O95299',
#   'Target.TFLink.ortho': 'Dm:P91929;Dr:F1RDV2;Mm:Q99LC3;Rn:Q561S0',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '38',
#   'Ensembl.GeneID.Target': 'ENSG00000075239',
#   'Name.Target': 'ACAT1',
#   'UniprotID.Target': 'P24752',
#   'Target.TFLink.ortho': 'Ce:Q22100;Dm:Q9W3N9;Mm:Q8QZT1;Rn:P17764;Sc:P41338',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '4720',
#   'Ensembl.GeneID.Target': 'ENSG00000158864',
#   'Name.Target': 'NDUFS2',
#   'UniprotID.Target': 'O75306',
#   'Target.TFLink.ortho': 'Ce:Q22800;Ce:Q93873;Dm:Q9V4E0;Dr:F1Q4N4;Mm:Q91WD5;Rn:Q641Y2',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2668',
#   'Ensembl.GeneID.Target': 'ENSG00000168621',
#   'Name.Target': 'GDNF',
#   'UniprotID.Target': 'P39905',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '89796',
#   'Ensembl.GeneID.Target': 'ENSG00000134369',
#   'Name.Target': 'NAV1',
#   'UniprotID.Target': 'Q8NEY1',
#   'Target.TFLink.ortho': 'Rn:D4A5I4',
#   'Target.nonTFLink.ortho': 'Dr:F1QQI8;Mm:A0A589P973',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '64061',
#   'Ensembl.GeneID.Target': 'ENSG00000184205',
#   'Name.Target': 'TSPYL2',
#   'UniprotID.Target': 'Q9H2G4',
#   'Target.TFLink.ortho': 'Mm:Q7TQI8;Rn:A0A096MJ32',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5947',
#   'Ensembl.GeneID.Target': 'ENSG00000114115',
#   'Name.Target': 'RBP1',
#   'UniprotID.Target': 'P09455',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2926',
#   'Ensembl.GeneID.Target': 'ENSG00000132463',
#   'Name.Target': 'GRSF1',
#   'UniprotID.Target': 'Q12849',
#   'Target.TFLink.ortho': 'Dr:F8W4V6;Mm:Q8C5Q4',
#   'Target.nonTFLink.ortho': 'Rn:F1LRK4',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5979',
#   'Ensembl.GeneID.Target': 'ENSG00000165731',
#   'Name.Target': 'RET',
#   'UniprotID.Target': 'P07949',
#   'Target.TFLink.ortho': 'Dr:A8E7C6;Mm:P35546',
#   'Target.nonTFLink.ortho': 'Rn:G3V9H8',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '201562',
#   'Ensembl.GeneID.Target': 'ENSG00000206527',
#   'Name.Target': 'HACD2',
#   'UniprotID.Target': 'Q6Y1H2',
#   'Target.TFLink.ortho': 'Ce:O17040;Dr:B0V199;Mm:Q9D3B1;Rn:D3ZHG0',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23632',
#   'Ensembl.GeneID.Target': 'ENSG00000118298',
#   'Name.Target': 'CA14',
#   'UniprotID.Target': 'Q9ULX7',
#   'Target.TFLink.ortho': 'Mm:Q9WVT6;Rn:A2IBE0',
#   'Target.nonTFLink.ortho': 'Dr:F8W4I7',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285',
#   'Source.database': 'ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '114882',
#   'Ensembl.GeneID.Target': 'ENSG00000091039',
#   'Name.Target': 'OSBPL8',
#   'UniprotID.Target': 'Q9BZF1',
#   'Target.TFLink.ortho': 'Rn:A0A0G2JXN8',
#   'Target.nonTFLink.ortho': 'Mm:A0A0R4J150',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '1160',
#   'Ensembl.GeneID.Target': 'ENSG00000131730',
#   'Name.Target': 'CKMT2',
#   'UniprotID.Target': 'P17540',
#   'Target.TFLink.ortho': 'Mm:Q6P8J7',
#   'Target.nonTFLink.ortho': 'Dm:Q9VF23;Rn:A0A0G2JVQ1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '54948',
#   'Ensembl.GeneID.Target': 'ENSG00000166902',
#   'Name.Target': 'MRPL16',
#   'UniprotID.Target': 'Q9NX20',
#   'Target.TFLink.ortho': 'Ce:Q22140;Dm:Q9W547;Mm:Q99N93;Rn:Q5M818',
#   'Target.nonTFLink.ortho': 'Dr:F1R2K1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8604',
#   'Ensembl.GeneID.Target': 'ENSG00000115840',
#   'Name.Target': 'SLC25A12',
#   'UniprotID.Target': 'O75746',
#   'Target.TFLink.ortho': 'Mm:Q8BH59;Rn:F1LX07',
#   'Target.nonTFLink.ortho': 'Dr:A0A0R4II73',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2037',
#   'Ensembl.GeneID.Target': 'ENSG00000079819',
#   'Name.Target': 'EPB41L2',
#   'UniprotID.Target': 'O43491',
#   'Target.TFLink.ortho': 'Mm:O70318',
#   'Target.nonTFLink.ortho': 'Rn:D3ZM69',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51279',
#   'Ensembl.GeneID.Target': 'ENSG00000139178',
#   'Name.Target': 'C1RL',
#   'UniprotID.Target': 'Q9NZP8',
#   'Target.TFLink.ortho': 'Mm:Q3UZ09;Rn:F1LP96',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '6391',
#   'Ensembl.GeneID.Target': 'ENSG00000143252',
#   'Name.Target': 'SDHC',
#   'UniprotID.Target': 'Q99643',
#   'Target.TFLink.ortho': 'Ce:P41956;Dm:Q9VGS3;Mm:Q9CZB0;Rn:Q641Z9',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '57787',
#   'Ensembl.GeneID.Target': 'ENSG00000007047',
#   'Name.Target': 'MARK4',
#   'UniprotID.Target': 'Q96L34',
#   'Target.TFLink.ortho': 'Dr:R4GEN1;Mm:Q8CIP4;Rn:D4A6T9',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '55245',
#   'Ensembl.GeneID.Target': 'ENSG00000101019',
#   'Name.Target': 'UQCC1',
#   'UniprotID.Target': 'Q9NVA1',
#   'Target.TFLink.ortho': 'Dm:Q9VRZ7;Dr:F1QK92;Mm:Q9CWU6;Rn:Q32Q54',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '64222',
#   'Ensembl.GeneID.Target': 'ENSG00000186283',
#   'Name.Target': 'TOR3A',
#   'UniprotID.Target': 'Q9H497',
#   'Target.TFLink.ortho': 'Dr:A9C3S4;Mm:Q9ER38;Rn:Q5M936',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '141',
#   'Ensembl.GeneID.Target': 'ENSG00000144843',
#   'Name.Target': 'ADPRH',
#   'UniprotID.Target': 'P54922',
#   'Target.TFLink.ortho': 'Mm:P54923;Rn:Q02589',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5396',
#   'Ensembl.GeneID.Target': 'ENSG00000116132',
#   'Name.Target': 'PRRX1',
#   'UniprotID.Target': 'P54821',
#   'Target.TFLink.ortho': 'Dr:Q6P295;Dr:Q7T373;Mm:P63013;Rn:P63014',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '400451',
#   'Ensembl.GeneID.Target': 'ENSG00000185442',
#   'Name.Target': 'FAM174B',
#   'UniprotID.Target': 'Q3ZCQ3',
#   'Target.TFLink.ortho': 'Mm:Q8K064',
#   'Target.nonTFLink.ortho': 'Rn:D4A4W1',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '7494',
#   'Ensembl.GeneID.Target': 'ENSG00000100219',
#   'Name.Target': 'XBP1',
#   'UniprotID.Target': 'P17861',
#   'Target.TFLink.ortho': 'Rn:A0A140TAA7',
#   'Target.nonTFLink.ortho': 'Dr:F1R5F9;Mm:A0A5F8MPD3',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '2119',
#   'Ensembl.GeneID.Target': 'ENSG00000244405',
#   'Name.Target': 'ETV5',
#   'UniprotID.Target': 'P41161',
#   'Target.TFLink.ortho': 'Dr:B0S6S7;Mm:Q9CXC9;Rn:D4AC56',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23596',
#   'Ensembl.GeneID.Target': 'ENSG00000203668',
#   'Name.Target': 'OPN3',
#   'UniprotID.Target': 'Q9H1Y3',
#   'Target.TFLink.ortho': 'Dr:A9NJI7;Mm:Q9WUK7;Rn:D3ZFS1',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '60314',
#   'Ensembl.GeneID.Target': 'ENSG00000139637',
#   'Name.Target': 'MYG1',
#   'UniprotID.Target': 'Q9HB07',
#   'Target.TFLink.ortho': '-',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '5116',
#   'Ensembl.GeneID.Target': 'ENSG00000160299',
#   'Name.Target': 'PCNT',
#   'UniprotID.Target': 'O95613',
#   'Target.TFLink.ortho': 'Dr:I3ISP1;Mm:F8VPV0;Rn:D3ZMY8',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '54715',
#   'Ensembl.GeneID.Target': 'ENSG00000078328',
#   'Name.Target': 'RBFOX1',
#   'UniprotID.Target': 'Q9NWB1',
#   'Target.TFLink.ortho': 'Dr:Q642J5;Mm:Q9JJ43;Rn:D3ZSL1',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10657',
#   'Ensembl.GeneID.Target': 'ENSG00000121774',
#   'Name.Target': 'KHDRBS1',
#   'UniprotID.Target': 'Q07666',
#   'Target.TFLink.ortho': 'Dr:Q6NW62;Mm:Q60749;Rn:Q91V33',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '10105',
#   'Ensembl.GeneID.Target': 'ENSG00000108179',
#   'Name.Target': 'PPIF',
#   'UniprotID.Target': 'P30405',
#   'Target.TFLink.ortho': 'Dm:Q7K2I4;Dm:P25007;Mm:Q99KR7;Rn:P29117',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '79758',
#   'Ensembl.GeneID.Target': 'ENSG00000102796',
#   'Name.Target': 'DHRS12',
#   'UniprotID.Target': 'A0PJE2',
#   'Target.TFLink.ortho': 'Dr:B0UYL5',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '29889',
#   'Ensembl.GeneID.Target': 'ENSG00000134697',
#   'Name.Target': 'GNL2',
#   'UniprotID.Target': 'Q13823',
#   'Target.TFLink.ortho': 'Ce:Q9XXN4;Dm:Q7JXU4;Dr:A0A0R4IXF1;Mm:Q99LH1;Rn:Q4KLJ3',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23408',
#   'Ensembl.GeneID.Target': 'ENSG00000124523',
#   'Name.Target': 'SIRT5',
#   'UniprotID.Target': 'Q9NXA8',
#   'Target.TFLink.ortho': 'Mm:Q8K2C6;Rn:Q68FX9',
#   'Target.nonTFLink.ortho': 'Dr:Q6DHI5',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '51027',
#   'Ensembl.GeneID.Target': 'ENSG00000178096',
#   'Name.Target': 'BOLA1',
#   'UniprotID.Target': 'Q9Y3E2',
#   'Target.TFLink.ortho': 'Ce:P91375;Dm:Q9VC53;Mm:Q9D8S9;Rn:Q06C60',
#   'Target.nonTFLink.ortho': 'Dr:F1R2T4',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '29126285;27924024',
#   'Source.database': 'GTRD;ReMap',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '8925',
#   'Ensembl.GeneID.Target': 'ENSG00000103657',
#   'Name.Target': 'HERC1',
#   'UniprotID.Target': 'Q15751',
#   'Target.TFLink.ortho': 'Mm:E9PZP8;Rn:A0A0G2JTT6',
#   'Target.nonTFLink.ortho': 'Dr:E7FBA7',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '81796',
#   'Ensembl.GeneID.Target': 'ENSG00000137571',
#   'Name.Target': 'SLCO5A1',
#   'UniprotID.Target': 'Q9H2Y9',
#   'Target.TFLink.ortho': 'Dr:E7F2I7;Mm:E9PVD9;Rn:D3ZZM7',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '7264',
#   'Ensembl.GeneID.Target': 'ENSG00000104522',
#   'Name.Target': 'TSTA3',
#   'UniprotID.Target': 'Q13630',
#   'Target.TFLink.ortho': 'Ce:G5EER4;Dm:Q9W1X8;Dr:Q6DC41;Mm:P23591;Rn:G3V762',
#   'Target.nonTFLink.ortho': 'Dr:B0S7C9;Dr:Q5SPD5',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '145957',
#   'Ensembl.GeneID.Target': 'ENSG00000169752',
#   'Name.Target': 'NRG4',
#   'UniprotID.Target': 'Q8WWG1',
#   'Target.TFLink.ortho': 'Mm:Q9WTX4;Rn:A0A0G2JYC9',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'},
#  {'NCBI.GeneID.Target': '23180',
#   'Ensembl.GeneID.Target': 'ENSG00000131378',
#   'Name.Target': 'RFTN1',
#   'UniprotID.Target': 'Q14699',
#   'Target.TFLink.ortho': 'Dr:A0A0G2L3G6;Mm:Q6A0D4',
#   'Target.nonTFLink.ortho': 'Dr:E9QG04;Rn:G3V7I2',
#   'Detection.method': 'chromatin immunoprecipitation assay',
#   'PubmedID': '27924024',
#   'Source.database': 'GTRD',
#   'Small-scale.evidence': 'No'}]

# %% [markdown]
# Extract "NCBI Gene" ids for adding transcription factor (TF) and target interaction

# %%
# from pyBiodatafuse.annotators.tflink import get_tf_target

# tflink_df, tflink_metadata = get_tf_target(
#     tf_file="data/human/TFLink_Homo_sapiens_interactions_All_simpleFormat_v1.0.tsv.gz",
#     filename="data/human/tflink_human.tsv.gz",
#     filter_deg=True,
#     bridgedb_df=bridgedb_df_human,
# )

# %%
# from pyBiodatafuse.annotators.gprofiler import get_gene_enrichment

# gprofiler_df, gprofiler_metadata = get_gene_enrichment(
#     bridgedb_df=bridgedb_df_human)

# %%
# gprofiler_df.head()

# %%
ncbi_df_human = get_identifier_of_interest(bridgedb_df_human, "NCBI Gene")
ncbi_to_ensembl = dict(zip(ncbi_df_human['target'], ncbi_df_human['identifier']))
ncbi_df_human.head(1)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSG00000000003           Ensembl   7105     NCBI Gene          TSPAN6
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  \
# 0    106.899174           -0.401659   0.143909 -2.791057    0.005254
#
#    padj_dea  minus_log10_pvalue_dea
# 0    0.0779                2.279542

# %%
bridgedb_df_human[bridgedb_df_human["target"] == "105378473"]
# Out:
#              identifier identifier.source     target target.source  \
# 105693  ENSG00000287047           Ensembl  105378473     NCBI Gene
#
#        GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  \
# 105693             NaN    108.208973            -0.81557   0.391216 -2.084706
#
#         pvalue_dea  padj_dea  minus_log10_pvalue_dea
# 105693    0.037096   0.21808                1.430673

# %%
print("Number of humman genes with mapping for NCBI Gene:", len(ncbi_df_human["target"].unique()))
# Out:
# Number of humman genes with mapping for NCBI Gene: 11792

# %% [markdown]
# ### Download TF-target interactions
#
# You can download the Gene-TF interactions dataset from **TFLink**. Please visit the following page for the download:
#
# [TFLink Download Page](https://tflink.net/download/)
#
# The datasets you need can be downloaded from the following links:
#
# **For Humans (Homo sapiens):**
# - [TFLink_Homo_sapiens_interactions_All_simpleFormat_v1.0.tsv.gz](https://cdn.netbiol.org/tflink/download_files/TFLink_Homo_sapiens_interactions_All_simpleFormat_v1.0.tsv.gz)
#
# **For Mice (Mus musculus):**
# - [TFLink_Mus_musculus_interactions_All_simpleFormat_v1.0.tsv.gz](https://cdn.netbiol.org/tflink/download_files/TFLink_Mus_musculus_interactions_All_simpleFormat_v1.0.tsv.gz)
#
# These files contain the TF-target interaction data in a simple format for each species.

# %%
# URLs for the TF datasets
url_human = "https://cdn.netbiol.org/tflink/download_files/TFLink_Homo_sapiens_interactions_All_simpleFormat_v1.0.tsv.gz"

# Function to download and read a gzipped file into a dataframe
def download_save_and_read(url, filename):
    if not os.path.exists(filename):
        response = requests.get(url)
        with open(filename, "wb") as file:
            file.write(response.content)
    else:
        print(f"{filename} already exists, skipping download.")

    with gzip.open(filename, "rt") as f:
        df = pd.read_csv(f, sep="\t")
    return df

# Download and read the mouse and human datasets
tf_df_human = download_save_and_read(url_human, "data/human/tflink_human.tsv.gz")

# Keep rows where both TF and target exist in our dataset
tf_df_human = tf_df_human[tf_df_human["NCBI.GeneID.TF"].isin(ncbi_df_human["target"])]
tf_df_human = tf_df_human[tf_df_human["NCBI.GeneID.Target"].isin(ncbi_df_human["target"])]

tf_df_human.head(1)
# Out:
#   UniprotID.TF UniprotID.Target NCBI.GeneID.TF NCBI.GeneID.Target Name.TF  \
# 1       P37231           P10826           5468               5915   PPARG
#
#   Name.Target                                   Detection.method  \
# 1        RARB  chromatin immunoprecipitation assay;inferred b...
#
#                               PubmedID      Organism   Source.database  \
# 1  17202159;12839938;29087512;27924024  Homo sapiens  GTRD;TRED;TRRUST
#
#   Small-scale.evidence TF.TFLink.ortho TF.nonTFLink.ortho  \
# 1                  Yes               -                  -
#
#    Target.TFLink.ortho Target.nonTFLink.ortho
# 1  Mm:P22605;Rn:D3ZFD9                      -

# %%
tf_df_human.shape
# Out:
# (4067478, 15)

# %%
# Extract the TF and the TF targets
tf_list_human = list(tf_df_human["NCBI.GeneID.TF"])
target_list_human = list(tf_df_human["NCBI.GeneID.Target"])

# Add 'is_tf' and 'is_target' columns
ncbi_df_human["is_tf"] = ncbi_df_human["target"].isin(tf_list_human)
ncbi_df_human["is_target"] = ncbi_df_human["target"].isin(target_list_human)

ncbi_df_human["is_target"].value_counts(), ncbi_df_human["is_tf"].value_counts()
# Out:
# (is_target
#  True     11283
#  False      534
#  Name: count, dtype: int64,
#  is_tf
#  False    10633
#  True      1184
#  Name: count, dtype: int64)

# %%
# kepp only rows where the target is a DEG
tf_sig_df_human = tf_df_human[tf_df_human["NCBI.GeneID.Target"].isin(ncbi_df_human[ncbi_df_human["padj_dea"] <= 0.05]["target"])]
# add ensembl gene id for the TF and target
tf_sig_df_human['Ensembl.GeneID.TF'] = tf_sig_df_human['NCBI.GeneID.TF'].map(ncbi_to_ensembl)
tf_sig_df_human['Ensembl.GeneID.Target'] = tf_sig_df_human['NCBI.GeneID.Target'].map(ncbi_to_ensembl)
tf_sig_df_human.head(1)
# Out:
#   UniprotID.TF UniprotID.Target NCBI.GeneID.TF NCBI.GeneID.Target Name.TF  \
# 6       P13631           P05412           5916               3725    RARG
#
#   Name.Target     Detection.method  PubmedID      Organism Source.database  \
# 6         JUN  inferred by curator  17202159  Homo sapiens            TRED
#
#   Small-scale.evidence      TF.TFLink.ortho TF.nonTFLink.ortho  \
# 6                  Yes  Dr:Q91392;Mm:P18911          Rn:D3ZF61
#
#              Target.TFLink.ortho Target.nonTFLink.ortho Ensembl.GeneID.TF  \
# 6  Dr:Q6NZT5;Mm:P05627;Rn:P17325                      -   ENSG00000172819
#
#   Ensembl.GeneID.Target
# 6       ENSG00000177606

# %%
tf_sig_df_human[tf_sig_df_human["Name.TF"] == "MYC"]["Name.Target"].unique()
# Out:
# array(['PKM', 'TGFB3', 'TUBG1', 'HERPUD1', 'PMVK', 'IGF2R', 'TMPO',
#        'AKR1A1', 'MCM7', 'PPIF', 'GAPDH', 'NDUFS1', 'ETFDH', 'GCLC',
#        'FECH', 'ZPR1', 'JUN', 'PARP1', 'DCAF11', 'AXIN2', 'MYC', 'ETS2',
#        'CD38', 'AP4M1', 'DUSP1', 'GADD45A', 'EIF3B', 'CDCA7', 'TFRC',
#        'NOP56', 'NDUFV1', 'IFNAR1', 'ACO2', 'ABCB6', 'CDKN1A', 'DAXX',
#        'ETFA', 'UNG', 'PRDX3', 'ARHGEF9', 'EFCAB7', 'CHSY1', 'SLC30A9',
#        'ECHDC1', 'MT-CO2', 'COQ6', 'GNG2', 'AGO4', 'GOLGA6L9', 'AOPEP',
#        'ECHS1', 'NFE2L2', 'ZFP36', 'ACKR1', 'PM20D2', 'MYLK4', 'SRRT',
#        'ING2', 'DBT', 'NUCKS1', 'CERT1', 'TBL2', 'GDI1', 'CIAO2A',
#        'HABP4', 'RMDN3', 'FABP3', 'LTBP1', 'INSIG1', 'PAAF1', 'ZNF367',
#        'FIBIN', 'NDUFA9', 'COQ9', 'FAM210A', 'LYSMD4', 'SC5D', 'ATP6V0D1',
#        'CD2BP2', 'HNRNPAB', 'FTH1', 'DOP1B', 'PNPLA4', 'OLFML3', 'CEP112',
#        'CLTCL1', 'OTUD1', 'PLAAT1', 'RBM19', 'IBTK', 'FOXO1', 'ALDH1A2',
#        'ADAMTS1', 'TP53BP1', 'LACTB', 'BCL6', 'SPRYD4', 'DCAF6', 'DGKG',
#        'NSF', 'FHL1', 'SUCLG1', 'EIF4EBP1', 'CAMTA1', 'AUP1', 'CPSF4',
#        'BTG2', 'NFKBIA', 'PCCA', 'COL1A2', 'KCNE4', 'SCN7A', 'GGPS1',
#        'NR1H3', 'ARHGEF6', 'NIPSNAP3B', 'TMED1', 'PPRC1', 'HSCB', 'PAN2',
#        'DMAC2', 'ARHGAP18', 'GCSH', 'TMEM185A', 'MT-ND3', 'UBE2D4',
#        'AGBL1', 'SRXN1', 'GSTZ1', 'CLYBL', 'NOP2', 'MCF2L2', 'ANAPC1',
#        'EIF4EBP3', 'CYP4V2', 'ACADSB', 'FBN1', 'THY1', 'MYL3', 'ANK2',
#        'HMG20A', 'HIBADH', 'ENTR1', 'CAPRIN2', 'CCS', 'SLC36A1', 'FGL2',
#        'AGL', 'TAB2', 'ATP5MC3', 'TNFRSF12A', 'LRP2BP', 'MT-CO3',
#        'TMEM159', 'ZNF608', 'NUP210', 'FNDC5', 'ACIN1', 'TAF1',
#        'KIDINS220', 'INHBB', 'PEX7', 'CDK11A', 'NDUFA10', 'ACAT1',
#        'NDUFS2', 'GDNF', 'NAV1', 'TSPYL2', 'RBP1', 'GRSF1', 'RET',
#        'HACD2', 'CA14', 'OSBPL8', 'CKMT2', 'MRPL16', 'SLC25A12',
#        'EPB41L2', 'C1RL', 'SDHC', 'MARK4', 'UQCC1', 'TOR3A', 'ADPRH',
#        'PRRX1', 'FAM174B', 'XBP1', 'ETV5', 'OPN3', 'MYG1', 'PCNT',
#        'RBFOX1', 'KHDRBS1', 'DHRS12', 'GNL2', 'SIRT5', 'BOLA1', 'HERC1',
#        'SLCO5A1', 'TSTA3', 'NRG4', 'RFTN1', 'HAPLN3', 'POLDIP3', 'MFSD6',
#        'SMIM20', 'LRPAP1', 'GATB', 'NMT1', 'RASD1', 'MT-CO1', 'SLCO4A1',
#        'ARHGAP10', 'TMEM50B', 'MFN2', 'ST3GAL5', 'NTAN1', 'KCTD9', 'CA11',
#        'NARS2', 'RANBP10', 'BHLHB9', 'GAB2', 'SHISA4', 'CYB5D2', 'NDUFS3',
#        'IARS2', 'ZDHHC7', 'TIMELESS', 'LDLRAD4', 'MT1X', 'PGAM2', 'BLCAP',
#        'KIF22', 'APBA1', 'SYNJ2BP', 'KRTCAP2', 'MICU1', 'CMC4', 'RCAN3',
#        'DLD', 'ADA2', 'CHRNG', 'C1orf122', 'PKD1L1', 'CSAD', 'RAB9B',
#        'NEDD1', 'BRAWNIN', 'HLTF', 'PPP2R5D', 'FSTL1', 'MKKS', 'MOSPD1',
#        'VLDLR', 'IDH2', 'PDHB', 'SIL1', 'DNASE1', 'MT-ND5', 'PKIA',
#        'DDX41', 'NUP85', 'MEMO1', 'AMOTL1', 'OXNAD1', 'PTP4A2', 'EEF2KMT',
#        'ALDOA', 'SLC38A4', 'BNIP3', 'NMNAT3', 'DECR1', 'PLN', 'CSRNP1',
#        'MAP3K7CL', 'GRIPAP1', 'PRKAG2', 'GSE1', 'CDH13', 'DDIT4', 'PARP4',
#        'GUF1', 'MTMR2', 'ASTN2', 'DDX27', 'CCDC80', 'AUH', 'CCDC107',
#        'SIRT4', 'ANKRD2', 'PTRHD1', 'GALNT1', 'ANKRD1', 'COQ10A', 'SCRN3',
#        'ZC3H10', 'MFGE8', 'SSRP1', 'LRRC41', 'EMD', 'PCBD1', 'TECRL',
#        'TIGD1', 'MT-ND2', 'RAPGEF2', 'ACTR1A', 'TACO1', 'BRMS1',
#        'SELENOM', 'PLA2G12A', 'APOD', 'AIG1', 'PRDX5', 'TXNL4A', 'ZCRB1',
#        'ABCA5', 'SNTB1', 'BTRC', 'RRP1', 'GADD45G', 'LRP4', 'VPS53',
#        'PHYH', 'TMLHE', 'CFAP61', 'ABCA1', 'CKAP2', 'PPP1R27', 'GOT2',
#        'PHPT1', 'CCN1', 'TRO', 'XIRP1', 'COX7B', 'CPT2', 'CCDC28B',
#        'SOCS3', 'MRPS24', 'PPP1R10', 'MRPL45', 'APRT', 'NDUFAB1', 'HSPB1',
#        'ARMCX4', 'USP54', 'MRPL44', 'RAB15', 'MB', 'FRAS1', 'BBS10',
#        'ANK1', 'RRAGD', 'MAP3K4', 'CDC42EP3', 'NIPSNAP2', 'SDF2L1',
#        'SLC35D1', 'PLCE1', 'APBB3', 'ICAM3', 'GNG5', 'P4HB', 'MT2A',
#        'GPX4', 'ADRM1', 'KRI1', 'PHKG2', 'MT-CYB', 'NXF1', 'FDXR',
#        'GLUD1', 'SPARC', 'CFAP44', 'ANGPT2', 'CEBPD', 'HMGCL', 'ATP6V1E2',
#        'CCDC167', 'CCNL2', 'ACBD5', 'NNT', 'PHKB', 'SFRP4', 'CKB', 'AATF',
#        'ADD3', 'WWP1', 'TMEM144', 'NADK2', 'CELF2', 'ABHD3', 'NUDT16',
#        'METTL15', 'NELFE', 'PRKACB', 'ARPP21', 'SLC35E3', 'SLC14A1',
#        'MBD5', 'PMP22', 'FAM149A', 'KCTD3', 'CARNMT1', 'CCDC124',
#        'PPP1R1C', 'AACS', 'PGRMC2', 'PAQR9', 'CHRAC1', 'PRICKLE2',
#        'ARMH3', 'DUT', 'RGN', 'LACTB2', 'RHOB', 'PSTPIP2', 'NNMT', 'BYSL',
#        'KCNQ5', 'SIRT3', 'SUCLG2', 'DHTKD1', 'AAMDC', 'RNPS1', 'UGCG',
#        'ATPAF1', 'ETFRF1', 'HSBP1L1', 'ZNRD2', 'TP63', 'RNF144A',
#        'ATP5F1B', 'KLHL7', 'CTPS1', 'SH3KBP1', 'PDHX', 'TTL', 'PTGDS',
#        'PPP1R12B', 'SPTB', 'KLF6', 'ALAS1', 'DCP1A', 'SUPV3L1', 'MT-ATP6',
#        'ARID5B', 'MT-ND4', 'TPPP3', 'HNRNPU', 'ABLIM2', 'C19orf12',
#        'SCP2', 'RNF5', 'NDUFAF5', 'LYRM7', 'DLST', 'KCTD2', 'ENC1',
#        'GSTK1', 'S100A1', 'IGFBP3', 'ACOT1', 'VPS16', 'KLF4', 'WASHC3',
#        'SLC22A3', 'IER5', 'UTRN', 'SLC7A6', 'APOOL', 'LRP1B', 'TPI1',
#        'PFKP', 'FBXO9', 'THSD4', 'SLC16A1', 'NUDT6', 'ATP5F1A', 'LOXL4',
#        'CYFIP2', 'RNF168', 'PPARA', 'GPX3', 'XPC', 'HIBCH', 'FAM171A1',
#        'SUCLA2', 'DNAJC19', 'MRM3', 'NTPCR', 'PRDX2', 'FUNDC2',
#        'TBC1D22B', 'IGSF3', 'DCUN1D5', 'SDHB', 'MYH6', 'MYORG', 'PSMG3',
#        'OXSM', 'B4GALT6', 'FERMT2', 'RNLS', 'DGLUCY', 'CPSF7', 'SCN3B',
#        'CNOT10', 'BLOC1S1', 'CCDC69', 'SMPD3', 'ARHGAP21', 'COX8A',
#        'KAZALD1', 'NREP', 'TMEM65', 'MT-ND1', 'SF3A1', 'SPPL2A', 'ARSG',
#        'EXOSC4', 'THSD1', 'CTNS', 'PLXDC1', 'SETD9', 'MT1E', 'UQCRC1',
#        'NGRN', 'NOXA1', 'BCKDHB', 'YARS2', 'CHRNA1', 'GTPBP8', 'MEA1',
#        'LIN37', 'ZCCHC2', 'CADM2', 'SYNPO2'], dtype=object)

# %%
tf_sig_df_human[tf_sig_df_human["Name.TF"] == "PDHX"]["Name.Target"].sort_values()
# Out:
# 2509282     AAMDC
# 5125177    ACADSB
# 1950997     ACBD5
# 831514     ACTR1A
# 3941183      AGO4
#             ...
# 2962146    WASHC3
# 3733022     YARS2
# 707720     ZC3H10
# 972910      ZCRB1
# 2592332     ZNRD2
# Name: Name.Target, Length: 77, dtype: object

# %%
tf_sig_df_human.shape
# Out:
# (192033, 17)

# %%
# Function to add targets and TFs to each row (gene)
def add_target_and_tf_interaction(ncbi_df, tf_df, filename):
    if not os.path.exists(filename):
        ncbi_df["its_target"] = None
        print(f"Processing targets. {ncbi_df.shape}")
        for index, row in ncbi_df.iterrows():
            if index % 2000 == 0 and index > 0:
                print(f"Processed {index} rows (targets).")
            if row["is_tf"]:
                targets = tf_df[tf_df["NCBI.GeneID.TF"] == row["target"]]
                if not targets.empty:
                    target_info_list = targets[["NCBI.GeneID.Target",
                                                "Ensembl.GeneID.Target",
                                                "Name.Target",
                                                "UniprotID.Target",
                                                "Target.TFLink.ortho",
                                                "Target.nonTFLink.ortho",
                                                "Detection.method",
                                                "PubmedID",
                                                "Source.database",
                                                "Small-scale.evidence",
                                            ]].to_dict(orient="records")
                    ncbi_df.at[index, "its_target"] = target_info_list
                else:
                    ncbi_df.at[index, "its_target"] = []

        ncbi_df["its_tf"] = None
        print("Processing TFs...")
        for index, row in ncbi_df.iterrows():
            if index % 2000 == 0 and index > 0:
                print(f"Processed {index} rows (TFs).")
            if row["is_target"] and row["padj_dea"] <= 0.05:
                tf = tf_df[tf_df["NCBI.GeneID.Target"] == row["target"]]
                if not tf.empty:
                    tf_info_list = tf[["NCBI.GeneID.TF",
                                       "Ensembl.GeneID.TF",
                                       "Name.TF",
                                       "UniprotID.TF",
                                       "TF.TFLink.ortho",
                                       "TF.nonTFLink.ortho",
                                       "Detection.method",
                                       "PubmedID",
                                       "Source.database",
                                       "Small-scale.evidence",
                                    ]].to_dict(orient="records")
                    ncbi_df.at[index, "its_tf"] = tf_info_list
                else:
                    # if row["padj_dea"] <= 0.05:
                    #     ncbi_df.at[index, "its_tf"] = None
                    # else:
                    ncbi_df.at[index, "its_tf"] = []

        ncbi_df.to_pickle(filename)

    else:
        with open(filename, 'rb') as f:
            ncbi_df = pickle.load(f)

    return ncbi_df

# Add target and TF
ncbi_tf_df_human = add_target_and_tf_interaction(ncbi_df_human, tf_sig_df_human, filename="data/human/ncbi_tf_df_human.pkl")
# Out:
# Processing targets. (11817, 15)
# Processed 2000 rows (targets).
# Processed 4000 rows (targets).
# Processed 6000 rows (targets).
# Processed 8000 rows (targets).
# Processed 10000 rows (targets).
# Processing TFs...
# Processed 2000 rows (TFs).
# Processed 4000 rows (TFs).
# Processed 6000 rows (TFs).
# Processed 8000 rows (TFs).
# Processed 10000 rows (TFs).

# %%
ncbi_tf_df_human.head()
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSG00000000003           Ensembl   7105     NCBI Gene          TSPAN6
# 1  ENSG00000000419           Ensembl   8813     NCBI Gene            DPM1
# 2  ENSG00000000457           Ensembl  57147     NCBI Gene           SCYL3
# 3  ENSG00000000938           Ensembl   2268     NCBI Gene             FGR
# 4  ENSG00000000971           Ensembl   3075     NCBI Gene             CFH
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  \
# 0    106.899174           -0.401659   0.143909 -2.791057    0.005254
# 1    601.924666           -0.104654   0.161936 -0.646270    0.518105
# 2    244.623536           -0.285418   0.118343 -2.411784    0.015875
# 3     91.958767            0.599304   0.342110  1.751786    0.079811
# 4    499.583125            0.079448   0.255376  0.311101    0.755724
#
#    padj_dea  minus_log10_pvalue_dea  is_tf  is_target its_target its_tf
# 0  0.077900                2.279542  False       True       None   None
# 1  0.783377                0.285582  False       True       None   None
# 2  0.141951                1.799295  False       True       None   None
# 3  0.328648                1.097940  False       True       None   None
# 4  0.907340                0.121637  False       True       None   None

# %%
ncbi_tf_df_human[ncbi_tf_df_human['its_target'].notna()].head(1)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 7  ENSG00000001167           Ensembl   4800     NCBI Gene            NFYA
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  \
# 7    198.963515            0.339027   0.133075  2.547627    0.010846
#
#    padj_dea  minus_log10_pvalue_dea  is_tf  is_target  \
# 7  0.114127                1.964737   True       True
#
#                                           its_target its_tf
# 7  [{'NCBI.GeneID.Target': '1647', 'Ensembl.GeneI...   None

# %%
ncbi_tf_df_human[ncbi_tf_df_human['target']=="1647"]
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 3343  ENSG00000116717           Ensembl   1647     NCBI Gene         GADD45A
#
#       baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  \
# 3343     448.20828            1.432184   0.377628  3.792579    0.000149
#
#       padj_dea  minus_log10_pvalue_dea  is_tf  is_target its_target  \
# 3343  0.008832                3.826549  False       True       None
#
#                                                  its_tf
# 3343  [{'NCBI.GeneID.TF': '672', 'Ensembl.GeneID.TF'...

# %%
ncbi_tf_df_human[ncbi_tf_df_human['target']=="1647"]["its_tf"].to_dict()
# Out:
# {3343: [{'NCBI.GeneID.TF': '672',
#    'Ensembl.GeneID.TF': 'ENSG00000012048',
#    'Name.TF': 'BRCA1',
#    'UniprotID.TF': 'P38398',
#    'TF.TFLink.ortho': 'Mm:P48754;Rn:G3V8S5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '17428466;12647291;18350249;11777930;10962562;27924024;18025037;17202159;29087512',
#    'Source.database': 'GTRD;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '4790',
#    'Ensembl.GeneID.TF': 'ENSG00000109320',
#    'Name.TF': 'NFKB1',
#    'UniprotID.TF': 'P19838',
#    'TF.TFLink.ortho': 'Dm:Q94527;Mm:P25799;Rn:F1LQH2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '367',
#    'Ensembl.GeneID.TF': 'ENSG00000169083',
#    'Name.TF': 'AR',
#    'UniprotID.TF': 'P10275',
#    'TF.TFLink.ortho': 'Mm:P19091;Rn:A0A0G2JSI8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation array;chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;20610535;27924024;17202159;22900683',
#    'Source.database': 'GTRD;HTRI;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '6599',
#    'Ensembl.GeneID.TF': 'ENSG00000173473',
#    'Name.TF': 'SMARCC1',
#    'UniprotID.TF': 'Q92922',
#    'TF.TFLink.ortho': 'Mm:P97496;Rn:A0A0G2K9D6',
#    'TF.nonTFLink.ortho': 'Dr:F1Q9K1',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;24234451;24434208',
#    'Source.database': 'GTRD;IntAct_via_DoRothEA;ReMap',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5914',
#    'Ensembl.GeneID.TF': 'ENSG00000131759',
#    'Name.TF': 'RARA',
#    'UniprotID.TF': 'P10276',
#    'TF.TFLink.ortho': 'Mm:P11416;Rn:A0A0G2JW78',
#    'TF.nonTFLink.ortho': 'Dr:T2DKU4',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27924024;17202159',
#    'Source.database': 'GTRD;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '4800',
#    'Ensembl.GeneID.TF': 'ENSG00000001167',
#    'Name.TF': 'NFYA',
#    'UniprotID.TF': 'P23511',
#    'TF.TFLink.ortho': 'Mm:P23708',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2KB97',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;11525640;11420680;27924024;29087512',
#    'Source.database': 'GTRD;ReMap;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '2309',
#    'Ensembl.GeneID.TF': 'ENSG00000118689',
#    'Name.TF': 'FOXO3',
#    'UniprotID.TF': 'O43524',
#    'TF.TFLink.ortho': 'Dr:Q5TYS1;Mm:Q9WVH4;Rn:D3ZBQ1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27899662;11964479;22761861;27924024;12048180',
#    'Source.database': 'GTRD;KEGG_via_DoRothEA;TFactS_via_DoRothea',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5467',
#    'Ensembl.GeneID.TF': 'ENSG00000112033',
#    'Name.TF': 'PPARD',
#    'UniprotID.TF': 'Q03181',
#    'TF.TFLink.ortho': 'Dr:A9C4A5;Mm:P35396;Rn:Q99ND3',
#    'TF.nonTFLink.ortho': 'Dr:F8W3D2',
#    'Detection.method': 'inferred by curator',
#    'PubmedID': '17202159',
#    'Source.database': 'TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '1874',
#    'Ensembl.GeneID.TF': 'ENSG00000205250',
#    'Name.TF': 'E2F4',
#    'UniprotID.TF': 'Q16254',
#    'TF.TFLink.ortho': 'Dr:A0A0R4ICD5;Mm:Q8R0K9;Rn:D4A9V4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;26578589;18971253;27924024;17202159',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '1050',
#    'Ensembl.GeneID.TF': 'ENSG00000245848',
#    'Name.TF': 'CEBPA',
#    'UniprotID.TF': 'P49715',
#    'TF.TFLink.ortho': 'Dr:Q8UVZ1;Mm:P53566;Rn:A0A0H2UI22',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;26578589;18971253;27924024;17202159',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '3727',
#    'Ensembl.GeneID.TF': 'ENSG00000130522',
#    'Name.TF': 'JUND',
#    'UniprotID.TF': 'P17535',
#    'TF.TFLink.ortho': 'Dr:B0V1Q6;Mm:P15066;Rn:P52909',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;electrophoretic mobility shift assay;inferred by curator',
#    'PubmedID': '29126285;27924024;29087512;22900683;17084916',
#    'Source.database': 'GTRD;HTRI;ReMap;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5465',
#    'Ensembl.GeneID.TF': 'ENSG00000186951',
#    'Name.TF': 'PPARA',
#    'UniprotID.TF': 'Q07869',
#    'TF.TFLink.ortho': 'Dr:K7DY57;Mm:P23204;Rn:P37230',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'inferred by curator',
#    'PubmedID': '17202159',
#    'Source.database': 'TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '472',
#    'Ensembl.GeneID.TF': 'ENSG00000149311',
#    'Name.TF': 'ATM',
#    'UniprotID.TF': 'Q13315',
#    'TF.TFLink.ortho': 'Mm:Q62388;Rn:D4ACL8',
#    'TF.nonTFLink.ortho': 'Dr:R4GE34',
#    'Detection.method': 'inferred by curator',
#    'PubmedID': '20164679;29087512',
#    'Source.database': 'TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '4609',
#    'Ensembl.GeneID.TF': 'ENSG00000136997',
#    'Name.TF': 'MYC',
#    'UniprotID.TF': 'P01106',
#    'TF.TFLink.ortho': 'Dr:F1RC36;Mm:P01108',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;15021909;22761861;27924024;22900683;14519204',
#    'Source.database': 'GTRD;HTRI;ReMap;TFactS_via_DoRothea',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '2099',
#    'Ensembl.GeneID.TF': 'ENSG00000091831',
#    'Name.TF': 'ESR1',
#    'UniprotID.TF': 'P03372',
#    'TF.TFLink.ortho': 'Mm:P19785',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K0D4',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27924024;17202159',
#    'Source.database': 'GTRD;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5451',
#    'Ensembl.GeneID.TF': 'ENSG00000143190',
#    'Name.TF': 'POU2F1',
#    'UniprotID.TF': 'P14859',
#    'TF.TFLink.ortho': 'Rn:F1LRD7',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4J1Z4',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;11525640;11420680;27924024;17202159;29087512',
#    'Source.database': 'GTRD;ReMap;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '7157',
#    'Ensembl.GeneID.TF': 'ENSG00000141510',
#    'Name.TF': 'TP53',
#    'UniprotID.TF': 'P04637',
#    'TF.TFLink.ortho': 'Mm:P02340',
#    'TF.nonTFLink.ortho': 'Dr:B0R0M3;Rn:M0R497',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;18350249;27899662;18431400;10566557;31340985;26578589;10327059;12007564;18225552;15031557;17344317;18971253;27924024;17202159;29087512;16581545',
#    'Source.database': 'DoRothEA;GTRD;KEGG_via_DoRothEA;ORegAnno;PAZAR;ReMap;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5468',
#    'Ensembl.GeneID.TF': 'ENSG00000132170',
#    'Name.TF': 'PPARG',
#    'UniprotID.TF': 'P37231',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '22880',
#    'Ensembl.GeneID.TF': 'ENSG00000133422',
#    'Name.TF': 'MORC2',
#    'UniprotID.TF': 'Q9Y6X9',
#    'TF.TFLink.ortho': 'Dr:Q68EG7;Mm:Q69ZX6;Rn:A0A0G2JWF7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57634',
#    'Ensembl.GeneID.TF': 'ENSG00000183495',
#    'Name.TF': 'EP400',
#    'UniprotID.TF': 'Q96L91',
#    'TF.TFLink.ortho': 'Mm:Q8CHI8;Rn:A0A0G2JU09',
#    'TF.nonTFLink.ortho': 'Dm:A0A0B4LFX8;Dr:A0A0R4IGB8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29781',
#    'Ensembl.GeneID.TF': 'ENSG00000025770',
#    'Name.TF': 'NCAPH2',
#    'UniprotID.TF': 'Q6IBW4',
#    'TF.TFLink.ortho': 'Dr:Q5RH01;Mm:Q8BSP2',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K4H8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8726',
#    'Ensembl.GeneID.TF': 'ENSG00000074266',
#    'Name.TF': 'EED',
#    'UniprotID.TF': 'O75530',
#    'TF.TFLink.ortho': 'Ce:Q9GYS1;Dm:Q9VKD5;Dr:Q566T0;Mm:Q921E6;Rn:B5DF02',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2625',
#    'Ensembl.GeneID.TF': 'ENSG00000107485',
#    'Name.TF': 'GATA3',
#    'UniprotID.TF': 'P23771',
#    'TF.TFLink.ortho': 'Dr:Q91428;Mm:P23772;Rn:Q99NH5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024;29126285;22900683;21878914',
#    'Source.database': 'GTRD;HTRI;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84662',
#    'Ensembl.GeneID.TF': 'ENSG00000126603',
#    'Name.TF': 'GLIS2',
#    'UniprotID.TF': 'Q9BZE0',
#    'TF.TFLink.ortho': 'Mm:Q8VDL9;Rn:D3ZIA9',
#    'TF.nonTFLink.ortho': 'Dr:A0A0R4IE83',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6598',
#    'Ensembl.GeneID.TF': 'ENSG00000099956',
#    'Name.TF': 'SMARCB1',
#    'UniprotID.TF': 'Q12824',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2122',
#    'Ensembl.GeneID.TF': 'ENSG00000085276',
#    'Name.TF': 'MECOM',
#    'UniprotID.TF': 'Q03112',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': 'Mm:G3UZT5;Rn:D3ZM26',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5090',
#    'Ensembl.GeneID.TF': 'ENSG00000167081',
#    'Name.TF': 'PBX3',
#    'UniprotID.TF': 'P40426',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6908',
#    'Ensembl.GeneID.TF': 'ENSG00000112592',
#    'Name.TF': 'TBP',
#    'UniprotID.TF': 'P20226',
#    'TF.TFLink.ortho': 'Dr:Q7SXL3;Mm:P29037;Rn:Q66HB1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3516',
#    'Ensembl.GeneID.TF': 'ENSG00000168214',
#    'Name.TF': 'RBPJ',
#    'UniprotID.TF': 'Q06330',
#    'TF.TFLink.ortho': 'Dm:P28159;Dr:A4FTT3;Mm:P31266;Rn:M0R7Q3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10664',
#    'Ensembl.GeneID.TF': 'ENSG00000102974',
#    'Name.TF': 'CTCF',
#    'UniprotID.TF': 'P49711',
#    'TF.TFLink.ortho': 'Dr:Q6JAA4;Mm:Q61164;Rn:A0A0H2UHP0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4000',
#    'Ensembl.GeneID.TF': 'ENSG00000160789',
#    'Name.TF': 'LMNA',
#    'UniprotID.TF': 'P02545',
#    'TF.TFLink.ortho': 'Mm:P48678;Rn:G3V8L3',
#    'TF.nonTFLink.ortho': 'Dr:B3DKC5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '79718',
#    'Ensembl.GeneID.TF': 'ENSG00000177565',
#    'Name.TF': 'TBL1XR1',
#    'UniprotID.TF': 'Q9BZK7',
#    'TF.TFLink.ortho': 'Dr:A5PF33;Mm:Q8BHJ5;Sc:P38262',
#    'TF.nonTFLink.ortho': 'Rn:D3ZNF4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3607',
#    'Ensembl.GeneID.TF': 'ENSG00000141568',
#    'Name.TF': 'FOXK2',
#    'UniprotID.TF': 'Q01167',
#    'TF.TFLink.ortho': 'Dr:E7FFM9;Mm:Q3UCQ1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3609',
#    'Ensembl.GeneID.TF': 'ENSG00000129351',
#    'Name.TF': 'ILF3',
#    'UniprotID.TF': 'Q12906',
#    'TF.TFLink.ortho': 'Mm:Q9Z1X4',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K4U6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5316',
#    'Ensembl.GeneID.TF': 'ENSG00000160199',
#    'Name.TF': 'PKNOX1',
#    'UniprotID.TF': 'P55347',
#    'TF.TFLink.ortho': 'Dr:E7FBG0;Mm:O70477',
#    'TF.nonTFLink.ortho': 'Rn:Q5BJP1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6722',
#    'Ensembl.GeneID.TF': 'ENSG00000112658',
#    'Name.TF': 'SRF',
#    'UniprotID.TF': 'P11831',
#    'TF.TFLink.ortho': 'Mm:Q9JM73;Rn:D3ZHH8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27161',
#    'Ensembl.GeneID.TF': 'ENSG00000123908',
#    'Name.TF': 'AGO2',
#    'UniprotID.TF': 'Q9UKV8',
#    'TF.TFLink.ortho': 'Mm:Q8CJG0;Rn:F1LRP7',
#    'TF.nonTFLink.ortho': 'Dr:E7EXY4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7155',
#    'Ensembl.GeneID.TF': 'ENSG00000077097',
#    'Name.TF': 'TOP2B',
#    'UniprotID.TF': 'Q02880',
#    'TF.TFLink.ortho': 'Dr:Q1LUT2;Mm:Q64511',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '60436',
#    'Ensembl.GeneID.TF': 'ENSG00000118707',
#    'Name.TF': 'TGIF2',
#    'UniprotID.TF': 'Q9GZN2',
#    'TF.TFLink.ortho': 'Mm:Q8C0Y1;Rn:B5DEL6',
#    'TF.nonTFLink.ortho': 'Rn:M0RCY5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9611',
#    'Ensembl.GeneID.TF': 'ENSG00000141027',
#    'Name.TF': 'NCOR1',
#    'UniprotID.TF': 'O75376',
#    'TF.TFLink.ortho': 'Rn:A0A0G2K2B4',
#    'TF.nonTFLink.ortho': 'Mm:Q5RIM6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6777',
#    'Ensembl.GeneID.TF': 'ENSG00000173757',
#    'Name.TF': 'STAT5B',
#    'UniprotID.TF': 'P51692',
#    'TF.TFLink.ortho': 'Mm:P42232;Rn:A0A0G2JSR4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '25842',
#    'Ensembl.GeneID.TF': 'ENSG00000111875',
#    'Name.TF': 'ASF1A',
#    'UniprotID.TF': 'Q9Y294',
#    'TF.TFLink.ortho': 'Dm:Q9V464;Dr:Q6NY34;Dr:Q6NYY4;Mm:Q9CQE6;Rn:D3ZFM1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27154',
#    'Ensembl.GeneID.TF': 'ENSG00000096070',
#    'Name.TF': 'BRPF3',
#    'UniprotID.TF': 'Q9ULD4',
#    'TF.TFLink.ortho': 'Dr:F6P390;Mm:B2KF05;Rn:D3ZMD3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2078',
#    'Ensembl.GeneID.TF': 'ENSG00000157554',
#    'Name.TF': 'ERG',
#    'UniprotID.TF': 'P11308',
#    'TF.TFLink.ortho': 'Mm:P81270',
#    'TF.nonTFLink.ortho': 'Dr:F1QK28;Rn:A0A0G2JWE9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23186',
#    'Ensembl.GeneID.TF': 'ENSG00000089902',
#    'Name.TF': 'RCOR1',
#    'UniprotID.TF': 'Q9UKL0',
#    'TF.TFLink.ortho': 'Dr:Q1MTF5',
#    'TF.nonTFLink.ortho': 'Rn:F1LXS5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4152',
#    'Ensembl.GeneID.TF': 'ENSG00000141644',
#    'Name.TF': 'MBD1',
#    'UniprotID.TF': 'Q9UIS9',
#    'TF.TFLink.ortho': 'Rn:Q66HB8',
#    'TF.nonTFLink.ortho': 'Mm:A0A286YDI1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27125',
#    'Ensembl.GeneID.TF': 'ENSG00000072364',
#    'Name.TF': 'AFF4',
#    'UniprotID.TF': 'Q9UHB7',
#    'TF.TFLink.ortho': 'Dm:Q9XZ21;Dr:I3ISK1;Mm:Q9ESC8;Rn:D3ZSX2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2313',
#    'Ensembl.GeneID.TF': 'ENSG00000151702',
#    'Name.TF': 'FLI1',
#    'UniprotID.TF': 'Q01543',
#    'TF.TFLink.ortho': 'Mm:P26323;Rn:Q4Z8P1',
#    'TF.nonTFLink.ortho': 'Dr:Q9PU61',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '167465',
#    'Ensembl.GeneID.TF': 'ENSG00000178175',
#    'Name.TF': 'ZNF366',
#    'UniprotID.TF': 'Q8N895',
#    'TF.TFLink.ortho': 'Mm:Q6NS86',
#    'TF.nonTFLink.ortho': 'Rn:D4A715',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23435',
#    'Ensembl.GeneID.TF': 'ENSG00000120948',
#    'Name.TF': 'TARDBP',
#    'UniprotID.TF': 'Q13148',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7003',
#    'Ensembl.GeneID.TF': 'ENSG00000187079',
#    'Name.TF': 'TEAD1',
#    'UniprotID.TF': 'P28347',
#    'TF.TFLink.ortho': 'Rn:A0A0G2K2N3',
#    'TF.nonTFLink.ortho': 'Dm:A8JUY5;Dr:F8W5M8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1027',
#    'Ensembl.GeneID.TF': 'ENSG00000111276',
#    'Name.TF': 'CDKN1B',
#    'UniprotID.TF': 'P46527',
#    'TF.TFLink.ortho': 'Mm:P46414;Rn:O08769',
#    'TF.nonTFLink.ortho': 'Ce:U4PBK8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1024',
#    'Ensembl.GeneID.TF': 'ENSG00000132964',
#    'Name.TF': 'CDK8',
#    'UniprotID.TF': 'P49336',
#    'TF.TFLink.ortho': 'Dm:Q9VT57;Dr:A8E4S2;Mm:Q8R3L8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4149',
#    'Ensembl.GeneID.TF': 'ENSG00000125952',
#    'Name.TF': 'MAX',
#    'UniprotID.TF': 'P61244',
#    'TF.TFLink.ortho': 'Ce:G5EEH5;Dm:P91664;Mm:P28574;Rn:P52164',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '15021909;29126285;22900683;27924024',
#    'Source.database': 'GTRD;HTRI;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '64763',
#    'Ensembl.GeneID.TF': 'ENSG00000105732',
#    'Name.TF': 'ZNF574',
#    'UniprotID.TF': 'Q6ZN55',
#    'TF.TFLink.ortho': 'Mm:Q8BY46;Rn:Q504L7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6613',
#    'Ensembl.GeneID.TF': 'ENSG00000188612',
#    'Name.TF': 'SUMO2',
#    'UniprotID.TF': 'P61956',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '657',
#    'Ensembl.GeneID.TF': 'ENSG00000107779',
#    'Name.TF': 'BMPR1A',
#    'UniprotID.TF': 'P36894',
#    'TF.TFLink.ortho': 'Mm:P36895;Rn:Q78EA7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4841',
#    'Ensembl.GeneID.TF': 'ENSG00000147140',
#    'Name.TF': 'NONO',
#    'UniprotID.TF': 'Q15233',
#    'TF.TFLink.ortho': 'Dr:Q802Z5;Mm:Q99K48;Rn:Q5FVM4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27107',
#    'Ensembl.GeneID.TF': 'ENSG00000066422',
#    'Name.TF': 'ZBTB11',
#    'UniprotID.TF': 'O95625',
#    'TF.TFLink.ortho': 'Dr:F1RAC1;Mm:G5E8B9;Rn:D3ZDP9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57504',
#    'Ensembl.GeneID.TF': 'ENSG00000057935',
#    'Name.TF': 'MTA3',
#    'UniprotID.TF': 'Q9BTC8',
#    'TF.TFLink.ortho': 'Mm:Q924K8;Rn:A0A0G2JTK6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1877',
#    'Ensembl.GeneID.TF': 'ENSG00000167967',
#    'Name.TF': 'E4F1',
#    'UniprotID.TF': 'Q66K89',
#    'TF.TFLink.ortho': 'Mm:Q8CCE9;Rn:F1MAM9',
#    'TF.nonTFLink.ortho': 'Dm:O61362;Dr:F1R041',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3090',
#    'Ensembl.GeneID.TF': 'ENSG00000177374',
#    'Name.TF': 'HIC1',
#    'UniprotID.TF': 'Q14526',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7936',
#    'Ensembl.GeneID.TF': 'ENSG00000204356',
#    'Name.TF': 'NELFE',
#    'UniprotID.TF': 'P18615',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10614',
#    'Ensembl.GeneID.TF': 'ENSG00000186834',
#    'Name.TF': 'HEXIM1',
#    'UniprotID.TF': 'O94992',
#    'TF.TFLink.ortho': 'Mm:Q8R409;Rn:Q5M9G1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23133',
#    'Ensembl.GeneID.TF': 'ENSG00000172943',
#    'Name.TF': 'PHF8',
#    'UniprotID.TF': 'Q9UPP1',
#    'TF.TFLink.ortho': 'Dr:P0CH95;Mm:Q80TJ7;Rn:D4AD31',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6659',
#    'Ensembl.GeneID.TF': 'ENSG00000124766',
#    'Name.TF': 'SOX4',
#    'UniprotID.TF': 'Q06945',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IQD2;Mm:Q06831',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '11100',
#    'Ensembl.GeneID.TF': 'ENSG00000105323',
#    'Name.TF': 'HNRNPUL1',
#    'UniprotID.TF': 'Q9BUJ2',
#    'TF.TFLink.ortho': 'Dr:Q1L9A1;Dr:E7F071;Mm:Q8VDM6;Rn:D4A962',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4779',
#    'Ensembl.GeneID.TF': 'ENSG00000082641',
#    'Name.TF': 'NFE2L1',
#    'UniprotID.TF': 'Q14494',
#    'TF.TFLink.ortho': 'Dr:U3JAR7;Mm:Q61985;Rn:D4A349',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6651',
#    'Ensembl.GeneID.TF': 'ENSG00000159140',
#    'Name.TF': 'SON',
#    'UniprotID.TF': 'P18583',
#    'TF.TFLink.ortho': 'Mm:Q9QX47;Rn:F1MAQ7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8625',
#    'Ensembl.GeneID.TF': 'ENSG00000064490',
#    'Name.TF': 'RFXANK',
#    'UniprotID.TF': 'O14593',
#    'TF.TFLink.ortho': 'Dm:Q9VL58;Dr:B3DI78;Mm:Q9Z205;Rn:Q5PQM6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5929',
#    'Ensembl.GeneID.TF': 'ENSG00000117222',
#    'Name.TF': 'RBBP5',
#    'UniprotID.TF': 'Q15291',
#    'TF.TFLink.ortho': 'Ce:Q09309;Dm:Q9VPH8;Mm:Q8BX09;Rn:D3ZC01;Sc:P39706',
#    'TF.nonTFLink.ortho': 'Dr:F1QST7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23028',
#    'Ensembl.GeneID.TF': 'ENSG00000004487',
#    'Name.TF': 'KDM1A',
#    'UniprotID.TF': 'O60341',
#    'TF.TFLink.ortho': 'Dm:Q9VW97;Dr:F6NIA2;Mm:Q6ZQ88;Rn:F1MA31',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '24149',
#    'Ensembl.GeneID.TF': 'ENSG00000171467',
#    'Name.TF': 'ZNF318',
#    'UniprotID.TF': 'Q5VUA4',
#    'TF.TFLink.ortho': 'Mm:Q99PP2;Rn:F1M0H0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9314',
#    'Ensembl.GeneID.TF': 'ENSG00000136826',
#    'Name.TF': 'KLF4',
#    'UniprotID.TF': 'O43474',
#    'TF.TFLink.ortho': 'Mm:Q60793;Rn:Q923V7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4199',
#    'Ensembl.GeneID.TF': 'ENSG00000065833',
#    'Name.TF': 'ME1',
#    'UniprotID.TF': 'P48163',
#    'TF.TFLink.ortho': 'Mm:P06801;Rn:A0A0G2K1S6',
#    'TF.nonTFLink.ortho': 'Dr:F1QU54',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '58486',
#    'Ensembl.GeneID.TF': 'ENSG00000236287',
#    'Name.TF': 'ZBED5',
#    'UniprotID.TF': 'Q49AG3',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10589',
#    'Ensembl.GeneID.TF': 'ENSG00000175550',
#    'Name.TF': 'DRAP1',
#    'UniprotID.TF': 'Q14919',
#    'TF.TFLink.ortho': 'Dr:F1R8S0;Mm:Q9D6N5;Rn:A0JPP1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29117',
#    'Ensembl.GeneID.TF': 'ENSG00000166164',
#    'Name.TF': 'BRD7',
#    'UniprotID.TF': 'Q9NPI1',
#    'TF.TFLink.ortho': 'Ce:Q17581;Dr:B0S7E1;Mm:O88665;Rn:A0A0G2JTM7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3054',
#    'Ensembl.GeneID.TF': 'ENSG00000172534',
#    'Name.TF': 'HCFC1',
#    'UniprotID.TF': 'P51610',
#    'TF.TFLink.ortho': 'Dr:F1Q750;Dr:A8WIP5;Mm:Q61191;Rn:D3ZN95',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6046',
#    'Ensembl.GeneID.TF': 'ENSG00000204256',
#    'Name.TF': 'BRD2',
#    'UniprotID.TF': 'P25440',
#    'TF.TFLink.ortho': 'Mm:Q7JJ13',
#    'TF.nonTFLink.ortho': 'Dr:Q1LWX7;Rn:Q6MGA9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57459',
#    'Ensembl.GeneID.TF': 'ENSG00000143614',
#    'Name.TF': 'GATAD2B',
#    'UniprotID.TF': 'Q8WXI9',
#    'TF.TFLink.ortho': 'Mm:Q8VHR5;Rn:Q4V8E1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10155',
#    'Ensembl.GeneID.TF': 'ENSG00000130726',
#    'Name.TF': 'TRIM28',
#    'UniprotID.TF': 'Q13263',
#    'TF.TFLink.ortho': 'Mm:Q62318;Rn:O08629',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;18971253;27924024;26578589',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '11198',
#    'Ensembl.GeneID.TF': 'ENSG00000092201',
#    'Name.TF': 'SUPT16H',
#    'UniprotID.TF': 'Q9Y5B9',
#    'TF.TFLink.ortho': 'Ce:Q9N5R9;Dm:Q8IRG6;Mm:G3X956;Rn:D4A4J0;Sc:P32558',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1997',
#    'Ensembl.GeneID.TF': 'ENSG00000120690',
#    'Name.TF': 'ELF1',
#    'UniprotID.TF': 'P32519',
#    'TF.TFLink.ortho': 'Dr:E7F1J0;Mm:Q60775',
#    'TF.nonTFLink.ortho': 'Rn:G3V9V2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '894',
#    'Ensembl.GeneID.TF': 'ENSG00000118971',
#    'Name.TF': 'CCND2',
#    'UniprotID.TF': 'P30279',
#    'TF.TFLink.ortho': 'Dr:F1R9R4;Mm:P30280;Rn:G3V8M9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51157',
#    'Ensembl.GeneID.TF': 'ENSG00000213015',
#    'Name.TF': 'ZNF580',
#    'UniprotID.TF': 'Q9UK33',
#    'TF.TFLink.ortho': 'Mm:Q9DB38',
#    'TF.nonTFLink.ortho': 'Rn:D4A235',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23462',
#    'Ensembl.GeneID.TF': 'ENSG00000164683',
#    'Name.TF': 'HEY1',
#    'UniprotID.TF': 'Q9Y5J3',
#    'TF.TFLink.ortho': 'Dr:Q8AXV6;Rn:D3ZNI5',
#    'TF.nonTFLink.ortho': 'Mm:Q9QUM5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8626',
#    'Ensembl.GeneID.TF': 'ENSG00000073282',
#    'Name.TF': 'TP63',
#    'UniprotID.TF': 'Q9H3D4',
#    'TF.TFLink.ortho': 'Mm:O88898;Rn:Q9JJP6',
#    'TF.nonTFLink.ortho': 'Dr:F1QLJ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8050',
#    'Ensembl.GeneID.TF': 'ENSG00000110435',
#    'Name.TF': 'PDHX',
#    'UniprotID.TF': 'O00330',
#    'TF.TFLink.ortho': 'Mm:Q8BKZ9',
#    'TF.nonTFLink.ortho': 'Dr:Q6NW45;Rn:A0A0G2JZH8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2000',
#    'Ensembl.GeneID.TF': 'ENSG00000102034',
#    'Name.TF': 'ELF4',
#    'UniprotID.TF': 'Q99607',
#    'TF.TFLink.ortho': 'Mm:Q9Z2U4',
#    'TF.nonTFLink.ortho': 'Rn:D3ZWM8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10127',
#    'Ensembl.GeneID.TF': 'ENSG00000006194',
#    'Name.TF': 'ZNF263',
#    'UniprotID.TF': 'O14978',
#    'TF.TFLink.ortho': 'Mm:Q8CF60;Rn:D3ZQ68',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4335',
#    'Ensembl.GeneID.TF': 'ENSG00000070444',
#    'Name.TF': 'MNT',
#    'UniprotID.TF': 'Q99583',
#    'TF.TFLink.ortho': 'Mm:O08789;Rn:A0A0U1RRY7',
#    'TF.nonTFLink.ortho': 'Dr:F1QBK5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10346',
#    'Ensembl.GeneID.TF': 'ENSG00000132274',
#    'Name.TF': 'TRIM22',
#    'UniprotID.TF': 'Q8IYM9',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5093',
#    'Ensembl.GeneID.TF': 'ENSG00000169564',
#    'Name.TF': 'PCBP1',
#    'UniprotID.TF': 'Q15365',
#    'TF.TFLink.ortho': 'Mm:P60335',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10413',
#    'Ensembl.GeneID.TF': 'ENSG00000137693',
#    'Name.TF': 'YAP1',
#    'UniprotID.TF': 'P46937',
#    'TF.TFLink.ortho': 'Dr:Q1L8J7;Mm:P46938;Rn:Q2EJA0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6774',
#    'Ensembl.GeneID.TF': 'ENSG00000168610',
#    'Name.TF': 'STAT3',
#    'UniprotID.TF': 'P40763',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7004',
#    'Ensembl.GeneID.TF': 'ENSG00000197905',
#    'Name.TF': 'TEAD4',
#    'UniprotID.TF': 'Q15561',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4IZY5;Rn:F1M665',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10625',
#    'Ensembl.GeneID.TF': 'ENSG00000116679',
#    'Name.TF': 'IVNS1ABP',
#    'UniprotID.TF': 'Q9Y6Y0',
#    'TF.TFLink.ortho': 'Ce:Q21854;Dr:Q5RG82;Mm:Q920Q8;Rn:A0A0G2K427',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5934',
#    'Ensembl.GeneID.TF': 'ENSG00000103479',
#    'Name.TF': 'RBL2',
#    'UniprotID.TF': 'Q08999',
#    'TF.TFLink.ortho': 'Dr:E7FDM3;Mm:Q64700;Rn:G3V7P7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7528',
#    'Ensembl.GeneID.TF': 'ENSG00000100811',
#    'Name.TF': 'YY1',
#    'UniprotID.TF': 'P25490',
#    'TF.TFLink.ortho': 'Mm:Q00899;Rn:Q8CHJ4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55553',
#    'Ensembl.GeneID.TF': 'ENSG00000110693',
#    'Name.TF': 'SOX6',
#    'UniprotID.TF': 'P35712',
#    'TF.TFLink.ortho': 'Mm:P40645',
#    'TF.nonTFLink.ortho': 'Dr:A0A1D5NSY8;Rn:A0A6R0V8A0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3725',
#    'Ensembl.GeneID.TF': 'ENSG00000177606',
#    'Name.TF': 'JUN',
#    'UniprotID.TF': 'P05412',
#    'TF.TFLink.ortho': 'Dr:Q6NZT5;Mm:P05627;Rn:P17325',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9324',
#    'Ensembl.GeneID.TF': 'ENSG00000118418',
#    'Name.TF': 'HMGN3',
#    'UniprotID.TF': 'Q15651',
#    'TF.TFLink.ortho': 'Mm:Q9DCB1',
#    'TF.nonTFLink.ortho': 'Rn:M0R953',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '862',
#    'Ensembl.GeneID.TF': 'ENSG00000079102',
#    'Name.TF': 'RUNX1T1',
#    'UniprotID.TF': 'Q06455',
#    'TF.TFLink.ortho': 'Mm:Q61909;Rn:A0A0G2K0G0',
#    'TF.nonTFLink.ortho': 'Dr:Q1L8K2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6879',
#    'Ensembl.GeneID.TF': 'ENSG00000178913',
#    'Name.TF': 'TAF7',
#    'UniprotID.TF': 'Q15545',
#    'TF.TFLink.ortho': 'Dr:Q8JHG4;Mm:Q9R1C0;Rn:B0BN78',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2959',
#    'Ensembl.GeneID.TF': 'ENSG00000137947',
#    'Name.TF': 'GTF2B',
#    'UniprotID.TF': 'Q00403',
#    'TF.TFLink.ortho': 'Ce:O16991;Dm:P29052;Dr:A0A0R4IRB5;Mm:P62915;Rn:A0A0G2JWZ8;Sc:P29055',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7182',
#    'Ensembl.GeneID.TF': 'ENSG00000177463',
#    'Name.TF': 'NR2C2',
#    'UniprotID.TF': 'P49116',
#    'TF.TFLink.ortho': 'Dr:F6PDV8;Mm:P49117;Rn:G3V7F5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4004',
#    'Ensembl.GeneID.TF': 'ENSG00000166407',
#    'Name.TF': 'LMO1',
#    'UniprotID.TF': 'P25800',
#    'TF.TFLink.ortho': 'Dm:Q8IRC7;Dr:Q8JFQ2;Mm:Q924W9;Rn:A0A0G2K422',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10013',
#    'Ensembl.GeneID.TF': 'ENSG00000094631',
#    'Name.TF': 'HDAC6',
#    'UniprotID.TF': 'Q9UBN7',
#    'TF.TFLink.ortho': 'Dr:F8W4B7;Mm:Q9Z2V5',
#    'TF.nonTFLink.ortho': 'Ce:A7LPD8;Dm:M9NEH6;Rn:A0A0G2QC41;Rn:D3ZVD8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55726',
#    'Ensembl.GeneID.TF': 'ENSG00000064102',
#    'Name.TF': 'INTS13',
#    'UniprotID.TF': 'Q9NVM9',
#    'TF.TFLink.ortho': 'Ce:O44500;Dm:Q9VEX5;Mm:Q8QZV7;Rn:D4A6N9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51755',
#    'Ensembl.GeneID.TF': 'ENSG00000167258',
#    'Name.TF': 'CDK12',
#    'UniprotID.TF': 'Q9NYV4',
#    'TF.TFLink.ortho': 'Dr:F1R6Y1;Mm:Q14AX6;Rn:Q3MJK5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4780',
#    'Ensembl.GeneID.TF': 'ENSG00000116044',
#    'Name.TF': 'NFE2L2',
#    'UniprotID.TF': 'Q16236',
#    'TF.TFLink.ortho': 'Dr:Q7ZVI2;Mm:Q60795;Rn:O54968',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23405',
#    'Ensembl.GeneID.TF': 'ENSG00000100697',
#    'Name.TF': 'DICER1',
#    'UniprotID.TF': 'Q9UPY3',
#    'TF.TFLink.ortho': 'Ce:P34529;Dm:Q9VCU9;Dr:Q6TV19;Mm:F8VQ54',
#    'TF.nonTFLink.ortho': 'Rn:E9PU15',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8554',
#    'Ensembl.GeneID.TF': 'ENSG00000033800',
#    'Name.TF': 'PIAS1',
#    'UniprotID.TF': 'O75925',
#    'TF.TFLink.ortho': 'Dr:X1WDM3;Dr:A0A1D5NSS2;Mm:O88907;Rn:G3V9T0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6935',
#    'Ensembl.GeneID.TF': 'ENSG00000148516',
#    'Name.TF': 'ZEB1',
#    'UniprotID.TF': 'P37275',
#    'TF.TFLink.ortho': 'Dr:F1QPM7;Mm:Q64318;Rn:F8WG35',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1432',
#    'Ensembl.GeneID.TF': 'ENSG00000112062',
#    'Name.TF': 'MAPK14',
#    'UniprotID.TF': 'Q16539',
#    'TF.TFLink.ortho': 'Dm:O61443;Dm:O62618;Mm:P47811;Rn:Q56A33',
#    'TF.nonTFLink.ortho': 'Dr:F1R202',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9189',
#    'Ensembl.GeneID.TF': 'ENSG00000214717',
#    'Name.TF': 'ZBED1',
#    'UniprotID.TF': 'O96006',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10463',
#    'Ensembl.GeneID.TF': 'ENSG00000014824',
#    'Name.TF': 'SLC30A9',
#    'UniprotID.TF': 'Q6PML9',
#    'TF.TFLink.ortho': 'Ce:Q3V5J4;Dr:Q5PQZ3;Mm:Q5IRJ6;Rn:D3ZWW5',
#    'TF.nonTFLink.ortho': 'Dm:A1Z936',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '80853',
#    'Ensembl.GeneID.TF': 'ENSG00000006459',
#    'Name.TF': 'KDM7A',
#    'UniprotID.TF': 'Q6ZMT4',
#    'TF.TFLink.ortho': 'Dr:Q5RHD1;Mm:Q3UWM4',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K1Z1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '196',
#    'Ensembl.GeneID.TF': 'ENSG00000106546',
#    'Name.TF': 'AHR',
#    'UniprotID.TF': 'P35869',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7767',
#    'Ensembl.GeneID.TF': 'ENSG00000267680',
#    'Name.TF': 'ZNF224',
#    'UniprotID.TF': 'Q9NZL3',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '83463',
#    'Ensembl.GeneID.TF': 'ENSG00000213347',
#    'Name.TF': 'MXD3',
#    'UniprotID.TF': 'Q9BW11',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IMG7;Mm:Q80US8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4089',
#    'Ensembl.GeneID.TF': 'ENSG00000141646',
#    'Name.TF': 'SMAD4',
#    'UniprotID.TF': 'Q13485',
#    'TF.TFLink.ortho': 'Mm:P97471;Rn:A0A0G2K970',
#    'TF.nonTFLink.ortho': 'Dm:Q8IMG6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5970',
#    'Ensembl.GeneID.TF': 'ENSG00000173039',
#    'Name.TF': 'RELA',
#    'UniprotID.TF': 'Q04206',
#    'TF.TFLink.ortho': 'Mm:Q04207;Rn:Q7TQN4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '54880',
#    'Ensembl.GeneID.TF': 'ENSG00000183337',
#    'Name.TF': 'BCOR',
#    'UniprotID.TF': 'Q6W2J9',
#    'TF.TFLink.ortho': 'Mm:Q8CGN4;Rn:D4A2J9',
#    'TF.nonTFLink.ortho': 'Dr:Q6W2J8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55818',
#    'Ensembl.GeneID.TF': 'ENSG00000115548',
#    'Name.TF': 'KDM3A',
#    'UniprotID.TF': 'Q9Y4C1',
#    'TF.TFLink.ortho': 'Mm:Q6PCM1;Rn:A0A0G2K220',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84844',
#    'Ensembl.GeneID.TF': 'ENSG00000100410',
#    'Name.TF': 'PHF5A',
#    'UniprotID.TF': 'Q7RTV0',
#    'TF.TFLink.ortho': 'Dm:Q9VMC8;Dr:Q6YMR2;Mm:P83870;Rn:P83871;Sc:Q06835',
#    'TF.nonTFLink.ortho': 'Ce:G5EBY6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8553',
#    'Ensembl.GeneID.TF': 'ENSG00000134107',
#    'Name.TF': 'BHLHE40',
#    'UniprotID.TF': 'O14503',
#    'TF.TFLink.ortho': 'Dr:Q6NY50;Mm:O35185;Rn:Q76JQ4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
# ...
#    'TF.TFLink.ortho': 'Mm:Q9Z2F6;Rn:D3ZQF8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7975',
#    'Ensembl.GeneID.TF': 'ENSG00000198517',
#    'Name.TF': 'MAFK',
#    'UniprotID.TF': 'O60675',
#    'TF.TFLink.ortho': 'Dm:A0A0B4LH09;Dr:A0A0R4IVU1;Mm:Q61827;Rn:Q6IRI7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4298',
#    'Ensembl.GeneID.TF': 'ENSG00000130382',
#    'Name.TF': 'MLLT1',
#    'UniprotID.TF': 'Q03111',
#    'TF.TFLink.ortho': 'Dr:E9QEN8;Mm:Q9ERL0;Rn:M0R462',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84148',
#    'Ensembl.GeneID.TF': 'ENSG00000103510',
#    'Name.TF': 'KAT8',
#    'UniprotID.TF': 'Q9H7Z6',
#    'TF.TFLink.ortho': 'Dm:Q9VAV6;Mm:Q9D1P2;Rn:Q5XI06',
#    'TF.nonTFLink.ortho': 'Dr:F1QX50',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2962',
#    'Ensembl.GeneID.TF': 'ENSG00000125651',
#    'Name.TF': 'GTF2F1',
#    'UniprotID.TF': 'P35269',
#    'TF.TFLink.ortho': 'Dm:Q05913;Dr:Q5PNQ6;Mm:Q3THK3;Rn:Q6AY96',
#    'TF.nonTFLink.ortho': 'Ce:Q17558',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7746',
#    'Ensembl.GeneID.TF': 'ENSG00000137185',
#    'Name.TF': 'ZSCAN9',
#    'UniprotID.TF': 'O15535',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6668',
#    'Ensembl.GeneID.TF': 'ENSG00000167182',
#    'Name.TF': 'SP2',
#    'UniprotID.TF': 'Q02086',
#    'TF.TFLink.ortho': 'Dr:F1Q4L6;Mm:Q8C5J0;Rn:B5DEH3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4999',
#    'Ensembl.GeneID.TF': 'ENSG00000115942',
#    'Name.TF': 'ORC2',
#    'UniprotID.TF': 'Q13416',
#    'TF.TFLink.ortho': 'Dm:Q24168;Mm:Q60862;Rn:Q75PQ8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10725',
#    'Ensembl.GeneID.TF': 'ENSG00000102908',
#    'Name.TF': 'NFAT5',
#    'UniprotID.TF': 'O94916',
#    'TF.TFLink.ortho': 'Mm:Q9WV30',
#    'TF.nonTFLink.ortho': 'Rn:D3ZGB1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5993',
#    'Ensembl.GeneID.TF': 'ENSG00000143390',
#    'Name.TF': 'RFX5',
#    'UniprotID.TF': 'P48382',
#    'TF.TFLink.ortho': 'Mm:Q9JL61;Rn:D3ZHD7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7227',
#    'Ensembl.GeneID.TF': 'ENSG00000104447',
#    'Name.TF': 'TRPS1',
#    'UniprotID.TF': 'Q9UHF7',
#    'TF.TFLink.ortho': 'Dr:F1QEY1;Rn:D3ZEM6',
#    'TF.nonTFLink.ortho': 'Mm:G3UW90',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7709',
#    'Ensembl.GeneID.TF': 'ENSG00000116809',
#    'Name.TF': 'ZBTB17',
#    'UniprotID.TF': 'Q13105',
#    'TF.TFLink.ortho': 'Ce:G5EDU4;Mm:Q60821;Rn:Q5XIU3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '22834',
#    'Ensembl.GeneID.TF': 'ENSG00000198740',
#    'Name.TF': 'ZNF652',
#    'UniprotID.TF': 'Q9Y2D9',
#    'TF.TFLink.ortho': 'Dm:A1ZBC5;Mm:Q5DU09;Rn:A1L1J6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '196528',
#    'Ensembl.GeneID.TF': 'ENSG00000189079',
#    'Name.TF': 'ARID2',
#    'UniprotID.TF': 'Q68CP9',
#    'TF.TFLink.ortho': 'Dm:A1Z6M0;Mm:E9Q7E2;Rn:D3ZJU0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '324',
#    'Ensembl.GeneID.TF': 'ENSG00000134982',
#    'Name.TF': 'APC',
#    'UniprotID.TF': 'P25054',
#    'TF.TFLink.ortho': 'Mm:B2RUG9',
#    'TF.nonTFLink.ortho': 'Dr:F8W4Z3;Rn:A0A0G2K8G0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9441',
#    'Ensembl.GeneID.TF': 'ENSG00000105085',
#    'Name.TF': 'MED26',
#    'UniprotID.TF': 'O95402',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '83855',
#    'Ensembl.GeneID.TF': 'ENSG00000129911',
#    'Name.TF': 'KLF16',
#    'UniprotID.TF': 'Q9BXK1',
#    'TF.TFLink.ortho': 'Mm:P58334;Rn:B2GUY9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4968',
#    'Ensembl.GeneID.TF': 'ENSG00000114026',
#    'Name.TF': 'OGG1',
#    'UniprotID.TF': 'O15527',
#    'TF.TFLink.ortho': 'Dm:Q9V3I8;Dr:B0R135;Mm:O08760;Rn:O70249',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '197407',
#    'Ensembl.GeneID.TF': 'ENSG00000180035',
#    'Name.TF': 'ZNF48',
#    'UniprotID.TF': 'Q96MX3',
#    'TF.TFLink.ortho': 'Ce:G5EFF4;Mm:Q3US17;Rn:D3ZY01',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '83439',
#    'Ensembl.GeneID.TF': 'ENSG00000152284',
#    'Name.TF': 'TCF7L1',
#    'UniprotID.TF': 'Q9HCS4',
#    'TF.TFLink.ortho': 'Dr:Q9YHE8;Dr:F1R336;Rn:F1M1R9',
#    'TF.nonTFLink.ortho': 'Mm:A1A549',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6772',
#    'Ensembl.GeneID.TF': 'ENSG00000115415',
#    'Name.TF': 'STAT1',
#    'UniprotID.TF': 'P42224',
#    'TF.TFLink.ortho': 'Dr:Q6P943',
#    'TF.nonTFLink.ortho': 'Mm:A0A087WSP5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2068',
#    'Ensembl.GeneID.TF': 'ENSG00000104884',
#    'Name.TF': 'ERCC2',
#    'UniprotID.TF': 'P18074',
#    'TF.TFLink.ortho': 'Dm:Q7KVP9;Dr:F1Q5E7;Mm:O08811;Rn:D3ZEG9;Sc:P06839',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '847',
#    'Ensembl.GeneID.TF': 'ENSG00000121691',
#    'Name.TF': 'CAT',
#    'UniprotID.TF': 'P04040',
#    'TF.TFLink.ortho': 'Ce:Q8MYL7;Dm:P17336;Mm:P24270;Rn:P04762;Sc:P15202',
#    'TF.nonTFLink.ortho': 'Ce:Q27487;Ce:O61235',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4088',
#    'Ensembl.GeneID.TF': 'ENSG00000166949',
#    'Name.TF': 'SMAD3',
#    'UniprotID.TF': 'P84022',
#    'TF.TFLink.ortho': 'Dr:Q8AY15;Mm:Q8BUN5;Rn:P84025',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55636',
#    'Ensembl.GeneID.TF': 'ENSG00000171316',
#    'Name.TF': 'CHD7',
#    'UniprotID.TF': 'Q9P2D1',
#    'TF.TFLink.ortho': 'Dr:F1QGL1;Mm:A2AJK6;Rn:D3ZAP7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4221',
#    'Ensembl.GeneID.TF': 'ENSG00000133895',
#    'Name.TF': 'MEN1',
#    'UniprotID.TF': 'O00255',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3164',
#    'Ensembl.GeneID.TF': 'ENSG00000123358',
#    'Name.TF': 'NR4A1',
#    'UniprotID.TF': 'P22736',
#    'TF.TFLink.ortho': 'Mm:P12813;Rn:P22829',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4086',
#    'Ensembl.GeneID.TF': 'ENSG00000170365',
#    'Name.TF': 'SMAD1',
#    'UniprotID.TF': 'Q15797',
#    'TF.TFLink.ortho': 'Mm:P70340;Rn:A0A0G2JSQ6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '604',
#    'Ensembl.GeneID.TF': 'ENSG00000113916',
#    'Name.TF': 'BCL6',
#    'UniprotID.TF': 'P41182',
#    'TF.TFLink.ortho': 'Dr:F1R5N6;Mm:P41183;Rn:B2GUV8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8462',
#    'Ensembl.GeneID.TF': 'ENSG00000172059',
#    'Name.TF': 'KLF11',
#    'UniprotID.TF': 'O14901',
#    'TF.TFLink.ortho': 'Dr:F1R5X2;Dr:Q5RIQ4;Mm:Q8K1S5;Rn:E9PTS6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2353',
#    'Ensembl.GeneID.TF': 'ENSG00000170345',
#    'Name.TF': 'FOS',
#    'UniprotID.TF': 'P01100',
#    'TF.TFLink.ortho': 'Dr:Q6P0S4;Mm:P01101;Rn:P12841',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;18971253;27924024;26578589',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23543',
#    'Ensembl.GeneID.TF': 'ENSG00000100320',
#    'Name.TF': 'RBFOX2',
#    'UniprotID.TF': 'O43251',
#    'TF.TFLink.ortho': 'Mm:Q8BP71',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2JYY7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7290',
#    'Ensembl.GeneID.TF': 'ENSG00000100084',
#    'Name.TF': 'HIRA',
#    'UniprotID.TF': 'P54198',
#    'TF.TFLink.ortho': 'Ce:Q09589;Dm:A1Z898;Dr:A2CEX6;Mm:Q61666;Rn:M0R4R2',
#    'TF.nonTFLink.ortho': 'Rn:M0R756',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2521',
#    'Ensembl.GeneID.TF': 'ENSG00000089280',
#    'Name.TF': 'FUS',
#    'UniprotID.TF': 'P35637',
#    'TF.TFLink.ortho': 'Dr:F1R0M4;Mm:P56959;Rn:Q5PQK2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29855',
#    'Ensembl.GeneID.TF': 'ENSG00000118900',
#    'Name.TF': 'UBN1',
#    'UniprotID.TF': 'Q9NPG3',
#    'TF.TFLink.ortho': 'Mm:Q4G0F8;Rn:D4A8C6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '168544',
#    'Ensembl.GeneID.TF': 'ENSG00000181444',
#    'Name.TF': 'ZNF467',
#    'UniprotID.TF': 'Q7Z7K2',
#    'TF.TFLink.ortho': 'Mm:Q8JZL0;Rn:Q5RJR4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '405',
#    'Ensembl.GeneID.TF': 'ENSG00000143437',
#    'Name.TF': 'ARNT',
#    'UniprotID.TF': 'P27540',
#    'TF.TFLink.ortho': 'Mm:P53762;Rn:F1LMF9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4774',
#    'Ensembl.GeneID.TF': 'ENSG00000162599',
#    'Name.TF': 'NFIA',
#    'UniprotID.TF': 'Q12857',
#    'TF.TFLink.ortho': 'Dr:Q1L9B0;Mm:Q02780;Rn:A0A0G2K5I9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '65980',
#    'Ensembl.GeneID.TF': 'ENSG00000028310',
#    'Name.TF': 'BRD9',
#    'UniprotID.TF': 'Q9H8M2',
#    'TF.TFLink.ortho': 'Dm:Q9VLX2;Dr:F1QNW6;Rn:D4ACF5',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4J175',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9839',
#    'Ensembl.GeneID.TF': 'ENSG00000169554',
#    'Name.TF': 'ZEB2',
#    'UniprotID.TF': 'O60315',
#    'TF.TFLink.ortho': 'Mm:Q9R0G7;Rn:E9PTC3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6671',
#    'Ensembl.GeneID.TF': 'ENSG00000105866',
#    'Name.TF': 'SP4',
#    'UniprotID.TF': 'Q02446',
#    'TF.TFLink.ortho': 'Dm:Q9VEW6;Mm:A0A1Y7VJR5;Rn:Q63158',
#    'TF.nonTFLink.ortho': 'Dr:F1QVQ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4824',
#    'Ensembl.GeneID.TF': 'ENSG00000167034',
#    'Name.TF': 'NKX3-1',
#    'UniprotID.TF': 'Q99801',
#    'TF.TFLink.ortho': 'Mm:P97436',
#    'TF.nonTFLink.ortho': 'Dr:Q68EL7;Rn:Q497B7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7728',
#    'Ensembl.GeneID.TF': 'ENSG00000105497',
#    'Name.TF': 'ZNF175',
#    'UniprotID.TF': 'Q9Y473',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '26959',
#    'Ensembl.GeneID.TF': 'ENSG00000105856',
#    'Name.TF': 'HBP1',
#    'UniprotID.TF': 'O60381',
#    'TF.TFLink.ortho': 'Dr:F1QK54;Mm:E9Q1A8;Rn:Z4YNI2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'}]}

# %%
ncbi_tf_df_human[ncbi_tf_df_human['target']=="1647"]["its_tf"].to_dict()
# Out:
# {3343: [{'NCBI.GeneID.TF': '672',
#    'Ensembl.GeneID.TF': 'ENSG00000012048',
#    'Name.TF': 'BRCA1',
#    'UniprotID.TF': 'P38398',
#    'TF.TFLink.ortho': 'Mm:P48754;Rn:G3V8S5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '17428466;12647291;18350249;11777930;10962562;27924024;18025037;17202159;29087512',
#    'Source.database': 'GTRD;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '4790',
#    'Ensembl.GeneID.TF': 'ENSG00000109320',
#    'Name.TF': 'NFKB1',
#    'UniprotID.TF': 'P19838',
#    'TF.TFLink.ortho': 'Dm:Q94527;Mm:P25799;Rn:F1LQH2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '367',
#    'Ensembl.GeneID.TF': 'ENSG00000169083',
#    'Name.TF': 'AR',
#    'UniprotID.TF': 'P10275',
#    'TF.TFLink.ortho': 'Mm:P19091;Rn:A0A0G2JSI8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation array;chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;20610535;27924024;17202159;22900683',
#    'Source.database': 'GTRD;HTRI;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '6599',
#    'Ensembl.GeneID.TF': 'ENSG00000173473',
#    'Name.TF': 'SMARCC1',
#    'UniprotID.TF': 'Q92922',
#    'TF.TFLink.ortho': 'Mm:P97496;Rn:A0A0G2K9D6',
#    'TF.nonTFLink.ortho': 'Dr:F1Q9K1',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;24234451;24434208',
#    'Source.database': 'GTRD;IntAct_via_DoRothEA;ReMap',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5914',
#    'Ensembl.GeneID.TF': 'ENSG00000131759',
#    'Name.TF': 'RARA',
#    'UniprotID.TF': 'P10276',
#    'TF.TFLink.ortho': 'Mm:P11416;Rn:A0A0G2JW78',
#    'TF.nonTFLink.ortho': 'Dr:T2DKU4',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27924024;17202159',
#    'Source.database': 'GTRD;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '4800',
#    'Ensembl.GeneID.TF': 'ENSG00000001167',
#    'Name.TF': 'NFYA',
#    'UniprotID.TF': 'P23511',
#    'TF.TFLink.ortho': 'Mm:P23708',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2KB97',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;11525640;11420680;27924024;29087512',
#    'Source.database': 'GTRD;ReMap;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '2309',
#    'Ensembl.GeneID.TF': 'ENSG00000118689',
#    'Name.TF': 'FOXO3',
#    'UniprotID.TF': 'O43524',
#    'TF.TFLink.ortho': 'Dr:Q5TYS1;Mm:Q9WVH4;Rn:D3ZBQ1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27899662;11964479;22761861;27924024;12048180',
#    'Source.database': 'GTRD;KEGG_via_DoRothEA;TFactS_via_DoRothea',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5467',
#    'Ensembl.GeneID.TF': 'ENSG00000112033',
#    'Name.TF': 'PPARD',
#    'UniprotID.TF': 'Q03181',
#    'TF.TFLink.ortho': 'Dr:A9C4A5;Mm:P35396;Rn:Q99ND3',
#    'TF.nonTFLink.ortho': 'Dr:F8W3D2',
#    'Detection.method': 'inferred by curator',
#    'PubmedID': '17202159',
#    'Source.database': 'TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '1874',
#    'Ensembl.GeneID.TF': 'ENSG00000205250',
#    'Name.TF': 'E2F4',
#    'UniprotID.TF': 'Q16254',
#    'TF.TFLink.ortho': 'Dr:A0A0R4ICD5;Mm:Q8R0K9;Rn:D4A9V4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;26578589;18971253;27924024;17202159',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '1050',
#    'Ensembl.GeneID.TF': 'ENSG00000245848',
#    'Name.TF': 'CEBPA',
#    'UniprotID.TF': 'P49715',
#    'TF.TFLink.ortho': 'Dr:Q8UVZ1;Mm:P53566;Rn:A0A0H2UI22',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;26578589;18971253;27924024;17202159',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '3727',
#    'Ensembl.GeneID.TF': 'ENSG00000130522',
#    'Name.TF': 'JUND',
#    'UniprotID.TF': 'P17535',
#    'TF.TFLink.ortho': 'Dr:B0V1Q6;Mm:P15066;Rn:P52909',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;electrophoretic mobility shift assay;inferred by curator',
#    'PubmedID': '29126285;27924024;29087512;22900683;17084916',
#    'Source.database': 'GTRD;HTRI;ReMap;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5465',
#    'Ensembl.GeneID.TF': 'ENSG00000186951',
#    'Name.TF': 'PPARA',
#    'UniprotID.TF': 'Q07869',
#    'TF.TFLink.ortho': 'Dr:K7DY57;Mm:P23204;Rn:P37230',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'inferred by curator',
#    'PubmedID': '17202159',
#    'Source.database': 'TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '472',
#    'Ensembl.GeneID.TF': 'ENSG00000149311',
#    'Name.TF': 'ATM',
#    'UniprotID.TF': 'Q13315',
#    'TF.TFLink.ortho': 'Mm:Q62388;Rn:D4ACL8',
#    'TF.nonTFLink.ortho': 'Dr:R4GE34',
#    'Detection.method': 'inferred by curator',
#    'PubmedID': '20164679;29087512',
#    'Source.database': 'TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '4609',
#    'Ensembl.GeneID.TF': 'ENSG00000136997',
#    'Name.TF': 'MYC',
#    'UniprotID.TF': 'P01106',
#    'TF.TFLink.ortho': 'Dr:F1RC36;Mm:P01108',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;15021909;22761861;27924024;22900683;14519204',
#    'Source.database': 'GTRD;HTRI;ReMap;TFactS_via_DoRothea',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '2099',
#    'Ensembl.GeneID.TF': 'ENSG00000091831',
#    'Name.TF': 'ESR1',
#    'UniprotID.TF': 'P03372',
#    'TF.TFLink.ortho': 'Mm:P19785',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K0D4',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27924024;17202159',
#    'Source.database': 'GTRD;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5451',
#    'Ensembl.GeneID.TF': 'ENSG00000143190',
#    'Name.TF': 'POU2F1',
#    'UniprotID.TF': 'P14859',
#    'TF.TFLink.ortho': 'Rn:F1LRD7',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4J1Z4',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;11525640;11420680;27924024;17202159;29087512',
#    'Source.database': 'GTRD;ReMap;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '7157',
#    'Ensembl.GeneID.TF': 'ENSG00000141510',
#    'Name.TF': 'TP53',
#    'UniprotID.TF': 'P04637',
#    'TF.TFLink.ortho': 'Mm:P02340',
#    'TF.nonTFLink.ortho': 'Dr:B0R0M3;Rn:M0R497',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;18350249;27899662;18431400;10566557;31340985;26578589;10327059;12007564;18225552;15031557;17344317;18971253;27924024;17202159;29087512;16581545',
#    'Source.database': 'DoRothEA;GTRD;KEGG_via_DoRothEA;ORegAnno;PAZAR;ReMap;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '5468',
#    'Ensembl.GeneID.TF': 'ENSG00000132170',
#    'Name.TF': 'PPARG',
#    'UniprotID.TF': 'P37231',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.TF': '22880',
#    'Ensembl.GeneID.TF': 'ENSG00000133422',
#    'Name.TF': 'MORC2',
#    'UniprotID.TF': 'Q9Y6X9',
#    'TF.TFLink.ortho': 'Dr:Q68EG7;Mm:Q69ZX6;Rn:A0A0G2JWF7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57634',
#    'Ensembl.GeneID.TF': 'ENSG00000183495',
#    'Name.TF': 'EP400',
#    'UniprotID.TF': 'Q96L91',
#    'TF.TFLink.ortho': 'Mm:Q8CHI8;Rn:A0A0G2JU09',
#    'TF.nonTFLink.ortho': 'Dm:A0A0B4LFX8;Dr:A0A0R4IGB8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29781',
#    'Ensembl.GeneID.TF': 'ENSG00000025770',
#    'Name.TF': 'NCAPH2',
#    'UniprotID.TF': 'Q6IBW4',
#    'TF.TFLink.ortho': 'Dr:Q5RH01;Mm:Q8BSP2',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K4H8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8726',
#    'Ensembl.GeneID.TF': 'ENSG00000074266',
#    'Name.TF': 'EED',
#    'UniprotID.TF': 'O75530',
#    'TF.TFLink.ortho': 'Ce:Q9GYS1;Dm:Q9VKD5;Dr:Q566T0;Mm:Q921E6;Rn:B5DF02',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2625',
#    'Ensembl.GeneID.TF': 'ENSG00000107485',
#    'Name.TF': 'GATA3',
#    'UniprotID.TF': 'P23771',
#    'TF.TFLink.ortho': 'Dr:Q91428;Mm:P23772;Rn:Q99NH5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024;29126285;22900683;21878914',
#    'Source.database': 'GTRD;HTRI;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84662',
#    'Ensembl.GeneID.TF': 'ENSG00000126603',
#    'Name.TF': 'GLIS2',
#    'UniprotID.TF': 'Q9BZE0',
#    'TF.TFLink.ortho': 'Mm:Q8VDL9;Rn:D3ZIA9',
#    'TF.nonTFLink.ortho': 'Dr:A0A0R4IE83',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6598',
#    'Ensembl.GeneID.TF': 'ENSG00000099956',
#    'Name.TF': 'SMARCB1',
#    'UniprotID.TF': 'Q12824',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2122',
#    'Ensembl.GeneID.TF': 'ENSG00000085276',
#    'Name.TF': 'MECOM',
#    'UniprotID.TF': 'Q03112',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': 'Mm:G3UZT5;Rn:D3ZM26',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5090',
#    'Ensembl.GeneID.TF': 'ENSG00000167081',
#    'Name.TF': 'PBX3',
#    'UniprotID.TF': 'P40426',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6908',
#    'Ensembl.GeneID.TF': 'ENSG00000112592',
#    'Name.TF': 'TBP',
#    'UniprotID.TF': 'P20226',
#    'TF.TFLink.ortho': 'Dr:Q7SXL3;Mm:P29037;Rn:Q66HB1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3516',
#    'Ensembl.GeneID.TF': 'ENSG00000168214',
#    'Name.TF': 'RBPJ',
#    'UniprotID.TF': 'Q06330',
#    'TF.TFLink.ortho': 'Dm:P28159;Dr:A4FTT3;Mm:P31266;Rn:M0R7Q3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10664',
#    'Ensembl.GeneID.TF': 'ENSG00000102974',
#    'Name.TF': 'CTCF',
#    'UniprotID.TF': 'P49711',
#    'TF.TFLink.ortho': 'Dr:Q6JAA4;Mm:Q61164;Rn:A0A0H2UHP0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4000',
#    'Ensembl.GeneID.TF': 'ENSG00000160789',
#    'Name.TF': 'LMNA',
#    'UniprotID.TF': 'P02545',
#    'TF.TFLink.ortho': 'Mm:P48678;Rn:G3V8L3',
#    'TF.nonTFLink.ortho': 'Dr:B3DKC5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '79718',
#    'Ensembl.GeneID.TF': 'ENSG00000177565',
#    'Name.TF': 'TBL1XR1',
#    'UniprotID.TF': 'Q9BZK7',
#    'TF.TFLink.ortho': 'Dr:A5PF33;Mm:Q8BHJ5;Sc:P38262',
#    'TF.nonTFLink.ortho': 'Rn:D3ZNF4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3607',
#    'Ensembl.GeneID.TF': 'ENSG00000141568',
#    'Name.TF': 'FOXK2',
#    'UniprotID.TF': 'Q01167',
#    'TF.TFLink.ortho': 'Dr:E7FFM9;Mm:Q3UCQ1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3609',
#    'Ensembl.GeneID.TF': 'ENSG00000129351',
#    'Name.TF': 'ILF3',
#    'UniprotID.TF': 'Q12906',
#    'TF.TFLink.ortho': 'Mm:Q9Z1X4',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K4U6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5316',
#    'Ensembl.GeneID.TF': 'ENSG00000160199',
#    'Name.TF': 'PKNOX1',
#    'UniprotID.TF': 'P55347',
#    'TF.TFLink.ortho': 'Dr:E7FBG0;Mm:O70477',
#    'TF.nonTFLink.ortho': 'Rn:Q5BJP1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6722',
#    'Ensembl.GeneID.TF': 'ENSG00000112658',
#    'Name.TF': 'SRF',
#    'UniprotID.TF': 'P11831',
#    'TF.TFLink.ortho': 'Mm:Q9JM73;Rn:D3ZHH8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27161',
#    'Ensembl.GeneID.TF': 'ENSG00000123908',
#    'Name.TF': 'AGO2',
#    'UniprotID.TF': 'Q9UKV8',
#    'TF.TFLink.ortho': 'Mm:Q8CJG0;Rn:F1LRP7',
#    'TF.nonTFLink.ortho': 'Dr:E7EXY4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7155',
#    'Ensembl.GeneID.TF': 'ENSG00000077097',
#    'Name.TF': 'TOP2B',
#    'UniprotID.TF': 'Q02880',
#    'TF.TFLink.ortho': 'Dr:Q1LUT2;Mm:Q64511',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '60436',
#    'Ensembl.GeneID.TF': 'ENSG00000118707',
#    'Name.TF': 'TGIF2',
#    'UniprotID.TF': 'Q9GZN2',
#    'TF.TFLink.ortho': 'Mm:Q8C0Y1;Rn:B5DEL6',
#    'TF.nonTFLink.ortho': 'Rn:M0RCY5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9611',
#    'Ensembl.GeneID.TF': 'ENSG00000141027',
#    'Name.TF': 'NCOR1',
#    'UniprotID.TF': 'O75376',
#    'TF.TFLink.ortho': 'Rn:A0A0G2K2B4',
#    'TF.nonTFLink.ortho': 'Mm:Q5RIM6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6777',
#    'Ensembl.GeneID.TF': 'ENSG00000173757',
#    'Name.TF': 'STAT5B',
#    'UniprotID.TF': 'P51692',
#    'TF.TFLink.ortho': 'Mm:P42232;Rn:A0A0G2JSR4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '25842',
#    'Ensembl.GeneID.TF': 'ENSG00000111875',
#    'Name.TF': 'ASF1A',
#    'UniprotID.TF': 'Q9Y294',
#    'TF.TFLink.ortho': 'Dm:Q9V464;Dr:Q6NY34;Dr:Q6NYY4;Mm:Q9CQE6;Rn:D3ZFM1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27154',
#    'Ensembl.GeneID.TF': 'ENSG00000096070',
#    'Name.TF': 'BRPF3',
#    'UniprotID.TF': 'Q9ULD4',
#    'TF.TFLink.ortho': 'Dr:F6P390;Mm:B2KF05;Rn:D3ZMD3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2078',
#    'Ensembl.GeneID.TF': 'ENSG00000157554',
#    'Name.TF': 'ERG',
#    'UniprotID.TF': 'P11308',
#    'TF.TFLink.ortho': 'Mm:P81270',
#    'TF.nonTFLink.ortho': 'Dr:F1QK28;Rn:A0A0G2JWE9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23186',
#    'Ensembl.GeneID.TF': 'ENSG00000089902',
#    'Name.TF': 'RCOR1',
#    'UniprotID.TF': 'Q9UKL0',
#    'TF.TFLink.ortho': 'Dr:Q1MTF5',
#    'TF.nonTFLink.ortho': 'Rn:F1LXS5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4152',
#    'Ensembl.GeneID.TF': 'ENSG00000141644',
#    'Name.TF': 'MBD1',
#    'UniprotID.TF': 'Q9UIS9',
#    'TF.TFLink.ortho': 'Rn:Q66HB8',
#    'TF.nonTFLink.ortho': 'Mm:A0A286YDI1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27125',
#    'Ensembl.GeneID.TF': 'ENSG00000072364',
#    'Name.TF': 'AFF4',
#    'UniprotID.TF': 'Q9UHB7',
#    'TF.TFLink.ortho': 'Dm:Q9XZ21;Dr:I3ISK1;Mm:Q9ESC8;Rn:D3ZSX2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2313',
#    'Ensembl.GeneID.TF': 'ENSG00000151702',
#    'Name.TF': 'FLI1',
#    'UniprotID.TF': 'Q01543',
#    'TF.TFLink.ortho': 'Mm:P26323;Rn:Q4Z8P1',
#    'TF.nonTFLink.ortho': 'Dr:Q9PU61',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '167465',
#    'Ensembl.GeneID.TF': 'ENSG00000178175',
#    'Name.TF': 'ZNF366',
#    'UniprotID.TF': 'Q8N895',
#    'TF.TFLink.ortho': 'Mm:Q6NS86',
#    'TF.nonTFLink.ortho': 'Rn:D4A715',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23435',
#    'Ensembl.GeneID.TF': 'ENSG00000120948',
#    'Name.TF': 'TARDBP',
#    'UniprotID.TF': 'Q13148',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7003',
#    'Ensembl.GeneID.TF': 'ENSG00000187079',
#    'Name.TF': 'TEAD1',
#    'UniprotID.TF': 'P28347',
#    'TF.TFLink.ortho': 'Rn:A0A0G2K2N3',
#    'TF.nonTFLink.ortho': 'Dm:A8JUY5;Dr:F8W5M8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1027',
#    'Ensembl.GeneID.TF': 'ENSG00000111276',
#    'Name.TF': 'CDKN1B',
#    'UniprotID.TF': 'P46527',
#    'TF.TFLink.ortho': 'Mm:P46414;Rn:O08769',
#    'TF.nonTFLink.ortho': 'Ce:U4PBK8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1024',
#    'Ensembl.GeneID.TF': 'ENSG00000132964',
#    'Name.TF': 'CDK8',
#    'UniprotID.TF': 'P49336',
#    'TF.TFLink.ortho': 'Dm:Q9VT57;Dr:A8E4S2;Mm:Q8R3L8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4149',
#    'Ensembl.GeneID.TF': 'ENSG00000125952',
#    'Name.TF': 'MAX',
#    'UniprotID.TF': 'P61244',
#    'TF.TFLink.ortho': 'Ce:G5EEH5;Dm:P91664;Mm:P28574;Rn:P52164',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '15021909;29126285;22900683;27924024',
#    'Source.database': 'GTRD;HTRI;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '64763',
#    'Ensembl.GeneID.TF': 'ENSG00000105732',
#    'Name.TF': 'ZNF574',
#    'UniprotID.TF': 'Q6ZN55',
#    'TF.TFLink.ortho': 'Mm:Q8BY46;Rn:Q504L7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6613',
#    'Ensembl.GeneID.TF': 'ENSG00000188612',
#    'Name.TF': 'SUMO2',
#    'UniprotID.TF': 'P61956',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '657',
#    'Ensembl.GeneID.TF': 'ENSG00000107779',
#    'Name.TF': 'BMPR1A',
#    'UniprotID.TF': 'P36894',
#    'TF.TFLink.ortho': 'Mm:P36895;Rn:Q78EA7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4841',
#    'Ensembl.GeneID.TF': 'ENSG00000147140',
#    'Name.TF': 'NONO',
#    'UniprotID.TF': 'Q15233',
#    'TF.TFLink.ortho': 'Dr:Q802Z5;Mm:Q99K48;Rn:Q5FVM4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27107',
#    'Ensembl.GeneID.TF': 'ENSG00000066422',
#    'Name.TF': 'ZBTB11',
#    'UniprotID.TF': 'O95625',
#    'TF.TFLink.ortho': 'Dr:F1RAC1;Mm:G5E8B9;Rn:D3ZDP9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57504',
#    'Ensembl.GeneID.TF': 'ENSG00000057935',
#    'Name.TF': 'MTA3',
#    'UniprotID.TF': 'Q9BTC8',
#    'TF.TFLink.ortho': 'Mm:Q924K8;Rn:A0A0G2JTK6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1877',
#    'Ensembl.GeneID.TF': 'ENSG00000167967',
#    'Name.TF': 'E4F1',
#    'UniprotID.TF': 'Q66K89',
#    'TF.TFLink.ortho': 'Mm:Q8CCE9;Rn:F1MAM9',
#    'TF.nonTFLink.ortho': 'Dm:O61362;Dr:F1R041',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3090',
#    'Ensembl.GeneID.TF': 'ENSG00000177374',
#    'Name.TF': 'HIC1',
#    'UniprotID.TF': 'Q14526',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7936',
#    'Ensembl.GeneID.TF': 'ENSG00000204356',
#    'Name.TF': 'NELFE',
#    'UniprotID.TF': 'P18615',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10614',
#    'Ensembl.GeneID.TF': 'ENSG00000186834',
#    'Name.TF': 'HEXIM1',
#    'UniprotID.TF': 'O94992',
#    'TF.TFLink.ortho': 'Mm:Q8R409;Rn:Q5M9G1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23133',
#    'Ensembl.GeneID.TF': 'ENSG00000172943',
#    'Name.TF': 'PHF8',
#    'UniprotID.TF': 'Q9UPP1',
#    'TF.TFLink.ortho': 'Dr:P0CH95;Mm:Q80TJ7;Rn:D4AD31',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6659',
#    'Ensembl.GeneID.TF': 'ENSG00000124766',
#    'Name.TF': 'SOX4',
#    'UniprotID.TF': 'Q06945',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IQD2;Mm:Q06831',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '11100',
#    'Ensembl.GeneID.TF': 'ENSG00000105323',
#    'Name.TF': 'HNRNPUL1',
#    'UniprotID.TF': 'Q9BUJ2',
#    'TF.TFLink.ortho': 'Dr:Q1L9A1;Dr:E7F071;Mm:Q8VDM6;Rn:D4A962',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4779',
#    'Ensembl.GeneID.TF': 'ENSG00000082641',
#    'Name.TF': 'NFE2L1',
#    'UniprotID.TF': 'Q14494',
#    'TF.TFLink.ortho': 'Dr:U3JAR7;Mm:Q61985;Rn:D4A349',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6651',
#    'Ensembl.GeneID.TF': 'ENSG00000159140',
#    'Name.TF': 'SON',
#    'UniprotID.TF': 'P18583',
#    'TF.TFLink.ortho': 'Mm:Q9QX47;Rn:F1MAQ7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8625',
#    'Ensembl.GeneID.TF': 'ENSG00000064490',
#    'Name.TF': 'RFXANK',
#    'UniprotID.TF': 'O14593',
#    'TF.TFLink.ortho': 'Dm:Q9VL58;Dr:B3DI78;Mm:Q9Z205;Rn:Q5PQM6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5929',
#    'Ensembl.GeneID.TF': 'ENSG00000117222',
#    'Name.TF': 'RBBP5',
#    'UniprotID.TF': 'Q15291',
#    'TF.TFLink.ortho': 'Ce:Q09309;Dm:Q9VPH8;Mm:Q8BX09;Rn:D3ZC01;Sc:P39706',
#    'TF.nonTFLink.ortho': 'Dr:F1QST7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23028',
#    'Ensembl.GeneID.TF': 'ENSG00000004487',
#    'Name.TF': 'KDM1A',
#    'UniprotID.TF': 'O60341',
#    'TF.TFLink.ortho': 'Dm:Q9VW97;Dr:F6NIA2;Mm:Q6ZQ88;Rn:F1MA31',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '24149',
#    'Ensembl.GeneID.TF': 'ENSG00000171467',
#    'Name.TF': 'ZNF318',
#    'UniprotID.TF': 'Q5VUA4',
#    'TF.TFLink.ortho': 'Mm:Q99PP2;Rn:F1M0H0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9314',
#    'Ensembl.GeneID.TF': 'ENSG00000136826',
#    'Name.TF': 'KLF4',
#    'UniprotID.TF': 'O43474',
#    'TF.TFLink.ortho': 'Mm:Q60793;Rn:Q923V7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4199',
#    'Ensembl.GeneID.TF': 'ENSG00000065833',
#    'Name.TF': 'ME1',
#    'UniprotID.TF': 'P48163',
#    'TF.TFLink.ortho': 'Mm:P06801;Rn:A0A0G2K1S6',
#    'TF.nonTFLink.ortho': 'Dr:F1QU54',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '58486',
#    'Ensembl.GeneID.TF': 'ENSG00000236287',
#    'Name.TF': 'ZBED5',
#    'UniprotID.TF': 'Q49AG3',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10589',
#    'Ensembl.GeneID.TF': 'ENSG00000175550',
#    'Name.TF': 'DRAP1',
#    'UniprotID.TF': 'Q14919',
#    'TF.TFLink.ortho': 'Dr:F1R8S0;Mm:Q9D6N5;Rn:A0JPP1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29117',
#    'Ensembl.GeneID.TF': 'ENSG00000166164',
#    'Name.TF': 'BRD7',
#    'UniprotID.TF': 'Q9NPI1',
#    'TF.TFLink.ortho': 'Ce:Q17581;Dr:B0S7E1;Mm:O88665;Rn:A0A0G2JTM7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3054',
#    'Ensembl.GeneID.TF': 'ENSG00000172534',
#    'Name.TF': 'HCFC1',
#    'UniprotID.TF': 'P51610',
#    'TF.TFLink.ortho': 'Dr:F1Q750;Dr:A8WIP5;Mm:Q61191;Rn:D3ZN95',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6046',
#    'Ensembl.GeneID.TF': 'ENSG00000204256',
#    'Name.TF': 'BRD2',
#    'UniprotID.TF': 'P25440',
#    'TF.TFLink.ortho': 'Mm:Q7JJ13',
#    'TF.nonTFLink.ortho': 'Dr:Q1LWX7;Rn:Q6MGA9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57459',
#    'Ensembl.GeneID.TF': 'ENSG00000143614',
#    'Name.TF': 'GATAD2B',
#    'UniprotID.TF': 'Q8WXI9',
#    'TF.TFLink.ortho': 'Mm:Q8VHR5;Rn:Q4V8E1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10155',
#    'Ensembl.GeneID.TF': 'ENSG00000130726',
#    'Name.TF': 'TRIM28',
#    'UniprotID.TF': 'Q13263',
#    'TF.TFLink.ortho': 'Mm:Q62318;Rn:O08629',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;18971253;27924024;26578589',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '11198',
#    'Ensembl.GeneID.TF': 'ENSG00000092201',
#    'Name.TF': 'SUPT16H',
#    'UniprotID.TF': 'Q9Y5B9',
#    'TF.TFLink.ortho': 'Ce:Q9N5R9;Dm:Q8IRG6;Mm:G3X956;Rn:D4A4J0;Sc:P32558',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1997',
#    'Ensembl.GeneID.TF': 'ENSG00000120690',
#    'Name.TF': 'ELF1',
#    'UniprotID.TF': 'P32519',
#    'TF.TFLink.ortho': 'Dr:E7F1J0;Mm:Q60775',
#    'TF.nonTFLink.ortho': 'Rn:G3V9V2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '894',
#    'Ensembl.GeneID.TF': 'ENSG00000118971',
#    'Name.TF': 'CCND2',
#    'UniprotID.TF': 'P30279',
#    'TF.TFLink.ortho': 'Dr:F1R9R4;Mm:P30280;Rn:G3V8M9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51157',
#    'Ensembl.GeneID.TF': 'ENSG00000213015',
#    'Name.TF': 'ZNF580',
#    'UniprotID.TF': 'Q9UK33',
#    'TF.TFLink.ortho': 'Mm:Q9DB38',
#    'TF.nonTFLink.ortho': 'Rn:D4A235',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23462',
#    'Ensembl.GeneID.TF': 'ENSG00000164683',
#    'Name.TF': 'HEY1',
#    'UniprotID.TF': 'Q9Y5J3',
#    'TF.TFLink.ortho': 'Dr:Q8AXV6;Rn:D3ZNI5',
#    'TF.nonTFLink.ortho': 'Mm:Q9QUM5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8626',
#    'Ensembl.GeneID.TF': 'ENSG00000073282',
#    'Name.TF': 'TP63',
#    'UniprotID.TF': 'Q9H3D4',
#    'TF.TFLink.ortho': 'Mm:O88898;Rn:Q9JJP6',
#    'TF.nonTFLink.ortho': 'Dr:F1QLJ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8050',
#    'Ensembl.GeneID.TF': 'ENSG00000110435',
#    'Name.TF': 'PDHX',
#    'UniprotID.TF': 'O00330',
#    'TF.TFLink.ortho': 'Mm:Q8BKZ9',
#    'TF.nonTFLink.ortho': 'Dr:Q6NW45;Rn:A0A0G2JZH8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2000',
#    'Ensembl.GeneID.TF': 'ENSG00000102034',
#    'Name.TF': 'ELF4',
#    'UniprotID.TF': 'Q99607',
#    'TF.TFLink.ortho': 'Mm:Q9Z2U4',
#    'TF.nonTFLink.ortho': 'Rn:D3ZWM8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10127',
#    'Ensembl.GeneID.TF': 'ENSG00000006194',
#    'Name.TF': 'ZNF263',
#    'UniprotID.TF': 'O14978',
#    'TF.TFLink.ortho': 'Mm:Q8CF60;Rn:D3ZQ68',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4335',
#    'Ensembl.GeneID.TF': 'ENSG00000070444',
#    'Name.TF': 'MNT',
#    'UniprotID.TF': 'Q99583',
#    'TF.TFLink.ortho': 'Mm:O08789;Rn:A0A0U1RRY7',
#    'TF.nonTFLink.ortho': 'Dr:F1QBK5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10346',
#    'Ensembl.GeneID.TF': 'ENSG00000132274',
#    'Name.TF': 'TRIM22',
#    'UniprotID.TF': 'Q8IYM9',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5093',
#    'Ensembl.GeneID.TF': 'ENSG00000169564',
#    'Name.TF': 'PCBP1',
#    'UniprotID.TF': 'Q15365',
#    'TF.TFLink.ortho': 'Mm:P60335',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10413',
#    'Ensembl.GeneID.TF': 'ENSG00000137693',
#    'Name.TF': 'YAP1',
#    'UniprotID.TF': 'P46937',
#    'TF.TFLink.ortho': 'Dr:Q1L8J7;Mm:P46938;Rn:Q2EJA0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6774',
#    'Ensembl.GeneID.TF': 'ENSG00000168610',
#    'Name.TF': 'STAT3',
#    'UniprotID.TF': 'P40763',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7004',
#    'Ensembl.GeneID.TF': 'ENSG00000197905',
#    'Name.TF': 'TEAD4',
#    'UniprotID.TF': 'Q15561',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4IZY5;Rn:F1M665',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10625',
#    'Ensembl.GeneID.TF': 'ENSG00000116679',
#    'Name.TF': 'IVNS1ABP',
#    'UniprotID.TF': 'Q9Y6Y0',
#    'TF.TFLink.ortho': 'Ce:Q21854;Dr:Q5RG82;Mm:Q920Q8;Rn:A0A0G2K427',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5934',
#    'Ensembl.GeneID.TF': 'ENSG00000103479',
#    'Name.TF': 'RBL2',
#    'UniprotID.TF': 'Q08999',
#    'TF.TFLink.ortho': 'Dr:E7FDM3;Mm:Q64700;Rn:G3V7P7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7528',
#    'Ensembl.GeneID.TF': 'ENSG00000100811',
#    'Name.TF': 'YY1',
#    'UniprotID.TF': 'P25490',
#    'TF.TFLink.ortho': 'Mm:Q00899;Rn:Q8CHJ4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55553',
#    'Ensembl.GeneID.TF': 'ENSG00000110693',
#    'Name.TF': 'SOX6',
#    'UniprotID.TF': 'P35712',
#    'TF.TFLink.ortho': 'Mm:P40645',
#    'TF.nonTFLink.ortho': 'Dr:A0A1D5NSY8;Rn:A0A6R0V8A0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3725',
#    'Ensembl.GeneID.TF': 'ENSG00000177606',
#    'Name.TF': 'JUN',
#    'UniprotID.TF': 'P05412',
#    'TF.TFLink.ortho': 'Dr:Q6NZT5;Mm:P05627;Rn:P17325',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9324',
#    'Ensembl.GeneID.TF': 'ENSG00000118418',
#    'Name.TF': 'HMGN3',
#    'UniprotID.TF': 'Q15651',
#    'TF.TFLink.ortho': 'Mm:Q9DCB1',
#    'TF.nonTFLink.ortho': 'Rn:M0R953',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '862',
#    'Ensembl.GeneID.TF': 'ENSG00000079102',
#    'Name.TF': 'RUNX1T1',
#    'UniprotID.TF': 'Q06455',
#    'TF.TFLink.ortho': 'Mm:Q61909;Rn:A0A0G2K0G0',
#    'TF.nonTFLink.ortho': 'Dr:Q1L8K2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6879',
#    'Ensembl.GeneID.TF': 'ENSG00000178913',
#    'Name.TF': 'TAF7',
#    'UniprotID.TF': 'Q15545',
#    'TF.TFLink.ortho': 'Dr:Q8JHG4;Mm:Q9R1C0;Rn:B0BN78',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2959',
#    'Ensembl.GeneID.TF': 'ENSG00000137947',
#    'Name.TF': 'GTF2B',
#    'UniprotID.TF': 'Q00403',
#    'TF.TFLink.ortho': 'Ce:O16991;Dm:P29052;Dr:A0A0R4IRB5;Mm:P62915;Rn:A0A0G2JWZ8;Sc:P29055',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7182',
#    'Ensembl.GeneID.TF': 'ENSG00000177463',
#    'Name.TF': 'NR2C2',
#    'UniprotID.TF': 'P49116',
#    'TF.TFLink.ortho': 'Dr:F6PDV8;Mm:P49117;Rn:G3V7F5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4004',
#    'Ensembl.GeneID.TF': 'ENSG00000166407',
#    'Name.TF': 'LMO1',
#    'UniprotID.TF': 'P25800',
#    'TF.TFLink.ortho': 'Dm:Q8IRC7;Dr:Q8JFQ2;Mm:Q924W9;Rn:A0A0G2K422',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10013',
#    'Ensembl.GeneID.TF': 'ENSG00000094631',
#    'Name.TF': 'HDAC6',
#    'UniprotID.TF': 'Q9UBN7',
#    'TF.TFLink.ortho': 'Dr:F8W4B7;Mm:Q9Z2V5',
#    'TF.nonTFLink.ortho': 'Ce:A7LPD8;Dm:M9NEH6;Rn:A0A0G2QC41;Rn:D3ZVD8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55726',
#    'Ensembl.GeneID.TF': 'ENSG00000064102',
#    'Name.TF': 'INTS13',
#    'UniprotID.TF': 'Q9NVM9',
#    'TF.TFLink.ortho': 'Ce:O44500;Dm:Q9VEX5;Mm:Q8QZV7;Rn:D4A6N9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51755',
#    'Ensembl.GeneID.TF': 'ENSG00000167258',
#    'Name.TF': 'CDK12',
#    'UniprotID.TF': 'Q9NYV4',
#    'TF.TFLink.ortho': 'Dr:F1R6Y1;Mm:Q14AX6;Rn:Q3MJK5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4780',
#    'Ensembl.GeneID.TF': 'ENSG00000116044',
#    'Name.TF': 'NFE2L2',
#    'UniprotID.TF': 'Q16236',
#    'TF.TFLink.ortho': 'Dr:Q7ZVI2;Mm:Q60795;Rn:O54968',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23405',
#    'Ensembl.GeneID.TF': 'ENSG00000100697',
#    'Name.TF': 'DICER1',
#    'UniprotID.TF': 'Q9UPY3',
#    'TF.TFLink.ortho': 'Ce:P34529;Dm:Q9VCU9;Dr:Q6TV19;Mm:F8VQ54',
#    'TF.nonTFLink.ortho': 'Rn:E9PU15',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8554',
#    'Ensembl.GeneID.TF': 'ENSG00000033800',
#    'Name.TF': 'PIAS1',
#    'UniprotID.TF': 'O75925',
#    'TF.TFLink.ortho': 'Dr:X1WDM3;Dr:A0A1D5NSS2;Mm:O88907;Rn:G3V9T0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6935',
#    'Ensembl.GeneID.TF': 'ENSG00000148516',
#    'Name.TF': 'ZEB1',
#    'UniprotID.TF': 'P37275',
#    'TF.TFLink.ortho': 'Dr:F1QPM7;Mm:Q64318;Rn:F8WG35',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1432',
#    'Ensembl.GeneID.TF': 'ENSG00000112062',
#    'Name.TF': 'MAPK14',
#    'UniprotID.TF': 'Q16539',
#    'TF.TFLink.ortho': 'Dm:O61443;Dm:O62618;Mm:P47811;Rn:Q56A33',
#    'TF.nonTFLink.ortho': 'Dr:F1R202',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9189',
#    'Ensembl.GeneID.TF': 'ENSG00000214717',
#    'Name.TF': 'ZBED1',
#    'UniprotID.TF': 'O96006',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10463',
#    'Ensembl.GeneID.TF': 'ENSG00000014824',
#    'Name.TF': 'SLC30A9',
#    'UniprotID.TF': 'Q6PML9',
#    'TF.TFLink.ortho': 'Ce:Q3V5J4;Dr:Q5PQZ3;Mm:Q5IRJ6;Rn:D3ZWW5',
#    'TF.nonTFLink.ortho': 'Dm:A1Z936',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '80853',
#    'Ensembl.GeneID.TF': 'ENSG00000006459',
#    'Name.TF': 'KDM7A',
#    'UniprotID.TF': 'Q6ZMT4',
#    'TF.TFLink.ortho': 'Dr:Q5RHD1;Mm:Q3UWM4',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K1Z1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '196',
#    'Ensembl.GeneID.TF': 'ENSG00000106546',
#    'Name.TF': 'AHR',
#    'UniprotID.TF': 'P35869',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7767',
#    'Ensembl.GeneID.TF': 'ENSG00000267680',
#    'Name.TF': 'ZNF224',
#    'UniprotID.TF': 'Q9NZL3',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '83463',
#    'Ensembl.GeneID.TF': 'ENSG00000213347',
#    'Name.TF': 'MXD3',
#    'UniprotID.TF': 'Q9BW11',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IMG7;Mm:Q80US8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4089',
#    'Ensembl.GeneID.TF': 'ENSG00000141646',
#    'Name.TF': 'SMAD4',
#    'UniprotID.TF': 'Q13485',
#    'TF.TFLink.ortho': 'Mm:P97471;Rn:A0A0G2K970',
#    'TF.nonTFLink.ortho': 'Dm:Q8IMG6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5970',
#    'Ensembl.GeneID.TF': 'ENSG00000173039',
#    'Name.TF': 'RELA',
#    'UniprotID.TF': 'Q04206',
#    'TF.TFLink.ortho': 'Mm:Q04207;Rn:Q7TQN4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '54880',
#    'Ensembl.GeneID.TF': 'ENSG00000183337',
#    'Name.TF': 'BCOR',
#    'UniprotID.TF': 'Q6W2J9',
#    'TF.TFLink.ortho': 'Mm:Q8CGN4;Rn:D4A2J9',
#    'TF.nonTFLink.ortho': 'Dr:Q6W2J8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55818',
#    'Ensembl.GeneID.TF': 'ENSG00000115548',
#    'Name.TF': 'KDM3A',
#    'UniprotID.TF': 'Q9Y4C1',
#    'TF.TFLink.ortho': 'Mm:Q6PCM1;Rn:A0A0G2K220',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84844',
#    'Ensembl.GeneID.TF': 'ENSG00000100410',
#    'Name.TF': 'PHF5A',
#    'UniprotID.TF': 'Q7RTV0',
#    'TF.TFLink.ortho': 'Dm:Q9VMC8;Dr:Q6YMR2;Mm:P83870;Rn:P83871;Sc:Q06835',
#    'TF.nonTFLink.ortho': 'Ce:G5EBY6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8553',
#    'Ensembl.GeneID.TF': 'ENSG00000134107',
#    'Name.TF': 'BHLHE40',
#    'UniprotID.TF': 'O14503',
#    'TF.TFLink.ortho': 'Dr:Q6NY50;Mm:O35185;Rn:Q76JQ4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
# ...
#    'TF.TFLink.ortho': 'Mm:Q9Z2F6;Rn:D3ZQF8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7975',
#    'Ensembl.GeneID.TF': 'ENSG00000198517',
#    'Name.TF': 'MAFK',
#    'UniprotID.TF': 'O60675',
#    'TF.TFLink.ortho': 'Dm:A0A0B4LH09;Dr:A0A0R4IVU1;Mm:Q61827;Rn:Q6IRI7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4298',
#    'Ensembl.GeneID.TF': 'ENSG00000130382',
#    'Name.TF': 'MLLT1',
#    'UniprotID.TF': 'Q03111',
#    'TF.TFLink.ortho': 'Dr:E9QEN8;Mm:Q9ERL0;Rn:M0R462',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84148',
#    'Ensembl.GeneID.TF': 'ENSG00000103510',
#    'Name.TF': 'KAT8',
#    'UniprotID.TF': 'Q9H7Z6',
#    'TF.TFLink.ortho': 'Dm:Q9VAV6;Mm:Q9D1P2;Rn:Q5XI06',
#    'TF.nonTFLink.ortho': 'Dr:F1QX50',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2962',
#    'Ensembl.GeneID.TF': 'ENSG00000125651',
#    'Name.TF': 'GTF2F1',
#    'UniprotID.TF': 'P35269',
#    'TF.TFLink.ortho': 'Dm:Q05913;Dr:Q5PNQ6;Mm:Q3THK3;Rn:Q6AY96',
#    'TF.nonTFLink.ortho': 'Ce:Q17558',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7746',
#    'Ensembl.GeneID.TF': 'ENSG00000137185',
#    'Name.TF': 'ZSCAN9',
#    'UniprotID.TF': 'O15535',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6668',
#    'Ensembl.GeneID.TF': 'ENSG00000167182',
#    'Name.TF': 'SP2',
#    'UniprotID.TF': 'Q02086',
#    'TF.TFLink.ortho': 'Dr:F1Q4L6;Mm:Q8C5J0;Rn:B5DEH3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4999',
#    'Ensembl.GeneID.TF': 'ENSG00000115942',
#    'Name.TF': 'ORC2',
#    'UniprotID.TF': 'Q13416',
#    'TF.TFLink.ortho': 'Dm:Q24168;Mm:Q60862;Rn:Q75PQ8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10725',
#    'Ensembl.GeneID.TF': 'ENSG00000102908',
#    'Name.TF': 'NFAT5',
#    'UniprotID.TF': 'O94916',
#    'TF.TFLink.ortho': 'Mm:Q9WV30',
#    'TF.nonTFLink.ortho': 'Rn:D3ZGB1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5993',
#    'Ensembl.GeneID.TF': 'ENSG00000143390',
#    'Name.TF': 'RFX5',
#    'UniprotID.TF': 'P48382',
#    'TF.TFLink.ortho': 'Mm:Q9JL61;Rn:D3ZHD7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7227',
#    'Ensembl.GeneID.TF': 'ENSG00000104447',
#    'Name.TF': 'TRPS1',
#    'UniprotID.TF': 'Q9UHF7',
#    'TF.TFLink.ortho': 'Dr:F1QEY1;Rn:D3ZEM6',
#    'TF.nonTFLink.ortho': 'Mm:G3UW90',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7709',
#    'Ensembl.GeneID.TF': 'ENSG00000116809',
#    'Name.TF': 'ZBTB17',
#    'UniprotID.TF': 'Q13105',
#    'TF.TFLink.ortho': 'Ce:G5EDU4;Mm:Q60821;Rn:Q5XIU3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '22834',
#    'Ensembl.GeneID.TF': 'ENSG00000198740',
#    'Name.TF': 'ZNF652',
#    'UniprotID.TF': 'Q9Y2D9',
#    'TF.TFLink.ortho': 'Dm:A1ZBC5;Mm:Q5DU09;Rn:A1L1J6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '196528',
#    'Ensembl.GeneID.TF': 'ENSG00000189079',
#    'Name.TF': 'ARID2',
#    'UniprotID.TF': 'Q68CP9',
#    'TF.TFLink.ortho': 'Dm:A1Z6M0;Mm:E9Q7E2;Rn:D3ZJU0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '324',
#    'Ensembl.GeneID.TF': 'ENSG00000134982',
#    'Name.TF': 'APC',
#    'UniprotID.TF': 'P25054',
#    'TF.TFLink.ortho': 'Mm:B2RUG9',
#    'TF.nonTFLink.ortho': 'Dr:F8W4Z3;Rn:A0A0G2K8G0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9441',
#    'Ensembl.GeneID.TF': 'ENSG00000105085',
#    'Name.TF': 'MED26',
#    'UniprotID.TF': 'O95402',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '83855',
#    'Ensembl.GeneID.TF': 'ENSG00000129911',
#    'Name.TF': 'KLF16',
#    'UniprotID.TF': 'Q9BXK1',
#    'TF.TFLink.ortho': 'Mm:P58334;Rn:B2GUY9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4968',
#    'Ensembl.GeneID.TF': 'ENSG00000114026',
#    'Name.TF': 'OGG1',
#    'UniprotID.TF': 'O15527',
#    'TF.TFLink.ortho': 'Dm:Q9V3I8;Dr:B0R135;Mm:O08760;Rn:O70249',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '197407',
#    'Ensembl.GeneID.TF': 'ENSG00000180035',
#    'Name.TF': 'ZNF48',
#    'UniprotID.TF': 'Q96MX3',
#    'TF.TFLink.ortho': 'Ce:G5EFF4;Mm:Q3US17;Rn:D3ZY01',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '83439',
#    'Ensembl.GeneID.TF': 'ENSG00000152284',
#    'Name.TF': 'TCF7L1',
#    'UniprotID.TF': 'Q9HCS4',
#    'TF.TFLink.ortho': 'Dr:Q9YHE8;Dr:F1R336;Rn:F1M1R9',
#    'TF.nonTFLink.ortho': 'Mm:A1A549',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6772',
#    'Ensembl.GeneID.TF': 'ENSG00000115415',
#    'Name.TF': 'STAT1',
#    'UniprotID.TF': 'P42224',
#    'TF.TFLink.ortho': 'Dr:Q6P943',
#    'TF.nonTFLink.ortho': 'Mm:A0A087WSP5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2068',
#    'Ensembl.GeneID.TF': 'ENSG00000104884',
#    'Name.TF': 'ERCC2',
#    'UniprotID.TF': 'P18074',
#    'TF.TFLink.ortho': 'Dm:Q7KVP9;Dr:F1Q5E7;Mm:O08811;Rn:D3ZEG9;Sc:P06839',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '847',
#    'Ensembl.GeneID.TF': 'ENSG00000121691',
#    'Name.TF': 'CAT',
#    'UniprotID.TF': 'P04040',
#    'TF.TFLink.ortho': 'Ce:Q8MYL7;Dm:P17336;Mm:P24270;Rn:P04762;Sc:P15202',
#    'TF.nonTFLink.ortho': 'Ce:Q27487;Ce:O61235',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4088',
#    'Ensembl.GeneID.TF': 'ENSG00000166949',
#    'Name.TF': 'SMAD3',
#    'UniprotID.TF': 'P84022',
#    'TF.TFLink.ortho': 'Dr:Q8AY15;Mm:Q8BUN5;Rn:P84025',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55636',
#    'Ensembl.GeneID.TF': 'ENSG00000171316',
#    'Name.TF': 'CHD7',
#    'UniprotID.TF': 'Q9P2D1',
#    'TF.TFLink.ortho': 'Dr:F1QGL1;Mm:A2AJK6;Rn:D3ZAP7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4221',
#    'Ensembl.GeneID.TF': 'ENSG00000133895',
#    'Name.TF': 'MEN1',
#    'UniprotID.TF': 'O00255',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3164',
#    'Ensembl.GeneID.TF': 'ENSG00000123358',
#    'Name.TF': 'NR4A1',
#    'UniprotID.TF': 'P22736',
#    'TF.TFLink.ortho': 'Mm:P12813;Rn:P22829',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4086',
#    'Ensembl.GeneID.TF': 'ENSG00000170365',
#    'Name.TF': 'SMAD1',
#    'UniprotID.TF': 'Q15797',
#    'TF.TFLink.ortho': 'Mm:P70340;Rn:A0A0G2JSQ6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '604',
#    'Ensembl.GeneID.TF': 'ENSG00000113916',
#    'Name.TF': 'BCL6',
#    'UniprotID.TF': 'P41182',
#    'TF.TFLink.ortho': 'Dr:F1R5N6;Mm:P41183;Rn:B2GUV8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8462',
#    'Ensembl.GeneID.TF': 'ENSG00000172059',
#    'Name.TF': 'KLF11',
#    'UniprotID.TF': 'O14901',
#    'TF.TFLink.ortho': 'Dr:F1R5X2;Dr:Q5RIQ4;Mm:Q8K1S5;Rn:E9PTS6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2353',
#    'Ensembl.GeneID.TF': 'ENSG00000170345',
#    'Name.TF': 'FOS',
#    'UniprotID.TF': 'P01100',
#    'TF.TFLink.ortho': 'Dr:Q6P0S4;Mm:P01101;Rn:P12841',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;18971253;27924024;26578589',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23543',
#    'Ensembl.GeneID.TF': 'ENSG00000100320',
#    'Name.TF': 'RBFOX2',
#    'UniprotID.TF': 'O43251',
#    'TF.TFLink.ortho': 'Mm:Q8BP71',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2JYY7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7290',
#    'Ensembl.GeneID.TF': 'ENSG00000100084',
#    'Name.TF': 'HIRA',
#    'UniprotID.TF': 'P54198',
#    'TF.TFLink.ortho': 'Ce:Q09589;Dm:A1Z898;Dr:A2CEX6;Mm:Q61666;Rn:M0R4R2',
#    'TF.nonTFLink.ortho': 'Rn:M0R756',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2521',
#    'Ensembl.GeneID.TF': 'ENSG00000089280',
#    'Name.TF': 'FUS',
#    'UniprotID.TF': 'P35637',
#    'TF.TFLink.ortho': 'Dr:F1R0M4;Mm:P56959;Rn:Q5PQK2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29855',
#    'Ensembl.GeneID.TF': 'ENSG00000118900',
#    'Name.TF': 'UBN1',
#    'UniprotID.TF': 'Q9NPG3',
#    'TF.TFLink.ortho': 'Mm:Q4G0F8;Rn:D4A8C6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '168544',
#    'Ensembl.GeneID.TF': 'ENSG00000181444',
#    'Name.TF': 'ZNF467',
#    'UniprotID.TF': 'Q7Z7K2',
#    'TF.TFLink.ortho': 'Mm:Q8JZL0;Rn:Q5RJR4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '405',
#    'Ensembl.GeneID.TF': 'ENSG00000143437',
#    'Name.TF': 'ARNT',
#    'UniprotID.TF': 'P27540',
#    'TF.TFLink.ortho': 'Mm:P53762;Rn:F1LMF9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4774',
#    'Ensembl.GeneID.TF': 'ENSG00000162599',
#    'Name.TF': 'NFIA',
#    'UniprotID.TF': 'Q12857',
#    'TF.TFLink.ortho': 'Dr:Q1L9B0;Mm:Q02780;Rn:A0A0G2K5I9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '65980',
#    'Ensembl.GeneID.TF': 'ENSG00000028310',
#    'Name.TF': 'BRD9',
#    'UniprotID.TF': 'Q9H8M2',
#    'TF.TFLink.ortho': 'Dm:Q9VLX2;Dr:F1QNW6;Rn:D4ACF5',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4J175',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9839',
#    'Ensembl.GeneID.TF': 'ENSG00000169554',
#    'Name.TF': 'ZEB2',
#    'UniprotID.TF': 'O60315',
#    'TF.TFLink.ortho': 'Mm:Q9R0G7;Rn:E9PTC3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6671',
#    'Ensembl.GeneID.TF': 'ENSG00000105866',
#    'Name.TF': 'SP4',
#    'UniprotID.TF': 'Q02446',
#    'TF.TFLink.ortho': 'Dm:Q9VEW6;Mm:A0A1Y7VJR5;Rn:Q63158',
#    'TF.nonTFLink.ortho': 'Dr:F1QVQ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4824',
#    'Ensembl.GeneID.TF': 'ENSG00000167034',
#    'Name.TF': 'NKX3-1',
#    'UniprotID.TF': 'Q99801',
#    'TF.TFLink.ortho': 'Mm:P97436',
#    'TF.nonTFLink.ortho': 'Dr:Q68EL7;Rn:Q497B7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7728',
#    'Ensembl.GeneID.TF': 'ENSG00000105497',
#    'Name.TF': 'ZNF175',
#    'UniprotID.TF': 'Q9Y473',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '26959',
#    'Ensembl.GeneID.TF': 'ENSG00000105856',
#    'Name.TF': 'HBP1',
#    'UniprotID.TF': 'O60381',
#    'TF.TFLink.ortho': 'Dr:F1QK54;Mm:E9Q1A8;Rn:Z4YNI2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'}]}

# %%
ncbi_tf_df_human[ncbi_tf_df_human['target']=="3725"]["its_target"].to_dict()
# Out:
# {9229: [{'NCBI.GeneID.Target': '2729',
#    'Ensembl.GeneID.Target': 'ENSG00000001084',
#    'Name.Target': 'GCLC',
#    'UniprotID.Target': 'P48506',
#    'Target.TFLink.ortho': 'Ce:Q20117;Dm:Q9W3K5;Dr:Q6NV35;Mm:P97494;Rn:P19468;Sc:P32477',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;electrophoretic mobility shift assay;inferred by curator',
#    'PubmedID': '11912197;16054171;29087512;27924024;11233143;22900683',
#    'Source.database': 'GTRD;HTRI;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '3725',
#    'Ensembl.GeneID.Target': 'ENSG00000177606',
#    'Name.Target': 'JUN',
#    'UniprotID.Target': 'P05412',
#    'Target.TFLink.ortho': 'Dr:Q6NZT5;Mm:P05627;Rn:P17325',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;19671687;26578589;9502786;18971253;27924024;17202159;29087512',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '226',
#    'Ensembl.GeneID.Target': 'ENSG00000149925',
#    'Name.Target': 'ALDOA',
#    'UniprotID.Target': 'P04075',
#    'Target.TFLink.ortho': 'Ce:P46563;Dm:P07764;Dr:Q803Q7;Mm:P05064;Rn:P05065',
#    'Target.nonTFLink.ortho': 'Dr:Q6P043',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '4609',
#    'Ensembl.GeneID.Target': 'ENSG00000136997',
#    'Name.Target': 'MYC',
#    'UniprotID.Target': 'P01106',
#    'Target.TFLink.ortho': 'Dr:F1RC36;Mm:P01108',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;2498162;24234451;12695333;25303530;20211142;22266862;14523011;27924024;17202159;29087512',
#    'Source.database': 'FANTOM4_via_DoRothEA;GTRD;IntAct_via_DoRothEA;ReMap;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '2114',
#    'Ensembl.GeneID.Target': 'ENSG00000157557',
#    'Name.Target': 'ETS2',
#    'UniprotID.Target': 'P15036',
#    'Target.TFLink.ortho': 'Dr:Q501S1;Mm:P15037;Rn:D4AAH4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;22354960;17202159;29087512',
#    'Source.database': 'GTRD;ReMap;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '19',
#    'Ensembl.GeneID.Target': 'ENSG00000165029',
#    'Name.Target': 'ABCA1',
#    'UniprotID.Target': 'O95477',
#    'Target.TFLink.ortho': 'Dr:E7F2Y6;Dr:B8A446;Mm:P41233;Rn:F1LNL3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '7037',
#    'Ensembl.GeneID.Target': 'ENSG00000072274',
#    'Name.Target': 'TFRC',
#    'UniprotID.Target': 'P02786',
#    'Target.TFLink.ortho': 'Mm:Q62351',
#    'Target.nonTFLink.ortho': 'Dr:Q5MPX4;Rn:Q99376',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '3454',
#    'Ensembl.GeneID.Target': 'ENSG00000142166',
#    'Name.Target': 'IFNAR1',
#    'UniprotID.Target': 'P17181',
#    'Target.TFLink.ortho': 'Mm:P33896;Rn:D3ZDS9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '2277',
#    'Ensembl.GeneID.Target': 'ENSG00000165197',
#    'Name.Target': 'VEGFD',
#    'UniprotID.Target': 'O43915',
#    'Target.TFLink.ortho': 'Dr:Q208T6;Mm:P97946',
#    'Target.nonTFLink.ortho': 'Rn:G3V9S8',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29087512;27924024;19136250;27899662',
#    'Source.database': 'GTRD;KEGG_via_DoRothEA;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '388',
#    'Ensembl.GeneID.Target': 'ENSG00000143878',
#    'Name.Target': 'RHOB',
#    'UniprotID.Target': 'P62745',
#    'Target.TFLink.ortho': 'Mm:P62746;Rn:P62747',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;29087512;21565167;27924024',
#    'Source.database': 'GTRD;ReMap;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '1026',
#    'Ensembl.GeneID.Target': 'ENSG00000124762',
#    'Name.Target': 'CDKN1A',
#    'UniprotID.Target': 'P38936',
#    'Target.TFLink.ortho': 'Mm:P39689;Rn:Q64315',
#    'Target.nonTFLink.ortho': 'Dr:A5WWG3',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '21278055;27924024;17202159;29087512;18094076',
#    'Source.database': 'GTRD;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '5730',
#    'Ensembl.GeneID.Target': 'ENSG00000107317',
#    'Name.Target': 'PTGDS',
#    'UniprotID.Target': 'P41222',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27924024;17202159',
#    'Source.database': 'GTRD;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '51278',
#    'Ensembl.GeneID.Target': 'ENSG00000162783',
#    'Name.Target': 'IER5',
#    'UniprotID.Target': 'Q5VY09',
#    'Target.TFLink.ortho': 'Dr:Q90X37;Mm:O89113',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;27924024;17202159',
#    'Source.database': 'GTRD;ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '5465',
#    'Ensembl.GeneID.Target': 'ENSG00000186951',
#    'Name.Target': 'PPARA',
#    'UniprotID.Target': 'Q07869',
#    'Target.TFLink.ortho': 'Dr:K7DY57;Mm:P23204;Rn:P37230',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27924024;18625220;17202159;29087512;10542237;22900683',
#    'Source.database': 'GTRD;HTRI;TRED;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '10875',
#    'Ensembl.GeneID.Target': 'ENSG00000127951',
#    'Name.Target': 'FGL2',
#    'UniprotID.Target': 'Q14314',
#    'Target.TFLink.ortho': 'Dm:Q9VW70;Mm:P12804;Rn:G3V7P2',
#    'Target.nonTFLink.ortho': 'Dr:Q5TYU3',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '27924024;17202159',
#    'Source.database': 'GTRD;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '1281',
#    'Ensembl.GeneID.Target': 'ENSG00000168542',
#    'Name.Target': 'COL3A1',
#    'UniprotID.Target': 'P02461',
#    'Target.TFLink.ortho': 'Mm:P08121;Rn:P13941',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;17202159',
#    'Source.database': 'ReMap;TRED',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '127687',
#    'Ensembl.GeneID.Target': 'ENSG00000197982',
#    'Name.Target': 'C1orf122',
#    'UniprotID.Target': 'Q6ZSJ8',
#    'Target.TFLink.ortho': 'Rn:D3ZK76',
#    'Target.nonTFLink.ortho': 'Mm:V9GXF1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '168507',
#    'Ensembl.GeneID.Target': 'ENSG00000158683',
#    'Name.Target': 'PKD1L1',
#    'UniprotID.Target': 'Q8TDX9',
#    'Target.TFLink.ortho': 'Mm:A0A0A0MQK4;Rn:F1M1X0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51380',
#    'Ensembl.GeneID.Target': 'ENSG00000139631',
#    'Name.Target': 'CSAD',
#    'UniprotID.Target': 'Q9Y600',
#    'Target.TFLink.ortho': 'Mm:Q9DBE0;Rn:Q64611',
#    'Target.nonTFLink.ortho': 'Dr:F1QG14',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51209',
#    'Ensembl.GeneID.Target': 'ENSG00000123570',
#    'Name.Target': 'RAB9B',
#    'UniprotID.Target': 'Q9NP90',
#    'Target.TFLink.ortho': 'Dr:E7F8G0;Mm:Q8BHH2;Rn:D3ZP15',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '121441',
#    'Ensembl.GeneID.Target': 'ENSG00000139350',
#    'Name.Target': 'NEDD1',
#    'UniprotID.Target': 'Q8NHV4',
#    'Target.TFLink.ortho': 'Dm:Q9VJ57;Mm:P33215;Rn:D3ZAH3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2110',
#    'Ensembl.GeneID.Target': 'ENSG00000171503',
#    'Name.Target': 'ETFDH',
#    'UniprotID.Target': 'Q16134',
#    'Target.TFLink.ortho': 'Ce:Q11190;Dm:Q7JWF1;Mm:Q921G7;Rn:Q66HF3;Sc:Q08822',
#    'Target.nonTFLink.ortho': 'Dr:Q66I16',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '728568',
#    'Ensembl.GeneID.Target': 'ENSG00000204954',
#    'Name.Target': 'BRAWNIN',
#    'UniprotID.Target': 'Q69YU5',
#    'Target.TFLink.ortho': 'Dr:E7EXZ6;Mm:Q8BTC1;Rn:D3ZZG3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6596',
#    'Ensembl.GeneID.Target': 'ENSG00000071794',
#    'Name.Target': 'HLTF',
#    'UniprotID.Target': 'Q14527',
#    'Target.TFLink.ortho': 'Dr:B0V118;Mm:Q6PCN7;Rn:A0A0G2JVH5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5528',
#    'Ensembl.GeneID.Target': 'ENSG00000112640',
#    'Name.Target': 'PPP2R5D',
#    'UniprotID.Target': 'Q14738',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': 'Mm:Q7TNL5;Rn:F1MAA3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '11167',
#    'Ensembl.GeneID.Target': 'ENSG00000163430',
#    'Name.Target': 'FSTL1',
#    'UniprotID.Target': 'Q12841',
#    'Target.TFLink.ortho': 'Dr:Q2PMI2;Mm:Q62356;Rn:Q62632',
#    'Target.nonTFLink.ortho': 'Dr:F1Q6U6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8195',
#    'Ensembl.GeneID.Target': 'ENSG00000125863',
#    'Name.Target': 'MKKS',
#    'UniprotID.Target': 'Q9NPJ1',
#    'Target.TFLink.ortho': 'Dr:F1QCQ8;Mm:Q9JI70;Rn:Q5XI30',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2235',
#    'Ensembl.GeneID.Target': 'ENSG00000066926',
#    'Name.Target': 'FECH',
#    'UniprotID.Target': 'P22830',
#    'Target.TFLink.ortho': 'Dm:Q9V9S8;Dr:F1R362;Mm:Q544X6;Rn:D3ZBM3;Sc:P16622',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56180',
#    'Ensembl.GeneID.Target': 'ENSG00000101928',
#    'Name.Target': 'MOSPD1',
#    'UniprotID.Target': 'Q9UJG1',
#    'Target.TFLink.ortho': 'Dr:F1R9R3;Mm:Q8VEL0',
#    'Target.nonTFLink.ortho': 'Rn:Q5RJS6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7436',
#    'Ensembl.GeneID.Target': 'ENSG00000147852',
#    'Name.Target': 'VLDLR',
#    'UniprotID.Target': 'P98155',
#    'Target.TFLink.ortho': 'Mm:P98156;Rn:F1LPV2',
#    'Target.nonTFLink.ortho': 'Dr:E9QBA5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3418',
#    'Ensembl.GeneID.Target': 'ENSG00000182054',
#    'Name.Target': 'IDH2',
#    'UniprotID.Target': 'P48735',
#    'Target.TFLink.ortho': 'Ce:O17643;Mm:P54071;Rn:P56574',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5162',
#    'Ensembl.GeneID.Target': 'ENSG00000168291',
#    'Name.Target': 'PDHB',
#    'UniprotID.Target': 'P11177',
#    'Target.TFLink.ortho': 'Ce:O44451;Dm:Q7K5K3;Dr:Q7T368;Mm:Q9D051;Sc:P32473',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2KAM3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8882',
#    'Ensembl.GeneID.Target': 'ENSG00000109917',
#    'Name.Target': 'ZPR1',
#    'UniprotID.Target': 'O75312',
#    'Target.TFLink.ortho': 'Ce:O16999;Dm:Q9W379;Dr:Q1LY31;Mm:Q62384;Rn:D3ZWN1;Sc:P53303',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '26095',
#    'Ensembl.GeneID.Target': 'ENSG00000204179',
#    'Name.Target': 'PTPN20',
#    'UniprotID.Target': 'Q4JDL3',
#    'Target.TFLink.ortho': 'Ce:P91498;Mm:O55082',
#    'Target.nonTFLink.ortho': 'Rn:A1L1L3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64374',
#    'Ensembl.GeneID.Target': 'ENSG00000120725',
#    'Name.Target': 'SIL1',
#    'UniprotID.Target': 'Q9H173',
#    'Target.TFLink.ortho': 'Dm:Q9VBV5;Dr:A0A0G2KDW7;Mm:Q9EPK6;Rn:Q6P6S4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1773',
#    'Ensembl.GeneID.Target': 'ENSG00000213918',
#    'Name.Target': 'DNASE1',
#    'UniprotID.Target': 'P24855',
#    'Target.TFLink.ortho': 'Mm:P49183',
#    'Target.nonTFLink.ortho': 'Dr:Q6DG72;Rn:P21704',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4540',
#    'Ensembl.GeneID.Target': 'ENSG00000198786',
#    'Name.Target': 'MT-ND5',
#    'UniprotID.Target': 'P03915',
#    'Target.TFLink.ortho': 'Dr:Q9MIY0;Mm:P03921',
#    'Target.nonTFLink.ortho': 'Rn:P11661',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '142',
#    'Ensembl.GeneID.Target': 'ENSG00000143799',
#    'Name.Target': 'PARP1',
#    'UniprotID.Target': 'P09874',
#    'Target.TFLink.ortho': 'Ce:Q9N4H4;Dm:P35875;Dr:Q5RHR0;Rn:P27008',
#    'Target.nonTFLink.ortho': 'Mm:Q921K2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5569',
#    'Ensembl.GeneID.Target': 'ENSG00000171033',
#    'Name.Target': 'PKIA',
#    'UniprotID.Target': 'P61925',
#    'Target.TFLink.ortho': 'Mm:P63248;Rn:P63249',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51428',
#    'Ensembl.GeneID.Target': 'ENSG00000183258',
#    'Name.Target': 'DDX41',
#    'UniprotID.Target': 'Q9UJV9',
#    'Target.TFLink.ortho': 'Dm:Q9V3C0;Mm:Q91VN6;Rn:B2RYL8',
#    'Target.nonTFLink.ortho': 'Ce:Q9N5K1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79902',
#    'Ensembl.GeneID.Target': 'ENSG00000125450',
#    'Name.Target': 'NUP85',
#    'UniprotID.Target': 'Q9BW27',
#    'Target.TFLink.ortho': 'Ce:Q22078;Dm:A1YK02;Mm:Q8R480;Rn:Q4QQS8',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4IZD5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51072',
#    'Ensembl.GeneID.Target': 'ENSG00000162959',
#    'Name.Target': 'MEMO1',
#    'UniprotID.Target': 'Q9Y316',
#    'Target.TFLink.ortho': 'Ce:Q22915;Dm:Q9VG04;Dr:A9JTC4;Mm:Q91VH6;Sc:P47085',
#    'Target.nonTFLink.ortho': 'Rn:F1LNE5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '154810',
#    'Ensembl.GeneID.Target': 'ENSG00000166025',
#    'Name.Target': 'AMOTL1',
#    'UniprotID.Target': 'Q8IY63',
#    'Target.TFLink.ortho': 'Mm:Q9D4H4;Rn:F1LZQ6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '92106',
#    'Ensembl.GeneID.Target': 'ENSG00000154814',
#    'Name.Target': 'OXNAD1',
#    'UniprotID.Target': 'Q96HP4',
#    'Target.TFLink.ortho': 'Dr:I3ISI1;Mm:Q8VE38;Rn:D4A0Y4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8073',
#    'Ensembl.GeneID.Target': 'ENSG00000184007',
#    'Name.Target': 'PTP4A2',
#    'UniprotID.Target': 'Q12974',
#    'Target.TFLink.ortho': 'Mm:O70274;Rn:Q6P9X4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '196483',
#    'Ensembl.GeneID.Target': 'ENSG00000118894',
#    'Name.Target': 'EEF2KMT',
#    'UniprotID.Target': 'Q96G04',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55089',
#    'Ensembl.GeneID.Target': 'ENSG00000139209',
#    'Name.Target': 'SLC38A4',
#    'UniprotID.Target': 'Q969I6',
#    'Target.TFLink.ortho': 'Dr:Q5SPB0;Mm:Q8R1S9;Rn:Q9EQ25',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '664',
#    'Ensembl.GeneID.Target': 'ENSG00000176171',
#    'Name.Target': 'BNIP3',
#    'UniprotID.Target': 'Q12983',
#    'Target.TFLink.ortho': 'Mm:O55003;Rn:Q9ET45',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '349565',
#    'Ensembl.GeneID.Target': 'ENSG00000163864',
#    'Name.Target': 'NMNAT3',
#    'UniprotID.Target': 'Q96T66',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1666',
#    'Ensembl.GeneID.Target': 'ENSG00000104325',
#    'Name.Target': 'DECR1',
#    'UniprotID.Target': 'Q16698',
#    'Target.TFLink.ortho': 'Ce:Q93761;Dr:F1QB21;Mm:Q9CQ62;Rn:G3V734',
#    'Target.nonTFLink.ortho': 'Ce:Q22230;Ce:Q23116',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64651',
#    'Ensembl.GeneID.Target': 'ENSG00000144655',
#    'Name.Target': 'CSRNP1',
#    'UniprotID.Target': 'Q96S65',
#    'Target.TFLink.ortho': 'Mm:P59054;Rn:D4AAK3',
#    'Target.nonTFLink.ortho': 'Dr:F1QNJ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56911',
#    'Ensembl.GeneID.Target': 'ENSG00000156265',
#    'Name.Target': 'MAP3K7CL',
#    'UniprotID.Target': 'P57077',
#    'Target.TFLink.ortho': 'Mm:P58500;Rn:A0A0G2K9U9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56850',
#    'Ensembl.GeneID.Target': 'ENSG00000068400',
#    'Name.Target': 'GRIPAP1',
#    'UniprotID.Target': 'Q4V328',
#    'Target.TFLink.ortho': 'Ce:Q20298;Dr:B0UYE9;Rn:Q9JHZ4',
#    'Target.nonTFLink.ortho': 'Mm:A2AEW8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51422',
#    'Ensembl.GeneID.Target': 'ENSG00000106617',
#    'Name.Target': 'PRKAG2',
#    'UniprotID.Target': 'Q9UGJ0',
#    'Target.TFLink.ortho': 'Mm:Q91WG5;Rn:A0A140UHX4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '80344',
#    'Ensembl.GeneID.Target': 'ENSG00000100897',
#    'Name.Target': 'DCAF11',
#    'UniprotID.Target': 'Q8TEB1',
#    'Target.TFLink.ortho': 'Ce:P90794;Dm:Q7JYQ4;Mm:Q91VU6;Rn:Q5M9G8',
#    'Target.nonTFLink.ortho': 'Dr:Q499B0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23199',
#    'Ensembl.GeneID.Target': 'ENSG00000131149',
#    'Name.Target': 'GSE1',
#    'UniprotID.Target': 'Q14687',
#    'Target.TFLink.ortho': 'Dr:Q1LWL6;Mm:Q3U3C9;Rn:F1M4A7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1012',
#    'Ensembl.GeneID.Target': 'ENSG00000140945',
#    'Name.Target': 'CDH13',
#    'UniprotID.Target': 'P55290',
#    'Target.TFLink.ortho': 'Mm:Q9WTR5;Rn:Q8R490',
#    'Target.nonTFLink.ortho': 'Dr:F1R6D1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54541',
#    'Ensembl.GeneID.Target': 'ENSG00000168209',
#    'Name.Target': 'DDIT4',
#    'UniprotID.Target': 'Q9NX09',
#    'Target.TFLink.ortho': 'Dm:Q9VTH4;Dr:Q7T346;Mm:Q9D3F7;Rn:G3V620',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '143',
#    'Ensembl.GeneID.Target': 'ENSG00000102699',
#    'Name.Target': 'PARP4',
#    'UniprotID.Target': 'Q9UKK3',
#    'Target.TFLink.ortho': 'Mm:E9PYK3',
#    'Target.nonTFLink.ortho': 'Dr:F1QHW9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8313',
#    'Ensembl.GeneID.Target': 'ENSG00000168646',
#    'Name.Target': 'AXIN2',
#    'UniprotID.Target': 'Q9Y2T1',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '60558',
#    'Ensembl.GeneID.Target': 'ENSG00000151806',
#    'Name.Target': 'GUF1',
#    'UniprotID.Target': 'Q8N442',
#    'Target.TFLink.ortho': 'Ce:P34617;Dm:Q9VRH6;Dr:E7FFK6;Mm:Q8C3X4;Rn:D3ZHF8;Sc:P46943',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8898',
#    'Ensembl.GeneID.Target': 'ENSG00000087053',
#    'Name.Target': 'MTMR2',
#    'UniprotID.Target': 'Q13614',
#    'Target.TFLink.ortho': 'Dm:Q9VMI9;Dr:A0JMK5;Mm:Q9Z2D1;Rn:D3ZA31',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23245',
#    'Ensembl.GeneID.Target': 'ENSG00000148219',
#    'Name.Target': 'ASTN2',
#    'UniprotID.Target': 'O75129',
#    'Target.TFLink.ortho': 'Mm:Q80Z10',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2JYU3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55661',
#    'Ensembl.GeneID.Target': 'ENSG00000124228',
#    'Name.Target': 'DDX27',
#    'UniprotID.Target': 'Q96GQ7',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '151887',
#    'Ensembl.GeneID.Target': 'ENSG00000091986',
#    'Name.Target': 'CCDC80',
#    'UniprotID.Target': 'Q76M96',
#    'Target.TFLink.ortho': 'Mm:Q8R2G6',
#    'Target.nonTFLink.ortho': 'Dr:Q90X49;Rn:Q6QD51',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '549',
#    'Ensembl.GeneID.Target': 'ENSG00000148090',
#    'Name.Target': 'AUH',
#    'UniprotID.Target': 'Q13825',
#    'Target.TFLink.ortho': 'Ce:O45106;Dm:A1Z934;Mm:A0A0R4J023;Rn:F1LU71',
#    'Target.nonTFLink.ortho': 'Dr:F1RDX1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '203260',
#    'Ensembl.GeneID.Target': 'ENSG00000159884',
#    'Name.Target': 'CCDC107',
#    'UniprotID.Target': 'Q8WV48',
#    'Target.TFLink.ortho': 'Mm:Q9DCC3;Rn:D4A3Y2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23409',
#    'Ensembl.GeneID.Target': 'ENSG00000089163',
#    'Name.Target': 'SIRT4',
#    'UniprotID.Target': 'Q9Y6E7',
#    'Target.TFLink.ortho': 'Ce:Q20480;Dm:Q8IRR5;Dr:F1QHM6;Mm:Q8R216;Rn:G3V641',
#    'Target.nonTFLink.ortho': 'Ce:Q20481',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '26287',
#    'Ensembl.GeneID.Target': 'ENSG00000165887',
#    'Name.Target': 'ANKRD2',
#    'UniprotID.Target': 'Q9GZV1',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '391356',
#    'Ensembl.GeneID.Target': 'ENSG00000184924',
#    'Name.Target': 'PTRHD1',
#    'UniprotID.Target': 'Q6GMV3',
#    'Target.TFLink.ortho': 'Ce:A7WK43;Dm:Q9VET3;Dr:Q5RIN6;Mm:D3Z4S3;Rn:D3ZBG6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2589',
#    'Ensembl.GeneID.Target': 'ENSG00000141429',
#    'Name.Target': 'GALNT1',
#    'UniprotID.Target': 'Q10472',
#    'Target.TFLink.ortho': 'Ce:P34678;Dr:E7FDA0;Mm:O08912;Rn:Q10473',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '27063',
#    'Ensembl.GeneID.Target': 'ENSG00000148677',
#    'Name.Target': 'ANKRD1',
#    'UniprotID.Target': 'Q15327',
#    'Target.TFLink.ortho': 'Dr:E7F095;Mm:Q9CR42;Rn:Q8R560',
#    'Target.nonTFLink.ortho': 'Dr:F1QQ98',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '93058',
#    'Ensembl.GeneID.Target': 'ENSG00000135469',
#    'Name.Target': 'COQ10A',
#    'UniprotID.Target': 'Q96MF6',
#    'Target.TFLink.ortho': 'Dm:Q8MLL3;Mm:E9Q3H6;Rn:D3ZX74;Sc:Q08058',
#    'Target.nonTFLink.ortho': 'Ce:Q304F0;Dr:E9QFB6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79634',
#    'Ensembl.GeneID.Target': 'ENSG00000144306',
#    'Name.Target': 'SCRN3',
#    'UniprotID.Target': 'Q0VDG4',
#    'Target.TFLink.ortho': 'Dr:Q803W1;Mm:Q3TMH2;Rn:A0A0G2K189',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '84872',
#    'Ensembl.GeneID.Target': 'ENSG00000135482',
#    'Name.Target': 'ZC3H10',
#    'UniprotID.Target': 'Q96K80',
#    'Target.TFLink.ortho': 'Dr:Q6ZM22;Mm:Q8R205;Rn:D3ZLM7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4240',
#    'Ensembl.GeneID.Target': 'ENSG00000140545',
#    'Name.Target': 'MFGE8',
#    'UniprotID.Target': 'Q08431',
#    'Target.TFLink.ortho': 'Mm:P21956',
#    'Target.nonTFLink.ortho': 'Dr:A2RRT1;Dr:A4QP32;Rn:Q1PBJ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6749',
#    'Ensembl.GeneID.Target': 'ENSG00000149136',
#    'Name.Target': 'SSRP1',
#    'UniprotID.Target': 'Q08945',
#    'Target.TFLink.ortho': 'Ce:O01683;Ce:P41848;Dm:Q05344;Mm:Q08943;Rn:Q04931;Sc:Q04636',
#    'Target.nonTFLink.ortho': 'Dr:B8A5B7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10489',
#    'Ensembl.GeneID.Target': 'ENSG00000132128',
#    'Name.Target': 'LRRC41',
#    'UniprotID.Target': 'Q15345',
#    'Target.TFLink.ortho': 'Dr:I3IS54;Mm:Q8K1C9;Rn:Q5M9H1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2010',
#    'Ensembl.GeneID.Target': 'ENSG00000102119',
#    'Name.Target': 'EMD',
#    'UniprotID.Target': 'P50402',
#    'Target.TFLink.ortho': 'Mm:O08579;Rn:Q6PCU4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5092',
#    'Ensembl.GeneID.Target': 'ENSG00000166228',
#    'Name.Target': 'PCBD1',
#    'UniprotID.Target': 'P61457',
#    'Target.TFLink.ortho': 'Ce:Q9TZH6;Dr:Q6PBI6;Mm:P61458;Rn:P61459',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '200765',
#    'Ensembl.GeneID.Target': 'ENSG00000221944',
#    'Name.Target': 'TIGD1',
#    'UniprotID.Target': 'Q96MW7',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4536',
#    'Ensembl.GeneID.Target': 'ENSG00000198763',
#    'Name.Target': 'MT-ND2',
#    'UniprotID.Target': 'P03891',
#    'Target.TFLink.ortho': 'Dr:Q9MIY9;Mm:P03893;Rn:P11662',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9179',
#    'Ensembl.GeneID.Target': 'ENSG00000221838',
#    'Name.Target': 'AP4M1',
#    'UniprotID.Target': 'O00189',
#    'Target.TFLink.ortho': 'Dr:Q7SZZ7;Mm:Q9JKC7;Rn:Q2PWT8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9693',
#    'Ensembl.GeneID.Target': 'ENSG00000109756',
#    'Name.Target': 'RAPGEF2',
#    'UniprotID.Target': 'Q9Y4G8',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10121',
#    'Ensembl.GeneID.Target': 'ENSG00000138107',
#    'Name.Target': 'ACTR1A',
#    'UniprotID.Target': 'P61163',
#    'Target.TFLink.ortho': 'Mm:P61164;Rn:P85515',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51204',
#    'Ensembl.GeneID.Target': 'ENSG00000136463',
#    'Name.Target': 'TACO1',
#    'UniprotID.Target': 'Q9BSH4',
#    'Target.TFLink.ortho': 'Ce:Q965T4;Mm:Q8K0Z7;Rn:D4A601;Sc:P53212',
#    'Target.nonTFLink.ortho': 'Dr:F1QP29;Dr:A0A0G2L877',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '25855',
#    'Ensembl.GeneID.Target': 'ENSG00000174744',
#    'Name.Target': 'BRMS1',
#    'UniprotID.Target': 'Q9HCU9',
#    'Target.TFLink.ortho': 'Mm:Q99N20',
#    'Target.nonTFLink.ortho': 'Rn:Q5M7T3;Rn:A0A0H2UI40',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '140606',
#    'Ensembl.GeneID.Target': 'ENSG00000198832',
#    'Name.Target': 'SELENOM',
#    'UniprotID.Target': 'Q8WWX9',
#    'Target.TFLink.ortho': 'Mm:Q8VHC3;Rn:A0A0G2JZZ4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '81579',
#    'Ensembl.GeneID.Target': 'ENSG00000123739',
#    'Name.Target': 'PLA2G12A',
#    'UniprotID.Target': 'Q9BZM1',
#    'Target.TFLink.ortho': 'Dr:A3KNJ5;Mm:Q9EPR2;Rn:B0K018',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '347',
#    'Ensembl.GeneID.Target': 'ENSG00000189058',
#    'Name.Target': 'APOD',
#    'UniprotID.Target': 'P05090',
#    'Target.TFLink.ortho': 'Dr:F1QDM9;Mm:P51910;Rn:M0R4S2',
#    'Target.nonTFLink.ortho': 'Dr:E7F2R8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51390',
#    'Ensembl.GeneID.Target': 'ENSG00000146416',
#    'Name.Target': 'AIG1',
#    'UniprotID.Target': 'Q9NVV5',
#    'Target.TFLink.ortho': 'Dm:Q9VPM9;Dm:Q9VTI1;Dr:Q5RIV5;Mm:Q9D8B1;Rn:B2RZC0',
#    'Target.nonTFLink.ortho': 'Dm:Q9VPN1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '25824',
#    'Ensembl.GeneID.Target': 'ENSG00000126432',
#    'Name.Target': 'PRDX5',
#    'UniprotID.Target': 'P30044',
#    'Target.TFLink.ortho': 'Dm:Q960M4;Mm:P99029;Rn:A0A0G2JSS8;Sc:P38013',
#    'Target.nonTFLink.ortho': 'Dr:F1QCE3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10907',
#    'Ensembl.GeneID.Target': 'ENSG00000141759',
#    'Name.Target': 'TXNL4A',
#    'UniprotID.Target': 'P83876',
#    'Target.TFLink.ortho': 'Ce:L8E6I4;Dm:Q8SZ87;Dr:F1QTJ2;Mm:P83877;Rn:D3ZSW5;Sc:Q06819',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '85437',
#    'Ensembl.GeneID.Target': 'ENSG00000139168',
#    'Name.Target': 'ZCRB1',
#    'UniprotID.Target': 'Q8TBF4',
#    'Target.TFLink.ortho': 'Dr:Q5SP50;Mm:Q9CZ96;Rn:Q499V6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23461',
#    'Ensembl.GeneID.Target': 'ENSG00000154265',
#    'Name.Target': 'ABCA5',
#    'UniprotID.Target': 'Q8WWZ7',
#    'Target.TFLink.ortho': 'Dr:F1QEL5;Mm:Q8K448',
#    'Target.nonTFLink.ortho': 'Rn:M0RA83',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6641',
#    'Ensembl.GeneID.Target': 'ENSG00000172164',
#    'Name.Target': 'SNTB1',
#    'UniprotID.Target': 'Q13884',
#    'Target.TFLink.ortho': 'Dr:Q6GMG2;Mm:Q99L88;Rn:D3ZWC6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8945',
#    'Ensembl.GeneID.Target': 'ENSG00000166167',
#    'Name.Target': 'BTRC',
#    'UniprotID.Target': 'Q9Y297',
#    'Target.TFLink.ortho': 'Mm:Q3ULA2;Rn:F1LMH8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8568',
#    'Ensembl.GeneID.Target': 'ENSG00000160214',
#    'Name.Target': 'RRP1',
#    'UniprotID.Target': 'P56182',
#    'Target.TFLink.ortho': 'Ce:Q18674;Mm:P56183;Rn:Q5M9F3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10912',
#    'Ensembl.GeneID.Target': 'ENSG00000130222',
#    'Name.Target': 'GADD45G',
#    'UniprotID.Target': 'O95257',
#    'Target.TFLink.ortho': 'Dr:Q6NUV6;Dr:Q6P021;Mm:Q9R0S0;Rn:Q9WTQ7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4038',
#    'Ensembl.GeneID.Target': 'ENSG00000134569',
#    'Name.Target': 'LRP4',
#    'UniprotID.Target': 'O75096',
#    'Target.TFLink.ortho': 'Dm:Q9VXM0;Mm:Q8VI56;Rn:Q9QYP1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55275',
#    'Ensembl.GeneID.Target': 'ENSG00000141252',
#    'Name.Target': 'VPS53',
#    'UniprotID.Target': 'Q5VIR6',
#    'Target.TFLink.ortho': 'Dm:Q9VQY8;Dr:E7FAG0;Mm:Q8CCB4;Rn:D3ZPE5;Sc:P47061',
#    'Target.nonTFLink.ortho': 'Ce:P34561',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5264',
#    'Ensembl.GeneID.Target': 'ENSG00000107537',
#    'Name.Target': 'PHYH',
#    'UniprotID.Target': 'O14832',
#    'Target.TFLink.ortho': 'Ce:O62515;Mm:O35386;Rn:P57093',
#    'Target.nonTFLink.ortho': 'Dr:E7FCS1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55217',
#    'Ensembl.GeneID.Target': 'ENSG00000185973',
#    'Name.Target': 'TMLHE',
#    'UniprotID.Target': 'Q9NVH6',
#    'Target.TFLink.ortho': 'Ce:Q21526;Dm:Q9VDM7;Dr:E7F0M9;Rn:Q91ZW6',
#    'Target.nonTFLink.ortho': 'Mm:Q91ZE0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '26074',
#    'Ensembl.GeneID.Target': 'ENSG00000089101',
#    'Name.Target': 'CFAP61',
#    'UniprotID.Target': 'Q8NHU2',
#    'Target.TFLink.ortho': 'Dm:Q9W206',
#    'Target.nonTFLink.ortho': 'Dm:Q7KVK5;Mm:A8Y5L4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '26586',
#    'Ensembl.GeneID.Target': 'ENSG00000136108',
#    'Name.Target': 'CKAP2',
#    'UniprotID.Target': 'Q8WWK9',
#    'Target.TFLink.ortho': 'Dr:E7F392;Mm:Q3V1H1;Rn:D3ZPD0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '116729',
#    'Ensembl.GeneID.Target': 'ENSG00000182676',
#    'Name.Target': 'PPP1R27',
#    'UniprotID.Target': 'Q86WC6',
#    'Target.TFLink.ortho': 'Mm:Q9D119',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4IKA8;Rn:D3ZXG0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2806',
#    'Ensembl.GeneID.Target': 'ENSG00000125166',
#    'Name.Target': 'GOT2',
#    'UniprotID.Target': 'P00505',
#    'Target.TFLink.ortho': 'Ce:Q17994;Dr:Q7SYK7;Mm:P05202;Rn:P00507',
#    'Target.nonTFLink.ortho': 'Dm:Q9VQ61;Dr:F1QCD4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '29085',
#    'Ensembl.GeneID.Target': 'ENSG00000054148',
#    'Name.Target': 'PHPT1',
#    'UniprotID.Target': 'Q9NRX4',
#    'Target.TFLink.ortho': 'Ce:P90861;Mm:Q9DAK9;Rn:D3ZP47',
#    'Target.nonTFLink.ortho': 'Dr:Q6DC18',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3491',
#    'Ensembl.GeneID.Target': 'ENSG00000142871',
#    'Name.Target': 'CCN1',
#    'UniprotID.Target': 'O00622',
#    'Target.TFLink.ortho': 'Dr:F1QL10;Mm:P18406;Rn:Q66HT5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '165904',
#    'Ensembl.GeneID.Target': 'ENSG00000168334',
#    'Name.Target': 'XIRP1',
#    'UniprotID.Target': 'Q702N8',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': 'Mm:A0A571BDS0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1349',
#    'Ensembl.GeneID.Target': 'ENSG00000131174',
#    'Name.Target': 'COX7B',
#    'UniprotID.Target': 'P24311',
#    'Target.TFLink.ortho': 'Mm:P56393;Rn:P80431',
#    'Target.nonTFLink.ortho': 'Dr:B3DJA6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1376',
#    'Ensembl.GeneID.Target': 'ENSG00000157184',
#    'Name.Target': 'CPT2',
#    'UniprotID.Target': 'P23786',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79140',
#    'Ensembl.GeneID.Target': 'ENSG00000160050',
#    'Name.Target': 'CCDC28B',
#    'UniprotID.Target': 'Q9BUN5',
#    'Target.TFLink.ortho': 'Dr:B8A4M8;Mm:Q8CEG5;Rn:B4F770',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9021',
#    'Ensembl.GeneID.Target': 'ENSG00000184557',
#    'Name.Target': 'SOCS3',
#    'UniprotID.Target': 'O14543',
#    'Target.TFLink.ortho': 'Dr:Q7ZUC6;Mm:O35718;Rn:G3V6D2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1843',
#    'Ensembl.GeneID.Target': 'ENSG00000120129',
#    'Name.Target': 'DUSP1',
#    'UniprotID.Target': 'P28562',
#    'Target.TFLink.ortho': 'Dr:A0A0R4IS50;Mm:P28563;Rn:Q64623',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1647',
#    'Ensembl.GeneID.Target': 'ENSG00000116717',
#    'Name.Target': 'GADD45A',
#    'UniprotID.Target': 'P24522',
#    'Target.TFLink.ortho': 'Dr:Q6GMM1;Mm:P48316;Rn:Q66HL6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64951',
#    'Ensembl.GeneID.Target': 'ENSG00000062582',
#    'Name.Target': 'MRPS24',
#    'UniprotID.Target': 'Q96EL2',
#    'Target.TFLink.ortho': 'Ce:Q688C0;Dm:Q9VCC3;Dr:Q502C1;Mm:Q9CQV5',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2K9G3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5514',
#    'Ensembl.GeneID.Target': 'ENSG00000204569',
# ...
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '389203',
#    'Ensembl.GeneID.Target': 'ENSG00000250317',
#    'Name.Target': 'SMIM20',
#    'UniprotID.Target': 'Q8N5G0',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4043',
#    'Ensembl.GeneID.Target': 'ENSG00000163956',
#    'Name.Target': 'LRPAP1',
#    'UniprotID.Target': 'P30533',
#    'Target.TFLink.ortho': 'Ce:G5EF26;Dm:Q9VH64;Dr:A2BGU5;Mm:P55302;Rn:Q99068',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5188',
#    'Ensembl.GeneID.Target': 'ENSG00000059691',
#    'Name.Target': 'GATB',
#    'UniprotID.Target': 'O75879',
#    'Target.TFLink.ortho': 'Dm:Q9VCD0;Mm:Q99JT1;Rn:M0R4L6;Sc:P33893',
#    'Target.nonTFLink.ortho': 'Dr:Q7T010',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4836',
#    'Ensembl.GeneID.Target': 'ENSG00000136448',
#    'Name.Target': 'NMT1',
#    'UniprotID.Target': 'P30419',
#    'Target.TFLink.ortho': 'Dr:F1QY00;Mm:O70310;Rn:Q8K1Q0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51655',
#    'Ensembl.GeneID.Target': 'ENSG00000108551',
#    'Name.Target': 'RASD1',
#    'UniprotID.Target': 'Q9Y272',
#    'Target.TFLink.ortho': 'Dr:Q6PHV8;Mm:O35626;Rn:Q9JKF8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4512',
#    'Ensembl.GeneID.Target': 'ENSG00000198804',
#    'Name.Target': 'MT-CO1',
#    'UniprotID.Target': 'P00395',
#    'Target.TFLink.ortho': 'Dm:P00399;Dr:Q9MIY8;Mm:P00397;Rn:P05503;Sc:P00401',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '28231',
#    'Ensembl.GeneID.Target': 'ENSG00000101187',
#    'Name.Target': 'SLCO4A1',
#    'UniprotID.Target': 'Q96BD0',
#    'Target.TFLink.ortho': 'Ce:Q9XWC5;Ce:X5LPS1;Dm:Q8SY02;Dr:E7FFX7;Mm:Q8K078;Rn:Q4V8N6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79658',
#    'Ensembl.GeneID.Target': 'ENSG00000071205',
#    'Name.Target': 'ARHGAP10',
#    'UniprotID.Target': 'A1A4S6',
#    'Target.TFLink.ortho': 'Dr:Q1JPR9;Mm:Q6Y5D8;Rn:D4AB50',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '757',
#    'Ensembl.GeneID.Target': 'ENSG00000142188',
#    'Name.Target': 'TMEM50B',
#    'UniprotID.Target': 'P56557',
#    'Target.TFLink.ortho': 'Dm:Q9VZE2;Mm:Q9D1X9;Rn:Q5BJS6',
#    'Target.nonTFLink.ortho': 'Ce:Q9N2X7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9927',
#    'Ensembl.GeneID.Target': 'ENSG00000116688',
#    'Name.Target': 'MFN2',
#    'UniprotID.Target': 'O95140',
#    'Target.TFLink.ortho': 'Dr:A8WIN6;Mm:Q80U63',
#    'Target.nonTFLink.ortho': 'Rn:F7FHF7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8869',
#    'Ensembl.GeneID.Target': 'ENSG00000115525',
#    'Name.Target': 'ST3GAL5',
#    'UniprotID.Target': 'Q9UNP4',
#    'Target.TFLink.ortho': 'Rn:Q68G12',
#    'Target.nonTFLink.ortho': 'Dr:F1RCA6;Mm:A0A0U1RNK2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '123803',
#    'Ensembl.GeneID.Target': 'ENSG00000157045',
#    'Name.Target': 'NTAN1',
#    'UniprotID.Target': 'Q96AB6',
#    'Target.TFLink.ortho': 'Dm:Q7KIS4;Mm:Q64311;Rn:A0A0G2JWG0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54793',
#    'Ensembl.GeneID.Target': 'ENSG00000104756',
#    'Name.Target': 'KCTD9',
#    'UniprotID.Target': 'Q7L273',
#    'Target.TFLink.ortho': 'Dm:B9A0N7;Dr:A8DZF0;Rn:D3ZE91',
#    'Target.nonTFLink.ortho': 'Dr:B0V3Q8;Mm:E9PUA6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '770',
#    'Ensembl.GeneID.Target': 'ENSG00000063180',
#    'Name.Target': 'CA11',
#    'UniprotID.Target': 'O75493',
#    'Target.TFLink.ortho': 'Mm:O70354;Rn:Q811X3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79731',
#    'Ensembl.GeneID.Target': 'ENSG00000137513',
#    'Name.Target': 'NARS2',
#    'UniprotID.Target': 'Q96I59',
#    'Target.TFLink.ortho': 'Ce:Q95PZ8;Dm:Q7JZR5;Mm:Q8BGV0;Sc:P25345',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2K7D7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '57610',
#    'Ensembl.GeneID.Target': 'ENSG00000141084',
#    'Name.Target': 'RANBP10',
#    'UniprotID.Target': 'Q6VN20',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '80823',
#    'Ensembl.GeneID.Target': 'ENSG00000198908',
#    'Name.Target': 'BHLHB9',
#    'UniprotID.Target': 'Q6PI77',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9846',
#    'Ensembl.GeneID.Target': 'ENSG00000033327',
#    'Name.Target': 'GAB2',
#    'UniprotID.Target': 'Q9UQC2',
#    'Target.TFLink.ortho': 'Mm:Q3ZB57;Rn:F1LSR2',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4I9X7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '149345',
#    'Ensembl.GeneID.Target': 'ENSG00000198892',
#    'Name.Target': 'SHISA4',
#    'UniprotID.Target': 'Q96DD7',
#    'Target.TFLink.ortho': 'Dr:A5WUR8;Mm:Q8CA71;Rn:A0MV40',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '124936',
#    'Ensembl.GeneID.Target': 'ENSG00000167740',
#    'Name.Target': 'CYB5D2',
#    'UniprotID.Target': 'Q8WUJ1',
#    'Target.TFLink.ortho': 'Ce:Q9XXA7;Dm:Q9W376;Mm:Q5SSH8;Rn:Q6AY62',
#    'Target.nonTFLink.ortho': 'Dr:A2CES0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4722',
#    'Ensembl.GeneID.Target': 'ENSG00000213619',
#    'Name.Target': 'NDUFS3',
#    'UniprotID.Target': 'O75489',
#    'Target.TFLink.ortho': 'Dm:Q9VZU4;Dr:F1R4C8;Mm:Q9DCT2;Rn:D3ZG43',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55699',
#    'Ensembl.GeneID.Target': 'ENSG00000067704',
#    'Name.Target': 'IARS2',
#    'UniprotID.Target': 'Q9NSE4',
#    'Target.TFLink.ortho': 'Dm:Q9VUY4;Dr:F1QUQ0;Mm:Q8BIJ6;Rn:A0A0G2K261;Sc:P48526',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55625',
#    'Ensembl.GeneID.Target': 'ENSG00000153786',
#    'Name.Target': 'ZDHHC7',
#    'UniprotID.Target': 'Q9NXF8',
#    'Target.TFLink.ortho': 'Dr:Q6DHI1;Mm:Q91WU6;Rn:Q923G5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2597',
#    'Ensembl.GeneID.Target': 'ENSG00000111640',
#    'Name.Target': 'GAPDH',
#    'UniprotID.Target': 'P04406',
#    'Target.TFLink.ortho': 'Ce:P17331;Ce:P04970;Ce:P17330;Ce:P17329;Dm:P07486;Dm:P07487;Mm:S4R1W1;Rn:P04797',
#    'Target.nonTFLink.ortho': 'Mm:S4R1W8;Mm:A0A1D5RLD8;Rn:D3ZGY4;Rn:M0R590',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8914',
#    'Ensembl.GeneID.Target': 'ENSG00000111602',
#    'Name.Target': 'TIMELESS',
#    'UniprotID.Target': 'Q9UNS1',
#    'Target.TFLink.ortho': 'Ce:G5EDN3;Dm:Q8INH7;Dr:E7FGL0;Mm:Q9R1X4;Rn:E9PTS7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '753',
#    'Ensembl.GeneID.Target': 'ENSG00000168675',
#    'Name.Target': 'LDLRAD4',
#    'UniprotID.Target': 'O15165',
#    'Target.TFLink.ortho': 'Dr:E9QGX8;Mm:Q8BWJ4',
#    'Target.nonTFLink.ortho': 'Rn:F1LZA8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4501',
#    'Ensembl.GeneID.Target': 'ENSG00000187193',
#    'Name.Target': 'MT1X',
#    'UniprotID.Target': 'P80297',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5224',
#    'Ensembl.GeneID.Target': 'ENSG00000164708',
#    'Name.Target': 'PGAM2',
#    'UniprotID.Target': 'P15259',
#    'Target.TFLink.ortho': 'Mm:O70250',
#    'Target.nonTFLink.ortho': 'Dr:Q7T3G4;Rn:P16290',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10904',
#    'Ensembl.GeneID.Target': 'ENSG00000166619',
#    'Name.Target': 'BLCAP',
#    'UniprotID.Target': 'P62952',
#    'Target.TFLink.ortho': 'Ce:G5EE03;Dm:Q9V3L0;Dr:Q9IB61;Mm:P62951;Rn:P62950',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3835',
#    'Ensembl.GeneID.Target': 'ENSG00000079616',
#    'Name.Target': 'KIF22',
#    'UniprotID.Target': 'Q14807',
#    'Target.TFLink.ortho': 'Dr:B7ZV80;Mm:Q3V300;Rn:Q5I0E8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '320',
#    'Ensembl.GeneID.Target': 'ENSG00000107282',
#    'Name.Target': 'APBA1',
#    'UniprotID.Target': 'Q02410',
#    'Target.TFLink.ortho': 'Mm:B2RUJ5;Rn:F1LR60',
#    'Target.nonTFLink.ortho': 'Dr:A0A2R9YJM9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55333',
#    'Ensembl.GeneID.Target': 'ENSG00000213463',
#    'Name.Target': 'SYNJ2BP',
#    'UniprotID.Target': 'P57105',
#    'Target.TFLink.ortho': 'Dr:Q7ZV59;Mm:Q9D6K5;Rn:Q9WVJ4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '200185',
#    'Ensembl.GeneID.Target': 'ENSG00000163463',
#    'Name.Target': 'KRTCAP2',
#    'UniprotID.Target': 'Q8N6L1',
#    'Target.TFLink.ortho': 'Dm:Q8INQ7;Dr:Q0P494;Mm:Q5RL79;Rn:B2RZC9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10367',
#    'Ensembl.GeneID.Target': 'ENSG00000107745',
#    'Name.Target': 'MICU1',
#    'UniprotID.Target': 'Q9BPX6',
#    'Target.TFLink.ortho': 'Ce:Q95PZ2;Dm:A2VEI2;Mm:Q8VCX5;Rn:A0A0G2K0T5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '100272147',
#    'Ensembl.GeneID.Target': 'ENSG00000182712',
#    'Name.Target': 'CMC4',
#    'UniprotID.Target': 'P56277',
#    'Target.TFLink.ortho': 'Dm:B7YZN8;Dr:A0A0R4IZJ0;Mm:Q61908;Rn:A0A0G2K2W2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '11123',
#    'Ensembl.GeneID.Target': 'ENSG00000117602',
#    'Name.Target': 'RCAN3',
#    'UniprotID.Target': 'Q9UKA8',
#    'Target.TFLink.ortho': 'Mm:Q9JKK0;Rn:F7ENE7',
#    'Target.nonTFLink.ortho': 'Dr:Q6DG39',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4719',
#    'Ensembl.GeneID.Target': 'ENSG00000023228',
#    'Name.Target': 'NDUFS1',
#    'UniprotID.Target': 'P28331',
#    'Target.TFLink.ortho': 'Ce:Q9N4Y8;Dm:Q94511;Mm:Q91VD9;Rn:Q66HF1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1738',
#    'Ensembl.GeneID.Target': 'ENSG00000091140',
#    'Name.Target': 'DLD',
#    'UniprotID.Target': 'P09622',
#    'Target.TFLink.ortho': 'Ce:O17953;Dm:Q9VVL7;Dr:Q6TNU6;Mm:O08749;Rn:Q6P6R2;Sc:P09624',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51816',
#    'Ensembl.GeneID.Target': 'ENSG00000093072',
#    'Name.Target': 'ADA2',
#    'UniprotID.Target': 'Q9NZK5',
#    'Target.TFLink.ortho': 'Dm:Q9VVK4;Dm:Q9VVK5',
#    'Target.nonTFLink.ortho': 'Dm:Q7KGG1;Dr:F1R9S0;Dr:F6NKG5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'}]}

# %% [markdown]
# ### Protein-Protein Interactions from STRING

# %%
# # Create a mapping dictionary for identifiers
# mapping = bridgedb_df_human[
#     (bridgedb_df_human['target.source'] == "HGNC") & (pd.notna(bridgedb_df_human['target']))
#     ].set_index('identifier')['target'].to_dict()

# # Apply mapping and replace values in identifier and identifier.source
# bridgedb_df_human['identifier'] = bridgedb_df_human['identifier'].map(mapping).combine_first(bridgedb_df_human['identifier'])
# bridgedb_df_human['identifier.source'] = bridgedb_df_human.apply(
#     lambda row: "HGNC" if row['identifier'] in mapping.values() else row['identifier.source'], axis=1
# )

# %%
# bridgedb_df_human[["identifier", "GENE_SYMBOL_dea"]][~(bridgedb_df_human["identifier"] == bridgedb_df_human["GENE_SYMBOL_dea"])].drop_duplicates()

# %%
string_path = os.path.join(base_dir, "data/human/string.pkl")
string_metadata_path = os.path.join(base_dir, "data/human/string_metadata.pkl")

if not os.path.exists(string_path):
    ppi_df, ppi_metadata = stringdb.get_ppi(
        bridgedb_df=bridgedb_df_human[bridgedb_df_human["padj_dea"] <= 0.05]
    )
    ppi_df.to_pickle(string_path)
    with open(string_metadata_path, "wb") as file:
        pickle.dump(ppi_metadata, file)
else:
    ppi_df = pd.read_pickle(string_path)
    with open(string_metadata_path, "rb") as file:
        ppi_metadata = pickle.load(file)

ppi_df.head()
# Out:
#         identifier identifier.source           target target.source  \
# 0  ENSG00000001084           Ensembl  ENSG00000001084       Ensembl
# 1  ENSG00000004468           Ensembl  ENSG00000004468       Ensembl
# 2  ENSG00000004779           Ensembl  ENSG00000004779       Ensembl
# 3  ENSG00000005700           Ensembl  ENSG00000005700       Ensembl
# 4  ENSG00000006327           Ensembl  ENSG00000006327       Ensembl
#
#   GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  \
# 0            GCLC    412.449345            0.454035   0.130200  3.487222
# 1            CD38    975.036348           -0.588804   0.173952 -3.384869
# 2         NDUFAB1   2346.167702           -0.432984   0.135670 -3.191446
# 3            IBTK   1511.600789           -0.436326   0.103624 -4.210661
# 4       TNFRSF12A    445.737333            1.655781   0.519291  3.188539
#
#    pvalue_dea  padj_dea  minus_log10_pvalue_dea  \
# 0    0.000488  0.018659                3.311521
# 1    0.000712  0.023909                3.147446
# 2    0.001416  0.036492                2.849052
# 3    0.000025  0.003024                4.594099
# 4    0.001430  0.036587                2.844684
#
#                                         StringDB_ppi
# 0  [{'stringdb_link_to': 'ENSG00000100906', 'Ense...
# 1  [{'stringdb_link_to': 'ENSG00000089163', 'Ense...
# 2  [{'stringdb_link_to': 'ENSG00000010256', 'Ense...
# 3  [{'stringdb_link_to': 'ENSG00000198886', 'Ense...
# 4  [{'stringdb_link_to': nan, 'Ensembl': nan, 'sc...

# %%
from pyBiodatafuse.constants import STRING_PPI_COL

ppi_df[STRING_PPI_COL].to_dict()
# Out:
# {0: [{'stringdb_link_to': 'ENSG00000100906',
#    'Ensembl': 'ENSP00000216797',
#    'score': 0.556,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000125166',
#    'Ensembl': 'ENSP00000245206',
#    'score': 0.838,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000126432',
#    'Ensembl': 'ENSP00000265462',
#    'score': 0.518,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167996',
#    'Ensembl': 'ENSP00000273550',
#    'score': 0.508,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000148672',
#    'Ensembl': 'ENSP00000277865',
#    'score': 0.847,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167815',
#    'Ensembl': 'ENSP00000301522',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000169715',
#    'Ensembl': 'ENSP00000328137',
#    'score': 0.455,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167468',
#    'Ensembl': 'ENSP00000346103',
#    'score': 0.809,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.419,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117448',
#    'Ensembl': 'ENSP00000361140',
#    'score': 0.409,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000271303',
#    'Ensembl': 'ENSP00000371388',
#    'score': 0.756,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000211445',
#    'Ensembl': 'ENSP00000373477',
#    'score': 0.705,
#    'Uniprot-TrEMBL': 'P22352',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.598,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116044',
#    'Ensembl': 'ENSP00000380252',
#    'score': 0.966,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  1: [{'stringdb_link_to': 'ENSG00000089163',
#    'Ensembl': 'ENSP00000202967',
#    'score': 0.921,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100219',
#    'Ensembl': 'ENSP00000216037',
#    'score': 0.527,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000128016',
#    'Ensembl': 'ENSP00000471239',
#    'score': 0.41,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143799',
#    'Ensembl': 'ENSP00000355759',
#    'score': 0.429,
#    'Uniprot-TrEMBL': 'P09874',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163864',
#    'Ensembl': 'ENSP00000495112',
#    'score': 0.446,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.459,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000113916',
#    'Ensembl': 'ENSP00000384371',
#    'score': 0.695,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.7,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154096',
#    'Ensembl': 'ENSP00000284240',
#    'score': 0.708,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000072274',
#    'Ensembl': 'ENSP00000376197',
#    'score': 0.788,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000112992',
#    'Ensembl': 'ENSP00000264663',
#    'score': 0.909,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152620',
#    'Ensembl': 'ENSP00000371362',
#    'score': 0.91,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000124523',
#    'Ensembl': 'ENSP00000476228',
#    'score': 0.923,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166741',
#    'Ensembl': 'ENSP00000441434',
#    'score': 0.925,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142082',
#    'Ensembl': 'ENSP00000372191',
#    'score': 0.939,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  2: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.983,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.669,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.658,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000104325',
#    'Ensembl': 'ENSP00000220764',
#    'score': 0.455,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000108179',
#    'Ensembl': 'ENSP00000225174',
#    'score': 0.445,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.47,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111669',
#    'Ensembl': 'ENSP00000229270',
#    'score': 0.546,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130414',
#    'Ensembl': 'ENSP00000252711',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000135900',
#    'Ensembl': 'ENSP00000258383',
#    'score': 0.945,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.677,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000106049',
#    'Ensembl': 'ENSP00000265395',
#    'score': 0.521,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000147592',
#    'Ensembl': 'ENSP00000276590',
#    'score': 0.48,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000151093',
#    'Ensembl': 'ENSP00000280701',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.752,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166902',
#    'Ensembl': 'ENSP00000300151',
#    'score': 0.957,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171861',
#    'Ensembl': 'ENSP00000306080',
#    'score': 0.965,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168291',
#    'Ensembl': 'ENSP00000307241',
#    'score': 0.741,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140905',
#    'Ensembl': 'ENSP00000319531',
#    'score': 0.858,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067225',
#    'Ensembl': 'ENSP00000320171',
#    'score': 0.421,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139131',
#    'Ensembl': 'ENSP00000320658',
#    'score': 0.415,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000176340',
#    'Ensembl': 'ENSP00000321260',
#    'score': 0.661,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000187630',
#    'Ensembl': 'ENSP00000334801',
#    'score': 0.405,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000119689',
#    'Ensembl': 'ENSP00000335304',
#    'score': 0.538,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.891,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.925,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198786',
#    'Ensembl': 'ENSP00000354813',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.793,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198938',
#    'Ensembl': 'ENSP00000354982',
#    'score': 0.869,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'ENSP00000355046',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198840',
#    'Ensembl': 'ENSP00000355206',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'ENSP00000356953',
#    'score': 0.504,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000158864',
#    'Ensembl': 'ENSP00000356972',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000127884',
#    'Ensembl': 'ENSP00000357535',
#    'score': 0.518,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000196177',
#    'Ensembl': 'ENSP00000357873',
#    'score': 0.426,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000178096',
#    'Ensembl': 'ENSP00000358149',
#    'score': 0.576,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.65,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134697',
#    'Ensembl': 'ENSP00000362153',
#    'score': 0.46,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.651,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000175198',
#    'Ensembl': 'ENSP00000365462',
#    'score': 0.478,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101247',
#    'Ensembl': 'ENSP00000367346',
#    'score': 0.799,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186687',
#    'Ensembl': 'ENSP00000368688',
#    'score': 0.838,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163607',
#    'Ensembl': 'ENSP00000373176',
#    'score': 0.817,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.624,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.405,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.767,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000169519',
#    'Ensembl': 'ENSP00000384369',
#    'score': 0.499,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000023228',
#    'Ensembl': 'ENSP00000392709',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000205707',
#    'Ensembl': 'ENSP00000450584',
#    'score': 0.948,
#    'Uniprot-TrEMBL': 'Q6IPR1',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140374',
#    'Ensembl': 'ENSP00000452762',
#    'score': 0.916,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000123472',
#    'Ensembl': 'ENSP00000460964',
#    'score': 0.485,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000131174',
#    'Ensembl': 'ENSP00000497474',
#    'score': 0.924,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000278845',
#    'Ensembl': 'ENSP00000484903',
#    'score': 0.939,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  3: [{'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  4: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  5: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  6: [{'stringdb_link_to': 'ENSG00000131462',
#    'Ensembl': 'ENSP00000251413',
#    'score': 0.698,
#    'Uniprot-TrEMBL': 'P23258',
#    'Uniprot-TrEMBL_link': None}],
#  7: [{'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.438,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130706',
#    'Ensembl': 'ENSP00000478877',
#    'score': 0.488,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  8: [{'stringdb_link_to': 'ENSG00000131462',
#    'Ensembl': 'ENSP00000251413',
#    'score': 0.54,
#    'Uniprot-TrEMBL': 'P23258',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000081760',
#    'Ensembl': 'ENSP00000324842',
#    'score': 0.41,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000153107',
#    'Ensembl': 'ENSP00000339109',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000160299',
#    'Ensembl': 'ENSP00000352572',
#    'score': 0.55,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000138107',
#    'Ensembl': 'ENSP00000358921',
#    'score': 0.55,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139350',
#    'Ensembl': 'ENSP00000451211',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000205937',
#    'Ensembl': 'ENSP00000457723',
#    'score': 0.86,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000221978',
#    'Ensembl': 'ENSP00000383611',
#    'score': 0.927,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  9: [{'stringdb_link_to': 'ENSG00000083123',
#    'Ensembl': 'ENSP00000318351',
#    'score': 0.423,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171503',
#    'Ensembl': 'ENSP00000426638',
#    'score': 0.43,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198899',
#    'Ensembl': 'ENSP00000354632',
#    'score': 0.435,
#    'Uniprot-TrEMBL': 'P00846',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067225',
#    'Ensembl': 'ENSP00000320171',
#    'score': 0.442,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186687',
#    'Ensembl': 'ENSP00000368688',
#    'score': 0.444,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136143',
#    'Ensembl': 'ENSP00000494360',
#    'score': 0.462,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.475,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.487,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000182054',
#    'Ensembl': 'ENSP00000331897',
#    'score': 0.491,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.5,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000054148',
#    'Ensembl': 'ENSP00000247665',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000088682',
#    'Ensembl': 'ENSP00000262507',
#    'score': 0.529,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000159720',
#    'Ensembl': 'ENSP00000290949',
#    'score': 0.539,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101019',
#    'Ensembl': 'ENSP00000363506',
#    'score': 0.542,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111669',
#    'Ensembl': 'ENSP00000229270',
#    'score': 0.556,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140374',
#    'Ensembl': 'ENSP00000452762',
#    'score': 0.569,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.578,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000149925',
#    'Ensembl': 'ENSP00000496166',
#    'score': 0.609,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.614,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000127884',
#    'Ensembl': 'ENSP00000357535',
#    'score': 0.625,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000119689',
#    'Ensembl': 'ENSP00000335304',
#    'score': 0.684,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'ENSP00000356953',
#    'score': 0.709,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000125166',
#    'Ensembl': 'ENSP00000245206',
#    'score': 0.718,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000176340',
#    'Ensembl': 'ENSP00000321260',
#    'score': 0.816,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168291',
#    'Ensembl': 'ENSP00000307241',
#    'score': 0.826,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.831,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.855,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'ENSP00000355046',
#    'score': 0.933,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.938,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198786',
#    'Ensembl': 'ENSP00000354813',
#    'score': 0.942,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.955,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198840',
#    'Ensembl': 'ENSP00000355206',
#    'score': 0.962,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.969,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.97,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.971,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000131174',
#    'Ensembl': 'ENSP00000497474',
#    'score': 0.974,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.979,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000004779',
#    'Ensembl': 'ENSP00000458770',
#    'score': 0.983,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198938',
#    'Ensembl': 'ENSP00000354982',
#    'score': 0.99,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.995,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.995,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130414',
#    'Ensembl': 'ENSP00000252711',
#    'score': 0.996,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.998,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000023228',
#    'Ensembl': 'ENSP00000392709',
#    'score': 0.998,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000158864',
#    'Ensembl': 'ENSP00000356972',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  10: [{'stringdb_link_to': 'ENSG00000104756',
#    'Ensembl': 'ENSP00000221200',
#    'score': 0.517,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186951',
#    'Ensembl': 'ENSP00000385523',
#    'score': 0.674,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  11: [{'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.436,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000104756',
#    'Ensembl': 'ENSP00000221200',
#    'score': 0.483,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000132463',
#    'Ensembl': 'ENSP00000254799',
#    'score': 0.413,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000173992',
#    'Ensembl': 'ENSP00000436318',
#    'score': 0.56,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  12: [{'stringdb_link_to': 'ENSG00000137692',
#    'Ensembl': 'ENSP00000260247',
#    'score': 0.461,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000073712',
#    'Ensembl': 'ENSP00000342858',
#    'score': 0.445,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000102119',
#    'Ensembl': 'ENSP00000358857',
#    'score': 0.709,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  13: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.998,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.946,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100209',
#    'Ensembl': 'ENSP00000216027',
#    'score': 0.575,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.865,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.682,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111669',
#    'Ensembl': 'ENSP00000229270',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000125166',
#    'Ensembl': 'ENSP00000245206',
#    'score': 0.461,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130414',
#    'Ensembl': 'ENSP00000252711',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136463',
#    'Ensembl': 'ENSP00000258975',
#    'score': 0.615,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.977,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000088682',
#    'Ensembl': 'ENSP00000262507',
#    'score': 0.551,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000181192',
#    'Ensembl': 'ENSP00000263035',
#    'score': 0.551,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139631',
#    'Ensembl': 'ENSP00000267085',
#    'score': 0.433,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139637',
#    'Ensembl': 'ENSP00000267103',
#    'score': 0.671,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.524,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.883,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168291',
#    'Ensembl': 'ENSP00000307241',
#    'score': 0.809,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000173085',
#    'Ensembl': 'ENSP00000310873',
#    'score': 0.43,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000083123',
#    'Ensembl': 'ENSP00000318351',
#    'score': 0.479,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.47,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000182054',
#    'Ensembl': 'ENSP00000331897',
#    'score': 0.494,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000119689',
#    'Ensembl': 'ENSP00000335304',
#    'score': 0.88,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.988,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.986,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198899',
#    'Ensembl': 'ENSP00000354632',
#    'score': 0.715,
#    'Uniprot-TrEMBL': 'P00846',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198786',
#    'Ensembl': 'ENSP00000354813',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.976,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198938',
#    'Ensembl': 'ENSP00000354982',
#    'score': 0.99,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'ENSP00000355046',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198840',
#    'Ensembl': 'ENSP00000355206',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067704',
#    'Ensembl': 'ENSP00000355889',
#    'score': 0.487,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'ENSP00000356953',
#    'score': 0.923,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000158864',
#    'Ensembl': 'ENSP00000356972',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000137992',
#    'Ensembl': 'ENSP00000359151',
#    'score': 0.631,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.665,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.996,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101247',
#    'Ensembl': 'ENSP00000367346',
#    'score': 0.877,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186687',
#    'Ensembl': 'ENSP00000368688',
#    'score': 0.424,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.752,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.443,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.961,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.506,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171503',
#    'Ensembl': 'ENSP00000426638',
#    'score': 0.573,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140374',
#    'Ensembl': 'ENSP00000452762',
#    'score': 0.598,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000172340',
#    'Ensembl': 'ENSP00000419325',
#    'score': 0.728,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136143',
#    'Ensembl': 'ENSP00000494360',
#    'score': 0.777,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000131174',
#    'Ensembl': 'ENSP00000497474',
#    'score': 0.936,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000004779',
#    'Ensembl': 'ENSP00000458770',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  14: [{'stringdb_link_to': 'ENSG00000100209',
#    'Ensembl': 'ENSP00000216027',
#    'score': 0.508,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.568,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000115657',
#    'Ensembl': 'ENSP00000265316',
#    'score': 0.466,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000151093',
#    'Ensembl': 'ENSP00000280701',
#    'score': 0.422,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198125',
#    'Ensembl': 'ENSP00000352835',
#    'score': 0.403,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117305',
#    'Ensembl': 'ENSP00000363614',
#    'score': 0.468,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000072274',
#    'Ensembl': 'ENSP00000376197',
#    'score': 0.421,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.469,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186951',
#    'Ensembl': 'ENSP00000385523',
#    'score': 0.547,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.905,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  15: [{'stringdb_link_to': 'ENSG00000123643',
#    'Ensembl': 'ENSP00000243389',
#    'score': 0.624,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000106617',
#    'Ensembl': 'ENSP00000287878',
#    'score': 0.565,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000159720',
#    'Ensembl': 'ENSP00000290949',
#    'score': 0.586,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000250565',
#    'Ensembl': 'ENSP00000304891',
#    'score': 0.514,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168209',
#    'Ensembl': 'ENSP00000307305',
#    'score': 0.653,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000243056',
#    'Ensembl': 'ENSP00000308472',
#    'score': 0.451,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000187840',
#    'Ensembl': 'ENSP00000340691',
#    'score': 0.753,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  16: [{'stringdb_link_to': 'ENSG00000189058',
#    'Ensembl': 'ENSP00000345179',
#    'score': 0.555,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134698',
#    'Ensembl': 'ENSP00000362306',
#    'score': 0.533,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165029',
#    'Ensembl': 'ENSP00000363868',
#    'score': 0.967,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000147852',
#    'Ensembl': 'ENSP00000371532',
#    'score': 0.527,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116044',
#    'Ensembl': 'ENSP00000380252',
#    'score': 0.558,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186951',
#    'Ensembl': 'ENSP00000385523',
#    'score': 0.86,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070371',
#    'Ensembl': 'ENSP00000441158',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  17: [{'stringdb_link_to': 'ENSG00000129675',
#    'Ensembl': 'ENSP00000250617',
#    'score': 0.491,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.408,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.427,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.427,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198125',
#    'Ensembl': 'ENSP00000352835',
#    'score': 0.431,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000113916',
#    'Ensembl': 'ENSP00000384371',
#    'score': 0.454,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116044',
#    'Ensembl': 'ENSP00000380252',
#    'score': 0.458,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136546',
#    'Ensembl': 'ENSP00000496114',
#    'score': 0.519,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171735',
#    'Ensembl': 'ENSP00000306522',
#    'score': 0.531,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000087087',
#    'Ensembl': 'ENSP00000480421',
#    'score': 0.535,
#    'Uniprot-TrEMBL': 'Q9BXP5',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166257',
#    'Ensembl': 'ENSP00000376523',
#    'score': 0.536,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070371',
#    'Ensembl': 'ENSP00000441158',
#    'score': 0.554,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143799',
#    'Ensembl': 'ENSP00000355759',
#    'score': 0.564,
#    'Uniprot-TrEMBL': 'P09874',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000073969',
#    'Ensembl': 'ENSP00000381293',
#    'score': 0.568,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134369',
#    'Ensembl': 'ENSP00000356265',
#    'score': 0.589,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168646',
#    'Ensembl': 'ENSP00000302625',
#    'score': 0.628,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.695,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000145362',
#    'Ensembl': 'ENSP00000349588',
#    'score': 0.906,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000148700',
#    'Ensembl': 'ENSP00000348381',
#    'score': 0.984,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070182',
#    'Ensembl': 'ENSP00000495909',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  18: [{'stringdb_link_to': 'ENSG00000137513',
#    'Ensembl': 'ENSP00000281038',
#    'score': 0.415,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165731',
#    'Ensembl': 'ENSP00000347942',
#    'score': 0.539,
#    'Uniprot-TrEMBL': 'P07949',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168621',
#    'Ensembl': 'ENSP00000409007',
#    'score': 0.511,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  19: [{'stringdb_link_to': 'ENSG00000123643',
#    'Ensembl': 'ENSP00000243389',
#    'score': 0.408,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  20: [{'stringdb_link_to': 'ENSG00000121774',
#    'Ensembl': 'ENSP00000313829',
#    'score': 0.412,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067225',
#    'Ensembl': 'ENSP00000320171',
#    'score': 0.425,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000221869',
#    'Ensembl': 'ENSP00000386165',
#    'score': 0.893,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000078328',
#    'Ensembl': 'ENSP00000391269',
#    'score': 0.594,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  21: [{'stringdb_link_to': 'ENSG00000119699',
#    'Ensembl': 'ENSP00000238682',
#    'score': 0.984,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000164692',
#    'Ensembl': 'ENSP00000297268',
#    'score': 0.606,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168542',
#    'Ensembl': 'ENSP00000304408',
#    'score': 0.491,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166147',
#    'Ensembl': 'ENSP00000325527',
#    'score': 0.989,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.504,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000146674',
#    'Ensembl': 'ENSP00000370473',
#    'score': 0.508,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  22: [{'stringdb_link_to': 'ENSG00000100219',
#    'Ensembl': 'ENSP00000216037',
#    'score': 0.823,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000128228',
#    'Ensembl': 'ENSP00000248958',
#    'score': 0.541,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.486,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  23: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  24: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000124762',
#    'Ensembl': 'ENSP00000384849',
#    'score': 0.472,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116717',
#    'Ensembl': 'ENSP00000360025',
#    'score': 0.477,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000161513',
#    'Ensembl': 'ENSP00000416515',
#    'score': 0.505,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.514,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.565,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  25: [{'stringdb_link_to': 'ENSG00000186469',
#    'Ensembl': 'ENSP00000334448',
#    'score': 0.541,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000174021',
#    'Ensembl': 'ENSP00000359675',
#    'score': 0.541,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  26: [{'stringdb_link_to': 'ENSG00000112992',
#    'Ensembl': 'ENSP00000264663',
#    'score': 0.527,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166619',
#    'Ensembl': 'ENSP00000397172',
#    'score': 0.684,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  27: [{'stringdb_link_to': 'ENSG00000100906',
#    'Ensembl': 'ENSP00000216797',
#    'score': 0.795,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.488,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165312',
#    'Ensembl': 'ENSP00000365678',
#    'score': 0.502,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  28: [{'stringdb_link_to': 'ENSG00000244405',
#    'Ensembl': 'ENSP00000306894',
#    'score': 0.455,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000138193',
#    'Ensembl': 'ENSP00000360431',
#    'score': 0.809,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  29: [{'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.407,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000088682',
#    'Ensembl': 'ENSP00000262507',
#    'score': 0.509,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117305',
#    'Ensembl': 'ENSP00000363614',
#    'score': 0.42,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000151093',
#    'Ensembl': 'ENSP00000280701',
#    'score': 0.432,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154814',
#    'Ensembl': 'ENSP00000487136',
#    'score': 0.498,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.551,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067704',
#    'Ensembl': 'ENSP00000355889',
#    'score': 0.594,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139131',
#    'Ensembl': 'ENSP00000320658',
#    'score': 0.596,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.654,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.684,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171793',
#    'Ensembl': 'ENSP00000497744',
#    'score': 0.736,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000175198',
#    'Ensembl': 'ENSP00000365462',
#    'score': 0.736,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000148672',
#    'Ensembl': 'ENSP00000277865',
#    'score': 0.81,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000161513',
#    'Ensembl': 'ENSP00000416515',
#    'score': 0.815,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000137513',
#    'Ensembl': 'ENSP00000281038',
#    'score': 0.995,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  30: [{'stringdb_link_to': 'ENSG00000135900',
#    'Ensembl': 'ENSP00000258383',
#    'score': 0.883,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000138600',
#    'Ensembl': 'ENSP00000261854',
#    'score': 0.444,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166902',
#    'Ensembl': 'ENSP00000300151',
#    'score': 0.866,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000169519',
#    'Ensembl': 'ENSP00000384369',
#    'score': 0.824,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000278845',
#    'Ensembl': 'ENSP00000484903',
#    'score': 0.861,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  31: [{'stringdb_link_to': 'ENSG00000118298',
#    'Ensembl': 'ENSP00000358107',
#    'score': 0.406,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  32: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  33: [{'stringdb_link_to': 'ENSG00000100209',
# ...
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143799',
#    'Ensembl': 'ENSP00000355759',
#    'score': 0.514,
#    'Uniprot-TrEMBL': 'P09874',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.413,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116717',
#    'Ensembl': 'ENSP00000360025',
#    'score': 0.509,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.572,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000008128',
#    'Ensembl': 'ENSP00000367900',
#    'score': 0.927,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000150907',
#    'Ensembl': 'ENSP00000368880',
#    'score': 0.418,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067369',
#    'Ensembl': 'ENSP00000371475',
#    'score': 0.505,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.602,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.813,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000124762',
#    'Ensembl': 'ENSP00000384849',
#    'score': 0.996,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  544: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  545: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  546: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  547: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  548: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  549: [{'stringdb_link_to': 'ENSG00000120860',
#    'Ensembl': 'ENSP00000240079',
#    'score': 0.639,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000141759',
#    'Ensembl': 'ENSP00000269601',
#    'score': 0.482,
#    'Uniprot-TrEMBL': 'P83876',
#    'Uniprot-TrEMBL_link': None}],
#  550: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  551: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  552: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  553: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  554: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  555: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  556: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  557: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  558: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  559: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  560: [{'stringdb_link_to': 'ENSG00000168209',
#    'Ensembl': 'ENSP00000307305',
#    'score': 0.507,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000025039',
#    'Ensembl': 'ENSP00000358423',
#    'score': 0.451,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000187840',
#    'Ensembl': 'ENSP00000340691',
#    'score': 0.915,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  561: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  562: [{'stringdb_link_to': 'ENSG00000058866',
#    'Ensembl': 'ENSP00000265022',
#    'score': 0.455,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165731',
#    'Ensembl': 'ENSP00000347942',
#    'score': 0.447,
#    'Uniprot-TrEMBL': 'P07949',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.593,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168621',
#    'Ensembl': 'ENSP00000409007',
#    'score': 0.784,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  563: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  564: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  565: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  566: [{'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.64,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.898,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000159720',
#    'Ensembl': 'ENSP00000290949',
#    'score': 0.996,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198899',
#    'Ensembl': 'ENSP00000354632',
#    'score': 0.467,
#    'Uniprot-TrEMBL': 'P00846',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000072274',
#    'Ensembl': 'ENSP00000376197',
#    'score': 0.507,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000025039',
#    'Ensembl': 'ENSP00000358423',
#    'score': 0.514,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000123472',
#    'Ensembl': 'ENSP00000460964',
#    'score': 0.543,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.857,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  567: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  568: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  569: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  570: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  571: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  572: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  573: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  574: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  575: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  576: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  577: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  578: [{'stringdb_link_to': 'ENSG00000126432',
#    'Ensembl': 'ENSP00000265462',
#    'score': 0.636,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167996',
#    'Ensembl': 'ENSP00000273550',
#    'score': 0.405,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000159388',
#    'Ensembl': 'ENSP00000290551',
#    'score': 0.515,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.78,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167815',
#    'Ensembl': 'ENSP00000301522',
#    'score': 0.889,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167468',
#    'Ensembl': 'ENSP00000346103',
#    'score': 0.542,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000211445',
#    'Ensembl': 'ENSP00000373477',
#    'score': 0.591,
#    'Uniprot-TrEMBL': 'P22352',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000001084',
#    'Ensembl': 'ENSP00000497574',
#    'score': 0.756,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116044',
#    'Ensembl': 'ENSP00000380252',
#    'score': 0.899,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  579: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  580: [{'stringdb_link_to': 'ENSG00000114999',
#    'Ensembl': 'ENSP00000233336',
#    'score': 0.45,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000121774',
#    'Ensembl': 'ENSP00000313829',
#    'score': 0.502,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000178896',
#    'Ensembl': 'ENSP00000315476',
#    'score': 0.647,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000106263',
#    'Ensembl': 'ENSP00000354125',
#    'score': 0.515,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000205937',
#    'Ensembl': 'ENSP00000457723',
#    'score': 0.59,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000128016',
#    'Ensembl': 'ENSP00000471239',
#    'score': 0.826,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000113300',
#    'Ensembl': 'ENSP00000481893',
#    'score': 0.506,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  581: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  582: [{'stringdb_link_to': 'ENSG00000112578',
#    'Ensembl': 'ENSP00000230340',
#    'score': 0.998,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.429,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000178896',
#    'Ensembl': 'ENSP00000315476',
#    'score': 0.644,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134697',
#    'Ensembl': 'ENSP00000362153',
#    'score': 0.866,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101361',
#    'Ensembl': 'ENSP00000370589',
#    'score': 0.996,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111641',
#    'Ensembl': 'ENSP00000371858',
#    'score': 0.726,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000160214',
#    'Ensembl': 'ENSP00000417464',
#    'score': 0.424,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000122965',
#    'Ensembl': 'ENSP00000442053',
#    'score': 0.949,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000129347',
#    'Ensembl': 'ENSP00000498803',
#    'score': 0.732,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000124228',
#    'Ensembl': 'ENSP00000483495',
#    'score': 0.873,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  583: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  584: [{'stringdb_link_to': 'ENSG00000132463',
#    'Ensembl': 'ENSP00000254799',
#    'score': 0.552,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000135900',
#    'Ensembl': 'ENSP00000258383',
#    'score': 0.941,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136463',
#    'Ensembl': 'ENSP00000258975',
#    'score': 0.444,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.54,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166902',
#    'Ensembl': 'ENSP00000300151',
#    'score': 0.89,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171861',
#    'Ensembl': 'ENSP00000306080',
#    'score': 0.816,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000062582',
#    'Ensembl': 'ENSP00000318158',
#    'score': 0.861,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.477,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101019',
#    'Ensembl': 'ENSP00000363506',
#    'score': 0.403,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.546,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000004779',
#    'Ensembl': 'ENSP00000458770',
#    'score': 0.939,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  585: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  586: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  587: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  588: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  589: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  590: [{'stringdb_link_to': 'ENSG00000111641',
#    'Ensembl': 'ENSP00000371858',
#    'score': 0.432,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000106263',
#    'Ensembl': 'ENSP00000354125',
#    'score': 0.482,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134697',
#    'Ensembl': 'ENSP00000362153',
#    'score': 0.495,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000120725',
#    'Ensembl': 'ENSP00000265195',
#    'score': 0.497,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166902',
#    'Ensembl': 'ENSP00000300151',
#    'score': 0.5,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101361',
#    'Ensembl': 'ENSP00000370589',
#    'score': 0.534,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000115657',
#    'Ensembl': 'ENSP00000265316',
#    'score': 0.643,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}]}

# %%
ppi_df[["target", "StringDB_ppi"]].head()
# Out:
#             target                                       StringDB_ppi
# 0  ENSG00000001084  [{'stringdb_link_to': 'ENSG00000100906', 'Ense...
# 1  ENSG00000004468  [{'stringdb_link_to': 'ENSG00000089163', 'Ense...
# 2  ENSG00000004779  [{'stringdb_link_to': 'ENSG00000010256', 'Ense...
# 3  ENSG00000005700  [{'stringdb_link_to': 'ENSG00000198886', 'Ense...
# 4  ENSG00000006327  [{'stringdb_link_to': nan, 'Ensembl': nan, 'sc...

# %%
ppi_df[ppi_df["target"] == "ENSG00000196177"]["StringDB_ppi"].values
# Out:
# array([list([{'stringdb_link_to': 'ENSG00000091140', 'Ensembl': 'ENSP00000205402', 'score': 0.471, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000100209', 'Ensembl': 'ENSP00000216027', 'score': 0.408, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000104325', 'Ensembl': 'ENSP00000220764', 'score': 0.4, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000110435', 'Ensembl': 'ENSP00000227868', 'score': 0.405, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000106049', 'Ensembl': 'ENSP00000265395', 'score': 0.581, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000075239', 'Ensembl': 'ENSP00000265838', 'score': 0.968, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000151093', 'Ensembl': 'ENSP00000280701', 'score': 0.413, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000168291', 'Ensembl': 'ENSP00000307241', 'score': 0.455, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000083123', 'Ensembl': 'ENSP00000318351', 'score': 0.753, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000081760', 'Ensembl': 'ENSP00000324842', 'score': 0.444, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000198130', 'Ensembl': 'ENSP00000352706', 'score': 0.795, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000127884', 'Ensembl': 'ENSP00000357535', 'score': 0.993, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000004779', 'Ensembl': 'ENSP00000458770', 'score': 0.426, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000107897', 'Ensembl': 'ENSP00000365049', 'score': 0.448, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000117305', 'Ensembl': 'ENSP00000363614', 'score': 0.478, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000163541', 'Ensembl': 'ENSP00000377446', 'score': 0.561, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000116171', 'Ensembl': 'ENSP00000360569', 'score': 0.613, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000157184', 'Ensembl': 'ENSP00000360541', 'score': 0.615, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000171503', 'Ensembl': 'ENSP00000426638', 'score': 0.655, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000175198', 'Ensembl': 'ENSP00000365462', 'score': 0.663, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000148090', 'Ensembl': 'ENSP00000364883', 'score': 0.689, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000140374', 'Ensembl': 'ENSP00000452762', 'score': 0.846, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000093144', 'Ensembl': 'ENSP00000436585', 'score': 0.89, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSG00000137992', 'Ensembl': 'ENSP00000359151', 'score': 0.951, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}])],
#       dtype=object)

# %%
ncbi_tf_gprofiler_mitocarta_df_human.head(1)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSG00000000003           Ensembl   7105  ncbi_gene_id          TSPAN6
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 0    106.899174           -0.401659   0.143909 -2.791057    0.005254  ...
#
#    g:Profiler_go:cc  g:Profiler_go:mf g:Profiler_hp g:Profiler_hpa  \
# 0               NaN               NaN           NaN            NaN
#
#   g:Profiler_kegg g:Profiler_mirna g:Profiler_reac g:Profiler_tf  \
# 0             NaN              NaN             NaN           NaN
#
#   g:Profiler_wp MitoCarta
# 0           NaN       NaN
#
# [1 rows x 29 columns]

# %%
combined_df = pd.merge(
    ncbi_tf_gprofiler_mitocarta_df_human,
    ppi_df[["target", "StringDB_ppi"]].rename(columns={"target": "identifier"}),
    on="identifier",
    how="left",
)

# %%
combined_df.columns
# Out:
# Index(['identifier', 'identifier.source', 'target', 'target.source',
#        'GENE_SYMBOL_dea', 'baseMean_dea', 'log2FoldChange_dea', 'lfcSE_dea',
#        'stat_dea', 'pvalue_dea', 'padj_dea', 'minus_log10_pvalue_dea', 'is_tf',
#        'is_target', 'its_target', 'its_tf', 'intersections',
#        'g:Profiler_corum', 'g:Profiler_go:bp', 'g:Profiler_go:cc',
#        'g:Profiler_go:mf', 'g:Profiler_hp', 'g:Profiler_hpa',
#        'g:Profiler_kegg', 'g:Profiler_mirna', 'g:Profiler_reac',
#        'g:Profiler_tf', 'g:Profiler_wp', 'MitoCarta', 'StringDB_ppi'],
#       dtype='object')

# %%
combined_df.head(1)
# Out:
#         identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSG00000000003           Ensembl   7105  ncbi_gene_id          TSPAN6
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 0    106.899174           -0.401659   0.143909 -2.791057    0.005254  ...
#
#    g:Profiler_go:mf  g:Profiler_hp g:Profiler_hpa g:Profiler_kegg  \
# 0               NaN            NaN            NaN             NaN
#
#   g:Profiler_mirna g:Profiler_reac g:Profiler_tf g:Profiler_wp MitoCarta  \
# 0              NaN             NaN           NaN           NaN       NaN
#
#   StringDB_ppi
# 0          NaN
#
# [1 rows x 30 columns]

# %%
combined_df["StringDB_ppi"].to_dict()
# Out:
# {0: nan,
#  1: nan,
#  2: nan,
#  3: nan,
#  4: nan,
#  5: nan,
#  6: [{'stringdb_link_to': 'ENSG00000100906',
#    'Ensembl': 'ENSP00000216797',
#    'score': 0.556,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000125166',
#    'Ensembl': 'ENSP00000245206',
#    'score': 0.838,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000126432',
#    'Ensembl': 'ENSP00000265462',
#    'score': 0.518,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167996',
#    'Ensembl': 'ENSP00000273550',
#    'score': 0.508,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000148672',
#    'Ensembl': 'ENSP00000277865',
#    'score': 0.847,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167815',
#    'Ensembl': 'ENSP00000301522',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000169715',
#    'Ensembl': 'ENSP00000328137',
#    'score': 0.455,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167468',
#    'Ensembl': 'ENSP00000346103',
#    'score': 0.809,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.419,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117448',
#    'Ensembl': 'ENSP00000361140',
#    'score': 0.409,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000271303',
#    'Ensembl': 'ENSP00000371388',
#    'score': 0.756,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000211445',
#    'Ensembl': 'ENSP00000373477',
#    'score': 0.705,
#    'Uniprot-TrEMBL': 'P22352',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.598,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116044',
#    'Ensembl': 'ENSP00000380252',
#    'score': 0.966,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  7: nan,
#  8: nan,
#  9: nan,
#  10: nan,
#  11: nan,
#  12: nan,
#  13: nan,
#  14: nan,
#  15: nan,
#  16: nan,
#  17: nan,
#  18: nan,
#  19: nan,
#  20: nan,
#  21: nan,
#  22: nan,
#  23: nan,
#  24: nan,
#  25: nan,
#  26: nan,
#  27: nan,
#  28: nan,
#  29: nan,
#  30: nan,
#  31: nan,
#  32: nan,
#  33: nan,
#  34: nan,
#  35: nan,
#  36: nan,
#  37: nan,
#  38: nan,
#  39: nan,
#  40: nan,
#  41: [{'stringdb_link_to': 'ENSG00000089163',
#    'Ensembl': 'ENSP00000202967',
#    'score': 0.921,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100219',
#    'Ensembl': 'ENSP00000216037',
#    'score': 0.527,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000128016',
#    'Ensembl': 'ENSP00000471239',
#    'score': 0.41,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143799',
#    'Ensembl': 'ENSP00000355759',
#    'score': 0.429,
#    'Uniprot-TrEMBL': 'P09874',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163864',
#    'Ensembl': 'ENSP00000495112',
#    'score': 0.446,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.459,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000113916',
#    'Ensembl': 'ENSP00000384371',
#    'score': 0.695,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.7,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154096',
#    'Ensembl': 'ENSP00000284240',
#    'score': 0.708,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000072274',
#    'Ensembl': 'ENSP00000376197',
#    'score': 0.788,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000112992',
#    'Ensembl': 'ENSP00000264663',
#    'score': 0.909,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152620',
#    'Ensembl': 'ENSP00000371362',
#    'score': 0.91,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000124523',
#    'Ensembl': 'ENSP00000476228',
#    'score': 0.923,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166741',
#    'Ensembl': 'ENSP00000441434',
#    'score': 0.925,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142082',
#    'Ensembl': 'ENSP00000372191',
#    'score': 0.939,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  42: nan,
#  43: nan,
#  44: nan,
#  45: nan,
#  46: nan,
#  47: nan,
#  48: nan,
#  49: nan,
#  50: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.983,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.669,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.658,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000104325',
#    'Ensembl': 'ENSP00000220764',
#    'score': 0.455,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000108179',
#    'Ensembl': 'ENSP00000225174',
#    'score': 0.445,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.47,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111669',
#    'Ensembl': 'ENSP00000229270',
#    'score': 0.546,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130414',
#    'Ensembl': 'ENSP00000252711',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000135900',
#    'Ensembl': 'ENSP00000258383',
#    'score': 0.945,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.677,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000106049',
#    'Ensembl': 'ENSP00000265395',
#    'score': 0.521,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000147592',
#    'Ensembl': 'ENSP00000276590',
#    'score': 0.48,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000151093',
#    'Ensembl': 'ENSP00000280701',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.752,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166902',
#    'Ensembl': 'ENSP00000300151',
#    'score': 0.957,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171861',
#    'Ensembl': 'ENSP00000306080',
#    'score': 0.965,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168291',
#    'Ensembl': 'ENSP00000307241',
#    'score': 0.741,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140905',
#    'Ensembl': 'ENSP00000319531',
#    'score': 0.858,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067225',
#    'Ensembl': 'ENSP00000320171',
#    'score': 0.421,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139131',
#    'Ensembl': 'ENSP00000320658',
#    'score': 0.415,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000176340',
#    'Ensembl': 'ENSP00000321260',
#    'score': 0.661,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000187630',
#    'Ensembl': 'ENSP00000334801',
#    'score': 0.405,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000119689',
#    'Ensembl': 'ENSP00000335304',
#    'score': 0.538,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.891,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.925,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198786',
#    'Ensembl': 'ENSP00000354813',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.793,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198938',
#    'Ensembl': 'ENSP00000354982',
#    'score': 0.869,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'ENSP00000355046',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198840',
#    'Ensembl': 'ENSP00000355206',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'ENSP00000356953',
#    'score': 0.504,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000158864',
#    'Ensembl': 'ENSP00000356972',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000127884',
#    'Ensembl': 'ENSP00000357535',
#    'score': 0.518,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000196177',
#    'Ensembl': 'ENSP00000357873',
#    'score': 0.426,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000178096',
#    'Ensembl': 'ENSP00000358149',
#    'score': 0.576,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.65,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134697',
#    'Ensembl': 'ENSP00000362153',
#    'score': 0.46,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.651,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000175198',
#    'Ensembl': 'ENSP00000365462',
#    'score': 0.478,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101247',
#    'Ensembl': 'ENSP00000367346',
#    'score': 0.799,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186687',
#    'Ensembl': 'ENSP00000368688',
#    'score': 0.838,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163607',
#    'Ensembl': 'ENSP00000373176',
#    'score': 0.817,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.624,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.405,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.767,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000169519',
#    'Ensembl': 'ENSP00000384369',
#    'score': 0.499,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000023228',
#    'Ensembl': 'ENSP00000392709',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000205707',
#    'Ensembl': 'ENSP00000450584',
#    'score': 0.948,
#    'Uniprot-TrEMBL': 'Q6IPR1',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140374',
#    'Ensembl': 'ENSP00000452762',
#    'score': 0.916,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000123472',
#    'Ensembl': 'ENSP00000460964',
#    'score': 0.485,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000131174',
#    'Ensembl': 'ENSP00000497474',
#    'score': 0.924,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000278845',
#    'Ensembl': 'ENSP00000484903',
#    'score': 0.939,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  51: nan,
#  52: nan,
#  53: nan,
#  54: nan,
#  55: nan,
#  56: nan,
#  57: nan,
#  58: nan,
#  59: nan,
#  60: nan,
#  61: nan,
#  62: nan,
#  63: nan,
#  64: nan,
#  65: nan,
#  66: nan,
#  67: nan,
#  68: nan,
#  69: nan,
#  70: nan,
#  71: nan,
#  72: nan,
#  73: nan,
#  74: nan,
#  75: nan,
#  76: nan,
#  77: nan,
#  78: nan,
#  79: nan,
#  80: nan,
#  81: [{'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  82: nan,
#  83: nan,
#  84: nan,
#  85: nan,
#  86: nan,
#  87: nan,
#  88: nan,
#  89: nan,
#  90: nan,
#  91: nan,
#  92: nan,
#  93: nan,
#  94: nan,
#  95: nan,
#  96: nan,
#  97: nan,
#  98: nan,
#  99: nan,
#  100: nan,
#  101: nan,
#  102: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  103: nan,
#  104: nan,
#  105: nan,
#  106: nan,
#  107: nan,
#  108: nan,
#  109: nan,
#  110: nan,
#  111: nan,
#  112: nan,
#  113: nan,
#  114: nan,
#  115: nan,
#  116: nan,
#  117: nan,
#  118: nan,
#  119: nan,
#  120: nan,
#  121: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  122: nan,
#  123: [{'stringdb_link_to': 'ENSG00000131462',
#    'Ensembl': 'ENSP00000251413',
#    'score': 0.698,
#    'Uniprot-TrEMBL': 'P23258',
#    'Uniprot-TrEMBL_link': None}],
#  124: [{'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.438,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130706',
#    'Ensembl': 'ENSP00000478877',
#    'score': 0.488,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  125: nan,
#  126: nan,
#  127: nan,
#  128: nan,
#  129: nan,
#  130: nan,
#  131: nan,
#  132: nan,
#  133: nan,
#  134: nan,
#  135: nan,
#  136: nan,
#  137: nan,
#  138: nan,
#  139: nan,
#  140: nan,
#  141: nan,
#  142: nan,
#  143: nan,
#  144: nan,
#  145: nan,
#  146: nan,
#  147: [{'stringdb_link_to': 'ENSG00000131462',
#    'Ensembl': 'ENSP00000251413',
#    'score': 0.54,
#    'Uniprot-TrEMBL': 'P23258',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000081760',
#    'Ensembl': 'ENSP00000324842',
#    'score': 0.41,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000153107',
#    'Ensembl': 'ENSP00000339109',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000160299',
#    'Ensembl': 'ENSP00000352572',
#    'score': 0.55,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000138107',
#    'Ensembl': 'ENSP00000358921',
#    'score': 0.55,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139350',
#    'Ensembl': 'ENSP00000451211',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000205937',
#    'Ensembl': 'ENSP00000457723',
#    'score': 0.86,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000221978',
#    'Ensembl': 'ENSP00000383611',
#    'score': 0.927,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  148: nan,
#  149: nan,
#  150: nan,
#  151: nan,
#  152: nan,
#  153: nan,
#  154: nan,
#  155: nan,
#  156: nan,
#  157: nan,
#  158: nan,
#  159: nan,
#  160: nan,
#  161: nan,
#  162: nan,
#  163: nan,
#  164: nan,
#  165: nan,
#  166: nan,
#  167: nan,
#  168: nan,
#  169: nan,
#  170: nan,
#  171: nan,
#  172: nan,
#  173: nan,
#  174: nan,
#  175: nan,
#  176: nan,
#  177: nan,
#  178: nan,
#  179: nan,
#  180: nan,
#  181: nan,
#  182: nan,
#  183: [{'stringdb_link_to': 'ENSG00000083123',
#    'Ensembl': 'ENSP00000318351',
#    'score': 0.423,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171503',
#    'Ensembl': 'ENSP00000426638',
#    'score': 0.43,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198899',
#    'Ensembl': 'ENSP00000354632',
#    'score': 0.435,
#    'Uniprot-TrEMBL': 'P00846',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067225',
#    'Ensembl': 'ENSP00000320171',
#    'score': 0.442,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186687',
#    'Ensembl': 'ENSP00000368688',
#    'score': 0.444,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136143',
#    'Ensembl': 'ENSP00000494360',
#    'score': 0.462,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.475,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.487,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000182054',
#    'Ensembl': 'ENSP00000331897',
#    'score': 0.491,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.5,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000054148',
#    'Ensembl': 'ENSP00000247665',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000088682',
#    'Ensembl': 'ENSP00000262507',
#    'score': 0.529,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000159720',
#    'Ensembl': 'ENSP00000290949',
#    'score': 0.539,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101019',
#    'Ensembl': 'ENSP00000363506',
#    'score': 0.542,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111669',
#    'Ensembl': 'ENSP00000229270',
#    'score': 0.556,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140374',
#    'Ensembl': 'ENSP00000452762',
#    'score': 0.569,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.578,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000149925',
#    'Ensembl': 'ENSP00000496166',
#    'score': 0.609,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.614,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000127884',
#    'Ensembl': 'ENSP00000357535',
#    'score': 0.625,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000119689',
#    'Ensembl': 'ENSP00000335304',
#    'score': 0.684,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'ENSP00000356953',
#    'score': 0.709,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000125166',
#    'Ensembl': 'ENSP00000245206',
#    'score': 0.718,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000176340',
#    'Ensembl': 'ENSP00000321260',
#    'score': 0.816,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168291',
#    'Ensembl': 'ENSP00000307241',
#    'score': 0.826,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.831,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.855,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'ENSP00000355046',
#    'score': 0.933,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.938,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198786',
#    'Ensembl': 'ENSP00000354813',
#    'score': 0.942,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.955,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198840',
#    'Ensembl': 'ENSP00000355206',
#    'score': 0.962,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.969,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.97,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.971,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000131174',
#    'Ensembl': 'ENSP00000497474',
#    'score': 0.974,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.979,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000004779',
#    'Ensembl': 'ENSP00000458770',
#    'score': 0.983,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198938',
#    'Ensembl': 'ENSP00000354982',
#    'score': 0.99,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.995,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.995,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130414',
#    'Ensembl': 'ENSP00000252711',
#    'score': 0.996,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.998,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000023228',
#    'Ensembl': 'ENSP00000392709',
#    'score': 0.998,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000158864',
#    'Ensembl': 'ENSP00000356972',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  184: nan,
#  185: nan,
#  186: nan,
#  187: nan,
#  188: nan,
#  189: nan,
#  190: nan,
#  191: nan,
#  192: nan,
#  193: nan,
#  194: nan,
#  195: nan,
#  196: nan,
#  197: nan,
#  198: nan,
#  199: nan,
#  200: nan,
#  201: nan,
#  202: nan,
#  203: nan,
#  204: nan,
#  205: nan,
#  206: nan,
#  207: nan,
#  208: nan,
#  209: nan,
#  210: nan,
#  211: nan,
#  212: nan,
#  213: nan,
#  214: nan,
#  215: nan,
#  216: nan,
#  217: nan,
#  218: nan,
#  219: nan,
#  220: nan,
#  221: nan,
#  222: nan,
#  223: nan,
#  224: nan,
#  225: nan,
#  226: nan,
#  227: nan,
#  228: [{'stringdb_link_to': 'ENSG00000104756',
#    'Ensembl': 'ENSP00000221200',
#    'score': 0.517,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186951',
#    'Ensembl': 'ENSP00000385523',
#    'score': 0.674,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  229: nan,
#  230: nan,
#  231: nan,
#  232: nan,
#  233: nan,
#  234: nan,
#  235: nan,
#  236: nan,
#  237: nan,
#  238: nan,
#  239: nan,
#  240: nan,
#  241: nan,
#  242: nan,
#  243: nan,
#  244: nan,
#  245: nan,
#  246: nan,
#  247: nan,
#  248: nan,
#  249: nan,
#  250: nan,
#  251: nan,
#  252: nan,
#  253: nan,
#  254: nan,
#  255: nan,
#  256: nan,
#  257: nan,
#  258: nan,
#  259: nan,
#  260: nan,
#  261: nan,
#  262: [{'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.436,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000104756',
#    'Ensembl': 'ENSP00000221200',
#    'score': 0.483,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000132463',
#    'Ensembl': 'ENSP00000254799',
#    'score': 0.413,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000173992',
#    'Ensembl': 'ENSP00000436318',
#    'score': 0.56,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  263: nan,
#  264: nan,
#  265: nan,
#  266: nan,
#  267: nan,
#  268: nan,
#  269: nan,
#  270: nan,
#  271: nan,
#  272: nan,
#  273: nan,
#  274: nan,
#  275: nan,
#  276: nan,
#  277: nan,
#  278: nan,
#  279: nan,
#  280: nan,
#  281: nan,
#  282: nan,
#  283: nan,
#  284: nan,
#  285: nan,
#  286: nan,
#  287: nan,
#  288: nan,
#  289: nan,
#  290: nan,
#  291: nan,
#  292: nan,
#  293: nan,
#  294: nan,
#  295: nan,
#  296: nan,
#  297: nan,
#  298: nan,
#  299: nan,
#  300: [{'stringdb_link_to': 'ENSG00000137692',
#    'Ensembl': 'ENSP00000260247',
#    'score': 0.461,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000073712',
#    'Ensembl': 'ENSP00000342858',
#    'score': 0.445,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000102119',
#    'Ensembl': 'ENSP00000358857',
#    'score': 0.709,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  301: nan,
#  302: nan,
#  303: nan,
#  304: nan,
#  305: nan,
#  306: nan,
#  307: nan,
#  308: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.998,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.946,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100209',
#    'Ensembl': 'ENSP00000216027',
#    'score': 0.575,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.865,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.682,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111669',
#    'Ensembl': 'ENSP00000229270',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000125166',
#    'Ensembl': 'ENSP00000245206',
#    'score': 0.461,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130414',
#    'Ensembl': 'ENSP00000252711',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136463',
#    'Ensembl': 'ENSP00000258975',
#    'score': 0.615,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.977,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000088682',
#    'Ensembl': 'ENSP00000262507',
#    'score': 0.551,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000181192',
#    'Ensembl': 'ENSP00000263035',
#    'score': 0.551,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139631',
#    'Ensembl': 'ENSP00000267085',
#    'score': 0.433,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139637',
#    'Ensembl': 'ENSP00000267103',
#    'score': 0.671,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.524,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.883,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168291',
#    'Ensembl': 'ENSP00000307241',
#    'score': 0.809,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000173085',
#    'Ensembl': 'ENSP00000310873',
#    'score': 0.43,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000083123',
#    'Ensembl': 'ENSP00000318351',
#    'score': 0.479,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.47,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000182054',
#    'Ensembl': 'ENSP00000331897',
#    'score': 0.494,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000119689',
#    'Ensembl': 'ENSP00000335304',
#    'score': 0.88,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.988,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.986,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198899',
#    'Ensembl': 'ENSP00000354632',
#    'score': 0.715,
#    'Uniprot-TrEMBL': 'P00846',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198786',
#    'Ensembl': 'ENSP00000354813',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.976,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198938',
#    'Ensembl': 'ENSP00000354982',
#    'score': 0.99,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'ENSP00000355046',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198840',
#    'Ensembl': 'ENSP00000355206',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067704',
#    'Ensembl': 'ENSP00000355889',
#    'score': 0.487,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'ENSP00000356953',
#    'score': 0.923,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000158864',
#    'Ensembl': 'ENSP00000356972',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000137992',
#    'Ensembl': 'ENSP00000359151',
#    'score': 0.631,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.665,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.996,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101247',
#    'Ensembl': 'ENSP00000367346',
#    'score': 0.877,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186687',
#    'Ensembl': 'ENSP00000368688',
#    'score': 0.424,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.752,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.443,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.961,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.506,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171503',
#    'Ensembl': 'ENSP00000426638',
#    'score': 0.573,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140374',
#    'Ensembl': 'ENSP00000452762',
#    'score': 0.598,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000172340',
#    'Ensembl': 'ENSP00000419325',
#    'score': 0.728,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136143',
#    'Ensembl': 'ENSP00000494360',
#    'score': 0.777,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000131174',
#    'Ensembl': 'ENSP00000497474',
#    'score': 0.936,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000004779',
#    'Ensembl': 'ENSP00000458770',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  309: nan,
#  310: nan,
#  311: [{'stringdb_link_to': 'ENSG00000100209',
#    'Ensembl': 'ENSP00000216027',
#    'score': 0.508,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.568,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000115657',
#    'Ensembl': 'ENSP00000265316',
#    'score': 0.466,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000151093',
#    'Ensembl': 'ENSP00000280701',
#    'score': 0.422,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198125',
#    'Ensembl': 'ENSP00000352835',
#    'score': 0.403,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117305',
#    'Ensembl': 'ENSP00000363614',
#    'score': 0.468,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000072274',
#    'Ensembl': 'ENSP00000376197',
#    'score': 0.421,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.469,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186951',
#    'Ensembl': 'ENSP00000385523',
#    'score': 0.547,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.905,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  312: nan,
#  313: nan,
#  314: nan,
#  315: nan,
#  316: nan,
#  317: nan,
#  318: nan,
#  319: nan,
#  320: nan,
#  321: nan,
#  322: nan,
#  323: [{'stringdb_link_to': 'ENSG00000123643',
#    'Ensembl': 'ENSP00000243389',
#    'score': 0.624,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000106617',
#    'Ensembl': 'ENSP00000287878',
#    'score': 0.565,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000159720',
#    'Ensembl': 'ENSP00000290949',
#    'score': 0.586,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000250565',
#    'Ensembl': 'ENSP00000304891',
#    'score': 0.514,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168209',
#    'Ensembl': 'ENSP00000307305',
#    'score': 0.653,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000243056',
#    'Ensembl': 'ENSP00000308472',
#    'score': 0.451,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000187840',
#    'Ensembl': 'ENSP00000340691',
#    'score': 0.753,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  324: nan,
#  325: nan,
#  326: [{'stringdb_link_to': 'ENSG00000189058',
#    'Ensembl': 'ENSP00000345179',
#    'score': 0.555,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134698',
#    'Ensembl': 'ENSP00000362306',
#    'score': 0.533,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165029',
#    'Ensembl': 'ENSP00000363868',
#    'score': 0.967,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000147852',
#    'Ensembl': 'ENSP00000371532',
#    'score': 0.527,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116044',
#    'Ensembl': 'ENSP00000380252',
#    'score': 0.558,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000186951',
#    'Ensembl': 'ENSP00000385523',
#    'score': 0.86,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070371',
#    'Ensembl': 'ENSP00000441158',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  327: nan,
#  328: nan,
#  329: nan,
#  330: nan,
#  331: nan,
#  332: nan,
#  333: nan,
#  334: nan,
#  335: nan,
#  336: nan,
#  337: nan,
#  338: nan,
#  339: nan,
#  340: nan,
#  341: nan,
#  342: nan,
#  343: nan,
#  344: nan,
#  345: nan,
#  346: nan,
#  347: nan,
#  348: nan,
#  349: nan,
#  350: [{'stringdb_link_to': 'ENSG00000129675',
#    'Ensembl': 'ENSP00000250617',
#    'score': 0.491,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.408,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.427,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.427,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198125',
#    'Ensembl': 'ENSP00000352835',
#    'score': 0.431,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000113916',
#    'Ensembl': 'ENSP00000384371',
#    'score': 0.454,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116044',
#    'Ensembl': 'ENSP00000380252',
#    'score': 0.458,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136546',
#    'Ensembl': 'ENSP00000496114',
#    'score': 0.519,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171735',
#    'Ensembl': 'ENSP00000306522',
#    'score': 0.531,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000087087',
#    'Ensembl': 'ENSP00000480421',
#    'score': 0.535,
#    'Uniprot-TrEMBL': 'Q9BXP5',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166257',
#    'Ensembl': 'ENSP00000376523',
#    'score': 0.536,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070371',
#    'Ensembl': 'ENSP00000441158',
#    'score': 0.554,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143799',
#    'Ensembl': 'ENSP00000355759',
#    'score': 0.564,
#    'Uniprot-TrEMBL': 'P09874',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000073969',
#    'Ensembl': 'ENSP00000381293',
#    'score': 0.568,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000134369',
#    'Ensembl': 'ENSP00000356265',
#    'score': 0.589,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168646',
#    'Ensembl': 'ENSP00000302625',
#    'score': 0.628,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.695,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000145362',
#    'Ensembl': 'ENSP00000349588',
#    'score': 0.906,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000148700',
#    'Ensembl': 'ENSP00000348381',
#    'score': 0.984,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070182',
#    'Ensembl': 'ENSP00000495909',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  351: nan,
#  352: nan,
#  353: nan,
#  354: nan,
#  355: nan,
#  356: nan,
#  357: nan,
#  358: nan,
#  359: nan,
#  360: nan,
#  361: nan,
#  362: nan,
#  363: nan,
#  364: nan,
#  365: nan,
#  366: nan,
#  367: nan,
#  368: nan,
#  369: nan,
#  370: nan,
#  371: nan,
#  372: nan,
#  373: nan,
#  374: [{'stringdb_link_to': 'ENSG00000137513',
#    'Ensembl': 'ENSP00000281038',
#    'score': 0.415,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165731',
#    'Ensembl': 'ENSP00000347942',
#    'score': 0.539,
#    'Uniprot-TrEMBL': 'P07949',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168621',
#    'Ensembl': 'ENSP00000409007',
#    'score': 0.511,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  375: nan,
#  376: nan,
#  377: nan,
#  378: nan,
#  379: nan,
#  380: nan,
#  381: nan,
#  382: nan,
#  383: nan,
#  384: nan,
#  385: nan,
#  386: nan,
#  387: nan,
#  388: nan,
#  389: nan,
#  390: nan,
#  391: nan,
#  392: nan,
#  393: nan,
#  394: nan,
#  395: nan,
#  396: nan,
#  397: nan,
#  398: nan,
#  399: nan,
#  400: nan,
#  401: nan,
#  402: nan,
#  403: nan,
#  404: nan,
#  405: nan,
#  406: nan,
#  407: nan,
#  408: nan,
#  409: nan,
#  410: nan,
#  411: nan,
#  412: nan,
#  413: nan,
#  414: nan,
#  415: nan,
#  416: nan,
#  417: nan,
#  418: nan,
#  419: nan,
#  420: nan,
#  421: nan,
#  422: nan,
#  423: nan,
#  424: [{'stringdb_link_to': 'ENSG00000123643',
#    'Ensembl': 'ENSP00000243389',
#    'score': 0.408,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  425: nan,
#  426: nan,
#  427: nan,
#  428: nan,
#  429: nan,
#  430: nan,
#  431: nan,
#  432: nan,
#  433: nan,
#  434: nan,
#  435: nan,
#  436: nan,
#  437: nan,
#  438: nan,
#  439: nan,
#  440: nan,
#  441: nan,
#  442: nan,
#  443: nan,
#  444: nan,
#  445: nan,
#  446: nan,
#  447: nan,
#  448: nan,
#  449: nan,
#  450: nan,
#  451: nan,
#  452: nan,
#  453: nan,
#  454: nan,
#  455: nan,
#  456: nan,
#  457: nan,
#  458: nan,
#  459: nan,
#  460: nan,
#  461: nan,
#  462: nan,
#  463: nan,
#  464: nan,
#  465: nan,
#  466: nan,
#  467: nan,
#  468: nan,
#  469: nan,
#  470: nan,
#  471: nan,
#  472: nan,
#  473: nan,
#  474: nan,
#  475: nan,
#  476: nan,
#  477: nan,
#  478: nan,
#  479: nan,
#  480: nan,
#  481: nan,
#  482: [{'stringdb_link_to': 'ENSG00000121774',
#    'Ensembl': 'ENSP00000313829',
#    'score': 0.412,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067225',
#    'Ensembl': 'ENSP00000320171',
#    'score': 0.425,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000221869',
#    'Ensembl': 'ENSP00000386165',
#    'score': 0.893,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000078328',
#    'Ensembl': 'ENSP00000391269',
#    'score': 0.594,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  483: nan,
#  484: nan,
#  485: nan,
#  486: nan,
#  487: nan,
#  488: nan,
#  489: nan,
#  490: [{'stringdb_link_to': 'ENSG00000119699',
#    'Ensembl': 'ENSP00000238682',
#    'score': 0.984,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000164692',
#    'Ensembl': 'ENSP00000297268',
#    'score': 0.606,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168542',
#    'Ensembl': 'ENSP00000304408',
#    'score': 0.491,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000166147',
#    'Ensembl': 'ENSP00000325527',
#    'score': 0.989,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.504,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000146674',
#    'Ensembl': 'ENSP00000370473',
#    'score': 0.508,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  491: nan,
#  492: nan,
#  493: nan,
#  494: nan,
#  495: nan,
#  496: nan,
#  497: nan,
#  498: nan,
#  499: nan,
#  500: nan,
#  501: nan,
#  502: nan,
#  503: nan,
#  504: nan,
#  505: nan,
#  506: nan,
#  507: nan,
#  508: nan,
#  509: [{'stringdb_link_to': 'ENSG00000100219',
#    'Ensembl': 'ENSP00000216037',
#    'score': 0.823,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000128228',
#    'Ensembl': 'ENSP00000248958',
#    'score': 0.541,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000185624',
#    'Ensembl': 'ENSP00000327801',
#    'score': 0.486,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  510: nan,
#  511: nan,
#  512: nan,
#  513: nan,
#  514: nan,
#  515: nan,
#  516: nan,
#  517: nan,
#  518: nan,
#  519: nan,
#  520: nan,
#  521: nan,
#  522: nan,
#  523: nan,
#  524: nan,
#  525: nan,
#  526: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  527: nan,
#  528: nan,
#  529: nan,
#  530: nan,
#  531: nan,
#  532: nan,
#  533: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.512,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000124762',
#    'Ensembl': 'ENSP00000384849',
# ...
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000073969',
#    'Ensembl': 'ENSP00000381293',
#    'score': 0.544,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000103657',
#    'Ensembl': 'ENSP00000390158',
#    'score': 0.672,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000221838',
#    'Ensembl': 'ENSP00000403663',
#    'score': 0.54,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000025434',
#    'Ensembl': 'ENSP00000477707',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  834: nan,
#  835: nan,
#  836: nan,
#  837: nan,
#  838: nan,
#  839: nan,
#  840: nan,
#  841: nan,
#  842: nan,
#  843: nan,
#  844: nan,
#  845: nan,
#  846: nan,
#  847: nan,
#  848: nan,
#  849: nan,
#  850: nan,
#  851: nan,
#  852: nan,
#  853: nan,
#  854: nan,
#  855: nan,
#  856: nan,
#  857: nan,
#  858: nan,
#  859: nan,
#  860: nan,
#  861: nan,
#  862: nan,
#  863: nan,
#  864: nan,
#  865: nan,
#  866: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  867: nan,
#  868: nan,
#  869: nan,
#  870: nan,
#  871: nan,
#  872: nan,
#  873: nan,
#  874: nan,
#  875: nan,
#  876: nan,
#  877: nan,
#  878: [{'stringdb_link_to': 'ENSG00000076248',
#    'Ensembl': 'ENSP00000242576',
#    'score': 0.498,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111602',
#    'Ensembl': 'ENSP00000450607',
#    'score': 0.44,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100227',
#    'Ensembl': 'ENSP00000397927',
#    'score': 0.499,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143799',
#    'Ensembl': 'ENSP00000355759',
#    'score': 0.53,
#    'Uniprot-TrEMBL': 'P09874',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067369',
#    'Ensembl': 'ENSP00000371475',
#    'score': 0.624,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  879: nan,
#  880: nan,
#  881: nan,
#  882: nan,
#  883: nan,
#  884: nan,
#  885: nan,
#  886: nan,
#  887: nan,
#  888: nan,
#  889: nan,
#  890: nan,
#  891: nan,
#  892: nan,
#  893: nan,
#  894: nan,
#  895: [{'stringdb_link_to': 'ENSG00000076662',
#    'Ensembl': 'ENSP00000160262',
#    'score': 0.435,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.511,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000004468',
#    'Ensembl': 'ENSP00000226279',
#    'score': 0.788,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213463',
#    'Ensembl': 'ENSP00000256366',
#    'score': 0.466,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000115657',
#    'Ensembl': 'ENSP00000265316',
#    'score': 0.659,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000120802',
#    'Ensembl': 'ENSP00000266732',
#    'score': 0.447,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143878',
#    'Ensembl': 'ENSP00000272233',
#    'score': 0.608,
#    'Uniprot-TrEMBL': 'P62745',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167996',
#    'Ensembl': 'ENSP00000273550',
#    'score': 0.995,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154096',
#    'Ensembl': 'ENSP00000284240',
#    'score': 0.699,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000159720',
#    'Ensembl': 'ENSP00000290949',
#    'score': 0.543,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000250565',
#    'Ensembl': 'ENSP00000304891',
#    'score': 0.507,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000146729',
#    'Ensembl': 'ENSP00000313050',
#    'score': 0.432,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000091879',
#    'Ensembl': 'ENSP00000314897',
#    'score': 0.486,
#    'Uniprot-TrEMBL': 'O15123',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167468',
#    'Ensembl': 'ENSP00000346103',
#    'score': 0.666,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000197081',
#    'Ensembl': 'ENSP00000349437',
#    'score': 0.673,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198125',
#    'Ensembl': 'ENSP00000352835',
#    'score': 0.566,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000137992',
#    'Ensembl': 'ENSP00000359151',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165029',
#    'Ensembl': 'ENSP00000363868',
#    'score': 0.504,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000023330',
#    'Ensembl': 'ENSP00000378416',
#    'score': 0.421,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000113916',
#    'Ensembl': 'ENSP00000384371',
#    'score': 0.511,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000135441',
#    'Ensembl': 'ENSP00000447537',
#    'score': 0.536,
#    'Uniprot-TrEMBL': 'P78537',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070371',
#    'Ensembl': 'ENSP00000441158',
#    'score': 0.54,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139998',
#    'Ensembl': 'ENSP00000434103',
#    'score': 0.548,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000066926',
#    'Ensembl': 'ENSP00000498358',
#    'score': 0.567,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.596,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000128016',
#    'Ensembl': 'ENSP00000471239',
#    'score': 0.618,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.753,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  896: nan,
#  897: nan,
#  898: nan,
#  899: nan,
#  900: nan,
#  901: nan,
#  902: nan,
#  903: nan,
#  904: nan,
#  905: nan,
#  906: nan,
#  907: nan,
#  908: nan,
#  909: nan,
#  910: nan,
#  911: nan,
#  912: nan,
#  913: nan,
#  914: nan,
#  915: nan,
#  916: nan,
#  917: nan,
#  918: nan,
#  919: nan,
#  920: nan,
#  921: nan,
#  922: nan,
#  923: [{'stringdb_link_to': 'ENSG00000186951',
#    'Ensembl': 'ENSP00000385523',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000197451',
#    'Ensembl': 'ENSP00000425031',
#    'score': 0.51,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000177606',
#    'Ensembl': 'ENSP00000360266',
#    'score': 0.513,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000123124',
#    'Ensembl': 'ENSP00000427793',
#    'score': 0.57,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000204209',
#    'Ensembl': 'ENSP00000266000',
#    'score': 0.573,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000124762',
#    'Ensembl': 'ENSP00000384849',
#    'score': 0.633,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.674,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168209',
#    'Ensembl': 'ENSP00000307305',
#    'score': 0.842,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  924: nan,
#  925: nan,
#  926: nan,
#  927: nan,
#  928: nan,
#  929: nan,
#  930: nan,
#  931: nan,
#  932: nan,
#  933: [{'stringdb_link_to': 'ENSG00000168542',
#    'Ensembl': 'ENSP00000304408',
#    'score': 0.43,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000022267',
#    'Ensembl': 'ENSP00000498684',
#    'score': 0.445,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070371',
#    'Ensembl': 'ENSP00000441158',
#    'score': 0.452,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136997',
#    'Ensembl': 'ENSP00000478887',
#    'score': 0.484,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  934: nan,
#  935: nan,
#  936: nan,
#  937: nan,
#  938: nan,
#  939: [{'stringdb_link_to': 'ENSG00000123570',
#    'Ensembl': 'ENSP00000243298',
#    'score': 0.677,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000029534',
#    'Ensembl': 'ENSP00000265709',
#    'score': 0.568,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000197081',
#    'Ensembl': 'ENSP00000349437',
#    'score': 0.514,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000145362',
#    'Ensembl': 'ENSP00000349588',
#    'score': 0.567,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000215305',
#    'Ensembl': 'ENSP00000369810',
#    'score': 0.533,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070182',
#    'Ensembl': 'ENSP00000495909',
#    'score': 0.524,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000070371',
#    'Ensembl': 'ENSP00000441158',
#    'score': 0.544,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000141252',
#    'Ensembl': 'ENSP00000401435',
#    'score': 0.63,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000203879',
#    'Ensembl': 'ENSP00000394071',
#    'score': 0.655,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  940: nan,
#  941: nan,
#  942: nan,
#  943: nan,
#  944: nan,
#  945: nan,
#  946: nan,
#  947: nan,
#  948: nan,
#  949: nan,
#  950: nan,
#  951: nan,
#  952: nan,
#  953: nan,
#  954: nan,
#  955: nan,
#  956: nan,
#  957: nan,
#  958: nan,
#  959: nan,
#  960: nan,
#  961: nan,
#  962: nan,
#  963: nan,
#  964: nan,
#  965: nan,
#  966: nan,
#  967: nan,
#  968: nan,
#  969: nan,
#  970: nan,
#  971: nan,
#  972: [{'stringdb_link_to': 'ENSG00000091140',
#    'Ensembl': 'ENSP00000205402',
#    'score': 0.632,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000100412',
#    'Ensembl': 'ENSP00000216254',
#    'score': 0.652,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110435',
#    'Ensembl': 'ENSP00000227868',
#    'score': 0.513,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111669',
#    'Ensembl': 'ENSP00000229270',
#    'score': 0.405,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000109929',
#    'Ensembl': 'ENSP00000264027',
#    'score': 0.559,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000165672',
#    'Ensembl': 'ENSP00000298510',
#    'score': 0.416,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000067225',
#    'Ensembl': 'ENSP00000320171',
#    'score': 0.419,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000083123',
#    'Ensembl': 'ENSP00000318351',
#    'score': 0.42,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000148672',
#    'Ensembl': 'ENSP00000277865',
#    'score': 0.423,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000204356',
#    'Ensembl': 'ENSP00000364578',
#    'score': 0.451,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000107897',
#    'Ensembl': 'ENSP00000365049',
#    'score': 0.475,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000175198',
#    'Ensembl': 'ENSP00000365462',
#    'score': 0.487,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000168291',
#    'Ensembl': 'ENSP00000307241',
#    'score': 0.491,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000151093',
#    'Ensembl': 'ENSP00000280701',
#    'score': 0.492,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000157184',
#    'Ensembl': 'ENSP00000360541',
#    'score': 0.493,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000182054',
#    'Ensembl': 'ENSP00000331897',
#    'score': 0.517,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.565,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000171503',
#    'Ensembl': 'ENSP00000426638',
#    'score': 0.575,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000112357',
#    'Ensembl': 'ENSP00000315680',
#    'score': 0.682,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000093144',
#    'Ensembl': 'ENSP00000436585',
#    'score': 0.712,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000148090',
#    'Ensembl': 'ENSP00000364883',
#    'score': 0.719,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000116171',
#    'Ensembl': 'ENSP00000360569',
#    'score': 0.724,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152904',
#    'Ensembl': 'ENSP00000282841',
#    'score': 0.735,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198130',
#    'Ensembl': 'ENSP00000352706',
#    'score': 0.751,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163344',
#    'Ensembl': 'ENSP00000357452',
#    'score': 0.758,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000140374',
#    'Ensembl': 'ENSP00000452762',
#    'score': 0.821,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000119689',
#    'Ensembl': 'ENSP00000335304',
#    'score': 0.847,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000127884',
#    'Ensembl': 'ENSP00000357535',
#    'score': 0.85,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000172340',
#    'Ensembl': 'ENSP00000419325',
#    'score': 0.867,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000136143',
#    'Ensembl': 'ENSP00000494360',
#    'score': 0.883,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.907,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000081760',
#    'Ensembl': 'ENSP00000324842',
#    'score': 0.962,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000196177',
#    'Ensembl': 'ENSP00000357873',
#    'score': 0.968,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117305',
#    'Ensembl': 'ENSP00000363614',
#    'score': 0.972,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  973: nan,
#  974: nan,
#  975: nan,
#  976: nan,
#  977: nan,
#  978: nan,
#  979: nan,
#  980: nan,
#  981: nan,
#  982: nan,
#  983: nan,
#  984: nan,
#  985: nan,
#  986: nan,
#  987: nan,
#  988: nan,
#  989: nan,
#  990: nan,
#  991: nan,
#  992: nan,
#  993: nan,
#  994: nan,
#  995: nan,
#  996: nan,
#  997: nan,
#  998: nan,
#  999: nan,
#  ...}

# %%
filename_human = "data/human/combined_df.pkl"

combined_df.to_pickle(filename_human)

# %% [markdown]
# ### graph

# %%
filename_human = "data/human/combined_df.pkl"
with open(filename_human, "rb") as f:
    combined_df = pickle.load(f)

# %%
# Extract all 'NCBI.GeneID.TF' values into a single list
ncbi_gene_ids = (
    combined_df["its_tf"]
    .apply(lambda x: [d["NCBI.GeneID.TF"] for d in x] if isinstance(x, list) else [])
    .explode()
    .dropna()
    .unique()
    .tolist()
)

len(ncbi_gene_ids)
# Out:
# 997

# %%
combined_df_tf = combined_df[combined_df["target"].isin(ncbi_gene_ids)]
combined_df_sig = combined_df[combined_df["padj_dea"] <= 0.05]
combined_df_sig = combined_df_sig[~combined_df_sig["target"].isin(ncbi_gene_ids)]
combined_df_sig.shape
# Out:
# (537, 30)

# %%
combined_df_tf_sig = pd.concat([combined_df_sig, combined_df_tf], axis=0, ignore_index=True)
combined_df_tf_sig.shape
# Out:
# (1535, 30)

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"] == "COQ10A"]["its_tf"].apply(
    lambda x: isinstance(x, list)
)
# Out:
# 207    True
# Name: its_tf, dtype: bool

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"] == "COQ10A"]["its_tf"].to_dict()
# Out:
# {207: [{'NCBI.GeneID.TF': '112398',
#    'Ensembl.GeneID.TF': 'ENSG00000269858',
#    'Name.TF': 'EGLN2',
#    'UniprotID.TF': 'Q96KS0',
#    'TF.TFLink.ortho': 'Mm:Q91YE2;Rn:Q6AYU4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '11091',
#    'Ensembl.GeneID.TF': 'ENSG00000196363',
#    'Name.TF': 'WDR5',
#    'UniprotID.TF': 'P61964',
#    'TF.TFLink.ortho': 'Dm:Q9V3J8;Dr:Q7ZTX2;Mm:P61965',
#    'TF.nonTFLink.ortho': 'Rn:Q498M4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1024',
#    'Ensembl.GeneID.TF': 'ENSG00000132964',
#    'Name.TF': 'CDK8',
#    'UniprotID.TF': 'P49336',
#    'TF.TFLink.ortho': 'Dm:Q9VT57;Dr:A8E4S2;Mm:Q8R3L8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4149',
#    'Ensembl.GeneID.TF': 'ENSG00000125952',
#    'Name.TF': 'MAX',
#    'UniprotID.TF': 'P61244',
#    'TF.TFLink.ortho': 'Ce:G5EEH5;Dm:P91664;Mm:P28574;Rn:P52164',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '94039',
#    'Ensembl.GeneID.TF': 'ENSG00000181896',
#    'Name.TF': 'ZNF101',
#    'UniprotID.TF': 'Q8IZC7',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '64763',
#    'Ensembl.GeneID.TF': 'ENSG00000105732',
#    'Name.TF': 'ZNF574',
#    'UniprotID.TF': 'Q6ZN55',
#    'TF.TFLink.ortho': 'Mm:Q8BY46;Rn:Q504L7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6613',
#    'Ensembl.GeneID.TF': 'ENSG00000188612',
#    'Name.TF': 'SUMO2',
#    'UniprotID.TF': 'P61956',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23361',
#    'Ensembl.GeneID.TF': 'ENSG00000102870',
#    'Name.TF': 'ZNF629',
#    'UniprotID.TF': 'Q9UEG4',
#    'TF.TFLink.ortho': 'Mm:Q6A085',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55145',
#    'Ensembl.GeneID.TF': 'ENSG00000131931',
#    'Name.TF': 'THAP1',
#    'UniprotID.TF': 'Q9NVV9',
#    'TF.TFLink.ortho': 'Dr:Q1JPT7;Mm:Q8CHW1;Rn:Q5U208',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '657',
#    'Ensembl.GeneID.TF': 'ENSG00000107779',
#    'Name.TF': 'BMPR1A',
#    'UniprotID.TF': 'P36894',
#    'TF.TFLink.ortho': 'Mm:P36895;Rn:Q78EA7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4841',
#    'Ensembl.GeneID.TF': 'ENSG00000147140',
#    'Name.TF': 'NONO',
#    'UniprotID.TF': 'Q15233',
#    'TF.TFLink.ortho': 'Dr:Q802Z5;Mm:Q99K48;Rn:Q5FVM4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27107',
#    'Ensembl.GeneID.TF': 'ENSG00000066422',
#    'Name.TF': 'ZBTB11',
#    'UniprotID.TF': 'O95625',
#    'TF.TFLink.ortho': 'Dr:F1RAC1;Mm:G5E8B9;Rn:D3ZDP9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57504',
#    'Ensembl.GeneID.TF': 'ENSG00000057935',
#    'Name.TF': 'MTA3',
#    'UniprotID.TF': 'Q9BTC8',
#    'TF.TFLink.ortho': 'Mm:Q924K8;Rn:A0A0G2JTK6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4790',
#    'Ensembl.GeneID.TF': 'ENSG00000109320',
#    'Name.TF': 'NFKB1',
#    'UniprotID.TF': 'P19838',
#    'TF.TFLink.ortho': 'Dm:Q94527;Mm:P25799;Rn:F1LQH2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3611',
#    'Ensembl.GeneID.TF': 'ENSG00000166333',
#    'Name.TF': 'ILK',
#    'UniprotID.TF': 'Q13418',
#    'TF.TFLink.ortho': 'Ce:Q9TZC4;Dm:Q9V400;Dr:Q6PHD6;Mm:O55222;Rn:Q99J82',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7936',
#    'Ensembl.GeneID.TF': 'ENSG00000204356',
#    'Name.TF': 'NELFE',
#    'UniprotID.TF': 'P18615',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10614',
#    'Ensembl.GeneID.TF': 'ENSG00000186834',
#    'Name.TF': 'HEXIM1',
#    'UniprotID.TF': 'O94992',
#    'TF.TFLink.ortho': 'Mm:Q8R409;Rn:Q5M9G1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4928',
#    'Ensembl.GeneID.TF': 'ENSG00000110713',
#    'Name.TF': 'NUP98',
#    'UniprotID.TF': 'P52948',
#    'TF.TFLink.ortho': 'Ce:G5EEH9;Rn:P49793;Sc:P49687',
#    'TF.nonTFLink.ortho': 'Mm:A0A1B0GSX7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23133',
#    'Ensembl.GeneID.TF': 'ENSG00000172943',
#    'Name.TF': 'PHF8',
#    'UniprotID.TF': 'Q9UPP1',
#    'TF.TFLink.ortho': 'Dr:P0CH95;Mm:Q80TJ7;Rn:D4AD31',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6659',
#    'Ensembl.GeneID.TF': 'ENSG00000124766',
#    'Name.TF': 'SOX4',
#    'UniprotID.TF': 'Q06945',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IQD2;Mm:Q06831',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4779',
#    'Ensembl.GeneID.TF': 'ENSG00000082641',
#    'Name.TF': 'NFE2L1',
#    'UniprotID.TF': 'Q14494',
#    'TF.TFLink.ortho': 'Dr:U3JAR7;Mm:Q61985;Rn:D4A349',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6651',
#    'Ensembl.GeneID.TF': 'ENSG00000159140',
#    'Name.TF': 'SON',
#    'UniprotID.TF': 'P18583',
#    'TF.TFLink.ortho': 'Mm:Q9QX47;Rn:F1MAQ7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5929',
#    'Ensembl.GeneID.TF': 'ENSG00000117222',
#    'Name.TF': 'RBBP5',
#    'UniprotID.TF': 'Q15291',
#    'TF.TFLink.ortho': 'Ce:Q09309;Dm:Q9VPH8;Mm:Q8BX09;Rn:D3ZC01;Sc:P39706',
#    'TF.nonTFLink.ortho': 'Dr:F1QST7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23028',
#    'Ensembl.GeneID.TF': 'ENSG00000004487',
#    'Name.TF': 'KDM1A',
#    'UniprotID.TF': 'O60341',
#    'TF.TFLink.ortho': 'Dm:Q9VW97;Dr:F6NIA2;Mm:Q6ZQ88;Rn:F1MA31',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9314',
#    'Ensembl.GeneID.TF': 'ENSG00000136826',
#    'Name.TF': 'KLF4',
#    'UniprotID.TF': 'O43474',
#    'TF.TFLink.ortho': 'Mm:Q60793;Rn:Q923V7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4199',
#    'Ensembl.GeneID.TF': 'ENSG00000065833',
#    'Name.TF': 'ME1',
#    'UniprotID.TF': 'P48163',
#    'TF.TFLink.ortho': 'Mm:P06801;Rn:A0A0G2K1S6',
#    'TF.nonTFLink.ortho': 'Dr:F1QU54',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '58486',
#    'Ensembl.GeneID.TF': 'ENSG00000236287',
#    'Name.TF': 'ZBED5',
#    'UniprotID.TF': 'Q49AG3',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23064',
#    'Ensembl.GeneID.TF': 'ENSG00000107290',
#    'Name.TF': 'SETX',
#    'UniprotID.TF': 'Q7Z333',
#    'TF.TFLink.ortho': 'Dr:E7FBJ2;Mm:A2AKX3',
#    'TF.nonTFLink.ortho': 'Rn:D4AEB3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3054',
#    'Ensembl.GeneID.TF': 'ENSG00000172534',
#    'Name.TF': 'HCFC1',
#    'UniprotID.TF': 'P51610',
#    'TF.TFLink.ortho': 'Dr:F1Q750;Dr:A8WIP5;Mm:Q61191;Rn:D3ZN95',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7756',
#    'Ensembl.GeneID.TF': 'ENSG00000010244',
#    'Name.TF': 'ZNF207',
#    'UniprotID.TF': 'O43670',
#    'TF.TFLink.ortho': 'Mm:Q9JMD0;Rn:Q498C9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10781',
#    'Ensembl.GeneID.TF': 'ENSG00000174652',
#    'Name.TF': 'ZNF266',
#    'UniprotID.TF': 'Q14584',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6046',
#    'Ensembl.GeneID.TF': 'ENSG00000204256',
#    'Name.TF': 'BRD2',
#    'UniprotID.TF': 'P25440',
#    'TF.TFLink.ortho': 'Mm:Q7JJ13',
#    'TF.nonTFLink.ortho': 'Dr:Q1LWX7;Rn:Q6MGA9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57459',
#    'Ensembl.GeneID.TF': 'ENSG00000143614',
#    'Name.TF': 'GATAD2B',
#    'UniprotID.TF': 'Q8WXI9',
#    'TF.TFLink.ortho': 'Mm:Q8VHR5;Rn:Q4V8E1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9682',
#    'Ensembl.GeneID.TF': 'ENSG00000066135',
#    'Name.TF': 'KDM4A',
#    'UniprotID.TF': 'O75164',
#    'TF.TFLink.ortho': 'Mm:Q8BW72;Rn:A0A0G2K5I7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10155',
#    'Ensembl.GeneID.TF': 'ENSG00000130726',
#    'Name.TF': 'TRIM28',
#    'UniprotID.TF': 'Q13263',
#    'TF.TFLink.ortho': 'Mm:Q62318;Rn:O08629',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1997',
#    'Ensembl.GeneID.TF': 'ENSG00000120690',
#    'Name.TF': 'ELF1',
#    'UniprotID.TF': 'P32519',
#    'TF.TFLink.ortho': 'Dr:E7F1J0;Mm:Q60775',
#    'TF.nonTFLink.ortho': 'Rn:G3V9V2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '894',
#    'Ensembl.GeneID.TF': 'ENSG00000118971',
#    'Name.TF': 'CCND2',
#    'UniprotID.TF': 'P30279',
#    'TF.TFLink.ortho': 'Dr:F1R9R4;Mm:P30280;Rn:G3V8M9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51157',
#    'Ensembl.GeneID.TF': 'ENSG00000213015',
#    'Name.TF': 'ZNF580',
#    'UniprotID.TF': 'Q9UK33',
#    'TF.TFLink.ortho': 'Mm:Q9DB38',
#    'TF.nonTFLink.ortho': 'Rn:D4A235',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2736',
#    'Ensembl.GeneID.TF': 'ENSG00000074047',
#    'Name.TF': 'GLI2',
#    'UniprotID.TF': 'P10070',
#    'TF.TFLink.ortho': 'Mm:Q0VGT2;Rn:F1M2B7',
#    'TF.nonTFLink.ortho': 'Dr:B0S6T1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23462',
#    'Ensembl.GeneID.TF': 'ENSG00000164683',
#    'Name.TF': 'HEY1',
#    'UniprotID.TF': 'Q9Y5J3',
#    'TF.TFLink.ortho': 'Dr:Q8AXV6;Rn:D3ZNI5',
#    'TF.nonTFLink.ortho': 'Mm:Q9QUM5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '25799',
#    'Ensembl.GeneID.TF': 'ENSG00000083812',
#    'Name.TF': 'ZNF324',
#    'UniprotID.TF': 'O75467',
#    'TF.TFLink.ortho': 'Mm:Q78F42;Rn:D3ZB44',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51780',
#    'Ensembl.GeneID.TF': 'ENSG00000120733',
#    'Name.TF': 'KDM3B',
#    'UniprotID.TF': 'Q7LBC6',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IDZ5;Mm:B9EKS2;Rn:M0RDF1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '367',
#    'Ensembl.GeneID.TF': 'ENSG00000169083',
#    'Name.TF': 'AR',
#    'UniprotID.TF': 'P10275',
#    'TF.TFLink.ortho': 'Mm:P19091;Rn:A0A0G2JSI8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8626',
#    'Ensembl.GeneID.TF': 'ENSG00000073282',
#    'Name.TF': 'TP63',
#    'UniprotID.TF': 'Q9H3D4',
#    'TF.TFLink.ortho': 'Mm:O88898;Rn:Q9JJP6',
#    'TF.nonTFLink.ortho': 'Dr:F1QLJ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8050',
#    'Ensembl.GeneID.TF': 'ENSG00000110435',
#    'Name.TF': 'PDHX',
#    'UniprotID.TF': 'O00330',
#    'TF.TFLink.ortho': 'Mm:Q8BKZ9',
#    'TF.nonTFLink.ortho': 'Dr:Q6NW45;Rn:A0A0G2JZH8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2000',
#    'Ensembl.GeneID.TF': 'ENSG00000102034',
#    'Name.TF': 'ELF4',
#    'UniprotID.TF': 'Q99607',
#    'TF.TFLink.ortho': 'Mm:Q9Z2U4',
#    'TF.nonTFLink.ortho': 'Rn:D3ZWM8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10127',
#    'Ensembl.GeneID.TF': 'ENSG00000006194',
#    'Name.TF': 'ZNF263',
#    'UniprotID.TF': 'O14978',
#    'TF.TFLink.ortho': 'Mm:Q8CF60;Rn:D3ZQ68',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '90993',
#    'Ensembl.GeneID.TF': 'ENSG00000157613',
#    'Name.TF': 'CREB3L1',
#    'UniprotID.TF': 'Q96BA8',
#    'TF.TFLink.ortho': 'Mm:A0A0R4J082;Rn:Q66HA2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4335',
#    'Ensembl.GeneID.TF': 'ENSG00000070444',
#    'Name.TF': 'MNT',
#    'UniprotID.TF': 'Q99583',
#    'TF.TFLink.ortho': 'Mm:O08789;Rn:A0A0U1RRY7',
#    'TF.nonTFLink.ortho': 'Dr:F1QBK5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10346',
#    'Ensembl.GeneID.TF': 'ENSG00000132274',
#    'Name.TF': 'TRIM22',
#    'UniprotID.TF': 'Q8IYM9',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9328',
#    'Ensembl.GeneID.TF': 'ENSG00000148308',
#    'Name.TF': 'GTF3C5',
#    'UniprotID.TF': 'Q9Y5Q8',
#    'TF.TFLink.ortho': 'Ce:Q22093;Dm:Q9VIZ2;Dr:E7EZ29;Mm:Q8R2T8;Rn:A1L1K6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6774',
#    'Ensembl.GeneID.TF': 'ENSG00000168610',
#    'Name.TF': 'STAT3',
#    'UniprotID.TF': 'P40763',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10625',
#    'Ensembl.GeneID.TF': 'ENSG00000116679',
#    'Name.TF': 'IVNS1ABP',
#    'UniprotID.TF': 'Q9Y6Y0',
#    'TF.TFLink.ortho': 'Ce:Q21854;Dr:Q5RG82;Mm:Q920Q8;Rn:A0A0G2K427',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '49854',
#    'Ensembl.GeneID.TF': 'ENSG00000173276',
#    'Name.TF': 'ZBTB21',
#    'UniprotID.TF': 'Q9ULJ3',
#    'TF.TFLink.ortho': 'Mm:E9Q444;Rn:D3ZVF2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5934',
#    'Ensembl.GeneID.TF': 'ENSG00000103479',
#    'Name.TF': 'RBL2',
#    'UniprotID.TF': 'Q08999',
#    'TF.TFLink.ortho': 'Dr:E7FDM3;Mm:Q64700;Rn:G3V7P7',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6599',
#    'Ensembl.GeneID.TF': 'ENSG00000173473',
#    'Name.TF': 'SMARCC1',
#    'UniprotID.TF': 'Q92922',
#    'TF.TFLink.ortho': 'Mm:P97496;Rn:A0A0G2K9D6',
#    'TF.nonTFLink.ortho': 'Dr:F1Q9K1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7528',
#    'Ensembl.GeneID.TF': 'ENSG00000100811',
#    'Name.TF': 'YY1',
#    'UniprotID.TF': 'P25490',
#    'TF.TFLink.ortho': 'Mm:Q00899;Rn:Q8CHJ4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55553',
#    'Ensembl.GeneID.TF': 'ENSG00000110693',
#    'Name.TF': 'SOX6',
#    'UniprotID.TF': 'P35712',
#    'TF.TFLink.ortho': 'Mm:P40645',
#    'TF.nonTFLink.ortho': 'Dr:A0A1D5NSY8;Rn:A0A6R0V8A0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3725',
#    'Ensembl.GeneID.TF': 'ENSG00000177606',
#    'Name.TF': 'JUN',
#    'UniprotID.TF': 'P05412',
#    'TF.TFLink.ortho': 'Dr:Q6NZT5;Mm:P05627;Rn:P17325',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9324',
#    'Ensembl.GeneID.TF': 'ENSG00000118418',
#    'Name.TF': 'HMGN3',
#    'UniprotID.TF': 'Q15651',
#    'TF.TFLink.ortho': 'Mm:Q9DCB1',
#    'TF.nonTFLink.ortho': 'Rn:M0R953',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9831',
#    'Ensembl.GeneID.TF': 'ENSG00000183309',
#    'Name.TF': 'ZNF623',
#    'UniprotID.TF': 'O75123',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '862',
#    'Ensembl.GeneID.TF': 'ENSG00000079102',
#    'Name.TF': 'RUNX1T1',
#    'UniprotID.TF': 'Q06455',
#    'TF.TFLink.ortho': 'Mm:Q61909;Rn:A0A0G2K0G0',
#    'TF.nonTFLink.ortho': 'Dr:Q1L8K2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6879',
#    'Ensembl.GeneID.TF': 'ENSG00000178913',
#    'Name.TF': 'TAF7',
#    'UniprotID.TF': 'Q15545',
#    'TF.TFLink.ortho': 'Dr:Q8JHG4;Mm:Q9R1C0;Rn:B0BN78',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2959',
#    'Ensembl.GeneID.TF': 'ENSG00000137947',
#    'Name.TF': 'GTF2B',
#    'UniprotID.TF': 'Q00403',
#    'TF.TFLink.ortho': 'Ce:O16991;Dm:P29052;Dr:A0A0R4IRB5;Mm:P62915;Rn:A0A0G2JWZ8;Sc:P29055',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7182',
#    'Ensembl.GeneID.TF': 'ENSG00000177463',
#    'Name.TF': 'NR2C2',
#    'UniprotID.TF': 'P49116',
#    'TF.TFLink.ortho': 'Dr:F6PDV8;Mm:P49117;Rn:G3V7F5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4004',
#    'Ensembl.GeneID.TF': 'ENSG00000166407',
#    'Name.TF': 'LMO1',
#    'UniprotID.TF': 'P25800',
#    'TF.TFLink.ortho': 'Dm:Q8IRC7;Dr:Q8JFQ2;Mm:Q924W9;Rn:A0A0G2K422',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4780',
#    'Ensembl.GeneID.TF': 'ENSG00000116044',
#    'Name.TF': 'NFE2L2',
#    'UniprotID.TF': 'Q16236',
#    'TF.TFLink.ortho': 'Dr:Q7ZVI2;Mm:Q60795;Rn:O54968',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '283933',
#    'Ensembl.GeneID.TF': 'ENSG00000176723',
#    'Name.TF': 'ZNF843',
#    'UniprotID.TF': 'Q8N446',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '54897',
#    'Ensembl.GeneID.TF': 'ENSG00000130940',
#    'Name.TF': 'CASZ1',
#    'UniprotID.TF': 'Q86V15',
#    'TF.TFLink.ortho': 'Mm:Q9CWL2;Rn:F1M0M0',
#    'TF.nonTFLink.ortho': 'Dr:E9QCI7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6935',
#    'Ensembl.GeneID.TF': 'ENSG00000148516',
#    'Name.TF': 'ZEB1',
#    'UniprotID.TF': 'P37275',
#    'TF.TFLink.ortho': 'Dr:F1QPM7;Mm:Q64318;Rn:F8WG35',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23466',
#    'Ensembl.GeneID.TF': 'ENSG00000183741',
#    'Name.TF': 'CBX6',
#    'UniprotID.TF': 'O95503',
#    'TF.TFLink.ortho': 'Dr:X1WBY5;Mm:Q9DBY5;Rn:E9PT11',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '83463',
#    'Ensembl.GeneID.TF': 'ENSG00000213347',
#    'Name.TF': 'MXD3',
#    'UniprotID.TF': 'Q9BW11',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IMG7;Mm:Q80US8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4089',
#    'Ensembl.GeneID.TF': 'ENSG00000141646',
#    'Name.TF': 'SMAD4',
#    'UniprotID.TF': 'Q13485',
#    'TF.TFLink.ortho': 'Mm:P97471;Rn:A0A0G2K970',
#    'TF.nonTFLink.ortho': 'Dm:Q8IMG6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5970',
#    'Ensembl.GeneID.TF': 'ENSG00000173039',
#    'Name.TF': 'RELA',
#    'UniprotID.TF': 'Q04206',
#    'TF.TFLink.ortho': 'Mm:Q04207;Rn:Q7TQN4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '54880',
#    'Ensembl.GeneID.TF': 'ENSG00000183337',
#    'Name.TF': 'BCOR',
#    'UniprotID.TF': 'Q6W2J9',
#    'TF.TFLink.ortho': 'Mm:Q8CGN4;Rn:D4A2J9',
#    'TF.nonTFLink.ortho': 'Dr:Q6W2J8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55818',
#    'Ensembl.GeneID.TF': 'ENSG00000115548',
#    'Name.TF': 'KDM3A',
#    'UniprotID.TF': 'Q9Y4C1',
#    'TF.TFLink.ortho': 'Mm:Q6PCM1;Rn:A0A0G2K220',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23090',
#    'Ensembl.GeneID.TF': 'ENSG00000102935',
#    'Name.TF': 'ZNF423',
#    'UniprotID.TF': 'Q2M1K9',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84844',
#    'Ensembl.GeneID.TF': 'ENSG00000100410',
#    'Name.TF': 'PHF5A',
#    'UniprotID.TF': 'Q7RTV0',
#    'TF.TFLink.ortho': 'Dm:Q9VMC8;Dr:Q6YMR2;Mm:P83870;Rn:P83871;Sc:Q06835',
#    'TF.nonTFLink.ortho': 'Ce:G5EBY6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8553',
#    'Ensembl.GeneID.TF': 'ENSG00000134107',
#    'Name.TF': 'BHLHE40',
#    'UniprotID.TF': 'O14503',
#    'TF.TFLink.ortho': 'Dr:Q6NY50;Mm:O35185;Rn:Q76JQ4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2308',
#    'Ensembl.GeneID.TF': 'ENSG00000150907',
#    'Name.TF': 'FOXO1',
#    'UniprotID.TF': 'Q12778',
#    'TF.TFLink.ortho': 'Dr:A3RK74;Mm:Q9R1E0;Rn:G3V7R4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '687',
#    'Ensembl.GeneID.TF': 'ENSG00000119138',
#    'Name.TF': 'KLF9',
#    'UniprotID.TF': 'Q13886',
#    'TF.TFLink.ortho': 'Mm:Q8CEC4;Rn:G3V7U5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5927',
#    'Ensembl.GeneID.TF': 'ENSG00000073614',
#    'Name.TF': 'KDM5A',
#    'UniprotID.TF': 'P29375',
#    'TF.TFLink.ortho': 'Mm:Q3UXZ9;Rn:A0A0G2JTU9;Sc:Q03214',
#    'TF.nonTFLink.ortho': 'Dr:A0A0G2KR99',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10765',
#    'Ensembl.GeneID.TF': 'ENSG00000117139',
#    'Name.TF': 'KDM5B',
#    'UniprotID.TF': 'Q9UGL1',
#    'TF.TFLink.ortho': 'Mm:Q80Y84;Rn:A0A0G2K6G9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8243',
#    'Ensembl.GeneID.TF': 'ENSG00000072501',
#    'Name.TF': 'SMC1A',
#    'UniprotID.TF': 'Q14683',
#    'TF.TFLink.ortho': 'Dm:Q9VCD8;Dr:Q6DRM9;Dr:E7F0X6;Mm:Q9CU62;Rn:F1LSS1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '90874',
#    'Ensembl.GeneID.TF': 'ENSG00000143067',
#    'Name.TF': 'ZNF697',
#    'UniprotID.TF': 'Q5TEC3',
#    'TF.TFLink.ortho': 'Mm:G5E8C0',
#    'TF.nonTFLink.ortho': 'Rn:D4AA20',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51341',
#    'Ensembl.GeneID.TF': 'ENSG00000178951',
#    'Name.TF': 'ZBTB7A',
#    'UniprotID.TF': 'O95365',
#    'TF.TFLink.ortho': 'Mm:O88939;Rn:G3V8P6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4297',
#    'Ensembl.GeneID.TF': 'ENSG00000118058',
#    'Name.TF': 'KMT2A',
#    'UniprotID.TF': 'Q03164',
#    'TF.TFLink.ortho': 'Dr:F1QL52;Mm:P55200',
#    'TF.nonTFLink.ortho': 'Rn:F1M0L3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7520',
#    'Ensembl.GeneID.TF': 'ENSG00000079246',
#    'Name.TF': 'XRCC5',
#    'UniprotID.TF': 'P13010',
#    'TF.TFLink.ortho': 'Dm:Q9I7M8;Mm:P27641;Rn:G3V817',
#    'TF.nonTFLink.ortho': 'Dr:A0A0R4IB13',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '54815',
#    'Ensembl.GeneID.TF': 'ENSG00000167491',
#    'Name.TF': 'GATAD2A',
#    'UniprotID.TF': 'Q86YP4',
#    'TF.TFLink.ortho': 'Rn:G3V8R7',
#    'TF.nonTFLink.ortho': 'Dr:Q1LVI0;Mm:E9QMN5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5914',
#    'Ensembl.GeneID.TF': 'ENSG00000131759',
#    'Name.TF': 'RARA',
#    'UniprotID.TF': 'P10276',
#    'TF.TFLink.ortho': 'Mm:P11416;Rn:A0A0G2JW78',
#    'TF.nonTFLink.ortho': 'Dr:T2DKU4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6015',
#    'Ensembl.GeneID.TF': 'ENSG00000204227',
#    'Name.TF': 'RING1',
#    'UniprotID.TF': 'Q06587',
#    'TF.TFLink.ortho': 'Mm:O35730;Rn:Q6MGB6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4800',
#    'Ensembl.GeneID.TF': 'ENSG00000001167',
#    'Name.TF': 'NFYA',
#    'UniprotID.TF': 'P23511',
#    'TF.TFLink.ortho': 'Mm:P23708',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2KB97',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51621',
#    'Ensembl.GeneID.TF': 'ENSG00000169926',
#    'Name.TF': 'KLF13',
#    'UniprotID.TF': 'Q9Y2Y9',
#    'TF.TFLink.ortho': 'Dr:F1RBH0;Mm:Q9JJZ6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2101',
#    'Ensembl.GeneID.TF': 'ENSG00000173153',
#    'Name.TF': 'ESRRA',
#    'UniprotID.TF': 'P11474',
#    'TF.TFLink.ortho': 'Mm:O08580;Rn:Q5QJV7',
#    'TF.nonTFLink.ortho': 'Dr:F1QQS8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '126375',
#    'Ensembl.GeneID.TF': 'ENSG00000180884',
#    'Name.TF': 'ZNF792',
#    'UniprotID.TF': 'Q3KQV3',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1385',
#    'Ensembl.GeneID.TF': 'ENSG00000118260',
#    'Name.TF': 'CREB1',
#    'UniprotID.TF': 'P16220',
#    'TF.TFLink.ortho': 'Dr:Q803K8;Mm:Q01147;Rn:P15337',
#    'TF.nonTFLink.ortho': 'Dr:E9QHG0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '54989',
#    'Ensembl.GeneID.TF': 'ENSG00000198146',
#    'Name.TF': 'ZNF770',
#    'UniprotID.TF': 'Q6IQ21',
#    'TF.TFLink.ortho': 'Mm:Q8BIQ8',
#    'TF.nonTFLink.ortho': 'Rn:F1M076',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1655',
#    'Ensembl.GeneID.TF': 'ENSG00000108654',
#    'Name.TF': 'DDX5',
#    'UniprotID.TF': 'P17844',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2004',
#    'Ensembl.GeneID.TF': 'ENSG00000111145',
#    'Name.TF': 'ELK3',
#    'UniprotID.TF': 'P41970',
#    'TF.TFLink.ortho': 'Dr:F1QIB0;Mm:P41971;Rn:D4A9V6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '865',
#    'Ensembl.GeneID.TF': 'ENSG00000067955',
#    'Name.TF': 'CBFB',
#    'UniprotID.TF': 'Q13951',
#    'TF.TFLink.ortho': 'Dm:Q24040;Dm:Q24039;Mm:Q08024;Rn:Q66HA7',
#    'TF.nonTFLink.ortho': 'Dr:A0A0B4P506',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9869',
#    'Ensembl.GeneID.TF': 'ENSG00000143379',
#    'Name.TF': 'SETDB1',
#    'UniprotID.TF': 'Q15047',
#    'TF.TFLink.ortho': 'Rn:A0A0G2K5A7',
#    'TF.nonTFLink.ortho': 'Dr:A0A0R4IPA3;Mm:D3YYC3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '466',
#    'Ensembl.GeneID.TF': 'ENSG00000123268',
#    'Name.TF': 'ATF1',
#    'UniprotID.TF': 'P18846',
#    'TF.TFLink.ortho': 'Dr:Q7T351;Mm:P81269;Rn:F7FD47',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7584',
#    'Ensembl.GeneID.TF': 'ENSG00000169981',
#    'Name.TF': 'ZNF35',
#    'UniprotID.TF': 'P13682',
#    'TF.TFLink.ortho': 'Mm:G3X9I0;Rn:Q5M881',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7014',
#    'Ensembl.GeneID.TF': 'ENSG00000132604',
#    'Name.TF': 'TERF2',
#    'UniprotID.TF': 'Q15554',
#    'TF.TFLink.ortho': 'Dr:F1QRC8;Rn:D3ZJF7',
#    'TF.nonTFLink.ortho': 'Mm:D3YZ08',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '221037',
#    'Ensembl.GeneID.TF': 'ENSG00000171988',
#    'Name.TF': 'JMJD1C',
#    'UniprotID.TF': 'Q15652',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IYD2;Rn:F1LMK8',
#    'TF.nonTFLink.ortho': 'Mm:A0A0A0MQ98',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7874',
#    'Ensembl.GeneID.TF': 'ENSG00000187555',
#    'Name.TF': 'USP7',
#    'UniprotID.TF': 'Q93009',
#    'TF.TFLink.ortho': 'Dm:Q9VYQ8;Rn:F1LM09',
#    'TF.nonTFLink.ortho': 'Ce:N1NTD8;Dr:I3ISS5;Mm:F8VPX1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '81608',
#    'Ensembl.GeneID.TF': 'ENSG00000145216',
#    'Name.TF': 'FIP1L1',
#    'UniprotID.TF': 'Q6UN15',
#    'TF.TFLink.ortho': 'Dm:Q9VN31;Mm:Q9D824',
#    'TF.nonTFLink.ortho': 'Ce:O16293;Dr:A7MCF0;Rn:A0A0G2K376',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2005',
#    'Ensembl.GeneID.TF': 'ENSG00000158711',
#    'Name.TF': 'ELK4',
#    'UniprotID.TF': 'P28324',
#    'TF.TFLink.ortho': 'Dr:F1R0K1;Mm:P41158;Rn:B4F7D4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10274',
#    'Ensembl.GeneID.TF': 'ENSG00000118007',
#    'Name.TF': 'STAG1',
#    'UniprotID.TF': 'Q8WVM7',
#    'TF.TFLink.ortho': 'Ce:Q19555;Dm:Q9VM62;Dr:E7FC33;Dr:F1QNA7;Mm:Q9D3E6;Rn:A0A0G2K9G6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1387',
#    'Ensembl.GeneID.TF': 'ENSG00000005339',
#    'Name.TF': 'CREBBP',
#    'UniprotID.TF': 'Q92793',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IPF2;Rn:F1M9G7',
#    'TF.nonTFLink.ortho': 'Mm:F8VPR5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1054',
#    'Ensembl.GeneID.TF': 'ENSG00000153879',
#    'Name.TF': 'CEBPG',
#    'UniprotID.TF': 'P53567',
#    'TF.TFLink.ortho': 'Dr:Q8UVY8;Mm:P53568;Rn:P26801',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '338328',
#    'Ensembl.GeneID.TF': 'ENSG00000277494',
#    'Name.TF': 'GPIHBP1',
#    'UniprotID.TF': 'Q8IV16',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1871',
#    'Ensembl.GeneID.TF': 'ENSG00000112242',
#    'Name.TF': 'E2F3',
#    'UniprotID.TF': 'O00716',
#    'TF.TFLink.ortho': 'Rn:A0A0G2K0V6',
#    'TF.nonTFLink.ortho': 'Mm:A0A1Y7VML1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1879',
#    'Ensembl.GeneID.TF': 'ENSG00000164330',
#    'Name.TF': 'EBF1',
#    'UniprotID.TF': 'Q9UH73',
#    'TF.TFLink.ortho': 'Dr:A0A0R4IWI1;Mm:Q07802;Rn:Q63398',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6907',
#    'Ensembl.GeneID.TF': 'ENSG00000101849',
#    'Name.TF': 'TBL1X',
#    'UniprotID.TF': 'O60907',
#    'TF.TFLink.ortho': 'Dr:A2RUX0;Mm:Q9QXE7;Rn:G3V6G5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9774',
#    'Ensembl.GeneID.TF': 'ENSG00000029363',
#    'Name.TF': 'BCLAF1',
#    'UniprotID.TF': 'Q9NYF8',
#    'TF.TFLink.ortho': 'Mm:Q8K019',
#    'TF.nonTFLink.ortho': 'Rn:B1WC16',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9849',
#    'Ensembl.GeneID.TF': 'ENSG00000177853',
#    'Name.TF': 'ZNF518A',
#    'UniprotID.TF': 'Q6AHZ1',
#    'TF.TFLink.ortho': 'Dr:U3JAE4;Mm:B2RRF6;Rn:Q499R0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55869',
#    'Ensembl.GeneID.TF': 'ENSG00000147099',
#    'Name.TF': 'HDAC8',
#    'UniprotID.TF': 'Q9BY41',
#    'TF.TFLink.ortho': 'Dr:F1R9J0;Mm:Q8VH37;Rn:B1WC68',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5971',
#    'Ensembl.GeneID.TF': 'ENSG00000104856',
#    'Name.TF': 'RELB',
#    'UniprotID.TF': 'Q01201',
#    'TF.TFLink.ortho': 'Mm:Q04863;Rn:D4A8H1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2145',
#    'Ensembl.GeneID.TF': 'ENSG00000108799',
#    'Name.TF': 'EZH1',
#    'UniprotID.TF': 'Q92800',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4J1C0;Rn:F1LZH3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5977',
#    'Ensembl.GeneID.TF': 'ENSG00000133884',
#    'Name.TF': 'DPF2',
#    'UniprotID.TF': 'Q92785',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1108',
#    'Ensembl.GeneID.TF': 'ENSG00000111642',
#    'Name.TF': 'CHD4',
#    'UniprotID.TF': 'Q14839',
#    'TF.TFLink.ortho': 'Dr:Q1LYP4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23512',
#    'Ensembl.GeneID.TF': 'ENSG00000178691',
#    'Name.TF': 'SUZ12',
#    'UniprotID.TF': 'Q15022',
#    'TF.TFLink.ortho': 'Dm:Q9NJG9;Dr:B0R1D5;Mm:Q80U70;Rn:A0A0G2K2I0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3146',
#    'Ensembl.GeneID.TF': 'ENSG00000189403',
#    'Name.TF': 'HMGB1',
#    'UniprotID.TF': 'P09429',
#    'TF.TFLink.ortho': 'Dr:Q6NX86;Dr:X1WFI9;Mm:P63158',
#    'TF.nonTFLink.ortho': 'Rn:D3ZXR5;Rn:A0A0G2K6P4;Rn:D3ZCR3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2551',
#    'Ensembl.GeneID.TF': 'ENSG00000154727',
#    'Name.TF': 'GABPA',
#    'UniprotID.TF': 'Q06546',
#    'TF.TFLink.ortho': 'Dm:Q04688;Dr:Q9I9E8;Mm:Q00422',
#    'TF.nonTFLink.ortho': 'Rn:D4ACQ9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7716',
#    'Ensembl.GeneID.TF': 'ENSG00000136451',
#    'Name.TF': 'VEZF1',
#    'UniprotID.TF': 'Q14119',
#    'TF.TFLink.ortho': 'Ce:Q21494;Mm:Q5SXC4;Rn:F1M8R0',
#    'TF.nonTFLink.ortho': 'Dr:F1R4Q4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2908',
#    'Ensembl.GeneID.TF': 'ENSG00000113580',
#    'Name.TF': 'NR3C1',
#    'UniprotID.TF': 'P04150',
#    'TF.TFLink.ortho': 'Dr:Q1XHK0',
#    'TF.nonTFLink.ortho': 'Mm:E9PYV1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6829',
#    'Ensembl.GeneID.TF': 'ENSG00000196235',
#    'Name.TF': 'SUPT5H',
#    'UniprotID.TF': 'O00267',
#    'TF.TFLink.ortho': 'Ce:Q21338;Dm:Q9V460;Dr:F1QD27;Mm:O55201;Rn:E9PTB2;Sc:P27692',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23309',
#    'Ensembl.GeneID.TF': 'ENSG00000127511',
#    'Name.TF': 'SIN3B',
#    'UniprotID.TF': 'O75182',
#    'TF.TFLink.ortho': 'Mm:Q62141',
#    'TF.nonTFLink.ortho': 'Dr:Q1LYM8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55769',
#    'Ensembl.GeneID.TF': 'ENSG00000167766',
#    'Name.TF': 'ZNF83',
#    'UniprotID.TF': 'P51522',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6773',
#    'Ensembl.GeneID.TF': 'ENSG00000170581',
#    'Name.TF': 'STAT2',
#    'UniprotID.TF': 'P52630',
#    'TF.TFLink.ortho': 'Rn:Q5XI26',
#    'TF.nonTFLink.ortho': 'Mm:E9QJX9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '30827',
#    'Ensembl.GeneID.TF': 'ENSG00000154832',
#    'Name.TF': 'CXXC1',
#    'UniprotID.TF': 'Q9P0U4',
# ...
#    'Name.TF': 'PPARG',
#    'UniprotID.TF': 'P37231',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '65980',
#    'Ensembl.GeneID.TF': 'ENSG00000028310',
#    'Name.TF': 'BRD9',
#    'UniprotID.TF': 'Q9H8M2',
#    'TF.TFLink.ortho': 'Dm:Q9VLX2;Dr:F1QNW6;Rn:D4ACF5',
#    'TF.nonTFLink.ortho': 'Mm:A0A0R4J175',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9839',
#    'Ensembl.GeneID.TF': 'ENSG00000169554',
#    'Name.TF': 'ZEB2',
#    'UniprotID.TF': 'O60315',
#    'TF.TFLink.ortho': 'Mm:Q9R0G7;Rn:E9PTC3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84124',
#    'Ensembl.GeneID.TF': 'ENSG00000160908',
#    'Name.TF': 'ZNF394',
#    'UniprotID.TF': 'Q53GI3',
#    'TF.TFLink.ortho': 'Mm:Q9Z1D9;Rn:Q498N6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6671',
#    'Ensembl.GeneID.TF': 'ENSG00000105866',
#    'Name.TF': 'SP4',
#    'UniprotID.TF': 'Q02446',
#    'TF.TFLink.ortho': 'Dm:Q9VEW6;Mm:A0A1Y7VJR5;Rn:Q63158',
#    'TF.nonTFLink.ortho': 'Dr:F1QVQ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4824',
#    'Ensembl.GeneID.TF': 'ENSG00000167034',
#    'Name.TF': 'NKX3-1',
#    'UniprotID.TF': 'Q99801',
#    'TF.TFLink.ortho': 'Mm:P97436',
#    'TF.nonTFLink.ortho': 'Dr:Q68EL7;Rn:Q497B7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '55929',
#    'Ensembl.GeneID.TF': 'ENSG00000178028',
#    'Name.TF': 'DMAP1',
#    'UniprotID.TF': 'Q9NPF5',
#    'TF.TFLink.ortho': 'Ce:A8XQE0;Dm:Q7K3D8;Dr:B8JI50;Mm:Q9JI44;Rn:Q568Y6',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7728',
#    'Ensembl.GeneID.TF': 'ENSG00000105497',
#    'Name.TF': 'ZNF175',
#    'UniprotID.TF': 'Q9Y473',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '26959',
#    'Ensembl.GeneID.TF': 'ENSG00000105856',
#    'Name.TF': 'HBP1',
#    'UniprotID.TF': 'O60381',
#    'TF.TFLink.ortho': 'Dr:F1QK54;Mm:E9Q1A8;Rn:Z4YNI2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '51574',
#    'Ensembl.GeneID.TF': 'ENSG00000174720',
#    'Name.TF': 'LARP7',
#    'UniprotID.TF': 'Q4G0J3',
#    'TF.TFLink.ortho': 'Dm:Q9W362;Dr:E7F7F2;Mm:Q05CL8;Rn:M0R7D1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '57634',
#    'Ensembl.GeneID.TF': 'ENSG00000183495',
#    'Name.TF': 'EP400',
#    'UniprotID.TF': 'Q96L91',
#    'TF.TFLink.ortho': 'Mm:Q8CHI8;Rn:A0A0G2JU09',
#    'TF.nonTFLink.ortho': 'Dm:A0A0B4LFX8;Dr:A0A0R4IGB8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29781',
#    'Ensembl.GeneID.TF': 'ENSG00000025770',
#    'Name.TF': 'NCAPH2',
#    'UniprotID.TF': 'Q6IBW4',
#    'TF.TFLink.ortho': 'Dr:Q5RH01;Mm:Q8BSP2',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K4H8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '8726',
#    'Ensembl.GeneID.TF': 'ENSG00000074266',
#    'Name.TF': 'EED',
#    'UniprotID.TF': 'O75530',
#    'TF.TFLink.ortho': 'Ce:Q9GYS1;Dm:Q9VKD5;Dr:Q566T0;Mm:Q921E6;Rn:B5DF02',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2625',
#    'Ensembl.GeneID.TF': 'ENSG00000107485',
#    'Name.TF': 'GATA3',
#    'UniprotID.TF': 'P23771',
#    'TF.TFLink.ortho': 'Dr:Q91428;Mm:P23772;Rn:Q99NH5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84662',
#    'Ensembl.GeneID.TF': 'ENSG00000126603',
#    'Name.TF': 'GLIS2',
#    'UniprotID.TF': 'Q9BZE0',
#    'TF.TFLink.ortho': 'Mm:Q8VDL9;Rn:D3ZIA9',
#    'TF.nonTFLink.ortho': 'Dr:A0A0R4IE83',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7629',
#    'Ensembl.GeneID.TF': 'ENSG00000065029',
#    'Name.TF': 'ZNF76',
#    'UniprotID.TF': 'P36508',
#    'TF.TFLink.ortho': 'Mm:Q8BMU0',
#    'TF.nonTFLink.ortho': 'Rn:F1LNL6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6598',
#    'Ensembl.GeneID.TF': 'ENSG00000099956',
#    'Name.TF': 'SMARCB1',
#    'UniprotID.TF': 'Q12824',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '672',
#    'Ensembl.GeneID.TF': 'ENSG00000012048',
#    'Name.TF': 'BRCA1',
#    'UniprotID.TF': 'P38398',
#    'TF.TFLink.ortho': 'Mm:P48754;Rn:G3V8S5',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2122',
#    'Ensembl.GeneID.TF': 'ENSG00000085276',
#    'Name.TF': 'MECOM',
#    'UniprotID.TF': 'Q03112',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': 'Mm:G3UZT5;Rn:D3ZM26',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '115196',
#    'Ensembl.GeneID.TF': 'ENSG00000172006',
#    'Name.TF': 'ZNF554',
#    'UniprotID.TF': 'Q86TJ5',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6908',
#    'Ensembl.GeneID.TF': 'ENSG00000112592',
#    'Name.TF': 'TBP',
#    'UniprotID.TF': 'P20226',
#    'TF.TFLink.ortho': 'Dr:Q7SXL3;Mm:P29037;Rn:Q66HB1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3516',
#    'Ensembl.GeneID.TF': 'ENSG00000168214',
#    'Name.TF': 'RBPJ',
#    'UniprotID.TF': 'Q06330',
#    'TF.TFLink.ortho': 'Dm:P28159;Dr:A4FTT3;Mm:P31266;Rn:M0R7Q3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '10664',
#    'Ensembl.GeneID.TF': 'ENSG00000102974',
#    'Name.TF': 'CTCF',
#    'UniprotID.TF': 'P49711',
#    'TF.TFLink.ortho': 'Dr:Q6JAA4;Mm:Q61164;Rn:A0A0H2UHP0',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;18971253;27924024;26578589',
#    'Source.database': 'GTRD;ORegAnno;PAZAR;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '4000',
#    'Ensembl.GeneID.TF': 'ENSG00000160789',
#    'Name.TF': 'LMNA',
#    'UniprotID.TF': 'P02545',
#    'TF.TFLink.ortho': 'Mm:P48678;Rn:G3V8L3',
#    'TF.nonTFLink.ortho': 'Dr:B3DKC5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '79718',
#    'Ensembl.GeneID.TF': 'ENSG00000177565',
#    'Name.TF': 'TBL1XR1',
#    'UniprotID.TF': 'Q9BZK7',
#    'TF.TFLink.ortho': 'Dr:A5PF33;Mm:Q8BHJ5;Sc:P38262',
#    'TF.nonTFLink.ortho': 'Rn:D3ZNF4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3607',
#    'Ensembl.GeneID.TF': 'ENSG00000141568',
#    'Name.TF': 'FOXK2',
#    'UniprotID.TF': 'Q01167',
#    'TF.TFLink.ortho': 'Dr:E7FFM9;Mm:Q3UCQ1',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '3609',
#    'Ensembl.GeneID.TF': 'ENSG00000129351',
#    'Name.TF': 'ILF3',
#    'UniprotID.TF': 'Q12906',
#    'TF.TFLink.ortho': 'Mm:Q9Z1X4',
#    'TF.nonTFLink.ortho': 'Rn:A0A0G2K4U6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '5316',
#    'Ensembl.GeneID.TF': 'ENSG00000160199',
#    'Name.TF': 'PKNOX1',
#    'UniprotID.TF': 'P55347',
#    'TF.TFLink.ortho': 'Dr:E7FBG0;Mm:O70477',
#    'TF.nonTFLink.ortho': 'Rn:Q5BJP1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6722',
#    'Ensembl.GeneID.TF': 'ENSG00000112658',
#    'Name.TF': 'SRF',
#    'UniprotID.TF': 'P11831',
#    'TF.TFLink.ortho': 'Mm:Q9JM73;Rn:D3ZHH8',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '9611',
#    'Ensembl.GeneID.TF': 'ENSG00000141027',
#    'Name.TF': 'NCOR1',
#    'UniprotID.TF': 'O75376',
#    'TF.TFLink.ortho': 'Rn:A0A0G2K2B4',
#    'TF.nonTFLink.ortho': 'Mm:Q5RIM6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '6777',
#    'Ensembl.GeneID.TF': 'ENSG00000173757',
#    'Name.TF': 'STAT5B',
#    'UniprotID.TF': 'P51692',
#    'TF.TFLink.ortho': 'Mm:P42232;Rn:A0A0G2JSR4',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1488',
#    'Ensembl.GeneID.TF': 'ENSG00000175029',
#    'Name.TF': 'CTBP2',
#    'UniprotID.TF': 'P56545',
#    'TF.TFLink.ortho': 'Mm:P56546;Sc:P40054',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '163059',
#    'Ensembl.GeneID.TF': 'ENSG00000197647',
#    'Name.TF': 'ZNF433',
#    'UniprotID.TF': 'Q8N7K0',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '29101',
#    'Ensembl.GeneID.TF': 'ENSG00000160075',
#    'Name.TF': 'SSU72',
#    'UniprotID.TF': 'Q9NP77',
#    'TF.TFLink.ortho': 'Dr:Q6PC19;Mm:Q9CY97;Rn:Q4KLK9',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27154',
#    'Ensembl.GeneID.TF': 'ENSG00000096070',
#    'Name.TF': 'BRPF3',
#    'UniprotID.TF': 'Q9ULD4',
#    'TF.TFLink.ortho': 'Dr:F6P390;Mm:B2KF05;Rn:D3ZMD3',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2078',
#    'Ensembl.GeneID.TF': 'ENSG00000157554',
#    'Name.TF': 'ERG',
#    'UniprotID.TF': 'P11308',
#    'TF.TFLink.ortho': 'Mm:P81270',
#    'TF.nonTFLink.ortho': 'Dr:F1QK28;Rn:A0A0G2JWE9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23186',
#    'Ensembl.GeneID.TF': 'ENSG00000089902',
#    'Name.TF': 'RCOR1',
#    'UniprotID.TF': 'Q9UKL0',
#    'TF.TFLink.ortho': 'Dr:Q1MTF5',
#    'TF.nonTFLink.ortho': 'Rn:F1LXS5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '84619',
#    'Ensembl.GeneID.TF': 'ENSG00000197114',
#    'Name.TF': 'ZGPAT',
#    'UniprotID.TF': 'Q8N5A5',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '7342',
#    'Ensembl.GeneID.TF': 'ENSG00000153560',
#    'Name.TF': 'UBP1',
#    'UniprotID.TF': 'Q9NZI7',
#    'TF.TFLink.ortho': 'Dr:A3KPT8;Mm:Q811S7;Rn:D4A030',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '27125',
#    'Ensembl.GeneID.TF': 'ENSG00000072364',
#    'Name.TF': 'AFF4',
#    'UniprotID.TF': 'Q9UHB7',
#    'TF.TFLink.ortho': 'Dm:Q9XZ21;Dr:I3ISK1;Mm:Q9ESC8;Rn:D3ZSX2',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '2313',
#    'Ensembl.GeneID.TF': 'ENSG00000151702',
#    'Name.TF': 'FLI1',
#    'UniprotID.TF': 'Q01543',
#    'TF.TFLink.ortho': 'Mm:P26323;Rn:Q4Z8P1',
#    'TF.nonTFLink.ortho': 'Dr:Q9PU61',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '167465',
#    'Ensembl.GeneID.TF': 'ENSG00000178175',
#    'Name.TF': 'ZNF366',
#    'UniprotID.TF': 'Q8N895',
#    'TF.TFLink.ortho': 'Mm:Q6NS86',
#    'TF.nonTFLink.ortho': 'Rn:D4A715',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '23435',
#    'Ensembl.GeneID.TF': 'ENSG00000120948',
#    'Name.TF': 'TARDBP',
#    'UniprotID.TF': 'Q13148',
#    'TF.TFLink.ortho': '-',
#    'TF.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.TF': '1027',
#    'Ensembl.GeneID.TF': 'ENSG00000111276',
#    'Name.TF': 'CDKN1B',
#    'UniprotID.TF': 'P46527',
#    'TF.TFLink.ortho': 'Mm:P46414;Rn:O08769',
#    'TF.nonTFLink.ortho': 'Ce:U4PBK8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'}]}

# %%
combined_df_tf[~combined_df_tf["target"].isin(combined_df_sig["target"].tolist())]
# Out:
#             identifier identifier.source  target target.source  \
# 7      ENSG00000001167           Ensembl    4800  ncbi_gene_id
# 43     ENSG00000004487           Ensembl   23028  ncbi_gene_id
# 74     ENSG00000005339           Ensembl    1387  ncbi_gene_id
# 88     ENSG00000005889           Ensembl    7543  ncbi_gene_id
# 99     ENSG00000006194           Ensembl   10127  ncbi_gene_id
# ...                ...               ...     ...           ...
# 11743  ENSG00000275700           Ensembl   26574  ncbi_gene_id
# 11756  ENSG00000276644           Ensembl    1602  ncbi_gene_id
# 11758  ENSG00000277258           Ensembl    7703  ncbi_gene_id
# 11760  ENSG00000277494           Ensembl  338328  ncbi_gene_id
# 11764  ENSG00000278129           Ensembl    7554  ncbi_gene_id
#
#       GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  \
# 7                NFYA    198.963515            0.339027   0.133075  2.547627
# 43              KDM1A   1310.615484            0.045821   0.067400  0.679830
# 74             CREBBP   1852.242330            0.116510   0.162612  0.716489
# 88                ZFX    732.044736           -0.164081   0.159735 -1.027205
# 99             ZNF263    337.618503            0.141491   0.132231  1.070034
# ...               ...           ...                 ...        ...       ...
# 11743            AATF    405.250619            0.422212   0.134613  3.136484
# 11756           DACH1     87.387806           -0.001658   0.179004 -0.009262
# 11758           PCGF2    160.048407            0.002932   0.203806  0.014386
# 11760         GPIHBP1    585.805576           -0.190933   0.355165 -0.537591
# 11764            ZNF8     54.639929           -0.362794   0.239010 -1.517904
#
#        pvalue_dea  ...                                   g:Profiler_go:mf  \
# 7        0.010846  ...                                                NaN
# 43       0.496612  ...                                                NaN
# 74       0.473690  ...                                                NaN
# 88       0.304324  ...                                                NaN
# 99       0.284604  ...                                                NaN
# ...           ...  ...                                                ...
# 11743    0.001710  ...  [{'id': 'GO:0019901', 'name': 'protein kinase ...
# 11756    0.992610  ...                                                NaN
# 11758    0.988522  ...                                                NaN
# 11760    0.590860  ...                                                NaN
# 11764    0.129039  ...                                                NaN
#
#        g:Profiler_hp g:Profiler_hpa g:Profiler_kegg  \
# 7                NaN            NaN             NaN
# 43               NaN            NaN             NaN
# 74               NaN            NaN             NaN
# 88               NaN            NaN             NaN
# 99               NaN            NaN             NaN
# ...              ...            ...             ...
# 11743            NaN            NaN             NaN
# 11756            NaN            NaN             NaN
# 11758            NaN            NaN             NaN
# 11760            NaN            NaN             NaN
# 11764            NaN            NaN             NaN
#
#                                         g:Profiler_mirna  \
# 7                                                    NaN
# 43                                                   NaN
# 74                                                   NaN
# 88                                                   NaN
# 99                                                   NaN
# ...                                                  ...
# 11743  [{'id': 'MIRNA:hsa-miR-634', 'name': 'hsa-miR-...
# 11756                                                NaN
# 11758                                                NaN
# 11760                                                NaN
# 11764                                                NaN
#
#                                          g:Profiler_reac  \
# 7                                                    NaN
# 43                                                   NaN
# 74                                                   NaN
# 88                                                   NaN
# 99                                                   NaN
# ...                                                  ...
# 11743  [{'id': 'REAC:R-HSA-162582', 'name': 'Signal T...
# 11756                                                NaN
# 11758                                                NaN
# 11760                                                NaN
# 11764                                                NaN
#
#                                            g:Profiler_tf  \
# 7                                                    NaN
# 43                                                   NaN
# 74                                                   NaN
# 88                                                   NaN
# 99                                                   NaN
# ...                                                  ...
# 11743  [{'id': 'TF:M10696', 'name': 'Factor: HOXA6; m...
# 11756                                                NaN
# 11758                                                NaN
# 11760                                                NaN
# 11764                                                NaN
#
#                                            g:Profiler_wp MitoCarta  \
# 7                                                    NaN       NaN
# 43                                                   NaN       NaN
# 74                                                   NaN       NaN
# 88                                                   NaN       NaN
# 99                                                   NaN       NaN
# ...                                                  ...       ...
# 11743  [{'id': 'WP:WP5287', 'name': '17q12 copy numbe...       NaN
# 11756                                                NaN       NaN
# 11758                                                NaN       NaN
# 11760                                                NaN       NaN
# 11764                                                NaN       NaN
#
#                                             StringDB_ppi
# 7                                                    NaN
# 43                                                   NaN
# 74                                                   NaN
# 88                                                   NaN
# 99                                                   NaN
# ...                                                  ...
# 11743  [{'stringdb_link_to': 'ENSG00000112578', 'Ense...
# 11756                                                NaN
# 11758                                                NaN
# 11760                                                NaN
# 11764                                                NaN
#
# [998 rows x 30 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["identifier"].isin(["ENSG00000001167", "ENSG00000116717"])]
# Out:
#           identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 139  ENSG00000116717           Ensembl   1647  ncbi_gene_id         GADD45A
# 537  ENSG00000001167           Ensembl   4800  ncbi_gene_id            NFYA
#
#      baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 139    448.208280            1.432184   0.377628  3.792579    0.000149  ...
# 537    198.963515            0.339027   0.133075  2.547627    0.010846  ...
#
#                                       g:Profiler_go:mf  g:Profiler_hp  \
# 139  [{'id': 'GO:0042802', 'name': 'identical prote...            NaN
# 537                                                NaN            NaN
#
#     g:Profiler_hpa                                    g:Profiler_kegg  \
# 139            NaN  [{'id': 'KEGG:05216', 'name': 'Thyroid cancer'...
# 537            NaN                                                NaN
#
#                                       g:Profiler_mirna  \
# 139  [{'id': 'MIRNA:hsa-miR-5701', 'name': 'hsa-miR...
# 537                                                NaN
#
#                                        g:Profiler_reac  \
# 139  [{'id': 'REAC:R-HSA-3700989', 'name': 'Transcr...
# 537                                                NaN
#
#                                          g:Profiler_tf  \
# 139  [{'id': 'TF:M10696', 'name': 'Factor: HOXA6; m...
# 537                                                NaN
#
#                                          g:Profiler_wp MitoCarta  \
# 139  [{'id': 'WP:WP1742', 'name': 'TP53 network', '...       NaN
# 537                                                NaN       NaN
#
#                                           StringDB_ppi
# 139  [{'stringdb_link_to': 'ENSG00000120129', 'Ense...
# 537                                                NaN
#
# [2 rows x 30 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["identifier"] == "ENSG00000001167"]
# Out:
#           identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 537  ENSG00000001167           Ensembl   4800  ncbi_gene_id            NFYA
#
#      baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 537    198.963515            0.339027   0.133075  2.547627    0.010846  ...
#
#      g:Profiler_go:mf  g:Profiler_hp g:Profiler_hpa g:Profiler_kegg  \
# 537               NaN            NaN            NaN             NaN
#
#     g:Profiler_mirna g:Profiler_reac g:Profiler_tf g:Profiler_wp MitoCarta  \
# 537              NaN             NaN           NaN           NaN       NaN
#
#     StringDB_ppi
# 537          NaN
#
# [1 rows x 30 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"] == "GADD45A"]
# Out:
#           identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 139  ENSG00000116717           Ensembl   1647  ncbi_gene_id         GADD45A
#
#      baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 139     448.20828            1.432184   0.377628  3.792579    0.000149  ...
#
#                                       g:Profiler_go:mf  g:Profiler_hp  \
# 139  [{'id': 'GO:0042802', 'name': 'identical prote...            NaN
#
#     g:Profiler_hpa                                    g:Profiler_kegg  \
# 139            NaN  [{'id': 'KEGG:05216', 'name': 'Thyroid cancer'...
#
#                                       g:Profiler_mirna  \
# 139  [{'id': 'MIRNA:hsa-miR-5701', 'name': 'hsa-miR...
#
#                                        g:Profiler_reac  \
# 139  [{'id': 'REAC:R-HSA-3700989', 'name': 'Transcr...
#
#                                          g:Profiler_tf  \
# 139  [{'id': 'TF:M10696', 'name': 'Factor: HOXA6; m...
#
#                                          g:Profiler_wp MitoCarta  \
# 139  [{'id': 'WP:WP1742', 'name': 'TP53 network', '...       NaN
#
#                                           StringDB_ppi
# 139  [{'stringdb_link_to': 'ENSG00000120129', 'Ense...
#
# [1 rows x 30 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["identifier"] == "ENSG00000001167"]["its_target"].to_dict()
# Out:
# {537: [{'NCBI.GeneID.Target': '1647',
#    'Ensembl.GeneID.Target': 'ENSG00000116717',
#    'Name.Target': 'GADD45A',
#    'UniprotID.Target': 'P24522',
#    'Target.TFLink.ortho': 'Dr:Q6GMM1;Mm:P48316;Rn:Q66HL6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;11525640;11420680;27924024;29087512',
#    'Source.database': 'GTRD;ReMap;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '84271',
#    'Ensembl.GeneID.Target': 'ENSG00000100227',
#    'Name.Target': 'POLDIP3',
#    'UniprotID.Target': 'Q9BY77',
#    'Target.TFLink.ortho': 'Mm:Q8BG81;Rn:D4A2B0',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4ILC0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54842',
#    'Ensembl.GeneID.Target': 'ENSG00000151690',
#    'Name.Target': 'MFSD6',
#    'UniprotID.Target': 'Q6ZSS7',
#    'Target.TFLink.ortho': 'Ce:Q95Y88;Dm:A1Z9U2;Rn:D3ZCJ3',
#    'Target.nonTFLink.ortho': 'Mm:D3Z183',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '389203',
#    'Ensembl.GeneID.Target': 'ENSG00000250317',
#    'Name.Target': 'SMIM20',
#    'UniprotID.Target': 'Q8N5G0',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4043',
#    'Ensembl.GeneID.Target': 'ENSG00000163956',
#    'Name.Target': 'LRPAP1',
#    'UniprotID.Target': 'P30533',
#    'Target.TFLink.ortho': 'Ce:G5EF26;Dm:Q9VH64;Dr:A2BGU5;Mm:P55302;Rn:Q99068',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5188',
#    'Ensembl.GeneID.Target': 'ENSG00000059691',
#    'Name.Target': 'GATB',
#    'UniprotID.Target': 'O75879',
#    'Target.TFLink.ortho': 'Dm:Q9VCD0;Mm:Q99JT1;Rn:M0R4L6;Sc:P33893',
#    'Target.nonTFLink.ortho': 'Dr:Q7T010',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4836',
#    'Ensembl.GeneID.Target': 'ENSG00000136448',
#    'Name.Target': 'NMT1',
#    'UniprotID.Target': 'P30419',
#    'Target.TFLink.ortho': 'Dr:F1QY00;Mm:O70310;Rn:Q8K1Q0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51655',
#    'Ensembl.GeneID.Target': 'ENSG00000108551',
#    'Name.Target': 'RASD1',
#    'UniprotID.Target': 'Q9Y272',
#    'Target.TFLink.ortho': 'Dr:Q6PHV8;Mm:O35626;Rn:Q9JKF8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '28231',
#    'Ensembl.GeneID.Target': 'ENSG00000101187',
#    'Name.Target': 'SLCO4A1',
#    'UniprotID.Target': 'Q96BD0',
#    'Target.TFLink.ortho': 'Ce:Q9XWC5;Ce:X5LPS1;Dm:Q8SY02;Dr:E7FFX7;Mm:Q8K078;Rn:Q4V8N6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '757',
#    'Ensembl.GeneID.Target': 'ENSG00000142188',
#    'Name.Target': 'TMEM50B',
#    'UniprotID.Target': 'P56557',
#    'Target.TFLink.ortho': 'Dm:Q9VZE2;Mm:Q9D1X9;Rn:Q5BJS6',
#    'Target.nonTFLink.ortho': 'Ce:Q9N2X7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9927',
#    'Ensembl.GeneID.Target': 'ENSG00000116688',
#    'Name.Target': 'MFN2',
#    'UniprotID.Target': 'O95140',
#    'Target.TFLink.ortho': 'Dr:A8WIN6;Mm:Q80U63',
#    'Target.nonTFLink.ortho': 'Rn:F7FHF7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8869',
#    'Ensembl.GeneID.Target': 'ENSG00000115525',
#    'Name.Target': 'ST3GAL5',
#    'UniprotID.Target': 'Q9UNP4',
#    'Target.TFLink.ortho': 'Rn:Q68G12',
#    'Target.nonTFLink.ortho': 'Dr:F1RCA6;Mm:A0A0U1RNK2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '123803',
#    'Ensembl.GeneID.Target': 'ENSG00000157045',
#    'Name.Target': 'NTAN1',
#    'UniprotID.Target': 'Q96AB6',
#    'Target.TFLink.ortho': 'Dm:Q7KIS4;Mm:Q64311;Rn:A0A0G2JWG0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54793',
#    'Ensembl.GeneID.Target': 'ENSG00000104756',
#    'Name.Target': 'KCTD9',
#    'UniprotID.Target': 'Q7L273',
#    'Target.TFLink.ortho': 'Dm:B9A0N7;Dr:A8DZF0;Rn:D3ZE91',
#    'Target.nonTFLink.ortho': 'Dr:B0V3Q8;Mm:E9PUA6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '770',
#    'Ensembl.GeneID.Target': 'ENSG00000063180',
#    'Name.Target': 'CA11',
#    'UniprotID.Target': 'O75493',
#    'Target.TFLink.ortho': 'Mm:O70354;Rn:Q811X3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79731',
#    'Ensembl.GeneID.Target': 'ENSG00000137513',
#    'Name.Target': 'NARS2',
#    'UniprotID.Target': 'Q96I59',
#    'Target.TFLink.ortho': 'Ce:Q95PZ8;Dm:Q7JZR5;Mm:Q8BGV0;Sc:P25345',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2K7D7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '57610',
#    'Ensembl.GeneID.Target': 'ENSG00000141084',
#    'Name.Target': 'RANBP10',
#    'UniprotID.Target': 'Q6VN20',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '80823',
#    'Ensembl.GeneID.Target': 'ENSG00000198908',
#    'Name.Target': 'BHLHB9',
#    'UniprotID.Target': 'Q6PI77',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9846',
#    'Ensembl.GeneID.Target': 'ENSG00000033327',
#    'Name.Target': 'GAB2',
#    'UniprotID.Target': 'Q9UQC2',
#    'Target.TFLink.ortho': 'Mm:Q3ZB57;Rn:F1LSR2',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4I9X7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '149345',
#    'Ensembl.GeneID.Target': 'ENSG00000198892',
#    'Name.Target': 'SHISA4',
#    'UniprotID.Target': 'Q96DD7',
#    'Target.TFLink.ortho': 'Dr:A5WUR8;Mm:Q8CA71;Rn:A0MV40',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '124936',
#    'Ensembl.GeneID.Target': 'ENSG00000167740',
#    'Name.Target': 'CYB5D2',
#    'UniprotID.Target': 'Q8WUJ1',
#    'Target.TFLink.ortho': 'Ce:Q9XXA7;Dm:Q9W376;Mm:Q5SSH8;Rn:Q6AY62',
#    'Target.nonTFLink.ortho': 'Dr:A2CES0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4722',
#    'Ensembl.GeneID.Target': 'ENSG00000213619',
#    'Name.Target': 'NDUFS3',
#    'UniprotID.Target': 'O75489',
#    'Target.TFLink.ortho': 'Dm:Q9VZU4;Dr:F1R4C8;Mm:Q9DCT2;Rn:D3ZG43',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55699',
#    'Ensembl.GeneID.Target': 'ENSG00000067704',
#    'Name.Target': 'IARS2',
#    'UniprotID.Target': 'Q9NSE4',
#    'Target.TFLink.ortho': 'Dm:Q9VUY4;Dr:F1QUQ0;Mm:Q8BIJ6;Rn:A0A0G2K261;Sc:P48526',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55625',
#    'Ensembl.GeneID.Target': 'ENSG00000153786',
#    'Name.Target': 'ZDHHC7',
#    'UniprotID.Target': 'Q9NXF8',
#    'Target.TFLink.ortho': 'Dr:Q6DHI1;Mm:Q91WU6;Rn:Q923G5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2597',
#    'Ensembl.GeneID.Target': 'ENSG00000111640',
#    'Name.Target': 'GAPDH',
#    'UniprotID.Target': 'P04406',
#    'Target.TFLink.ortho': 'Ce:P17331;Ce:P04970;Ce:P17330;Ce:P17329;Dm:P07486;Dm:P07487;Mm:S4R1W1;Rn:P04797',
#    'Target.nonTFLink.ortho': 'Mm:S4R1W8;Mm:A0A1D5RLD8;Rn:D3ZGY4;Rn:M0R590',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8914',
#    'Ensembl.GeneID.Target': 'ENSG00000111602',
#    'Name.Target': 'TIMELESS',
#    'UniprotID.Target': 'Q9UNS1',
#    'Target.TFLink.ortho': 'Ce:G5EDN3;Dm:Q8INH7;Dr:E7FGL0;Mm:Q9R1X4;Rn:E9PTS7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '753',
#    'Ensembl.GeneID.Target': 'ENSG00000168675',
#    'Name.Target': 'LDLRAD4',
#    'UniprotID.Target': 'O15165',
#    'Target.TFLink.ortho': 'Dr:E9QGX8;Mm:Q8BWJ4',
#    'Target.nonTFLink.ortho': 'Rn:F1LZA8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4501',
#    'Ensembl.GeneID.Target': 'ENSG00000187193',
#    'Name.Target': 'MT1X',
#    'UniprotID.Target': 'P80297',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5224',
#    'Ensembl.GeneID.Target': 'ENSG00000164708',
#    'Name.Target': 'PGAM2',
#    'UniprotID.Target': 'P15259',
#    'Target.TFLink.ortho': 'Mm:O70250',
#    'Target.nonTFLink.ortho': 'Dr:Q7T3G4;Rn:P16290',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10904',
#    'Ensembl.GeneID.Target': 'ENSG00000166619',
#    'Name.Target': 'BLCAP',
#    'UniprotID.Target': 'P62952',
#    'Target.TFLink.ortho': 'Ce:G5EE03;Dm:Q9V3L0;Dr:Q9IB61;Mm:P62951;Rn:P62950',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3835',
#    'Ensembl.GeneID.Target': 'ENSG00000079616',
#    'Name.Target': 'KIF22',
#    'UniprotID.Target': 'Q14807',
#    'Target.TFLink.ortho': 'Dr:B7ZV80;Mm:Q3V300;Rn:Q5I0E8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '320',
#    'Ensembl.GeneID.Target': 'ENSG00000107282',
#    'Name.Target': 'APBA1',
#    'UniprotID.Target': 'Q02410',
#    'Target.TFLink.ortho': 'Mm:B2RUJ5;Rn:F1LR60',
#    'Target.nonTFLink.ortho': 'Dr:A0A2R9YJM9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '200185',
#    'Ensembl.GeneID.Target': 'ENSG00000163463',
#    'Name.Target': 'KRTCAP2',
#    'UniprotID.Target': 'Q8N6L1',
#    'Target.TFLink.ortho': 'Dm:Q8INQ7;Dr:Q0P494;Mm:Q5RL79;Rn:B2RZC9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10367',
#    'Ensembl.GeneID.Target': 'ENSG00000107745',
#    'Name.Target': 'MICU1',
#    'UniprotID.Target': 'Q9BPX6',
#    'Target.TFLink.ortho': 'Ce:Q95PZ2;Dm:A2VEI2;Mm:Q8VCX5;Rn:A0A0G2K0T5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '100272147',
#    'Ensembl.GeneID.Target': 'ENSG00000182712',
#    'Name.Target': 'CMC4',
#    'UniprotID.Target': 'P56277',
#    'Target.TFLink.ortho': 'Dm:B7YZN8;Dr:A0A0R4IZJ0;Mm:Q61908;Rn:A0A0G2K2W2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '11123',
#    'Ensembl.GeneID.Target': 'ENSG00000117602',
#    'Name.Target': 'RCAN3',
#    'UniprotID.Target': 'Q9UKA8',
#    'Target.TFLink.ortho': 'Mm:Q9JKK0;Rn:F7ENE7',
#    'Target.nonTFLink.ortho': 'Dr:Q6DG39',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4719',
#    'Ensembl.GeneID.Target': 'ENSG00000023228',
#    'Name.Target': 'NDUFS1',
#    'UniprotID.Target': 'P28331',
#    'Target.TFLink.ortho': 'Ce:Q9N4Y8;Dm:Q94511;Mm:Q91VD9;Rn:Q66HF1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1738',
#    'Ensembl.GeneID.Target': 'ENSG00000091140',
#    'Name.Target': 'DLD',
#    'UniprotID.Target': 'P09622',
#    'Target.TFLink.ortho': 'Ce:O17953;Dm:Q9VVL7;Dr:Q6TNU6;Mm:O08749;Rn:Q6P6R2;Sc:P09624',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1146',
#    'Ensembl.GeneID.Target': 'ENSG00000196811',
#    'Name.Target': 'CHRNG',
#    'UniprotID.Target': 'P07510',
#    'Target.TFLink.ortho': 'Mm:F8VQK4',
#    'Target.nonTFLink.ortho': 'Dr:E7F9V1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '127687',
#    'Ensembl.GeneID.Target': 'ENSG00000197982',
#    'Name.Target': 'C1orf122',
#    'UniprotID.Target': 'Q6ZSJ8',
#    'Target.TFLink.ortho': 'Rn:D3ZK76',
#    'Target.nonTFLink.ortho': 'Mm:V9GXF1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51380',
#    'Ensembl.GeneID.Target': 'ENSG00000139631',
#    'Name.Target': 'CSAD',
#    'UniprotID.Target': 'Q9Y600',
#    'Target.TFLink.ortho': 'Mm:Q9DBE0;Rn:Q64611',
#    'Target.nonTFLink.ortho': 'Dr:F1QG14',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51209',
#    'Ensembl.GeneID.Target': 'ENSG00000123570',
#    'Name.Target': 'RAB9B',
#    'UniprotID.Target': 'Q9NP90',
#    'Target.TFLink.ortho': 'Dr:E7F8G0;Mm:Q8BHH2;Rn:D3ZP15',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '121441',
#    'Ensembl.GeneID.Target': 'ENSG00000139350',
#    'Name.Target': 'NEDD1',
#    'UniprotID.Target': 'Q8NHV4',
#    'Target.TFLink.ortho': 'Dm:Q9VJ57;Mm:P33215;Rn:D3ZAH3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2110',
#    'Ensembl.GeneID.Target': 'ENSG00000171503',
#    'Name.Target': 'ETFDH',
#    'UniprotID.Target': 'Q16134',
#    'Target.TFLink.ortho': 'Ce:Q11190;Dm:Q7JWF1;Mm:Q921G7;Rn:Q66HF3;Sc:Q08822',
#    'Target.nonTFLink.ortho': 'Dr:Q66I16',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '728568',
#    'Ensembl.GeneID.Target': 'ENSG00000204954',
#    'Name.Target': 'BRAWNIN',
#    'UniprotID.Target': 'Q69YU5',
#    'Target.TFLink.ortho': 'Dr:E7EXZ6;Mm:Q8BTC1;Rn:D3ZZG3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6596',
#    'Ensembl.GeneID.Target': 'ENSG00000071794',
#    'Name.Target': 'HLTF',
#    'UniprotID.Target': 'Q14527',
#    'Target.TFLink.ortho': 'Dr:B0V118;Mm:Q6PCN7;Rn:A0A0G2JVH5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2729',
#    'Ensembl.GeneID.Target': 'ENSG00000001084',
#    'Name.Target': 'GCLC',
#    'UniprotID.Target': 'P48506',
#    'Target.TFLink.ortho': 'Ce:Q20117;Dm:Q9W3K5;Dr:Q6NV35;Mm:P97494;Rn:P19468;Sc:P32477',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5528',
#    'Ensembl.GeneID.Target': 'ENSG00000112640',
#    'Name.Target': 'PPP2R5D',
#    'UniprotID.Target': 'Q14738',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': 'Mm:Q7TNL5;Rn:F1MAA3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '11167',
#    'Ensembl.GeneID.Target': 'ENSG00000163430',
#    'Name.Target': 'FSTL1',
#    'UniprotID.Target': 'Q12841',
#    'Target.TFLink.ortho': 'Dr:Q2PMI2;Mm:Q62356;Rn:Q62632',
#    'Target.nonTFLink.ortho': 'Dr:F1Q6U6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8195',
#    'Ensembl.GeneID.Target': 'ENSG00000125863',
#    'Name.Target': 'MKKS',
#    'UniprotID.Target': 'Q9NPJ1',
#    'Target.TFLink.ortho': 'Dr:F1QCQ8;Mm:Q9JI70;Rn:Q5XI30',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2235',
#    'Ensembl.GeneID.Target': 'ENSG00000066926',
#    'Name.Target': 'FECH',
#    'UniprotID.Target': 'P22830',
#    'Target.TFLink.ortho': 'Dm:Q9V9S8;Dr:F1R362;Mm:Q544X6;Rn:D3ZBM3;Sc:P16622',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56180',
#    'Ensembl.GeneID.Target': 'ENSG00000101928',
#    'Name.Target': 'MOSPD1',
#    'UniprotID.Target': 'Q9UJG1',
#    'Target.TFLink.ortho': 'Dr:F1R9R3;Mm:Q8VEL0',
#    'Target.nonTFLink.ortho': 'Rn:Q5RJS6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7436',
#    'Ensembl.GeneID.Target': 'ENSG00000147852',
#    'Name.Target': 'VLDLR',
#    'UniprotID.Target': 'P98155',
#    'Target.TFLink.ortho': 'Mm:P98156;Rn:F1LPV2',
#    'Target.nonTFLink.ortho': 'Dr:E9QBA5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3418',
#    'Ensembl.GeneID.Target': 'ENSG00000182054',
#    'Name.Target': 'IDH2',
#    'UniprotID.Target': 'P48735',
#    'Target.TFLink.ortho': 'Ce:O17643;Mm:P54071;Rn:P56574',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5162',
#    'Ensembl.GeneID.Target': 'ENSG00000168291',
#    'Name.Target': 'PDHB',
#    'UniprotID.Target': 'P11177',
#    'Target.TFLink.ortho': 'Ce:O44451;Dm:Q7K5K3;Dr:Q7T368;Mm:Q9D051;Sc:P32473',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2KAM3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8882',
#    'Ensembl.GeneID.Target': 'ENSG00000109917',
#    'Name.Target': 'ZPR1',
#    'UniprotID.Target': 'O75312',
#    'Target.TFLink.ortho': 'Ce:O16999;Dm:Q9W379;Dr:Q1LY31;Mm:Q62384;Rn:D3ZWN1;Sc:P53303',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3725',
#    'Ensembl.GeneID.Target': 'ENSG00000177606',
#    'Name.Target': 'JUN',
#    'UniprotID.Target': 'P05412',
#    'Target.TFLink.ortho': 'Dr:Q6NZT5;Mm:P05627;Rn:P17325',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64374',
#    'Ensembl.GeneID.Target': 'ENSG00000120725',
#    'Name.Target': 'SIL1',
#    'UniprotID.Target': 'Q9H173',
#    'Target.TFLink.ortho': 'Dm:Q9VBV5;Dr:A0A0G2KDW7;Mm:Q9EPK6;Rn:Q6P6S4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1773',
#    'Ensembl.GeneID.Target': 'ENSG00000213918',
#    'Name.Target': 'DNASE1',
#    'UniprotID.Target': 'P24855',
#    'Target.TFLink.ortho': 'Mm:P49183',
#    'Target.nonTFLink.ortho': 'Dr:Q6DG72;Rn:P21704',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '142',
#    'Ensembl.GeneID.Target': 'ENSG00000143799',
#    'Name.Target': 'PARP1',
#    'UniprotID.Target': 'P09874',
#    'Target.TFLink.ortho': 'Ce:Q9N4H4;Dm:P35875;Dr:Q5RHR0;Rn:P27008',
#    'Target.nonTFLink.ortho': 'Mm:Q921K2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5569',
#    'Ensembl.GeneID.Target': 'ENSG00000171033',
#    'Name.Target': 'PKIA',
#    'UniprotID.Target': 'P61925',
#    'Target.TFLink.ortho': 'Mm:P63248;Rn:P63249',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51428',
#    'Ensembl.GeneID.Target': 'ENSG00000183258',
#    'Name.Target': 'DDX41',
#    'UniprotID.Target': 'Q9UJV9',
#    'Target.TFLink.ortho': 'Dm:Q9V3C0;Mm:Q91VN6;Rn:B2RYL8',
#    'Target.nonTFLink.ortho': 'Ce:Q9N5K1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79902',
#    'Ensembl.GeneID.Target': 'ENSG00000125450',
#    'Name.Target': 'NUP85',
#    'UniprotID.Target': 'Q9BW27',
#    'Target.TFLink.ortho': 'Ce:Q22078;Dm:A1YK02;Mm:Q8R480;Rn:Q4QQS8',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4IZD5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51072',
#    'Ensembl.GeneID.Target': 'ENSG00000162959',
#    'Name.Target': 'MEMO1',
#    'UniprotID.Target': 'Q9Y316',
#    'Target.TFLink.ortho': 'Ce:Q22915;Dm:Q9VG04;Dr:A9JTC4;Mm:Q91VH6;Sc:P47085',
#    'Target.nonTFLink.ortho': 'Rn:F1LNE5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '154810',
#    'Ensembl.GeneID.Target': 'ENSG00000166025',
#    'Name.Target': 'AMOTL1',
#    'UniprotID.Target': 'Q8IY63',
#    'Target.TFLink.ortho': 'Mm:Q9D4H4;Rn:F1LZQ6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '92106',
#    'Ensembl.GeneID.Target': 'ENSG00000154814',
#    'Name.Target': 'OXNAD1',
#    'UniprotID.Target': 'Q96HP4',
#    'Target.TFLink.ortho': 'Dr:I3ISI1;Mm:Q8VE38;Rn:D4A0Y4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8073',
#    'Ensembl.GeneID.Target': 'ENSG00000184007',
#    'Name.Target': 'PTP4A2',
#    'UniprotID.Target': 'Q12974',
#    'Target.TFLink.ortho': 'Mm:O70274;Rn:Q6P9X4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '196483',
#    'Ensembl.GeneID.Target': 'ENSG00000118894',
#    'Name.Target': 'EEF2KMT',
#    'UniprotID.Target': 'Q96G04',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '226',
#    'Ensembl.GeneID.Target': 'ENSG00000149925',
#    'Name.Target': 'ALDOA',
#    'UniprotID.Target': 'P04075',
#    'Target.TFLink.ortho': 'Ce:P46563;Dm:P07764;Dr:Q803Q7;Mm:P05064;Rn:P05065',
#    'Target.nonTFLink.ortho': 'Dr:Q6P043',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55089',
#    'Ensembl.GeneID.Target': 'ENSG00000139209',
#    'Name.Target': 'SLC38A4',
#    'UniprotID.Target': 'Q969I6',
#    'Target.TFLink.ortho': 'Dr:Q5SPB0;Mm:Q8R1S9;Rn:Q9EQ25',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '664',
#    'Ensembl.GeneID.Target': 'ENSG00000176171',
#    'Name.Target': 'BNIP3',
#    'UniprotID.Target': 'Q12983',
#    'Target.TFLink.ortho': 'Mm:O55003;Rn:Q9ET45',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '349565',
#    'Ensembl.GeneID.Target': 'ENSG00000163864',
#    'Name.Target': 'NMNAT3',
#    'UniprotID.Target': 'Q96T66',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1666',
#    'Ensembl.GeneID.Target': 'ENSG00000104325',
#    'Name.Target': 'DECR1',
#    'UniprotID.Target': 'Q16698',
#    'Target.TFLink.ortho': 'Ce:Q93761;Dr:F1QB21;Mm:Q9CQ62;Rn:G3V734',
#    'Target.nonTFLink.ortho': 'Ce:Q22230;Ce:Q23116',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64651',
#    'Ensembl.GeneID.Target': 'ENSG00000144655',
#    'Name.Target': 'CSRNP1',
#    'UniprotID.Target': 'Q96S65',
#    'Target.TFLink.ortho': 'Mm:P59054;Rn:D4AAK3',
#    'Target.nonTFLink.ortho': 'Dr:F1QNJ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56911',
#    'Ensembl.GeneID.Target': 'ENSG00000156265',
#    'Name.Target': 'MAP3K7CL',
#    'UniprotID.Target': 'P57077',
#    'Target.TFLink.ortho': 'Mm:P58500;Rn:A0A0G2K9U9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56850',
#    'Ensembl.GeneID.Target': 'ENSG00000068400',
#    'Name.Target': 'GRIPAP1',
#    'UniprotID.Target': 'Q4V328',
#    'Target.TFLink.ortho': 'Ce:Q20298;Dr:B0UYE9;Rn:Q9JHZ4',
#    'Target.nonTFLink.ortho': 'Mm:A2AEW8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51422',
#    'Ensembl.GeneID.Target': 'ENSG00000106617',
#    'Name.Target': 'PRKAG2',
#    'UniprotID.Target': 'Q9UGJ0',
#    'Target.TFLink.ortho': 'Mm:Q91WG5;Rn:A0A140UHX4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '80344',
#    'Ensembl.GeneID.Target': 'ENSG00000100897',
#    'Name.Target': 'DCAF11',
#    'UniprotID.Target': 'Q8TEB1',
#    'Target.TFLink.ortho': 'Ce:P90794;Dm:Q7JYQ4;Mm:Q91VU6;Rn:Q5M9G8',
#    'Target.nonTFLink.ortho': 'Dr:Q499B0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23199',
#    'Ensembl.GeneID.Target': 'ENSG00000131149',
#    'Name.Target': 'GSE1',
#    'UniprotID.Target': 'Q14687',
#    'Target.TFLink.ortho': 'Dr:Q1LWL6;Mm:Q3U3C9;Rn:F1M4A7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54541',
#    'Ensembl.GeneID.Target': 'ENSG00000168209',
#    'Name.Target': 'DDIT4',
#    'UniprotID.Target': 'Q9NX09',
#    'Target.TFLink.ortho': 'Dm:Q9VTH4;Dr:Q7T346;Mm:Q9D3F7;Rn:G3V620',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8313',
#    'Ensembl.GeneID.Target': 'ENSG00000168646',
#    'Name.Target': 'AXIN2',
#    'UniprotID.Target': 'Q9Y2T1',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '60558',
#    'Ensembl.GeneID.Target': 'ENSG00000151806',
#    'Name.Target': 'GUF1',
#    'UniprotID.Target': 'Q8N442',
#    'Target.TFLink.ortho': 'Ce:P34617;Dm:Q9VRH6;Dr:E7FFK6;Mm:Q8C3X4;Rn:D3ZHF8;Sc:P46943',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8898',
#    'Ensembl.GeneID.Target': 'ENSG00000087053',
#    'Name.Target': 'MTMR2',
#    'UniprotID.Target': 'Q13614',
#    'Target.TFLink.ortho': 'Dm:Q9VMI9;Dr:A0JMK5;Mm:Q9Z2D1;Rn:D3ZA31',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23245',
#    'Ensembl.GeneID.Target': 'ENSG00000148219',
#    'Name.Target': 'ASTN2',
#    'UniprotID.Target': 'O75129',
#    'Target.TFLink.ortho': 'Mm:Q80Z10',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2JYU3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55661',
#    'Ensembl.GeneID.Target': 'ENSG00000124228',
#    'Name.Target': 'DDX27',
#    'UniprotID.Target': 'Q96GQ7',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '549',
#    'Ensembl.GeneID.Target': 'ENSG00000148090',
#    'Name.Target': 'AUH',
#    'UniprotID.Target': 'Q13825',
#    'Target.TFLink.ortho': 'Ce:O45106;Dm:A1Z934;Mm:A0A0R4J023;Rn:F1LU71',
#    'Target.nonTFLink.ortho': 'Dr:F1RDX1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '203260',
#    'Ensembl.GeneID.Target': 'ENSG00000159884',
#    'Name.Target': 'CCDC107',
#    'UniprotID.Target': 'Q8WV48',
#    'Target.TFLink.ortho': 'Mm:Q9DCC3;Rn:D4A3Y2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23409',
#    'Ensembl.GeneID.Target': 'ENSG00000089163',
#    'Name.Target': 'SIRT4',
#    'UniprotID.Target': 'Q9Y6E7',
#    'Target.TFLink.ortho': 'Ce:Q20480;Dm:Q8IRR5;Dr:F1QHM6;Mm:Q8R216;Rn:G3V641',
#    'Target.nonTFLink.ortho': 'Ce:Q20481',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '26287',
#    'Ensembl.GeneID.Target': 'ENSG00000165887',
#    'Name.Target': 'ANKRD2',
#    'UniprotID.Target': 'Q9GZV1',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '391356',
#    'Ensembl.GeneID.Target': 'ENSG00000184924',
#    'Name.Target': 'PTRHD1',
#    'UniprotID.Target': 'Q6GMV3',
#    'Target.TFLink.ortho': 'Ce:A7WK43;Dm:Q9VET3;Dr:Q5RIN6;Mm:D3Z4S3;Rn:D3ZBG6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2589',
#    'Ensembl.GeneID.Target': 'ENSG00000141429',
#    'Name.Target': 'GALNT1',
#    'UniprotID.Target': 'Q10472',
#    'Target.TFLink.ortho': 'Ce:P34678;Dr:E7FDA0;Mm:O08912;Rn:Q10473',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4609',
#    'Ensembl.GeneID.Target': 'ENSG00000136997',
#    'Name.Target': 'MYC',
#    'UniprotID.Target': 'P01106',
#    'Target.TFLink.ortho': 'Dr:F1RC36;Mm:P01108',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '93058',
#    'Ensembl.GeneID.Target': 'ENSG00000135469',
#    'Name.Target': 'COQ10A',
#    'UniprotID.Target': 'Q96MF6',
#    'Target.TFLink.ortho': 'Dm:Q8MLL3;Mm:E9Q3H6;Rn:D3ZX74;Sc:Q08058',
#    'Target.nonTFLink.ortho': 'Ce:Q304F0;Dr:E9QFB6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79634',
#    'Ensembl.GeneID.Target': 'ENSG00000144306',
#    'Name.Target': 'SCRN3',
#    'UniprotID.Target': 'Q0VDG4',
#    'Target.TFLink.ortho': 'Dr:Q803W1;Mm:Q3TMH2;Rn:A0A0G2K189',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '84872',
#    'Ensembl.GeneID.Target': 'ENSG00000135482',
#    'Name.Target': 'ZC3H10',
#    'UniprotID.Target': 'Q96K80',
#    'Target.TFLink.ortho': 'Dr:Q6ZM22;Mm:Q8R205;Rn:D3ZLM7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4240',
#    'Ensembl.GeneID.Target': 'ENSG00000140545',
#    'Name.Target': 'MFGE8',
#    'UniprotID.Target': 'Q08431',
#    'Target.TFLink.ortho': 'Mm:P21956',
#    'Target.nonTFLink.ortho': 'Dr:A2RRT1;Dr:A4QP32;Rn:Q1PBJ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6749',
#    'Ensembl.GeneID.Target': 'ENSG00000149136',
#    'Name.Target': 'SSRP1',
#    'UniprotID.Target': 'Q08945',
#    'Target.TFLink.ortho': 'Ce:O01683;Ce:P41848;Dm:Q05344;Mm:Q08943;Rn:Q04931;Sc:Q04636',
#    'Target.nonTFLink.ortho': 'Dr:B8A5B7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10489',
#    'Ensembl.GeneID.Target': 'ENSG00000132128',
#    'Name.Target': 'LRRC41',
#    'UniprotID.Target': 'Q15345',
#    'Target.TFLink.ortho': 'Dr:I3IS54;Mm:Q8K1C9;Rn:Q5M9H1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2010',
#    'Ensembl.GeneID.Target': 'ENSG00000102119',
#    'Name.Target': 'EMD',
#    'UniprotID.Target': 'P50402',
#    'Target.TFLink.ortho': 'Mm:O08579;Rn:Q6PCU4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5092',
#    'Ensembl.GeneID.Target': 'ENSG00000166228',
#    'Name.Target': 'PCBD1',
#    'UniprotID.Target': 'P61457',
#    'Target.TFLink.ortho': 'Ce:Q9TZH6;Dr:Q6PBI6;Mm:P61458;Rn:P61459',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2114',
#    'Ensembl.GeneID.Target': 'ENSG00000157557',
#    'Name.Target': 'ETS2',
#    'UniprotID.Target': 'P15036',
#    'Target.TFLink.ortho': 'Dr:Q501S1;Mm:P15037;Rn:D4AAH4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '200765',
#    'Ensembl.GeneID.Target': 'ENSG00000221944',
#    'Name.Target': 'TIGD1',
#    'UniprotID.Target': 'Q96MW7',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4536',
#    'Ensembl.GeneID.Target': 'ENSG00000198763',
#    'Name.Target': 'MT-ND2',
#    'UniprotID.Target': 'P03891',
#    'Target.TFLink.ortho': 'Dr:Q9MIY9;Mm:P03893;Rn:P11662',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9179',
#    'Ensembl.GeneID.Target': 'ENSG00000221838',
#    'Name.Target': 'AP4M1',
#    'UniprotID.Target': 'O00189',
#    'Target.TFLink.ortho': 'Dr:Q7SZZ7;Mm:Q9JKC7;Rn:Q2PWT8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9693',
#    'Ensembl.GeneID.Target': 'ENSG00000109756',
#    'Name.Target': 'RAPGEF2',
#    'UniprotID.Target': 'Q9Y4G8',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10121',
#    'Ensembl.GeneID.Target': 'ENSG00000138107',
#    'Name.Target': 'ACTR1A',
#    'UniprotID.Target': 'P61163',
#    'Target.TFLink.ortho': 'Mm:P61164;Rn:P85515',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51204',
#    'Ensembl.GeneID.Target': 'ENSG00000136463',
#    'Name.Target': 'TACO1',
#    'UniprotID.Target': 'Q9BSH4',
#    'Target.TFLink.ortho': 'Ce:Q965T4;Mm:Q8K0Z7;Rn:D4A601;Sc:P53212',
#    'Target.nonTFLink.ortho': 'Dr:F1QP29;Dr:A0A0G2L877',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '25855',
#    'Ensembl.GeneID.Target': 'ENSG00000174744',
#    'Name.Target': 'BRMS1',
#    'UniprotID.Target': 'Q9HCU9',
#    'Target.TFLink.ortho': 'Mm:Q99N20',
#    'Target.nonTFLink.ortho': 'Rn:Q5M7T3;Rn:A0A0H2UI40',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '140606',
#    'Ensembl.GeneID.Target': 'ENSG00000198832',
#    'Name.Target': 'SELENOM',
#    'UniprotID.Target': 'Q8WWX9',
#    'Target.TFLink.ortho': 'Mm:Q8VHC3;Rn:A0A0G2JZZ4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '81579',
#    'Ensembl.GeneID.Target': 'ENSG00000123739',
#    'Name.Target': 'PLA2G12A',
#    'UniprotID.Target': 'Q9BZM1',
#    'Target.TFLink.ortho': 'Dr:A3KNJ5;Mm:Q9EPR2;Rn:B0K018',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51390',
#    'Ensembl.GeneID.Target': 'ENSG00000146416',
#    'Name.Target': 'AIG1',
#    'UniprotID.Target': 'Q9NVV5',
#    'Target.TFLink.ortho': 'Dm:Q9VPM9;Dm:Q9VTI1;Dr:Q5RIV5;Mm:Q9D8B1;Rn:B2RZC0',
#    'Target.nonTFLink.ortho': 'Dm:Q9VPN1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '25824',
#    'Ensembl.GeneID.Target': 'ENSG00000126432',
#    'Name.Target': 'PRDX5',
#    'UniprotID.Target': 'P30044',
#    'Target.TFLink.ortho': 'Dm:Q960M4;Mm:P99029;Rn:A0A0G2JSS8;Sc:P38013',
#    'Target.nonTFLink.ortho': 'Dr:F1QCE3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10907',
#    'Ensembl.GeneID.Target': 'ENSG00000141759',
#    'Name.Target': 'TXNL4A',
#    'UniprotID.Target': 'P83876',
#    'Target.TFLink.ortho': 'Ce:L8E6I4;Dm:Q8SZ87;Dr:F1QTJ2;Mm:P83877;Rn:D3ZSW5;Sc:Q06819',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '85437',
#    'Ensembl.GeneID.Target': 'ENSG00000139168',
#    'Name.Target': 'ZCRB1',
#    'UniprotID.Target': 'Q8TBF4',
#    'Target.TFLink.ortho': 'Dr:Q5SP50;Mm:Q9CZ96;Rn:Q499V6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23461',
#    'Ensembl.GeneID.Target': 'ENSG00000154265',
#    'Name.Target': 'ABCA5',
#    'UniprotID.Target': 'Q8WWZ7',
#    'Target.TFLink.ortho': 'Dr:F1QEL5;Mm:Q8K448',
#    'Target.nonTFLink.ortho': 'Rn:M0RA83',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6641',
#    'Ensembl.GeneID.Target': 'ENSG00000172164',
#    'Name.Target': 'SNTB1',
#    'UniprotID.Target': 'Q13884',
#    'Target.TFLink.ortho': 'Dr:Q6GMG2;Mm:Q99L88;Rn:D3ZWC6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8945',
#    'Ensembl.GeneID.Target': 'ENSG00000166167',
#    'Name.Target': 'BTRC',
#    'UniprotID.Target': 'Q9Y297',
#    'Target.TFLink.ortho': 'Mm:Q3ULA2;Rn:F1LMH8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8568',
#    'Ensembl.GeneID.Target': 'ENSG00000160214',
#    'Name.Target': 'RRP1',
#    'UniprotID.Target': 'P56182',
#    'Target.TFLink.ortho': 'Ce:Q18674;Mm:P56183;Rn:Q5M9F3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10912',
#    'Ensembl.GeneID.Target': 'ENSG00000130222',
#    'Name.Target': 'GADD45G',
#    'UniprotID.Target': 'O95257',
#    'Target.TFLink.ortho': 'Dr:Q6NUV6;Dr:Q6P021;Mm:Q9R0S0;Rn:Q9WTQ7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4038',
#    'Ensembl.GeneID.Target': 'ENSG00000134569',
#    'Name.Target': 'LRP4',
#    'UniprotID.Target': 'O75096',
# ...
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '38',
#    'Ensembl.GeneID.Target': 'ENSG00000075239',
#    'Name.Target': 'ACAT1',
#    'UniprotID.Target': 'P24752',
#    'Target.TFLink.ortho': 'Ce:Q22100;Dm:Q9W3N9;Mm:Q8QZT1;Rn:P17764;Sc:P41338',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4720',
#    'Ensembl.GeneID.Target': 'ENSG00000158864',
#    'Name.Target': 'NDUFS2',
#    'UniprotID.Target': 'O75306',
#    'Target.TFLink.ortho': 'Ce:Q22800;Ce:Q93873;Dm:Q9V4E0;Dr:F1Q4N4;Mm:Q91WD5;Rn:Q641Y2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2668',
#    'Ensembl.GeneID.Target': 'ENSG00000168621',
#    'Name.Target': 'GDNF',
#    'UniprotID.Target': 'P39905',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '89796',
#    'Ensembl.GeneID.Target': 'ENSG00000134369',
#    'Name.Target': 'NAV1',
#    'UniprotID.Target': 'Q8NEY1',
#    'Target.TFLink.ortho': 'Rn:D4A5I4',
#    'Target.nonTFLink.ortho': 'Dr:F1QQI8;Mm:A0A589P973',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64061',
#    'Ensembl.GeneID.Target': 'ENSG00000184205',
#    'Name.Target': 'TSPYL2',
#    'UniprotID.Target': 'Q9H2G4',
#    'Target.TFLink.ortho': 'Mm:Q7TQI8;Rn:A0A096MJ32',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5947',
#    'Ensembl.GeneID.Target': 'ENSG00000114115',
#    'Name.Target': 'RBP1',
#    'UniprotID.Target': 'P09455',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2926',
#    'Ensembl.GeneID.Target': 'ENSG00000132463',
#    'Name.Target': 'GRSF1',
#    'UniprotID.Target': 'Q12849',
#    'Target.TFLink.ortho': 'Dr:F8W4V6;Mm:Q8C5Q4',
#    'Target.nonTFLink.ortho': 'Rn:F1LRK4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5979',
#    'Ensembl.GeneID.Target': 'ENSG00000165731',
#    'Name.Target': 'RET',
#    'UniprotID.Target': 'P07949',
#    'Target.TFLink.ortho': 'Dr:A8E7C6;Mm:P35546',
#    'Target.nonTFLink.ortho': 'Rn:G3V9H8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '201562',
#    'Ensembl.GeneID.Target': 'ENSG00000206527',
#    'Name.Target': 'HACD2',
#    'UniprotID.Target': 'Q6Y1H2',
#    'Target.TFLink.ortho': 'Ce:O17040;Dr:B0V199;Mm:Q9D3B1;Rn:D3ZHG0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23632',
#    'Ensembl.GeneID.Target': 'ENSG00000118298',
#    'Name.Target': 'CA14',
#    'UniprotID.Target': 'Q9ULX7',
#    'Target.TFLink.ortho': 'Mm:Q9WVT6;Rn:A2IBE0',
#    'Target.nonTFLink.ortho': 'Dr:F8W4I7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '114882',
#    'Ensembl.GeneID.Target': 'ENSG00000091039',
#    'Name.Target': 'OSBPL8',
#    'UniprotID.Target': 'Q9BZF1',
#    'Target.TFLink.ortho': 'Rn:A0A0G2JXN8',
#    'Target.nonTFLink.ortho': 'Mm:A0A0R4J150',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1160',
#    'Ensembl.GeneID.Target': 'ENSG00000131730',
#    'Name.Target': 'CKMT2',
#    'UniprotID.Target': 'P17540',
#    'Target.TFLink.ortho': 'Mm:Q6P8J7',
#    'Target.nonTFLink.ortho': 'Dm:Q9VF23;Rn:A0A0G2JVQ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54948',
#    'Ensembl.GeneID.Target': 'ENSG00000166902',
#    'Name.Target': 'MRPL16',
#    'UniprotID.Target': 'Q9NX20',
#    'Target.TFLink.ortho': 'Ce:Q22140;Dm:Q9W547;Mm:Q99N93;Rn:Q5M818',
#    'Target.nonTFLink.ortho': 'Dr:F1R2K1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8604',
#    'Ensembl.GeneID.Target': 'ENSG00000115840',
#    'Name.Target': 'SLC25A12',
#    'UniprotID.Target': 'O75746',
#    'Target.TFLink.ortho': 'Mm:Q8BH59;Rn:F1LX07',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4II73',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2037',
#    'Ensembl.GeneID.Target': 'ENSG00000079819',
#    'Name.Target': 'EPB41L2',
#    'UniprotID.Target': 'O43491',
#    'Target.TFLink.ortho': 'Mm:O70318',
#    'Target.nonTFLink.ortho': 'Rn:D3ZM69',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51279',
#    'Ensembl.GeneID.Target': 'ENSG00000139178',
#    'Name.Target': 'C1RL',
#    'UniprotID.Target': 'Q9NZP8',
#    'Target.TFLink.ortho': 'Mm:Q3UZ09;Rn:F1LP96',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6391',
#    'Ensembl.GeneID.Target': 'ENSG00000143252',
#    'Name.Target': 'SDHC',
#    'UniprotID.Target': 'Q99643',
#    'Target.TFLink.ortho': 'Ce:P41956;Dm:Q9VGS3;Mm:Q9CZB0;Rn:Q641Z9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '57787',
#    'Ensembl.GeneID.Target': 'ENSG00000007047',
#    'Name.Target': 'MARK4',
#    'UniprotID.Target': 'Q96L34',
#    'Target.TFLink.ortho': 'Dr:R4GEN1;Mm:Q8CIP4;Rn:D4A6T9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55245',
#    'Ensembl.GeneID.Target': 'ENSG00000101019',
#    'Name.Target': 'UQCC1',
#    'UniprotID.Target': 'Q9NVA1',
#    'Target.TFLink.ortho': 'Dm:Q9VRZ7;Dr:F1QK92;Mm:Q9CWU6;Rn:Q32Q54',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64222',
#    'Ensembl.GeneID.Target': 'ENSG00000186283',
#    'Name.Target': 'TOR3A',
#    'UniprotID.Target': 'Q9H497',
#    'Target.TFLink.ortho': 'Dr:A9C3S4;Mm:Q9ER38;Rn:Q5M936',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '141',
#    'Ensembl.GeneID.Target': 'ENSG00000144843',
#    'Name.Target': 'ADPRH',
#    'UniprotID.Target': 'P54922',
#    'Target.TFLink.ortho': 'Mm:P54923;Rn:Q02589',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5396',
#    'Ensembl.GeneID.Target': 'ENSG00000116132',
#    'Name.Target': 'PRRX1',
#    'UniprotID.Target': 'P54821',
#    'Target.TFLink.ortho': 'Dr:Q6P295;Dr:Q7T373;Mm:P63013;Rn:P63014',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '400451',
#    'Ensembl.GeneID.Target': 'ENSG00000185442',
#    'Name.Target': 'FAM174B',
#    'UniprotID.Target': 'Q3ZCQ3',
#    'Target.TFLink.ortho': 'Mm:Q8K064',
#    'Target.nonTFLink.ortho': 'Rn:D4A4W1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7494',
#    'Ensembl.GeneID.Target': 'ENSG00000100219',
#    'Name.Target': 'XBP1',
#    'UniprotID.Target': 'P17861',
#    'Target.TFLink.ortho': 'Rn:A0A140TAA7',
#    'Target.nonTFLink.ortho': 'Dr:F1R5F9;Mm:A0A5F8MPD3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2119',
#    'Ensembl.GeneID.Target': 'ENSG00000244405',
#    'Name.Target': 'ETV5',
#    'UniprotID.Target': 'P41161',
#    'Target.TFLink.ortho': 'Dr:B0S6S7;Mm:Q9CXC9;Rn:D4AC56',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23596',
#    'Ensembl.GeneID.Target': 'ENSG00000203668',
#    'Name.Target': 'OPN3',
#    'UniprotID.Target': 'Q9H1Y3',
#    'Target.TFLink.ortho': 'Dr:A9NJI7;Mm:Q9WUK7;Rn:D3ZFS1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '60314',
#    'Ensembl.GeneID.Target': 'ENSG00000139637',
#    'Name.Target': 'MYG1',
#    'UniprotID.Target': 'Q9HB07',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5116',
#    'Ensembl.GeneID.Target': 'ENSG00000160299',
#    'Name.Target': 'PCNT',
#    'UniprotID.Target': 'O95613',
#    'Target.TFLink.ortho': 'Dr:I3ISP1;Mm:F8VPV0;Rn:D3ZMY8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54715',
#    'Ensembl.GeneID.Target': 'ENSG00000078328',
#    'Name.Target': 'RBFOX1',
#    'UniprotID.Target': 'Q9NWB1',
#    'Target.TFLink.ortho': 'Dr:Q642J5;Mm:Q9JJ43;Rn:D3ZSL1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10657',
#    'Ensembl.GeneID.Target': 'ENSG00000121774',
#    'Name.Target': 'KHDRBS1',
#    'UniprotID.Target': 'Q07666',
#    'Target.TFLink.ortho': 'Dr:Q6NW62;Mm:Q60749;Rn:Q91V33',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10105',
#    'Ensembl.GeneID.Target': 'ENSG00000108179',
#    'Name.Target': 'PPIF',
#    'UniprotID.Target': 'P30405',
#    'Target.TFLink.ortho': 'Dm:Q7K2I4;Dm:P25007;Mm:Q99KR7;Rn:P29117',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79758',
#    'Ensembl.GeneID.Target': 'ENSG00000102796',
#    'Name.Target': 'DHRS12',
#    'UniprotID.Target': 'A0PJE2',
#    'Target.TFLink.ortho': 'Dr:B0UYL5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '29889',
#    'Ensembl.GeneID.Target': 'ENSG00000134697',
#    'Name.Target': 'GNL2',
#    'UniprotID.Target': 'Q13823',
#    'Target.TFLink.ortho': 'Ce:Q9XXN4;Dm:Q7JXU4;Dr:A0A0R4IXF1;Mm:Q99LH1;Rn:Q4KLJ3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23408',
#    'Ensembl.GeneID.Target': 'ENSG00000124523',
#    'Name.Target': 'SIRT5',
#    'UniprotID.Target': 'Q9NXA8',
#    'Target.TFLink.ortho': 'Mm:Q8K2C6;Rn:Q68FX9',
#    'Target.nonTFLink.ortho': 'Dr:Q6DHI5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51027',
#    'Ensembl.GeneID.Target': 'ENSG00000178096',
#    'Name.Target': 'BOLA1',
#    'UniprotID.Target': 'Q9Y3E2',
#    'Target.TFLink.ortho': 'Ce:P91375;Dm:Q9VC53;Mm:Q9D8S9;Rn:Q06C60',
#    'Target.nonTFLink.ortho': 'Dr:F1R2T4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8925',
#    'Ensembl.GeneID.Target': 'ENSG00000103657',
#    'Name.Target': 'HERC1',
#    'UniprotID.Target': 'Q15751',
#    'Target.TFLink.ortho': 'Mm:E9PZP8;Rn:A0A0G2JTT6',
#    'Target.nonTFLink.ortho': 'Dr:E7FBA7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '81796',
#    'Ensembl.GeneID.Target': 'ENSG00000137571',
#    'Name.Target': 'SLCO5A1',
#    'UniprotID.Target': 'Q9H2Y9',
#    'Target.TFLink.ortho': 'Dr:E7F2I7;Mm:E9PVD9;Rn:D3ZZM7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7264',
#    'Ensembl.GeneID.Target': 'ENSG00000104522',
#    'Name.Target': 'TSTA3',
#    'UniprotID.Target': 'Q13630',
#    'Target.TFLink.ortho': 'Ce:G5EER4;Dm:Q9W1X8;Dr:Q6DC41;Mm:P23591;Rn:G3V762',
#    'Target.nonTFLink.ortho': 'Dr:B0S7C9;Dr:Q5SPD5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '145957',
#    'Ensembl.GeneID.Target': 'ENSG00000169752',
#    'Name.Target': 'NRG4',
#    'UniprotID.Target': 'Q8WWG1',
#    'Target.TFLink.ortho': 'Mm:Q9WTX4;Rn:A0A0G2JYC9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23180',
#    'Ensembl.GeneID.Target': 'ENSG00000131378',
#    'Name.Target': 'RFTN1',
#    'UniprotID.Target': 'Q14699',
#    'Target.TFLink.ortho': 'Dr:A0A0G2L3G6;Mm:Q6A0D4',
#    'Target.nonTFLink.ortho': 'Dr:E9QG04;Rn:G3V7I2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'}]}

# %%
combined_df_tf_sig["its_target"][10]

# %%
# Extract all targets for NFYA ('NCBI.GeneID.TF')
ncbi_gene_ids_NFYA_targets = (
    combined_df_tf_sig[combined_df_tf_sig["identifier"] == "ENSG00000001167"]["its_target"]
    .apply(lambda x: [d["NCBI.GeneID.Target"] for d in x] if isinstance(x, list) else [])
    .explode()
    .dropna()
    .unique()
    .tolist()
)

len(ncbi_gene_ids_NFYA_targets)
# Out:
# 502

# %%
# combined_df = combine_sources(
#     merged_df_human,
#     [
#     ppi_df,
#     ],
# )

# %%
# combined_metadata = create_or_append_to_metadata(
#     bridgedb_metadata_human,
#     [
#     ppi_metadata,
#     get_data_versions("hsapiens")
#     ],
# )

# %%
# combined_metadata

# %%
combined_df[combined_df["identifier"] == "CDKN1A"]["StringDB_ppi"].to_dict()
# Out:
# {}

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"].str.contains("OTF6", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [identifier, identifier.source, target, target.source, GENE_SYMBOL_dea, baseMean_dea, log2FoldChange_dea, lfcSE_dea, stat_dea, pvalue_dea, padj_dea, minus_log10_pvalue_dea, is_tf, is_target, its_target, its_tf, intersections, g:Profiler_corum, g:Profiler_go:bp, g:Profiler_go:cc, g:Profiler_go:mf, g:Profiler_hp, g:Profiler_hpa, g:Profiler_kegg, g:Profiler_mirna, g:Profiler_reac, g:Profiler_tf, g:Profiler_wp, MitoCarta, StringDB_ppi]
# Index: []
#
# [0 rows x 30 columns]

# %%
combined_df[combined_df["GENE_SYMBOL_dea"] == "MT-ND4"]
# Out:
#             identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 10722  ENSG00000198886           Ensembl   4538  ncbi_gene_id          MT-ND4
#
#        baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 10722  1.098081e+06           -0.722805   0.164567 -4.392165    0.000011  ...
#
#                                         g:Profiler_go:mf  \
# 10722  [{'id': 'GO:0016491', 'name': 'oxidoreductase ...
#
#                                            g:Profiler_hp  \
# 10722  [{'id': 'HP:0001941', 'name': 'Acidosis', 'p_v...
#
#                                           g:Profiler_hpa  \
# 10722  [{'id': 'HPA:0440341', 'name': 'skeletal muscl...
#
#                                          g:Profiler_kegg  \
# 10722  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                         g:Profiler_mirna  \
# 10722  [{'id': 'MIRNA:hsa-miR-652-3p', 'name': 'hsa-m...
#
#                                          g:Profiler_reac  \
# 10722  [{'id': 'REAC:R-HSA-1428517', 'name': 'The cit...
#
#                                            g:Profiler_tf  \
# 10722  [{'id': 'TF:M07428', 'name': 'Factor: Six-3; m...
#
#                                            g:Profiler_wp  \
# 10722  [{'id': 'WP:WP111', 'name': 'Electron transpor...
#
#                                                MitoCarta  \
# 10722  [{'gene_description': 'NADH dehydrogenase, sub...
#
#                                             StringDB_ppi
# 10722  [{'stringdb_link_to': 'ENSG00000010256', 'Ense...
#
# [1 rows x 30 columns]

# %%
combined_df[combined_df["identifier"] == "ENSG00000198886"]["StringDB_ppi"].to_dict()
# Out:
# {10722: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.971,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000108179',
#    'Ensembl': 'ENSP00000225174',
#    'score': 0.404,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000130414',
#    'Ensembl': 'ENSP00000252711',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.553,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000213619',
#    'Ensembl': 'ENSP00000263774',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139180',
#    'Ensembl': 'ENSP00000266544',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000139631',
#    'Ensembl': 'ENSP00000267085',
#    'score': 0.428,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.513,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000005700',
#    'Ensembl': 'ENSP00000305721',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198899',
#    'Ensembl': 'ENSP00000354632',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'P00846',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198786',
#    'Ensembl': 'ENSP00000354813',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000105341',
#    'Ensembl': 'ENSP00000403910',
#    'score': 0.445,
#    'Uniprot-TrEMBL': 'Q9NW81',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000163541',
#    'Ensembl': 'ENSP00000377446',
#    'score': 0.458,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000103657',
#    'Ensembl': 'ENSP00000390158',
#    'score': 0.464,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000111640',
#    'Ensembl': 'ENSP00000380070',
#    'score': 0.507,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000101247',
#    'Ensembl': 'ENSP00000367346',
#    'score': 0.587,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'ENSP00000381736',
#    'score': 0.654,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000142875',
#    'Ensembl': 'ENSP00000359719',
#    'score': 0.666,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'ENSP00000356953',
#    'score': 0.696,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000131174',
#    'Ensembl': 'ENSP00000497474',
#    'score': 0.873,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'ENSP00000364649',
#    'score': 0.958,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000023228',
#    'Ensembl': 'ENSP00000392709',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000004779',
#    'Ensembl': 'ENSP00000458770',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198840',
#    'Ensembl': 'ENSP00000355206',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000167792',
#    'Ensembl': 'ENSP00000497587',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'ENSP00000355046',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000198938',
#    'Ensembl': 'ENSP00000354982',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSG00000158864',
#    'Ensembl': 'ENSP00000356972',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}]}

# %%
combined_df[combined_df["identifier"] == "ENSG00000005700"]["StringDB_ppi"].to_dict()
# Out:
# {81: [{'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'ENSP00000354961',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}]}

# %%
combined_df[combined_df["identifier"] == "ENSG00000108387"]
# Out:
#            identifier identifier.source target target.source  \
# 2558  ENSG00000108387           Ensembl   5414  ncbi_gene_id
#
#           GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea  \
# 2558  2004-09-01 00:00:00    193.471021            0.073477    0.13493
#
#       stat_dea  pvalue_dea  ...  g:Profiler_go:mf  g:Profiler_hp  \
# 2558  0.544556    0.586059  ...               NaN            NaN
#
#      g:Profiler_hpa g:Profiler_kegg g:Profiler_mirna g:Profiler_reac  \
# 2558            NaN             NaN              NaN             NaN
#
#      g:Profiler_tf g:Profiler_wp  \
# 2558           NaN           NaN
#
#                                               MitoCarta StringDB_ppi
# 2558  [{'gene_description': 'septin 4', 'evidence': ...          NaN
#
# [1 rows x 30 columns]

# %%
pygraph = generator.save_graph(
    combined_df=combined_df_tf_sig,
    combined_metadata=bridgedb_metadata_human,
    graph_name="graph_human",
    graph_dir="./data/human",
)
# Out:
# Combined DataFrame saved in ./data/human/graph_human/graph_human_df.pkl
# Metadata saved in ./data/human/graph_human/graph_human_metadata.pkl
# Building graph: 100%|██████████| 1535/1535 [00:04<00:00, 310.14it/s]
# Graph is built successfully
# Graph saved in ./data/human/graph_human/graph_human_graph.pkl and ./data/human/graph_human/graph_human_graph.gml

# %%
print(pygraph)
# Out:
# MultiDiGraph with 17603 nodes and 316748 edges

# %%
from pyBiodatafuse.graph import neo4j

neo4j.save_graph_to_graphml(pygraph, "data/human/graph_human/networkx_graph_human.graphml")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
