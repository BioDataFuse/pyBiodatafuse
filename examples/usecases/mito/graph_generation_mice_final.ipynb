# %% [markdown]
# ## Explore mitochondrial impairment in tumars

# %% [markdown]
# **Aim**: in this notebook, you will see all the steps for collecting data and constructing a KG to explore mitochondrial impairment in tumer (both in mice and mice)

# %% [markdown]
# ### Import required libraries

# %%
# Import modules
import gzip
import os
import pickle
from io import BytesIO

import numpy as np
import pandas as pd
import requests
from gprofiler.gprofiler import GProfiler

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import (
    bgee,
    disgenet,
    minerva,
    molmedb,
    opentargets,
    pubchem,
    stringdb,
    wikipathways,
)
from pyBiodatafuse.constants import BGEE_GENE_EXPRESSION_LEVELS_COL, DISGENET_DISEASE_COL, GPROFILER
from pyBiodatafuse.graph import generator
from pyBiodatafuse.utils import (
    combine_sources,
    create_harmonized_input_file,
    create_or_append_to_metadata,
    get_identifier_of_interest,
)

os.makedirs("data", exist_ok=True)
base_dir = os.path.abspath(os.getcwd())

# %% [markdown]
# ### Load the input files

# %%
all_genes_mice = pd.read_excel("datasets/Copy of 344P_cachexia_vs_sham_FDR_0.01_all_genes.xlsx" , usecols="B:J")
all_genes_mice.rename(
    columns={"Unnamed: 1": "identifier", "Unnamed: 2": "GENE_SYMBOL"}, inplace=True
)
all_genes_mice.head()
# Out:
#            identifier GENE_SYMBOL      baseMean  log2FoldChange     lfcSE  \
# 0  ENSMUSG00000021903     Galnt15   2770.437508        2.521182  0.099941
# 1  ENSMUSG00000059824         Dbp   2816.783019       -2.985239  0.191760
# 2  ENSMUSG00000041417      Pik3r1   2934.327264        2.047483  0.136776
# 3  ENSMUSG00000004939       Nmrk2    675.068734       -3.981474  0.274358
# 4  ENSMUSG00000028834      Trim63  44995.104413        3.738275  0.261289
#
#         stat         pvalue           padj  minus_log10_pvalue
# 0  25.226601  2.046157e-140  2.373133e-136          139.689061
# 1 -15.567614   1.208303e-54   7.006949e-51           53.917824
# 2  14.969629   1.159658e-50   4.483238e-47           49.935670
# 3 -14.511978   1.017437e-47   2.950057e-44           46.992493
# 4  14.307048   1.977304e-46   4.586555e-43           45.703926

# %%
# Read only specific columns and skip the first row
all_genes_mice = pd.read_excel("datasets/Copy of 344P_cachexia_vs_sham_FDR_0.01_all_genes.xlsx" , usecols="B:J")
all_genes_mice.rename(
    columns={"Unnamed: 1": "identifier", "Unnamed: 2": "GENE_SYMBOL"}, inplace=True
)
deg_mice = all_genes_mice[
     (all_genes_mice['padj'] < 0.01) &
    (
        (all_genes_mice['log2FoldChange'] > 1) |
        (all_genes_mice['log2FoldChange'] < -1)
    )
]
print("Number of genes:", len(all_genes_mice["identifier"].unique()))
print("Number of DEGs:", len(deg_mice["identifier"].unique()))
deg_mice.head(1)
# Out:
# Number of genes: 11599
# Number of DEGs: 846
#            identifier GENE_SYMBOL     baseMean  log2FoldChange     lfcSE  \
# 0  ENSMUSG00000021903     Galnt15  2770.437508        2.521182  0.099941
#
#         stat         pvalue           padj  minus_log10_pvalue
# 0  25.226601  2.046157e-140  2.373133e-136          139.689061

# %% [markdown]
# ### Entity resolution with BridgeDB

# %%
pickle_path_mice = os.path.join(base_dir, "data/mice/bridgedb_df_mice.pkl")
metadata_path_mice = os.path.join(base_dir, "data/mice/bridgedb_metadata_mice.pkl")

if not os.path.exists(pickle_path_mice):
    bridgedb_df_mice, bridgedb_metadata_mice = id_mapper.bridgedb_xref(
        identifiers=all_genes_mice,
        input_species="Mouse",
        input_datasource="Ensembl",
        output_datasource="All",
    )
    bridgedb_df_mice.to_pickle(pickle_path_mice)
    with open(metadata_path_mice, "wb") as file:
        pickle.dump(bridgedb_metadata_mice, file)
else:
    bridgedb_df_mice = pd.read_pickle(pickle_path_mice)
    with open(metadata_path_mice, "rb") as file:
        bridgedb_metadata_mice = pickle.load(file)

# %%
print("Number of genes with mapping in BridgeDb:", len(bridgedb_df_mice["identifier"].unique()))
bridgedb_df_mice.head(1)
# Out:
# Number of genes with mapping in BridgeDb: 11588
#            identifier identifier.source  target   target.source  \
# 0  ENSMUSG00000021903           Ensembl  Q9D2N8  Uniprot-TrEMBL
#
#   GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea  \
# 0         Galnt15   2770.437508            2.521182   0.099941  25.226601
#
#       pvalue_dea       padj_dea  minus_log10_pvalue_dea
# 0  2.046157e-140  2.373133e-136              139.689061

# %% [markdown]
# ### Enrichment analysis using g:Profiler
# all the pathways and annotations are being added despite being significance.

# %%
len(bridgedb_df_mice["identifier"].unique())
# Out:
# 11588

# %%
len(bridgedb_df_mice[
            (bridgedb_df_mice['padj_dea'] < 0.01) &
                (
                    (bridgedb_df_mice['log2FoldChange_dea'] > 1) |
                    (bridgedb_df_mice['log2FoldChange_dea'] < -1)
                )]["identifier"]
        .unique())
# Out:
# 846

# %%
gp = GProfiler(return_dataframe=True)
filename_mice = "data/mice/gprofiler_mice_0.01.pkl"
if not os.path.exists(filename_mice):
    gprofiler_mice = gp.profile(
        organism="mmusculus",
        all_results=True,
        query=bridgedb_df_mice[
            (bridgedb_df_mice['padj_dea'] < 0.01)]["identifier"]
        .unique()
        .tolist(),
        background=bridgedb_df_mice["identifier"].unique().tolist(),
        no_evidences=False,
        significance_threshold_method="fdr",
        user_threshold=0.05,
    )
    gprofiler_mice.rename(columns={"native": "id"}, inplace=True)
    gprofiler_mice["datasource"] = "g:Profiler"
    gprofiler_mice.to_pickle(filename_mice)
else:
    with open(filename_mice, "rb") as f:
        gprofiler_mice = pickle.load(f)

# %%
print(gprofiler_mice.shape)
gprofiler_mice.head(1)
# Out:
# (30481, 17)
#   source          id                      name   p_value  significant  \
# 0  GO:BP  GO:0032774  RNA biosynthetic process  0.001777         True
#
#                                          description  term_size  query_size  \
# 0  "The chemical reactions and pathways resulting...       2922        3953
#
#    intersection_size  effective_domain_size  precision    recall    query  \
# 0               1112                  11577   0.281305  0.380561  query_1
#
#                     parents  \
# 0  [GO:0016070, GO:0141187]
#
#                                        intersections  \
# 0  [ENSMUSG00000059824, ENSMUSG00000041417, ENSMU...
#
#                                            evidences  datasource
# 0  [[ISO, IBA, TAS, IEA], [IDA, IMP, ISS, ISO, IE...  g:Profiler

# %%
# Function to count upregulated and downregulated genes
def count_up_down(genes, bridgedb_df_mice):
    if not isinstance(genes, list) or len(genes) == 0:  # Ensure genes is a list
        return 0, 0

    genes = [str(g).strip() for g in genes]
    filtered_df = bridgedb_df_mice[bridgedb_df_mice["identifier"].isin(genes)]

    upregulated = (filtered_df["log2FoldChange_dea"] > 0).sum()
    downregulated = (filtered_df["log2FoldChange_dea"] < 0).sum()
    
    return upregulated, downregulated

# %%
# Keep only significant results
gprofiler_sig_mice= gprofiler_mice[gprofiler_mice["significant"] == True]

# %%
gprofiler_sig_mice[["no_upregulated_genes", "no_downregulated_genes"]]  = gprofiler_sig_mice["intersections"].apply(
    lambda genes: pd.Series(count_up_down(genes, bridgedb_df_mice[bridgedb_df_mice["target.source"] == "Ensembl"]))
)
gprofiler_sig_mice.head(2)
# Out:
#   source          id                      name   p_value  significant  \
# 0  GO:BP  GO:0032774  RNA biosynthetic process  0.001777         True
# 1  GO:BP  GO:0016070     RNA metabolic process  0.002043         True
#
#                                          description  term_size  query_size  \
# 0  "The chemical reactions and pathways resulting...       2922        3953
# 1  "The cellular chemical reactions and pathways ...       3068        3953
#
#    intersection_size  effective_domain_size  precision    recall    query  \
# 0               1112                  11577   0.281305  0.380561  query_1
# 1               1160                  11577   0.293448  0.378096  query_1
#
#                     parents  \
# 0  [GO:0016070, GO:0141187]
# 1              [GO:0090304]
#
#                                        intersections  \
# 0  [ENSMUSG00000059824, ENSMUSG00000041417, ENSMU...
# 1  [ENSMUSG00000059824, ENSMUSG00000041417, ENSMU...
#
#                                            evidences  datasource  \
# 0  [[ISO, IBA, TAS, IEA], [IDA, IMP, ISS, ISO, IE...  g:Profiler
# 1  [[ISO, IBA, TAS, IEA], [IDA, IMP, ISS, ISO, IE...  g:Profiler
#
#    no_upregulated_genes  no_downregulated_genes
# 0                   783                     329
# 1                   814                     346

# %%
gprofiler_mice['significant'].value_counts()
# Out:
# significant
# False    30417
# True        64
# Name: count, dtype: int64

# %%
gprofiler_sig_mice.shape
# Out:
# (64, 19)

# %%
selected_columns = ["source", "id", "name", "p_value", "term_size", "intersection_size", "parents","no_upregulated_genes", "no_downregulated_genes"]
gprofiler_sig_mice[selected_columns].to_csv("data/mice/gprofiler_sig_mice_0.01.csv", index=False)

# %% [markdown]
# #### For the graph

# %%
gprofiler_mice[gprofiler_mice["id"] == "HP:0011805"]["intersections"].values
# Out:
# array([list(['ENSMUSG00000022270', 'ENSMUSG00000039242', 'ENSMUSG00000035606', 'ENSMUSG00000073418', 'ENSMUSG00000051627', 'ENSMUSG00000055435', 'ENSMUSG00000096054', 'ENSMUSG00000063275', 'ENSMUSG00000026012', 'ENSMUSG00000005360', 'ENSMUSG00000001627', 'ENSMUSG00000020593', 'ENSMUSG00000043639', 'ENSMUSG00000047407', 'ENSMUSG00000018076', 'ENSMUSG00000041235', 'ENSMUSG00000016559', 'ENSMUSG00000041798', 'ENSMUSG00000022094', 'ENSMUSG00000027274', 'ENSMUSG00000028766', 'ENSMUSG00000029009', 'ENSMUSG00000026179', 'ENSMUSG00000013539', 'ENSMUSG00000007613', 'ENSMUSG00000047635', 'ENSMUSG00000025509', 'ENSMUSG00000056537', 'ENSMUSG00000006307', 'ENSMUSG00000020744', 'ENSMUSG00000028414', 'ENSMUSG00000031381', 'ENSMUSG00000005686', 'ENSMUSG00000022510', 'ENSMUSG00000034083', 'ENSMUSG00000040363', 'ENSMUSG00000041695', 'ENSMUSG00000022617', 'ENSMUSG00000042548', 'ENSMUSG00000017491', 'ENSMUSG00000029683', 'ENSMUSG00000024589', 'ENSMUSG00000033107', 'ENSMUSG00000051456', 'ENSMUSG00000048126', 'ENSMUSG00000029163', 'ENSMUSG00000038594', 'ENSMUSG00000002831', 'ENSMUSG00000070348', 'ENSMUSG00000028736', 'ENSMUSG00000020241', 'ENSMUSG00000058454', 'ENSMUSG00000033323', 'ENSMUSG00000067825', 'ENSMUSG00000004951', 'ENSMUSG00000030278', 'ENSMUSG00000021994', 'ENSMUSG00000015243', 'ENSMUSG00000025352', 'ENSMUSG00000068699', 'ENSMUSG00000092035', 'ENSMUSG00000019842', 'ENSMUSG00000032788', 'ENSMUSG00000025608', 'ENSMUSG00000009471', 'ENSMUSG00000040136', 'ENSMUSG00000054978', 'ENSMUSG00000039410', 'ENSMUSG00000025777', 'ENSMUSG00000024803', 'ENSMUSG00000040724', 'ENSMUSG00000029610', 'ENSMUSG00000034799', 'ENSMUSG00000013584', 'ENSMUSG00000022500', 'ENSMUSG00000069919', 'ENSMUSG00000024330', 'ENSMUSG00000007122', 'ENSMUSG00000000567', 'ENSMUSG00000072235', 'ENSMUSG00000040841', 'ENSMUSG00000020475', 'ENSMUSG00000069917', 'ENSMUSG00000026043', 'ENSMUSG00000001119', 'ENSMUSG00000000489', 'ENSMUSG00000029304', 'ENSMUSG00000007888', 'ENSMUSG00000035969', 'ENSMUSG00000025007', 'ENSMUSG00000001506', 'ENSMUSG00000048279', 'ENSMUSG00000031425', 'ENSMUSG00000037251', 'ENSMUSG00000026971', 'ENSMUSG00000074622', 'ENSMUSG00000033579', 'ENSMUSG00000018217'])],
#       dtype=object)

# %%
gprofiler_mice = gprofiler_mice[
    ~gprofiler_mice["parents"].apply(lambda x: x == [])
]  # rm the root terms

# %%
# from pyBiodatafuse.constants import GPROFILER


def create_path_info(row):
    path_info = {
        col: row[col] for col in gprofiler_mice.columns if col not in ["intersections", "source"]
    }
    return path_info


gprofiler_mice["gprofiler"] = gprofiler_mice.apply(create_path_info, axis=1)
gprofiler_mice = gprofiler_mice.drop(
    columns=[
        col
        for col in gprofiler_mice.columns
        if col not in ["source", "id", "intersections", "gprofiler"]
    ]
)
gprofiler_mice = gprofiler_mice.explode("intersections").reset_index(drop=True)
unique_sources = sorted(gprofiler_mice["source"].unique())
gprofiler_mice_final = pd.DataFrame()
gprofiler_mice_final["intersections"] = gprofiler_mice["intersections"].unique()
for source in unique_sources:
    source_subset = gprofiler_mice[gprofiler_mice["source"] == source]
    source_dictionaries = source_subset.groupby("intersections")["gprofiler"].apply(list).to_dict()
    gprofiler_mice_final[f"{GPROFILER}_{str.lower(source)}"] = gprofiler_mice_final[
        "intersections"
    ].map(source_dictionaries)
gprofiler_mice_final.head(1)
# Out:
#         intersections g:Profiler_corum  \
# 0  ENSMUSG00000027947              NaN
#
#                                     g:Profiler_go:bp  \
# 0  [{'id': 'GO:0051239', 'name': 'regulation of m...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0005615', 'name': 'extracellular s...
#
#                                     g:Profiler_go:mf  \
# 0  [{'id': 'GO:0005102', 'name': 'signaling recep...
#
#                                        g:Profiler_hp  \
# 0  [{'id': 'HP:0030386', 'name': 'Abnormal propor...
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:04060', 'name': 'Cytokine-cytoki...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:mmu-miR-155-5p', 'name': 'mmu-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-MMU-162582', 'name': 'Signal T...
#
#                                        g:Profiler_tf  \
# 0  [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...
#
#                                        g:Profiler_wp
# 0  [{'id': 'WP:WP2841', 'name': 'Focal adhesion P...

# %%
## get version


def get_data_versions(organism):
    url = "https://biit.cs.ut.ee/gprofiler/api/util/data_versions"
    params = {"organism": organism}
    try:
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            return data
        else:
            raise Exception(f"Failed to retrieve data: {response.status_code}")
    except Exception as e:
        return {"error": str(e)}


get_data_versions("mmusculus")
# Out:
# {'biomart': 'Ensembl',
#  'biomart_version': '111',
#  'display_name': 'Mouse',
#  'genebuild': 'GRCm39',
#  'gprofiler_version': 'e111_eg58_p18_f463989d',
#  'organism': 'mmusculus',
#  'sources': {'CORUM': {'name': 'CORUM protein complexes',
#    'version': '28.11.2022 Corum 4.1'},
#   'GO:BP': {'name': 'biological process',
#    'version': 'annotations: BioMart\nclasses: releases/2024-01-17'},
#   'GO:CC': {'name': 'cellular component',
#    'version': 'annotations: BioMart\nclasses: releases/2024-01-17'},
#   'GO:MF': {'name': 'molecular function',
#    'version': 'annotations: BioMart\nclasses: releases/2024-01-17'},
#   'HP': {'name': 'Human Phenotype Ontology',
#    'version': 'annotations: 01.2024\nclasses: None'},
#   'KEGG': {'name': 'Kyoto Encyclopedia of Genes and Genomes',
#    'version': 'KEGG FTP Release 2024-01-22'},
#   'MIRNA': {'name': 'miRTarBase', 'version': 'Release 9.0'},
#   'REAC': {'name': 'Reactome',
#    'version': 'annotations: BioMart\nclasses: 2024-1-25'},
#   'TF': {'name': 'Transfac',
#    'version': 'annotations: TRANSFAC Release 2023.2\nclasses: v2'},
#   'WP': {'name': 'WikiPathways', 'version': '20240101'}},
#  'taxonomy_id': '10090'}

# %%
ncbi_tf_gprofiler_df_mice = pd.merge(
    ncbi_tf_df_mice,
    gprofiler_mice_final,
    left_on="identifier",
    right_on="intersections",
    how="outer",
)

# %%
ncbi_tf_gprofiler_df_mice.head(2)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl  78754     NCBI Gene         Galnt15
# 1  ENSMUSG00000059824           Ensembl  13170     NCBI Gene             Dbp
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  ...  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140  ...
# 1   2816.783019           -2.985239   0.191760 -15.567614   1.208303e-54  ...
#
#    g:Profiler_corum                                   g:Profiler_go:bp  \
# 0               NaN  [{'id': 'GO:0006493', 'name': 'protein O-linke...
# 1               NaN  [{'id': 'GO:0048518', 'name': 'positive regula...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0030133', 'name': 'transport vesic...
# 1  [{'id': 'GO:0005667', 'name': 'transcription r...
#
#                                     g:Profiler_go:mf g:Profiler_hp  \
# 0  [{'id': 'GO:0030246', 'name': 'carbohydrate bi...           NaN
# 1  [{'id': 'GO:0000981', 'name': 'DNA-binding tra...           NaN
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
# 1  [{'id': 'KEGG:04710', 'name': 'Circadian rhyth...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:mmu-miR-34b-5p', 'name': 'mmu-m...
# 1  [{'id': 'MIRNA:mmu-miR-122-5p', 'name': 'mmu-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-MMU-5173105', 'name': 'O-linke...
# 1                                                NaN
#
#                                        g:Profiler_tf g:Profiler_wp
# 0  [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...           NaN
# 1  [{'id': 'TF:M03882', 'name': 'Factor: RelB:p50...           NaN
#
# [2 rows x 27 columns]

# %%
ncbi_tf_gprofiler_df_mice[ncbi_tf_gprofiler_df_mice["g:Profiler_reac"].notna()].head(1)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl  78754     NCBI Gene         Galnt15
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  ...  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140  ...
#
#    g:Profiler_corum                                   g:Profiler_go:bp  \
# 0               NaN  [{'id': 'GO:0006493', 'name': 'protein O-linke...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0030133', 'name': 'transport vesic...
#
#                                     g:Profiler_go:mf g:Profiler_hp  \
# 0  [{'id': 'GO:0030246', 'name': 'carbohydrate bi...           NaN
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:mmu-miR-34b-5p', 'name': 'mmu-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-MMU-5173105', 'name': 'O-linke...
#
#                                        g:Profiler_tf g:Profiler_wp
# 0  [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...           NaN
#
# [1 rows x 27 columns]

# %%
ncbi_tf_gprofiler_df_mice[ncbi_tf_gprofiler_df_mice["g:Profiler_reac"].notna()].head(1)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl  78754     NCBI Gene         Galnt15
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  ...  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140  ...
#
#    g:Profiler_corum                                   g:Profiler_go:bp  \
# 0               NaN  [{'id': 'GO:0006493', 'name': 'protein O-linke...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0030133', 'name': 'transport vesic...
#
#                                     g:Profiler_go:mf g:Profiler_hp  \
# 0  [{'id': 'GO:0030246', 'name': 'carbohydrate bi...           NaN
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:mmu-miR-34b-5p', 'name': 'mmu-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-MMU-5173105', 'name': 'O-linke...
#
#                                        g:Profiler_tf g:Profiler_wp
# 0  [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...           NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# ### Add MitoCarta data

# %%
# URLs for the mice MitoCarta Dataset
mitocarta_url_mice = (
    "https://personal.broadinstitute.org/scalvo/MitoCarta3.0/Mouse.MitoCarta3.0.xls"
)


# Function to download and read a gzipped file into a dataframe
def download_save_and_read(url, filename):
    if not os.path.exists(filename):
        response = requests.get(url)
        with open(filename, "wb") as file:
            file.write(response.content)
    else:
        print(f"{filename} already exists, skipping download.")

    # Load the second sheet ("A Mouse MitoCarta3.0") into a DataFrame
    df = pd.read_excel(url, sheet_name="A Mouse MitoCarta3.0")
    return df


# Download and read the mice MitoCarta dataset
mitocarta_mice_df = download_save_and_read(mitocarta_url_mice, "data/mice/mice_mitocarta3.0.xls")

mitocarta_mice_df.head(1)
# Out:
# data/mice/mice_mitocarta3.0.xls already exists, skipping download.
#    MouseGeneID  HumanOrthologGeneID Symbol                      Synonyms  \
# 0        66445               1537.0   Cyc1  2610002H19Rik|AA408921|Cyct1
#
#       Description MitoCarta3.0_List  \
# 0  cytochrome c-1      MitoCarta3.0
#
#                                MitoCarta3.0_Evidence  \
# 0  literature, APEX_IMS, APEX_matrix, targetP sig...
#
#   MitoCarta3.0_SubMitoLocalization  \
# 0                              MIM
#
#                            MitoCarta3.0_MitoPathways TrainingDataset  ...  \
# 0  OXPHOS > Complex III > CIII subunits | Metabol...           Tmito  ...
#
#    liver_total_peak_intensity_log10  heart_total_peak_intensity_log10  \
# 0                              10.0                              10.4
#
#    skeletalmuscle_total_peak_intensity_log10  \
# 0                                        9.8
#
#   adipose_total_peak_intensity_log10  \
# 0                               10.1
#
#   smallintestine_total_peak_intensity_log10  \
# 0                                      10.2
#
#   largeintestine_total_peak_intensity_log10  \
# 0                                      10.2
#
#    stomach_total_peak_intensity_log10  placenta_total_peak_intensity_log10  \
# 0                                10.0                                 10.0
#
#   testis_total_peak_intensity_log10  HPA_Main_Location_2020 (Reliability)
# 0                               9.8              Mitochondria (Supported)
#
# [1 rows x 48 columns]

# %%
# Select relevant columns for inclusion in the graph
selected_columns_mice = [
    "EnsemblGeneID",
    "Description",
    "MitoCarta3.0_Evidence",
    "MitoCarta3.0_SubMitoLocalization",
    "MitoCarta3.0_MitoPathways",
    "HPA_Main_Location_2020 (Reliability)",
    "Tissues",
]

mitocarta_mice_selected = mitocarta_mice_df[selected_columns_mice]

# Rename columns for clarity
mitocarta_mice_selected.rename(
    columns={
        "EnsemblGeneID": "ensembl_id",
        "Description": "gene_description",
        "MitoCarta3.0_Evidence": "evidence",
        "MitoCarta3.0_SubMitoLocalization": "sub_mito_localization",
        "MitoCarta3.0_MitoPathways": "mito_pathways",
        "HPA_Main_Location_2020 (Reliability)": "hpa_location",
        "Tissues": "tissue_expression",
    },
    inplace=True,
)

# %%
mitocarta_mice_selected["mito_pathways"] = (
    mitocarta_mice_selected["mito_pathways"]
    .str.split(">")
    .str[-1]
    .str.split("|")
    .str[0]
    .str.strip()
)
mitocarta_mice_selected.head(1)
# Out:
#            ensembl_id gene_description  \
# 0  ENSMUSG00000022551   cytochrome c-1
#
#                                             evidence sub_mito_localization  \
# 0  literature, APEX_IMS, APEX_matrix, targetP sig...                   MIM
#
#      mito_pathways              hpa_location tissue_expression
# 0  OXPHOS subunits  Mitochondria (Supported)            all 14

# %%
mitocarta_mice_selected = mitocarta_mice_selected.dropna(subset=["mito_pathways"]).reset_index(drop=True) # Drop rows with missing mito_pathways
mitocarta_mice_selected["ensembl_id"] = mitocarta_mice_selected["ensembl_id"].str.split("|")
mitocarta_mice_selected = mitocarta_mice_selected.explode("ensembl_id").reset_index(drop=True)

# %%
mitocarta_mice_selected = mitocarta_mice_selected[mitocarta_mice_selected["ensembl_id"].isin(bridgedb_df_mice["identifier"][bridgedb_df_mice["padj_dea"] < 0.01])] # Keep only significant genes existing in our dataset

# %%
bridgedb_df_mice.head(1)
# Out:
#            identifier identifier.source  target   target.source  \
# 0  ENSMUSG00000021903           Ensembl  Q9D2N8  Uniprot-TrEMBL
#
#   GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea  \
# 0         Galnt15   2770.437508            2.521182   0.099941  25.226601
#
#       pvalue_dea       padj_dea  minus_log10_pvalue_dea
# 0  2.046157e-140  2.373133e-136              139.689061

# %%
mitocarta_mice_selected.head(3)
# Out:
#            ensembl_id                                   gene_description  \
# 0  ENSMUSG00000022551                                     cytochrome c-1
# 2  ENSMUSG00000003072  ATP synthase, H+ transporting, mitochondrial F...
# 7  ENSMUSG00000039640                mitochondrial ribosomal protein L12
#
#                                             evidence sub_mito_localization  \
# 0  literature, APEX_IMS, APEX_matrix, targetP sig...                   MIM
# 2  literature, APEX_matrix, targetP signal, yeast...                   MIM
# 7  literature, targetP signal+, yeast mito homolo...                Matrix
#
#             mito_pathways              hpa_location tissue_expression
# 0         OXPHOS subunits  Mitochondria (Supported)            all 14
# 2         OXPHOS subunits                       NaN            all 14
# 7  Mitochondrial ribosome  Mitochondria (Supported)            all 14

# %%
aggregated_mitocarta_mice_selected = mitocarta_mice_selected.groupby("mito_pathways").agg(
    {
        "ensembl_id": list,
    }
).reset_index()
aggregated_mitocarta_mice_selected["intersections"] = aggregated_mitocarta_mice_selected["ensembl_id"].apply(len)

# %%
aggregated_mitocarta_mice_selected.head(4)
# Out:
#                mito_pathways  \
# 0           ABC transporters
# 1                  Apoptosis
# 2                  Autophagy
# 3  Biotin utilizing proteins
#
#                                           ensembl_id  intersections  \
# 0  [ENSMUSG00000031974, ENSMUSG00000055782, ENSMU...              3
# 1  [ENSMUSG00000036932, ENSMUSG00000058927, ENSMU...              9
# 2  [ENSMUSG00000025040, ENSMUSG00000029500, ENSMU...              4
# 3                               [ENSMUSG00000042010]              1
#
#    no_upregulated_genes  no_downregulated_genes
# 0                     0                       3
# 1                     5                       4
# 2                     3                       1
# 3                     1                       0

# %%
aggregated_mitocarta_mice_selected[["no_upregulated_genes", "no_downregulated_genes"]]  = aggregated_mitocarta_mice_selected["ensembl_id"].apply(
    lambda genes: pd.Series(count_up_down(genes, bridgedb_df_mice[bridgedb_df_mice["target.source"] == "Ensembl"]))
)

# %%
aggregated_mitocarta_mice_selected.to_csv("data/mice/mitocarta_mice_0.01.csv", index=False)

# %%
aggregated_mitocarta_mice_selected
# Out:
#                                       mito_pathways  \
# 0                                  ABC transporters
# 1                                         Apoptosis
# 2                                         Autophagy
# 3                         Biotin utilizing proteins
# 4   Branched-chain amino acid dehydrogenase complex
# ..                                              ...
# 76                                     mtDNA repair
# 77                                mtDNA replication
# 78                        mtDNA stability and decay
# 79                                   mtRNA granules
# 80                        mtRNA stability and decay
#
#                                            ensembl_id  intersections  \
# 0   [ENSMUSG00000031974, ENSMUSG00000055782, ENSMU...              3
# 1   [ENSMUSG00000036932, ENSMUSG00000058927, ENSMU...              9
# 2   [ENSMUSG00000025040, ENSMUSG00000029500, ENSMU...              4
# 3                                [ENSMUSG00000042010]              1
# 4                                [ENSMUSG00000037826]              1
# ..                                                ...            ...
# 76                               [ENSMUSG00000029591]              1
# 77                               [ENSMUSG00000002814]              1
# 78           [ENSMUSG00000042787, ENSMUSG00000027424]              2
# 79                               [ENSMUSG00000029624]              1
# 80           [ENSMUSG00000024234, ENSMUSG00000028959]              2
#
#     no_upregulated_genes  no_downregulated_genes
# 0                      0                       3
# 1                      5                       4
# 2                      3                       1
# 3                      1                       0
# 4                      0                       1
# ..                   ...                     ...
# 76                     0                       1
# 77                     1                       0
# 78                     0                       2
# 79                     1                       0
# 80                     1                       1
#
# [81 rows x 5 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #### For the graph

# %%
from pyBiodatafuse.constants import MITOCARTA

df_melted = mitocarta_mice_selected.apply(
    lambda row: [row["ensembl_id"], [row.drop("ensembl_id").to_dict()]], axis=1
)
df_transformed = pd.DataFrame(df_melted.tolist(), columns=["ensembl_id", MITOCARTA])
df_transformed.head()
# Out:
#            ensembl_id                                          MitoCarta
# 0  ENSMUSG00000022551  [{'gene_description': 'cytochrome c-1', 'evide...
# 1  ENSMUSG00000031299  [{'gene_description': 'pyruvate dehydrogenase ...
# 2  ENSMUSG00000003072  [{'gene_description': 'ATP synthase, H+ transp...
# 3  ENSMUSG00000021241  [{'gene_description': 'iron-sulfur cluster ass...
# 4  ENSMUSG00000021748  [{'gene_description': 'pyruvate dehydrogenase ...

# %%
# Merge mice MitoCarta with the graph dataset
ncbi_tf_gprofiler_mitocarta_df_mice = pd.merge(
    ncbi_tf_gprofiler_df_mice,
    df_transformed,
    left_on="identifier",
    right_on="ensembl_id",
    how="left",
).drop(columns=["ensembl_id"])

ncbi_tf_gprofiler_mitocarta_df_mice.head(67)
# Out:
#             identifier identifier.source  target target.source  \
# 0   ENSMUSG00000021903           Ensembl   78754     NCBI Gene
# 1   ENSMUSG00000059824           Ensembl   13170     NCBI Gene
# 2   ENSMUSG00000041417           Ensembl   18708     NCBI Gene
# 3   ENSMUSG00000004939           Ensembl   69564     NCBI Gene
# 4   ENSMUSG00000028834           Ensembl  433766     NCBI Gene
# ..                 ...               ...     ...           ...
# 62  ENSMUSG00000044938           Ensembl  244923     NCBI Gene
# 63  ENSMUSG00000025612           Ensembl   12013     NCBI Gene
# 64  ENSMUSG00000027496           Ensembl   20878     NCBI Gene
# 65  ENSMUSG00000075327           Ensembl  381990     NCBI Gene
# 66  ENSMUSG00000046668           Ensembl   67393     NCBI Gene
#
#    GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea  \
# 0          Galnt15   2770.437508            2.521182   0.099941  25.226601
# 1              Dbp   2816.783019           -2.985239   0.191760 -15.567614
# 2           Pik3r1   2934.327264            2.047483   0.136776  14.969629
# 3            Nmrk2    675.068734           -3.981474   0.274358 -14.511978
# 4           Trim63  44995.104413            3.738275   0.261289  14.307048
# ..             ...           ...                 ...        ...        ...
# 62          Klhl31  14539.906824           -1.154039   0.120236  -9.598146
# 63           Bach1   2266.828985            1.633857   0.170924   9.558977
# 64           Aurka    311.745006           -1.896545   0.198482  -9.555240
# 65           Zbtb2    454.438141            1.730660   0.182292   9.493914
# 66           Cxxc5    501.155326           -1.659495   0.174947  -9.485730
#
#        pvalue_dea  ...                                   g:Profiler_go:bp  \
# 0   2.046157e-140  ...  [{'id': 'GO:0006493', 'name': 'protein O-linke...
# 1    1.208303e-54  ...  [{'id': 'GO:0048518', 'name': 'positive regula...
# 2    1.159658e-50  ...  [{'id': 'GO:0051239', 'name': 'regulation of m...
# 3    1.017437e-47  ...  [{'id': 'GO:0048869', 'name': 'cellular develo...
# 4    1.977304e-46  ...  [{'id': 'GO:0051239', 'name': 'regulation of m...
# ..            ...  ...                                                ...
# 62   8.139554e-22  ...  [{'id': 'GO:0050896', 'name': 'response to sti...
# 63   1.189265e-21  ...  [{'id': 'GO:0050896', 'name': 'response to sti...
# 64   1.232977e-21  ...  [{'id': 'GO:0050896', 'name': 'response to sti...
# 65   2.225187e-21  ...  [{'id': 'GO:0051239', 'name': 'regulation of m...
# 66   2.406926e-21  ...  [{'id': 'GO:0048519', 'name': 'negative regula...
#
#                                      g:Profiler_go:cc  \
# 0   [{'id': 'GO:0030133', 'name': 'transport vesic...
# 1   [{'id': 'GO:0005667', 'name': 'transcription r...
# 2   [{'id': 'GO:0005942', 'name': 'phosphatidylino...
# 3   [{'id': 'GO:0071944', 'name': 'cell periphery'...
# 4   [{'id': 'GO:0043292', 'name': 'contractile fib...
# ..                                                ...
# 62  [{'id': 'GO:0005737', 'name': 'cytoplasm', 'p_...
# 63  [{'id': 'GO:0005667', 'name': 'transcription r...
# 64  [{'id': 'GO:0071944', 'name': 'cell periphery'...
# 65  [{'id': 'GO:0005622', 'name': 'intracellular a...
# 66  [{'id': 'GO:0005737', 'name': 'cytoplasm', 'p_...
#
#                                      g:Profiler_go:mf  \
# 0   [{'id': 'GO:0030246', 'name': 'carbohydrate bi...
# 1   [{'id': 'GO:0000981', 'name': 'DNA-binding tra...
# 2   [{'id': 'GO:0005102', 'name': 'signaling recep...
# 3   [{'id': 'GO:0005515', 'name': 'protein binding...
# 4   [{'id': 'GO:0005515', 'name': 'protein binding...
# ..                                                ...
# 62  [{'id': 'GO:0005515', 'name': 'protein binding...
# 63  [{'id': 'GO:0005515', 'name': 'protein binding...
# 64  [{'id': 'GO:0140677', 'name': 'molecular funct...
# 65  [{'id': 'GO:0005515', 'name': 'protein binding...
# 66  [{'id': 'GO:0005515', 'name': 'protein binding...
#
#                                         g:Profiler_hp  \
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'id': 'HP:0025539', 'name': 'Abnormal B cell...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 62                                                NaN
# 63                                                NaN
# 64  [{'id': 'HP:0001442', 'name': 'Typified by som...
# 65                                                NaN
# 66                                                NaN
#
#                                       g:Profiler_kegg  \
# 0   [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
# 1   [{'id': 'KEGG:04710', 'name': 'Circadian rhyth...
# 2   [{'id': 'KEGG:04933', 'name': 'AGE-RAGE signal...
# 3   [{'id': 'KEGG:00760', 'name': 'Nicotinate and ...
# 4                                                 NaN
# ..                                                ...
# 62                                                NaN
# 63                                                NaN
# 64  [{'id': 'KEGG:04114', 'name': 'Oocyte meiosis'...
# 65                                                NaN
# 66                                                NaN
#
#                                      g:Profiler_mirna  \
# 0   [{'id': 'MIRNA:mmu-miR-34b-5p', 'name': 'mmu-m...
# 1   [{'id': 'MIRNA:mmu-miR-122-5p', 'name': 'mmu-m...
# 2   [{'id': 'MIRNA:mmu-miR-340-5p', 'name': 'mmu-m...
# 3   [{'id': 'MIRNA:mmu-miR-709', 'name': 'mmu-miR-...
# 4                                                 NaN
# ..                                                ...
# 62  [{'id': 'MIRNA:mmu-miR-1897-5p', 'name': 'mmu-...
# 63  [{'id': 'MIRNA:mmu-miR-122-5p', 'name': 'mmu-m...
# 64                                                NaN
# 65  [{'id': 'MIRNA:mmu-miR-431-5p', 'name': 'mmu-m...
# 66  [{'id': 'MIRNA:mmu-miR-410-3p', 'name': 'mmu-m...
#
#                                       g:Profiler_reac  \
# 0   [{'id': 'REAC:R-MMU-5173105', 'name': 'O-linke...
# 1                                                 NaN
# 2   [{'id': 'REAC:R-MMU-6806834', 'name': 'Signali...
# 3   [{'id': 'REAC:R-MMU-196854', 'name': 'Metaboli...
# 4                                                 NaN
# ..                                                ...
# 62                                                NaN
# 63  [{'id': 'REAC:R-MMU-9707616', 'name': 'Heme si...
# 64  [{'id': 'REAC:R-MMU-6804114', 'name': 'TP53 Re...
# 65                                                NaN
# 66                                                NaN
#
#                                         g:Profiler_tf  \
# 0   [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...
# 1   [{'id': 'TF:M03882', 'name': 'Factor: RelB:p50...
# 2   [{'id': 'TF:M00446_1', 'name': 'Factor: Spz1; ...
# 3   [{'id': 'TF:M00446_1', 'name': 'Factor: Spz1; ...
# 4   [{'id': 'TF:M10174_1', 'name': 'Factor: AR; mo...
# ..                                                ...
# 62  [{'id': 'TF:M00407', 'name': 'Factor: RSRFC4; ...
# 63  [{'id': 'TF:M07094', 'name': 'Factor: FOXO1A; ...
# 64  [{'id': 'TF:M08998_1', 'name': 'Factor: GR; mo...
# 65  [{'id': 'TF:M10351', 'name': 'Factor: PTF1; mo...
# 66  [{'id': 'TF:M00446_1', 'name': 'Factor: Spz1; ...
#
#                                         g:Profiler_wp MitoCarta
# 0                                                 NaN       NaN
# 1                                                 NaN       NaN
# 2   [{'id': 'WP:WP2841', 'name': 'Focal adhesion P...       NaN
# 3                                                 NaN       NaN
# 4   [{'id': 'WP:WP5024', 'name': 'Hypoxia dependen...       NaN
# ..                                                ...       ...
# 62                                                NaN       NaN
# 63                                                NaN       NaN
# 64                                                NaN       NaN
# 65                                                NaN       NaN
# 66                                                NaN       NaN
#
# [67 rows x 28 columns]

# %%
ncbi_tf_gprofiler_mitocarta_df_mice[MITOCARTA][11242]
# Out:
# [{'gene_description': 'lactate dehydrogenase A-like 6B',
#   'evidence': 'targetP signal, Rickettsial homolog, mito protein domain, MS/MS',
#   'sub_mito_localization': 'Matrix',
#   'mito_pathways': 'Carbohydrate metabolism',
#   'hpa_location': nan,
#   'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}]

# %%
ncbi_tf_gprofiler_mitocarta_df_mice["target.source"] = ncbi_tf_gprofiler_mitocarta_df_mice[
    "target.source"
].str.replace("NCBI Gene", "ncbi_gene_id", regex=False)

ncbi_tf_gprofiler_mitocarta_df_mice.head(1)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl  78754  ncbi_gene_id         Galnt15
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  ...  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140  ...
#
#                                     g:Profiler_go:bp  \
# 0  [{'id': 'GO:0006493', 'name': 'protein O-linke...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0030133', 'name': 'transport vesic...
#
#                                     g:Profiler_go:mf g:Profiler_hp  \
# 0  [{'id': 'GO:0030246', 'name': 'carbohydrate bi...           NaN
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:mmu-miR-34b-5p', 'name': 'mmu-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-MMU-5173105', 'name': 'O-linke...
#
#                                        g:Profiler_tf g:Profiler_wp MitoCarta
# 0  [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...           NaN       NaN
#
# [1 rows x 28 columns]

# %%
ncbi_tf_gprofiler_mitocarta_df_mice[MITOCARTA].to_dict()
# Out:
# {0: nan,
#  1: nan,
#  2: nan,
#  3: nan,
#  4: nan,
#  5: nan,
#  6: nan,
#  7: nan,
#  8: nan,
#  9: nan,
#  10: nan,
#  11: nan,
#  12: nan,
#  13: nan,
#  14: nan,
#  15: nan,
#  16: nan,
#  17: nan,
#  18: nan,
#  19: nan,
#  20: nan,
#  21: nan,
#  22: nan,
#  23: nan,
#  24: nan,
#  25: nan,
#  26: nan,
#  27: nan,
#  28: nan,
#  29: nan,
#  30: [{'gene_description': 'acyl-CoA thioesterase 2',
#    'evidence': 'literature, targetP signal, mito protein domain, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Lipid metabolism',
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  31: nan,
#  32: nan,
#  33: nan,
#  34: nan,
#  35: nan,
#  36: nan,
#  37: nan,
#  38: [{'gene_description': 'pyruvate dehydrogenase kinase, isoenzyme 4',
#    'evidence': 'literature, targetP signal, yeast mito homolog+, mito protein domain+, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Pyruvate metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, testis'}],
#  39: nan,
#  40: nan,
#  41: nan,
#  42: nan,
#  43: nan,
#  44: nan,
#  45: nan,
#  46: nan,
#  47: nan,
#  48: nan,
#  49: nan,
#  50: nan,
#  51: nan,
#  52: nan,
#  53: nan,
#  54: nan,
#  55: nan,
#  56: nan,
#  57: nan,
#  58: nan,
#  59: nan,
#  60: nan,
#  61: nan,
#  62: nan,
#  63: nan,
#  64: nan,
#  65: nan,
#  66: nan,
#  67: nan,
#  68: nan,
#  69: nan,
#  70: nan,
#  71: nan,
#  72: nan,
#  73: nan,
#  74: nan,
#  75: nan,
#  76: nan,
#  77: nan,
#  78: nan,
#  79: nan,
#  80: nan,
#  81: nan,
#  82: nan,
#  83: nan,
#  84: nan,
#  85: nan,
#  86: nan,
#  87: nan,
#  88: nan,
#  89: nan,
#  90: nan,
#  91: nan,
#  92: nan,
#  93: nan,
#  94: nan,
#  95: nan,
#  96: nan,
#  97: nan,
#  98: [{'gene_description': 'acyl-CoA synthetase long-chain family member 6',
#    'evidence': 'yeast mito homolog, Rickettsial homolog, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Fatty acid oxidation',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, largeintestine, stomach, testis'}],
#  99: nan,
#  100: nan,
#  101: nan,
#  102: nan,
#  103: nan,
#  104: nan,
#  105: nan,
#  106: nan,
#  107: nan,
#  108: nan,
#  109: nan,
#  110: nan,
#  111: nan,
#  112: nan,
#  113: nan,
#  114: nan,
#  115: nan,
#  116: nan,
#  117: nan,
#  118: nan,
#  119: nan,
#  120: nan,
#  121: nan,
#  122: nan,
#  123: [{'gene_description': 'solute carrier family 25, member 39',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+, induction, coexpression',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': nan,
#    'tissue_expression': nan}],
#  124: nan,
#  125: nan,
#  126: nan,
#  127: nan,
#  128: nan,
#  129: nan,
#  130: nan,
#  131: nan,
#  132: nan,
#  133: nan,
#  134: nan,
#  135: nan,
#  136: nan,
#  137: nan,
#  138: nan,
#  139: nan,
#  140: nan,
#  141: nan,
#  142: nan,
#  143: nan,
#  144: nan,
#  145: nan,
#  146: nan,
#  147: nan,
#  148: nan,
#  149: nan,
#  150: nan,
#  151: nan,
#  152: nan,
#  153: nan,
#  154: nan,
#  155: nan,
#  156: nan,
#  157: nan,
#  158: nan,
#  159: nan,
#  160: nan,
#  161: nan,
#  162: nan,
#  163: nan,
#  164: nan,
#  165: nan,
#  166: nan,
#  167: nan,
#  168: nan,
#  169: nan,
#  170: [{'gene_description': "exonuclease 3'-5' domain containing 2",
#    'evidence': 'literature,mito protein domain',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Translation',
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'cerebrum, cerebellum, testis'}],
#  171: nan,
#  172: nan,
#  173: nan,
#  174: nan,
#  175: nan,
#  176: nan,
#  177: nan,
#  178: nan,
#  179: nan,
#  180: nan,
#  181: nan,
#  182: nan,
#  183: nan,
#  184: nan,
#  185: nan,
#  186: nan,
#  187: nan,
#  188: nan,
#  189: nan,
#  190: nan,
#  191: nan,
#  192: nan,
#  193: nan,
#  194: nan,
#  195: nan,
#  196: nan,
#  197: nan,
#  198: nan,
#  199: nan,
#  200: nan,
#  201: nan,
#  202: nan,
#  203: nan,
#  204: nan,
#  205: nan,
#  206: nan,
#  207: [{'gene_description': 'molybdenum cofactor synthesis 1',
#    'evidence': 'APEX_matrix, targetP signal, mito protein domain+, MS/MS+',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Molybdenum cofactor synthesis and proteins',
#    'hpa_location': 'Cytosol (Approved)',
#    'tissue_expression': 'cerebrum, liver, adipose, smallintestine, largeintestine, stomach, placenta'}],
#  208: [{'gene_description': 'paroxysmal nonkinesiogenic dyskinesia',
#    'evidence': 'literature,targetP signal, mito protein domain, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Enhanced)',
#    'tissue_expression': 'cerebrum, cerebellum, spinalcord, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  209: nan,
#  210: nan,
#  211: nan,
#  212: nan,
#  213: nan,
#  214: nan,
#  215: nan,
#  216: [{'gene_description': 'solute carrier family 25, member 34',
#    'evidence': 'yeast mito homolog+, mito protein domain+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': nan}],
#  217: nan,
#  218: nan,
#  219: nan,
#  220: nan,
#  221: nan,
#  222: [{'gene_description': 'HemK methyltransferase family member 1',
#    'evidence': 'GFP, targetP signal, yeast mito homolog, Rickettsial homolog, mito protein domain+',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Translation factors',
#    'hpa_location': nan,
#    'tissue_expression': nan}],
#  223: nan,
#  224: nan,
#  225: nan,
#  226: nan,
#  227: nan,
#  228: nan,
#  229: nan,
#  230: nan,
#  231: nan,
#  232: nan,
#  233: nan,
#  234: nan,
#  235: nan,
#  236: nan,
#  237: [{'gene_description': 'RIKEN cDNA 2810006K23 gene',
#    'evidence': 'literature, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Translation factors',
#    'hpa_location': 'Cytosol;Nucleoplasm (Approved)',
#    'tissue_expression': 'cerebrum, brainstem, spinalcord, adipose, largeintestine, stomach, placenta'}],
#  238: nan,
#  239: nan,
#  240: nan,
#  241: nan,
#  242: nan,
#  243: nan,
#  244: nan,
#  245: [{'gene_description': 'coenzyme Q10B',
#    'evidence': 'GFP, targetP signal, yeast mito homolog+, Rickettsial homolog, mito protein domain+, MS/MS+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Coenzyme Q metabolism',
#    'hpa_location': 'Cytosol (Approved)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, largeintestine, stomach, placenta'}],
#  246: nan,
#  247: nan,
#  248: nan,
#  249: nan,
#  250: nan,
#  251: nan,
#  252: nan,
#  253: nan,
#  254: nan,
#  255: nan,
#  256: nan,
#  257: nan,
#  258: [{'gene_description': 'solute carrier family 25 (mitochondrial thiamine pyrophosphate carrier), member 19',
#    'evidence': 'literature, yeast mito homolog++, mito protein domain+, induction, coexpression, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebellum, spinalcord, adipose, testis'}],
#  259: nan,
#  260: nan,
#  261: [{'gene_description': 'dephospho-CoA kinase domain containing',
#    'evidence': 'GFP, yeast mito homolog, Rickettsial homolog, mito protein domain, coexpression, MS/MS',
#    'sub_mito_localization': 'Membrane',
#    'mito_pathways': nan,
#    'hpa_location': 'Nucleoplasm (Approved)',
#    'tissue_expression': 'all 14'}],
#  262: nan,
#  263: nan,
#  264: nan,
#  265: nan,
#  266: nan,
#  267: nan,
#  268: nan,
#  269: nan,
#  270: nan,
#  271: nan,
#  272: nan,
#  273: nan,
#  274: nan,
#  275: nan,
#  276: nan,
#  277: nan,
#  278: nan,
#  279: nan,
#  280: nan,
#  281: nan,
#  282: nan,
#  283: nan,
#  284: nan,
#  285: nan,
#  286: nan,
#  287: nan,
#  288: nan,
#  289: nan,
#  290: nan,
#  291: nan,
#  292: nan,
#  293: nan,
#  294: [{'gene_description': 'transmembrane protein 126B',
#    'evidence': 'mito protein domain+, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  295: nan,
#  296: nan,
#  297: nan,
#  298: nan,
#  299: nan,
#  300: nan,
#  301: nan,
#  302: [{'gene_description': '3-hydroxy-3-methylglutaryl-Coenzyme A synthase 2',
#    'evidence': 'literature, targetP signal+, Rickettsial homolog, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Ketone metabolism',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebellum, spinalcord, liver, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  303: nan,
#  304: nan,
#  305: nan,
#  306: nan,
#  307: nan,
#  308: nan,
#  309: nan,
#  310: nan,
#  311: nan,
#  312: nan,
#  313: nan,
#  314: nan,
#  315: nan,
#  316: nan,
#  317: [{'gene_description': 'ribose 5-phosphate isomerase A',
#    'evidence': 'APEX_matrix, targetP signal',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Carbohydrate metabolism',
#    'hpa_location': 'Nucleoplasm;Plasma membrane;Vesicles (Approved)',
#    'tissue_expression': 'placenta'}],
#  318: nan,
#  319: nan,
#  320: nan,
#  321: nan,
#  322: nan,
#  323: nan,
#  324: nan,
#  325: nan,
#  326: nan,
#  327: nan,
#  328: nan,
#  329: nan,
#  330: nan,
#  331: nan,
#  332: nan,
#  333: nan,
#  334: [{'gene_description': 'malonyl-CoA decarboxylase',
#    'evidence': 'literature, APEX_matrix, targetP signal, mito protein domain, coexpression++, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Lipid metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta'}],
#  335: nan,
#  336: nan,
#  337: nan,
#  338: nan,
#  339: nan,
#  340: nan,
#  341: nan,
#  342: nan,
#  343: nan,
#  344: nan,
#  345: nan,
#  346: nan,
#  347: nan,
#  348: nan,
#  349: nan,
#  350: nan,
#  351: nan,
#  352: nan,
#  353: nan,
#  354: nan,
#  355: nan,
#  356: nan,
#  357: nan,
#  358: nan,
#  359: nan,
#  360: nan,
#  361: nan,
#  362: nan,
#  363: [{'gene_description': 'solute carrier family 25, member 28',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': nan,
#    'tissue_expression': nan}],
#  364: nan,
#  365: nan,
#  366: nan,
#  367: nan,
#  368: nan,
#  369: nan,
#  370: nan,
#  371: nan,
#  372: nan,
#  373: nan,
#  374: nan,
#  375: nan,
#  376: nan,
#  377: nan,
#  378: nan,
#  379: nan,
#  380: [{'gene_description': 'optic atrophy 3',
#    'evidence': 'literature, targetP signal, coexpression, MS/MS++',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': nan,
#    'hpa_location': 'Cytosol (Approved)',
#    'tissue_expression': 'all 14'}],
#  381: nan,
#  382: nan,
#  383: [{'gene_description': 'acyl-CoA synthetase short-chain family member 1',
#    'evidence': 'literature, APEX_matrix, targetP signal, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Fatty acid oxidation',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  384: [{'gene_description': 'uncoupling protein 2 (mitochondrial, proton carrier)',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': nan}],
#  385: nan,
#  386: nan,
#  387: nan,
#  388: nan,
#  389: nan,
#  390: nan,
#  391: nan,
#  392: nan,
#  393: nan,
#  394: nan,
#  395: nan,
#  396: nan,
#  397: nan,
#  398: nan,
#  399: nan,
#  400: nan,
#  401: nan,
#  402: nan,
#  403: nan,
#  404: nan,
#  405: nan,
#  406: nan,
#  407: [{'gene_description': 'radical S-adenosyl methionine domain containing 1',
#    'evidence': 'APEX_matrix, targetP signal, Rickettsial homolog, mito protein domain, coexpression',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Fe-S-containing proteins',
#    'hpa_location': 'Cytosol (Approved)',
#    'tissue_expression': nan}],
#  408: nan,
#  409: nan,
#  410: nan,
#  411: nan,
#  412: nan,
#  413: nan,
#  414: nan,
#  415: nan,
#  416: nan,
#  417: nan,
#  418: nan,
#  419: nan,
#  420: nan,
#  421: nan,
#  422: nan,
#  423: nan,
#  424: nan,
#  425: nan,
#  426: nan,
#  427: nan,
#  428: nan,
#  429: nan,
#  430: nan,
#  431: nan,
#  432: nan,
#  433: nan,
#  434: nan,
#  435: nan,
#  436: nan,
#  437: nan,
#  438: nan,
#  439: nan,
#  440: nan,
#  441: nan,
#  442: nan,
#  443: nan,
#  444: nan,
#  445: nan,
#  446: nan,
#  447: nan,
#  448: nan,
#  449: nan,
#  450: [{'gene_description': 'solute carrier family 25, member 35',
#    'evidence': 'APEX_matrix, yeast mito homolog+, mito protein domain+, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': 'Mitochondria;Vesicles (Approved)',
#    'tissue_expression': 'cerebrum, cerebellum, kidney, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  451: nan,
#  452: nan,
#  453: nan,
#  454: nan,
#  455: nan,
#  456: [{'gene_description': 'solute carrier family 25 (mitochondrial carrier; phosphate carrier), member 23',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+, MS/MS',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, brainstem, spinalcord, liver, adipose, smallintestine, largeintestine, stomach, placenta'}],
#  457: nan,
#  458: nan,
#  459: nan,
#  460: nan,
#  461: nan,
#  462: nan,
#  463: nan,
#  464: nan,
#  465: [{'gene_description': 'yrdC domain containing (E.coli)',
#    'evidence': 'manual, targetP signal, Rickettsial homolog',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mt-tRNA modifications',
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': nan}],
#  466: nan,
#  467: nan,
#  468: nan,
#  469: nan,
#  470: nan,
#  471: nan,
#  472: [{'gene_description': 'methylmalonic aciduria (cobalamin deficiency) type A',
#    'evidence': 'manual, targetP signal, coexpression+',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Vitamin B12 metabolism',
#    'hpa_location': 'Cytosol (Approved)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, kidney, liver, heart, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  473: nan,
#  474: nan,
#  475: nan,
#  476: nan,
#  477: nan,
#  478: nan,
#  479: nan,
#  480: nan,
#  481: nan,
#  482: nan,
#  483: nan,
#  484: nan,
#  485: nan,
#  486: nan,
#  487: nan,
#  488: nan,
#  489: nan,
#  490: nan,
#  491: nan,
#  492: nan,
#  493: nan,
#  494: [{'gene_description': 'ATP-binding cassette, sub-family D (ALD), member 2',
#    'evidence': 'targetP signal, Rickettsial homolog, mito protein domain, coexpression, MS/MS+',
#    'sub_mito_localization': 'Membrane',
#    'mito_pathways': 'ABC transporters',
#    'hpa_location': nan,
#    'tissue_expression': 'adipose'}],
#  495: nan,
#  496: nan,
#  497: nan,
#  498: nan,
#  499: nan,
#  500: nan,
#  501: nan,
#  502: nan,
#  503: nan,
#  504: nan,
#  505: nan,
#  506: nan,
#  507: nan,
#  508: nan,
#  509: nan,
#  510: nan,
#  511: nan,
#  512: nan,
#  513: nan,
#  514: nan,
#  515: nan,
#  516: nan,
#  517: nan,
#  518: nan,
#  519: nan,
#  520: nan,
#  521: nan,
#  522: nan,
#  523: nan,
#  524: nan,
#  525: nan,
#  526: nan,
#  527: [{'gene_description': 'vacuolar protein sorting 13D',
#    'evidence': 'manual, yeast mito homolog, mito protein domain, induction, coexpression',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Autophagy',
#    'hpa_location': 'Nucleoplasm;Vesicles (Approved)',
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, skeletalmuscle'}],
#  528: nan,
#  529: nan,
#  530: nan,
#  531: nan,
#  532: nan,
#  533: nan,
#  534: nan,
#  535: nan,
#  536: nan,
#  537: nan,
#  538: nan,
#  539: nan,
#  540: nan,
#  541: nan,
#  542: nan,
#  543: nan,
#  544: nan,
#  545: nan,
#  546: nan,
#  547: nan,
#  548: nan,
#  549: nan,
#  550: nan,
#  551: nan,
#  552: nan,
#  553: nan,
#  554: nan,
#  555: nan,
#  556: nan,
#  557: nan,
#  558: nan,
#  559: nan,
#  560: nan,
#  561: nan,
#  562: [{'gene_description': 'cytochrome C oxidase assembly factor 3',
#    'evidence': 'APEX_IMS, APEX_matrix, mito protein domain+, coexpression, MS/MS++',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  563: nan,
#  564: nan,
#  565: [{'gene_description': 'mitochondrial ribosomal protein L34',
#    'evidence': 'literature, APEX_matrix, targetP signal+, yeast mito homolog++, Rickettsial homolog, mito protein domain, induction, coexpression++, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, heart, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  566: nan,
#  567: nan,
#  568: nan,
#  569: nan,
#  570: nan,
#  571: nan,
#  572: nan,
#  573: nan,
#  574: nan,
#  575: nan,
#  576: nan,
#  577: nan,
#  578: nan,
#  579: nan,
#  580: nan,
#  581: nan,
#  582: [{'gene_description': 'armadillo repeat containing, X-linked 3',
#    'evidence': 'literature',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Trafficking',
#    'hpa_location': 'Nucleoplasm (Approved)',
#    'tissue_expression': nan}],
#  583: nan,
#  584: nan,
#  585: nan,
#  586: nan,
#  587: nan,
#  588: nan,
#  589: nan,
#  590: nan,
#  591: nan,
#  592: nan,
#  593: nan,
#  594: nan,
#  595: nan,
#  596: nan,
#  597: nan,
#  598: nan,
#  599: nan,
#  600: nan,
#  601: nan,
#  602: nan,
#  603: nan,
#  604: nan,
#  605: nan,
#  606: nan,
#  607: nan,
#  608: nan,
#  609: nan,
#  610: nan,
#  611: nan,
#  612: nan,
#  613: nan,
#  614: nan,
#  615: nan,
#  616: nan,
#  617: nan,
#  618: [{'gene_description': 'prenyl (solanesyl) diphosphate synthase, subunit 2',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog+, Rickettsial homolog, mito protein domain, coexpression+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'Coenzyme Q metabolism',
#    'hpa_location': 'Cytosol (Enhanced)',
#    'tissue_expression': 'smallintestine, largeintestine'}],
#  619: nan,
#  620: nan,
#  621: nan,
#  622: nan,
#  623: nan,
#  624: nan,
#  625: [{'gene_description': 'solute carrier family 25, member 33',
#    'evidence': 'literature, yeast mito homolog+, mito protein domain+',
#    'sub_mito_localization': 'MIM',
#    'mito_pathways': 'SLC25A family',
#    'hpa_location': nan,
#    'tissue_expression': 'brainstem, spinalcord, placenta, testis'}],
#  626: nan,
#  627: nan,
#  628: nan,
#  629: nan,
#  630: nan,
#  631: nan,
#  632: nan,
#  633: nan,
#  634: nan,
#  635: nan,
#  636: nan,
#  637: nan,
#  638: nan,
#  639: nan,
#  640: nan,
#  641: [{'gene_description': 'thymidine kinase 2, mitochondrial',
#    'evidence': 'literature, targetP signal+, mito protein domain, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Nucleotide synthesis and processing',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, adipose'}],
#  642: nan,
#  643: nan,
#  644: nan,
#  645: nan,
#  646: nan,
#  647: nan,
#  648: nan,
#  649: nan,
#  650: nan,
#  651: nan,
#  652: nan,
#  653: nan,
#  654: nan,
#  655: nan,
#  656: nan,
#  657: nan,
#  658: nan,
#  659: nan,
#  660: nan,
#  661: nan,
#  662: nan,
#  663: nan,
#  664: nan,
#  665: nan,
#  666: nan,
#  667: nan,
#  668: nan,
#  669: nan,
#  670: nan,
#  671: [{'gene_description': 'translocase of outer mitochondrial membrane 40-like',
#    'evidence': 'targetP signal, yeast mito homolog+, mito protein domain+, induction, coexpression+, MS/MS',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'TOM',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, adipose, largeintestine, stomach, testis'}],
#  672: nan,
#  673: nan,
#  674: nan,
#  675: nan,
#  676: nan,
#  677: nan,
#  678: nan,
#  679: nan,
#  680: nan,
#  681: nan,
#  682: nan,
#  683: nan,
#  684: nan,
#  685: nan,
#  686: nan,
#  687: nan,
#  688: nan,
#  689: nan,
#  690: nan,
#  691: [{'gene_description': 'oxidoreductase NAD-binding domain containing 1',
#    'evidence': 'APEX_matrix, GFP, targetP signal, yeast mito homolog, mito protein domain, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': nan,
#    'hpa_location': 'Nucleoplasm (Approved)',
#    'tissue_expression': 'cerebrum, spinalcord, liver, heart, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  692: nan,
#  693: nan,
#  694: [{'gene_description': 'family with sequence similarity 136, member A',
#    'evidence': 'APEX_IMS, mito protein domain+, MS/MS++',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': nan,
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  695: [{'gene_description': 'family with sequence similarity 136, member A',
#    'evidence': 'APEX_IMS, mito protein domain+, MS/MS++',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': nan,
#    'hpa_location': 'Mitochondria (Approved)',
#    'tissue_expression': 'all 14'}],
#  696: [{'gene_description': 'COX assembly mitochondrial protein 2',
#    'evidence': 'APEX_IMS, yeast mito homolog++, mito protein domain+, induction, coexpression, MS/MS+',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, spinalcord, liver, heart, adipose, largeintestine, stomach, placenta, testis'}],
#  697: nan,
#  698: nan,
#  699: nan,
#  700: nan,
#  701: [{'gene_description': 'flavin adenine dinucleotide synthetase 1',
#    'evidence': 'APEX_matrix, mito protein domain, induction, coexpression',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Vitamin B2 metabolism',
#    'hpa_location': 'Cytosol;Plasma membrane (Supported)',
#    'tissue_expression': 'spinalcord, adipose, stomach'}],
#  702: nan,
#  703: nan,
#  704: nan,
#  705: nan,
#  706: nan,
#  707: nan,
#  708: nan,
#  709: nan,
#  710: nan,
#  711: nan,
#  712: nan,
#  713: nan,
#  714: nan,
#  715: nan,
#  716: nan,
#  717: nan,
#  718: nan,
#  719: nan,
#  720: nan,
#  721: nan,
#  722: nan,
#  723: nan,
#  724: nan,
#  725: nan,
#  726: nan,
#  727: nan,
#  728: nan,
#  729: nan,
#  730: nan,
#  731: nan,
#  732: nan,
#  733: nan,
#  734: [{'gene_description': 'ATP-binding cassette, sub-family D (ALD), member 1',
#    'evidence': 'targetP signal, Rickettsial homolog, mito protein domain, induction',
#    'sub_mito_localization': 'Membrane',
#    'mito_pathways': 'ABC transporters',
#    'hpa_location': nan,
#    'tissue_expression': 'adipose'}],
#  735: nan,
#  736: nan,
#  737: nan,
#  738: nan,
#  739: nan,
#  740: nan,
#  741: nan,
#  742: nan,
#  743: nan,
#  744: nan,
#  745: nan,
#  746: nan,
#  747: nan,
#  748: nan,
#  749: nan,
#  750: nan,
#  751: nan,
#  752: nan,
#  753: nan,
#  754: nan,
#  755: nan,
#  756: nan,
#  757: nan,
#  758: nan,
#  759: nan,
#  760: [{'gene_description': 'mitochondrial ribosomal protein L49',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog++, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': nan,
#    'tissue_expression': 'all 14'}],
#  761: nan,
#  762: nan,
#  763: nan,
#  764: nan,
#  765: nan,
#  766: nan,
#  767: nan,
#  768: nan,
#  769: nan,
#  770: nan,
#  771: nan,
#  772: nan,
#  773: [{'gene_description': 'BCL2-like 11 (apoptosis facilitator)',
#    'evidence': 'manual, targetP signal',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Apoptosis',
#    'hpa_location': nan,
#    'tissue_expression': nan}],
#  774: [{'gene_description': 'cytochrome c oxidase assembly factor 6',
#    'evidence': 'APEX_IMS, yeast mito homolog++, mito protein domain+, induction, coexpression+, MS/MS',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': 'OXPHOS assembly factors',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebrum, cerebellum, spinalcord, liver, adipose, smallintestine, largeintestine, placenta, testis'}],
#  775: nan,
#  776: [{'gene_description': 'aldehyde dehydrogenase 1 family, member L1',
#    'evidence': 'APEX_matrix, yeast mito homolog, Rickettsial homolog, mito protein domain, induction, coexpression, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Folate and 1-C metabolism',
#    'hpa_location': 'Cytosol (Supported)',
#    'tissue_expression': 'cerebrum, liver, smallintestine, largeintestine, stomach, placenta, testis'}],
#  777: nan,
#  778: nan,
#  779: nan,
#  780: nan,
#  781: nan,
#  782: nan,
#  783: nan,
#  784: nan,
#  785: nan,
#  786: nan,
#  787: nan,
#  788: nan,
#  789: nan,
#  790: nan,
#  791: nan,
#  792: nan,
#  793: nan,
#  794: nan,
#  795: nan,
#  796: nan,
#  797: nan,
#  798: nan,
#  799: nan,
#  800: nan,
#  801: nan,
#  802: nan,
#  803: nan,
#  804: nan,
#  805: nan,
#  806: nan,
#  807: nan,
#  808: nan,
#  809: nan,
#  810: nan,
#  811: nan,
#  812: nan,
#  813: nan,
#  814: nan,
#  815: nan,
#  816: nan,
#  817: nan,
#  818: nan,
#  819: nan,
#  820: nan,
#  821: nan,
#  822: nan,
#  823: nan,
#  824: nan,
#  825: nan,
#  826: nan,
#  827: nan,
#  828: nan,
#  829: nan,
#  830: nan,
#  831: nan,
#  832: nan,
#  833: nan,
#  834: nan,
#  835: nan,
#  836: nan,
#  837: nan,
#  838: nan,
#  839: [{'gene_description': 'mitochondrial ribosomal protein L9',
#    'evidence': 'literature, APEX_matrix, targetP signal, Rickettsial homolog, mito protein domain, induction, coexpression+, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  840: nan,
#  841: nan,
#  842: nan,
#  843: nan,
#  844: nan,
#  845: nan,
#  846: nan,
#  847: nan,
#  848: nan,
#  849: nan,
#  850: nan,
#  851: nan,
#  852: nan,
#  853: nan,
#  854: nan,
#  855: nan,
#  856: nan,
#  857: nan,
#  858: nan,
#  859: nan,
#  860: nan,
#  861: nan,
#  862: nan,
#  863: nan,
#  864: nan,
#  865: nan,
#  866: nan,
#  867: nan,
#  868: nan,
#  869: nan,
#  870: nan,
#  871: nan,
#  872: nan,
#  873: nan,
#  874: nan,
#  875: nan,
#  876: nan,
#  877: nan,
#  878: nan,
#  879: nan,
#  880: nan,
#  881: nan,
#  882: nan,
#  883: nan,
#  884: nan,
#  885: nan,
#  886: nan,
#  887: nan,
#  888: nan,
#  889: nan,
#  890: nan,
#  891: nan,
#  892: nan,
#  893: nan,
#  894: nan,
#  895: nan,
#  896: nan,
#  897: nan,
#  898: nan,
#  899: nan,
#  900: nan,
#  901: nan,
#  902: nan,
#  903: [{'gene_description': 'DnaJ heat shock protein family (Hsp40) member C11',
#    'evidence': 'GFP, yeast mito homolog+, Rickettsial homolog, mito protein domain, coexpression, MS/MS++',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Intramitochondrial membrane interactions',
#    'hpa_location': 'Cytosol (Approved)',
#    'tissue_expression': 'all 14'}],
#  904: nan,
#  905: nan,
#  906: nan,
#  907: nan,
#  908: nan,
#  909: nan,
#  910: nan,
#  911: nan,
#  912: [{'gene_description': 'mitochondrial ribosomal protein L36',
#    'evidence': 'literature, targetP signal, yeast mito homolog++, mito protein domain, induction, coexpression+',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': 'Mitochondria;Nuclear bodies (Supported)',
#    'tissue_expression': nan}],
#  913: nan,
#  914: nan,
#  915: nan,
#  916: nan,
#  917: [{'gene_description': 'mitochondrial ribosomal protein L4',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain, induction, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Mitochondrial ribosome',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, brainstem, spinalcord, kidney, liver, adipose, smallintestine, largeintestine, placenta, testis'}],
#  918: nan,
#  919: nan,
#  920: nan,
#  921: nan,
#  922: nan,
#  923: nan,
#  924: nan,
#  925: nan,
#  926: nan,
#  927: nan,
#  928: nan,
#  929: nan,
#  930: nan,
#  931: nan,
#  932: nan,
#  933: nan,
#  934: nan,
#  935: nan,
#  936: nan,
#  937: nan,
#  938: nan,
#  939: nan,
#  940: nan,
#  941: nan,
#  942: nan,
#  943: nan,
#  944: [{'gene_description': 'acetyl-Coenzyme A carboxylase beta',
#    'evidence': 'yeast mito homolog, Rickettsial homolog, mito protein domain, coexpression+',
#    'sub_mito_localization': 'MOM',
#    'mito_pathways': 'Biotin utilizing proteins',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, kidney, liver, adipose, largeintestine, stomach, placenta, testis'}],
#  945: nan,
#  946: nan,
#  947: nan,
#  948: nan,
#  949: nan,
#  950: nan,
#  951: [{'gene_description': 'aminolevulinic acid synthase 2, erythroid',
#    'evidence': 'literature, targetP signal, yeast mito homolog+, Rickettsial homolog, mito protein domain+, coexpression',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Heme synthesis and processing',
#    'hpa_location': nan,
#    'tissue_expression': nan}],
#  952: nan,
#  953: nan,
#  954: nan,
#  955: [{'gene_description': 'caseinolytic mitochondrial matrix peptidase chaperone subunit',
#    'evidence': 'literature, APEX_matrix, targetP signal, yeast mito homolog++, Rickettsial homolog, mito protein domain, induction, coexpression, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'Proteases',
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'all 14'}],
#  956: nan,
#  957: nan,
#  958: nan,
#  959: nan,
#  960: nan,
#  961: nan,
#  962: nan,
#  963: nan,
#  964: nan,
#  965: nan,
#  966: nan,
#  967: nan,
#  968: nan,
#  969: nan,
#  970: nan,
#  971: [{'gene_description': 'acid phosphatase 6, lysophosphatidic',
#    'evidence': 'literature, APEX_IMS, targetP signal, mito protein domain, MS/MS++',
#    'sub_mito_localization': 'IMS',
#    'mito_pathways': 'Phospholipid metabolism',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, spinalcord, kidney, liver, skeletalmuscle, adipose, smallintestine, largeintestine, stomach, placenta, testis'}],
#  972: nan,
#  973: nan,
#  974: nan,
#  975: [{'gene_description': 'alkB homolog 7',
#    'evidence': 'APEX_matrix, targetP signal+, mito protein domain, induction, coexpression++, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': nan,
#    'hpa_location': 'Mitochondria (Supported)',
#    'tissue_expression': 'cerebellum, brainstem, largeintestine, testis'}],
#  976: nan,
#  977: nan,
#  978: nan,
#  979: nan,
#  980: nan,
#  981: nan,
#  982: nan,
#  983: nan,
#  984: nan,
#  985: nan,
#  986: [{'gene_description': 'mitochondrial transcription termination factor 2',
#    'evidence': 'literature, APEX_matrix, targetP signal, mito protein domain+, induction, coexpression, MS/MS',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': 'mtDNA nucleoid',
#    'hpa_location': nan,
#    'tissue_expression': 'cerebrum, cerebellum, brainstem, spinalcord, liver, heart, skeletalmuscle, adipose, largeintestine, testis'}],
#  987: nan,
#  988: nan,
#  989: nan,
#  990: nan,
#  991: nan,
#  992: nan,
#  993: nan,
#  994: nan,
#  995: nan,
#  996: nan,
#  997: [{'gene_description': 'reticulon 4 interacting protein 1',
#    'evidence': 'literature, APEX_matrix, targetP signal+, yeast mito homolog, mito protein domain, induction, coexpression++, MS/MS++',
#    'sub_mito_localization': 'Matrix',
#    'mito_pathways': nan,
#    'hpa_location': nan,
#    'tissue_expression': 'all 14'}],
#  998: nan,
#  999: nan,
#  ...}

# %%
ncbi_tf_gprofiler_mitocarta_df_mice["its_target"][ncbi_tf_gprofiler_mitocarta_df_mice["its_target"].notna()]
ncbi_tf_gprofiler_mitocarta_df_mice["its_target"][1]
# Out:
# [{'NCBI.GeneID.Target': '18626',
#   'Ensembl.GeneID.Target': 'ENSMUSG00000020893',
#   'Name.Target': 'Per1',
#   'UniprotID.Target': 'O35973',
#   'Target.TFLink.ortho': 'Hs:O15534;Dr:B3DK47;Rn:A0A0H2UHZ7',
#   'Target.nonTFLink.ortho': '-',
#   'Detection.method': 'inferred by curator',
#   'PubmedID': '10848603;29087512',
#   'Source.database': 'TRRUST',
#   'Small-scale.evidence': 'Yes'}]

# %% [markdown]
# Extract "NCBI Gene" ids for adding transcription factor (TF) and target interaction

# %%
ncbi_df_mice = get_identifier_of_interest(bridgedb_df_mice, "NCBI Gene")
ncbi_to_ensembl = dict(zip(ncbi_df_mice['target'], ncbi_df_mice['identifier']))
ncbi_df_mice.head(1)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl  78754     NCBI Gene         Galnt15
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140
#
#         padj_dea  minus_log10_pvalue_dea
# 0  2.373133e-136              139.689061

# %%
bridgedb_df_mice[bridgedb_df_mice["target"] == "78754"]
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 1  ENSMUSG00000021903           Ensembl  78754     NCBI Gene         Galnt15
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  \
# 1   2770.437508            2.521182   0.099941  25.226601  2.046157e-140
#
#         padj_dea  minus_log10_pvalue_dea
# 1  2.373133e-136              139.689061

# %%
print("Number of humman genes with mapping for NCBI Gene:", len(ncbi_df_mice["target"].unique()))
# Out:
# Number of humman genes with mapping for NCBI Gene: 11219

# %% [markdown]
# ### Download TF-target interactions
#
# You can download the Gene-TF interactions dataset from **TFLink**. Please visit the following page for the download:
#
# [TFLink Download Page](https://tflink.net/download/)
#
# The datasets you need can be downloaded from the following links:
#
# **For Human (Homo sapiens):**
# - [TFLink_Homo_sapiens_interactions_All_simpleFormat_v1.0.tsv.gz](https://cdn.netbiol.org/tflink/download_files/TFLink_Homo_sapiens_interactions_All_simpleFormat_v1.0.tsv.gz)
#
# **For Mice (Mus musculus):**
# - [TFLink_Mus_musculus_interactions_All_simpleFormat_v1.0.tsv.gz](https://cdn.netbiol.org/tflink/download_files/TFLink_Mus_musculus_interactions_All_simpleFormat_v1.0.tsv.gz)
#
# These files contain the TF-target interaction data in a simple format for each species.

# %%
# URLs for the TF datasets
url_mice = "https://cdn.netbiol.org/tflink/download_files/TFLink_Mus_musculus_interactions_All_simpleFormat_v1.0.tsv.gz"

# Function to download and read a gzipped file into a dataframe
def download_save_and_read(url, filename):
    if not os.path.exists(filename):
        response = requests.get(url)
        with open(filename, "wb") as file:
            file.write(response.content)
    else:
        print(f"{filename} already exists, skipping download.")

    with gzip.open(filename, "rt") as f:
        df = pd.read_csv(f, sep="\t")
    return df

# Download and read the mouse and mice datasets
tf_df_mice = download_save_and_read(url_mice, "data/mice/tflink_mice.tsv.gz")

# Keep rows where both TF and target exist in our dataset
tf_df_mice = tf_df_mice[tf_df_mice["NCBI.GeneID.TF"].isin(ncbi_df_mice["target"])]
tf_df_mice = tf_df_mice[tf_df_mice["NCBI.GeneID.Target"].isin(ncbi_df_mice["target"])]

tf_df_mice.head(1)
# Out:
# data/mice/tflink_mice.tsv.gz already exists, skipping download.
#   UniprotID.TF UniprotID.Target NCBI.GeneID.TF NCBI.GeneID.Target Name.TF  \
# 0       Q9JL61           P14483          53970              14961    Rfx5
#
#   Name.Target     Detection.method           PubmedID      Organism  \
# 0      H2-Ab1  inferred by curator  29087512;11258423  Mus musculus
#
#   Source.database Small-scale.evidence      TF.TFLink.ortho  \
# 0          TRRUST                  Yes  Hs:P48382;Rn:D3ZHD7
#
#   TF.nonTFLink.ortho Target.TFLink.ortho Target.nonTFLink.ortho
# 0                  -           Rn:Q6AYB1              Hs:Q5SU54

# %%
tf_df_mice.shape
# Out:
# (2014896, 15)

# %%
# Extract the TF and the TF targets
tf_list_mice = list(tf_df_mice["NCBI.GeneID.TF"])
target_list_mice = list(tf_df_mice["NCBI.GeneID.Target"])

# Add 'is_tf' and 'is_target' columns
ncbi_df_mice["is_tf"] = ncbi_df_mice["target"].isin(tf_list_mice)
ncbi_df_mice["is_target"] = ncbi_df_mice["target"].isin(target_list_mice)

ncbi_df_mice["is_target"].value_counts(), ncbi_df_mice["is_tf"].value_counts()
# Out:
# (is_target
#  True     10759
#  False      472
#  Name: count, dtype: int64,
#  is_tf
#  False    10557
#  True       674
#  Name: count, dtype: int64)

# %%
# kepp only rows where the target is a DEG
tf_sig_df_mice = tf_df_mice[tf_df_mice["NCBI.GeneID.Target"].isin(ncbi_df_mice[
    (ncbi_df_mice['padj_dea'] < 0.01) &
    (
        (ncbi_df_mice['log2FoldChange_dea'] > 1) |
        (ncbi_df_mice['log2FoldChange_dea'] < -1)
    )]["target"])]
# add ensembl gene id for the TF and target
tf_sig_df_mice['Ensembl.GeneID.TF'] = tf_sig_df_mice['NCBI.GeneID.TF'].map(ncbi_to_ensembl)
tf_sig_df_mice['Ensembl.GeneID.Target'] = tf_sig_df_mice['NCBI.GeneID.Target'].map(ncbi_to_ensembl)
tf_sig_df_mice.head(1)
# Out:
#   UniprotID.TF UniprotID.Target NCBI.GeneID.TF NCBI.GeneID.Target Name.TF  \
# 0       Q9JL61           P14483          53970              14961    Rfx5
#
#   Name.Target     Detection.method           PubmedID      Organism  \
# 0      H2-Ab1  inferred by curator  29087512;11258423  Mus musculus
#
#   Source.database Small-scale.evidence      TF.TFLink.ortho  \
# 0          TRRUST                  Yes  Hs:P48382;Rn:D3ZHD7
#
#   TF.nonTFLink.ortho Target.TFLink.ortho Target.nonTFLink.ortho  \
# 0                  -           Rn:Q6AYB1              Hs:Q5SU54
#
#     Ensembl.GeneID.TF Ensembl.GeneID.Target
# 0  ENSMUSG00000005774    ENSMUSG00000073421

# %%
tf_sig_df_mice[(tf_sig_df_mice["Name.TF"] == "Hif1a") & (tf_sig_df_mice["Name.Target"] == "Sertad2")]
# Out:
#         UniprotID.TF UniprotID.Target NCBI.GeneID.TF NCBI.GeneID.Target  \
# 3614494       Q61221           Q9JJG5          15251              58172
#
#         Name.TF Name.Target                     Detection.method  PubmedID  \
# 3614494   Hif1a     Sertad2  chromatin immunoprecipitation assay  27924024
#
#              Organism Source.database Small-scale.evidence  \
# 3614494  Mus musculus            GTRD                   No
#
#                        TF.TFLink.ortho TF.nonTFLink.ortho  \
# 3614494  Hs:Q16665;Dr:Q6EHI4;Rn:D4A8P8                  -
#
#          Target.TFLink.ortho Target.nonTFLink.ortho   Ensembl.GeneID.TF  \
# 3614494  Hs:Q14140;Dr:Q7ZZ27              Rn:F7F8X3  ENSMUSG00000021109
#
#         Ensembl.GeneID.Target
# 3614494    ENSMUSG00000049800

# %%
tf_sig_df_mice[tf_sig_df_mice["Name.TF"] == "Pdhx"]["Name.Target"].sort_values()
# Out:
# Series([], Name: Name.Target, dtype: object)

# %%
tf_sig_df_mice.shape
# Out:
# (123350, 17)

# %%
# Function to add targets and TFs to each row (gene)
def add_target_and_tf_interaction(ncbi_df, tf_df, filename):
    if not os.path.exists(filename):
        ncbi_df["its_target"] = None
        print(f"Processing targets. {ncbi_df.shape}")
        for index, row in ncbi_df.iterrows():
            if index % 2000 == 0 and index > 0:
                print(f"Processed {index} rows (targets).")
            if row["is_tf"]:
                targets = tf_df[tf_df["NCBI.GeneID.TF"] == row["target"]]
                if not targets.empty:
                    target_info_list = targets[["NCBI.GeneID.Target",
                                                "Ensembl.GeneID.Target",
                                                "Name.Target",
                                                "UniprotID.Target",
                                                "Target.TFLink.ortho",
                                                "Target.nonTFLink.ortho",
                                                "Detection.method",
                                                "PubmedID",
                                                "Source.database",
                                                "Small-scale.evidence",
                                            ]].to_dict(orient="records")
                    ncbi_df.at[index, "its_target"] = target_info_list
                else:
                    ncbi_df.at[index, "its_target"] = []

        ncbi_df["its_tf"] = None
        print("Processing TFs...")
        for index, row in ncbi_df.iterrows():
            if index % 2000 == 0 and index > 0:
                print(f"Processed {index} rows (TFs).")
            if row["is_target"] and row["padj_dea"] <= 0.01 and (row["log2FoldChange_dea"] > 1 or row["log2FoldChange_dea"] < -1):
                tf = tf_df[tf_df["NCBI.GeneID.Target"] == row["target"]]
                if not tf.empty:
                    tf_info_list = tf[["NCBI.GeneID.TF",
                                       "Ensembl.GeneID.TF",
                                       "Name.TF",
                                       "UniprotID.TF",
                                       "TF.TFLink.ortho",
                                       "TF.nonTFLink.ortho",
                                       "Detection.method",
                                       "PubmedID",
                                       "Source.database",
                                       "Small-scale.evidence",
                                    ]].to_dict(orient="records")
                    ncbi_df.at[index, "its_tf"] = tf_info_list
                else:
                    # if row["padj_dea"] <= 0.01:
                    #     ncbi_df.at[index, "its_tf"] = None
                    # else:
                    ncbi_df.at[index, "its_tf"] = []

        ncbi_df.to_pickle(filename)

    else:
        with open(filename, 'rb') as f:
            ncbi_df = pickle.load(f)

    return ncbi_df

# Add target and TF
ncbi_tf_df_mice = add_target_and_tf_interaction(ncbi_df_mice, tf_sig_df_mice, filename="data/mice/ncbi_tf_df_mice.pkl")

# %%
ncbi_tf_df_mice.head()
# Out:
#            identifier identifier.source  target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl   78754     NCBI Gene         Galnt15
# 1  ENSMUSG00000059824           Ensembl   13170     NCBI Gene             Dbp
# 2  ENSMUSG00000041417           Ensembl   18708     NCBI Gene          Pik3r1
# 3  ENSMUSG00000004939           Ensembl   69564     NCBI Gene           Nmrk2
# 4  ENSMUSG00000028834           Ensembl  433766     NCBI Gene          Trim63
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140
# 1   2816.783019           -2.985239   0.191760 -15.567614   1.208303e-54
# 2   2934.327264            2.047483   0.136776  14.969629   1.159658e-50
# 3    675.068734           -3.981474   0.274358 -14.511978   1.017437e-47
# 4  44995.104413            3.738275   0.261289  14.307048   1.977304e-46
#
#         padj_dea  minus_log10_pvalue_dea  is_tf  is_target  \
# 0  2.373133e-136              139.689061  False       True
# 1   7.006949e-51               53.917824   True       True
# 2   4.483238e-47               49.935670  False       True
# 3   2.950057e-44               46.992493  False       True
# 4   4.586555e-43               45.703926  False       True
#
#                                           its_target  \
# 0                                               None
# 1  [{'NCBI.GeneID.Target': '18626', 'Ensembl.Gene...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                               its_tf
# 0  [{'NCBI.GeneID.TF': '14461', 'Ensembl.GeneID.T...
# 1  [{'NCBI.GeneID.TF': '11865', 'Ensembl.GeneID.T...
# 2  [{'NCBI.GeneID.TF': '17342', 'Ensembl.GeneID.T...
# 3  [{'NCBI.GeneID.TF': '17257', 'Ensembl.GeneID.T...
# 4  [{'NCBI.GeneID.TF': '226442', 'Ensembl.GeneID....

# %%
ncbi_tf_df_mice[ncbi_tf_df_mice['its_target'].notna()].head(1)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 1  ENSMUSG00000059824           Ensembl  13170     NCBI Gene             Dbp
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea    pvalue_dea  \
# 1   2816.783019           -2.985239    0.19176 -15.567614  1.208303e-54
#
#        padj_dea  minus_log10_pvalue_dea  is_tf  is_target  \
# 1  7.006949e-51               53.917824   True       True
#
#                                           its_target  \
# 1  [{'NCBI.GeneID.Target': '18626', 'Ensembl.Gene...
#
#                                               its_tf
# 1  [{'NCBI.GeneID.TF': '11865', 'Ensembl.GeneID.T...

# %%
ncbi_tf_df_mice[ncbi_tf_df_mice['target']=="1647"]
# Out:
# Empty DataFrame
# Columns: [identifier, identifier.source, target, target.source, GENE_SYMBOL_dea, baseMean_dea, log2FoldChange_dea, lfcSE_dea, stat_dea, pvalue_dea, padj_dea, minus_log10_pvalue_dea, is_tf, is_target, its_target, its_tf]
# Index: []

# %%
ncbi_tf_df_mice[ncbi_tf_df_mice['target']=="1647"]["its_tf"].to_dict()
# Out:
# {}

# %%
ncbi_tf_df_mice[ncbi_tf_df_mice['target']=="1647"]["its_tf"].to_dict()
# Out:
# {}

# %%
ncbi_tf_df_mice[ncbi_tf_df_mice['target']=="3725"]["its_target"].to_dict()
# Out:
# {}

# %% [markdown]
# ### Protein-Protein Interactions from STRING

# %%
string_path = os.path.join(base_dir, "data/mice/string.pkl")
string_metadata_path = os.path.join(base_dir, "data/mice/string_metadata.pkl")

if not os.path.exists(string_path):
    ppi_df, ppi_metadata = stringdb.get_ppi(
        bridgedb_df=bridgedb_df_mice[
                        (bridgedb_df_mice['padj_dea'] < 0.01) &
                (
                    (bridgedb_df_mice['log2FoldChange_dea'] > 1) |
                    (bridgedb_df_mice['log2FoldChange_dea'] < -1)
                )
        ],
        species= "Mouse"
    )
    ppi_df.to_pickle(string_path)
    with open(string_metadata_path, "wb") as file:
        pickle.dump(ppi_metadata, file)
else:
    ppi_df = pd.read_pickle(string_path)
    with open(string_metadata_path, "rb") as file:
        ppi_metadata = pickle.load(file)

ppi_df.head()
# Out:
#            identifier identifier.source              target target.source  \
# 0  ENSMUSG00000021903           Ensembl  ENSMUSG00000021903       Ensembl
# 1  ENSMUSG00000059824           Ensembl  ENSMUSG00000059824       Ensembl
# 2  ENSMUSG00000041417           Ensembl  ENSMUSG00000041417       Ensembl
# 3  ENSMUSG00000004939           Ensembl  ENSMUSG00000004939       Ensembl
# 4  ENSMUSG00000028834           Ensembl  ENSMUSG00000028834       Ensembl
#
#   GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea  \
# 0         Galnt15   2770.437508            2.521182   0.099941  25.226601
# 1             Dbp   2816.783019           -2.985239   0.191760 -15.567614
# 2          Pik3r1   2934.327264            2.047483   0.136776  14.969629
# 3           Nmrk2    675.068734           -3.981474   0.274358 -14.511978
# 4          Trim63  44995.104413            3.738275   0.261289  14.307048
#
#       pvalue_dea       padj_dea  minus_log10_pvalue_dea  \
# 0  2.046157e-140  2.373133e-136              139.689061
# 1   1.208303e-54   7.006949e-51               53.917824
# 2   1.159658e-50   4.483238e-47               49.935670
# 3   1.017437e-47   2.950057e-44               46.992493
# 4   1.977304e-46   4.586555e-43               45.703926
#
#                                         StringDB_ppi
# 0  [{'stringdb_link_to': 'ENSMUSG00000021906', 'E...
# 1  [{'stringdb_link_to': 'ENSMUSG00000020893', 'E...
# 2  [{'stringdb_link_to': 'ENSMUSG00000000290', 'E...
# 3  [{'stringdb_link_to': 'ENSMUSG00000079243', 'E...
# 4  [{'stringdb_link_to': 'ENSMUSG00000020475', 'E...

# %%
ppi_df.shape
# Out:
# (846, 13)

# %%
from pyBiodatafuse.constants import STRING_PPI_COL

ppi_df[STRING_PPI_COL].to_dict()
# Out:
# {0: [{'stringdb_link_to': 'ENSMUSG00000021906',
#    'Ensembl': 'ENSMUSP00000022462',
#    'score': 0.505,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  1: [{'stringdb_link_to': 'ENSMUSG00000020893',
#    'Ensembl': 'ENSMUSP00000021271',
#    'score': 0.7,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000023087',
#    'Ensembl': 'ENSMUSP00000023849',
#    'score': 0.425,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000030103',
#    'Ensembl': 'ENSMUSP00000032194',
#    'score': 0.47,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032010',
#    'Ensembl': 'ENSMUSP00000034508',
#    'score': 0.415,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000068742',
#    'Ensembl': 'ENSMUSP00000088047',
#    'score': 0.704,
#    'Uniprot-TrEMBL': 'Q9R194',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000055116',
#    'Ensembl': 'ENSMUSP00000147989',
#    'score': 0.933,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  2: [{'stringdb_link_to': 'ENSMUSG00000000290',
#    'Ensembl': 'ENSMUSP00000000299',
#    'score': 0.916,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000000359',
#    'Ensembl': 'ENSMUSP00000000369',
#    'score': 0.682,
#    'Uniprot-TrEMBL': 'O35929',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000000489',
#    'Ensembl': 'ENSMUSP00000000500',
#    'score': 0.603,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000004508',
#    'Ensembl': 'ENSMUSP00000004622',
#    'score': 0.975,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000007613',
#    'Ensembl': 'ENSMUSP00000007757',
#    'score': 0.62,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022346',
#    'Ensembl': 'ENSMUSP00000022971',
#    'score': 0.426,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022797',
#    'Ensembl': 'ENSMUSP00000023486',
#    'score': 0.472,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000024697',
#    'Ensembl': 'ENSMUSP00000025602',
#    'score': 0.571,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026012',
#    'Ensembl': 'ENSMUSP00000027165',
#    'score': 0.936,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000

#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000024371',
#    'Ensembl': 'ENSMUSP00000025230',
#    'score': 0.95,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032086',
#    'Ensembl': 'ENSMUSP00000034591',
#    'score': 0.454,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000036896',
#    'Ensembl': 'ENSMUSP00000036747',
#    'score': 0.975,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000037095',
#    'Ensembl': 'ENSMUSP00000038048',
#    'score': 0.424,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000036905',
#    'Ensembl': 'ENSMUSP00000040246',
#    'score': 0.972,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026580',
#    'Ensembl': 'ENSMUSP00000123924',
#    'score': 0.421,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000007480',
#    'Ensembl': 'ENSMUSP00000130497',
#    'score': 0.487,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000031722',
#    'Ensembl': 'ENSMUSP00000074436',
#    'score': 0.536,
#    'Uniprot-TrEMBL': 'Q61646',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026365',
#    'Ensembl': 'ENSMUSP00000107607',
#    'score': 0.929,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  29: [{'stringdb_link_to': 'ENSMUSG00000025612',
#    'Ensembl': 'ENSMUSP00000026703',
#    'score': 0.967,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000029135',
#    'Ensembl': 'ENSMUSP00000031017',
#    'score': 0.734,
#    'Uniprot-TrEMBL': 'P47930',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000042622',
#    'Ensembl': 'ENSMUSP00000094076',
#    'score': 0.701,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052684',
#    'Ensembl': 'ENSMUSP00000102711',
#    'score': 0.705,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000040270',
#    'Ensembl': 'ENSMUSP00000103815',
#    'score': 0.963,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000055435',
#    'Ensembl': 'ENSMUSP00000104732',
#    'score': 0.435,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  30: [{'stringdb_link_to': 'ENSMUSG00000019577',
#    'Ensembl': 'ENSMUSP00000019721',
#    'score': 0.61,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032942',
#    'Ensembl': 'ENSMUSP00000032958',
#    'score': 0.415,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027875',
#    'Ensembl': 'ENSMUSP00000088249',
#    'score': 0.43,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000074064',
#    'Ensembl': 'ENSMUSP00000095970',
#    'score': 0.509,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000008348',
#    'Ensembl': 'ENSMUSP00000114180',
#    'score': 0.517,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000021456',
#    'Ensembl': 'ENSMUSP00000021907',
#    'score': 0.901,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  31: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  32: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  33: [{'stringdb_link_to': 'ENSMUSG00000067081',
#    'Ensembl': 'ENSMUSP00000084095',
#    'score': 0.463,
#    'Uniprot-TrEMBL': 'Q8VHA6',
#    'Uniprot-TrEMBL_link': None}],
#  34: [{'stringdb_link_to': 'ENSMUSG00000049281',
#    'Ensembl': 'ENSMUSP00000051627',
#    'score': 0.401,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  35: [{'stringdb_link_to': 'ENSMUSG00000022346',
#    'Ensembl': 'ENSMUSP00000022971',
#    'score': 0.504,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022952',
#    'Ensembl': 'ENSMUSP00000023673',
#    'score': 0.836,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000025220',
#    'Ensembl': 'ENSMUSP00000026243',
#    'score': 0.517,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000036390',
#    'Ensembl': 'ENSMUSP00000044034',
#    'score': 0.601,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000046668',
#    'Ensembl': 'ENSMUSP00000054307',
#    'score': 0.9,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000016559',
#    'Ensembl': 'ENSMUSP00000102062',
#    'score': 0.606,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000042548',
#    'Ensembl': 'ENSMUSP00000105413',
#    'score': 0.92,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000053470',
#    'Ensembl': 'ENSMUSP00000128789',
#    'score': 0.409,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  36: [{'stringdb_link_to': 'ENSMUSG00000038022',
#    'Ensembl': 'ENSMUSP00000061221',
#    'score': 0.554,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  37: [{'stringdb_link_to': 'ENSMUSG00000005686',
#    'Ensembl': 'ENSMUSP00000005829',
#    'score': 0.54,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  38: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#

#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027858',
#    'Ensembl': 'ENSMUSP00000029451',
#    'score': 0.479,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000031425',
#    'Ensembl': 'ENSMUSP00000033800',
#    'score': 0.625,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000068566',
#    'Ensembl': 'ENSMUSP00000145120',
#    'score': 0.602,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000033579',
#    'Ensembl': 'ENSMUSP00000043597',
#    'score': 0.651,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  843: [{'stringdb_link_to': 'ENSMUSG00000000567',
#    'Ensembl': 'ENSMUSP00000000579',
#    'score': 0.502,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000031609',
#    'Ensembl': 'ENSMUSP00000034022',
#    'score': 0.609,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000040423',
#    'Ensembl': 'ENSMUSP00000124871',
#    'score': 0.552,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000035673',
#    'Ensembl': 'ENSMUSP00000151590',
#    'score': 0.574,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  844: [{'stringdb_link_to': 'ENSMUSG00000000290',
#    'Ensembl': 'ENSMUSP00000000299',
#    'score': 0.725,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000029163',
#    'Ensembl': 'ENSMUSP00000031055',
#    'score': 0.723,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000031425',
#    'Ensembl': 'ENSMUSP00000033800',
#    'score': 0.792,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026971',
#    'Ensembl': 'ENSMUSP00000054944',
#    'score': 0.72,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027009',
#    'Ensembl': 'ENSMUSP00000099718',
#    'score': 0.72,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  845: [{'stringdb_link_to': 'ENSMUSG00000000567',
#    'Ensembl': 'ENSMUSP00000000579',
#    'score': 0.545,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022346',
#    'Ensembl': 'ENSMUSP00000022971',
#    'score': 0.5,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022952',
#    'Ensembl': 'ENSMUSP00000023673',
#    'score': 0.526,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027496',
#    'Ensembl': 'ENSMUSP00000028997',
#    'score': 0.513,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000055639',
#    'Ensembl': 'ENSMUSP00000071464',
#    'score': 0.502,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000029086',
#    'Ensembl': 'ENSMUSP00000073751',
#    'score': 0.44,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000070348',
#    'Ensembl': 'ENSMUSP00000091495',
#    'score': 0.468,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000055435',
#    'Ensembl': 'ENSMUSP00000104732',
#    'score': 0.572,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052684',
#    'Ensembl': 'ENSMUSP00000102711',
#    'score': 0.597,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000055799',
#    'Ensembl': 'ENSMUSP00000109687',
#    'score': 0.761,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}]}

# %%
ppi_df[["target", "StringDB_ppi"]].head()
# Out:
#                target                                       StringDB_ppi
# 0  ENSMUSG00000021903  [{'stringdb_link_to': 'ENSMUSG00000021906', 'E...
# 1  ENSMUSG00000059824  [{'stringdb_link_to': 'ENSMUSG00000020893', 'E...
# 2  ENSMUSG00000041417  [{'stringdb_link_to': 'ENSMUSG00000000290', 'E...
# 3  ENSMUSG00000004939  [{'stringdb_link_to': 'ENSMUSG00000079243', 'E...
# 4  ENSMUSG00000028834  [{'stringdb_link_to': 'ENSMUSG00000020475', 'E...

# %%
ppi_df[ppi_df["target"] == "ENSMUSG00000032010"]["StringDB_ppi"].values
# Out:
# array([list([{'stringdb_link_to': 'ENSMUSG00000020893', 'Ensembl': 'ENSMUSP00000021271', 'score': 0.768, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSMUSG00000051705', 'Ensembl': 'ENSMUSP00000149463', 'score': 0.401, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSMUSG00000059824', 'Ensembl': 'ENSMUSP00000079693', 'score': 0.415, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSMUSG00000068742', 'Ensembl': 'ENSMUSP00000088047', 'score': 0.503, 'Uniprot-TrEMBL': 'Q9R194', 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSMUSG00000030967', 'Ensembl': 'ENSMUSP00000101763', 'score': 0.551, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSMUSG00000055116', 'Ensembl': 'ENSMUSP00000147989', 'score': 0.688, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}, {'stringdb_link_to': 'ENSMUSG00000008348', 'Ensembl': 'ENSMUSP00000114180', 'score': 0.856, 'Uniprot-TrEMBL': None, 'Uniprot-TrEMBL_link': None}])],
#       dtype=object)

# %%
ncbi_tf_gprofiler_mitocarta_df_mice.head(1)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl  78754  ncbi_gene_id         Galnt15
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  ...  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140  ...
#
#                                     g:Profiler_go:bp  \
# 0  [{'id': 'GO:0006493', 'name': 'protein O-linke...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0030133', 'name': 'transport vesic...
#
#                                     g:Profiler_go:mf g:Profiler_hp  \
# 0  [{'id': 'GO:0030246', 'name': 'carbohydrate bi...           NaN
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:mmu-miR-34b-5p', 'name': 'mmu-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-MMU-5173105', 'name': 'O-linke...
#
#                                        g:Profiler_tf g:Profiler_wp MitoCarta
# 0  [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...           NaN       NaN
#
# [1 rows x 28 columns]

# %%
combined_df = pd.merge(
    ncbi_tf_gprofiler_mitocarta_df_mice,
    ppi_df[["target", "StringDB_ppi"]].rename(columns={"target": "identifier"}),
    on="identifier",
    how="left",
)

# %%
combined_df.columns
# Out:
# Index(['identifier', 'identifier.source', 'target', 'target.source',
#        'GENE_SYMBOL_dea', 'baseMean_dea', 'log2FoldChange_dea', 'lfcSE_dea',
#        'stat_dea', 'pvalue_dea', 'padj_dea', 'minus_log10_pvalue_dea', 'is_tf',
#        'is_target', 'its_target', 'its_tf', 'intersections',
#        'g:Profiler_corum', 'g:Profiler_go:bp', 'g:Profiler_go:cc',
#        'g:Profiler_go:mf', 'g:Profiler_hp', 'g:Profiler_kegg',
#        'g:Profiler_mirna', 'g:Profiler_reac', 'g:Profiler_tf', 'g:Profiler_wp',
#        'MitoCarta', 'StringDB_ppi'],
#       dtype='object')

# %%
combined_df.head(1)
# Out:
#            identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 0  ENSMUSG00000021903           Ensembl  78754  ncbi_gene_id         Galnt15
#
#    baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea     pvalue_dea  ...  \
# 0   2770.437508            2.521182   0.099941  25.226601  2.046157e-140  ...
#
#                                     g:Profiler_go:cc  \
# 0  [{'id': 'GO:0030133', 'name': 'transport vesic...
#
#                                     g:Profiler_go:mf g:Profiler_hp  \
# 0  [{'id': 'GO:0030246', 'name': 'carbohydrate bi...           NaN
#
#                                      g:Profiler_kegg  \
# 0  [{'id': 'KEGG:01100', 'name': 'Metabolic pathw...
#
#                                     g:Profiler_mirna  \
# 0  [{'id': 'MIRNA:mmu-miR-34b-5p', 'name': 'mmu-m...
#
#                                      g:Profiler_reac  \
# 0  [{'id': 'REAC:R-MMU-5173105', 'name': 'O-linke...
#
#                                        g:Profiler_tf g:Profiler_wp MitoCarta  \
# 0  [{'id': 'TF:M04454_1', 'name': 'Factor: AR; mo...           NaN       NaN
#
#                                         StringDB_ppi
# 0  [{'stringdb_link_to': 'ENSMUSG00000021906', 'E...
#
# [1 rows x 29 columns]

# %%
combined_df["StringDB_ppi"].to_dict()
# Out:
# {0: [{'stringdb_link_to': 'ENSMUSG00000021906',
#    'Ensembl': 'ENSMUSP00000022462',
#    'score': 0.505,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  1: [{'stringdb_link_to': 'ENSMUSG00000020893',
#    'Ensembl': 'ENSMUSP00000021271',
#    'score': 0.7,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000023087',
#    'Ensembl': 'ENSMUSP00000023849',
#    'score': 0.425,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000030103',
#    'Ensembl': 'ENSMUSP00000032194',
#    'score': 0.47,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032010',
#    'Ensembl': 'ENSMUSP00000034508',
#    'score': 0.415,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000068742',
#    'Ensembl': 'ENSMUSP00000088047',
#    'score': 0.704,
#    'Uniprot-TrEMBL': 'Q9R194',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000055116',
#    'Ensembl': 'ENSMUSP00000147989',
#    'score': 0.933,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  2: [{'stringdb_link_to': 'ENSMUSG00000000290',
#    'Ensembl': 'ENSMUSP00000000299',
#    'score': 0.916,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000000359',
#    'Ensembl': 'ENSMUSP00000000369',
#    'score': 0.682,
#    'Uniprot-TrEMBL': 'O35929',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000000489',
#    'Ensembl': 'ENSMUSP00000000500',
#    'score': 0.603,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000004508',
#    'Ensembl': 'ENSMUSP00000004622',
#    'score': 0.975,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000007613',
#    'Ensembl': 'ENSMUSP00000007757',
#    'score': 0.62,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022346',
#    'Ensembl': 'ENSMUSP00000022971',
#    'score': 0.426,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022797',
#    'Ensembl': 'ENSMUSP00000023486',
#    'score': 0.472,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000024697',
#    'Ensembl': 'ENSMUSP00000025602',
#    'score': 0.571,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026012',
#    'Ensembl': 'ENSMUSP00000027165',
#    'score': 0.936,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026072',
#    'Ensembl': 'ENSMUSP00000027241',
#    'score': 0.58,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026173',
#    'Ensembl': 'ENSMUSP00000027362',
#    'score': 0.659,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026656',
#    'Ensembl': 'ENSMUSP00000027966',
#    'score': 0.588,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000029186',
#    'Ensembl': 'ENSMUSP00000031081',
#    'score': 0.908,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032766',
#    'Ensembl': 'ENSMUSP00000031670',
#    'score': 0.681,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000038894',
#    'Ensembl': 'ENSMUSP00000038514',
#    'score': 0.981,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000037104',
#    'Ensembl': 'ENSMUSP00000038591',
#    'score': 0.631,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000044641',
#    'Ensembl': 'ENSMUSP00000052619',
#    'score': 0.455,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000044167',
#    'Ensembl': 'ENSMUSP00000055308',
#    'score': 0.545,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000021782',
#    'Ensembl': 'ENSMUSP00000087879',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000066571',
#    'Ensembl': 'ENSMUSP00000103709',
#    'score': 0.406,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052684',
#    'Ensembl': 'ENSMUSP00000102711',
#    'score': 0.425,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000070348',
#    'Ensembl': 'ENSMUSP00000091495',
#    'score': 0.431,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000071713',
#    'Ensembl': 'ENSMUSP00000154836',
#    'score': 0.44,
#    'Uniprot-TrEMBL': 'P26955',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000021709',
#    'Ensembl': 'ENSMUSP00000140536',
#    'score': 0.445,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000040990',
#    'Ensembl': 'ENSMUSP00000108075',
#    'score': 0.474,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000074121',
#    'Ensembl': 'ENSMUSP00000057916',
#    'score': 0.499,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000048756',
#    'Ensembl': 'ENSMUSP00000101141',
#    'score': 0.511,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000110206',
#    'Ensembl': 'ENSMUSP00000123506',
#    'score': 0.528,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000048240',
#    'Ensembl': 'ENSMUSP00000097061',
#    'score': 0.65,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000053113',
#    'Ensembl': 'ENSMUSP00000059129',
#    'score': 0.673,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000023805',
#    'Ensembl': 'ENSMUSP00000111457',
#    'score': 0.684,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032192',
#    'Ensembl': 'ENSMUSP00000149938',
#    'score': 0.684,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00

#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000039361',
#    'Ensembl': 'ENSMUSP00000146501',
#    'score': 0.658,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000023067',
#    'Ensembl': 'ENSMUSP00000156559',
#    'score': 0.736,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000110206',
#    'Ensembl': 'ENSMUSP00000123506',
#    'score': 0.762,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000024589',
#    'Ensembl': 'ENSMUSP00000158026',
#    'score': 0.843,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000103034',
#    'Ensembl': 'ENSMUSP00000141419',
#    'score': 0.965,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  11: [{'stringdb_link_to': 'ENSMUSG00000061024',
#    'Ensembl': 'ENSMUSP00000071955',
#    'score': 0.445,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000103034',
#    'Ensembl': 'ENSMUSP00000141419',
#    'score': 0.467,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000110206',
#    'Ensembl': 'ENSMUSP00000123506',
#    'score': 0.502,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000042354',
#    'Ensembl': 'ENSMUSP00000047119',
#    'score': 0.603,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000060036',
#    'Ensembl': 'ENSMUSP00000080354',
#    'score': 0.617,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000030161',
#    'Ensembl': 'ENSMUSP00000032264',
#    'score': 0.685,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  12: [{'stringdb_link_to': 'ENSMUSG00000000359',
#    'Ensembl': 'ENSMUSP00000000369',
#    'score': 0.5,
#    'Uniprot-TrEMBL': 'O35929',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000004665',
#    'Ensembl': 'ENSMUSP00000004784',
#    'score': 0.54,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022091',
#    'Ensembl': 'ENSMUSP00000022682',
#    'score': 0.683,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000023277',
#    'Ensembl': 'ENSMUSP00000024047',
#    'score': 0.418,
#    'Uniprot-TrEMBL': 'Q9Z0P5',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000041378',
#    'Ensembl': 'ENSMUSP00000041925',
#    'score': 0.444,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026580',
#    'Ensembl': 'ENSMUSP00000123924',
#    'score': 0.459,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000037519',
#    'Ensembl': 'ENSMUSP00000138312',
#    'score': 0.475,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000037313',
#    'Ensembl': 'ENSMUSP00000074394',
#    'score': 0.52,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000079243',
#    'Ensembl': 'ENSMUSP00000107262',
#    'score': 0.556,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000068699',
#    'Ensembl': 'ENSMUSP00000064163',
#    'score': 0.562,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026971',
#    'Ensembl': 'ENSMUSP00000054944',
#    'score': 0.677,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027009',
#    'Ensembl': 'ENSMUSP00000099718',
#    'score': 0.697,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  13: [{'stringdb_link_to': 'ENSMUSG00000037251',
#    'Ensembl': 'ENSMUSP00000053802',
#    'score': 0.992,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000028414',
#    'Ensembl': 'ENSMUSP00000114699',
#    'score': 0.878,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  14: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  15: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  16: [{'stringdb_link_to': 'ENSMUSG00000031775',
#    'Ensembl': 'ENSMUSP00000034227',
#    'score': 0.602,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  17: [{'stringdb_link_to': 'ENSMUSG00000007122',
#    'Ensembl': 'ENSMUSP00000003554',
#    'score': 0.41,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022357',
#    'Ensembl': 'ENSMUSP00000022985',
#    'score': 0.505,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000051985',
#    'Ensembl': 'ENSMUSP00000129680',
#    'score': 0.462,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000068699',
#    'Ensembl': 'ENSMUSP00000064163',
#    'score': 0.486,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  18: [{'stringdb_link_to': 'ENSMUSG00000022074',
#    'Ensembl': 'ENSMUSP00000022663',
#    'score': 0.454,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000025880',
#    'Ensembl': 'ENSMUSP00000026999',
#    'score': 0.43,
#    'Uniprot-TrEMBL': 'O35253',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000031490',
#    'Ensembl': 'ENSMUSP00000033880',
#    'score': 0.418,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000036390',
#    'Ensembl': 'ENSMUSP00000044034',
#    'score': 0.522,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000030104',
#    'Ensembl': 'ENSMUSP00000086565',
#    'score': 0.641,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052684',
#    'Ensembl': 'ENSMUSP00000102711',
#    'score': 0.47,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027381',
#    'Ensembl': 'ENSMUSP00000105970',
#    'score': 0.486,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#

#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000074064',
#    'Ensembl': 'ENSMUSP00000095970',
#    'score': 0.509,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000008348',
#    'Ensembl': 'ENSMUSP00000114180',
#    'score': 0.517,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000021456',
#    'Ensembl': 'ENSMUSP00000021907',
#    'score': 0.901,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  31: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  32: [{'stringdb_link_to': 'ENSMUSG00000067081',
#    'Ensembl': 'ENSMUSP00000084095',
#    'score': 0.463,
#    'Uniprot-TrEMBL': 'Q8VHA6',
#    'Uniprot-TrEMBL_link': None}],
#  33: [{'stringdb_link_to': 'ENSMUSG00000049281',
#    'Ensembl': 'ENSMUSP00000051627',
#    'score': 0.401,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  34: [{'stringdb_link_to': 'ENSMUSG00000022346',
#    'Ensembl': 'ENSMUSP00000022971',
#    'score': 0.504,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022952',
#    'Ensembl': 'ENSMUSP00000023673',
#    'score': 0.836,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000025220',
#    'Ensembl': 'ENSMUSP00000026243',
#    'score': 0.517,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000036390',
#    'Ensembl': 'ENSMUSP00000044034',
#    'score': 0.601,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000046668',
#    'Ensembl': 'ENSMUSP00000054307',
#    'score': 0.9,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000016559',
#    'Ensembl': 'ENSMUSP00000102062',
#    'score': 0.606,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000042548',
#    'Ensembl': 'ENSMUSP00000105413',
#    'score': 0.92,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000053470',
#    'Ensembl': 'ENSMUSP00000128789',
#    'score': 0.409,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  35: [{'stringdb_link_to': 'ENSMUSG00000038022',
#    'Ensembl': 'ENSMUSP00000061221',
#    'score': 0.554,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  36: [{'stringdb_link_to': 'ENSMUSG00000005686',
#    'Ensembl': 'ENSMUSP00000005829',
#    'score': 0.54,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  37: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  38: [{'stringdb_link_to': 'ENSMUSG00000002289',
#    'Ensembl': 'ENSMUSP00000002360',
#    'score': 0.767,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000048756',
#    'Ensembl': 'ENSMUSP00000101141',
#    'score': 0.4,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000030278',
#    'Ensembl': 'ENSMUSP00000108712',
#    'score': 0.409,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000024222',
#    'Ensembl': 'ENSMUSP00000110440',
#    'score': 0.41,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000025007',
#    'Ensembl': 'ENSMUSP00000025979',
#    'score': 0.411,
# ...
#  948: [{'stringdb_link_to': 'ENSMUSG00000038642',
#    'Ensembl': 'ENSMUSP00000015667',
#    'score': 0.409,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022797',
#    'Ensembl': 'ENSMUSP00000023486',
#    'score': 0.678,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000028854',
#    'Ensembl': 'ENSMUSP00000030669',
#    'score': 0.442,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000070348',
#    'Ensembl': 'ENSMUSP00000091495',
#    'score': 0.453,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000073418',
#    'Ensembl': 'ENSMUSP00000069418',
#    'score': 0.454,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052684',
#    'Ensembl': 'ENSMUSP00000102711',
#    'score': 0.461,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000071713',
#    'Ensembl': 'ENSMUSP00000154836',
#    'score': 0.486,
#    'Uniprot-TrEMBL': 'P26955',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000039361',
#    'Ensembl': 'ENSMUSP00000146501',
#    'score': 0.52,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000010609',
#    'Ensembl': 'ENSMUSP00000106735',
#    'score': 0.817,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  949: [{'stringdb_link_to': 'ENSMUSG00000079020',
#    'Ensembl': 'ENSMUSP00000121775',
#    'score': 0.413,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000025512',
#    'Ensembl': 'ENSMUSP00000130360',
#    'score': 0.48,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  950: nan,
#  951: [{'stringdb_link_to': 'ENSMUSG00000015340',
#    'Ensembl': 'ENSMUSP00000015484',
#    'score': 0.488,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000022797',
#    'Ensembl': 'ENSMUSP00000023486',
#    'score': 0.615,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052305',
#    'Ensembl': 'ENSMUSP00000023934',
#    'score': 0.749,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000

#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000070348',
#    'Ensembl': 'ENSMUSP00000091495',
#    'score': 0.738,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000016559',
#    'Ensembl': 'ENSMUSP00000102062',
#    'score': 0.757,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000042548',
#    'Ensembl': 'ENSMUSP00000105413',
#    'score': 0.788,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000053113',
#    'Ensembl': 'ENSMUSP00000059129',
#    'score': 0.828,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000040943',
#    'Ensembl': 'ENSMUSP00000143029',
#    'score': 0.836,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000048756',
#    'Ensembl': 'ENSMUSP00000101141',
#    'score': 0.84,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  955: nan,
#  956: [{'stringdb_link_to': 'ENSMUSG00000019948',
#    'Ensembl': 'ENSMUSP00000020109',
#    'score': 0.606,
#    'Uniprot-TrEMBL': 'A0A0R4J009',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000028329',
#    'Ensembl': 'ENSMUSP00000030013',
#    'score': 0.509,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000016559',
#    'Ensembl': 'ENSMUSP00000102062',
#    'score': 0.414,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000031543',
#    'Ensembl': 'ENSMUSP00000113571',
#    'score': 0.456,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000042185',
#    'Ensembl': 'ENSMUSP00000083341',
#    'score': 0.997,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  957: nan,
#  958: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  959: nan,
#  960: [{'stringdb_link_to': 'ENSMUSG00000024168',
#    'Ensembl': 'ENSMUSP00000024984',
#    'score': 0.54,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  961: nan,
#  962: nan,
#  963: nan,
#  964: [{'stringdb_link_to': 'ENSMUSG00000062031',
#    'Ensembl': 'ENSMUSP00000078372',
#    'score': 0.432,
#    'Uniprot-TrEMBL': 'Q8BP56',
#    'Uniprot-TrEMBL_link': None}],
#  965: nan,
#  966: nan,
#  967: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  968: [{'stringdb_link_to': 'ENSMUSG00000022952',
#    'Ensembl': 'ENSMUSP00000023673',
#    'score': 0.536,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000039410',
#    'Ensembl': 'ENSMUSP00000030902',
#    'score': 0.414,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000029135',
#    'Ensembl': 'ENSMUSP00000031017',
#    'score': 0.549,
#    'Uniprot-TrEMBL': 'P47930',
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000033863',
#    'Ensembl': 'ENSMUSP00000045639',
#    'score': 0.457,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000053113',
#    'Ensembl': 'ENSMUSP00000059129',
#    'score': 0.493,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052837',
#    'Ensembl': 'ENSMUSP00000064680',
#    'score': 0.518,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000052684',
#    'Ensembl': 'ENSMUSP00000102711',
#    'score': 0.76,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000030087',
#    'Ensembl': 'ENSMUSP00000144962',
#    'score': 0.538,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  969: nan,
#  970: nan,
#  971: nan,
#  972: nan,
#  973: nan,
#  974: [{'stringdb_link_to': 'ENSMUSG00000001627',
#    'Ensembl': 'ENSMUSP00000001672',
#    'score': 0.484,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027858',
#    'Ensembl': 'ENSMUSP00000029451',
#    'score': 0.43,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000016559',
#    'Ensembl': 'ENSMUSP00000102062',
#    'score': 0.541,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000047407',
#    'Ensembl': 'ENSMUSP00000130930',
#    'score': 0.429,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  975: [{'stringdb_link_to': 'ENSMUSG00000039754',
#    'Ensembl': 'ENSMUSP00000040403',
#    'score': 0.866,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  976: [{'stringdb_link_to': 'ENSMUSG00000024413',
#    'Ensembl': 'ENSMUSP00000025279',
#    'score': 0.821,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000001700',
#    'Ensembl': 'ENSMUSP00000157710',
#    'score': 0.468,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  977: nan,
#  978: nan,
#  979: nan,
#  980: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  981: nan,
#  982: nan,
#  983: [{'stringdb_link_to': 'ENSMUSG00000032766',
#    'Ensembl': 'ENSMUSP00000031670',
#    'score': 0.688,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032177',
#    'Ensembl': 'ENSMUSP00000037025',
#    'score': 0.764,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000048240',
#    'Ensembl': 'ENSMUSP00000097061',
#    'score': 0.732,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000021948',
#    'Ensembl': 'ENSMUSP00000107830',
#    'score': 0.918,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000021699',
#    'Ensembl': 'ENSMUSP00000113488',
#    'score': 0.75,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000032192',
#    'Ensembl': 'ENSMUSP00000149938',
#    'score': 0.677,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000064120',
#    'Ensembl': 'ENSMUSP00000133694',
#    'score': 0.808,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  984: nan,
#  985: nan,
#  986: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  987: nan,
#  988: nan,
#  989: nan,
#  990: [{'stringdb_link_to': 'ENSMUSG00000022009',
#    'Ensembl': 'ENSMUSP00000022586',
#    'score': 0.545,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000026743',
#    'Ensembl': 'ENSMUSP00000028076',
#    'score': 0.919,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000027829',
#    'Ensembl': 'ENSMUSP00000029416',
#    'score': 0.73,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000029313',
#    'Ensembl': 'ENSMUSP00000031256',
#    'score': 0.999,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000033323',
#    'Ensembl': 'ENSMUSP00000038938',
#    'score': 0.818,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None},
#   {'stringdb_link_to': 'ENSMUSG00000041328',
#    'Ensembl': 'ENSMUSP00000113717',
#    'score': 0.488,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  991: nan,
#  992: nan,
#  993: nan,
#  994: nan,
#  995: nan,
#  996: [{'stringdb_link_to': nan,
#    'Ensembl': nan,
#    'score': nan,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  997: [{'stringdb_link_to': 'ENSMUSG00000038248',
#    'Ensembl': 'ENSMUSP00000040072',
#    'score': 0.424,
#    'Uniprot-TrEMBL': None,
#    'Uniprot-TrEMBL_link': None}],
#  998: nan,
#  999: nan,
#  ...}

# %%
filename_mice = "data/mice/combined_df.pkl"

combined_df.to_pickle(filename_mice)

# %% [markdown]
# ### graph

# %%
filename_mice = "data/mice/combined_df.pkl"
with open(filename_mice, "rb") as f:
    combined_df = pickle.load(f)

# %%
# Extract all 'NCBI.GeneID.TF' values into a single list
ncbi_gene_ids = (
    combined_df["its_tf"]
    .apply(lambda x: [d["NCBI.GeneID.TF"] for d in x] if isinstance(x, list) else [])
    .explode()
    .dropna()
    .unique()
    .tolist()
)

len(ncbi_gene_ids)
# Out:
# 529

# %%
combined_df_tf = combined_df[combined_df["target"].isin(ncbi_gene_ids)]
combined_df_sig = combined_df[
    (combined_df['padj_dea'] < 0.01) &
    (
        (combined_df['log2FoldChange_dea'] > 1) |
        (combined_df['log2FoldChange_dea'] < -1)
    )]


combined_df_sig = combined_df_sig[~combined_df_sig["target"].isin(ncbi_gene_ids)]
combined_df_sig.shape
# Out:
# (755, 29)

# %%
combined_df_tf_sig = pd.concat([combined_df_sig, combined_df_tf], axis=0, ignore_index=True)
combined_df_tf_sig.shape
# Out:
# (1285, 29)

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"] == "COQ10A"]["its_tf"].apply(
    lambda x: isinstance(x, list)
)
# Out:
# Series([], Name: its_tf, dtype: object)

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"] == "COQ10A"]["its_tf"].to_dict()
# Out:
# {}

# %%
combined_df_tf[~combined_df_tf["target"].isin(combined_df_sig["target"].tolist())]
# Out:
#                identifier identifier.source  target target.source  \
# 1      ENSMUSG00000059824           Ensembl   13170  ncbi_gene_id
# 9      ENSMUSG00000037465           Ensembl   21847  ncbi_gene_id
# 21     ENSMUSG00000042292           Ensembl  223701  ncbi_gene_id
# 29     ENSMUSG00000018143           Ensembl   17135  ncbi_gene_id
# 34     ENSMUSG00000040943           Ensembl  214133  ncbi_gene_id
# ...                   ...               ...     ...           ...
# 11084  ENSMUSG00000000440           Ensembl   19016  ncbi_gene_id
# 11131  ENSMUSG00000055866           Ensembl   18627  ncbi_gene_id
# 11136  ENSMUSG00000033249           Ensembl   26386  ncbi_gene_id
# 11143  ENSMUSG00000026021           Ensembl   22218  ncbi_gene_id
# 11225  ENSMUSG00000005718           Ensembl   83383  ncbi_gene_id
#
#       GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea   stat_dea  \
# 1                 Dbp   2816.783019           -2.985239   0.191760 -15.567614
# 9               Klf10   2481.208552            2.189743   0.166819  13.126470
# 21               Mkl1   1080.501466           -2.232213   0.191789 -11.638880
# 29               Mafk   2165.985925            2.109705   0.193895  10.880657
# 34               Tet2    841.463638            1.321798   0.125819  10.505543
# ...               ...           ...                 ...        ...        ...
# 11084           Pparg    104.582903           -0.012934   0.259905  -0.049763
# 11131            Per2   1058.682323            0.006802   0.207956   0.032707
# 11136            Hsf4    367.784805            0.005086   0.162026   0.031391
# 11143           Sumo1   1372.979132           -0.002733   0.094426  -0.028941
# 11225           Tfap4    274.276267           -0.000643   0.251716  -0.002556
#
#          pvalue_dea  ...                                   g:Profiler_go:cc  \
# 1      1.208303e-54  ...  [{'id': 'GO:0005667', 'name': 'transcription r...
# 9      2.322309e-39  ...  [{'id': 'GO:0005622', 'name': 'intracellular a...
# 21     2.614271e-31  ...  [{'id': 'GO:0005737', 'name': 'cytoplasm', 'p_...
# 29     1.425327e-27  ...  [{'id': 'GO:0005622', 'name': 'intracellular a...
# 34     8.145301e-26  ...  [{'id': 'GO:0005622', 'name': 'intracellular a...
# ...             ...  ...                                                ...
# 11084  9.603111e-01  ...                                                NaN
# 11131  9.739080e-01  ...                                                NaN
# 11136  9.749574e-01  ...                                                NaN
# 11143  9.769115e-01  ...                                                NaN
# 11225  9.979610e-01  ...                                                NaN
#
#                                         g:Profiler_go:mf  \
# 1      [{'id': 'GO:0000981', 'name': 'DNA-binding tra...
# 9      [{'id': 'GO:0005515', 'name': 'protein binding...
# 21     [{'id': 'GO:0005515', 'name': 'protein binding...
# 29     [{'id': 'GO:0005515', 'name': 'protein binding...
# 34     [{'id': 'GO:0005515', 'name': 'protein binding...
# ...                                                  ...
# 11084                                                NaN
# 11131                                                NaN
# 11136                                                NaN
# 11143                                                NaN
# 11225                                                NaN
#
#                                            g:Profiler_hp  \
# 1                                                    NaN
# 9                                                    NaN
# 21     [{'id': 'HP:0031378', 'name': 'Abnormal lympho...
# 29                                                   NaN
# 34     [{'id': 'HP:0030386', 'name': 'Abnormal propor...
# ...                                                  ...
# 11084                                                NaN
# 11131                                                NaN
# 11136                                                NaN
# 11143                                                NaN
# 11225                                                NaN
#
#                                          g:Profiler_kegg  \
# 1      [{'id': 'KEGG:04710', 'name': 'Circadian rhyth...
# 9                                                    NaN
# 21                                                   NaN
# 29                                                   NaN
# 34                                                   NaN
# ...                                                  ...
# 11084                                                NaN
# 11131                                                NaN
# 11136                                                NaN
# 11143                                                NaN
# 11225                                                NaN
#
#                                         g:Profiler_mirna  \
# 1      [{'id': 'MIRNA:mmu-miR-122-5p', 'name': 'mmu-m...
# 9      [{'id': 'MIRNA:mmu-miR-301b-3p', 'name': 'mmu-...
# 21     [{'id': 'MIRNA:mmu-miR-1a-3p', 'name': 'mmu-mi...
# 29     [{'id': 'MIRNA:mmu-miR-3473c', 'name': 'mmu-mi...
# 34     [{'id': 'MIRNA:mmu-miR-466d-5p', 'name': 'mmu-...
# ...                                                  ...
# 11084                                                NaN
# 11131                                                NaN
# 11136                                                NaN
# 11143                                                NaN
# 11225                                                NaN
#
#                                          g:Profiler_reac  \
# 1                                                    NaN
# 9                                                    NaN
# 21     [{'id': 'REAC:R-MMU-162582', 'name': 'Signal T...
# 29     [{'id': 'REAC:R-MMU-9707616', 'name': 'Heme si...
# 34                                                   NaN
# ...                                                  ...
# 11084                                                NaN
# 11131                                                NaN
# 11136                                                NaN
# 11143                                                NaN
# 11225                                                NaN
#
#                                            g:Profiler_tf  \
# 1      [{'id': 'TF:M03882', 'name': 'Factor: RelB:p50...
# 9      [{'id': 'TF:M00002', 'name': 'Factor: E47; mot...
# 21     [{'id': 'TF:M02024_1', 'name': 'Factor: mef-2A...
# 29     [{'id': 'TF:M10174_1', 'name': 'Factor: AR; mo...
# 34     [{'id': 'TF:M03882', 'name': 'Factor: RelB:p50...
# ...                                                  ...
# 11084                                                NaN
# 11131                                                NaN
# 11136                                                NaN
# 11143                                                NaN
# 11225                                                NaN
#
#                                            g:Profiler_wp MitoCarta  \
# 1                                                    NaN       NaN
# 9                                                    NaN       NaN
# 21                                                   NaN       NaN
# 29     [{'id': 'WP:WP4265', 'name': 'Ethanol metaboli...       NaN
# 34                                                   NaN       NaN
# ...                                                  ...       ...
# 11084                                                NaN       NaN
# 11131                                                NaN       NaN
# 11136                                                NaN       NaN
# 11143                                                NaN       NaN
# 11225                                                NaN       NaN
#
#                                             StringDB_ppi
# 1      [{'stringdb_link_to': 'ENSMUSG00000020893', 'E...
# 9      [{'stringdb_link_to': 'ENSMUSG00000025880', 'E...
# 21     [{'stringdb_link_to': 'ENSMUSG00000044167', 'E...
# 29     [{'stringdb_link_to': 'ENSMUSG00000025612', 'E...
# 34     [{'stringdb_link_to': 'ENSMUSG00000022346', 'E...
# ...                                                  ...
# 11084                                                NaN
# 11131                                                NaN
# 11136                                                NaN
# 11143                                                NaN
# 11225                                                NaN
#
# [530 rows x 29 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["identifier"].isin(["ENSG00000001167", "ENSG00000116717"])]
# Out:
# Empty DataFrame
# Columns: [identifier, identifier.source, target, target.source, GENE_SYMBOL_dea, baseMean_dea, log2FoldChange_dea, lfcSE_dea, stat_dea, pvalue_dea, padj_dea, minus_log10_pvalue_dea, is_tf, is_target, its_target, its_tf, intersections, g:Profiler_corum, g:Profiler_go:bp, g:Profiler_go:cc, g:Profiler_go:mf, g:Profiler_hp, g:Profiler_kegg, g:Profiler_mirna, g:Profiler_reac, g:Profiler_tf, g:Profiler_wp, MitoCarta, StringDB_ppi]
# Index: []
#
# [0 rows x 29 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["identifier"] == "ENSG00000001167"]
# Out:
#           identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 205  ENSG00000001167           Ensembl   4800  ncbi_gene_id            NFYA
#
#      baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 205    198.963515            0.339027   0.133075  2.547627    0.010846  ...
#
#      g:Profiler_go:mf  g:Profiler_hp g:Profiler_hpa g:Profiler_kegg  \
# 205               NaN            NaN            NaN             NaN
#
#     g:Profiler_mirna g:Profiler_reac g:Profiler_tf g:Profiler_wp MitoCarta  \
# 205              NaN             NaN           NaN           NaN       NaN
#
#     StringDB_ppi
# 205          NaN
#
# [1 rows x 30 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"] == "GADD45A"]
# Out:
#          identifier identifier.source target target.source GENE_SYMBOL_dea  \
# 55  ENSG00000116717           Ensembl   1647  ncbi_gene_id         GADD45A
#
#     baseMean_dea  log2FoldChange_dea  lfcSE_dea  stat_dea  pvalue_dea  ...  \
# 55     448.20828            1.432184   0.377628  3.792579    0.000149  ...
#
#                                      g:Profiler_go:mf  g:Profiler_hp  \
# 55  [{'id': 'GO:0019899', 'name': 'enzyme binding'...            NaN
#
#    g:Profiler_hpa                                    g:Profiler_kegg  \
# 55            NaN  [{'id': 'KEGG:05220', 'name': 'Chronic myeloid...
#
#                                      g:Profiler_mirna  \
# 55  [{'id': 'MIRNA:hsa-miR-26b-5p', 'name': 'hsa-m...
#
#                                       g:Profiler_reac  \
# 55  [{'id': 'REAC:R-HSA-6791312', 'name': 'TP53 Re...
#
#                                         g:Profiler_tf  \
# 55  [{'id': 'TF:M07322_1', 'name': 'Factor: HSF4; ...
#
#                                         g:Profiler_wp MitoCarta  \
# 55  [{'id': 'WP:WP3640', 'name': 'Imatinib and chr...       NaN
#
#                                          StringDB_ppi
# 55  [{'stringdb_link_to': 'ENSG00000120129', 'Ense...
#
# [1 rows x 30 columns]

# %%
combined_df_tf_sig[combined_df_tf_sig["identifier"] == "ENSG00000001167"]["its_target"].to_dict()
# Out:
# {205: [{'NCBI.GeneID.Target': '1647',
#    'Ensembl.GeneID.Target': 'ENSG00000116717',
#    'Name.Target': 'GADD45A',
#    'UniprotID.Target': 'P24522',
#    'Target.TFLink.ortho': 'Dr:Q6GMM1;Mm:P48316;Rn:Q66HL6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay;inferred by curator',
#    'PubmedID': '29126285;11525640;11420680;27924024;29087512',
#    'Source.database': 'GTRD;ReMap;TRRUST',
#    'Small-scale.evidence': 'Yes'},
#   {'NCBI.GeneID.Target': '84271',
#    'Ensembl.GeneID.Target': 'ENSG00000100227',
#    'Name.Target': 'POLDIP3',
#    'UniprotID.Target': 'Q9BY77',
#    'Target.TFLink.ortho': 'Mm:Q8BG81;Rn:D4A2B0',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4ILC0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4043',
#    'Ensembl.GeneID.Target': 'ENSG00000163956',
#    'Name.Target': 'LRPAP1',
#    'UniprotID.Target': 'P30533',
#    'Target.TFLink.ortho': 'Ce:G5EF26;Dm:Q9VH64;Dr:A2BGU5;Mm:P55302;Rn:Q99068',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51655',
#    'Ensembl.GeneID.Target': 'ENSG00000108551',
#    'Name.Target': 'RASD1',
#    'UniprotID.Target': 'Q9Y272',
#    'Target.TFLink.ortho': 'Dr:Q6PHV8;Mm:O35626;Rn:Q9JKF8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '28231',
#    'Ensembl.GeneID.Target': 'ENSG00000101187',
#    'Name.Target': 'SLCO4A1',
#    'UniprotID.Target': 'Q96BD0',
#    'Target.TFLink.ortho': 'Ce:Q9XWC5;Ce:X5LPS1;Dm:Q8SY02;Dr:E7FFX7;Mm:Q8K078;Rn:Q4V8N6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '757',
#    'Ensembl.GeneID.Target': 'ENSG00000142188',
#    'Name.Target': 'TMEM50B',
#    'UniprotID.Target': 'P56557',
#    'Target.TFLink.ortho': 'Dm:Q9VZE2;Mm:Q9D1X9;Rn:Q5BJS6',
#    'Target.nonTFLink.ortho': 'Ce:Q9N2X7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8869',
#    'Ensembl.GeneID.Target': 'ENSG00000115525',
#    'Name.Target': 'ST3GAL5',
#    'UniprotID.Target': 'Q9UNP4',
#    'Target.TFLink.ortho': 'Rn:Q68G12',
#    'Target.nonTFLink.ortho': 'Dr:F1RCA6;Mm:A0A0U1RNK2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '123803',
#    'Ensembl.GeneID.Target': 'ENSG00000157045',
#    'Name.Target': 'NTAN1',
#    'UniprotID.Target': 'Q96AB6',
#    'Target.TFLink.ortho': 'Dm:Q7KIS4;Mm:Q64311;Rn:A0A0G2JWG0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '57610',
#    'Ensembl.GeneID.Target': 'ENSG00000141084',
#    'Name.Target': 'RANBP10',
#    'UniprotID.Target': 'Q6VN20',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9846',
#    'Ensembl.GeneID.Target': 'ENSG00000033327',
#    'Name.Target': 'GAB2',
#    'UniprotID.Target': 'Q9UQC2',
#    'Target.TFLink.ortho': 'Mm:Q3ZB57;Rn:F1LSR2',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4I9X7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '124936',
#    'Ensembl.GeneID.Target': 'ENSG00000167740',
#    'Name.Target': 'CYB5D2',
#    'UniprotID.Target': 'Q8WUJ1',
#    'Target.TFLink.ortho': 'Ce:Q9XXA7;Dm:Q9W376;Mm:Q5SSH8;Rn:Q6AY62',
#    'Target.nonTFLink.ortho': 'Dr:A2CES0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55699',
#    'Ensembl.GeneID.Target': 'ENSG00000067704',
#    'Name.Target': 'IARS2',
#    'UniprotID.Target': 'Q9NSE4',
#    'Target.TFLink.ortho': 'Dm:Q9VUY4;Dr:F1QUQ0;Mm:Q8BIJ6;Rn:A0A0G2K261;Sc:P48526',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '753',
#    'Ensembl.GeneID.Target': 'ENSG00000168675',
#    'Name.Target': 'LDLRAD4',
#    'UniprotID.Target': 'O15165',
#    'Target.TFLink.ortho': 'Dr:E9QGX8;Mm:Q8BWJ4',
#    'Target.nonTFLink.ortho': 'Rn:F1LZA8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10904',
#    'Ensembl.GeneID.Target': 'ENSG00000166619',
#    'Name.Target': 'BLCAP',
#    'UniprotID.Target': 'P62952',
#    'Target.TFLink.ortho': 'Ce:G5EE03;Dm:Q9V3L0;Dr:Q9IB61;Mm:P62951;Rn:P62950',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10367',
#    'Ensembl.GeneID.Target': 'ENSG00000107745',
#    'Name.Target': 'MICU1',
#    'UniprotID.Target': 'Q9BPX6',
#    'Target.TFLink.ortho': 'Ce:Q95PZ2;Dm:A2VEI2;Mm:Q8VCX5;Rn:A0A0G2K0T5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '100272147',
#    'Ensembl.GeneID.Target': 'ENSG00000182712',
#    'Name.Target': 'CMC4',
#    'UniprotID.Target': 'P56277',
#    'Target.TFLink.ortho': 'Dm:B7YZN8;Dr:A0A0R4IZJ0;Mm:Q61908;Rn:A0A0G2K2W2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4719',
#    'Ensembl.GeneID.Target': 'ENSG00000023228',
#    'Name.Target': 'NDUFS1',
#    'UniprotID.Target': 'P28331',
#    'Target.TFLink.ortho': 'Ce:Q9N4Y8;Dm:Q94511;Mm:Q91VD9;Rn:Q66HF1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1738',
#    'Ensembl.GeneID.Target': 'ENSG00000091140',
#    'Name.Target': 'DLD',
#    'UniprotID.Target': 'P09622',
#    'Target.TFLink.ortho': 'Ce:O17953;Dm:Q9VVL7;Dr:Q6TNU6;Mm:O08749;Rn:Q6P6R2;Sc:P09624',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '127687',
#    'Ensembl.GeneID.Target': 'ENSG00000197982',
#    'Name.Target': 'C1orf122',
#    'UniprotID.Target': 'Q6ZSJ8',
#    'Target.TFLink.ortho': 'Rn:D3ZK76',
#    'Target.nonTFLink.ortho': 'Mm:V9GXF1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6596',
#    'Ensembl.GeneID.Target': 'ENSG00000071794',
#    'Name.Target': 'HLTF',
#    'UniprotID.Target': 'Q14527',
#    'Target.TFLink.ortho': 'Dr:B0V118;Mm:Q6PCN7;Rn:A0A0G2JVH5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8195',
#    'Ensembl.GeneID.Target': 'ENSG00000125863',
#    'Name.Target': 'MKKS',
#    'UniprotID.Target': 'Q9NPJ1',
#    'Target.TFLink.ortho': 'Dr:F1QCQ8;Mm:Q9JI70;Rn:Q5XI30',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2235',
#    'Ensembl.GeneID.Target': 'ENSG00000066926',
#    'Name.Target': 'FECH',
#    'UniprotID.Target': 'P22830',
#    'Target.TFLink.ortho': 'Dm:Q9V9S8;Dr:F1R362;Mm:Q544X6;Rn:D3ZBM3;Sc:P16622',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56180',
#    'Ensembl.GeneID.Target': 'ENSG00000101928',
#    'Name.Target': 'MOSPD1',
#    'UniprotID.Target': 'Q9UJG1',
#    'Target.TFLink.ortho': 'Dr:F1R9R3;Mm:Q8VEL0',
#    'Target.nonTFLink.ortho': 'Rn:Q5RJS6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7436',
#    'Ensembl.GeneID.Target': 'ENSG00000147852',
#    'Name.Target': 'VLDLR',
#    'UniprotID.Target': 'P98155',
#    'Target.TFLink.ortho': 'Mm:P98156;Rn:F1LPV2',
#    'Target.nonTFLink.ortho': 'Dr:E9QBA5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '154810',
#    'Ensembl.GeneID.Target': 'ENSG00000166025',
#    'Name.Target': 'AMOTL1',
#    'UniprotID.Target': 'Q8IY63',
#    'Target.TFLink.ortho': 'Mm:Q9D4H4;Rn:F1LZQ6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '92106',
#    'Ensembl.GeneID.Target': 'ENSG00000154814',
#    'Name.Target': 'OXNAD1',
#    'UniprotID.Target': 'Q96HP4',
#    'Target.TFLink.ortho': 'Dr:I3ISI1;Mm:Q8VE38;Rn:D4A0Y4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1666',
#    'Ensembl.GeneID.Target': 'ENSG00000104325',
#    'Name.Target': 'DECR1',
#    'UniprotID.Target': 'Q16698',
#    'Target.TFLink.ortho': 'Ce:Q93761;Dr:F1QB21;Mm:Q9CQ62;Rn:G3V734',
#    'Target.nonTFLink.ortho': 'Ce:Q22230;Ce:Q23116',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54541',
#    'Ensembl.GeneID.Target': 'ENSG00000168209',
#    'Name.Target': 'DDIT4',
#    'UniprotID.Target': 'Q9NX09',
#    'Target.TFLink.ortho': 'Dm:Q9VTH4;Dr:Q7T346;Mm:Q9D3F7;Rn:G3V620',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8898',
#    'Ensembl.GeneID.Target': 'ENSG00000087053',
#    'Name.Target': 'MTMR2',
#    'UniprotID.Target': 'Q13614',
#    'Target.TFLink.ortho': 'Dm:Q9VMI9;Dr:A0JMK5;Mm:Q9Z2D1;Rn:D3ZA31',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '549',
#    'Ensembl.GeneID.Target': 'ENSG00000148090',
#    'Name.Target': 'AUH',
#    'UniprotID.Target': 'Q13825',
#    'Target.TFLink.ortho': 'Ce:O45106;Dm:A1Z934;Mm:A0A0R4J023;Rn:F1LU71',
#    'Target.nonTFLink.ortho': 'Dr:F1RDX1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '203260',
#    'Ensembl.GeneID.Target': 'ENSG00000159884',
#    'Name.Target': 'CCDC107',
#    'UniprotID.Target': 'Q8WV48',
#    'Target.TFLink.ortho': 'Mm:Q9DCC3;Rn:D4A3Y2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '26287',
#    'Ensembl.GeneID.Target': 'ENSG00000165887',
#    'Name.Target': 'ANKRD2',
#    'UniprotID.Target': 'Q9GZV1',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '391356',
#    'Ensembl.GeneID.Target': 'ENSG00000184924',
#    'Name.Target': 'PTRHD1',
#    'UniprotID.Target': 'Q6GMV3',
#    'Target.TFLink.ortho': 'Ce:A7WK43;Dm:Q9VET3;Dr:Q5RIN6;Mm:D3Z4S3;Rn:D3ZBG6',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2589',
#    'Ensembl.GeneID.Target': 'ENSG00000141429',
#    'Name.Target': 'GALNT1',
#    'UniprotID.Target': 'Q10472',
#    'Target.TFLink.ortho': 'Ce:P34678;Dr:E7FDA0;Mm:O08912;Rn:Q10473',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4609',
#    'Ensembl.GeneID.Target': 'ENSG00000136997',
#    'Name.Target': 'MYC',
#    'UniprotID.Target': 'P01106',
#    'Target.TFLink.ortho': 'Dr:F1RC36;Mm:P01108',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '93058',
#    'Ensembl.GeneID.Target': 'ENSG00000135469',
#    'Name.Target': 'COQ10A',
#    'UniprotID.Target': 'Q96MF6',
#    'Target.TFLink.ortho': 'Dm:Q8MLL3;Mm:E9Q3H6;Rn:D3ZX74;Sc:Q08058',
#    'Target.nonTFLink.ortho': 'Ce:Q304F0;Dr:E9QFB6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79634',
#    'Ensembl.GeneID.Target': 'ENSG00000144306',
#    'Name.Target': 'SCRN3',
#    'UniprotID.Target': 'Q0VDG4',
#    'Target.TFLink.ortho': 'Dr:Q803W1;Mm:Q3TMH2;Rn:A0A0G2K189',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2114',
#    'Ensembl.GeneID.Target': 'ENSG00000157557',
#    'Name.Target': 'ETS2',
#    'UniprotID.Target': 'P15036',
#    'Target.TFLink.ortho': 'Dr:Q501S1;Mm:P15037;Rn:D4AAH4',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '200765',
#    'Ensembl.GeneID.Target': 'ENSG00000221944',
#    'Name.Target': 'TIGD1',
#    'UniprotID.Target': 'Q96MW7',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4536',
#    'Ensembl.GeneID.Target': 'ENSG00000198763',
#    'Name.Target': 'MT-ND2',
#    'UniprotID.Target': 'P03891',
#    'Target.TFLink.ortho': 'Dr:Q9MIY9;Mm:P03893;Rn:P11662',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51390',
#    'Ensembl.GeneID.Target': 'ENSG00000146416',
#    'Name.Target': 'AIG1',
#    'UniprotID.Target': 'Q9NVV5',
#    'Target.TFLink.ortho': 'Dm:Q9VPM9;Dm:Q9VTI1;Dr:Q5RIV5;Mm:Q9D8B1;Rn:B2RZC0',
#    'Target.nonTFLink.ortho': 'Dm:Q9VPN1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10907',
#    'Ensembl.GeneID.Target': 'ENSG00000141759',
#    'Name.Target': 'TXNL4A',
#    'UniprotID.Target': 'P83876',
#    'Target.TFLink.ortho': 'Ce:L8E6I4;Dm:Q8SZ87;Dr:F1QTJ2;Mm:P83877;Rn:D3ZSW5;Sc:Q06819',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8568',
#    'Ensembl.GeneID.Target': 'ENSG00000160214',
#    'Name.Target': 'RRP1',
#    'UniprotID.Target': 'P56182',
#    'Target.TFLink.ortho': 'Ce:Q18674;Mm:P56183;Rn:Q5M9F3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55275',
#    'Ensembl.GeneID.Target': 'ENSG00000141252',
#    'Name.Target': 'VPS53',
#    'UniprotID.Target': 'Q5VIR6',
#    'Target.TFLink.ortho': 'Dm:Q9VQY8;Dr:E7FAG0;Mm:Q8CCB4;Rn:D3ZPE5;Sc:P47061',
#    'Target.nonTFLink.ortho': 'Ce:P34561',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '26074',
#    'Ensembl.GeneID.Target': 'ENSG00000089101',
#    'Name.Target': 'CFAP61',
#    'UniprotID.Target': 'Q8NHU2',
#    'Target.TFLink.ortho': 'Dm:Q9W206',
#    'Target.nonTFLink.ortho': 'Dm:Q7KVK5;Mm:A8Y5L4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '116729',
#    'Ensembl.GeneID.Target': 'ENSG00000182676',
#    'Name.Target': 'PPP1R27',
#    'UniprotID.Target': 'Q86WC6',
#    'Target.TFLink.ortho': 'Mm:Q9D119',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4IKA8;Rn:D3ZXG0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2806',
#    'Ensembl.GeneID.Target': 'ENSG00000125166',
#    'Name.Target': 'GOT2',
#    'UniprotID.Target': 'P00505',
#    'Target.TFLink.ortho': 'Ce:Q17994;Dr:Q7SYK7;Mm:P05202;Rn:P00507',
#    'Target.nonTFLink.ortho': 'Dm:Q9VQ61;Dr:F1QCD4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1843',
#    'Ensembl.GeneID.Target': 'ENSG00000120129',
#    'Name.Target': 'DUSP1',
#    'UniprotID.Target': 'P28562',
#    'Target.TFLink.ortho': 'Dr:A0A0R4IS50;Mm:P28563;Rn:Q64623',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5514',
#    'Ensembl.GeneID.Target': 'ENSG00000204569',
#    'Name.Target': 'PPP1R10',
#    'UniprotID.Target': 'Q96QC0',
#    'Target.TFLink.ortho': 'Ce:Q8MQ25;Dr:A3KPX4;Mm:Q80W00;Rn:A0A0G2K3G9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3315',
#    'Ensembl.GeneID.Target': 'ENSG00000106211',
#    'Name.Target': 'HSPB1',
#    'UniprotID.Target': 'P04792',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '100131755',
#    'Ensembl.GeneID.Target': 'ENSG00000196440',
#    'Name.Target': 'ARMCX4',
#    'UniprotID.Target': 'Q5H9R4',
#    'Target.TFLink.ortho': 'Mm:E9PWM3;Rn:D3ZV39',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '376267',
#    'Ensembl.GeneID.Target': 'ENSG00000139998',
#    'Name.Target': 'RAB15',
#    'UniprotID.Target': 'P59190',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '80144',
#    'Ensembl.GeneID.Target': 'ENSG00000138759',
#    'Name.Target': 'FRAS1',
#    'UniprotID.Target': 'Q86XX4',
#    'Target.TFLink.ortho': 'Mm:Q80T14',
#    'Target.nonTFLink.ortho': 'Dr:F1Q633;Rn:F1M3H3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '286',
#    'Ensembl.GeneID.Target': 'ENSG00000029534',
#    'Name.Target': 'ANK1',
#    'UniprotID.Target': 'P16157',
#    'Target.TFLink.ortho': 'Dm:Q0KIE7',
#    'Target.nonTFLink.ortho': 'Mm:G5E8J2;Rn:D3Z9Z0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '58528',
#    'Ensembl.GeneID.Target': 'ENSG00000025039',
#    'Name.Target': 'RRAGD',
#    'UniprotID.Target': 'Q9NQL2',
#    'Target.TFLink.ortho': 'Mm:B1AWT2;Rn:B2RZ38',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10602',
#    'Ensembl.GeneID.Target': 'ENSG00000163171',
#    'Name.Target': 'CDC42EP3',
#    'UniprotID.Target': 'Q9UKI2',
#    'Target.TFLink.ortho': 'Dr:Q66HU1;Mm:Q9CQC5;Rn:Q0VGK8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23169',
#    'Ensembl.GeneID.Target': 'ENSG00000116704',
#    'Name.Target': 'SLC35D1',
#    'UniprotID.Target': 'Q9NTN3',
#    'Target.TFLink.ortho': 'Dm:Q95YI5;Dr:E9QF41;Dr:F1QZD9;Mm:A2AKQ0;Rn:D3ZVG2',
#    'Target.nonTFLink.ortho': 'Ce:Q18779',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7037',
#    'Ensembl.GeneID.Target': 'ENSG00000072274',
#    'Name.Target': 'TFRC',
#    'UniprotID.Target': 'P02786',
#    'Target.TFLink.ortho': 'Mm:Q62351',
#    'Target.nonTFLink.ortho': 'Dr:Q5MPX4;Rn:Q99376',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2787',
#    'Ensembl.GeneID.Target': 'ENSG00000174021',
#    'Name.Target': 'GNG5',
#    'UniprotID.Target': 'P63218',
#    'Target.TFLink.ortho': 'Dr:Q6TH03;Mm:Q80SZ7;Rn:P63219',
#    'Target.nonTFLink.ortho': 'Mm:A0A3B2WD42',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4502',
#    'Ensembl.GeneID.Target': 'ENSG00000125148',
#    'Name.Target': 'MT2A',
#    'UniprotID.Target': 'P02795',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '65095',
#    'Ensembl.GeneID.Target': 'ENSG00000129347',
#    'Name.Target': 'KRI1',
#    'UniprotID.Target': 'Q8N9T8',
#    'Target.TFLink.ortho': 'Ce:Q20760;Dm:Q9VTU0;Dr:B3DKN1;Mm:F6WIU1;Rn:A0A0G2K4X2;Sc:P42846',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4519',
#    'Ensembl.GeneID.Target': 'ENSG00000198727',
#    'Name.Target': 'MT-CYB',
#    'UniprotID.Target': 'P00156',
#    'Target.TFLink.ortho': 'Dr:Q9MIX8;Mm:P00158;Rn:P00159;Sc:P00163',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2232',
#    'Ensembl.GeneID.Target': 'ENSG00000161513',
#    'Name.Target': 'FDXR',
#    'UniprotID.Target': 'P22570',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2746',
#    'Ensembl.GeneID.Target': 'ENSG00000148672',
#    'Name.Target': 'GLUD1',
#    'UniprotID.Target': 'P00367',
#    'Target.TFLink.ortho': 'Mm:P26443;Rn:P10860',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1052',
#    'Ensembl.GeneID.Target': 'ENSG00000221869',
#    'Name.Target': 'CEBPD',
#    'UniprotID.Target': 'P49716',
#    'Target.TFLink.ortho': 'Dr:Q6P612;Mm:Q00322;Rn:Q03484',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '81669',
#    'Ensembl.GeneID.Target': 'ENSG00000221978',
#    'Name.Target': 'CCNL2',
#    'UniprotID.Target': 'Q96S94',
#    'Target.TFLink.ortho': 'Ce:P34424;Mm:Q9JJA7',
#    'Target.nonTFLink.ortho': 'Rn:A0A0H2UHQ5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23530',
#    'Ensembl.GeneID.Target': 'ENSG00000112992',
#    'Name.Target': 'NNT',
#    'UniprotID.Target': 'Q13423',
#    'Target.TFLink.ortho': 'Ce:Q18031;Mm:Q8BGK0;Rn:Q5BJZ3',
#    'Target.nonTFLink.ortho': 'Dr:Q6NYQ7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6424',
#    'Ensembl.GeneID.Target': 'ENSG00000106483',
#    'Name.Target': 'SFRP4',
#    'UniprotID.Target': 'Q6FHJ7',
#    'Target.TFLink.ortho': 'Mm:Q9Z1N6;Rn:G3V8G7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1152',
#    'Ensembl.GeneID.Target': 'ENSG00000166165',
#    'Name.Target': 'CKB',
#    'UniprotID.Target': 'P12277',
#    'Target.TFLink.ortho': 'Dr:Q08BV6;Mm:Q04447',
#    'Target.nonTFLink.ortho': 'Dr:Q8AY63;Rn:P07335',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '11059',
#    'Ensembl.GeneID.Target': 'ENSG00000123124',
#    'Name.Target': 'WWP1',
#    'UniprotID.Target': 'Q9H0M0',
#    'Target.TFLink.ortho': 'Ce:Q9N2Z7;Mm:Q8BZZ3',
#    'Target.nonTFLink.ortho': 'Dr:X1WEK3;Rn:Q4V8H7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '133686',
#    'Ensembl.GeneID.Target': 'ENSG00000152620',
#    'Name.Target': 'NADK2',
#    'UniprotID.Target': 'Q4G0N4',
#    'Target.TFLink.ortho': 'Ce:Q9XXI5;Dm:A0A0B4KEG0;Dr:A0A0R4IKV3;Mm:Q8C5H8',
#    'Target.nonTFLink.ortho': 'Rn:A0A096MKG5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10777',
#    'Ensembl.GeneID.Target': 'ENSG00000172995',
#    'Name.Target': 'ARPP21',
#    'UniprotID.Target': 'Q9UBL0',
#    'Target.TFLink.ortho': 'Mm:Q9DCB4',
#    'Target.nonTFLink.ortho': 'Rn:A0A0G2JVX9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55508',
#    'Ensembl.GeneID.Target': 'ENSG00000175782',
#    'Name.Target': 'SLC35E3',
#    'UniprotID.Target': 'Q7Z769',
#    'Target.TFLink.ortho': 'Dr:Q5VSE1;Mm:Q6PGC7;Rn:B2GUZ8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '25854',
#    'Ensembl.GeneID.Target': 'ENSG00000109794',
#    'Name.Target': 'FAM149A',
#    'UniprotID.Target': 'A5PLN7',
#    'Target.TFLink.ortho': 'Dr:E9QBP7;Mm:Q8CFV2;Rn:F1LUX5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10424',
#    'Ensembl.GeneID.Target': 'ENSG00000164040',
#    'Name.Target': 'PGRMC2',
#    'UniprotID.Target': 'O15173',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '344838',
#    'Ensembl.GeneID.Target': 'ENSG00000188582',
#    'Name.Target': 'PAQR9',
#    'UniprotID.Target': 'Q6ZVX9',
#    'Target.TFLink.ortho': 'Mm:Q6TCG2;Rn:F1LWK5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79591',
#    'Ensembl.GeneID.Target': 'ENSG00000120029',
#    'Name.Target': 'ARMH3',
#    'UniprotID.Target': 'Q5T2E6',
#    'Target.TFLink.ortho': 'Dm:Q7KSU3;Mm:Q6PD19;Rn:D3ZZE3',
#    'Target.nonTFLink.ortho': 'Dr:Q6PGW3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9104',
#    'Ensembl.GeneID.Target': 'ENSG00000130988',
#    'Name.Target': 'RGN',
#    'UniprotID.Target': 'Q15493',
#    'Target.TFLink.ortho': 'Dr:Q6TLF6;Mm:Q64374;Rn:Q03336',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9050',
#    'Ensembl.GeneID.Target': 'ENSG00000152229',
#    'Name.Target': 'PSTPIP2',
#    'UniprotID.Target': 'Q9H939',
#    'Target.TFLink.ortho': 'Mm:Q99M15;Rn:D3ZA66',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4837',
#    'Ensembl.GeneID.Target': 'ENSG00000166741',
#    'Name.Target': 'NNMT',
#    'UniprotID.Target': 'P40261',
#    'Target.TFLink.ortho': 'Mm:O55239;Rn:D4A605',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '705',
#    'Ensembl.GeneID.Target': 'ENSG00000112578',
#    'Name.Target': 'BYSL',
#    'UniprotID.Target': 'Q13895',
#    'Target.TFLink.ortho': 'Ce:Q20932;Dm:P51406;Dr:F1R7L3;Mm:O54825;Rn:M0RDF7;Sc:P38333',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '56479',
#    'Ensembl.GeneID.Target': 'ENSG00000185760',
#    'Name.Target': 'KCNQ5',
#    'UniprotID.Target': 'Q9NR82',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23410',
#    'Ensembl.GeneID.Target': 'ENSG00000142082',
#    'Name.Target': 'SIRT3',
#    'UniprotID.Target': 'Q9NTG7',
#    'Target.TFLink.ortho': 'Mm:Q8R104;Rn:C6ZII9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10058',
#    'Ensembl.GeneID.Target': 'ENSG00000115657',
#    'Name.Target': 'ABCB6',
#    'UniprotID.Target': 'Q9NP58',
#    'Target.TFLink.ortho': 'Dm:Q9VF20;Dr:F1QCK2;Mm:Q9DC29;Rn:O70595',
#    'Target.nonTFLink.ortho': 'Ce:G5EFD4;Dr:B0S6D9',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8801',
#    'Ensembl.GeneID.Target': 'ENSG00000172340',
#    'Name.Target': 'SUCLG2',
#    'UniprotID.Target': 'Q96I99',
#    'Target.TFLink.ortho': 'Ce:P53589;Dm:Q9V470;Dr:F1R7X5;Mm:Q9Z2I8;Rn:F1LPV8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55526',
#    'Ensembl.GeneID.Target': 'ENSG00000181192',
#    'Name.Target': 'DHTKD1',
#    'UniprotID.Target': 'Q96HY7',
#    'Target.TFLink.ortho': 'Ce:Q23629;Dm:Q9VA02;Dr:F1R838;Mm:A2ATU0;Rn:Q4KLP0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '28971',
#    'Ensembl.GeneID.Target': 'ENSG00000087884',
#    'Name.Target': 'AAMDC',
#    'UniprotID.Target': 'Q9H7C9',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7357',
#    'Ensembl.GeneID.Target': 'ENSG00000148154',
#    'Name.Target': 'UGCG',
#    'UniprotID.Target': 'Q16739',
#    'Target.TFLink.ortho': 'Ce:Q21054;Ce:O18037;Ce:G5EC84;Dm:Q9W297;Dr:F1QNT4;Mm:O88693;Rn:Q9R0E0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1026',
#    'Ensembl.GeneID.Target': 'ENSG00000124762',
#    'Name.Target': 'CDKN1A',
#    'UniprotID.Target': 'P38936',
#    'Target.TFLink.ortho': 'Mm:P39689;Rn:Q64315',
#    'Target.nonTFLink.ortho': 'Dr:A5WWG3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64756',
#    'Ensembl.GeneID.Target': 'ENSG00000123472',
#    'Name.Target': 'ATPAF1',
#    'UniprotID.Target': 'Q5TC12',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '440498',
#    'Ensembl.GeneID.Target': 'ENSG00000226742',
#    'Name.Target': 'HSBP1L1',
#    'UniprotID.Target': 'C9JCN9',
#    'Target.TFLink.ortho': 'Mm:B2RXB2',
#    'Target.nonTFLink.ortho': 'Rn:D4A9E1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '506',
#    'Ensembl.GeneID.Target': 'ENSG00000110955',
#    'Name.Target': 'ATP5F1B',
#    'UniprotID.Target': 'P06576',
#    'Target.TFLink.ortho': 'Ce:P46561;Dm:Q05825;Mm:P56480;Rn:G3V6D3;Sc:P00830',
#    'Target.nonTFLink.ortho': 'Dr:A8WGC6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8050',
#    'Ensembl.GeneID.Target': 'ENSG00000110435',
#    'Name.Target': 'PDHX',
#    'UniprotID.Target': 'O00330',
#    'Target.TFLink.ortho': 'Mm:Q8BKZ9',
#    'Target.nonTFLink.ortho': 'Dr:Q6NW45;Rn:A0A0G2JZH8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '150465',
#    'Ensembl.GeneID.Target': 'ENSG00000114999',
#    'Name.Target': 'TTL',
#    'UniprotID.Target': 'Q8NG68',
#    'Target.TFLink.ortho': 'Mm:P38585;Rn:G3V8C8',
#    'Target.nonTFLink.ortho': 'Dr:F1R9V1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '211',
#    'Ensembl.GeneID.Target': 'ENSG00000023330',
#    'Name.Target': 'ALAS1',
#    'UniprotID.Target': 'P13196',
#    'Target.TFLink.ortho': 'Dr:F1RB22;Mm:Q8VC19;Rn:A0A0G2K962',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55802',
#    'Ensembl.GeneID.Target': 'ENSG00000272886',
#    'Name.Target': 'DCP1A',
#    'UniprotID.Target': 'Q9NPI6',
#    'Target.TFLink.ortho': 'Mm:Q91YD3;Rn:D4AE80',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4IBD6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '84159',
#    'Ensembl.GeneID.Target': 'ENSG00000150347',
#    'Name.Target': 'ARID5B',
#    'UniprotID.Target': 'Q14865',
#    'Target.TFLink.ortho': 'Dr:E7F888;Mm:Q8BM75',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4538',
#    'Ensembl.GeneID.Target': 'ENSG00000198886',
#    'Name.Target': 'MT-ND4',
#    'UniprotID.Target': 'P03905',
#    'Target.TFLink.ortho': 'Mm:P03911',
#    'Target.nonTFLink.ortho': 'Dr:Q9MIY1;Rn:P05508',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51673',
#    'Ensembl.GeneID.Target': 'ENSG00000159713',
#    'Name.Target': 'TPPP3',
#    'UniprotID.Target': 'Q9BW30',
#    'Target.TFLink.ortho': 'Dr:E7FG48;Mm:Q9CRB6;Rn:Q5PPN5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '84448',
#    'Ensembl.GeneID.Target': 'ENSG00000163995',
#    'Name.Target': 'ABLIM2',
#    'UniprotID.Target': 'Q6H8Q1',
#    'Target.TFLink.ortho': 'Dr:U3JA30;Rn:A0A0G2JXC7',
#    'Target.nonTFLink.ortho': 'Mm:E9Q4K0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '83636',
#    'Ensembl.GeneID.Target': 'ENSG00000131943',
#    'Name.Target': 'C19orf12',
#    'UniprotID.Target': 'Q9NSK7',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6342',
#    'Ensembl.GeneID.Target': 'ENSG00000116171',
#    'Name.Target': 'SCP2',
#    'UniprotID.Target': 'P22307',
#    'Target.TFLink.ortho': 'Ce:G5EDP2;Dm:Q9VJ44;Dm:Q9VJ43;Dr:Q6P4V5;Mm:P32020;Rn:F1LQ55',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6048',
#    'Ensembl.GeneID.Target': 'ENSG00000204308',
#    'Name.Target': 'RNF5',
#    'UniprotID.Target': 'Q99942',
#    'Target.TFLink.ortho': 'Mm:O35445;Rn:Q5M807',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79133',
#    'Ensembl.GeneID.Target': 'ENSG00000101247',
#    'Name.Target': 'NDUFAF5',
#    'UniprotID.Target': 'Q5TEU4',
#    'Target.TFLink.ortho': 'Ce:Q9NAP7;Dm:Q7K1S1;Mm:A2APY7;Rn:B2GV71',
#    'Target.nonTFLink.ortho': 'Dr:B8JKQ0',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8507',
#    'Ensembl.GeneID.Target': 'ENSG00000171617',
#    'Name.Target': 'ENC1',
#    'UniprotID.Target': 'O14682',
#    'Target.TFLink.ortho': 'Dr:F1QKP6;Mm:O35709;Rn:Q6DKY8',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23510',
#    'Ensembl.GeneID.Target': 'ENSG00000180901',
#    'Name.Target': 'KCTD2',
#    'UniprotID.Target': 'Q14681',
#    'Target.TFLink.ortho': 'Mm:Q4VBE7;Rn:F1M5Q3',
#    'Target.nonTFLink.ortho': 'Dr:Q0P490',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '373156',
#    'Ensembl.GeneID.Target': 'ENSG00000197448',
#    'Name.Target': 'GSTK1',
#    'UniprotID.Target': 'Q9Y2Q3',
#    'Target.TFLink.ortho': 'Ce:Q09652;Ce:Q18973;Dr:E9QB37;Dr:Q6DGU9;Mm:Q9DCM2;Rn:P24473',
#    'Target.nonTFLink.ortho': 'Dr:E9QF67',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6271',
#    'Ensembl.GeneID.Target': 'ENSG00000160678',
#    'Name.Target': 'S100A1',
#    'UniprotID.Target': 'P23297',
#    'Target.TFLink.ortho': 'Dr:A3KH13;Mm:Q91V77',
#    'Target.nonTFLink.ortho': 'Rn:P35467',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64601',
#    'Ensembl.GeneID.Target': 'ENSG00000215305',
#    'Name.Target': 'VPS16',
#    'UniprotID.Target': 'Q9H269',
#    'Target.TFLink.ortho': 'Ce:Q11182;Dm:Q9VHG1;Dr:A5D6T0;Mm:G3X8X7;Rn:Q642A9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '53353',
#    'Ensembl.GeneID.Target': 'ENSG00000168702',
#    'Name.Target': 'LRP1B',
#    'UniprotID.Target': 'Q9NZR2',
#    'Target.TFLink.ortho': 'Mm:A2API5',
#    'Target.nonTFLink.ortho': 'Dr:F1QTG8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5214',
#    'Ensembl.GeneID.Target': 'ENSG00000067057',
#    'Name.Target': 'PFKP',
#    'UniprotID.Target': 'Q01813',
#    'Target.TFLink.ortho': 'Dr:X1WDM7;Mm:Q9WUA3;Rn:A0A0A0MXY5',
#    'Target.nonTFLink.ortho': 'Dr:F1R2A3',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '498',
#    'Ensembl.GeneID.Target': 'ENSG00000152234',
#    'Name.Target': 'ATP5F1A',
#    'UniprotID.Target': 'P25705',
#    'Target.TFLink.ortho': 'Ce:Q9XXK1;Dm:P35381;Mm:Q03265;Sc:P07251',
#    'Target.nonTFLink.ortho': 'Dr:Q08BA1;Rn:A0A0G2K099',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '165918',
#    'Ensembl.GeneID.Target': 'ENSG00000163961',
#    'Name.Target': 'RNF168',
#    'UniprotID.Target': 'Q8IYW5',
#    'Target.TFLink.ortho': 'Rn:A0A140TA93',
#    'Target.nonTFLink.ortho': 'Mm:E9PYW4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5465',
#    'Ensembl.GeneID.Target': 'ENSG00000186951',
#    'Name.Target': 'PPARA',
#    'UniprotID.Target': 'Q07869',
#    'Target.TFLink.ortho': 'Dr:K7DY57;Mm:P23204;Rn:P37230',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8803',
#    'Ensembl.GeneID.Target': 'ENSG00000136143',
#    'Name.Target': 'SUCLA2',
#    'UniprotID.Target': 'Q9P2R7',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '84284',
#    'Ensembl.GeneID.Target': 'ENSG00000135778',
#    'Name.Target': 'NTPCR',
#    'UniprotID.Target': 'Q9BSD7',
#    'Target.TFLink.ortho': 'Dm:Q9VP84;Mm:Q9CQA9;Rn:D4A478',
#    'Target.nonTFLink.ortho': 'Dr:B8K0C4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6390',
#    'Ensembl.GeneID.Target': 'ENSG00000117118',
#    'Name.Target': 'SDHB',
#    'UniprotID.Target': 'P21912',
#    'Target.TFLink.ortho': 'Ce:Q09545;Dm:P21914;Dr:A5PL98;Mm:Q9CQA3;Rn:P21913;Sc:P21801',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '57462',
#    'Ensembl.GeneID.Target': 'ENSG00000164976',
#    'Name.Target': 'MYORG',
#    'UniprotID.Target': 'Q6NSJ0',
#    'Target.TFLink.ortho': 'Dr:E7F1U0;Mm:Q69ZQ1;Rn:D4AE63',
#    'Target.nonTFLink.ortho': 'Dm:Q9VBR6;Dr:A0A0R4IJD4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '55328',
#    'Ensembl.GeneID.Target': 'ENSG00000184719',
#    'Name.Target': 'RNLS',
#    'UniprotID.Target': 'Q5VYX0',
#    'Target.TFLink.ortho': 'Dr:A8DZ59;Rn:Q5U2W9',
#    'Target.nonTFLink.ortho': 'Mm:E9Q243',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '79869',
#    'Ensembl.GeneID.Target': 'ENSG00000149532',
#    'Name.Target': 'CPSF7',
#    'UniprotID.Target': 'Q8N684',
#    'Target.TFLink.ortho': 'Mm:Q8BTV2;Rn:Q5XI29',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
# ...
#   {'NCBI.GeneID.Target': '7832',
#    'Ensembl.GeneID.Target': 'ENSG00000159388',
#    'Name.Target': 'BTG2',
#    'UniprotID.Target': 'P78543',
#    'Target.TFLink.ortho': 'Dr:Q9IB77;Mm:Q04211;Rn:P27049',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4792',
#    'Ensembl.GeneID.Target': 'ENSG00000100906',
#    'Name.Target': 'NFKBIA',
#    'UniprotID.Target': 'P25963',
#    'Target.TFLink.ortho': 'Dr:Q7ZW68;Dr:F1QCG4;Mm:Q9Z1E3;Rn:Q63746',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5095',
#    'Ensembl.GeneID.Target': 'ENSG00000175198',
#    'Name.Target': 'PCCA',
#    'UniprotID.Target': 'P05165',
#    'Target.TFLink.ortho': 'Ce:Q19842;Dr:F1QPL7;Mm:Q91ZA3;Rn:A0A0G2K5P9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '9453',
#    'Ensembl.GeneID.Target': 'ENSG00000152904',
#    'Name.Target': 'GGPS1',
#    'UniprotID.Target': 'O95749',
#    'Target.TFLink.ortho': 'Dm:Q9VS54;Mm:Q9WTN0;Rn:Q6F596;Sc:Q12051',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '150274',
#    'Ensembl.GeneID.Target': 'ENSG00000100209',
#    'Name.Target': 'HSCB',
#    'UniprotID.Target': 'Q8IWL3',
#    'Target.TFLink.ortho': 'Ce:Q21324;Dm:A8JNT7;Mm:A0A0R4J0T0;Rn:D3ZME7;Sc:P53193',
#    'Target.nonTFLink.ortho': 'Dr:B0V1J6',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2653',
#    'Ensembl.GeneID.Target': 'ENSG00000140905',
#    'Name.Target': 'GCSH',
#    'UniprotID.Target': 'P23434',
#    'Target.TFLink.ortho': 'Ce:Q20634;Ce:O62122;Dm:Q9U616;Dr:Q6DGX4;Mm:Q91WK5;Sc:P39726',
#    'Target.nonTFLink.ortho': 'Dr:F1QRR5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '51619',
#    'Ensembl.GeneID.Target': 'ENSG00000078967',
#    'Name.Target': 'UBE2D4',
#    'UniprotID.Target': 'Q9Y2X8',
#    'Target.TFLink.ortho': 'Dr:A4QNX5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '123624',
#    'Ensembl.GeneID.Target': 'ENSG00000273540',
#    'Name.Target': 'AGBL1',
#    'UniprotID.Target': 'Q96MI9',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': 'Mm:D3Z1M2;Rn:A0A0G2JV75',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2954',
#    'Ensembl.GeneID.Target': 'ENSG00000100577',
#    'Name.Target': 'GSTZ1',
#    'UniprotID.Target': 'O43708',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '171425',
#    'Ensembl.GeneID.Target': 'ENSG00000125246',
#    'Name.Target': 'CLYBL',
#    'UniprotID.Target': 'Q8N0X4',
#    'Target.TFLink.ortho': 'Ce:Q93167;Dr:Q1JPT8;Mm:Q8R4N0;Rn:Q5I0K3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '4839',
#    'Ensembl.GeneID.Target': 'ENSG00000111641',
#    'Name.Target': 'NOP2',
#    'UniprotID.Target': 'P46087',
#    'Target.TFLink.ortho': 'Dr:F1QWP7;Mm:E9QN31;Rn:D4ACW1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64682',
#    'Ensembl.GeneID.Target': 'ENSG00000153107',
#    'Name.Target': 'ANAPC1',
#    'UniprotID.Target': 'Q9H1A4',
#    'Target.TFLink.ortho': 'Dm:Q9VXV3;Dr:A0A2R8QA59;Mm:P53995;Rn:F1M801',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8637',
#    'Ensembl.GeneID.Target': 'ENSG00000243056',
#    'Name.Target': 'EIF4EBP3',
#    'UniprotID.Target': 'O60516',
#    'Target.TFLink.ortho': 'Dr:Q98TT6;Mm:Q80VV3',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '285440',
#    'Ensembl.GeneID.Target': 'ENSG00000145476',
#    'Name.Target': 'CYP4V2',
#    'UniprotID.Target': 'Q6ZWL3',
#    'Target.TFLink.ortho': 'Ce:G5EGT6;Dm:Q9VA27;Dr:A0JMQ6;Mm:Q9DBW0;Rn:A2RRT9',
#    'Target.nonTFLink.ortho': 'Dr:A0JMN1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '36',
#    'Ensembl.GeneID.Target': 'ENSG00000196177',
#    'Name.Target': 'ACADSB',
#    'UniprotID.Target': 'P45954',
#    'Target.TFLink.ortho': 'Ce:O44549;Ce:H2KZG6;Dm:Q9VVU1;Dr:F1QFQ7;Mm:Q9DBL1;Rn:A0A0A0MY00',
#    'Target.nonTFLink.ortho': 'Ce:A0A0K3AQR2',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '7112',
#    'Ensembl.GeneID.Target': 'ENSG00000120802',
#    'Name.Target': 'TMPO',
#    'UniprotID.Target': 'P42166',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '287',
#    'Ensembl.GeneID.Target': 'ENSG00000145362',
#    'Name.Target': 'ANK2',
#    'UniprotID.Target': 'Q01484',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '11112',
#    'Ensembl.GeneID.Target': 'ENSG00000106049',
#    'Name.Target': 'HIBADH',
#    'UniprotID.Target': 'P31937',
#    'Target.TFLink.ortho': 'Ce:Q9XTI0;Dm:Q9V8M5;Dr:F1QE62;Dr:A0A0R4IA23;Mm:Q99L13;Rn:P29266',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '206358',
#    'Ensembl.GeneID.Target': 'ENSG00000123643',
#    'Name.Target': 'SLC36A1',
#    'UniprotID.Target': 'Q7Z2H8',
#    'Target.TFLink.ortho': 'Mm:Q8K4D3;Rn:Q924A5;Sc:P36062',
#    'Target.nonTFLink.ortho': 'Dr:E7F5P8',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '518',
#    'Ensembl.GeneID.Target': 'ENSG00000154518',
#    'Name.Target': 'ATP5MC3',
#    'UniprotID.Target': 'P48201',
#    'Target.TFLink.ortho': 'Dr:Q7ZYW7;Mm:Q9CR84;Mm:P56384;Rn:Q499S2',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '22985',
#    'Ensembl.GeneID.Target': 'ENSG00000100813',
#    'Name.Target': 'ACIN1',
#    'UniprotID.Target': 'Q9UKV3',
#    'Target.TFLink.ortho': 'Dr:F1Q511;Mm:Q9JIX8;Rn:E9PST5',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '3625',
#    'Ensembl.GeneID.Target': 'ENSG00000163083',
#    'Name.Target': 'INHBB',
#    'UniprotID.Target': 'P09529',
#    'Target.TFLink.ortho': 'Mm:Q04999;Rn:A0A0G2K0C6',
#    'Target.nonTFLink.ortho': 'Dr:A0A0G2KD75',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '5191',
#    'Ensembl.GeneID.Target': 'ENSG00000112357',
#    'Name.Target': 'PEX7',
#    'UniprotID.Target': 'O00628',
#    'Target.TFLink.ortho': 'Dm:Q9VSN7;Dr:F1QFW8;Mm:P97865;Rn:Q498S5;Sc:P39108',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2668',
#    'Ensembl.GeneID.Target': 'ENSG00000168621',
#    'Name.Target': 'GDNF',
#    'UniprotID.Target': 'P39905',
#    'Target.TFLink.ortho': '-',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '64061',
#    'Ensembl.GeneID.Target': 'ENSG00000184205',
#    'Name.Target': 'TSPYL2',
#    'UniprotID.Target': 'Q9H2G4',
#    'Target.TFLink.ortho': 'Mm:Q7TQI8;Rn:A0A096MJ32',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2926',
#    'Ensembl.GeneID.Target': 'ENSG00000132463',
#    'Name.Target': 'GRSF1',
#    'UniprotID.Target': 'Q12849',
#    'Target.TFLink.ortho': 'Dr:F8W4V6;Mm:Q8C5Q4',
#    'Target.nonTFLink.ortho': 'Rn:F1LRK4',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '201562',
#    'Ensembl.GeneID.Target': 'ENSG00000206527',
#    'Name.Target': 'HACD2',
#    'UniprotID.Target': 'Q6Y1H2',
#    'Target.TFLink.ortho': 'Ce:O17040;Dr:B0V199;Mm:Q9D3B1;Rn:D3ZHG0',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23632',
#    'Ensembl.GeneID.Target': 'ENSG00000118298',
#    'Name.Target': 'CA14',
#    'UniprotID.Target': 'Q9ULX7',
#    'Target.TFLink.ortho': 'Mm:Q9WVT6;Rn:A2IBE0',
#    'Target.nonTFLink.ortho': 'Dr:F8W4I7',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285',
#    'Source.database': 'ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '1160',
#    'Ensembl.GeneID.Target': 'ENSG00000131730',
#    'Name.Target': 'CKMT2',
#    'UniprotID.Target': 'P17540',
#    'Target.TFLink.ortho': 'Mm:Q6P8J7',
#    'Target.nonTFLink.ortho': 'Dm:Q9VF23;Rn:A0A0G2JVQ1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54948',
#    'Ensembl.GeneID.Target': 'ENSG00000166902',
#    'Name.Target': 'MRPL16',
#    'UniprotID.Target': 'Q9NX20',
#    'Target.TFLink.ortho': 'Ce:Q22140;Dm:Q9W547;Mm:Q99N93;Rn:Q5M818',
#    'Target.nonTFLink.ortho': 'Dr:F1R2K1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '8604',
#    'Ensembl.GeneID.Target': 'ENSG00000115840',
#    'Name.Target': 'SLC25A12',
#    'UniprotID.Target': 'O75746',
#    'Target.TFLink.ortho': 'Mm:Q8BH59;Rn:F1LX07',
#    'Target.nonTFLink.ortho': 'Dr:A0A0R4II73',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '2037',
#    'Ensembl.GeneID.Target': 'ENSG00000079819',
#    'Name.Target': 'EPB41L2',
#    'UniprotID.Target': 'O43491',
#    'Target.TFLink.ortho': 'Mm:O70318',
#    'Target.nonTFLink.ortho': 'Rn:D3ZM69',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '6391',
#    'Ensembl.GeneID.Target': 'ENSG00000143252',
#    'Name.Target': 'SDHC',
#    'UniprotID.Target': 'Q99643',
#    'Target.TFLink.ortho': 'Ce:P41956;Dm:Q9VGS3;Mm:Q9CZB0;Rn:Q641Z9',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '141',
#    'Ensembl.GeneID.Target': 'ENSG00000144843',
#    'Name.Target': 'ADPRH',
#    'UniprotID.Target': 'P54922',
#    'Target.TFLink.ortho': 'Mm:P54923;Rn:Q02589',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '400451',
#    'Ensembl.GeneID.Target': 'ENSG00000185442',
#    'Name.Target': 'FAM174B',
#    'UniprotID.Target': 'Q3ZCQ3',
#    'Target.TFLink.ortho': 'Mm:Q8K064',
#    'Target.nonTFLink.ortho': 'Rn:D4A4W1',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23596',
#    'Ensembl.GeneID.Target': 'ENSG00000203668',
#    'Name.Target': 'OPN3',
#    'UniprotID.Target': 'Q9H1Y3',
#    'Target.TFLink.ortho': 'Dr:A9NJI7;Mm:Q9WUK7;Rn:D3ZFS1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '54715',
#    'Ensembl.GeneID.Target': 'ENSG00000078328',
#    'Name.Target': 'RBFOX1',
#    'UniprotID.Target': 'Q9NWB1',
#    'Target.TFLink.ortho': 'Dr:Q642J5;Mm:Q9JJ43;Rn:D3ZSL1',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '10105',
#    'Ensembl.GeneID.Target': 'ENSG00000108179',
#    'Name.Target': 'PPIF',
#    'UniprotID.Target': 'P30405',
#    'Target.TFLink.ortho': 'Dm:Q7K2I4;Dm:P25007;Mm:Q99KR7;Rn:P29117',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '23408',
#    'Ensembl.GeneID.Target': 'ENSG00000124523',
#    'Name.Target': 'SIRT5',
#    'UniprotID.Target': 'Q9NXA8',
#    'Target.TFLink.ortho': 'Mm:Q8K2C6;Rn:Q68FX9',
#    'Target.nonTFLink.ortho': 'Dr:Q6DHI5',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '29126285;27924024',
#    'Source.database': 'GTRD;ReMap',
#    'Small-scale.evidence': 'No'},
#   {'NCBI.GeneID.Target': '81796',
#    'Ensembl.GeneID.Target': 'ENSG00000137571',
#    'Name.Target': 'SLCO5A1',
#    'UniprotID.Target': 'Q9H2Y9',
#    'Target.TFLink.ortho': 'Dr:E7F2I7;Mm:E9PVD9;Rn:D3ZZM7',
#    'Target.nonTFLink.ortho': '-',
#    'Detection.method': 'chromatin immunoprecipitation assay',
#    'PubmedID': '27924024',
#    'Source.database': 'GTRD',
#    'Small-scale.evidence': 'No'}]}

# %%
combined_df_tf_sig["its_target"][10]

# %%
# Extract all targets for NFYA ('NCBI.GeneID.TF')
ncbi_gene_ids_NFYA_targets = (
    combined_df_tf_sig[combined_df_tf_sig["identifier"] == "ENSG00000001167"]["its_target"]
    .apply(lambda x: [d["NCBI.GeneID.Target"] for d in x] if isinstance(x, list) else [])
    .explode()
    .dropna()
    .unique()
    .tolist()
)

len(ncbi_gene_ids_NFYA_targets)
# Out:
# 0

# %%
# combined_df = combine_sources(
#     merged_df_mice,
#     [
#     ppi_df,
#     ],
# )

# %%
# combined_metadata = create_or_append_to_metadata(
#     bridgedb_metadata_mice,
#     [
#     ppi_metadata,
#     get_data_versions("hsapiens")
#     ],
# )

# %%
# combined_metadata
# Out:
# [{'datasource': 'StringDB',
#   'metadata': {'source_version': {'source_version': '12.0'}},
#   'query': {'size': 222,
#    'input_type': 'HGNC',
#    'number_of_added_edges': 532,
#    'time': '0:00:00.651298',
#    'date': '2024-12-18 14:43:18',
#    'url': 'https://string-db.org/api'}},
#  {'biomart': 'Ensembl',
#   'biomart_version': '111',
#   'display_name': 'Human',
#   'genebuild': 'GRCh38.p14',
#   'gprofiler_version': 'e111_eg58_p18_f463989d',
#   'organism': 'hsapiens',
#   'sources': {'CORUM': {'name': 'CORUM protein complexes',
#     'version': '28.11.2022 Corum 4.1'},
#    'GO:BP': {'name': 'biological process',
#     'version': 'annotations: BioMart\nclasses: releases/2024-01-17'},
#    'GO:CC': {'name': 'cellular component',
#     'version': 'annotations: BioMart\nclasses: releases/2024-01-17'},
#    'GO:MF': {'name': 'molecular function',
#     'version': 'annotations: BioMart\nclasses: releases/2024-01-17'},
#    'HP': {'name': 'Human Phenotype Ontology',
#     'version': 'annotations: 01.2024\nclasses: None'},
#    'HPA': {'name': 'Human Protein Atlas',
#     'version': 'annotations: HPA website: 23-07-17\nclasses: script: 24-01-02'},
#    'KEGG': {'name': 'Kyoto Encyclopedia of Genes and Genomes',
#     'version': 'KEGG FTP Release 2024-01-22'},
#    'MIRNA': {'name': 'miRTarBase', 'version': 'Release 9.0'},
#    'REAC': {'name': 'Reactome',
#     'version': 'annotations: BioMart\nclasses: 2024-1-25'},
#    'TF': {'name': 'Transfac',
#     'version': 'annotations: TRANSFAC Release 2023.2\nclasses: v2'},
#    'WP': {'name': 'WikiPathways', 'version': '20240101'}},
#   'taxonomy_id': '9606'},
#  {'datasource': 'BridgeDb',
#   'metadata': {'source_version': {'java.version': '11.0.16',
#     'bridgedb.version': '3.0.25',
#     'webservice.version': '2.1.7'},
#    'data_version': ['DATASOURCENAME: Ensembl',
#     'BUILDDATE: 20230311',
#     'SERIES: Homo sapiens genes and proteins',
#     'DATATYPE: GeneProduct',
#     'DATASOURCEVERSION: 108',
#     'SCHEMAVERSION: 3',
#     'DATASOURCENAME: Wikidata',
#     'BUILDDATE: 20211127',
#     'SERIES: humancorona',
#     'DATATYPE: GeneProduct',
#     'DATASOURCEVERSION: 1.0.0',
#     'SCHEMAVERSION: 3',
#     'DATASOURCENAME: Wikidata',
#     'BUILDDATE: 20230209',
#     'SERIES: Complexes',
#     'DATATYPE: Complexes',
#     'DATASOURCEVERSION: 1.0.0',
#     'SCHEMAVERSION: 3',
#     'DATASOURCENAME: Wikidata',
#     'BUILDDATE: 20230506',
#     'SERIES: Homo sapiens genes and proteins',
#     'DATATYPE: GeneProduct',
#     'DATASOURCEVERSION: 1.0.0',
#     'SCHEMAVERSION: 3',
#     'DATASOURCENAME: EBI-RHEA',
#     'BUILDDATE: 20210109',
#     'SERIES: standard-interaction',
#     'DATATYPE: Interaction',
#     'DATASOURCEVERSION: 115',
#     'SCHEMAVERSION: 3',
#     'DATASOURCENAME: HMDB-CHEBI-WIKIDATA',
#     'BUILDDATE: 20220707',
#     'DATATYPE: Metabolite',
#     'SERIES: standard_metabolite',
#     'DATASOURCEVERSION: HMDB5.0.20211102-CHEBI211-WIKIDATA20220707',
#     'SCHEMAVERSION: 3',
#     'DATASOURCENAME: Wikidata',
#     'BUILDDATE: 20211211',
#     'SERIES: pathways',
#     'DATATYPE: Pathways',
#     'DATASOURCEVERSION: 1.0.0',
#     'BRIDGEDBVERSION: 3.0.10',
#     'SCHEMAVERSION: 3',
#     'DATASOURCENAME: Wikidata',
#     'BUILDDATE: 20230428',
#     'SERIES: publications',
#     'DATATYPE: Article',
#     'DATASOURCEVERSION: 1.0.0',
#     'BRIDGEDBVERSION: 3.0.22-SNAPSHOT',
#     'SCHEMAVERSION: 3']},
#   'query': {'size': 12322,
#    'input_type': 'Ensembl',
#    'time': '0:00:05.538243',
#    'date': '2024-12-18 14:39:58',
#    'url': 'https://webservice.bridgedb.org/Human/xrefsBatch',
\tEn\nENSG00000007384\tEn\nENSG00000007392\tEn\nENSG00000007402\tEn\nENSG00000007516\tEn\nENSG00000007520\tEn\nENSG00000007541\tEn\nENSG00000007545\tEn\nENSG00000007866\tEn\nENSG00000007923\tEn\nENSG00000007933\tEn\nENSG00000007944\tEn\nENSG00000008018\tEn\nENSG00000008083\tEn\nENSG00000008086\tEn\nENSG00000008128\tEn\nENSG00000008130\tEn\nENSG00000008256\tEn\nENSG00000008277\tEn\nENSG00000008282\tEn\nENSG00000008283\tEn\nENSG00000008294\tEn\nENSG00000008311\tEn\nENSG00000008324\tEn\nENSG00000008382\tEn\nENSG00000008405\tEn\nENSG00000008441\tEn\nENSG00000008513\tEn\nENSG00000008516\tEn\nENSG00000008517\tEn\nENSG00000008710\tEn\nENSG00000008838\tEn\nENSG00000008853\tEn\nENSG00000008869\tEn\nENSG00000008952\tEn\nENSG00000008988\tEn\nENSG00000009307\tEn\nENSG00000009335\tEn\nENSG00000009413\tEn\nENSG00000009709\tEn\nENSG00000009724\tEn\nENSG00000009780\tEn\nENSG00000009830\tEn\nENSG00000009844\tEn\nENSG00000009950\tEn\nENSG00000009954\tEn\nENSG00000010017\tEn\nENSG00000010072\tEn\nENSG00000010165\tEn\nENSG00000010219\tEn\nENSG00000010244\tEn\nENSG00000010256\tEn\nENSG00000010270\tEn\nENSG00000010278\tEn\nENSG00000010282\tEn\nENSG00000010292\tEn\nENSG00000010295\tEn\nENSG00000010318\tEn\nENSG00000 ...

# %%
combined_df[combined_df["identifier"] == "CDKN1A"]["StringDB_ppi"].to_dict()
# Out:
# {}

# %%
combined_df_tf_sig[combined_df_tf_sig["GENE_SYMBOL_dea"].str.contains("OTF6", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [identifier, identifier.source, target, target.source, GENE_SYMBOL_dea, baseMean_dea, log2FoldChange_dea, lfcSE_dea, stat_dea, pvalue_dea, padj_dea, minus_log10_pvalue_dea, is_tf, is_target, its_target, its_tf, intersections, g:Profiler_corum, g:Profiler_go:bp, g:Profiler_go:cc, g:Profiler_go:mf, g:Profiler_hp, g:Profiler_kegg, g:Profiler_mirna, g:Profiler_reac, g:Profiler_tf, g:Profiler_wp, MitoCarta, StringDB_ppi]
# Index: []
#
# [0 rows x 29 columns]

# %%
combined_df[combined_df["GENE_SYMBOL_dea"] == "MT-ND4"]
# Out:
# Empty DataFrame
# Columns: [identifier, identifier.source, target, target.source, GENE_SYMBOL_dea, baseMean_dea, log2FoldChange_dea, lfcSE_dea, stat_dea, pvalue_dea, padj_dea, minus_log10_pvalue_dea, is_tf, is_target, its_target, its_tf, intersections, g:Profiler_corum, g:Profiler_go:bp, g:Profiler_go:cc, g:Profiler_go:mf, g:Profiler_hp, g:Profiler_kegg, g:Profiler_mirna, g:Profiler_reac, g:Profiler_tf, g:Profiler_wp, MitoCarta, StringDB_ppi]
# Index: []
#
# [0 rows x 29 columns]

# %%
combined_df[combined_df["identifier"] == "ENSG00000198886"]["StringDB_ppi"].to_dict()
# Out:
# {10722: [{'stringdb_link_to': 'ENSG00000010256',
#    'Ensembl': 'ENSP00000203407',
#    'score': 0.971,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000108179',
#    'Ensembl': 'ENSP00000225174',
#    'score': 0.404,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000110955',
#    'Ensembl': 'ENSP00000262030',
#    'score': 0.553,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000154518',
#    'Ensembl': 'ENSP00000284727',
#    'score': 0.513,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000005700',
#    'Ensembl': 'ENSP00000305721',
#    'score': 0.457,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000198804',
#    'Ensembl': 'ENSP00000354499',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000198727',
#    'Ensembl': 'ENSP00000354554',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000198899',
#    'Ensembl': 'ENSP00000354632',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000198888',
#    'Ensembl': 'ENSP00000354687',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000198712',
#    'Ensembl': 'ENSP00000354876',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000101247',
#    'Ensembl': 'Ensembl:ENSP00000367346',
#    'score': 0.587,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000152234',
#    'Ensembl': 'Ensembl:ENSP00000381736',
#    'score': 0.654,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000143252',
#    'Ensembl': 'Ensembl:ENSP00000356953',
#    'score': 0.696,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000117118',
#    'Ensembl': 'Ensembl:ENSP00000364649',
#    'score': 0.958,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000023228',
#    'Ensembl': 'Ensembl:ENSP00000392709',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'MT-ND4'},
#   {'stringdb_link_to': 'ENSG00000198763',
#    'Ensembl': 'Ensembl:ENSP00000355046',
#    'score': 0.999,
#    'Uniprot-TrEMBL': 'MT-ND4'}]}

# %%
combined_df[combined_df["identifier"] == "ENSG00000005700"]["StringDB_ppi"].to_dict()
# Out:
# {81: [{'stringdb_link_to': 'ENSG00000198886',
#    'Ensembl': 'Ensembl:ENSP00000354961',
#    'score': 0.457,
#    'Uniprot-TrEMBL': 'IBTK'}]}

# %%
combined_df[combined_df["identifier"] == "ENSG00000108387"]
# Out:
#            identifier identifier.source target target.source  \
# 2558  ENSG00000108387           Ensembl   5414  ncbi_gene_id
#
#           GENE_SYMBOL_dea  baseMean_dea  log2FoldChange_dea  lfcSE_dea  \
# 2558  2004-09-01 00:00:00    193.471021            0.073477    0.13493
#
#       stat_dea  pvalue_dea  ...  g:Profiler_go:mf  g:Profiler_hp  \
# 2558  0.544556    0.586059  ...               NaN            NaN
#
#      g:Profiler_hpa g:Profiler_kegg g:Profiler_mirna g:Profiler_reac  \
# 2558            NaN             NaN              NaN             NaN
#
#      g:Profiler_tf g:Profiler_wp  \
# 2558           NaN           NaN
#
#                                               MitoCarta StringDB_ppi
# 2558  [{'gene_description': 'septin 4', 'evidence': ...          NaN
#
# [1 rows x 30 columns]

# %%
pygraph = generator.save_graph(
    combined_df=combined_df_tf_sig,
    combined_metadata=bridgedb_metadata_mice,
    graph_name="graph_mice",
    graph_dir="./data/mice",
)
# Out:
# Combined DataFrame saved in ./data/mice/graph_mice/graph_mice_df.pkl
# Metadata saved in ./data/mice/graph_mice/graph_mice_metadata.pkl
# Building graph: 100%|██████████| 1285/1285 [00:04<00:00, 303.40it/s]
# Graph is built successfully
# Graph saved in ./data/mice/graph_mice/graph_mice_graph.pkl and ./data/mice/graph_mice/graph_mice_graph.gml

# %%
print(pygraph)
# Out:
# MultiDiGraph with 17327 nodes and 275684 edges

# %%
from pyBiodatafuse.graph import neo4j

neo4j.save_graph_to_graphml(pygraph, "data/mice/graph_mice/networkx_graph_mice.graphml")
