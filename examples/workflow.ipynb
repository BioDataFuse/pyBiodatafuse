# %% [markdown]
# # Workflow playground for the project

# %%
# Import modules
import os

import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import disgenet, molmedb, opentargets, wikipathways
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# ## Load the input list and convert it to a dataframe

# %%
genes_of_interest = """AGRN
ALG14
ALG2
CHAT
CHD8
CHRNA1
CHRNB1
CHRND
CHRNE
CHRNG
COL13A1
COLQ
DOK7
SLC22A5"""
gene_list = genes_of_interest.split("\n")
len(gene_list)
# Out:
# 14

# %%
data_input = pd.DataFrame(gene_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0       AGRN
# 1      ALG14
# 2       ALG2
# 3       CHAT
# 4       CHD8

# %% [markdown]
# ## Entity resolution using BridgeDB

# %%
bridgdb_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input["identifier"],
    input_species="Human",
    input_datasource="HGNC",
    output_datasource="All",
)
bridgdb_df.head()
# Out:
#   identifier identifier.source      target  target.source
# 0       AGRN              HGNC  GO:0046872  Gene Ontology
# 1       AGRN              HGNC     4053565           Affy
# 2       AGRN              HGNC     4053601           Affy
# 3       AGRN              HGNC     4053600           Affy
# 4       AGRN              HGNC     4053602           Affy

# %% [markdown]
# ## Disease annotating using DisGeNet

# %%
api_key = "0209751bfa7b6a981a8f5fb5f062313067ecd36c"  # TODO: add your key
params = {"source": "CURATED", "format": "json"}  # only curated data
disgenet_result, disgenet_metadata = disgenet.get_gene_disease(
    bridgedb_df=bridgdb_df, api_key=api_key, params=params
)
disgenet_result.head()
# Out:
#   identifier identifier.source  target target.source  \
# 0       AGRN              HGNC  375790     NCBI Gene
# 1      ALG14              HGNC  199857     NCBI Gene
# 2       ALG2              HGNC   85365     NCBI Gene
# 3       CHAT              HGNC    1103     NCBI Gene
# 4       CHD8              HGNC   57680     NCBI Gene
#
#                                             DisGeNET
# 0  [{'gene_dsi': 0.626, 'gene_dpi': 0.538, 'gene_...
# 1  [{'gene_dsi': 0.722, 'gene_dpi': 0.308, 'gene_...
# 2  [{'gene_dsi': 0.67, 'gene_dpi': 0.423, 'gene_p...
# 3  [{'gene_dsi': 0.52, 'gene_dpi': 0.808, 'gene_p...
# 4  [{'gene_dsi': 0.656, 'gene_dpi': 0.577, 'gene_...

# %%
disgenet_result["DisGeNET"][0]
# Out:
# [{'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C3808739',
#   'disease_name': 'MYASTHENIC SYNDROME, CONGENITAL, 8',
#   'disease_class': None,
#   'disease_class_name': None,
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.8,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2009.0,
#   'year_final': 2014.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751882',
#   'disease_name': 'Myasthenic Syndromes, Congenital',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.65,
#   'ei': 1.0,
#   'el': 'strong',
#   'year_initial': 2009.0,
#   'year_final': 2020.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751883',
#   'disease_name': 'Congenital Myasthenic Syndromes, Postsynaptic',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.5,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2009.0,
#   'year_final': 2012.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751884',
#   'disease_name': 'Congenital Myasthenic Syndromes, Presynaptic',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.5,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2009.0,
#   'year_final': 2012.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0023467',
#   'disease_name': 'Leukemia, Myelocytic, Acute',
#   'disease_class': 'C04',
#   'disease_class_name': '   Neoplasms',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Neoplastic Process',
#   'score': 0.3,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2007.0,
#   'year_final': 2007.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0026998',
#   'disease_name': 'Acute Myeloid Leukemia, M1',
#   'disease_class': 'C04',
#   'disease_class_name': '   Neoplasms',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Neoplastic Process',
#   'score': 0.3,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2007.0,
#   'year_final': 2007.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751885',
#   'disease_name': 'Myasthenic Syndromes, Congenital, Slow Channel',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.3,
#   'ei': nan,
#   'el': None,
#   'year_initial': nan,
#   'year_final': nan,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C1850792',
#   'disease_name': 'Congenital myasthenic syndrome ib',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.3,
#   'ei': nan,
#   'el': 'limited',
#   'year_initial': nan,
#   'year_final': nan,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C1879321',
#   'disease_name': 'Acute Myeloid Leukemia (AML-M2)',
#   'disease_class': 'C04',
#   'disease_class_name': '   Neoplasms',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Neoplastic Process',
#   'score': 0.3,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2007.0,
#   'year_final': 2007.0,
#   'source': 'CURATED'}]

# %% [markdown]
# ## Gene location annotation from OpenTargets

# %%
loc_df, opentargets_loc_metadata = opentargets.get_gene_location(bridgedb_df=bridgdb_df)
loc_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                 OpenTargets_Location
# 0  [{'loc_identifier': 'SL-0243', 'subcellular_lo...
# 1  [{'loc_identifier': 'SL-0097', 'subcellular_lo...
# 2  [{'loc_identifier': 'SL-0162', 'subcellular_lo...
# 3  [{'loc_identifier': nan, 'subcellular_loc': na...
# 4  [{'loc_identifier': 'SL-0191', 'subcellular_lo...

# %%
go_process_df, opentargets_go_metadata = opentargets.get_gene_go_process(bridgedb_df=bridgdb_df)
go_process_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                           GO_Process
# 0  [{'go_id': 'GO:0005796', 'go_name': 'Golgi lum...
# 1  [{'go_id': 'GO:0006488', 'go_name': 'dolichol-...
# 2  [{'go_id': 'GO:0046982', 'go_name': 'protein h...
# 3  [{'go_id': 'GO:0004102', 'go_name': 'choline O...
# 4  [{'go_id': 'GO:0005654', 'go_name': 'nucleopla...

# %%
reactome_process_df, opentargets_process_metadata = opentargets.get_gene_reactome_pathways(
    bridgedb_df=bridgdb_df
)
reactome_process_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                    Reactome_Pathways
# 0  [{'pathway_name': 'ECM proteoglycans', 'pathwa...
# 1  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 2  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 3  [{'pathway_name': 'Synthesis of PC', 'pathway_...
# 4  [{'pathway_name': 'Deactivation of the beta-ca...

# %%
drug_df, opentargets_drug_metadata = opentargets.get_gene_drug_interactions(bridgedb_df=bridgdb_df)
drug_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                         ChEMBL_Drugs
# 0  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 1  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 2  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 3  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 4  [{'chembl_id': nan, 'drug_name': nan, 'relatio...

# %%
disease_df, opentargets_disease_metadata = opentargets.get_gene_disease_associations(
    bridgedb_df=bridgdb_df
)
disease_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                 OpenTargets_Diseases
# 0  [{'disease_id': nan, 'disease_name': nan, 'the...
# 1  [{'disease_id': nan, 'disease_name': nan, 'the...
# 2  [{'disease_id': nan, 'disease_name': nan, 'the...
# 3  [{'disease_id': nan, 'disease_name': nan, 'the...
# 4  [{'disease_id': nan, 'disease_name': nan, 'the...

# %% [markdown]
# ## Inhibitors of trasporters encoded by genes annotation by MolMeDB

# %%
inhibitor_df, inhibitor_metadata = molmedb.get_transporter_inhibitor(bridgedb_df=bridgdb_df)
inhibitor_df.head()
# Out:
#   identifier identifier.source      target   target.source  \
# 0       AGRN              HGNC  A0A087X208  Uniprot-TrEMBL
# 1       AGRN              HGNC  A0A494C0G5  Uniprot-TrEMBL
# 2       AGRN              HGNC  A0A494C1I6  Uniprot-TrEMBL
# 3       AGRN              HGNC      O00468  Uniprot-TrEMBL
# 4      ALG14              HGNC      Q96F25  Uniprot-TrEMBL
#
#                                transporter_inhibitor
# 0  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 1  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 2  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 3  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 4  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...

# %%
inhibitor_df["transporter_inhibitor"][72]
# Out:
# [{'label': 'Cefepime',
#   'InChIKey': 'HVFLCNVBZFFHBT-UHFFFAOYSA-O',
#   'SMILES': 'CON=C(C(=O)NC1C(=O)N2C(C(=O)O)=C(C[N+]3(C)CCCC3)CSC12)c1csc(N)n1',
#   'pubchem_compound_id': '2623',
#   'molmedb_id': 'MM16967',
#   'source_doi': 'doi:10.1074/jbc.275.3.1699',
#   'source_pmid': '10636865',
#   'chebi_id': nan,
#   'drugbank_id': nan},
#  {'label': 'Cephaloridine',
#   'InChIKey': 'CZTQZXZIADLWOZ-UHFFFAOYSA-O',
#   'SMILES': 'O=C(Cc1cccs1)NC1C(=O)N2C(C(=O)O)=C(C[n+]3ccccc3)CSC12',
#   'pubchem_compound_id': '5773',
#   'molmedb_id': 'MM00638',
#   'source_doi': 'doi:10.1074/jbc.275.3.1699',
#   'source_pmid': '10636865',
#   'chebi_id': '3537',
#   'drugbank_id': 'DB09008'}]

# %% [markdown]
# ## Combing all the results into single dataframe

# %%
combined_df = combine_sources(
    [disgenet_result, loc_df, go_process_df, reactome_process_df, drug_df, disease_df, inhibitor_df]
)

# %%
combined_df.head(4)
# Out:
#   identifier identifier.source  target target.source  \
# 0       AGRN              HGNC  375790     NCBI Gene
# 1      ALG14              HGNC  199857     NCBI Gene
# 2       ALG2              HGNC   85365     NCBI Gene
# 3       CHAT              HGNC    1103     NCBI Gene
#
#                                             DisGeNET  \
# 0  [{'gene_dsi': 0.626, 'gene_dpi': 0.538, 'gene_...
# 1  [{'gene_dsi': 0.722, 'gene_dpi': 0.308, 'gene_...
# 2  [{'gene_dsi': 0.67, 'gene_dpi': 0.423, 'gene_p...
# 3  [{'gene_dsi': 0.52, 'gene_dpi': 0.808, 'gene_p...
#
#                                 OpenTargets_Location  \
# 0  [{'loc_identifier': 'SL-0243', 'subcellular_lo...
# 1  [{'loc_identifier': 'SL-0097', 'subcellular_lo...
# 2  [{'loc_identifier': 'SL-0162', 'subcellular_lo...
# 3  [{'loc_identifier': nan, 'subcellular_loc': na...
#
#                                           GO_Process  \
# 0  [{'go_id': 'GO:0005796', 'go_name': 'Golgi lum...
# 1  [{'go_id': 'GO:0006488', 'go_name': 'dolichol-...
# 2  [{'go_id': 'GO:0046982', 'go_name': 'protein h...
# 3  [{'go_id': 'GO:0004102', 'go_name': 'choline O...
#
#                                    Reactome_Pathways  \
# 0  [{'pathway_name': 'ECM proteoglycans', 'pathwa...
# 1  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 2  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 3  [{'pathway_name': 'Synthesis of PC', 'pathway_...
#
#                                         ChEMBL_Drugs  \
# 0  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 1  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 2  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 3  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
#
#                                 OpenTargets_Diseases  \
# 0  [{'disease_id': nan, 'disease_name': nan, 'the...
# 1  [{'disease_id': nan, 'disease_name': nan, 'the...
# 2  [{'disease_id': nan, 'disease_name': nan, 'the...
# 3  [{'disease_id': nan, 'disease_name': nan, 'the...
#
#                                transporter_inhibitor
# 0  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 1  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 2  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...
# 3  [{'label': nan, 'InChIKey': nan, 'SMILES': nan...

# %% [markdown]
# # Metabolite workflow

# %%
metabolites_of_interest = """100208
10040286
10041551
10025195"""
metabolite_list = metabolites_of_interest.split("\n")
len(metabolite_list)
# Out:
# 4

# %%
data_input = pd.DataFrame(metabolite_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0     100208
# 1   10040286
# 2   10041551
# 3   10025195

# %%
bridgdb_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input["identifier"],
    input_species="Human",
    input_datasource="PubChem Compound",
    output_datasource="All",
)
bridgdb_df.head(100)
# Out:
#    identifier identifier.source                       target  \
# 0      100208  PubChem-compound                        90560
# 1      100208  PubChem-compound                       100208
# 2      100208  PubChem-compound                  HMDB0244377
# 3      100208  PubChem-compound  OFDNQWIFNXBECV-UHFFFAOYSA-N
# 4      100208  PubChem-compound                       C11280
# 5      100208  PubChem-compound                   Q104246146
# 6    10040286  PubChem-compound                     10040286
# 7    10040286  PubChem-compound                 CHEMBL602850
# 8    10040286  PubChem-compound                    Q27163373
# 9    10040286  PubChem-compound                        91540
# 10   10040286  PubChem-compound                  CHEBI:91540
# 11   10040286  PubChem-compound  FYGREZKTJIXWIH-UHFFFAOYSA-N
# 12   10040286  PubChem-compound                      8215850
# 13   10041551  PubChem-compound                     10041551
# 14   10041551  PubChem-compound  OVVBIIBBRZVPAL-UHFFFAOYSA-N
# 15   10041551  PubChem-compound                    Q27088017
# 16   10041551  PubChem-compound                         7537
# 17   10041551  PubChem-compound                      8217115
# 18   10025195  PubChem-compound                    Q82248803
# 19   10025195  PubChem-compound                     10025195
# 20   10025195  PubChem-compound               DTXSID70434393
# 21   10025195  PubChem-compound                  174643-77-7
# 22   10025195  PubChem-compound  LEJRLSZVESQKJK-UHFFFAOYSA-N
#
#                                    target.source
# 0                                     ChemSpider
# 1                               PubChem Compound
# 2                                           HMDB
# 3                                       InChIKey
# 4                                  KEGG Compound
# 5                                       Wikidata
# 6                               PubChem Compound
# 7                                ChEMBL compound
# 8                                       Wikidata
# 9                                          ChEBI
# 10                                         ChEBI
# 11                                      InChIKey
# 12                                    ChemSpider
# 13                              PubChem Compound
# 14                                      InChIKey
# 15                                      Wikidata
# 16  Guide to Pharmacology Ligand ID (aka IUPHAR)
# 17                                    ChemSpider
# 18                                      Wikidata
# 19                              PubChem Compound
# 20                                           NaN
# 21                                           CAS
# 22                                      InChIKey

# %%
transporter_inhibited_df, transporter_inhibited_metadata = molmedb.get_transporter_inhibited(bridgedb_df=bridgdb_df)
transporter_inhibited_df.head()
# Out:
#   identifier identifier.source                       target target.source  \
# 0     100208  PubChem-compound  OFDNQWIFNXBECV-UHFFFAOYSA-N      InChIKey
# 1   10025195  PubChem-compound  LEJRLSZVESQKJK-UHFFFAOYSA-N      InChIKey
# 2   10040286  PubChem-compound  FYGREZKTJIXWIH-UHFFFAOYSA-N      InChIKey
# 3   10041551  PubChem-compound  OVVBIIBBRZVPAL-UHFFFAOYSA-N      InChIKey
#
#                                transporter_inhibited
# 0  [{'uniprot_trembl_id': 'P08183', 'hgcn_id': 'A...
# 1  [{'uniprot_trembl_id': 'Q01959', 'hgcn_id': 'S...
# 2  [{'uniprot_trembl_id': 'Q01959', 'hgcn_id': 'S...
# 3  [{'uniprot_trembl_id': 'P23975', 'hgcn_id': 'S...

# %%
transporter_inhibited_df["transporter_inhibited"][0]
# Out:
# [{'uniprot_trembl_id': 'P08183',
#   'hgcn_id': 'ABCB1',
#   'source_doi': 'doi:10.1074/jbc.271.6.3163',
#   'source_pmid': '8621716'}]
