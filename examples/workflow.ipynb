# %% [markdown]
# # Workflow playground for the project

# %%
# Import modules
import os

import pandas as pd

from pyBiodatafuse import id_mapper
from pyBiodatafuse.annotators import disgenet, molmedb, opentargets, wikipathways
from pyBiodatafuse.utils import combine_sources

# %% [markdown]
# ### Load the input list and convert it to a dataframe

# %%
genes_of_interest = """AGRN
ALG14
ALG2
CHAT
CHD8
CHRNA1
CHRNB1
CHRND
CHRNE
CHRNG
COL13A1
COLQ
DOK7
SLC22A1"""
gene_list = genes_of_interest.split("\n")
len(gene_list)
# Out:
# 14

# %%
data_input = pd.DataFrame(gene_list, columns=["identifier"])
data_input.head()
# Out:
#   identifier
# 0       AGRN
# 1      ALG14
# 2       ALG2
# 3       CHAT
# 4       CHD8

# %% [markdown]
# ### Entity resolution using BridgeDB

# %%
bridgdb_df, bridgdb_metadata = id_mapper.bridgedb_xref(
    identifiers=data_input["identifier"],
    input_species="Human",
    input_datasource="HGNC",
    output_datasource="All",
)
bridgdb_df.head()
# Out:
#   identifier identifier.source      target  target.source
# 0       AGRN              HGNC  GO:0046872  Gene Ontology
# 1       AGRN              HGNC     4053565           Affy
# 2       AGRN              HGNC     4053601           Affy
# 3       AGRN              HGNC     4053600           Affy
# 4       AGRN              HGNC     4053602           Affy

# %% [markdown]
# # Disease annotating using DisGeNet

# %%
api_key = "0209751bfa7b6a981a8f5fb5f062313067ecd36c"  # TODO: add your key
params = {"source": "CURATED", "format": "json"}  # only curated data
disgenet_result, disgenet_metadata = disgenet.get_gene_disease(
    bridgedb_df=bridgdb_df, api_key=api_key, params=params
)
disgenet_result.head()
# Out:
#   identifier identifier.source  target target.source  \
# 0       AGRN              HGNC  375790     NCBI Gene
# 1      ALG14              HGNC  199857     NCBI Gene
# 2       ALG2              HGNC   85365     NCBI Gene
# 3       CHAT              HGNC    1103     NCBI Gene
# 4       CHD8              HGNC   57680     NCBI Gene
#
#                                             DisGeNET
# 0  [{'gene_dsi': 0.626, 'gene_dpi': 0.538, 'gene_...
# 1  [{'gene_dsi': 0.722, 'gene_dpi': 0.308, 'gene_...
# 2  [{'gene_dsi': 0.67, 'gene_dpi': 0.423, 'gene_p...
# 3  [{'gene_dsi': 0.52, 'gene_dpi': 0.808, 'gene_p...
# 4  [{'gene_dsi': 0.656, 'gene_dpi': 0.577, 'gene_...

# %%
disgenet_result["DisGeNET"][0]
# Out:
# [{'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C3808739',
#   'disease_name': 'MYASTHENIC SYNDROME, CONGENITAL, 8',
#   'disease_class': None,
#   'disease_class_name': None,
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.8,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2009.0,
#   'year_final': 2014.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751882',
#   'disease_name': 'Myasthenic Syndromes, Congenital',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.65,
#   'ei': 1.0,
#   'el': 'strong',
#   'year_initial': 2009.0,
#   'year_final': 2020.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751883',
#   'disease_name': 'Congenital Myasthenic Syndromes, Postsynaptic',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.5,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2009.0,
#   'year_final': 2012.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751884',
#   'disease_name': 'Congenital Myasthenic Syndromes, Presynaptic',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.5,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2009.0,
#   'year_final': 2012.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0023467',
#   'disease_name': 'Leukemia, Myelocytic, Acute',
#   'disease_class': 'C04',
#   'disease_class_name': '   Neoplasms',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Neoplastic Process',
#   'score': 0.3,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2007.0,
#   'year_final': 2007.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0026998',
#   'disease_name': 'Acute Myeloid Leukemia, M1',
#   'disease_class': 'C04',
#   'disease_class_name': '   Neoplasms',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Neoplastic Process',
#   'score': 0.3,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2007.0,
#   'year_final': 2007.0,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C0751885',
#   'disease_name': 'Myasthenic Syndromes, Congenital, Slow Channel',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.3,
#   'ei': nan,
#   'el': None,
#   'year_initial': nan,
#   'year_final': nan,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C1850792',
#   'disease_name': 'Congenital myasthenic syndrome ib',
#   'disease_class': 'C16;C10',
#   'disease_class_name': '   Congenital, Hereditary, and Neonatal Diseases and Abnormalities;    Nervous System Diseases',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Disease or Syndrome',
#   'score': 0.3,
#   'ei': nan,
#   'el': 'limited',
#   'year_initial': nan,
#   'year_final': nan,
#   'source': 'CURATED'},
#  {'gene_dsi': 0.626,
#   'gene_dpi': 0.538,
#   'gene_pli': 5.4727e-07,
#   'protein_class': None,
#   'protein_class_name': None,
#   'diseaseid': 'C1879321',
#   'disease_name': 'Acute Myeloid Leukemia (AML-M2)',
#   'disease_class': 'C04',
#   'disease_class_name': '   Neoplasms',
#   'disease_type': 'disease',
#   'disease_semantic_type': 'Neoplastic Process',
#   'score': 0.3,
#   'ei': 1.0,
#   'el': None,
#   'year_initial': 2007.0,
#   'year_final': 2007.0,
#   'source': 'CURATED'}]

# %% [markdown]
# # Gene location annotation from OpenTargets

# %%
loc_df, opentargets_loc_metadata = opentargets.get_gene_location(bridgedb_df=bridgdb_df)
loc_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                 OpenTargets_Location
# 0  [{'loc_identifier': 'SL-0243', 'subcellular_lo...
# 1  [{'loc_identifier': 'SL-0097', 'subcellular_lo...
# 2  [{'loc_identifier': 'SL-0162', 'subcellular_lo...
# 3  [{'loc_identifier': nan, 'subcellular_loc': na...
# 4  [{'loc_identifier': 'SL-0191', 'subcellular_lo...

# %%
go_process_df, opentargets_go_metadata = opentargets.get_gene_go_process(bridgedb_df=bridgdb_df)
go_process_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                           GO_Process
# 0  [{'go_id': 'GO:0005796', 'go_name': 'Golgi lum...
# 1  [{'go_id': 'GO:0006488', 'go_name': 'dolichol-...
# 2  [{'go_id': 'GO:0046982', 'go_name': 'protein h...
# 3  [{'go_id': 'GO:0004102', 'go_name': 'choline O...
# 4  [{'go_id': 'GO:0005654', 'go_name': 'nucleopla...

# %%
reactome_process_df, opentargets_process_metadata = opentargets.get_gene_reactome_pathways(
    bridgedb_df=bridgdb_df
)
reactome_process_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                    Reactome_Pathways
# 0  [{'pathway_name': 'ECM proteoglycans', 'pathwa...
# 1  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 2  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 3  [{'pathway_name': 'Synthesis of PC', 'pathway_...
# 4  [{'pathway_name': 'Deactivation of the beta-ca...

# %%
drug_df, opentargets_drug_metadata = opentargets.get_gene_drug_interactions(bridgedb_df=bridgdb_df)
drug_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                         ChEMBL_Drugs
# 0  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 1  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 2  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 3  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 4  [{'chembl_id': nan, 'drug_name': nan, 'relatio...

# %%
disease_df, opentargets_disease_metadata = opentargets.get_gene_disease_associations(
    bridgedb_df=bridgdb_df
)
disease_df.head()
# Out:
#   identifier identifier.source           target target.source  \
# 0       AGRN              HGNC  ENSG00000188157       Ensembl
# 1      ALG14              HGNC  ENSG00000172339       Ensembl
# 2       ALG2              HGNC  ENSG00000119523       Ensembl
# 3       CHAT              HGNC  ENSG00000070748       Ensembl
# 4       CHD8              HGNC  ENSG00000100888       Ensembl
#
#                                 OpenTargets_Diseases
# 0  [{'disease_id': nan, 'disease_name': nan, 'the...
# 1  [{'disease_id': nan, 'disease_name': nan, 'the...
# 2  [{'disease_id': nan, 'disease_name': nan, 'the...
# 3  [{'disease_id': nan, 'disease_name': nan, 'the...
# 4  [{'disease_id': nan, 'disease_name': nan, 'the...

# %% [markdown]
# # Inhibitors of trasporters encoded by genes annotation by MolMeDB

# %%
inhibitor_df, inhibitor_metadata = molmedb.get_transporter_inhibitor(bridgedb_df=bridgdb_df)
inhibitor_df["MolMeDB"][70]
# Out:
# [{'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'AAKJLRGGTJKAMG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-LHHVKLHASA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-LHHVKLHASA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-LHHVKLHASA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-LHHVKLHASA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'RJKFOVLPORLFTN-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C'},
#  {'inhibitor_InChIKey': 'XMAYWYJOQHXEEK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)cc4Cl)O3)cc2)CC1'},
#  {'inhibitor_InChIKey': 'LXMSZDCAJNLERA-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)SC1CC2=CC(=O)CCC2(C)C2CCC3(C)C(CCC34CCC(=O)O4)C12'},
#  {'inhibitor_InChIKey': 'QWAXKHKRTORLEM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)(C)NC(=O)C1CC2CCCCC2CN1CC(O)C(Cc1ccccc1)NC(=O)C(CC(N)=O)NC(=O)c1ccc2ccccc2n1'},
#  {'inhibitor_InChIKey': 'QWAXKHKRTORLEM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)(C)NC(=O)C1CC2CCCCC2CN1CC(O)C(Cc1ccccc1)NC(=O)C(CC(N)=O)NC(=O)c1ccc2ccccc2n1'},
#  {'inhibitor_InChIKey': 'FBMYKMYQHCBIGU-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)(Cc1c[nH]c2ccccc12)NCC(O)COc1ccccc1C#N'},
#  {'inhibitor_InChIKey': 'JZQKKSLKJUAGIC-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)NCC(O)COc1cccc2[nH]ccc12'},
#  {'inhibitor_InChIKey': 'JFVZFKDSXNQEJW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)OC(=O)OCOP(=O)(COC(C)Cn1cnc2c(N)ncnc21)OCOC(=O)OC(C)C'},
#  {'inhibitor_InChIKey': 'NCDNCNXCDXHOMX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)C(Cc2ccccc2)NC(=O)OCc2cncs2)C(C)C)cs1'},
#  {'inhibitor_InChIKey': 'NCDNCNXCDXHOMX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)C(Cc2ccccc2)NC(=O)OCc2cncs2)C(C)C)cs1'},
#  {'inhibitor_InChIKey': 'QZVCTJOXCFMACW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(COc1ccccc1)N(CCCl)Cc1ccccc1'},
#  {'inhibitor_InChIKey': 'BUGYDGFZZOZRHP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC12CC3CC(C)(C1)CC(N)(C3)C2'},
#  {'inhibitor_InChIKey': 'OMFXVFTZEKFJBZ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC12CCC(=O)C=C1CCC1C2C(O)CC2(C)C(C(=O)CO)CCC12'},
#  {'inhibitor_InChIKey': 'GJSGYPDDPQRWPK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCC[N+](CCCCC)(CCCCC)CCCCC'},
#  {'inhibitor_InChIKey': 'GJSGYPDDPQRWPK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCC[N+](CCCCC)(CCCCC)CCCCC'},
#  {'inhibitor_InChIKey': 'DZLFLBLQUQXARW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCC[N+](CCCC)(CCCC)CCCC'},
#  {'inhibitor_InChIKey': 'JWHAUXFOSRPERK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1'},
#  {'inhibitor_InChIKey': 'AGJZCWVTGOVGBS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN1C(=Cc2ccc3ccccc3[n+]2CC)C=Cc2ccccc21'},
#  {'inhibitor_InChIKey': 'AGJZCWVTGOVGBS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN1C(=Cc2ccc3ccccc3[n+]2CC)C=Cc2ccccc21'},
#  {'inhibitor_InChIKey': 'FAEKWTJYAYMJKF-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCOc1cc(CC(=O)NC(CC(C)C)c2ccccc2N2CCCCC2)ccc1C(=O)O'},
#  {'inhibitor_InChIKey': 'BDYYDXJSHYEDGB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C(=O)C(Cl)Cl)c1ccc(OC(=O)c2ccco2)cc1'},
#  {'inhibitor_InChIKey': 'KRMDCWKBEZIMAB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCC=C1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'WSEQXVZVJXJVFP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCC1(c2ccc(F)cc2)OCc2cc(C#N)ccc21'},
#  {'inhibitor_InChIKey': 'LGLFFNDHMLKUMI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)c1ccc(C(=C2C=CC(=[N+](C)C)C=C2)c2ccc(N(C)C)cc2)cc1'},
#  {'inhibitor_InChIKey': 'HCYAFALTSJYZDH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNCCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'YREYEVIYCVEVJK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COCCCOc1ccnc(CS(=O)c2nc3ccccc3[nH]2)c1C'},
#  {'inhibitor_InChIKey': 'RUZYUOTYCVRMRZ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)C4COc5ccccc5O4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'IENZQIKPVFGBNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'IENZQIKPVFGBNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'IENZQIKPVFGBNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'IENZQIKPVFGBNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'SGTNSNPWRIOYBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'},
#  {'inhibitor_InChIKey': 'SGTNSNPWRIOYBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'},
#  {'inhibitor_InChIKey': 'SGTNSNPWRIOYBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'},
#  {'inhibitor_InChIKey': 'CMJZRLIOGSSFJB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'C[n+]1cccc(-c2ccccc2)c1'},
#  {'inhibitor_InChIKey': 'HHZIURLSWUIHRB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1'},
#  {'inhibitor_InChIKey': 'HBOMLICNUCNMMY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1cn(C2CC(N=[N+]=[N-])C(CO)O2)c(=O)[nH]c1=O'},
#  {'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'ICFJFFQQTFMIBG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(N)NC(=N)NCCc1ccccc1'},
#  {'inhibitor_InChIKey': 'DKNWSYNQZKUICI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC12CC3CC(CC(C3)C1)C2'},
#  {'inhibitor_InChIKey': 'SSJXIUAHEKJCMH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC1CCCCC1N'},
#  {'inhibitor_InChIKey': 'XQSPYNMVSIKCOC-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Nc1nc(=O)n(C2CSC(CO)O2)cc1F'},
#  {'inhibitor_InChIKey': 'MCGSCOLBFJQGHM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Nc1nc(NC2CC2)c2ncn(C3C=CC(CO)C3)c2n1'},
#  {'inhibitor_InChIKey': 'URKOMYMAXPYINW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'OCCOCCN1CCN(C2=Nc3ccccc3Sc3ccccc32)CC1'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-LHHVKLHASA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'METKIMKYRPQLGS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)NCC(O)COc1ccc(CC(N)=O)cc1'},
#  {'inhibitor_InChIKey': 'AQHHHDLHHXJYJD-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)NCC(O)COc1cccc2ccccc12'},
#  {'inhibitor_InChIKey': 'XEYBRNLFEZDVAW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCCC(O)C=CC1C(O)CC(=O)C1CC=CCCCC(=O)O'},
#  {'inhibitor_InChIKey': 'XEYBRNLFEZDVAW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCCC(O)C=CC1C(O)CC(=O)C1CC=CCCCC(=O)O'},
#  {'inhibitor_InChIKey': 'PXGPLTODNUVGFL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCCC(O)C=CC1C(O)CC(O)C1CC=CCCCC(=O)O'},
#  {'inhibitor_InChIKey': 'PXGPLTODNUVGFL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCCC(O)C=CC1C(O)CC(O)C1CC=CCCCC(=O)O'},
#  {'inhibitor_InChIKey': 'AGJZCWVTGOVGBS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN1C(=Cc2ccc3ccccc3[n+]2CC)C=Cc2ccccc21'},
#  {'inhibitor_InChIKey': 'AGJZCWVTGOVGBS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN1C(=Cc2ccc3ccccc3[n+]2CC)C=Cc2ccccc21'},
#  {'inhibitor_InChIKey': 'QTANTQQOYSUMLC-UHFFFAOYSA-O',
#   'inhibitor_SMILES': 'CC[n+]1c(-c2ccccc2)c2cc(N)ccc2c2ccc(N)cc21'},
#  {'inhibitor_InChIKey': 'XZWYZXLIPXDOLR-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)C(=N)N=C(N)N'},
#  {'inhibitor_InChIKey': 'XZWYZXLIPXDOLR-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)C(=N)N=C(N)N'},
#  {'inhibitor_InChIKey': 'KWGRBVOPPLSCSI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNC(C)C(O)c1ccccc1'},
#  {'inhibitor_InChIKey': 'SGTNSNPWRIOYBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'},
#  {'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'JWPGJSVJDAJRLW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(N)N1CCc2ccccc2C1'},
#  {'inhibitor_InChIKey': 'JTEGQNOMFQHVDC-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Nc1ccn(C2CSC(CO)O2)c(=O)n1'},
#  {'inhibitor_InChIKey': 'AAKJLRGGTJKAMG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-LHHVKLHASA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-LHHVKLHASA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-WZBLMQSHSA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@H]2[C@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'CEMAWMOMDPGJMB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'C=CCOc1ccccc1OCC(O)CNC(C)C'},
#  {'inhibitor_InChIKey': 'RJKFOVLPORLFTN-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C'},
#  {'inhibitor_InChIKey': 'XMAYWYJOQHXEEK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)cc4Cl)O3)cc2)CC1'},
#  {'inhibitor_InChIKey': 'CBVCZFGXHXORBI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1ccccc1)C(=O)NC1c2ccccc2CC1O'},
#  {'inhibitor_InChIKey': 'DSOKWLKBYFUNEO-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)(C)c1ccc(N=C(N)N)cc1'},
#  {'inhibitor_InChIKey': 'FBMYKMYQHCBIGU-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)(Cc1c[nH]c2ccccc12)NCC(O)COc1ccccc1C#N'},
#  {'inhibitor_InChIKey': 'UVTNFZQICZKOEM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)N(CCC(C(N)=O)(c1ccccc1)c1ccccn1)C(C)C'},
#  {'inhibitor_InChIKey': 'UVTNFZQICZKOEM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)N(CCC(C(N)=O)(c1ccccc1)c1ccccn1)C(C)C'},
#  {'inhibitor_InChIKey': 'AQHHHDLHHXJYJD-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)NCC(O)COc1cccc2ccccc12'},
#  {'inhibitor_InChIKey': 'NCDNCNXCDXHOMX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)C(Cc2ccccc2)NC(=O)OCc2cncs2)C(C)C)cs1'},
#  {'inhibitor_InChIKey': 'JRWZLRBJNMZMFE-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(CCc1ccc(O)cc1)NCCc1ccc(O)c(O)c1'},
#  {'inhibitor_InChIKey': 'ZSCDBOWYZJWBIY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(CN(C)C)CN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'PWWVAXIEGOYWEE-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(CN1c2ccccc2Sc2ccccc21)N(C)C'},
#  {'inhibitor_InChIKey': 'QZVCTJOXCFMACW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(COc1ccccc1)N(CCCl)Cc1ccccc1'},
#  {'inhibitor_InChIKey': 'QZVCTJOXCFMACW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(COc1ccccc1)N(CCCl)Cc1ccccc1'},
#  {'inhibitor_InChIKey': 'BUGYDGFZZOZRHP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC12CC3CC(C)(C1)CC(N)(C3)C2'},
#  {'inhibitor_InChIKey': 'OMFXVFTZEKFJBZ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC12CCC(=O)C=C1CCC1C2C(O)CC2(C)C(C(=O)CO)CCC12'},
#  {'inhibitor_InChIKey': 'NPAGDVCDWIYMMC-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC12CCC3C4CCC(=O)C=C4CCC3C1CCC2O'},
#  {'inhibitor_InChIKey': 'VOXZDWNPVJITMN-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC12CCC3c4ccc(O)cc4CCC3C1CCC2O'},
#  {'inhibitor_InChIKey': 'DTIFFPXSSXFQCJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCCC[N+](CCCCCC)(CCCCCC)CCCCCC'},
#  {'inhibitor_InChIKey': 'DZLFLBLQUQXARW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCC[N+](CCCC)(CCCC)CCCC'},
#  {'inhibitor_InChIKey': 'JWHAUXFOSRPERK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1'},
#  {'inhibitor_InChIKey': 'JWHAUXFOSRPERK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1'},
#  {'inhibitor_InChIKey': 'OSBSFAARYOCBHB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCC[N+](CCC)(CCC)CCC'},
#  {'inhibitor_InChIKey': 'CDOZDBSBBXSXLB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21'},
#  {'inhibitor_InChIKey': 'WINHZLLDWRZWRT-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2C(=O)Nc3ccc(F)cc32)c1C'},
#  {'inhibitor_InChIKey': 'TTWJBBZEZQICBI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCNC(=O)c1cc(Cl)c(N)cc1OC'},
#  {'inhibitor_InChIKey': 'RYOOHIUJEJZCFT-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCNC(C(=O)OCCC(C)C)c1ccccc1'},
#  {'inhibitor_InChIKey': 'CFJMRBQWBDQYMK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCOCCOC(=O)C1(c2ccccc2)CCCC1'},
#  {'inhibitor_InChIKey': 'AGJZCWVTGOVGBS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN1C(=Cc2ccc3ccccc3[n+]2CC)C=Cc2ccccc21'},
#  {'inhibitor_InChIKey': 'FAEKWTJYAYMJKF-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCOc1cc(CC(=O)NC(CC(C)C)c2ccccc2N2CCCCC2)ccc1C(=O)O'},
#  {'inhibitor_InChIKey': 'UWKQSNNFCGGAFS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC'},
#  {'inhibitor_InChIKey': 'WKSAUQYGYAYLPV-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1'},
#  {'inhibitor_InChIKey': 'XZWYZXLIPXDOLR-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)C(=N)N=C(N)N'},
#  {'inhibitor_InChIKey': 'XZWYZXLIPXDOLR-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)C(=N)N=C(N)N'},
#  {'inhibitor_InChIKey': 'RDOIQAHITMMDAJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)C(=O)C(CCN1CCC(O)(c2ccc(Cl)cc2)CC1)(c1ccccc1)c1ccccc1'},
#  {'inhibitor_InChIKey': 'KRMDCWKBEZIMAB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCC=C1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'ODQWQRRAPPTVAG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCC=C1c2ccccc2COc2ccccc21'},
#  {'inhibitor_InChIKey': 'WSPOMRSOLSGNFJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCC=C1c2ccccc2Sc2ccc(Cl)cc21'},
#  {'inhibitor_InChIKey': 'WSEQXVZVJXJVFP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCC1(c2ccc(F)cc2)OCc2cc(C#N)ccc21'},
#  {'inhibitor_InChIKey': 'GDLIGKIOYRNHDA-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2CCc2ccc(Cl)cc21'},
#  {'inhibitor_InChIKey': 'BCGWQEUPMDMJNV-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'BCGWQEUPMDMJNV-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'BCGWQEUPMDMJNV-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'ZPEIMTDSQAKGNT-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21'},
#  {'inhibitor_InChIKey': 'ZPEIMTDSQAKGNT-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21'},
#  {'inhibitor_InChIKey': 'ZGUGWUXLJSTTMA-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2Sc2ccccc21'},
#  {'inhibitor_InChIKey': 'NERVJFDGDIPHLJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(CCCl)C1c2ccccc2-c2ccccc21'},
#  {'inhibitor_InChIKey': 'RKUNBYITZUJHSG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2'},
#  {'inhibitor_InChIKey': 'BQJCRHHNABKAKU-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN1CCC23c4c5ccc(O)c4OC2C(O)C=CC3C1C5'},
#  {'inhibitor_InChIKey': 'YNNUSGIPVFPVBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN1CCCC1CCOC(C)(c1ccccc1)c1ccc(Cl)cc1'},
#  {'inhibitor_InChIKey': 'WIKYUJGCLQQFNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1'},
#  {'inhibitor_InChIKey': 'VMWNQDUVQKEIOC-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN1CCc2cccc3c2C1Cc1ccc(O)c(O)c1-3'},
#  {'inhibitor_InChIKey': 'AQIXAKUUQRKLND-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNC(=NCCSCc1nc[nH]c1C)NC#N'},
#  {'inhibitor_InChIKey': 'AQIXAKUUQRKLND-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNC(=NCCSCc1nc[nH]c1C)NC#N'},
#  {'inhibitor_InChIKey': 'HCYAFALTSJYZDH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNCCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'HCYAFALTSJYZDH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNCCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'DDUHZTYCFQRHIY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COC1=CC(=O)CC(C)C12Oc1c(Cl)c(OC)cc(OC)c1C2=O'},
#  {'inhibitor_InChIKey': 'XXCCGRRUBBGZRE-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc(C(O)CNC(C)C)ccc1O'},
#  {'inhibitor_InChIKey': 'IEDVJHCEMCRBQM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC'},
#  {'inhibitor_InChIKey': 'IEDVJHCEMCRBQM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC'},
#  {'inhibitor_InChIKey': 'XCPGHVQEEXUHNC-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc(NS(C)(=O)=O)ccc1Nc1c2ccccc2nc2ccccc12'},
#  {'inhibitor_InChIKey': 'WNMJYKCGWZFFKR-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N(C)CCCNC(=O)C3CCCO3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'VCKUSRYTPJJLNI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)C4CCCO4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'IENZQIKPVFGBNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'IENZQIKPVFGBNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'HSUGRBWQSSZJOP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(C2Sc3ccccc3N(CCN(C)C)C(=O)C2OC(C)=O)cc1'},
#  {'inhibitor_InChIKey': 'SGTNSNPWRIOYBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'},
#  {'inhibitor_InChIKey': 'VHSBBVZJABQOSG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCNCC(O)c2ccc(O)cc2)cc1OC'},
#  {'inhibitor_InChIKey': 'MKXZASYAUGDDCJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc2c(c1)C13CCCCC1C(C2)N(C)CC3'},
#  {'inhibitor_InChIKey': 'TVYLLZQTGLZFBW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cccc(C2(O)CCCCC2CN(C)C)c1'},
#  {'inhibitor_InChIKey': 'OGHNVEJMJSYVRP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccccc1OCCNCC(O)COc1cccc2[nH]c3ccccc3c12'},
#  {'inhibitor_InChIKey': 'IQPSEEYGBUAQFF-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccnc(CS(=O)c2nc3cc(OC(F)F)ccc3[nH]2)c1OC'},
#  {'inhibitor_InChIKey': 'GKNPSSNBBWDAGH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'C[N+]1(C)CCCC(OC(=O)C(O)(c2ccccc2)c2ccccc2)C1'},
#  {'inhibitor_InChIKey': 'JMPFSEBWVLAJKM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1cc(C(C#N)c2ccc(Cl)cc2)c(Cl)cc1NC(=O)c1cc(I)cc(I)c1O'},
#  {'inhibitor_InChIKey': 'PKQYVFHRKFDVCH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1ccc(N=C(N)N)cc1'},
#  {'inhibitor_InChIKey': 'KTUFNOKKBVMGRW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc(-c2cccnc2)n1'},
#  {'inhibitor_InChIKey': 'QVYRGXJJSLMXQH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1ccccc1C(OCCN(C)C)c1ccccc1'},
#  {'inhibitor_InChIKey': 'QVYRGXJJSLMXQH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1ccccc1C(OCCN(C)C)c1ccccc1'},
#  {'inhibitor_InChIKey': 'JZRWCGZRTZMZEH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1'},
#  {'inhibitor_InChIKey': 'FELGMEQIXOGIFQ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1nccn1CC1CCc2c(c3ccccc3n2C)C1=O'},
#  {'inhibitor_InChIKey': 'FELGMEQIXOGIFQ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1nccn1CC1CCc2c(c3ccccc3n2C)C1=O'},
#  {'inhibitor_InChIKey': 'FELGMEQIXOGIFQ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1nccn1CC1CCc2c(c3ccccc3n2C)C1=O'},
#  {'inhibitor_InChIKey': 'FLNXBVJLPJNOSI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1ccc(C(OCCN2CCCCC2)c2ccccc2)cc1'},
#  {'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'VNFPBHJOKIVQEB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1'},
#  {'inhibitor_InChIKey': 'OEBPANQZQGQPHF-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cn1c(NCCN(CCO)CCCc2ccc([N+](=O)[O-])cc2)cc(=O)n(C)c1=O'},
#  {'inhibitor_InChIKey': 'XDRYMKDFEDOLFX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1'},
#  {'inhibitor_InChIKey': 'GHXZTYHSJHQHIJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(NCCCCCCNC(=N)NC(=N)Nc1ccc(Cl)cc1)NC(=N)Nc1ccc(Cl)cc1'},
#  {'inhibitor_InChIKey': 'XSDQTOBWRPYKKA-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(N)NC(=O)c1nc(Cl)c(N)nc1N'},
#  {'inhibitor_InChIKey': 'ICFJFFQQTFMIBG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(N)NC(=N)NCCc1ccccc1'},
#  {'inhibitor_InChIKey': 'WDZVGELJXXEGPV-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(N)NN=Cc1c(Cl)cccc1Cl'},
#  {'inhibitor_InChIKey': 'RNEXKKNNOIRYGI-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC(N)=Nc1ccc(Br)cc1'},
#  {'inhibitor_InChIKey': 'XMDQDPWQAWHNDK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC(N)=Nc1ccc(Cc2ccccc2)cc1'},
#  {'inhibitor_InChIKey': 'ZSJNJAJDBNFVCA-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC(N)=Nc1ccc(Cl)cc1'},
#  {'inhibitor_InChIKey': 'STTLMODNENPLQQ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC(N)=Nc1ccc(F)cc1'},
#  {'inhibitor_InChIKey': 'JMWQDIKJRCJGMY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC(N)=Nc1ccc(I)cc1'},
#  {'inhibitor_InChIKey': 'DWLMIHRZURMFAQ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC(N)=Nc1cccc(Cl)c1'},
#  {'inhibitor_InChIKey': 'XUFQPHANEAPEMJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'NC(N)=Nc1nc(CSCCC(N)=NS(N)(=O)=O)cs1'},
#  {'inhibitor_InChIKey': 'YLJREFDVOIBQDA-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Nc1c2c(nc3ccccc13)CCCC2'},
#  {'inhibitor_InChIKey': 'YLJREFDVOIBQDA-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Nc1c2c(nc3ccccc13)CCCC2'},
#  {'inhibitor_InChIKey': 'LNEPOXFFQSENCJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1'},
#  {'inhibitor_InChIKey': 'KKZJGLLVHKMTCM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'O=C1c2c(O)ccc(O)c2C(=O)c2c(NCCNCCO)ccc(NCCNCCO)c21'},
#  {'inhibitor_InChIKey': 'IZEKFCXSFNUWAM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'OCCN(CCO)c1nc(N2CCCCC2)c2nc(N(CCO)CCO)nc(N3CCCCC3)c2n1'},
#  {'inhibitor_InChIKey': 'NJMYODHXAKYRHW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'OCCN1CCN(CCC=C2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1'},
#  {'inhibitor_InChIKey': 'PLDUPXSUYLZYBN-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'OCCN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1'},
#  {'inhibitor_InChIKey': 'JFIOVJDNOJYLKP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Oc1c(Cl)cc(Cl)cc1Sc1cc(Cl)cc(Cl)c1O'},
#  {'inhibitor_InChIKey': 'JFIOVJDNOJYLKP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Oc1c(Cl)cc(Cl)cc1Sc1cc(Cl)cc(Cl)c1O'},
#  {'inhibitor_InChIKey': 'MDNWOSOZYLHTCG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Oc1ccc(Cl)cc1Cc1cc(Cl)ccc1O'},
#  {'inhibitor_InChIKey': 'YRYCIFUZSUMAAY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'c1ccc(CC2NCCc3ccccc32)cc1'},
#  {'inhibitor_InChIKey': 'CBXCPBUEXACCNR-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC[N+](CC)(CC)CC'},
#  {'inhibitor_InChIKey': 'GOEMGAFJFRBGGG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(C(C)=O)c1'},
#  {'inhibitor_InChIKey': 'AQIXAKUUQRKLND-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNC(=NCCSCc1nc[nH]c1C)NC#N'},
#  {'inhibitor_InChIKey': 'GJSURZIOUXUGAL-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Clc1cccc(Cl)c1N=C1NCCN1'},
#  {'inhibitor_InChIKey': 'OMFXVFTZEKFJBZ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC12CCC(=O)C=C1CCC1C2C(O)CC2(C)C(C(=O)CO)CCC12'},
#  {'inhibitor_InChIKey': 'FMGYKKMPNATWHP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'C[n+]1ccc(-c2ccccc2)cc1'},
#  {'inhibitor_InChIKey': 'HCYAFALTSJYZDH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNCCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'SVOQIEJWJCQGDQ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC1=NN(c2ccc(C)c(C)c2)C(=O)C1=NNc1cccc(-c2cccc(C(=O)O)c2)c1O'},
#  {'inhibitor_InChIKey': 'DDLIGBOFAVUZHB-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2'},
#  {'inhibitor_InChIKey': 'ZYVXHFWBYUDDBM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNC(=O)c1cccnc1'},
#  {'inhibitor_InChIKey': 'REQCZEXYDRLIBE-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCNC(=O)c1ccc(N)cc1'},
#  {'inhibitor_InChIKey': 'AGJZCWVTGOVGBS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN1C(=Cc2ccc3ccccc3[n+]2CC)C=Cc2ccccc21'},
#  {'inhibitor_InChIKey': 'AGJZCWVTGOVGBS-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN1C(=Cc2ccc3ccccc3[n+]2CC)C=Cc2ccccc21'},
#  {'inhibitor_InChIKey': 'LOUPRKONTZGTKE-WZBLMQSHSA-N',
#   'inhibitor_SMILES': 'C=C[C@H]1CN2CC[C@H]1C[C@H]2[C@H](O)c1ccnc2ccc(OC)cc12'},
#  {'inhibitor_InChIKey': 'CBXCPBUEXACCNR-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC[N+](CC)(CC)CC'},
#  {'inhibitor_InChIKey': 'GJSGYPDDPQRWPK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCC[N+](CCCCC)(CCCCC)CCCCC'},
#  {'inhibitor_InChIKey': 'BGSZAXLLHYERSY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)OC1CC2CCC3C(CCC4(C)C3CC([N+]3(C)CCCCC3)C4OC(C)=O)C2(C)CC1N1CCCCC1'},
#  {'inhibitor_InChIKey': 'BGSZAXLLHYERSY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)OC1CC2CCC3C(CCC4(C)C3CC([N+]3(C)CCCCC3)C4OC(C)=O)C2(C)CC1N1CCCCC1'},
#  {'inhibitor_InChIKey': 'SGTNSNPWRIOYBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'},
#  {'inhibitor_InChIKey': 'XMAYWYJOQHXEEK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)cc4Cl)O3)cc2)CC1'},
#  {'inhibitor_InChIKey': 'JRWZLRBJNMZMFE-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CC(CCc1ccc(O)cc1)NCCc1ccc(O)c(O)c1'},
#  {'inhibitor_InChIKey': 'DTIFFPXSSXFQCJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCCCCC[N+](CCCCCC)(CCCCCC)CCCCCC'},
#  {'inhibitor_InChIKey': 'WINHZLLDWRZWRT-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2C(=O)Nc3ccc(F)cc32)c1C'},
#  {'inhibitor_InChIKey': 'RYOOHIUJEJZCFT-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCNC(C(=O)OCCC(C)C)c1ccccc1'},
#  {'inhibitor_InChIKey': 'CFJMRBQWBDQYMK-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCN(CC)CCOCCOC(=O)C1(c2ccccc2)CCCC1'},
#  {'inhibitor_InChIKey': 'FAEKWTJYAYMJKF-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CCOc1cc(CC(=O)NC(CC(C)C)c2ccccc2N2CCCCC2)ccc1C(=O)O'},
#  {'inhibitor_InChIKey': 'BCGWQEUPMDMJNV-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN(C)CCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'YNNUSGIPVFPVBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CN1CCCC1CCOC(C)(c1ccccc1)c1ccc(Cl)cc1'},
#  {'inhibitor_InChIKey': 'HCYAFALTSJYZDH-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'CNCCCN1c2ccccc2CCc2ccccc21'},
#  {'inhibitor_InChIKey': 'DDUHZTYCFQRHIY-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COC1=CC(=O)CC(C)C12Oc1c(Cl)c(OC)cc(OC)c1C2=O'},
#  {'inhibitor_InChIKey': 'XCPGHVQEEXUHNC-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc(NS(C)(=O)=O)ccc1Nc1c2ccccc2nc2ccccc12'},
#  {'inhibitor_InChIKey': 'IENZQIKPVFGBNW-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'},
#  {'inhibitor_InChIKey': 'SGTNSNPWRIOYBX-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'},
#  {'inhibitor_InChIKey': 'OGHNVEJMJSYVRP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'COc1ccccc1OCCNCC(O)COc1cccc2[nH]c3ccccc3c12'},
#  {'inhibitor_InChIKey': 'JMPFSEBWVLAJKM-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Cc1cc(C(C#N)c2ccc(Cl)cc2)c(Cl)cc1NC(=O)c1cc(I)cc(I)c1O'},
#  {'inhibitor_InChIKey': 'WDZVGELJXXEGPV-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(N)NN=Cc1c(Cl)cccc1Cl'},
#  {'inhibitor_InChIKey': 'GHXZTYHSJHQHIJ-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'N=C(NCCCCCCNC(=N)NC(=N)Nc1ccc(Cl)cc1)NC(=N)Nc1ccc(Cl)cc1'},
#  {'inhibitor_InChIKey': 'JFIOVJDNOJYLKP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Oc1c(Cl)cc(Cl)cc1Sc1cc(Cl)cc(Cl)c1O'},
#  {'inhibitor_InChIKey': 'JFIOVJDNOJYLKP-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Oc1c(Cl)cc(Cl)cc1Sc1cc(Cl)cc(Cl)c1O'},
#  {'inhibitor_InChIKey': 'MDNWOSOZYLHTCG-UHFFFAOYSA-N',
#   'inhibitor_SMILES': 'Oc1ccc(Cl)cc1Cc1cc(Cl)ccc1O'}]

# %% [markdown]
# # Combing all the results into single dataframe

# %%
combined_df = combine_sources(
    [disgenet_result, loc_df, go_process_df, reactome_process_df, drug_df, disease_df, inhibitor_df]
)

# %%
combined_df.head(4)
# Out:
#   identifier identifier.source  target target.source  \
# 0       AGRN              HGNC  375790     NCBI Gene
# 1      ALG14              HGNC  199857     NCBI Gene
# 2       ALG2              HGNC   85365     NCBI Gene
# 3       CHAT              HGNC    1103     NCBI Gene
#
#                                             DisGeNET  \
# 0  [{'gene_dsi': 0.626, 'gene_dpi': 0.538, 'gene_...
# 1  [{'gene_dsi': 0.722, 'gene_dpi': 0.308, 'gene_...
# 2  [{'gene_dsi': 0.67, 'gene_dpi': 0.423, 'gene_p...
# 3  [{'gene_dsi': 0.52, 'gene_dpi': 0.808, 'gene_p...
#
#                                 OpenTargets_Location  \
# 0  [{'loc_identifier': 'SL-0243', 'subcellular_lo...
# 1  [{'loc_identifier': 'SL-0097', 'subcellular_lo...
# 2  [{'loc_identifier': 'SL-0162', 'subcellular_lo...
# 3  [{'loc_identifier': nan, 'subcellular_loc': na...
#
#                                           GO_Process  \
# 0  [{'go_id': 'GO:0005796', 'go_name': 'Golgi lum...
# 1  [{'go_id': 'GO:0006488', 'go_name': 'dolichol-...
# 2  [{'go_id': 'GO:0046982', 'go_name': 'protein h...
# 3  [{'go_id': 'GO:0004102', 'go_name': 'choline O...
#
#                                    Reactome_Pathways  \
# 0  [{'pathway_name': 'ECM proteoglycans', 'pathwa...
# 1  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 2  [{'pathway_name': 'Biosynthesis of the N-glyca...
# 3  [{'pathway_name': 'Synthesis of PC', 'pathway_...
#
#                                         ChEMBL_Drugs  \
# 0  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 1  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 2  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
# 3  [{'chembl_id': nan, 'drug_name': nan, 'relatio...
#
#                                 OpenTargets_Diseases  \
# 0  [{'disease_id': nan, 'disease_name': nan, 'the...
# 1  [{'disease_id': nan, 'disease_name': nan, 'the...
# 2  [{'disease_id': nan, 'disease_name': nan, 'the...
# 3  [{'disease_id': nan, 'disease_name': nan, 'the...
#
#                                              MolMeDB
# 0  [{'inhibitor_InChIKey': nan, 'inhibitor_SMILES...
# 1  [{'inhibitor_InChIKey': nan, 'inhibitor_SMILES...
# 2  [{'inhibitor_InChIKey': nan, 'inhibitor_SMILES...
# 3  [{'inhibitor_InChIKey': nan, 'inhibitor_SMILES...
